# %%
from skimage.filters import gabor_kernel
from skimage import io
from skimage.transform import resize
from matplotlib import pyplot as plt 
import numpy as np

import math

# %%
def get_gabor_filters(inchannels, outchannels, kernel_size = (3,3)):
    delta = 1e-4
    freqs = (math.pi/2)*(math.sqrt(2)**(-np.random.randint(0,5, (outchannels, inchannels))))
    thetas = (math.pi/8)*np.random.randint(0,8, (outchannels, inchannels))
    sigmas = math.pi/(freqs)
    psis = math.pi * np.random.rand(outchannels, inchannels)
    x0, y0 = np.ceil(np.array(kernel_size)/2)    
    
    y, x = np.meshgrid(
            np.linspace(-x0 + 1, x0 + 0, kernel_size[0]),
            np.linspace(-y0 + 1, y0 + 0, kernel_size[1]),
    )
    filterbank = []
    
    for i in range(outchannels):
        for j in range(inchannels):
            freq = freqs[i][j]
            theta = thetas[i][j]
            sigma = sigmas[i][j]
            psi = psis[i][j]
            
            rotx = x * np.cos(theta) + y * np.sin(theta)
            roty = -x * np.sin(theta) + y * np.cos(theta)

            g = np.exp(
                -0.5 * ((rotx ** 2 + roty ** 2) / (sigma + delta) ** 2)
            )
            g = g * np.cos(freq * rotx + psi)
#             g = g / (2 * math.pi * (sigma ** 2))
#             g = gabor_kernel(frequency=freq, bandwidth=sigma, theta=theta, offset=psi, n_stds=0).real
            filterbank.append(g)
    return filterbank

filterbank = get_gabor_filters(3, 64, (9,9))

fig = plt.subplots(12, 16, figsize=(22,22))
for i,gf in enumerate(filterbank):
    plt.subplot(12, 16, i+1)
    plt.imshow(gf, cmap='gray')
    plt.axis('off')

# %%
from tensorflow.keras.datasets import cifar10
from tensorflow.keras.utils import to_categorical

# The data, split between train and test sets:
(x_train, y_train), (x_test, y_test) = cifar10.load_data()
x_train = x_train.astype('float32') / 255.0
x_test = x_test.astype('float32') / 255.0

y_train = to_categorical(y_train, 10)
y_test = to_categorical(y_test, 10)

print('x_train shape:', x_train.shape)
print('x_test shape:', x_test.shape)
# Out:
# x_train shape: (50000, 32, 32, 3)
# x_test shape: (10000, 32, 32, 3)

# %%
np.array(filterbank[0]).shape
# Out:
# (9, 9)

# %%
# Importing the Keras libraries and packages
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Activation
from tensorflow.keras.layers import Input, Dense, Dropout, BatchNormalization
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import RMSprop, Adam

# dimensionality of input and latent encoded representations
inpt_dim = (32, 32, 3)

inpt_img = Input(shape=inpt_dim)

# Block 1
cl1 = Conv2D(64, (9, 9), strides=(2, 2),activation='relu', input_shape = inpt_dim)(inpt_img)
bnl2 = BatchNormalization()(cl1)
# afl3 = Activation('relu')(bnl2)
pl4 = MaxPooling2D(pool_size = (2, 2))(bnl2)

# Adding a second convolutional layer
cl5 = Conv2D(128, (3, 3), strides=(1, 1), activation='relu')(pl4)
bnl6 = BatchNormalization()(cl5)
# afl7 = Activation('relu')(bnl6)
pl8 = MaxPooling2D(pool_size = (2, 2))(bnl6)
bnl9 = BatchNormalization()(pl8)

# Step 3 - Flattening
fl10 = Flatten()(bnl9)

# Step 4 - Full connection
dol11 = Dropout(0.5)(fl10)
dl12 = Dense(units = 256, activation = 'relu')(dol11)
dol13 = Dropout(0.2)(dl12)
dl14 = Dense(units = 64, activation = 'relu')(dol13)
dol15 = Dropout(0.1)(dl14)
output = Dense(units = 10, activation = 'sigmoid')(dol15)

classifier = Model(inpt_img, output)

# Compiling the CNN
opt = RMSprop(learning_rate=0.001)
# opt = Adam(learning_rate=0.01)

classifier.compile(optimizer = opt, loss = 'binary_crossentropy', 
                   metrics = ['accuracy'])

print(classifier.summary())
# Out:
# Model: "functional_9"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_5 (InputLayer)         [(None, 32, 32, 3)]       0
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 12, 12, 64)        15616
# _________________________________________________________________
# batch_normalization_12 (Batc (None, 12, 12, 64)        256
# _________________________________________________________________
# max_pooling2d_8 (MaxPooling2 (None, 6, 6, 64)          0
# _________________________________________________________________
# conv2d_9 (Conv2D)            (None, 4, 4, 128)         73856
# _________________________________________________________________
# batch_normalization_13 (Batc (None, 4, 4, 128)         512
# _________________________________________________________________
# max_pooling2d_9 (MaxPooling2 (None, 2, 2, 128)         0
# _________________________________________________________________
# batch_normalization_14 (Batc (None, 2, 2, 128)         512
# _________________________________________________________________
# flatten_4 (Flatten)          (None, 512)               0
# _________________________________________________________________
# dropout_12 (Dropout)         (None, 512)               0
# _________________________________________________________________
# dense_12 (Dense)             (None, 256)               131328
# _________________________________________________________________
# dropout_13 (Dropout)         (None, 256)               0
# _________________________________________________________________
# dense_13 (Dense)             (None, 64)                16448
# _________________________________________________________________
# dropout_14 (Dropout)         (None, 64)                0
# _________________________________________________________________
# dense_14 (Dense)             (None, 10)                650
# =================================================================
# Total params: 239,178
# Trainable params: 238,538
# Non-trainable params: 640
# _________________________________________________________________
# None

# %%
cnnl1 = classifier.layers[1].name   # get the name of the first conv layer
W = classifier.get_layer(name=cnnl1).get_weights()[0]   #get the filters
wshape = W.shape  #save the original shape

# %%
gabor_filters = np.empty(wshape, dtype='float32')
for kernel_index in range(wshape[3]):
    for channel_index in range(3):
        gabor_filters[:,:,channel_index, kernel_index] = filterbank[kernel_index+channel_index]
# for k in range(0,wshape[3],3):
#   gabor_filters[:,:,0,k] = filterbank[k]
#   gabor_filters[:,:,1,k] = filterbank[k]
#   gabor_filters[:,:,2,k] = filterbank[k]

# %%
# Fitting the CNN to the images

from tensorflow.keras.callbacks import ReduceLROnPlateau, EarlyStopping

reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=10,  
                              min_delta=1e-4, mode='min', verbose=1)

stop_alg = EarlyStopping(monitor='val_loss', patience=35, 
                         restore_best_weights=True, verbose=1)

hist = classifier.fit(x_train, y_train, batch_size=100, epochs=1000, 
                   callbacks=[stop_alg, reduce_lr], shuffle=True, 
                   validation_data=(x_test, y_test))

classifier.save_weights("cnn.hdf5")
# Out:
# Epoch 1/1000
# 500/500 [==============================] - 20s 40ms/step - loss: 0.2775 - accuracy: 0.3520 - val_loss: 0.2731 - val_accuracy: 0.3675
# Epoch 2/1000
# 500/500 [==============================] - 20s 40ms/step - loss: 0.2290 - accuracy: 0.4741 - val_loss: 0.2377 - val_accuracy: 0.4504
# Epoch 3/1000
# 500/500 [==============================] - 20s 40ms/step - loss: 0.2123 - accuracy: 0.5198 - val_loss: 0.2112 - val_accuracy: 0.5286
# Epoch 4/1000
# 500/500 [==============================] - 20s 40ms/step - loss: 0.2016 - accuracy: 0.5513 - val_loss: 0.2112 - val_accuracy: 0.5325
# Epoch 5/1000
# 500/500 [==============================] - 20s 40ms/step - loss: 0.1932 - accuracy: 0.5722 - val_loss: 0.2472 - val_accuracy: 0.4539
# Epoch 6/1000
# 500/500 [==============================] - 20s 40ms/step - loss: 0.1863 - accuracy: 0.5901 - val_loss: 0.1966 - val_accuracy: 0.5583
# Epoch 7/1000
# 500/500 [==============================] - 20s 40ms/step - loss: 0.1803 - accuracy: 0.6062 - val_loss: 0.1780 - val_accuracy: 0.6159
# Epoch 8/1000
# 500/500 [==============================] - 20s 40ms/step - loss: 0.1752 - accuracy: 0.6197 - val_loss: 0.1793 - val_accuracy: 0.6037
# Epoch 9/1000
# 500/500 [==============================] - 20s 41ms/step - loss: 0.1716 - accuracy: 0.6259 - val_loss: 0.1953 - val_accuracy: 0.5616
# Epoch 10/1000
# 500/500 [==============================] - 21s 43ms/step - loss: 0.1676 - accuracy: 0.6380 - val_loss: 0.1820 - val_accuracy: 0.5984
# Epoch 11/1000
# 500/500 [==============================] - 21s 42ms/step - loss: 0.1634 - accuracy: 0.6469 - val_loss: 0.1681 - val_accuracy: 0.6350
# Epoch 12/1000
# 500/500 [==============================] - 21s 42ms/step - loss: 0.1598 - accuracy: 0.6562 - val_loss: 0.1803 - val_accuracy: 0.6061
# Epoch 13/1000
# 500/500 [==============================] - 20s 40ms/step - loss: 0.1576 - accuracy: 0.6630 - val_loss: 0.2229 - val_accuracy: 0.5395
# Epoch 14/1000
# 500/500 [==============================] - 20s 40ms/step - loss: 0.1550 - accuracy: 0.6697 - val_loss: 0.1764 - val_accuracy: 0.6191
# Epoch 15/1000
# 500/500 [==============================] - 23s 46ms/step - loss: 0.1520 - accuracy: 0.6758 - val_loss: 0.2018 - val_accuracy: 0.5550
# Epoch 16/1000
# 500/500 [==============================] - 23s 45ms/step - loss: 0.1506 - accuracy: 0.6801 - val_loss: 0.1755 - val_accuracy: 0.6118
# Epoch 17/1000
# 500/500 [==============================] - 24s 49ms/step - loss: 0.1483 - accuracy: 0.6864 - val_loss: 0.1531 - val_accuracy: 0.6659
# Epoch 18/1000
# 500/500 [==============================] - 24s 48ms/step - loss: 0.1460 - accuracy: 0.6914 - val_loss: 0.1563 - val_accuracy: 0.6603
# Epoch 19/1000
# 500/500 [==============================] - 22s 45ms/step - loss: 0.1444 - accuracy: 0.6938 - val_loss: 0.1435 - val_accuracy: 0.6959
# Epoch 20/1000
# 500/500 [==============================] - 25s 49ms/step - loss: 0.1429 - accuracy: 0.6992 - val_loss: 0.1664 - val_accuracy: 0.6466
# Epoch 21/1000
# 500/500 [==============================] - 21s 42ms/step - loss: 0.1418 - accuracy: 0.7008 - val_loss: 0.1497 - val_accuracy: 0.6769
# Epoch 22/1000
# 500/500 [==============================] - 20s 41ms/step - loss: 0.1395 - accuracy: 0.7074 - val_loss: 0.1473 - val_accuracy: 0.6822
# Epoch 23/1000
# 500/500 [==============================] - 22s 44ms/step - loss: 0.1390 - accuracy: 0.7075 - val_loss: 0.1563 - val_accuracy: 0.6602
# Epoch 24/1000
# 500/500 [==============================] - 22s 44ms/step - loss: 0.1370 - accuracy: 0.7122 - val_loss: 0.1900 - val_accuracy: 0.5858
# Epoch 25/1000
# 500/500 [==============================] - 31s 61ms/step - loss: 0.1352 - accuracy: 0.7172 - val_loss: 0.1567 - val_accuracy: 0.6592
# Epoch 26/1000
# 500/500 [==============================] - 35s 70ms/step - loss: 0.1355 - accuracy: 0.7180 - val_loss: 0.1600 - val_accuracy: 0.6593
# Epoch 27/1000
# 500/500 [==============================] - 41s 81ms/step - loss: 0.1345 - accuracy: 0.7181 - val_loss: 0.1534 - val_accuracy: 0.6704
# Epoch 28/1000
# 500/500 [==============================] - 40s 81ms/step - loss: 0.1329 - accuracy: 0.7239 - val_loss: 0.1498 - val_accuracy: 0.6845
# Epoch 29/1000
# 500/500 [==============================] - ETA: 0s - loss: 0.1321 - accuracy: 0.7251
# Epoch 00029: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 500/500 [==============================] - 39s 78ms/step - loss: 0.1321 - accuracy: 0.7251 - val_loss: 0.1650 - val_accuracy: 0.6568
# Epoch 30/1000
# 500/500 [==============================] - 42s 83ms/step - loss: 0.1238 - accuracy: 0.7437 - val_loss: 0.1427 - val_accuracy: 0.6985
# Epoch 31/1000
# 500/500 [==============================] - 44s 88ms/step - loss: 0.1226 - accuracy: 0.7456 - val_loss: 0.1425 - val_accuracy: 0.6997
# Epoch 32/1000
# 500/500 [==============================] - 43s 86ms/step - loss: 0.1205 - accuracy: 0.7501 - val_loss: 0.1294 - val_accuracy: 0.7295
# Epoch 33/1000
# 500/500 [==============================] - 43s 87ms/step - loss: 0.1190 - accuracy: 0.7532 - val_loss: 0.1305 - val_accuracy: 0.7268
# Epoch 34/1000
# 500/500 [==============================] - 43s 86ms/step - loss: 0.1189 - accuracy: 0.7532 - val_loss: 0.1321 - val_accuracy: 0.7234
# Epoch 35/1000
# 500/500 [==============================] - 41s 83ms/step - loss: 0.1182 - accuracy: 0.7549 - val_loss: 0.1297 - val_accuracy: 0.7277
# Epoch 36/1000
# 500/500 [==============================] - 40s 80ms/step - loss: 0.1170 - accuracy: 0.7584 - val_loss: 0.1276 - val_accuracy: 0.7371
# Epoch 37/1000
# 500/500 [==============================] - 40s 80ms/step - loss: 0.1166 - accuracy: 0.7609 - val_loss: 0.1307 - val_accuracy: 0.7275
# Epoch 38/1000
# 500/500 [==============================] - 40s 80ms/step - loss: 0.1166 - accuracy: 0.7587 - val_loss: 0.1269 - val_accuracy: 0.7348
# Epoch 39/1000
# 500/500 [==============================] - 39s 77ms/step - loss: 0.1156 - accuracy: 0.7627 - val_loss: 0.1370 - val_accuracy: 0.7145
# Epoch 40/1000
# 500/500 [==============================] - 38s 76ms/step - loss: 0.1146 - accuracy: 0.7643 - val_loss: 0.1330 - val_accuracy: 0.7254
# Epoch 41/1000
# 500/500 [==============================] - 38s 76ms/step - loss: 0.1136 - accuracy: 0.7654 - val_loss: 0.1233 - val_accuracy: 0.7393
# Epoch 42/1000
# 500/500 [==============================] - 38s 75ms/step - loss: 0.1135 - accuracy: 0.7679 - val_loss: 0.1378 - val_accuracy: 0.7125
# Epoch 43/1000
# 500/500 [==============================] - 38s 76ms/step - loss: 0.1128 - accuracy: 0.7687 - val_loss: 0.1473 - val_accuracy: 0.6974
# Epoch 44/1000
# 500/500 [==============================] - 41s 82ms/step - loss: 0.1130 - accuracy: 0.7701 - val_loss: 0.1236 - val_accuracy: 0.7453
# Epoch 45/1000
# 500/500 [==============================] - 42s 83ms/step - loss: 0.1116 - accuracy: 0.7729 - val_loss: 0.1367 - val_accuracy: 0.7211
# Epoch 46/1000
# 500/500 [==============================] - 39s 79ms/step - loss: 0.1122 - accuracy: 0.7734 - val_loss: 0.1303 - val_accuracy: 0.7304
# Epoch 47/1000
# 500/500 [==============================] - 41s 82ms/step - loss: 0.1105 - accuracy: 0.7747 - val_loss: 0.1274 - val_accuracy: 0.7315
# Epoch 48/1000
# 500/500 [==============================] - 40s 80ms/step - loss: 0.1107 - accuracy: 0.7740 - val_loss: 0.1271 - val_accuracy: 0.7401
# Epoch 49/1000
# 500/500 [==============================] - 39s 77ms/step - loss: 0.1102 - accuracy: 0.7760 - val_loss: 0.1359 - val_accuracy: 0.7186
# Epoch 50/1000
# 500/500 [==============================] - 38s 76ms/step - loss: 0.1111 - accuracy: 0.7724 - val_loss: 0.1275 - val_accuracy: 0.7372
# Epoch 51/1000
# 500/500 [==============================] - ETA: 0s - loss: 0.1098 - accuracy: 0.7761
# Epoch 00051: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 500/500 [==============================] - 38s 76ms/step - loss: 0.1098 - accuracy: 0.7761 - val_loss: 0.1356 - val_accuracy: 0.7236
# Epoch 52/1000
# 500/500 [==============================] - 40s 80ms/step - loss: 0.1063 - accuracy: 0.7844 - val_loss: 0.1201 - val_accuracy: 0.7485
# Epoch 53/1000
# 500/500 [==============================] - 39s 77ms/step - loss: 0.1043 - accuracy: 0.7870 - val_loss: 0.1200 - val_accuracy: 0.7540
# Epoch 54/1000
# 500/500 [==============================] - 40s 79ms/step - loss: 0.1048 - accuracy: 0.7882 - val_loss: 0.1184 - val_accuracy: 0.7597
# Epoch 55/1000
# 500/500 [==============================] - 39s 77ms/step - loss: 0.1034 - accuracy: 0.7900 - val_loss: 0.1204 - val_accuracy: 0.7519
# Epoch 56/1000
# 500/500 [==============================] - 39s 78ms/step - loss: 0.1034 - accuracy: 0.7916 - val_loss: 0.1208 - val_accuracy: 0.7498
# Epoch 57/1000
# 500/500 [==============================] - 38s 76ms/step - loss: 0.1021 - accuracy: 0.7919 - val_loss: 0.1255 - val_accuracy: 0.7436
# Epoch 58/1000
# 500/500 [==============================] - 38s 75ms/step - loss: 0.1028 - accuracy: 0.7924 - val_loss: 0.1234 - val_accuracy: 0.7425
# Epoch 59/1000
# 500/500 [==============================] - 38s 75ms/step - loss: 0.1032 - accuracy: 0.7915 - val_loss: 0.1186 - val_accuracy: 0.7530
# Epoch 60/1000
# 500/500 [==============================] - 38s 77ms/step - loss: 0.1023 - accuracy: 0.7935 - val_loss: 0.1188 - val_accuracy: 0.7543
# Epoch 61/1000
# 500/500 [==============================] - 42s 84ms/step - loss: 0.1013 - accuracy: 0.7951 - val_loss: 0.1181 - val_accuracy: 0.7533
# Epoch 62/1000
# 500/500 [==============================] - 43s 85ms/step - loss: 0.1012 - accuracy: 0.7954 - val_loss: 0.1184 - val_accuracy: 0.7551
# Epoch 63/1000
# 500/500 [==============================] - 39s 78ms/step - loss: 0.1010 - accuracy: 0.7954 - val_loss: 0.1195 - val_accuracy: 0.7550
# Epoch 64/1000
# 500/500 [==============================] - 39s 78ms/step - loss: 0.1005 - accuracy: 0.7985 - val_loss: 0.1195 - val_accuracy: 0.7569
# Epoch 65/1000
# 500/500 [==============================] - 40s 79ms/step - loss: 0.1007 - accuracy: 0.7966 - val_loss: 0.1295 - val_accuracy: 0.7365
# Epoch 66/1000
# 500/500 [==============================] - 38s 77ms/step - loss: 0.1008 - accuracy: 0.7951 - val_loss: 0.1201 - val_accuracy: 0.7590
# Epoch 67/1000
# 500/500 [==============================] - 40s 80ms/step - loss: 0.1003 - accuracy: 0.7973 - val_loss: 0.1225 - val_accuracy: 0.7479
# Epoch 68/1000
# 500/500 [==============================] - 43s 86ms/step - loss: 0.0992 - accuracy: 0.8006 - val_loss: 0.1228 - val_accuracy: 0.7491
# Epoch 69/1000
# 500/500 [==============================] - 41s 82ms/step - loss: 0.1000 - accuracy: 0.7975 - val_loss: 0.1195 - val_accuracy: 0.7522
# Epoch 70/1000
# 500/500 [==============================] - 40s 81ms/step - loss: 0.0991 - accuracy: 0.8008 - val_loss: 0.1211 - val_accuracy: 0.7520
# Epoch 71/1000
# 500/500 [==============================] - ETA: 0s - loss: 0.0997 - accuracy: 0.7973
# Epoch 00071: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 500/500 [==============================] - 39s 78ms/step - loss: 0.0997 - accuracy: 0.7973 - val_loss: 0.1188 - val_accuracy: 0.7534
# Epoch 72/1000
# 500/500 [==============================] - 39s 79ms/step - loss: 0.0972 - accuracy: 0.8047 - val_loss: 0.1168 - val_accuracy: 0.7582
# Epoch 73/1000
# 500/500 [==============================] - 45s 90ms/step - loss: 0.0963 - accuracy: 0.8047 - val_loss: 0.1163 - val_accuracy: 0.7605
# Epoch 74/1000
# 500/500 [==============================] - 43s 85ms/step - loss: 0.0970 - accuracy: 0.8037 - val_loss: 0.1161 - val_accuracy: 0.7630
# Epoch 75/1000
# 500/500 [==============================] - 41s 82ms/step - loss: 0.0966 - accuracy: 0.8060 - val_loss: 0.1176 - val_accuracy: 0.7604
# Epoch 76/1000
# 500/500 [==============================] - 41s 82ms/step - loss: 0.0968 - accuracy: 0.8055 - val_loss: 0.1164 - val_accuracy: 0.7589
# Epoch 77/1000
# 500/500 [==============================] - 41s 82ms/step - loss: 0.0952 - accuracy: 0.8081 - val_loss: 0.1156 - val_accuracy: 0.7644
# Epoch 78/1000
# 500/500 [==============================] - 40s 80ms/step - loss: 0.0953 - accuracy: 0.8076 - val_loss: 0.1152 - val_accuracy: 0.7665
# Epoch 79/1000
# 500/500 [==============================] - 40s 80ms/step - loss: 0.0959 - accuracy: 0.8075 - val_loss: 0.1178 - val_accuracy: 0.7588
# Epoch 80/1000
# 500/500 [==============================] - 40s 80ms/step - loss: 0.0950 - accuracy: 0.8096 - val_loss: 0.1183 - val_accuracy: 0.7571
# Epoch 81/1000
# 500/500 [==============================] - 41s 82ms/step - loss: 0.0953 - accuracy: 0.8074 - val_loss: 0.1163 - val_accuracy: 0.7619
# Epoch 82/1000
# 500/500 [==============================] - 40s 80ms/step - loss: 0.0944 - accuracy: 0.8106 - val_loss: 0.1162 - val_accuracy: 0.7630
# Epoch 83/1000
# 500/500 [==============================] - 41s 82ms/step - loss: 0.0954 - accuracy: 0.8083 - val_loss: 0.1234 - val_accuracy: 0.7523
# Epoch 84/1000
# 500/500 [==============================] - 41s 81ms/step - loss: 0.0953 - accuracy: 0.8092 - val_loss: 0.1168 - val_accuracy: 0.7598
# Epoch 85/1000
# 500/500 [==============================] - 42s 84ms/step - loss: 0.0941 - accuracy: 0.8104 - val_loss: 0.1175 - val_accuracy: 0.7632
# Epoch 86/1000
# 500/500 [==============================] - 40s 81ms/step - loss: 0.0944 - accuracy: 0.8101 - val_loss: 0.1177 - val_accuracy: 0.7593
# Epoch 87/1000
# 500/500 [==============================] - 39s 79ms/step - loss: 0.0939 - accuracy: 0.8108 - val_loss: 0.1211 - val_accuracy: 0.7531
# Epoch 88/1000
# 500/500 [==============================] - ETA: 0s - loss: 0.0942 - accuracy: 0.8125
# Epoch 00088: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 500/500 [==============================] - 40s 79ms/step - loss: 0.0942 - accuracy: 0.8125 - val_loss: 0.1161 - val_accuracy: 0.7621
# Epoch 89/1000
# 500/500 [==============================] - 41s 82ms/step - loss: 0.0939 - accuracy: 0.8131 - val_loss: 0.1171 - val_accuracy: 0.7592
# Epoch 90/1000
# 500/500 [==============================] - 41s 83ms/step - loss: 0.0924 - accuracy: 0.8153 - val_loss: 0.1153 - val_accuracy: 0.7654
# Epoch 91/1000
# 500/500 [==============================] - 43s 86ms/step - loss: 0.0933 - accuracy: 0.8126 - val_loss: 0.1158 - val_accuracy: 0.7659
# Epoch 92/1000
# 500/500 [==============================] - 42s 85ms/step - loss: 0.0924 - accuracy: 0.8153 - val_loss: 0.1169 - val_accuracy: 0.7612
# Epoch 93/1000
# 500/500 [==============================] - 48s 96ms/step - loss: 0.0925 - accuracy: 0.8146 - val_loss: 0.1159 - val_accuracy: 0.7646
# Epoch 94/1000
# 500/500 [==============================] - 46s 93ms/step - loss: 0.0920 - accuracy: 0.8143 - val_loss: 0.1161 - val_accuracy: 0.7633
# Epoch 95/1000
# 500/500 [==============================] - 46s 93ms/step - loss: 0.0920 - accuracy: 0.8148 - val_loss: 0.1171 - val_accuracy: 0.7629
# Epoch 96/1000
# 500/500 [==============================] - 43s 87ms/step - loss: 0.0925 - accuracy: 0.8155 - val_loss: 0.1153 - val_accuracy: 0.7682
# Epoch 97/1000
# 500/500 [==============================] - 39s 79ms/step - loss: 0.0934 - accuracy: 0.8145 - val_loss: 0.1156 - val_accuracy: 0.7661
# Epoch 98/1000
# 500/500 [==============================] - ETA: 0s - loss: 0.0930 - accuracy: 0.8165
# Epoch 00098: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# 500/500 [==============================] - 41s 82ms/step - loss: 0.0930 - accuracy: 0.8165 - val_loss: 0.1153 - val_accuracy: 0.7671
# Epoch 99/1000
# 500/500 [==============================] - 41s 82ms/step - loss: 0.0925 - accuracy: 0.8148 - val_loss: 0.1150 - val_accuracy: 0.7665
# Epoch 100/1000
# 500/500 [==============================] - 39s 77ms/step - loss: 0.0918 - accuracy: 0.8155 - val_loss: 0.1150 - val_accuracy: 0.7663
# Epoch 101/1000
# 500/500 [==============================] - 41s 82ms/step - loss: 0.0923 - accuracy: 0.8163 - val_loss: 0.1151 - val_accuracy: 0.7677
# Epoch 102/1000
# 500/500 [==============================] - 45s 89ms/step - loss: 0.0914 - accuracy: 0.8170 - val_loss: 0.1156 - val_accuracy: 0.7659
# Epoch 103/1000
# 500/500 [==============================] - 42s 84ms/step - loss: 0.0914 - accuracy: 0.8187 - val_loss: 0.1157 - val_accuracy: 0.7668
# Epoch 104/1000
# 500/500 [==============================] - 39s 78ms/step - loss: 0.0911 - accuracy: 0.8178 - val_loss: 0.1155 - val_accuracy: 0.7661
# Epoch 105/1000
# 500/500 [==============================] - 40s 80ms/step - loss: 0.0915 - accuracy: 0.8169 - val_loss: 0.1155 - val_accuracy: 0.7675
# Epoch 106/1000
# 500/500 [==============================] - 42s 85ms/step - loss: 0.0912 - accuracy: 0.8172 - val_loss: 0.1152 - val_accuracy: 0.7678
# Epoch 107/1000
# 500/500 [==============================] - 42s 83ms/step - loss: 0.0928 - accuracy: 0.8147 - val_loss: 0.1151 - val_accuracy: 0.7673
# Epoch 108/1000
# 500/500 [==============================] - 42s 85ms/step - loss: 0.0913 - accuracy: 0.8160 - val_loss: 0.1150 - val_accuracy: 0.7671
# Epoch 109/1000
# 500/500 [==============================] - ETA: 0s - loss: 0.0910 - accuracy: 0.8190
# Epoch 00109: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# 500/500 [==============================] - 42s 85ms/step - loss: 0.0910 - accuracy: 0.8190 - val_loss: 0.1151 - val_accuracy: 0.7657
# Epoch 110/1000
# 500/500 [==============================] - 39s 78ms/step - loss: 0.0911 - accuracy: 0.8168 - val_loss: 0.1151 - val_accuracy: 0.7674
# Epoch 111/1000
# 500/500 [==============================] - 39s 78ms/step - loss: 0.0912 - accuracy: 0.8173 - val_loss: 0.1153 - val_accuracy: 0.7675
# Epoch 112/1000
# 500/500 [==============================] - 41s 81ms/step - loss: 0.0916 - accuracy: 0.8170 - val_loss: 0.1147 - val_accuracy: 0.7681
# Epoch 113/1000
# 500/500 [==============================] - 39s 78ms/step - loss: 0.0903 - accuracy: 0.8196 - val_loss: 0.1149 - val_accuracy: 0.7674
# Epoch 114/1000
# 500/500 [==============================] - 39s 78ms/step - loss: 0.0899 - accuracy: 0.8213 - val_loss: 0.1149 - val_accuracy: 0.7671
# Epoch 115/1000
# 500/500 [==============================] - 41s 83ms/step - loss: 0.0909 - accuracy: 0.8185 - val_loss: 0.1154 - val_accuracy: 0.7656
# Epoch 116/1000
# 500/500 [==============================] - 39s 78ms/step - loss: 0.0911 - accuracy: 0.8174 - val_loss: 0.1152 - val_accuracy: 0.7663
# Epoch 117/1000
# 500/500 [==============================] - 38s 75ms/step - loss: 0.0910 - accuracy: 0.8180 - val_loss: 0.1150 - val_accuracy: 0.7667
# Epoch 118/1000
# 500/500 [==============================] - 38s 76ms/step - loss: 0.0901 - accuracy: 0.8196 - val_loss: 0.1149 - val_accuracy: 0.7676
# Epoch 119/1000
# 500/500 [==============================] - 40s 79ms/step - loss: 0.0915 - accuracy: 0.8166 - val_loss: 0.1148 - val_accuracy: 0.7677
# Epoch 120/1000
# 500/500 [==============================] - 41s 82ms/step - loss: 0.0906 - accuracy: 0.8182 - val_loss: 0.1149 - val_accuracy: 0.7682
# Epoch 121/1000
# 500/500 [==============================] - 41s 82ms/step - loss: 0.0909 - accuracy: 0.8184 - val_loss: 0.1147 - val_accuracy: 0.7687
# Epoch 122/1000
# 500/500 [==============================] - ETA: 0s - loss: 0.0898 - accuracy: 0.8202
# Epoch 00122: ReduceLROnPlateau reducing learning rate to 7.812500371073838e-06.
# 500/500 [==============================] - 41s 82ms/step - loss: 0.0898 - accuracy: 0.8202 - val_loss: 0.1150 - val_accuracy: 0.7682
# Epoch 123/1000
# 500/500 [==============================] - 40s 80ms/step - loss: 0.0902 - accuracy: 0.8207 - val_loss: 0.1150 - val_accuracy: 0.7684
# Epoch 124/1000
# 500/500 [==============================] - 45s 90ms/step - loss: 0.0910 - accuracy: 0.8194 - val_loss: 0.1148 - val_accuracy: 0.7690
# Epoch 125/1000
# 500/500 [==============================] - 42s 85ms/step - loss: 0.0905 - accuracy: 0.8176 - val_loss: 0.1148 - val_accuracy: 0.7663
# Epoch 126/1000
# 500/500 [==============================] - 44s 88ms/step - loss: 0.0908 - accuracy: 0.8183 - val_loss: 0.1150 - val_accuracy: 0.7682
# Epoch 127/1000
# 500/500 [==============================] - 42s 84ms/step - loss: 0.0908 - accuracy: 0.8192 - val_loss: 0.1150 - val_accuracy: 0.7677
# Epoch 128/1000
# 500/500 [==============================] - 42s 83ms/step - loss: 0.0908 - accuracy: 0.8184 - val_loss: 0.1149 - val_accuracy: 0.7684
# Epoch 129/1000
# 500/500 [==============================] - 40s 80ms/step - loss: 0.0899 - accuracy: 0.8217 - val_loss: 0.1150 - val_accuracy: 0.7687
# Epoch 130/1000
# 500/500 [==============================] - 41s 82ms/step - loss: 0.0905 - accuracy: 0.8214 - val_loss: 0.1150 - val_accuracy: 0.7678
# Epoch 131/1000
# 500/500 [==============================] - 41s 82ms/step - loss: 0.0905 - accuracy: 0.8182 - val_loss: 0.1151 - val_accuracy: 0.7667
# Epoch 132/1000
# 500/500 [==============================] - ETA: 0s - loss: 0.0904 - accuracy: 0.8186
# Epoch 00132: ReduceLROnPlateau reducing learning rate to 3.906250185536919e-06.
# 500/500 [==============================] - 40s 79ms/step - loss: 0.0904 - accuracy: 0.8186 - val_loss: 0.1148 - val_accuracy: 0.7688
# Epoch 133/1000
# 500/500 [==============================] - 40s 80ms/step - loss: 0.0904 - accuracy: 0.8198 - val_loss: 0.1149 - val_accuracy: 0.7684
# Epoch 134/1000
# 500/500 [==============================] - 39s 77ms/step - loss: 0.0894 - accuracy: 0.8203 - val_loss: 0.1150 - val_accuracy: 0.7688
# Epoch 135/1000
# 500/500 [==============================] - 41s 82ms/step - loss: 0.0909 - accuracy: 0.8189 - val_loss: 0.1149 - val_accuracy: 0.7688
# Epoch 136/1000
# 500/500 [==============================] - 41s 83ms/step - loss: 0.0906 - accuracy: 0.8179 - val_loss: 0.1149 - val_accuracy: 0.7695
# Epoch 137/1000
# 500/500 [==============================] - 42s 83ms/step - loss: 0.0908 - accuracy: 0.8176 - val_loss: 0.1149 - val_accuracy: 0.7690
# Epoch 138/1000
# 500/500 [==============================] - 41s 82ms/step - loss: 0.0894 - accuracy: 0.8217 - val_loss: 0.1149 - val_accuracy: 0.7688
# Epoch 139/1000
# 500/500 [==============================] - 40s 81ms/step - loss: 0.0907 - accuracy: 0.8209 - val_loss: 0.1148 - val_accuracy: 0.7689
# Epoch 140/1000
# 500/500 [==============================] - 40s 80ms/step - loss: 0.0894 - accuracy: 0.8216 - val_loss: 0.1149 - val_accuracy: 0.7691
# Epoch 141/1000
# 500/500 [==============================] - 40s 79ms/step - loss: 0.0896 - accuracy: 0.8214 - val_loss: 0.1149 - val_accuracy: 0.7686
# Epoch 142/1000
# 500/500 [==============================] - ETA: 0s - loss: 0.0904 - accuracy: 0.8211
# Epoch 00142: ReduceLROnPlateau reducing learning rate to 1.9531250927684596e-06.
# 500/500 [==============================] - 41s 81ms/step - loss: 0.0904 - accuracy: 0.8211 - val_loss: 0.1149 - val_accuracy: 0.7686
# Epoch 143/1000
# 500/500 [==============================] - 40s 80ms/step - loss: 0.0905 - accuracy: 0.8192 - val_loss: 0.1149 - val_accuracy: 0.7691
# Epoch 144/1000
# 500/500 [==============================] - 40s 80ms/step - loss: 0.0908 - accuracy: 0.8182 - val_loss: 0.1149 - val_accuracy: 0.7691
# Epoch 145/1000
# 500/500 [==============================] - 40s 81ms/step - loss: 0.0910 - accuracy: 0.8167 - val_loss: 0.1148 - val_accuracy: 0.7694
# Epoch 146/1000
# 500/500 [==============================] - 40s 80ms/step - loss: 0.0901 - accuracy: 0.8186 - val_loss: 0.1149 - val_accuracy: 0.7684
# Epoch 147/1000
# 500/500 [==============================] - 40s 79ms/step - loss: 0.0904 - accuracy: 0.8201 - val_loss: 0.1149 - val_accuracy: 0.7689
# Epoch 148/1000
# 500/500 [==============================] - 42s 83ms/step - loss: 0.0896 - accuracy: 0.8198 - val_loss: 0.1149 - val_accuracy: 0.7686
# Epoch 149/1000
# 500/500 [==============================] - 41s 81ms/step - loss: 0.0901 - accuracy: 0.8197 - val_loss: 0.1149 - val_accuracy: 0.7683
# Epoch 150/1000
# 500/500 [==============================] - 41s 83ms/step - loss: 0.0897 - accuracy: 0.8204 - val_loss: 0.1149 - val_accuracy: 0.7690
# Epoch 151/1000
# 500/500 [==============================] - 42s 84ms/step - loss: 0.0911 - accuracy: 0.8184 - val_loss: 0.1148 - val_accuracy: 0.7680
# Epoch 152/1000
# 500/500 [==============================] - ETA: 0s - loss: 0.0902 - accuracy: 0.8187
# Epoch 00152: ReduceLROnPlateau reducing learning rate to 9.765625463842298e-07.
# 500/500 [==============================] - 39s 78ms/step - loss: 0.0902 - accuracy: 0.8187 - val_loss: 0.1149 - val_accuracy: 0.7690
# Epoch 153/1000
# 500/500 [==============================] - 38s 76ms/step - loss: 0.0902 - accuracy: 0.8210 - val_loss: 0.1149 - val_accuracy: 0.7691
# Epoch 154/1000
# 500/500 [==============================] - 42s 84ms/step - loss: 0.0909 - accuracy: 0.8182 - val_loss: 0.1149 - val_accuracy: 0.7694
# Epoch 155/1000
# 500/500 [==============================] - 40s 81ms/step - loss: 0.0898 - accuracy: 0.8189 - val_loss: 0.1149 - val_accuracy: 0.7689
# Epoch 156/1000
# 500/500 [==============================] - ETA: 0s - loss: 0.0906 - accuracy: 0.8195Restoring model weights from the end of the best epoch.
# 500/500 [==============================] - 39s 78ms/step - loss: 0.0906 - accuracy: 0.8195 - val_loss: 0.1149 - val_accuracy: 0.7689
# Epoch 00156: early stopping

# %%
import matplotlib.pyplot as plt

fig = plt.figure(figsize=(10,6))
plt.plot(hist.history['loss'], color='#785ef0')
plt.plot(hist.history['val_loss'], color='#dc267f')
plt.title('Model Loss Progress')
plt.ylabel('Binary Cross-Entropy Loss')
plt.xlabel('Epoch')
plt.legend(['Training Set', 'Test Set'], loc='upper right')
plt.savefig('9*9 freq-5 theta-8 loss.png', dpi=350, bbox_inches='tight')
plt.show()

# %%
from sklearn.preprocessing import MinMaxScaler

cnnl1 = classifier.layers[1].name   # get the name of the first conv layer
W = classifier.get_layer(name=cnnl1).get_weights()[0]   #get the filters
wshape = W.shape  #save the original shape

# this part will scale to [0, 1] for visualization purposes
scaler = MinMaxScaler()
scaler.fit(W.reshape(-1,1))
W = scaler.transform(W.reshape(-1,1))
W = W.reshape(wshape)

# since there are 64 filters, we will display them 8x8
fig, axs = plt.subplots(8,8, figsize=(24,24))
fig.subplots_adjust(hspace = .25, wspace=.001)
axs = axs.ravel()
for i in range(W.shape[-1]):
  # we reshape to a 3D (RGB) image shape and display
  h = np.reshape(W[:,:,:,i], (9,9,3))
  axs[i].imshow(h)
  axs[i].set_title('Filter ' + str(i))    
plt.savefig("9*9 freq-5 theta-8 filters.png", bbox_inches='tight', dpi=350)

# %%
W.shape
# Out:
# (9, 9, 3, 64)

# %%
fig = plt.subplots(12, 16, figsize=(22,22))

filter_layers = []
for i in range(64):
    for j in range(3):
        filter_layers.append(np.reshape(W[:,:,j, i], (9,9)))
for i,gf in enumerate(filter_layers):
    plt.subplot(12, 16, i+1)
    plt.imshow(gf, cmap='gray')
    plt.axis('off')
