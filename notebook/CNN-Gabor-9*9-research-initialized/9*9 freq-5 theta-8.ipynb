# %%
from skimage.filters import gabor_kernel
from skimage import io
from skimage.transform import resize
from matplotlib import pyplot as plt 
import numpy as np

import math

# %%
def get_gabor_filters(inchannels, outchannels, kernel_size = (3,3)):
    delta = 1e-4
    freqs = (math.pi/2)*(math.sqrt(2)**(-np.random.randint(0,5, (outchannels, inchannels))))
    thetas = (math.pi/8)*np.random.randint(0,8, (outchannels, inchannels))
    sigmas = math.pi/(freqs)
    psis = math.pi * np.random.rand(outchannels, inchannels)
    x0, y0 = np.ceil(np.array(kernel_size)/2)    
    
    y, x = np.meshgrid(
            np.linspace(-x0 + 1, x0 + 0, kernel_size[0]),
            np.linspace(-y0 + 1, y0 + 0, kernel_size[1]),
    )
    filterbank = []
    
    for i in range(outchannels):
        for j in range(inchannels):
            freq = freqs[i][j]
            theta = thetas[i][j]
            sigma = sigmas[i][j]
            psi = psis[i][j]
            
            rotx = x * np.cos(theta) + y * np.sin(theta)
            roty = -x * np.sin(theta) + y * np.cos(theta)

            g = np.exp(
                -0.5 * ((rotx ** 2 + roty ** 2) / (sigma + delta) ** 2)
            )
            g = g * np.cos(freq * rotx + psi)
#             g = g / (2 * math.pi * (sigma ** 2))
#             g = gabor_kernel(frequency=freq, bandwidth=sigma, theta=theta, offset=psi, n_stds=0).real
            filterbank.append(g)
    return filterbank

filterbank = get_gabor_filters(3, 64, (9,9))

fig = plt.subplots(12, 16, figsize=(22,22))
for i,gf in enumerate(filterbank):
    plt.subplot(12, 16, i+1)
    plt.imshow(gf, cmap='gray')
    plt.axis('off')

# %%
from tensorflow.keras.datasets import cifar10
from tensorflow.keras.utils import to_categorical

# The data, split between train and test sets:
(x_train, y_train), (x_test, y_test) = cifar10.load_data()
x_train = x_train.astype('float32') / 255.0
x_test = x_test.astype('float32') / 255.0

y_train = to_categorical(y_train, 10)
y_test = to_categorical(y_test, 10)

print('x_train shape:', x_train.shape)
print('x_test shape:', x_test.shape)
# Out:
# x_train shape: (50000, 32, 32, 3)
# x_test shape: (10000, 32, 32, 3)

# %%
np.array(filterbank[0]).shape
# Out:
# (9, 9)

# %%
# Importing the Keras libraries and packages
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Activation
from tensorflow.keras.layers import Input, Dense, Dropout, BatchNormalization
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import RMSprop, Adam

# dimensionality of input and latent encoded representations
inpt_dim = (32, 32, 3)

inpt_img = Input(shape=inpt_dim)

# Block 1
cl1 = Conv2D(64, (9, 9), strides=(2, 2),activation='relu', input_shape = inpt_dim)(inpt_img)
bnl2 = BatchNormalization()(cl1)
# afl3 = Activation('relu')(bnl2)
pl4 = MaxPooling2D(pool_size = (2, 2))(bnl2)

# Adding a second convolutional layer
cl5 = Conv2D(128, (3, 3), strides=(1, 1), activation='relu')(pl4)
bnl6 = BatchNormalization()(cl5)
# afl7 = Activation('relu')(bnl6)
pl8 = MaxPooling2D(pool_size = (2, 2))(bnl6)
bnl9 = BatchNormalization()(pl8)

# Step 3 - Flattening
fl10 = Flatten()(bnl9)

# Step 4 - Full connection
dol11 = Dropout(0.5)(fl10)
dl12 = Dense(units = 256, activation = 'relu')(dol11)
dol13 = Dropout(0.2)(dl12)
dl14 = Dense(units = 64, activation = 'relu')(dol13)
dol15 = Dropout(0.1)(dl14)
output = Dense(units = 10, activation = 'sigmoid')(dol15)

classifier = Model(inpt_img, output)

# Compiling the CNN
opt = RMSprop(learning_rate=0.001)
# opt = Adam(learning_rate=0.01)

classifier.compile(optimizer = opt, loss = 'binary_crossentropy', 
                   metrics = ['accuracy'])

print(classifier.summary())
# Out:
# Model: "functional_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 32, 32, 3)]       0
# _________________________________________________________________
# conv2d (Conv2D)              (None, 12, 12, 64)        15616
# _________________________________________________________________
# batch_normalization (BatchNo (None, 12, 12, 64)        256
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 6, 6, 64)          0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 4, 4, 128)         73856
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 4, 4, 128)         512
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 2, 2, 128)         0
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 2, 2, 128)         512
# _________________________________________________________________
# flatten (Flatten)            (None, 512)               0
# _________________________________________________________________
# dropout (Dropout)            (None, 512)               0
# _________________________________________________________________
# dense (Dense)                (None, 256)               131328
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 64)                16448
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 64)                0
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                650
# =================================================================
# Total params: 239,178
# Trainable params: 238,538
# Non-trainable params: 640
# _________________________________________________________________
# None

# %%
cnnl1 = classifier.layers[1].name   # get the name of the first conv layer
W = classifier.get_layer(name=cnnl1).get_weights()[0]   #get the filters
wshape = W.shape  #save the original shape

# %%
gabor_filters = W
for kernel_index in range(wshape[3]):
    for channel_index in range(3):
        gabor_filters[:,:,channel_index, kernel_index] = filterbank[kernel_index+channel_index]

cnnl1 = classifier.layers[1].name   # get the name of the first conv layer
classifier.get_layer(name=cnnl1).set_weights([gabor_filters, classifier.get_layer(name=cnnl1).get_weights()[1]])
filter_layers = []
for i in range(64):
    for j in range(3):
        filter_layers.append(np.reshape(W[:,:,j, i], (9,9)))
for i,gf in enumerate(filter_layers):
    plt.subplot(12, 16, i+1)
    plt.imshow(gf, cmap='gray')
    plt.axis('off')

# %%
# Fitting the CNN to the images

from tensorflow.keras.callbacks import ReduceLROnPlateau, EarlyStopping

reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=10,  
                              min_delta=1e-4, mode='min', verbose=1)

stop_alg = EarlyStopping(monitor='val_loss', patience=35, 
                         restore_best_weights=True, verbose=1)

hist = classifier.fit(x_train, y_train, batch_size=100, epochs=1000, 
                   callbacks=[stop_alg, reduce_lr], shuffle=True, 
                   validation_data=(x_test, y_test))

classifier.save_weights("cnn.hdf5")
# Out:
# Epoch 1/1000
# 500/500 [==============================] - 42s 84ms/step - loss: 0.2633 - accuracy: 0.4043 - val_loss: 0.2136 - val_accuracy: 0.5033
# Epoch 2/1000
# 500/500 [==============================] - 44s 88ms/step - loss: 0.2146 - accuracy: 0.5188 - val_loss: 0.1888 - val_accuracy: 0.5806
# Epoch 3/1000
# 500/500 [==============================] - 53s 107ms/step - loss: 0.1989 - accuracy: 0.5576 - val_loss: 0.1937 - val_accuracy: 0.5704
# Epoch 4/1000
# 500/500 [==============================] - 53s 106ms/step - loss: 0.1892 - accuracy: 0.5858 - val_loss: 0.1717 - val_accuracy: 0.6309
# Epoch 5/1000
# 500/500 [==============================] - 51s 103ms/step - loss: 0.1806 - accuracy: 0.6069 - val_loss: 0.1682 - val_accuracy: 0.6319
# Epoch 6/1000
# 500/500 [==============================] - 50s 100ms/step - loss: 0.1737 - accuracy: 0.6244 - val_loss: 0.1606 - val_accuracy: 0.6521
# Epoch 7/1000
# 500/500 [==============================] - 50s 100ms/step - loss: 0.1682 - accuracy: 0.6368 - val_loss: 0.1571 - val_accuracy: 0.6681
# Epoch 8/1000
# 500/500 [==============================] - 51s 101ms/step - loss: 0.1639 - accuracy: 0.6507 - val_loss: 0.1517 - val_accuracy: 0.6785
# Epoch 9/1000
# 500/500 [==============================] - 50s 101ms/step - loss: 0.1599 - accuracy: 0.6576 - val_loss: 0.1533 - val_accuracy: 0.6702
# Epoch 10/1000
# 500/500 [==============================] - 52s 103ms/step - loss: 0.1555 - accuracy: 0.6685 - val_loss: 0.1551 - val_accuracy: 0.6689
# Epoch 11/1000
# 500/500 [==============================] - 52s 105ms/step - loss: 0.1526 - accuracy: 0.6767 - val_loss: 0.1688 - val_accuracy: 0.6359
# Epoch 12/1000
# 500/500 [==============================] - 51s 102ms/step - loss: 0.1489 - accuracy: 0.6829 - val_loss: 0.1781 - val_accuracy: 0.6255
# Epoch 13/1000
# 500/500 [==============================] - 51s 102ms/step - loss: 0.1475 - accuracy: 0.6898 - val_loss: 0.1566 - val_accuracy: 0.6715
# Epoch 14/1000
# 500/500 [==============================] - 51s 102ms/step - loss: 0.1453 - accuracy: 0.6925 - val_loss: 0.1465 - val_accuracy: 0.6891
# Epoch 15/1000
# 500/500 [==============================] - 52s 104ms/step - loss: 0.1426 - accuracy: 0.6975 - val_loss: 0.1407 - val_accuracy: 0.7053
# Epoch 16/1000
# 500/500 [==============================] - 52s 105ms/step - loss: 0.1400 - accuracy: 0.7047 - val_loss: 0.1448 - val_accuracy: 0.6956
# Epoch 17/1000
# 500/500 [==============================] - 51s 102ms/step - loss: 0.1386 - accuracy: 0.7081 - val_loss: 0.1447 - val_accuracy: 0.6881
# Epoch 18/1000
# 500/500 [==============================] - 50s 101ms/step - loss: 0.1369 - accuracy: 0.7126 - val_loss: 0.1353 - val_accuracy: 0.7186
# Epoch 19/1000
# 500/500 [==============================] - 51s 101ms/step - loss: 0.1364 - accuracy: 0.7141 - val_loss: 0.1510 - val_accuracy: 0.6803
# Epoch 20/1000
# 500/500 [==============================] - 50s 100ms/step - loss: 0.1336 - accuracy: 0.7205 - val_loss: 0.1353 - val_accuracy: 0.7151
# Epoch 21/1000
# 500/500 [==============================] - 51s 102ms/step - loss: 0.1330 - accuracy: 0.7227 - val_loss: 0.1445 - val_accuracy: 0.6946
# Epoch 22/1000
# 500/500 [==============================] - 51s 102ms/step - loss: 0.1312 - accuracy: 0.7266 - val_loss: 0.1490 - val_accuracy: 0.6925
# Epoch 23/1000
# 500/500 [==============================] - 50s 101ms/step - loss: 0.1298 - accuracy: 0.7288 - val_loss: 0.1399 - val_accuracy: 0.7023
# Epoch 24/1000
# 500/500 [==============================] - 52s 103ms/step - loss: 0.1281 - accuracy: 0.7334 - val_loss: 0.1419 - val_accuracy: 0.7072
# Epoch 25/1000
# 500/500 [==============================] - 51s 102ms/step - loss: 0.1277 - accuracy: 0.7345 - val_loss: 0.1503 - val_accuracy: 0.6816
# Epoch 26/1000
# 500/500 [==============================] - 50s 99ms/step - loss: 0.1261 - accuracy: 0.7391 - val_loss: 0.1483 - val_accuracy: 0.6916
# Epoch 27/1000
# 500/500 [==============================] - 49s 99ms/step - loss: 0.1248 - accuracy: 0.7418 - val_loss: 0.1493 - val_accuracy: 0.6772
# Epoch 28/1000
# 500/500 [==============================] - ETA: 0s - loss: 0.1243 - accuracy: 0.7443
# Epoch 00028: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 500/500 [==============================] - 50s 99ms/step - loss: 0.1243 - accuracy: 0.7443 - val_loss: 0.1462 - val_accuracy: 0.6946
# Epoch 29/1000
# 500/500 [==============================] - 49s 99ms/step - loss: 0.1173 - accuracy: 0.7578 - val_loss: 0.1304 - val_accuracy: 0.7262
# Epoch 30/1000
# 500/500 [==============================] - 46s 93ms/step - loss: 0.1154 - accuracy: 0.7621 - val_loss: 0.1284 - val_accuracy: 0.7298
# Epoch 31/1000
# 500/500 [==============================] - 49s 97ms/step - loss: 0.1146 - accuracy: 0.7639 - val_loss: 0.1274 - val_accuracy: 0.7356
# Epoch 32/1000
# 500/500 [==============================] - 49s 99ms/step - loss: 0.1139 - accuracy: 0.7660 - val_loss: 0.1255 - val_accuracy: 0.7345
# Epoch 33/1000
# 500/500 [==============================] - 49s 99ms/step - loss: 0.1125 - accuracy: 0.7684 - val_loss: 0.1242 - val_accuracy: 0.7398
# Epoch 34/1000
# 500/500 [==============================] - 49s 99ms/step - loss: 0.1126 - accuracy: 0.7675 - val_loss: 0.1236 - val_accuracy: 0.7406
# Epoch 35/1000
# 500/500 [==============================] - 49s 98ms/step - loss: 0.1112 - accuracy: 0.7729 - val_loss: 0.1235 - val_accuracy: 0.7400
# Epoch 36/1000
# 500/500 [==============================] - 49s 99ms/step - loss: 0.1098 - accuracy: 0.7758 - val_loss: 0.1272 - val_accuracy: 0.7378
# Epoch 37/1000
# 500/500 [==============================] - 49s 98ms/step - loss: 0.1101 - accuracy: 0.7753 - val_loss: 0.1230 - val_accuracy: 0.7419
# Epoch 38/1000
# 500/500 [==============================] - 49s 99ms/step - loss: 0.1088 - accuracy: 0.7781 - val_loss: 0.1244 - val_accuracy: 0.7357
# Epoch 39/1000
# 500/500 [==============================] - 49s 99ms/step - loss: 0.1069 - accuracy: 0.7818 - val_loss: 0.1232 - val_accuracy: 0.7432
# Epoch 40/1000
# 500/500 [==============================] - 49s 98ms/step - loss: 0.1077 - accuracy: 0.7796 - val_loss: 0.1220 - val_accuracy: 0.7451
# Epoch 41/1000
# 500/500 [==============================] - 49s 99ms/step - loss: 0.1069 - accuracy: 0.7815 - val_loss: 0.1227 - val_accuracy: 0.7412
# Epoch 42/1000
# 500/500 [==============================] - 49s 98ms/step - loss: 0.1071 - accuracy: 0.7822 - val_loss: 0.1227 - val_accuracy: 0.7465
# Epoch 43/1000
# 500/500 [==============================] - 49s 98ms/step - loss: 0.1066 - accuracy: 0.7835 - val_loss: 0.1230 - val_accuracy: 0.7465
# Epoch 44/1000
# 500/500 [==============================] - 49s 98ms/step - loss: 0.1053 - accuracy: 0.7856 - val_loss: 0.1208 - val_accuracy: 0.7528
# Epoch 45/1000
# 500/500 [==============================] - 49s 98ms/step - loss: 0.1051 - accuracy: 0.7861 - val_loss: 0.1274 - val_accuracy: 0.7374
# Epoch 46/1000
# 500/500 [==============================] - 49s 98ms/step - loss: 0.1049 - accuracy: 0.7873 - val_loss: 0.1251 - val_accuracy: 0.7406
# Epoch 47/1000
# 500/500 [==============================] - 49s 99ms/step - loss: 0.1047 - accuracy: 0.7869 - val_loss: 0.1247 - val_accuracy: 0.7392
# Epoch 48/1000
# 500/500 [==============================] - 50s 99ms/step - loss: 0.1044 - accuracy: 0.7876 - val_loss: 0.1286 - val_accuracy: 0.7309
# Epoch 49/1000
# 500/500 [==============================] - 50s 100ms/step - loss: 0.1027 - accuracy: 0.7926 - val_loss: 0.1205 - val_accuracy: 0.7513
# Epoch 50/1000
# 500/500 [==============================] - 50s 99ms/step - loss: 0.1030 - accuracy: 0.7914 - val_loss: 0.1217 - val_accuracy: 0.7446
# Epoch 51/1000
# 500/500 [==============================] - 49s 99ms/step - loss: 0.1030 - accuracy: 0.7904 - val_loss: 0.1222 - val_accuracy: 0.7463
# Epoch 52/1000
# 500/500 [==============================] - 50s 99ms/step - loss: 0.1029 - accuracy: 0.7915 - val_loss: 0.1211 - val_accuracy: 0.7469
# Epoch 53/1000
# 500/500 [==============================] - 49s 99ms/step - loss: 0.1023 - accuracy: 0.7927 - val_loss: 0.1234 - val_accuracy: 0.7433
# Epoch 54/1000
# 500/500 [==============================] - 49s 99ms/step - loss: 0.1011 - accuracy: 0.7935 - val_loss: 0.1252 - val_accuracy: 0.7413
# Epoch 55/1000
# 500/500 [==============================] - 49s 99ms/step - loss: 0.1013 - accuracy: 0.7955 - val_loss: 0.1267 - val_accuracy: 0.7384
# Epoch 56/1000
# 500/500 [==============================] - 50s 100ms/step - loss: 0.1008 - accuracy: 0.7941 - val_loss: 0.1211 - val_accuracy: 0.7482
# Epoch 57/1000
# 500/500 [==============================] - 49s 99ms/step - loss: 0.1008 - accuracy: 0.7962 - val_loss: 0.1280 - val_accuracy: 0.7311
# Epoch 58/1000
# 500/500 [==============================] - 50s 100ms/step - loss: 0.0996 - accuracy: 0.7993 - val_loss: 0.1222 - val_accuracy: 0.7473
# Epoch 59/1000
# 500/500 [==============================] - ETA: 0s - loss: 0.0996 - accuracy: 0.7989
# Epoch 00059: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 500/500 [==============================] - 50s 100ms/step - loss: 0.0996 - accuracy: 0.7989 - val_loss: 0.1234 - val_accuracy: 0.7472
# Epoch 60/1000
# 500/500 [==============================] - 50s 99ms/step - loss: 0.0959 - accuracy: 0.8069 - val_loss: 0.1185 - val_accuracy: 0.7558
# Epoch 61/1000
# 500/500 [==============================] - 49s 99ms/step - loss: 0.0956 - accuracy: 0.8078 - val_loss: 0.1224 - val_accuracy: 0.7455
# Epoch 62/1000
# 500/500 [==============================] - 46s 92ms/step - loss: 0.0950 - accuracy: 0.8088 - val_loss: 0.1270 - val_accuracy: 0.7428
# Epoch 63/1000
# 500/500 [==============================] - 47s 94ms/step - loss: 0.0952 - accuracy: 0.8100 - val_loss: 0.1191 - val_accuracy: 0.7570
# Epoch 64/1000
# 500/500 [==============================] - 50s 99ms/step - loss: 0.0950 - accuracy: 0.8090 - val_loss: 0.1188 - val_accuracy: 0.7554
# Epoch 65/1000
# 500/500 [==============================] - 50s 99ms/step - loss: 0.0930 - accuracy: 0.8138 - val_loss: 0.1178 - val_accuracy: 0.7569
# Epoch 66/1000
# 500/500 [==============================] - 50s 100ms/step - loss: 0.0940 - accuracy: 0.8128 - val_loss: 0.1205 - val_accuracy: 0.7493
# Epoch 67/1000
# 500/500 [==============================] - 50s 100ms/step - loss: 0.0933 - accuracy: 0.8133 - val_loss: 0.1199 - val_accuracy: 0.7539
# Epoch 68/1000
# 500/500 [==============================] - 50s 100ms/step - loss: 0.0923 - accuracy: 0.8148 - val_loss: 0.1201 - val_accuracy: 0.7529
# Epoch 69/1000
# 500/500 [==============================] - 50s 100ms/step - loss: 0.0929 - accuracy: 0.8137 - val_loss: 0.1211 - val_accuracy: 0.7550
# Epoch 70/1000
# 500/500 [==============================] - 49s 99ms/step - loss: 0.0919 - accuracy: 0.8149 - val_loss: 0.1223 - val_accuracy: 0.7490
# Epoch 71/1000
# 500/500 [==============================] - 49s 99ms/step - loss: 0.0918 - accuracy: 0.8156 - val_loss: 0.1203 - val_accuracy: 0.7555
# Epoch 72/1000
# 500/500 [==============================] - 50s 100ms/step - loss: 0.0934 - accuracy: 0.8136 - val_loss: 0.1177 - val_accuracy: 0.7589
# Epoch 73/1000
# 500/500 [==============================] - 50s 101ms/step - loss: 0.0921 - accuracy: 0.8162 - val_loss: 0.1224 - val_accuracy: 0.7515
# Epoch 74/1000
# 500/500 [==============================] - 49s 99ms/step - loss: 0.0904 - accuracy: 0.8188 - val_loss: 0.1186 - val_accuracy: 0.7557
# Epoch 75/1000
# 500/500 [==============================] - ETA: 0s - loss: 0.0916 - accuracy: 0.8186
# Epoch 00075: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 500/500 [==============================] - 50s 99ms/step - loss: 0.0916 - accuracy: 0.8186 - val_loss: 0.1192 - val_accuracy: 0.7566
# Epoch 76/1000
# 500/500 [==============================] - 49s 99ms/step - loss: 0.0902 - accuracy: 0.8182 - val_loss: 0.1176 - val_accuracy: 0.7606
# Epoch 77/1000
# 500/500 [==============================] - 50s 99ms/step - loss: 0.0902 - accuracy: 0.8203 - val_loss: 0.1180 - val_accuracy: 0.7581
# Epoch 78/1000
# 500/500 [==============================] - 50s 99ms/step - loss: 0.0896 - accuracy: 0.8223 - val_loss: 0.1198 - val_accuracy: 0.7568
# Epoch 79/1000
# 500/500 [==============================] - 49s 99ms/step - loss: 0.0883 - accuracy: 0.8244 - val_loss: 0.1186 - val_accuracy: 0.7571
# Epoch 80/1000
# 500/500 [==============================] - 49s 98ms/step - loss: 0.0886 - accuracy: 0.8219 - val_loss: 0.1181 - val_accuracy: 0.7604
# Epoch 81/1000
# 500/500 [==============================] - 50s 99ms/step - loss: 0.0884 - accuracy: 0.8248 - val_loss: 0.1186 - val_accuracy: 0.7580
# Epoch 82/1000
# 500/500 [==============================] - 50s 99ms/step - loss: 0.0888 - accuracy: 0.8236 - val_loss: 0.1188 - val_accuracy: 0.7570
# Epoch 83/1000
# 500/500 [==============================] - 50s 99ms/step - loss: 0.0880 - accuracy: 0.8230 - val_loss: 0.1179 - val_accuracy: 0.7612
# Epoch 84/1000
# 500/500 [==============================] - 50s 99ms/step - loss: 0.0884 - accuracy: 0.8250 - val_loss: 0.1200 - val_accuracy: 0.7558
# Epoch 85/1000
# 500/500 [==============================] - 50s 100ms/step - loss: 0.0883 - accuracy: 0.8254 - val_loss: 0.1181 - val_accuracy: 0.7582
# Epoch 86/1000
# 500/500 [==============================] - ETA: 0s - loss: 0.0882 - accuracy: 0.8253
# Epoch 00086: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 500/500 [==============================] - 50s 99ms/step - loss: 0.0882 - accuracy: 0.8253 - val_loss: 0.1188 - val_accuracy: 0.7578
# Epoch 87/1000
# 500/500 [==============================] - 50s 99ms/step - loss: 0.0874 - accuracy: 0.8245 - val_loss: 0.1175 - val_accuracy: 0.7590
# Epoch 88/1000
# 500/500 [==============================] - 49s 99ms/step - loss: 0.0872 - accuracy: 0.8282 - val_loss: 0.1180 - val_accuracy: 0.7592
# Epoch 89/1000
# 500/500 [==============================] - 50s 99ms/step - loss: 0.0864 - accuracy: 0.8275 - val_loss: 0.1176 - val_accuracy: 0.7604
# Epoch 90/1000
# 500/500 [==============================] - 49s 98ms/step - loss: 0.0859 - accuracy: 0.8283 - val_loss: 0.1188 - val_accuracy: 0.7601
# Epoch 91/1000
# 500/500 [==============================] - 49s 99ms/step - loss: 0.0866 - accuracy: 0.8277 - val_loss: 0.1182 - val_accuracy: 0.7597
# Epoch 92/1000
# 500/500 [==============================] - 49s 98ms/step - loss: 0.0863 - accuracy: 0.8286 - val_loss: 0.1178 - val_accuracy: 0.7614
# Epoch 93/1000
# 500/500 [==============================] - 49s 98ms/step - loss: 0.0864 - accuracy: 0.8284 - val_loss: 0.1183 - val_accuracy: 0.7608
# Epoch 94/1000
# 500/500 [==============================] - 47s 95ms/step - loss: 0.0864 - accuracy: 0.8283 - val_loss: 0.1175 - val_accuracy: 0.7610
# Epoch 95/1000
# 500/500 [==============================] - 46s 93ms/step - loss: 0.0857 - accuracy: 0.8299 - val_loss: 0.1175 - val_accuracy: 0.7606
# Epoch 96/1000
# 500/500 [==============================] - 48s 97ms/step - loss: 0.0855 - accuracy: 0.8295 - val_loss: 0.1184 - val_accuracy: 0.7605
# Epoch 97/1000
# 500/500 [==============================] - ETA: 0s - loss: 0.0855 - accuracy: 0.8319
# Epoch 00097: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# 500/500 [==============================] - 49s 99ms/step - loss: 0.0855 - accuracy: 0.8319 - val_loss: 0.1177 - val_accuracy: 0.7620
# Epoch 98/1000
# 500/500 [==============================] - 50s 99ms/step - loss: 0.0857 - accuracy: 0.8294 - val_loss: 0.1174 - val_accuracy: 0.7627
# Epoch 99/1000
# 500/500 [==============================] - 50s 100ms/step - loss: 0.0853 - accuracy: 0.8315 - val_loss: 0.1174 - val_accuracy: 0.7621
# Epoch 100/1000
# 500/500 [==============================] - 49s 98ms/step - loss: 0.0852 - accuracy: 0.8306 - val_loss: 0.1178 - val_accuracy: 0.7614
# Epoch 101/1000
# 500/500 [==============================] - 49s 99ms/step - loss: 0.0849 - accuracy: 0.8300 - val_loss: 0.1175 - val_accuracy: 0.7632
# Epoch 102/1000
# 500/500 [==============================] - 50s 99ms/step - loss: 0.0852 - accuracy: 0.8312 - val_loss: 0.1175 - val_accuracy: 0.7635
# Epoch 103/1000
# 500/500 [==============================] - 49s 98ms/step - loss: 0.0847 - accuracy: 0.8299 - val_loss: 0.1177 - val_accuracy: 0.7623
# Epoch 104/1000
# 500/500 [==============================] - 50s 100ms/step - loss: 0.0850 - accuracy: 0.8301 - val_loss: 0.1180 - val_accuracy: 0.7630
# Epoch 105/1000
# 500/500 [==============================] - 49s 98ms/step - loss: 0.0846 - accuracy: 0.8318 - val_loss: 0.1180 - val_accuracy: 0.7628
# Epoch 106/1000
# 500/500 [==============================] - 49s 99ms/step - loss: 0.0851 - accuracy: 0.8305 - val_loss: 0.1176 - val_accuracy: 0.7621
# Epoch 107/1000
# 500/500 [==============================] - ETA: 0s - loss: 0.0849 - accuracy: 0.8312
# Epoch 00107: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# 500/500 [==============================] - 49s 99ms/step - loss: 0.0849 - accuracy: 0.8312 - val_loss: 0.1175 - val_accuracy: 0.7627
# Epoch 108/1000
# 500/500 [==============================] - 49s 98ms/step - loss: 0.0848 - accuracy: 0.8316 - val_loss: 0.1176 - val_accuracy: 0.7638
# Epoch 109/1000
# 500/500 [==============================] - 49s 98ms/step - loss: 0.0851 - accuracy: 0.8311 - val_loss: 0.1176 - val_accuracy: 0.7626
# Epoch 110/1000
# 500/500 [==============================] - 49s 99ms/step - loss: 0.0849 - accuracy: 0.8315 - val_loss: 0.1175 - val_accuracy: 0.7643
# Epoch 111/1000
# 500/500 [==============================] - 49s 99ms/step - loss: 0.0835 - accuracy: 0.8340 - val_loss: 0.1176 - val_accuracy: 0.7642
# Epoch 112/1000
# 500/500 [==============================] - 50s 99ms/step - loss: 0.0848 - accuracy: 0.8311 - val_loss: 0.1176 - val_accuracy: 0.7637
# Epoch 113/1000
# 500/500 [==============================] - 50s 100ms/step - loss: 0.0858 - accuracy: 0.8294 - val_loss: 0.1177 - val_accuracy: 0.7632
# Epoch 114/1000
# 500/500 [==============================] - 50s 99ms/step - loss: 0.0844 - accuracy: 0.8329 - val_loss: 0.1176 - val_accuracy: 0.7636
# Epoch 115/1000
# 500/500 [==============================] - 49s 98ms/step - loss: 0.0846 - accuracy: 0.8324 - val_loss: 0.1175 - val_accuracy: 0.7627
# Epoch 116/1000
# 500/500 [==============================] - 50s 100ms/step - loss: 0.0843 - accuracy: 0.8313 - val_loss: 0.1176 - val_accuracy: 0.7636
# Epoch 117/1000
# 500/500 [==============================] - ETA: 0s - loss: 0.0855 - accuracy: 0.8330
# Epoch 00117: ReduceLROnPlateau reducing learning rate to 7.812500371073838e-06.
# 500/500 [==============================] - 51s 102ms/step - loss: 0.0855 - accuracy: 0.8330 - val_loss: 0.1175 - val_accuracy: 0.7631
# Epoch 118/1000
# 500/500 [==============================] - 49s 97ms/step - loss: 0.0844 - accuracy: 0.8312 - val_loss: 0.1174 - val_accuracy: 0.7647
# Epoch 119/1000
# 500/500 [==============================] - 49s 99ms/step - loss: 0.0843 - accuracy: 0.8340 - val_loss: 0.1175 - val_accuracy: 0.7645
# Epoch 120/1000
# 500/500 [==============================] - 50s 99ms/step - loss: 0.0847 - accuracy: 0.8324 - val_loss: 0.1175 - val_accuracy: 0.7638
# Epoch 121/1000
# 500/500 [==============================] - 50s 100ms/step - loss: 0.0840 - accuracy: 0.8319 - val_loss: 0.1175 - val_accuracy: 0.7646
# Epoch 122/1000
# 500/500 [==============================] - 50s 99ms/step - loss: 0.0839 - accuracy: 0.8315 - val_loss: 0.1176 - val_accuracy: 0.7629
# Epoch 123/1000
# 500/500 [==============================] - 50s 99ms/step - loss: 0.0837 - accuracy: 0.8347 - val_loss: 0.1176 - val_accuracy: 0.7636
# Epoch 124/1000
# 500/500 [==============================] - 49s 98ms/step - loss: 0.0841 - accuracy: 0.8335 - val_loss: 0.1175 - val_accuracy: 0.7641
# Epoch 125/1000
# 500/500 [==============================] - 49s 99ms/step - loss: 0.0837 - accuracy: 0.8344 - val_loss: 0.1177 - val_accuracy: 0.7634
# Epoch 126/1000
# 500/500 [==============================] - 49s 98ms/step - loss: 0.0835 - accuracy: 0.8328 - val_loss: 0.1177 - val_accuracy: 0.7636
# Epoch 127/1000
# 500/500 [==============================] - 45s 89ms/step - loss: 0.0839 - accuracy: 0.8335 - val_loss: 0.1177 - val_accuracy: 0.7634
# Epoch 128/1000
# 500/500 [==============================] - ETA: 0s - loss: 0.0841 - accuracy: 0.8333
# Epoch 00128: ReduceLROnPlateau reducing learning rate to 3.906250185536919e-06.
# 500/500 [==============================] - 47s 94ms/step - loss: 0.0841 - accuracy: 0.8333 - val_loss: 0.1176 - val_accuracy: 0.7650
# Epoch 129/1000
# 500/500 [==============================] - 49s 98ms/step - loss: 0.0841 - accuracy: 0.8330 - val_loss: 0.1176 - val_accuracy: 0.7638
# Epoch 130/1000
# 500/500 [==============================] - 42s 84ms/step - loss: 0.0845 - accuracy: 0.8314 - val_loss: 0.1176 - val_accuracy: 0.7640
# Epoch 131/1000
# 500/500 [==============================] - 39s 79ms/step - loss: 0.0839 - accuracy: 0.8334 - val_loss: 0.1176 - val_accuracy: 0.7641
# Epoch 132/1000
# 500/500 [==============================] - 40s 80ms/step - loss: 0.0833 - accuracy: 0.8332 - val_loss: 0.1176 - val_accuracy: 0.7636
# Epoch 133/1000
# 500/500 [==============================] - 39s 78ms/step - loss: 0.0839 - accuracy: 0.8337 - val_loss: 0.1177 - val_accuracy: 0.7641
# Epoch 134/1000
# 500/500 [==============================] - 39s 78ms/step - loss: 0.0831 - accuracy: 0.8351 - val_loss: 0.1176 - val_accuracy: 0.7636
# Epoch 135/1000
# 500/500 [==============================] - 39s 77ms/step - loss: 0.0831 - accuracy: 0.8354 - val_loss: 0.1175 - val_accuracy: 0.7638
# Epoch 136/1000
# 500/500 [==============================] - 39s 77ms/step - loss: 0.0845 - accuracy: 0.8320 - val_loss: 0.1176 - val_accuracy: 0.7643
# Epoch 137/1000
# 500/500 [==============================] - 38s 77ms/step - loss: 0.0840 - accuracy: 0.8345 - val_loss: 0.1176 - val_accuracy: 0.7640
# Epoch 138/1000
# 500/500 [==============================] - ETA: 0s - loss: 0.0835 - accuracy: 0.8356
# Epoch 00138: ReduceLROnPlateau reducing learning rate to 1.9531250927684596e-06.
# 500/500 [==============================] - 39s 77ms/step - loss: 0.0835 - accuracy: 0.8356 - val_loss: 0.1176 - val_accuracy: 0.7642
# Epoch 139/1000
# 500/500 [==============================] - 38s 75ms/step - loss: 0.0845 - accuracy: 0.8311 - val_loss: 0.1177 - val_accuracy: 0.7642
# Epoch 140/1000
# 500/500 [==============================] - 38s 75ms/step - loss: 0.0845 - accuracy: 0.8330 - val_loss: 0.1176 - val_accuracy: 0.7642
# Epoch 141/1000
# 500/500 [==============================] - 38s 77ms/step - loss: 0.0837 - accuracy: 0.8343 - val_loss: 0.1177 - val_accuracy: 0.7637
# Epoch 142/1000
# 500/500 [==============================] - 38s 76ms/step - loss: 0.0837 - accuracy: 0.8344 - val_loss: 0.1176 - val_accuracy: 0.7641
# Epoch 143/1000
# 500/500 [==============================] - 38s 76ms/step - loss: 0.0835 - accuracy: 0.8337 - val_loss: 0.1177 - val_accuracy: 0.7637
# Epoch 144/1000
# 500/500 [==============================] - 38s 77ms/step - loss: 0.0836 - accuracy: 0.8341 - val_loss: 0.1176 - val_accuracy: 0.7638
# Epoch 145/1000
# 500/500 [==============================] - 39s 77ms/step - loss: 0.0842 - accuracy: 0.8324 - val_loss: 0.1175 - val_accuracy: 0.7642
# Epoch 146/1000
# 500/500 [==============================] - 38s 77ms/step - loss: 0.0845 - accuracy: 0.8319 - val_loss: 0.1176 - val_accuracy: 0.7644
# Epoch 147/1000
# 500/500 [==============================] - 38s 76ms/step - loss: 0.0834 - accuracy: 0.8352 - val_loss: 0.1176 - val_accuracy: 0.7639
# Epoch 148/1000
# 500/500 [==============================] - ETA: 0s - loss: 0.0840 - accuracy: 0.8334
# Epoch 00148: ReduceLROnPlateau reducing learning rate to 9.765625463842298e-07.
# 500/500 [==============================] - 38s 76ms/step - loss: 0.0840 - accuracy: 0.8334 - val_loss: 0.1176 - val_accuracy: 0.7645
# Epoch 149/1000
# 500/500 [==============================] - 38s 76ms/step - loss: 0.0848 - accuracy: 0.8319 - val_loss: 0.1176 - val_accuracy: 0.7645
# Epoch 150/1000
# 500/500 [==============================] - 38s 76ms/step - loss: 0.0838 - accuracy: 0.8358 - val_loss: 0.1176 - val_accuracy: 0.7643
# Epoch 151/1000
# 500/500 [==============================] - 38s 76ms/step - loss: 0.0841 - accuracy: 0.8320 - val_loss: 0.1175 - val_accuracy: 0.7641
# Epoch 152/1000
# 500/500 [==============================] - 38s 76ms/step - loss: 0.0841 - accuracy: 0.8332 - val_loss: 0.1176 - val_accuracy: 0.7637
# Epoch 153/1000
# 500/500 [==============================] - ETA: 0s - loss: 0.0828 - accuracy: 0.8343Restoring model weights from the end of the best epoch.
# 500/500 [==============================] - 39s 77ms/step - loss: 0.0828 - accuracy: 0.8343 - val_loss: 0.1176 - val_accuracy: 0.7638
# Epoch 00153: early stopping

# %%
import matplotlib.pyplot as plt

fig = plt.figure(figsize=(10,6))
plt.plot(hist.history['loss'], color='#785ef0')
plt.plot(hist.history['val_loss'], color='#dc267f')
plt.title('Model Loss Progress')
plt.ylabel('Binary Cross-Entropy Loss')
plt.xlabel('Epoch')
plt.legend(['Training Set', 'Test Set'], loc='upper right')
plt.savefig('9*9 freq-5 theta-8 loss.png', dpi=350, bbox_inches='tight')
plt.show()

# %%
from sklearn.preprocessing import MinMaxScaler

cnnl1 = classifier.layers[1].name   # get the name of the first conv layer
W = classifier.get_layer(name=cnnl1).get_weights()[0]   #get the filters
wshape = W.shape  #save the original shape

# this part will scale to [0, 1] for visualization purposes
scaler = MinMaxScaler()
scaler.fit(W.reshape(-1,1))
W = scaler.transform(W.reshape(-1,1))
W = W.reshape(wshape)

# since there are 64 filters, we will display them 8x8
fig, axs = plt.subplots(8,8, figsize=(24,24))
fig.subplots_adjust(hspace = .25, wspace=.001)
axs = axs.ravel()
for i in range(W.shape[-1]):
  # we reshape to a 3D (RGB) image shape and display
  h = np.reshape(W[:,:,:,i], (9,9,3))
  axs[i].imshow(h)
  axs[i].set_title('Filter ' + str(i))    
plt.savefig("9*9 freq-5 theta-8 filters.png", bbox_inches='tight', dpi=350)

# %%
W.shape
# Out:
# (9, 9, 3, 64)

# %%
fig = plt.subplots(12, 16, figsize=(22,22))

filter_layers = []
for i in range(64):
    for j in range(3):
        filter_layers.append(np.reshape(W[:,:,j, i], (9,9)))
for i,gf in enumerate(filter_layers):
    plt.subplot(12, 16, i+1)
    plt.imshow(gf, cmap='gray')
    plt.axis('off')
