# %%
from skimage.filters import gabor_kernel
from skimage import io
from skimage.transform import resize
from matplotlib import pyplot as plt 
import numpy as np

import math

# %%
def get_gabor_filters(inchannels, outchannels, kernel_size = (3,3)):
    delta = 1e-4
    freqs = (math.pi/2)*math.sqrt(2)**(-np.random.randint(0,5, (outchannels, inchannels)))
    thetas = (math.pi/8)*np.random.randint(0,8, (outchannels, inchannels))
    sigmas = math.pi/freqs
    psis = math.pi * np.random.rand(outchannels, inchannels)
    x0, y0 = np.ceil(np.array(kernel_size)/2)    
    
    y, x = np.meshgrid(
            np.linspace(-x0 + 1, x0 + 0, kernel_size[0]),
            np.linspace(-y0 + 1, y0 + 0, kernel_size[1]),
    )
    filterbank = []
    
    for i in range(outchannels):
        for j in range(inchannels):
            freq = freqs[i][j]
            theta = thetas[i][j]
            sigma = sigmas[i][j]
            psi = psis[i][j]
            
            rotx = x * np.cos(theta) + y * np.sin(theta)
            roty = -x * np.sin(theta) + y * np.cos(theta)

            g = np.exp(
                -0.5 * ((rotx ** 2 + roty ** 2) / (sigma + delta) ** 2)
            )
            g = g * np.cos(freq * rotx + psi)
            g = g / (2 * math.pi * sigma ** 2)
            filterbank.append(g)
    return filterbank

filterbank = get_gabor_filters(3, 64, (9,9))

fig = plt.subplots(12, 16, figsize=(22,22))
for i,gf in enumerate(filterbank):
    plt.subplot(12, 16, i+1)
    plt.imshow(gf, cmap='gray')
    plt.axis('off')

# %%
from tensorflow.keras.datasets import cifar10
from tensorflow.keras.utils import to_categorical

# The data, split between train and test sets:
(x_train, y_train), (x_test, y_test) = cifar10.load_data()
x_train = x_train.astype('float32') / 255.0
x_test = x_test.astype('float32') / 255.0

y_train = to_categorical(y_train, 10)
y_test = to_categorical(y_test, 10)

print('x_train shape:', x_train.shape)
print('x_test shape:', x_test.shape)
# Out:
# x_train shape: (50000, 32, 32, 3)
# x_test shape: (10000, 32, 32, 3)

# %%
# Importing the Keras libraries and packages
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Activation
from tensorflow.keras.layers import Input, Dense, Dropout, BatchNormalization
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import RMSprop, Adam

# dimensionality of input and latent encoded representations
inpt_dim = (32, 32, 3)

inpt_img = Input(shape=inpt_dim)

# Block 1
cl1 = Conv2D(64, (9, 9), strides=(2, 2),activation='relu', input_shape = inpt_dim)(inpt_img)
bnl2 = BatchNormalization()(cl1)
# afl3 = Activation('relu')(bnl2)
pl4 = MaxPooling2D(pool_size = (2, 2))(bnl2)

# Adding a second convolutional layer
cl5 = Conv2D(128, (3, 3), strides=(1, 1), activation='relu')(pl4)
bnl6 = BatchNormalization()(cl5)
# afl7 = Activation('relu')(bnl6)
pl8 = MaxPooling2D(pool_size = (2, 2))(bnl6)
bnl9 = BatchNormalization()(pl8)

# Step 3 - Flattening
fl10 = Flatten()(bnl9)

# Step 4 - Full connection
dol11 = Dropout(0.5)(fl10)
dl12 = Dense(units = 256, activation = 'relu')(dol11)
dol13 = Dropout(0.2)(dl12)
dl14 = Dense(units = 64, activation = 'relu')(dol13)
dol15 = Dropout(0.1)(dl14)
output = Dense(units = 10, activation = 'sigmoid')(dol15)

classifier = Model(inpt_img, output)

# Compiling the CNN
opt = RMSprop(learning_rate=0.001)
# opt = Adam(learning_rate=0.01)

classifier.compile(optimizer = opt, loss = 'binary_crossentropy', 
                   metrics = ['accuracy'])

print(classifier.summary())
# Out:
# Model: "functional_9"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_5 (InputLayer)         [(None, 32, 32, 3)]       0
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 12, 12, 64)        15616
# _________________________________________________________________
# batch_normalization_12 (Batc (None, 12, 12, 64)        256
# _________________________________________________________________
# max_pooling2d_8 (MaxPooling2 (None, 6, 6, 64)          0
# _________________________________________________________________
# conv2d_9 (Conv2D)            (None, 4, 4, 128)         73856
# _________________________________________________________________
# batch_normalization_13 (Batc (None, 4, 4, 128)         512
# _________________________________________________________________
# max_pooling2d_9 (MaxPooling2 (None, 2, 2, 128)         0
# _________________________________________________________________
# batch_normalization_14 (Batc (None, 2, 2, 128)         512
# _________________________________________________________________
# flatten_4 (Flatten)          (None, 512)               0
# _________________________________________________________________
# dropout_12 (Dropout)         (None, 512)               0
# _________________________________________________________________
# dense_12 (Dense)             (None, 256)               131328
# _________________________________________________________________
# dropout_13 (Dropout)         (None, 256)               0
# _________________________________________________________________
# dense_13 (Dense)             (None, 64)                16448
# _________________________________________________________________
# dropout_14 (Dropout)         (None, 64)                0
# _________________________________________________________________
# dense_14 (Dense)             (None, 10)                650
# =================================================================
# Total params: 239,178
# Trainable params: 238,538
# Non-trainable params: 640
# _________________________________________________________________
# None

# %%
cnnl1 = classifier.layers[1].name   # get the name of the first conv layer
W = classifier.get_layer(name=cnnl1).get_weights()[0]   #get the filters
wshape = W.shape  #save the original shape

# %%
classifier.get_layer(name=cnnl1).get_weights()[1].shape
# Out:
# (64,)

# %%
gabor_filters = np.empty(wshape, dtype='float32')
for kernel_index in range(wshape[3]):
    for channel_index in range(3):
        gabor_filters[:,:,channel_index, kernel_index] = filterbank[kernel_index+channel_index]

cnnl1 = classifier.layers[1].name   # get the name of the first conv layer
classifier.get_layer(name=cnnl1).set_weights([gabor_filters, classifier.get_layer(name=cnnl1).get_weights()[1]])   #set the filters
# for k in range(0,wshape[3],3):
#   gabor_filters[:,:,0,k] = filterbank[k]
#   gabor_filters[:,:,1,k] = filterbank[k]
#   gabor_filters[:,:,2,k] = filterbank[k]

# %%
fig = plt.subplots(12, 16, figsize=(22,22))
W = classifier.get_layer(name=cnnl1).get_weights()[0]   #get the filters
filter_layers = []
for i in range(64):
    for j in range(3):
        filter_layers.append(np.reshape(W[:,:,j, i], (9,9)))
for i,gf in enumerate(filter_layers):
    plt.subplot(12, 16, i+1)
    plt.imshow(gf, cmap='gray')
    plt.axis('off')

# %%
# Fitting the CNN to the images

from tensorflow.keras.callbacks import ReduceLROnPlateau, EarlyStopping

reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=10,  
                              min_delta=1e-4, mode='min', verbose=1)

stop_alg = EarlyStopping(monitor='val_loss', patience=35, 
                         restore_best_weights=True, verbose=1)

hist = classifier.fit(x_train, y_train, batch_size=100, epochs=1000, 
                   callbacks=[stop_alg, reduce_lr], shuffle=True, 
                   validation_data=(x_test, y_test))

classifier.save_weights("cnn.hdf5")
# Out:
# Epoch 1/1000
# 500/500 [==============================] - 20s 39ms/step - loss: 0.2766 - accuracy: 0.3508 - val_loss: 0.2456 - val_accuracy: 0.4382
# Epoch 2/1000
# 500/500 [==============================] - 19s 38ms/step - loss: 0.2307 - accuracy: 0.4699 - val_loss: 0.2517 - val_accuracy: 0.4344
# Epoch 3/1000
# 500/500 [==============================] - 19s 39ms/step - loss: 0.2124 - accuracy: 0.5210 - val_loss: 0.2217 - val_accuracy: 0.5064
# Epoch 4/1000
# 500/500 [==============================] - 19s 38ms/step - loss: 0.2013 - accuracy: 0.5535 - val_loss: 0.2242 - val_accuracy: 0.4962
# Epoch 5/1000
# 500/500 [==============================] - 19s 39ms/step - loss: 0.1917 - accuracy: 0.5768 - val_loss: 0.2243 - val_accuracy: 0.4923
# Epoch 6/1000
# 500/500 [==============================] - 19s 39ms/step - loss: 0.1857 - accuracy: 0.5926 - val_loss: 0.2176 - val_accuracy: 0.5040
# Epoch 7/1000
# 500/500 [==============================] - 19s 39ms/step - loss: 0.1801 - accuracy: 0.6071 - val_loss: 0.2198 - val_accuracy: 0.5012
# Epoch 8/1000
# 500/500 [==============================] - 19s 39ms/step - loss: 0.1761 - accuracy: 0.6165 - val_loss: 0.1841 - val_accuracy: 0.5902
# Epoch 9/1000
# 500/500 [==============================] - 21s 42ms/step - loss: 0.1717 - accuracy: 0.6286 - val_loss: 0.1651 - val_accuracy: 0.6470
# Epoch 10/1000
# 500/500 [==============================] - 19s 38ms/step - loss: 0.1671 - accuracy: 0.6391 - val_loss: 0.2186 - val_accuracy: 0.5246
# Epoch 11/1000
# 500/500 [==============================] - 19s 38ms/step - loss: 0.1640 - accuracy: 0.6484 - val_loss: 0.1827 - val_accuracy: 0.6038
# Epoch 12/1000
# 500/500 [==============================] - 21s 43ms/step - loss: 0.1611 - accuracy: 0.6546 - val_loss: 0.1828 - val_accuracy: 0.5879
# Epoch 13/1000
# 500/500 [==============================] - 20s 39ms/step - loss: 0.1597 - accuracy: 0.6595 - val_loss: 0.1562 - val_accuracy: 0.6667
# Epoch 14/1000
# 500/500 [==============================] - 20s 39ms/step - loss: 0.1568 - accuracy: 0.6635 - val_loss: 0.1599 - val_accuracy: 0.6535
# Epoch 15/1000
# 500/500 [==============================] - 20s 40ms/step - loss: 0.1553 - accuracy: 0.6680 - val_loss: 0.1691 - val_accuracy: 0.6328
# Epoch 16/1000
# 500/500 [==============================] - 21s 41ms/step - loss: 0.1528 - accuracy: 0.6756 - val_loss: 0.1787 - val_accuracy: 0.5994
# Epoch 17/1000
# 500/500 [==============================] - 20s 40ms/step - loss: 0.1514 - accuracy: 0.6773 - val_loss: 0.2074 - val_accuracy: 0.5670
# Epoch 18/1000
# 500/500 [==============================] - 21s 41ms/step - loss: 0.1496 - accuracy: 0.6823 - val_loss: 0.1699 - val_accuracy: 0.6425
# Epoch 19/1000
# 500/500 [==============================] - 19s 39ms/step - loss: 0.1479 - accuracy: 0.6880 - val_loss: 0.1786 - val_accuracy: 0.6134
# Epoch 20/1000
# 500/500 [==============================] - 19s 39ms/step - loss: 0.1464 - accuracy: 0.6906 - val_loss: 0.1958 - val_accuracy: 0.5919
# Epoch 21/1000
# 500/500 [==============================] - 19s 39ms/step - loss: 0.1454 - accuracy: 0.6922 - val_loss: 0.1577 - val_accuracy: 0.6631
# Epoch 22/1000
# 500/500 [==============================] - 19s 39ms/step - loss: 0.1440 - accuracy: 0.6935 - val_loss: 0.1624 - val_accuracy: 0.6491
# Epoch 23/1000
# 499/500 [============================>.] - ETA: 0s - loss: 0.1430 - accuracy: 0.6993
# Epoch 00023: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 500/500 [==============================] - 19s 39ms/step - loss: 0.1430 - accuracy: 0.6993 - val_loss: 0.1669 - val_accuracy: 0.6390
# Epoch 24/1000
# 500/500 [==============================] - 19s 39ms/step - loss: 0.1360 - accuracy: 0.7137 - val_loss: 0.1770 - val_accuracy: 0.6462
# Epoch 25/1000
# 500/500 [==============================] - 19s 39ms/step - loss: 0.1334 - accuracy: 0.7184 - val_loss: 0.1326 - val_accuracy: 0.7255
# Epoch 26/1000
# 500/500 [==============================] - 20s 41ms/step - loss: 0.1322 - accuracy: 0.7217 - val_loss: 0.1357 - val_accuracy: 0.7151
# Epoch 27/1000
# 500/500 [==============================] - 20s 40ms/step - loss: 0.1313 - accuracy: 0.7233 - val_loss: 0.1438 - val_accuracy: 0.6980
# Epoch 28/1000
# 500/500 [==============================] - 20s 40ms/step - loss: 0.1298 - accuracy: 0.7282 - val_loss: 0.1495 - val_accuracy: 0.6720
# Epoch 29/1000
# 500/500 [==============================] - 20s 40ms/step - loss: 0.1293 - accuracy: 0.7311 - val_loss: 0.1359 - val_accuracy: 0.7159
# Epoch 30/1000
# 500/500 [==============================] - 20s 40ms/step - loss: 0.1282 - accuracy: 0.7313 - val_loss: 0.1354 - val_accuracy: 0.7177
# Epoch 31/1000
# 500/500 [==============================] - 20s 40ms/step - loss: 0.1280 - accuracy: 0.7311 - val_loss: 0.1314 - val_accuracy: 0.7228
# Epoch 32/1000
# 500/500 [==============================] - 20s 40ms/step - loss: 0.1275 - accuracy: 0.7374 - val_loss: 0.1575 - val_accuracy: 0.6810
# Epoch 33/1000
# 500/500 [==============================] - 20s 40ms/step - loss: 0.1273 - accuracy: 0.7359 - val_loss: 0.1459 - val_accuracy: 0.6924
# Epoch 34/1000
# 500/500 [==============================] - 21s 41ms/step - loss: 0.1263 - accuracy: 0.7364 - val_loss: 0.1353 - val_accuracy: 0.7159
# Epoch 35/1000
# 500/500 [==============================] - 19s 38ms/step - loss: 0.1261 - accuracy: 0.7385 - val_loss: 0.1327 - val_accuracy: 0.7193
# Epoch 36/1000
# 500/500 [==============================] - 19s 39ms/step - loss: 0.1247 - accuracy: 0.7407 - val_loss: 0.1343 - val_accuracy: 0.7191
# Epoch 37/1000
# 500/500 [==============================] - 19s 38ms/step - loss: 0.1243 - accuracy: 0.7400 - val_loss: 0.1281 - val_accuracy: 0.7315
# Epoch 38/1000
# 500/500 [==============================] - 19s 38ms/step - loss: 0.1253 - accuracy: 0.7406 - val_loss: 0.1345 - val_accuracy: 0.7167
# Epoch 39/1000
# 500/500 [==============================] - 21s 42ms/step - loss: 0.1240 - accuracy: 0.7412 - val_loss: 0.1309 - val_accuracy: 0.7238
# Epoch 40/1000
# 500/500 [==============================] - 18s 37ms/step - loss: 0.1228 - accuracy: 0.7456 - val_loss: 0.1511 - val_accuracy: 0.6763
# Epoch 41/1000
# 500/500 [==============================] - 18s 37ms/step - loss: 0.1230 - accuracy: 0.7446 - val_loss: 0.1341 - val_accuracy: 0.7246
# Epoch 42/1000
# 500/500 [==============================] - 19s 38ms/step - loss: 0.1224 - accuracy: 0.7454 - val_loss: 0.1369 - val_accuracy: 0.7100
# Epoch 43/1000
# 500/500 [==============================] - 20s 40ms/step - loss: 0.1217 - accuracy: 0.7478 - val_loss: 0.1315 - val_accuracy: 0.7234
# Epoch 44/1000
# 500/500 [==============================] - 20s 39ms/step - loss: 0.1219 - accuracy: 0.7473 - val_loss: 0.1317 - val_accuracy: 0.7239
# Epoch 45/1000
# 500/500 [==============================] - 20s 40ms/step - loss: 0.1217 - accuracy: 0.7488 - val_loss: 0.1352 - val_accuracy: 0.7146
# Epoch 46/1000
# 500/500 [==============================] - 21s 42ms/step - loss: 0.1206 - accuracy: 0.7496 - val_loss: 0.1293 - val_accuracy: 0.7300
# Epoch 47/1000
# 499/500 [============================>.] - ETA: 0s - loss: 0.1201 - accuracy: 0.7520
# Epoch 00047: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 500/500 [==============================] - 20s 41ms/step - loss: 0.1201 - accuracy: 0.7520 - val_loss: 0.1298 - val_accuracy: 0.7313
# Epoch 48/1000
# 500/500 [==============================] - 21s 41ms/step - loss: 0.1158 - accuracy: 0.7615 - val_loss: 0.1297 - val_accuracy: 0.7274
# Epoch 49/1000
# 500/500 [==============================] - 21s 42ms/step - loss: 0.1156 - accuracy: 0.7605 - val_loss: 0.1301 - val_accuracy: 0.7290
# Epoch 50/1000
# 500/500 [==============================] - 20s 41ms/step - loss: 0.1152 - accuracy: 0.7616 - val_loss: 0.1256 - val_accuracy: 0.7407
# Epoch 51/1000
# 500/500 [==============================] - 21s 41ms/step - loss: 0.1150 - accuracy: 0.7637 - val_loss: 0.1287 - val_accuracy: 0.7310
# Epoch 52/1000
# 500/500 [==============================] - 21s 42ms/step - loss: 0.1140 - accuracy: 0.7661 - val_loss: 0.1284 - val_accuracy: 0.7340
# Epoch 53/1000
# 500/500 [==============================] - 20s 40ms/step - loss: 0.1135 - accuracy: 0.7669 - val_loss: 0.1284 - val_accuracy: 0.7302
# Epoch 54/1000
# 500/500 [==============================] - 19s 39ms/step - loss: 0.1135 - accuracy: 0.7675 - val_loss: 0.1256 - val_accuracy: 0.7396
# Epoch 55/1000
# 500/500 [==============================] - 19s 39ms/step - loss: 0.1133 - accuracy: 0.7685 - val_loss: 0.1288 - val_accuracy: 0.7345
# Epoch 56/1000
# 500/500 [==============================] - 20s 39ms/step - loss: 0.1128 - accuracy: 0.7687 - val_loss: 0.1245 - val_accuracy: 0.7405
# Epoch 57/1000
# 500/500 [==============================] - 20s 40ms/step - loss: 0.1123 - accuracy: 0.7694 - val_loss: 0.1270 - val_accuracy: 0.7347
# Epoch 58/1000
# 500/500 [==============================] - 19s 38ms/step - loss: 0.1125 - accuracy: 0.7680 - val_loss: 0.1308 - val_accuracy: 0.7219
# Epoch 59/1000
# 500/500 [==============================] - 19s 38ms/step - loss: 0.1136 - accuracy: 0.7682 - val_loss: 0.1257 - val_accuracy: 0.7351
# Epoch 60/1000
# 500/500 [==============================] - 19s 38ms/step - loss: 0.1119 - accuracy: 0.7697 - val_loss: 0.1262 - val_accuracy: 0.7389
# Epoch 61/1000
# 500/500 [==============================] - 19s 38ms/step - loss: 0.1123 - accuracy: 0.7688 - val_loss: 0.1295 - val_accuracy: 0.7287
# Epoch 62/1000
# 500/500 [==============================] - 19s 38ms/step - loss: 0.1121 - accuracy: 0.7719 - val_loss: 0.1313 - val_accuracy: 0.7161
# Epoch 63/1000
# 500/500 [==============================] - 20s 40ms/step - loss: 0.1111 - accuracy: 0.7733 - val_loss: 0.1245 - val_accuracy: 0.7408
# Epoch 64/1000
# 500/500 [==============================] - 20s 39ms/step - loss: 0.1112 - accuracy: 0.7722 - val_loss: 0.1277 - val_accuracy: 0.7326
# Epoch 65/1000
# 500/500 [==============================] - 22s 44ms/step - loss: 0.1116 - accuracy: 0.7710 - val_loss: 0.1271 - val_accuracy: 0.7338
# Epoch 66/1000
# 500/500 [==============================] - 20s 40ms/step - loss: 0.1115 - accuracy: 0.7706 - val_loss: 0.1244 - val_accuracy: 0.7431
# Epoch 67/1000
# 500/500 [==============================] - 23s 47ms/step - loss: 0.1100 - accuracy: 0.7740 - val_loss: 0.1247 - val_accuracy: 0.7422
# Epoch 68/1000
# 500/500 [==============================] - 21s 42ms/step - loss: 0.1104 - accuracy: 0.7724 - val_loss: 0.1257 - val_accuracy: 0.7444
# Epoch 69/1000
# 500/500 [==============================] - 22s 44ms/step - loss: 0.1099 - accuracy: 0.7758 - val_loss: 0.1278 - val_accuracy: 0.7284
# Epoch 70/1000
# 500/500 [==============================] - 21s 42ms/step - loss: 0.1097 - accuracy: 0.7762 - val_loss: 0.1339 - val_accuracy: 0.7207
# Epoch 71/1000
# 500/500 [==============================] - 20s 40ms/step - loss: 0.1109 - accuracy: 0.7730 - val_loss: 0.1288 - val_accuracy: 0.7274
# Epoch 72/1000
# 500/500 [==============================] - 20s 40ms/step - loss: 0.1094 - accuracy: 0.7772 - val_loss: 0.1258 - val_accuracy: 0.7402
# Epoch 73/1000
# 500/500 [==============================] - 20s 40ms/step - loss: 0.1099 - accuracy: 0.7740 - val_loss: 0.1269 - val_accuracy: 0.7371
# Epoch 74/1000
# 500/500 [==============================] - 20s 40ms/step - loss: 0.1085 - accuracy: 0.7787 - val_loss: 0.1256 - val_accuracy: 0.7432
# Epoch 75/1000
# 500/500 [==============================] - 19s 39ms/step - loss: 0.1099 - accuracy: 0.7758 - val_loss: 0.1246 - val_accuracy: 0.7424
# Epoch 76/1000
# 500/500 [==============================] - ETA: 0s - loss: 0.1086 - accuracy: 0.7784
# Epoch 00076: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 500/500 [==============================] - 20s 40ms/step - loss: 0.1086 - accuracy: 0.7784 - val_loss: 0.1247 - val_accuracy: 0.7415
# Epoch 77/1000
# 500/500 [==============================] - 20s 39ms/step - loss: 0.1069 - accuracy: 0.7839 - val_loss: 0.1255 - val_accuracy: 0.7384
# Epoch 78/1000
# 500/500 [==============================] - 19s 39ms/step - loss: 0.1065 - accuracy: 0.7834 - val_loss: 0.1265 - val_accuracy: 0.7403
# Epoch 79/1000
# 500/500 [==============================] - 19s 39ms/step - loss: 0.1071 - accuracy: 0.7820 - val_loss: 0.1228 - val_accuracy: 0.7465
# Epoch 80/1000
# 500/500 [==============================] - 19s 39ms/step - loss: 0.1060 - accuracy: 0.7857 - val_loss: 0.1249 - val_accuracy: 0.7422
# Epoch 81/1000
# 500/500 [==============================] - 19s 39ms/step - loss: 0.1063 - accuracy: 0.7829 - val_loss: 0.1245 - val_accuracy: 0.7398
# Epoch 82/1000
# 500/500 [==============================] - 20s 39ms/step - loss: 0.1057 - accuracy: 0.7840 - val_loss: 0.1255 - val_accuracy: 0.7418
# Epoch 83/1000
# 500/500 [==============================] - 20s 40ms/step - loss: 0.1055 - accuracy: 0.7845 - val_loss: 0.1238 - val_accuracy: 0.7439
# Epoch 84/1000
# 500/500 [==============================] - 20s 40ms/step - loss: 0.1061 - accuracy: 0.7826 - val_loss: 0.1243 - val_accuracy: 0.7438
# Epoch 85/1000
# 500/500 [==============================] - 20s 41ms/step - loss: 0.1055 - accuracy: 0.7833 - val_loss: 0.1231 - val_accuracy: 0.7482
# Epoch 86/1000
# 500/500 [==============================] - 20s 40ms/step - loss: 0.1044 - accuracy: 0.7871 - val_loss: 0.1225 - val_accuracy: 0.7485
# Epoch 87/1000
# 500/500 [==============================] - 20s 39ms/step - loss: 0.1056 - accuracy: 0.7840 - val_loss: 0.1242 - val_accuracy: 0.7469
# Epoch 88/1000
# 500/500 [==============================] - 19s 38ms/step - loss: 0.1052 - accuracy: 0.7860 - val_loss: 0.1230 - val_accuracy: 0.7428
# Epoch 89/1000
# 500/500 [==============================] - 20s 40ms/step - loss: 0.1050 - accuracy: 0.7872 - val_loss: 0.1248 - val_accuracy: 0.7424
# Epoch 90/1000
# 500/500 [==============================] - 21s 41ms/step - loss: 0.1056 - accuracy: 0.7842 - val_loss: 0.1236 - val_accuracy: 0.7459
# Epoch 91/1000
# 500/500 [==============================] - 19s 37ms/step - loss: 0.1060 - accuracy: 0.7849 - val_loss: 0.1244 - val_accuracy: 0.7400
# Epoch 92/1000
# 500/500 [==============================] - 19s 38ms/step - loss: 0.1054 - accuracy: 0.7862 - val_loss: 0.1227 - val_accuracy: 0.7462
# Epoch 93/1000
# 500/500 [==============================] - 19s 38ms/step - loss: 0.1042 - accuracy: 0.7849 - val_loss: 0.1232 - val_accuracy: 0.7463
# Epoch 94/1000
# 500/500 [==============================] - 21s 41ms/step - loss: 0.1052 - accuracy: 0.7859 - val_loss: 0.1279 - val_accuracy: 0.7311
# Epoch 95/1000
# 500/500 [==============================] - 19s 38ms/step - loss: 0.1048 - accuracy: 0.7870 - val_loss: 0.1228 - val_accuracy: 0.7480
# Epoch 96/1000
# 499/500 [============================>.] - ETA: 0s - loss: 0.1042 - accuracy: 0.7876
# Epoch 00096: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 500/500 [==============================] - 19s 38ms/step - loss: 0.1042 - accuracy: 0.7876 - val_loss: 0.1239 - val_accuracy: 0.7418
# Epoch 97/1000
# 500/500 [==============================] - 19s 38ms/step - loss: 0.1027 - accuracy: 0.7917 - val_loss: 0.1224 - val_accuracy: 0.7460
# Epoch 98/1000
# 500/500 [==============================] - 19s 38ms/step - loss: 0.1035 - accuracy: 0.7900 - val_loss: 0.1219 - val_accuracy: 0.7480
# Epoch 99/1000
# 500/500 [==============================] - 19s 37ms/step - loss: 0.1027 - accuracy: 0.7892 - val_loss: 0.1226 - val_accuracy: 0.7463
# Epoch 100/1000
# 500/500 [==============================] - 19s 37ms/step - loss: 0.1030 - accuracy: 0.7925 - val_loss: 0.1223 - val_accuracy: 0.7453
# Epoch 101/1000
# 500/500 [==============================] - 19s 38ms/step - loss: 0.1027 - accuracy: 0.7915 - val_loss: 0.1227 - val_accuracy: 0.7452
# Epoch 102/1000
# 500/500 [==============================] - 25s 51ms/step - loss: 0.1031 - accuracy: 0.7916 - val_loss: 0.1221 - val_accuracy: 0.7491
# Epoch 103/1000
# 500/500 [==============================] - 25s 49ms/step - loss: 0.1027 - accuracy: 0.7924 - val_loss: 0.1233 - val_accuracy: 0.7421
# Epoch 104/1000
# 500/500 [==============================] - 19s 38ms/step - loss: 0.1019 - accuracy: 0.7931 - val_loss: 0.1228 - val_accuracy: 0.7425
# Epoch 105/1000
# 500/500 [==============================] - 21s 42ms/step - loss: 0.1021 - accuracy: 0.7905 - val_loss: 0.1229 - val_accuracy: 0.7451
# Epoch 106/1000
# 500/500 [==============================] - 21s 43ms/step - loss: 0.1023 - accuracy: 0.7909 - val_loss: 0.1223 - val_accuracy: 0.7466
# Epoch 107/1000
# 500/500 [==============================] - 20s 40ms/step - loss: 0.1024 - accuracy: 0.7927 - val_loss: 0.1223 - val_accuracy: 0.7446
# Epoch 108/1000
# 500/500 [==============================] - 19s 39ms/step - loss: 0.1026 - accuracy: 0.7909 - val_loss: 0.1217 - val_accuracy: 0.7455
# Epoch 109/1000
# 500/500 [==============================] - 28s 56ms/step - loss: 0.1019 - accuracy: 0.7944 - val_loss: 0.1224 - val_accuracy: 0.7457
# Epoch 110/1000
# 500/500 [==============================] - 40s 80ms/step - loss: 0.1014 - accuracy: 0.7961 - val_loss: 0.1233 - val_accuracy: 0.7486
# Epoch 111/1000
# 500/500 [==============================] - 41s 81ms/step - loss: 0.1031 - accuracy: 0.7902 - val_loss: 0.1231 - val_accuracy: 0.7412
# Epoch 112/1000
# 500/500 [==============================] - 41s 81ms/step - loss: 0.1017 - accuracy: 0.7951 - val_loss: 0.1225 - val_accuracy: 0.7475
# Epoch 113/1000
# 500/500 [==============================] - 41s 83ms/step - loss: 0.1019 - accuracy: 0.7936 - val_loss: 0.1218 - val_accuracy: 0.7502
# Epoch 114/1000
# 500/500 [==============================] - 41s 81ms/step - loss: 0.1015 - accuracy: 0.7944 - val_loss: 0.1223 - val_accuracy: 0.7503
# Epoch 115/1000
# 500/500 [==============================] - 42s 85ms/step - loss: 0.1020 - accuracy: 0.7920 - val_loss: 0.1218 - val_accuracy: 0.7479
# Epoch 116/1000
# 500/500 [==============================] - 42s 85ms/step - loss: 0.1016 - accuracy: 0.7952 - val_loss: 0.1234 - val_accuracy: 0.7407
# Epoch 117/1000
# 500/500 [==============================] - 42s 84ms/step - loss: 0.1015 - accuracy: 0.7952 - val_loss: 0.1215 - val_accuracy: 0.7525
# Epoch 118/1000
# 500/500 [==============================] - 41s 82ms/step - loss: 0.1021 - accuracy: 0.7940 - val_loss: 0.1218 - val_accuracy: 0.7487
# Epoch 119/1000
# 500/500 [==============================] - 39s 78ms/step - loss: 0.1020 - accuracy: 0.7921 - val_loss: 0.1223 - val_accuracy: 0.7497
# Epoch 120/1000
# 500/500 [==============================] - 39s 78ms/step - loss: 0.1013 - accuracy: 0.7943 - val_loss: 0.1216 - val_accuracy: 0.7524
# Epoch 121/1000
# 500/500 [==============================] - 39s 78ms/step - loss: 0.1014 - accuracy: 0.7960 - val_loss: 0.1224 - val_accuracy: 0.7467
# Epoch 122/1000
# 500/500 [==============================] - 43s 86ms/step - loss: 0.1025 - accuracy: 0.7916 - val_loss: 0.1226 - val_accuracy: 0.7473
# Epoch 123/1000
# 500/500 [==============================] - 40s 81ms/step - loss: 0.1016 - accuracy: 0.7927 - val_loss: 0.1225 - val_accuracy: 0.7480
# Epoch 124/1000
# 500/500 [==============================] - 41s 82ms/step - loss: 0.1019 - accuracy: 0.7929 - val_loss: 0.1214 - val_accuracy: 0.7501
# Epoch 125/1000
# 500/500 [==============================] - 41s 83ms/step - loss: 0.1014 - accuracy: 0.7927 - val_loss: 0.1216 - val_accuracy: 0.7487
# Epoch 126/1000
# 500/500 [==============================] - 42s 84ms/step - loss: 0.1016 - accuracy: 0.7947 - val_loss: 0.1226 - val_accuracy: 0.7467
# Epoch 127/1000
# 500/500 [==============================] - 42s 84ms/step - loss: 0.1015 - accuracy: 0.7931 - val_loss: 0.1231 - val_accuracy: 0.7442
# Epoch 128/1000
# 500/500 [==============================] - 41s 81ms/step - loss: 0.1011 - accuracy: 0.7959 - val_loss: 0.1219 - val_accuracy: 0.7523
# Epoch 129/1000
# 500/500 [==============================] - 42s 83ms/step - loss: 0.1014 - accuracy: 0.7941 - val_loss: 0.1216 - val_accuracy: 0.7511
# Epoch 130/1000
# 500/500 [==============================] - 42s 83ms/step - loss: 0.1025 - accuracy: 0.7929 - val_loss: 0.1218 - val_accuracy: 0.7495
# Epoch 131/1000
# 500/500 [==============================] - 43s 85ms/step - loss: 0.1009 - accuracy: 0.7950 - val_loss: 0.1230 - val_accuracy: 0.7411
# Epoch 132/1000
# 500/500 [==============================] - 38s 77ms/step - loss: 0.1002 - accuracy: 0.7972 - val_loss: 0.1223 - val_accuracy: 0.7476
# Epoch 133/1000
# 500/500 [==============================] - 39s 78ms/step - loss: 0.1008 - accuracy: 0.7964 - val_loss: 0.1223 - val_accuracy: 0.7468
# Epoch 134/1000
# 500/500 [==============================] - ETA: 0s - loss: 0.1027 - accuracy: 0.7914
# Epoch 00134: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# 500/500 [==============================] - 42s 84ms/step - loss: 0.1027 - accuracy: 0.7914 - val_loss: 0.1226 - val_accuracy: 0.7479
# Epoch 135/1000
# 500/500 [==============================] - 40s 79ms/step - loss: 0.1009 - accuracy: 0.7966 - val_loss: 0.1219 - val_accuracy: 0.7473
# Epoch 136/1000
# 500/500 [==============================] - 42s 84ms/step - loss: 0.1006 - accuracy: 0.7971 - val_loss: 0.1225 - val_accuracy: 0.7480
# Epoch 137/1000
# 500/500 [==============================] - 41s 82ms/step - loss: 0.1006 - accuracy: 0.7963 - val_loss: 0.1215 - val_accuracy: 0.7506
# Epoch 138/1000
# 500/500 [==============================] - 41s 82ms/step - loss: 0.1000 - accuracy: 0.7976 - val_loss: 0.1217 - val_accuracy: 0.7518
# Epoch 139/1000
# 500/500 [==============================] - 39s 78ms/step - loss: 0.1008 - accuracy: 0.7960 - val_loss: 0.1217 - val_accuracy: 0.7498
# Epoch 140/1000
# 500/500 [==============================] - 40s 80ms/step - loss: 0.1007 - accuracy: 0.7972 - val_loss: 0.1219 - val_accuracy: 0.7475
# Epoch 141/1000
# 500/500 [==============================] - 40s 81ms/step - loss: 0.1007 - accuracy: 0.7947 - val_loss: 0.1224 - val_accuracy: 0.7466
# Epoch 142/1000
# 500/500 [==============================] - 40s 81ms/step - loss: 0.1002 - accuracy: 0.7975 - val_loss: 0.1221 - val_accuracy: 0.7496
# Epoch 143/1000
# 500/500 [==============================] - 42s 85ms/step - loss: 0.1005 - accuracy: 0.7988 - val_loss: 0.1216 - val_accuracy: 0.7504
# Epoch 144/1000
# 500/500 [==============================] - ETA: 0s - loss: 0.0996 - accuracy: 0.7976
# Epoch 00144: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# 500/500 [==============================] - 44s 89ms/step - loss: 0.0996 - accuracy: 0.7976 - val_loss: 0.1219 - val_accuracy: 0.7510
# Epoch 145/1000
# 500/500 [==============================] - 41s 82ms/step - loss: 0.0996 - accuracy: 0.7991 - val_loss: 0.1215 - val_accuracy: 0.7493
# Epoch 146/1000
# 500/500 [==============================] - 42s 85ms/step - loss: 0.0994 - accuracy: 0.7995 - val_loss: 0.1214 - val_accuracy: 0.7499
# Epoch 147/1000
# 500/500 [==============================] - 40s 80ms/step - loss: 0.0999 - accuracy: 0.7980 - val_loss: 0.1216 - val_accuracy: 0.7512
# Epoch 148/1000
# 500/500 [==============================] - 40s 80ms/step - loss: 0.0992 - accuracy: 0.7982 - val_loss: 0.1217 - val_accuracy: 0.7509
# Epoch 149/1000
# 500/500 [==============================] - 42s 83ms/step - loss: 0.1002 - accuracy: 0.7981 - val_loss: 0.1215 - val_accuracy: 0.7529
# Epoch 150/1000
# 500/500 [==============================] - 41s 81ms/step - loss: 0.0996 - accuracy: 0.7990 - val_loss: 0.1213 - val_accuracy: 0.7515
# Epoch 151/1000
# 500/500 [==============================] - 40s 81ms/step - loss: 0.0995 - accuracy: 0.7997 - val_loss: 0.1214 - val_accuracy: 0.7501
# Epoch 152/1000
# 500/500 [==============================] - 41s 81ms/step - loss: 0.1007 - accuracy: 0.7953 - val_loss: 0.1217 - val_accuracy: 0.7486
# Epoch 153/1000
# 500/500 [==============================] - 41s 83ms/step - loss: 0.1002 - accuracy: 0.7977 - val_loss: 0.1215 - val_accuracy: 0.7508
# Epoch 154/1000
# 500/500 [==============================] - 40s 79ms/step - loss: 0.0994 - accuracy: 0.7989 - val_loss: 0.1213 - val_accuracy: 0.7523
# Epoch 155/1000
# 500/500 [==============================] - 38s 76ms/step - loss: 0.0990 - accuracy: 0.7998 - val_loss: 0.1214 - val_accuracy: 0.7499
# Epoch 156/1000
# 500/500 [==============================] - 38s 76ms/step - loss: 0.1001 - accuracy: 0.7981 - val_loss: 0.1215 - val_accuracy: 0.7495
# Epoch 157/1000
# 500/500 [==============================] - 38s 77ms/step - loss: 0.0996 - accuracy: 0.7978 - val_loss: 0.1214 - val_accuracy: 0.7508
# Epoch 158/1000
# 500/500 [==============================] - 38s 77ms/step - loss: 0.0995 - accuracy: 0.7986 - val_loss: 0.1213 - val_accuracy: 0.7516
# Epoch 159/1000
# 500/500 [==============================] - 39s 78ms/step - loss: 0.0991 - accuracy: 0.7996 - val_loss: 0.1222 - val_accuracy: 0.7478
# Epoch 160/1000
# 500/500 [==============================] - ETA: 0s - loss: 0.1002 - accuracy: 0.7966
# Epoch 00160: ReduceLROnPlateau reducing learning rate to 7.812500371073838e-06.
# 500/500 [==============================] - 38s 76ms/step - loss: 0.1002 - accuracy: 0.7966 - val_loss: 0.1215 - val_accuracy: 0.7507
# Epoch 161/1000
# 500/500 [==============================] - 38s 75ms/step - loss: 0.0997 - accuracy: 0.7974 - val_loss: 0.1214 - val_accuracy: 0.7511
# Epoch 162/1000
# 500/500 [==============================] - 37s 75ms/step - loss: 0.0988 - accuracy: 0.8006 - val_loss: 0.1215 - val_accuracy: 0.7505
# Epoch 163/1000
# 500/500 [==============================] - 37s 75ms/step - loss: 0.0995 - accuracy: 0.8000 - val_loss: 0.1213 - val_accuracy: 0.7520
# Epoch 164/1000
# 500/500 [==============================] - 37s 75ms/step - loss: 0.0987 - accuracy: 0.7985 - val_loss: 0.1213 - val_accuracy: 0.7510
# Epoch 165/1000
# 500/500 [==============================] - 37s 75ms/step - loss: 0.0988 - accuracy: 0.7991 - val_loss: 0.1213 - val_accuracy: 0.7523
# Epoch 166/1000
# 500/500 [==============================] - 37s 75ms/step - loss: 0.1004 - accuracy: 0.7981 - val_loss: 0.1214 - val_accuracy: 0.7500
# Epoch 167/1000
# 500/500 [==============================] - 38s 77ms/step - loss: 0.0992 - accuracy: 0.7982 - val_loss: 0.1214 - val_accuracy: 0.7528
# Epoch 168/1000
# 500/500 [==============================] - 40s 80ms/step - loss: 0.0999 - accuracy: 0.7980 - val_loss: 0.1214 - val_accuracy: 0.7514
# Epoch 169/1000
# 500/500 [==============================] - 43s 86ms/step - loss: 0.0998 - accuracy: 0.7998 - val_loss: 0.1213 - val_accuracy: 0.7513
# Epoch 170/1000
# 500/500 [==============================] - ETA: 0s - loss: 0.0996 - accuracy: 0.7988
# Epoch 00170: ReduceLROnPlateau reducing learning rate to 3.906250185536919e-06.
# 500/500 [==============================] - 41s 82ms/step - loss: 0.0996 - accuracy: 0.7988 - val_loss: 0.1213 - val_accuracy: 0.7517
# Epoch 171/1000
# 500/500 [==============================] - 41s 82ms/step - loss: 0.0983 - accuracy: 0.8034 - val_loss: 0.1214 - val_accuracy: 0.7522
# Epoch 172/1000
# 500/500 [==============================] - 42s 84ms/step - loss: 0.0998 - accuracy: 0.7982 - val_loss: 0.1215 - val_accuracy: 0.7519
# Epoch 173/1000
# 500/500 [==============================] - 43s 86ms/step - loss: 0.0991 - accuracy: 0.8006 - val_loss: 0.1214 - val_accuracy: 0.7528
# Epoch 174/1000
# 500/500 [==============================] - 40s 80ms/step - loss: 0.0993 - accuracy: 0.7972 - val_loss: 0.1214 - val_accuracy: 0.7522
# Epoch 175/1000
# 500/500 [==============================] - 39s 79ms/step - loss: 0.0988 - accuracy: 0.7996 - val_loss: 0.1214 - val_accuracy: 0.7504
# Epoch 176/1000
# 500/500 [==============================] - 38s 77ms/step - loss: 0.0996 - accuracy: 0.7982 - val_loss: 0.1214 - val_accuracy: 0.7521
# Epoch 177/1000
# 500/500 [==============================] - 37s 75ms/step - loss: 0.0994 - accuracy: 0.7977 - val_loss: 0.1214 - val_accuracy: 0.7518
# Epoch 178/1000
# 500/500 [==============================] - 36s 72ms/step - loss: 0.0994 - accuracy: 0.7979 - val_loss: 0.1213 - val_accuracy: 0.7520
# Epoch 179/1000
# 500/500 [==============================] - 36s 72ms/step - loss: 0.0988 - accuracy: 0.8000 - val_loss: 0.1213 - val_accuracy: 0.7520
# Epoch 180/1000
# 500/500 [==============================] - ETA: 0s - loss: 0.0996 - accuracy: 0.7996
# Epoch 00180: ReduceLROnPlateau reducing learning rate to 1.9531250927684596e-06.
# 500/500 [==============================] - 36s 73ms/step - loss: 0.0996 - accuracy: 0.7996 - val_loss: 0.1213 - val_accuracy: 0.7514
# Epoch 181/1000
# 500/500 [==============================] - 38s 75ms/step - loss: 0.0992 - accuracy: 0.8002 - val_loss: 0.1213 - val_accuracy: 0.7513
# Epoch 182/1000
# 500/500 [==============================] - 38s 76ms/step - loss: 0.0987 - accuracy: 0.8027 - val_loss: 0.1213 - val_accuracy: 0.7526
# Epoch 183/1000
# 500/500 [==============================] - 38s 76ms/step - loss: 0.0992 - accuracy: 0.7993 - val_loss: 0.1213 - val_accuracy: 0.7522
# Epoch 184/1000
# 500/500 [==============================] - 38s 76ms/step - loss: 0.0994 - accuracy: 0.7982 - val_loss: 0.1213 - val_accuracy: 0.7525
# Epoch 185/1000
# 500/500 [==============================] - ETA: 0s - loss: 0.0990 - accuracy: 0.7997Restoring model weights from the end of the best epoch.
# 500/500 [==============================] - 38s 77ms/step - loss: 0.0990 - accuracy: 0.7997 - val_loss: 0.1213 - val_accuracy: 0.7522
# Epoch 00185: early stopping

# %%
import matplotlib.pyplot as plt

fig = plt.figure(figsize=(10,6))
plt.plot(hist.history['loss'], color='#785ef0')
plt.plot(hist.history['val_loss'], color='#dc267f')
plt.title('Model Loss Progress')
plt.ylabel('Binary Cross-Entropy Loss')
plt.xlabel('Epoch')
plt.legend(['Training Set', 'Test Set'], loc='upper right')
plt.savefig('cnn-gabor.9*9.png', dpi=350, bbox_inches='tight')
plt.show()

# %%
from sklearn.preprocessing import MinMaxScaler

cnnl1 = classifier.layers[1].name   # get the name of the first conv layer
W = classifier.get_layer(name=cnnl1).get_weights()[0]   #get the filters
wshape = W.shape  #save the original shape

# this part will scale to [0, 1] for visualization purposes
scaler = MinMaxScaler()
scaler.fit(W.reshape(-1,1))
W = scaler.transform(W.reshape(-1,1))
W = W.reshape(wshape)

# since there are 64 filters, we will display them 8x8
fig, axs = plt.subplots(8,8, figsize=(24,24))
fig.subplots_adjust(hspace = .25, wspace=.001)
axs = axs.ravel()
for i in range(W.shape[-1]):
  # we reshape to a 3D (RGB) image shape and display
  h = np.reshape(W[:,:,:,i], (9,9,3))
  axs[i].imshow(h)
  axs[i].set_title('Filter ' + str(i))    
plt.savefig("cnn-gabor.full filters-9*9.png", bbox_inches='tight', dpi=350)

# %%
cnnl1 = classifier.layers[1].name   # get the name of the first conv layer
W = classifier.get_layer(name=cnnl1).get_weights()[0]
plt.hist(W.ravel(), bins=100)
print(np.min(W),np.max(W))
# Out:
# -0.4485356 0.33007565
