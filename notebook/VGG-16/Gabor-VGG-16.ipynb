# %%
from skimage.filters import gabor_kernel
from skimage import io
from skimage.transform import resize
from matplotlib import pyplot as plt 
import numpy as np

import math

# %%
fig = plt.subplots(12, 16, figsize=(22,22))
filterbank = []
cnt = 0
for angle in np.linspace(0.0, 3.14159, 16, endpoint=False):
  for freq in [0.3, 0.45, 0.6]:
    for band in [0.2, 0.8, 0.6, 0.4]:
      print(freq, band, angle)
      cnt = cnt + 1
      gf = gabor_kernel(frequency=freq, bandwidth=band, theta=angle, n_stds=0).real
      plt.subplot(12, 16, cnt)
#       gf = resize(gk.real,(9,9),anti_aliasing=False)
#       gf = gf - np.min(gf)
#       gf = gf/np.max(gf)
#       gf = gf * 0.6
#       gf = gf - 0.3
      filterbank.append(gf)
      plt.imshow(gf, cmap='gray')
      print(gf.real.shape)
      # plt.colorbar()
      plt.axis('off')
      plt.title("$\\gamma=${0:0.1f} $\\lambda=${1:0.1f} $\\theta=${0:0.2f}".format(freq,band,angle))
plt.show()
# Out:
# 0.3 0.2 0.0
# (3, 3)
# 0.3 0.8 0.0
# (3, 3)
# 0.3 0.6 0.0
# (3, 3)
# 0.3 0.4 0.0
# (3, 3)
# 0.45 0.2 0.0
# (3, 3)
# 0.45 0.8 0.0
# (3, 3)
# 0.45 0.6 0.0
# (3, 3)
# 0.45 0.4 0.0
# (3, 3)
# 0.6 0.2 0.0
# (3, 3)
# 0.6 0.8 0.0
# (3, 3)
# 0.6 0.6 0.0
# (3, 3)
# 0.6 0.4 0.0
# (3, 3)
# 0.3 0.2 0.196349375
# (3, 3)
# 0.3 0.8 0.196349375
# (3, 3)
# 0.3 0.6 0.196349375
# (3, 3)
# 0.3 0.4 0.196349375
# (3, 3)
# 0.45 0.2 0.196349375
# (3, 3)
# 0.45 0.8 0.196349375
# (3, 3)
# 0.45 0.6 0.196349375
# (3, 3)
# 0.45 0.4 0.196349375
# (3, 3)
# 0.6 0.2 0.196349375
# (3, 3)
# 0.6 0.8 0.196349375
# (3, 3)
# 0.6 0.6 0.196349375
# (3, 3)
# 0.6 0.4 0.196349375
# (3, 3)
# 0.3 0.2 0.39269875
# (3, 3)
# 0.3 0.8 0.39269875
# (3, 3)
# 0.3 0.6 0.39269875
# (3, 3)
# 0.3 0.4 0.39269875
# (3, 3)
# 0.45 0.2 0.39269875
# (3, 3)
# 0.45 0.8 0.39269875
# (3, 3)
# 0.45 0.6 0.39269875
# (3, 3)
# 0.45 0.4 0.39269875
# (3, 3)
# 0.6 0.2 0.39269875
# (3, 3)
# 0.6 0.8 0.39269875
# (3, 3)
# 0.6 0.6 0.39269875
# (3, 3)
# 0.6 0.4 0.39269875
# (3, 3)
# 0.3 0.2 0.5890481249999999
# (3, 3)
# 0.3 0.8 0.5890481249999999
# (3, 3)
# 0.3 0.6 0.5890481249999999
# (3, 3)
# 0.3 0.4 0.5890481249999999
# (3, 3)
# 0.45 0.2 0.5890481249999999
# (3, 3)
# 0.45 0.8 0.5890481249999999
# (3, 3)
# 0.45 0.6 0.5890481249999999
# (3, 3)
# 0.45 0.4 0.5890481249999999
# (3, 3)
# 0.6 0.2 0.5890481249999999
# (3, 3)
# 0.6 0.8 0.5890481249999999
# (3, 3)
# 0.6 0.6 0.5890481249999999
# (3, 3)
# 0.6 0.4 0.5890481249999999
# (3, 3)
# 0.3 0.2 0.7853975
# (3, 3)
# 0.3 0.8 0.7853975
# (3, 3)
# 0.3 0.6 0.7853975
# (3, 3)
# 0.3 0.4 0.7853975
# (3, 3)
# 0.45 0.2 0.7853975
# (3, 3)
# 0.45 0.8 0.7853975
# (3, 3)
# 0.45 0.6 0.7853975
# (3, 3)
# 0.45 0.4 0.7853975
# (3, 3)
# 0.6 0.2 0.7853975
# (3, 3)
# 0.6 0.8 0.7853975
# (3, 3)
# 0.6 0.6 0.7853975
# (3, 3)
# 0.6 0.4 0.7853975
# (3, 3)
# 0.3 0.2 0.981746875
# (3, 3)
# 0.3 0.8 0.981746875
# (3, 3)
# 0.3 0.6 0.981746875
# (3, 3)
# 0.3 0.4 0.981746875
# (3, 3)
# 0.45 0.2 0.981746875
# (3, 3)
# 0.45 0.8 0.981746875
# (3, 3)
# 0.45 0.6 0.981746875
# (3, 3)
# 0.45 0.4 0.981746875
# (3, 3)
# 0.6 0.2 0.981746875
# (3, 3)
# 0.6 0.8 0.981746875
# (3, 3)
# 0.6 0.6 0.981746875
# (3, 3)
# 0.6 0.4 0.981746875
# (3, 3)
# 0.3 0.2 1.1780962499999998
# (3, 3)
# 0.3 0.8 1.1780962499999998
# (3, 3)
# 0.3 0.6 1.1780962499999998
# (3, 3)
# 0.3 0.4 1.1780962499999998
# (3, 3)
# 0.45 0.2 1.1780962499999998
# (3, 3)
# 0.45 0.8 1.1780962499999998
# (3, 3)
# 0.45 0.6 1.1780962499999998
# (3, 3)
# 0.45 0.4 1.1780962499999998
# (3, 3)
# 0.6 0.2 1.1780962499999998
# (3, 3)
# 0.6 0.8 1.1780962499999998
# (3, 3)
# 0.6 0.6 1.1780962499999998
# (3, 3)
# 0.6 0.4 1.1780962499999998
# (3, 3)
# 0.3 0.2 1.374445625
# (3, 3)
# 0.3 0.8 1.374445625
# (3, 3)
# 0.3 0.6 1.374445625
# (3, 3)
# 0.3 0.4 1.374445625
# (3, 3)
# 0.45 0.2 1.374445625
# (3, 3)
# 0.45 0.8 1.374445625
# (3, 3)
# 0.45 0.6 1.374445625
# (3, 3)
# 0.45 0.4 1.374445625
# (3, 3)
# 0.6 0.2 1.374445625
# (3, 3)
# 0.6 0.8 1.374445625
# (3, 3)
# 0.6 0.6 1.374445625
# (3, 3)
# 0.6 0.4 1.374445625
# (3, 3)
# 0.3 0.2 1.570795
# (3, 3)
# 0.3 0.8 1.570795
# (3, 3)
# 0.3 0.6 1.570795
# (3, 3)
# 0.3 0.4 1.570795
# (3, 3)
# 0.45 0.2 1.570795
# (3, 3)
# 0.45 0.8 1.570795
# (3, 3)
# 0.45 0.6 1.570795
# (3, 3)
# 0.45 0.4 1.570795
# (3, 3)
# 0.6 0.2 1.570795
# (3, 3)
# 0.6 0.8 1.570795
# (3, 3)
# 0.6 0.6 1.570795
# (3, 3)
# 0.6 0.4 1.570795
# (3, 3)
# 0.3 0.2 1.767144375
# (3, 3)
# 0.3 0.8 1.767144375
# (3, 3)
# 0.3 0.6 1.767144375
# (3, 3)
# 0.3 0.4 1.767144375
# (3, 3)
# 0.45 0.2 1.767144375
# (3, 3)
# 0.45 0.8 1.767144375
# (3, 3)
# 0.45 0.6 1.767144375
# (3, 3)
# 0.45 0.4 1.767144375
# (3, 3)
# 0.6 0.2 1.767144375
# (3, 3)
# 0.6 0.8 1.767144375
# (3, 3)
# 0.6 0.6 1.767144375
# (3, 3)
# 0.6 0.4 1.767144375
# (3, 3)
# 0.3 0.2 1.96349375
# (3, 3)
# 0.3 0.8 1.96349375
# (3, 3)
# 0.3 0.6 1.96349375
# (3, 3)
# 0.3 0.4 1.96349375
# (3, 3)
# 0.45 0.2 1.96349375
# (3, 3)
# 0.45 0.8 1.96349375
# (3, 3)
# 0.45 0.6 1.96349375
# (3, 3)
# 0.45 0.4 1.96349375
# (3, 3)
# 0.6 0.2 1.96349375
# (3, 3)
# 0.6 0.8 1.96349375
# (3, 3)
# 0.6 0.6 1.96349375
# (3, 3)
# 0.6 0.4 1.96349375
# (3, 3)
# 0.3 0.2 2.159843125
# (3, 3)
# 0.3 0.8 2.159843125
# (3, 3)
# 0.3 0.6 2.159843125
# (3, 3)
# 0.3 0.4 2.159843125
# (3, 3)
# 0.45 0.2 2.159843125
# (3, 3)
# 0.45 0.8 2.159843125
# (3, 3)
# 0.45 0.6 2.159843125
# (3, 3)
# 0.45 0.4 2.159843125
# (3, 3)
# 0.6 0.2 2.159843125
# (3, 3)
# 0.6 0.8 2.159843125
# (3, 3)
# 0.6 0.6 2.159843125
# (3, 3)
# 0.6 0.4 2.159843125
# (3, 3)
# 0.3 0.2 2.3561924999999997
# (3, 3)
# 0.3 0.8 2.3561924999999997
# (3, 3)
# 0.3 0.6 2.3561924999999997
# (3, 3)
# 0.3 0.4 2.3561924999999997
# (3, 3)
# 0.45 0.2 2.3561924999999997
# (3, 3)
# 0.45 0.8 2.3561924999999997
# (3, 3)
# 0.45 0.6 2.3561924999999997
# (3, 3)
# 0.45 0.4 2.3561924999999997
# (3, 3)
# 0.6 0.2 2.3561924999999997
# (3, 3)
# 0.6 0.8 2.3561924999999997
# (3, 3)
# 0.6 0.6 2.3561924999999997
# (3, 3)
# 0.6 0.4 2.3561924999999997
# (3, 3)
# 0.3 0.2 2.5525418749999997
# (3, 3)
# 0.3 0.8 2.5525418749999997
# (3, 3)
# 0.3 0.6 2.5525418749999997
# (3, 3)
# 0.3 0.4 2.5525418749999997
# (3, 3)
# 0.45 0.2 2.5525418749999997
# (3, 3)
# 0.45 0.8 2.5525418749999997
# (3, 3)
# 0.45 0.6 2.5525418749999997
# (3, 3)
# 0.45 0.4 2.5525418749999997
# (3, 3)
# 0.6 0.2 2.5525418749999997
# (3, 3)
# 0.6 0.8 2.5525418749999997
# (3, 3)
# 0.6 0.6 2.5525418749999997
# (3, 3)
# 0.6 0.4 2.5525418749999997
# (3, 3)
# 0.3 0.2 2.74889125
# (3, 3)
# 0.3 0.8 2.74889125
# (3, 3)
# 0.3 0.6 2.74889125
# (3, 3)
# 0.3 0.4 2.74889125
# (3, 3)
# 0.45 0.2 2.74889125
# (3, 3)
# 0.45 0.8 2.74889125
# (3, 3)
# 0.45 0.6 2.74889125
# (3, 3)
# 0.45 0.4 2.74889125
# (3, 3)
# 0.6 0.2 2.74889125
# (3, 3)
# 0.6 0.8 2.74889125
# (3, 3)
# 0.6 0.6 2.74889125
# (3, 3)
# 0.6 0.4 2.74889125
# (3, 3)
# 0.3 0.2 2.945240625
# (3, 3)
# 0.3 0.8 2.945240625
# (3, 3)
# 0.3 0.6 2.945240625
# (3, 3)
# 0.3 0.4 2.945240625
# (3, 3)
# 0.45 0.2 2.945240625
# (3, 3)
# 0.45 0.8 2.945240625
# (3, 3)
# 0.45 0.6 2.945240625
# (3, 3)
# 0.45 0.4 2.945240625
# (3, 3)
# 0.6 0.2 2.945240625
# (3, 3)
# 0.6 0.8 2.945240625
# (3, 3)
# 0.6 0.6 2.945240625
# (3, 3)
# 0.6 0.4 2.945240625
# (3, 3)

# %%
from tensorflow.keras.datasets import cifar10
from tensorflow.keras.utils import to_categorical

# The data, split between train and test sets:
(x_train, y_train), (x_test, y_test) = cifar10.load_data()
x_train = x_train.astype('float32') / 255.0
x_test = x_test.astype('float32') / 255.0

y_train = to_categorical(y_train, 10)
y_test = to_categorical(y_test, 10)

print('x_train shape:', x_train.shape)
print('x_test shape:', x_test.shape)
# Out:
# x_train shape: (50000, 32, 32, 3)
# x_test shape: (10000, 32, 32, 3)

# %%
# Importing the Keras libraries and packages
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Activation
from tensorflow.keras.layers import Input, Dense, Dropout, BatchNormalization
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import RMSprop, Adam

input_dim = (32,32,3)
input_img = Input(shape=input_dim)

cl1 = Conv2D(64, kernel_size=(3,3), strides=(1,1), padding='same',
             input_shape=input_dim, activation='relu')(input_img)
pl1 = MaxPooling2D(pool_size=(2,2), strides=(2,2))(cl1)

cl2 = Conv2D(128, kernel_size=(3,3), strides=(1,1), padding='same',
             activation='relu')(pl1)
pl2 = MaxPooling2D(pool_size=(2,2), strides=(2,2))(cl2)

cl3 = Conv2D(256, kernel_size=(3,3), strides=(1,1), padding='same',
             activation='relu')(pl2)
pl3 = MaxPooling2D(pool_size=(2,2), strides=(2,2))(cl3)

cl4 = Conv2D(512, kernel_size=(3,3), strides=(1,1), padding='same',
             activation='relu')(pl3)
pl4 = MaxPooling2D(pool_size=(2,2), strides=(2,2))(cl4)

cl5 = Conv2D(512, kernel_size=(3,3), strides=(1,1), padding='same',
             activation='relu')(pl4)
pl5 = MaxPooling2D(pool_size=(2,2), strides=(2,2))(cl5)

flat = Flatten()(pl5)

fc6 = Dense(units=4096, activation='relu')(flat)
fc7 = Dense(units=4096, activation='relu')(fc6)

output = Dense(units=10, activation='softmax')(fc7)

classifier = Model(input_img, output)

# Compiling the CNN
opt = RMSprop(learning_rate=0.001)
# opt = Adam(learning_rate=0.01)

classifier.compile(optimizer = opt, loss = 'binary_crossentropy', 
                   metrics = ['accuracy'])

print(classifier.summary())
# Out:
# Model: "functional_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 32, 32, 3)]       0
# _________________________________________________________________
# conv2d (Conv2D)              (None, 32, 32, 64)        1792
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 16, 16, 64)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 16, 16, 128)       73856
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 8, 8, 128)         0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 8, 8, 256)         295168
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 4, 4, 256)         0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 4, 4, 512)         1180160
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 2, 2, 512)         0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 2, 2, 512)         2359808
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 1, 1, 512)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 512)               0
# _________________________________________________________________
# dense (Dense)                (None, 4096)              2101248
# _________________________________________________________________
# dense_1 (Dense)              (None, 4096)              16781312
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                40970
# =================================================================
# Total params: 22,834,314
# Trainable params: 22,834,314
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
np.array(filterbank).shape
# Out:
# (192, 3, 3)

# %%
cnnl1 = classifier.layers[1].name   # get the name of the first conv layer
W = classifier.get_layer(name=cnnl1).get_weights()[0]   #get the filters
wshape = W.shape  #save the original shape

# %%
wshape
# Out:
# (3, 3, 3, 64)

# %%
gabor_filters = np.empty(wshape, dtype='float32')
for kernel_index in range(wshape[3]):
    for channel_index in range(3):
        gabor_filters[:,:,channel_index, kernel_index] = filterbank[kernel_index+channel_index]

# %%
# Fitting the CNN to the images

from tensorflow.keras.callbacks import ReduceLROnPlateau, EarlyStopping

reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=10,  
                              min_delta=1e-4, mode='min', verbose=1)

stop_alg = EarlyStopping(monitor='val_loss', patience=35, 
                         restore_best_weights=True, verbose=1)

hist = classifier.fit(x_train, y_train, batch_size=100, epochs=1000, 
                   callbacks=[stop_alg, reduce_lr], shuffle=True, 
                   validation_data=(x_test, y_test))

classifier.save_weights("cnn.hdf5")
# Out:
# Epoch 1/1000
# 500/500 [==============================] - 421s 841ms/step - loss: 0.2977 - accuracy: 0.2357 - val_loss: 0.2336 - val_accuracy: 0.4440
# Epoch 2/1000
# 500/500 [==============================] - 408s 815ms/step - loss: 0.2144 - accuracy: 0.4997 - val_loss: 0.1764 - val_accuracy: 0.6106
# Epoch 3/1000
# 500/500 [==============================] - 416s 832ms/step - loss: 0.1692 - accuracy: 0.6295 - val_loss: 0.1604 - val_accuracy: 0.6550
# Epoch 4/1000
# 500/500 [==============================] - 413s 827ms/step - loss: 0.1414 - accuracy: 0.7006 - val_loss: 0.1464 - val_accuracy: 0.6936
# Epoch 5/1000
# 500/500 [==============================] - 437s 875ms/step - loss: 0.1217 - accuracy: 0.7492 - val_loss: 0.1351 - val_accuracy: 0.7328
# Epoch 6/1000
# 500/500 [==============================] - 428s 856ms/step - loss: 0.1069 - accuracy: 0.7801 - val_loss: 0.1460 - val_accuracy: 0.7520
# Epoch 7/1000
# 500/500 [==============================] - 421s 841ms/step - loss: 0.0962 - accuracy: 0.8069 - val_loss: 0.1463 - val_accuracy: 0.7197
# Epoch 8/1000
# 500/500 [==============================] - 424s 849ms/step - loss: 0.0863 - accuracy: 0.8291 - val_loss: 0.1403 - val_accuracy: 0.7463
# Epoch 9/1000
# 500/500 [==============================] - 424s 848ms/step - loss: 0.0782 - accuracy: 0.8480 - val_loss: 0.1401 - val_accuracy: 0.7567
# Epoch 10/1000
# 500/500 [==============================] - 416s 831ms/step - loss: 0.0713 - accuracy: 0.8647 - val_loss: 0.1618 - val_accuracy: 0.7573
# Epoch 11/1000
# 500/500 [==============================] - 416s 832ms/step - loss: 0.0638 - accuracy: 0.8824 - val_loss: 0.1358 - val_accuracy: 0.7438
# Epoch 12/1000
# 500/500 [==============================] - 418s 836ms/step - loss: 0.0616 - accuracy: 0.8878 - val_loss: 0.1753 - val_accuracy: 0.6885
# Epoch 13/1000
# 500/500 [==============================] - 423s 845ms/step - loss: 0.0542 - accuracy: 0.9012 - val_loss: 0.1656 - val_accuracy: 0.7722
# Epoch 14/1000
# 500/500 [==============================] - 439s 878ms/step - loss: 0.0515 - accuracy: 0.9082 - val_loss: 0.1816 - val_accuracy: 0.7359
# Epoch 15/1000
# 500/500 [==============================] - ETA: 0s - loss: 0.0497 - accuracy: 0.9118
# Epoch 00015: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 500/500 [==============================] - 426s 853ms/step - loss: 0.0497 - accuracy: 0.9118 - val_loss: 0.1626 - val_accuracy: 0.7550
# Epoch 16/1000
# 500/500 [==============================] - 400s 799ms/step - loss: 0.0221 - accuracy: 0.9619 - val_loss: 0.1953 - val_accuracy: 0.7797
# Epoch 17/1000
# 500/500 [==============================] - 425s 851ms/step - loss: 0.0185 - accuracy: 0.9710 - val_loss: 0.2586 - val_accuracy: 0.7769
# Epoch 18/1000
# 500/500 [==============================] - 410s 820ms/step - loss: 0.0180 - accuracy: 0.9724 - val_loss: 0.2335 - val_accuracy: 0.7715
# Epoch 19/1000
# 500/500 [==============================] - 424s 847ms/step - loss: 0.0175 - accuracy: 0.9735 - val_loss: 0.2379 - val_accuracy: 0.7541
# Epoch 20/1000
# 500/500 [==============================] - 409s 819ms/step - loss: 0.0174 - accuracy: 0.9746 - val_loss: 0.1974 - val_accuracy: 0.7635
# Epoch 21/1000
# 500/500 [==============================] - 416s 832ms/step - loss: 0.0179 - accuracy: 0.9745 - val_loss: 0.2595 - val_accuracy: 0.7766
# Epoch 22/1000
# 500/500 [==============================] - 411s 822ms/step - loss: 0.0164 - accuracy: 0.9758 - val_loss: 0.2755 - val_accuracy: 0.7710
# Epoch 23/1000
# 500/500 [==============================] - 457s 915ms/step - loss: 0.0173 - accuracy: 0.9755 - val_loss: 0.2789 - val_accuracy: 0.7758
# Epoch 24/1000
# 500/500 [==============================] - 415s 830ms/step - loss: 0.0175 - accuracy: 0.9757 - val_loss: 0.2916 - val_accuracy: 0.7664
# Epoch 25/1000
# 500/500 [==============================] - ETA: 0s - loss: 0.0174 - accuracy: 0.9767
# Epoch 00025: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 500/500 [==============================] - 472s 945ms/step - loss: 0.0174 - accuracy: 0.9767 - val_loss: 0.2421 - val_accuracy: 0.7588
# Epoch 26/1000
# 500/500 [==============================] - 417s 834ms/step - loss: 0.0056 - accuracy: 0.9922 - val_loss: 0.3500 - val_accuracy: 0.7846
# Epoch 27/1000
# 500/500 [==============================] - 423s 845ms/step - loss: 0.0055 - accuracy: 0.9929 - val_loss: 0.3229 - val_accuracy: 0.7724
# Epoch 28/1000
# 500/500 [==============================] - 415s 830ms/step - loss: 0.0053 - accuracy: 0.9938 - val_loss: 0.4535 - val_accuracy: 0.7710
# Epoch 29/1000
# 500/500 [==============================] - 403s 806ms/step - loss: 0.0055 - accuracy: 0.9937 - val_loss: 0.3987 - val_accuracy: 0.7749
# Epoch 30/1000
# 500/500 [==============================] - 410s 820ms/step - loss: 0.0066 - accuracy: 0.9937 - val_loss: 0.4018 - val_accuracy: 0.7861
# Epoch 31/1000
# 500/500 [==============================] - 410s 819ms/step - loss: 0.0076 - accuracy: 0.9928 - val_loss: 0.3378 - val_accuracy: 0.7717
# Epoch 32/1000
# 500/500 [==============================] - 406s 811ms/step - loss: 0.0061 - accuracy: 0.9935 - val_loss: 0.4134 - val_accuracy: 0.7807
# Epoch 33/1000
# 500/500 [==============================] - 409s 817ms/step - loss: 0.0056 - accuracy: 0.9941 - val_loss: 0.4066 - val_accuracy: 0.7859
# Epoch 34/1000
# 500/500 [==============================] - 417s 835ms/step - loss: 0.0064 - accuracy: 0.9935 - val_loss: 0.4437 - val_accuracy: 0.7856
# Epoch 35/1000
# 500/500 [==============================] - ETA: 0s - loss: 0.0060 - accuracy: 0.9931
# Epoch 00035: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 500/500 [==============================] - 408s 816ms/step - loss: 0.0060 - accuracy: 0.9931 - val_loss: 0.4632 - val_accuracy: 0.7814
# Epoch 36/1000
# 500/500 [==============================] - 403s 806ms/step - loss: 0.0027 - accuracy: 0.9979 - val_loss: 0.4668 - val_accuracy: 0.7818
# Epoch 37/1000
# 500/500 [==============================] - 409s 819ms/step - loss: 0.0016 - accuracy: 0.9988 - val_loss: 0.4918 - val_accuracy: 0.7876
# Epoch 38/1000
# 500/500 [==============================] - 466s 933ms/step - loss: 0.0014 - accuracy: 0.9990 - val_loss: 0.4960 - val_accuracy: 0.7804
# Epoch 39/1000
# 500/500 [==============================] - 412s 825ms/step - loss: 0.0013 - accuracy: 0.9990 - val_loss: 0.4733 - val_accuracy: 0.7904
# Epoch 40/1000
# 500/500 [==============================] - ETA: 0s - loss: 0.0014 - accuracy: 0.9990Restoring model weights from the end of the best epoch.
# 500/500 [==============================] - 395s 791ms/step - loss: 0.0014 - accuracy: 0.9990 - val_loss: 0.5068 - val_accuracy: 0.7889
# Epoch 00040: early stopping

# %%
import matplotlib.pyplot as plt

fig = plt.figure(figsize=(10,6))
plt.plot(hist.history['loss'], color='#785ef0')
plt.plot(hist.history['val_loss'], color='#dc267f')
plt.title('Model Loss Progress')
plt.ylabel('Binary Cross-Entropy Loss')
plt.xlabel('Epoch')
plt.legend(['Training Set', 'Test Set'], loc='upper right')
plt.savefig('cnn-gabor.cifar10.loss-2.png', dpi=350, bbox_inches='tight')
plt.show()

# %%
from sklearn.preprocessing import MinMaxScaler

cnnl1 = classifier.layers[1].name   # get the name of the first conv layer
W = classifier.get_layer(name=cnnl1).get_weights()[0]   #get the filters
wshape = W.shape  #save the original shape

# this part will scale to [0, 1] for visualization purposes
scaler = MinMaxScaler()
scaler.fit(W.reshape(-1,1))
W = scaler.transform(W.reshape(-1,1))
W = W.reshape(wshape)

# since there are 64 filters, we will display them 8x8
fig, axs = plt.subplots(8,8, figsize=(24,24))
fig.subplots_adjust(hspace = .25, wspace=.001)
axs = axs.ravel()
for i in range(W.shape[-1]):
  # we reshape to a 3D (RGB) image shape and display
  h = np.reshape(W[:,:,:,i], (3,3,3))
  axs[i].imshow(h)
  axs[i].set_title('Filter ' + str(i))    
plt.savefig("cnn-gabor.full.filters-2.png", bbox_inches='tight', dpi=350)

# %%
cnnl1 = classifier.layers[1].name   # get the name of the first conv layer
W = classifier.get_layer(name=cnnl1).get_weights()[0]
plt.hist(W.ravel(), bins=100)
print(np.min(W),np.max(W))
# Out:
# -0.17248091 0.1565103
