# %% [markdown]
# <a href="https://colab.research.google.com/github/mehang/Improvised-CNN/blob/master/notebook/Cifar-100-fine/resized/15*15/cifar100_fine_15_15.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import matplotlib.pyplot as plt
import numpy as np
import os
import PIL
import tensorflow as tf
import pandas as pd

from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import pathlib
import time

from tensorflow.keras.preprocessing.image import ImageDataGenerator, load_img
from tensorflow.keras.utils import to_categorical
from sklearn.model_selection import train_test_split

# %%
# !unzip /content/drive/My\ Drive/Gabor\ Dataset/cifar100_fine.zip -d cifar100_fine
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: cifar100_fine/cifar100_fine/test/cloud.8.jpg
#   inflating: cifar100_fine/cifar100_fine/test/orange.19.jpg
#   inflating: cifar100_fine/cifar100_fine/test/mountain.21.jpg
#   inflating: cifar100_fine/cifar100_fine/test/chimpanzee.24.jpg
#   inflating: cifar100_fine/cifar100_fine/test/computer_keyboard.26.jpg
#   inflating: cifar100_fine/cifar100_fine/test/rose.29.jpg
#   inflating: cifar100_fine/cifar100_fine/test/turtle.33.jpg
#   inflating: cifar100_fine/cifar100_fine/test/beaver.50.jpg
#   inflating: cifar100_fine/cifar100_fine/test/sweet_pepper.101.jpg
#   inflating: cifar100_fine/cifar100_fine/test/forest.124.jpg
#   inflating: cifar100_fine/cifar100_fine/test/snail.151.jpg
#   inflating: cifar100_fine/cifar100_fine/test/caterpillar.152.jpg
#   inflating: cifar100_fine/cifar100_fine/test/cup.185.jpg
#   inflating: cifar100_fine/cifar100_fine/test/whale.187.jpg
#   inflating: cifar100_fine/cifar100_fine/test/plain.203.jpg
#   inflating: cifar100_fine/cifar100_fine/test/streetcar.219.jpg
#   inflating: cifar100_fine/cifar100_fine/test/snail.223.jpg
#   inflating: cifar100_fine/cifar100_fine/test/apple.226.jpg
#   inflating: cifar100_fine/cifar100_fine/test/sunflower.238.jpg
#   inflating: cifar100_fine/cifar100_fine/test/chimpanzee.243.jpg
#   inflating: cifar100_fine/cifar100_fine/test/table.281.jpg
#   inflating: cifar100_fine/cifar100_fine/test/leopard.288.jpg
#   inflating: cifar100_fine/cifar100_fine/test/telephone.304.jpg
#   inflating: cifar100_fine/cifar100_fine/test/leopard.313.jpg
#   inflating: cifar100_fine/cifar100_fine/test/ray.323.jpg
#   inflating: cifar100_fine/cifar100_fine/test/bed.334.jpg
#   inflating: cifar100_fine/cifar100_fine/test/plain.335.jpg
#   inflating: cifar100_fine/cifar100_fine/test/willow_tree.356.jpg
#   inflating: cifar100_fine/cifar100_fine/test/bowl.365.jpg
#   inflating: cifar100_fine/cifar100_fine/test/mountain.397.jpg
#   inflating: cifar100_fine/cifar100_fine/test/bee.404.jpg
#   inflating: cifar100_fine/cifar100_fine/test/lamp.410.jpg
#   inflating: cifar100_fine/cifar100_fine/test/willow_tree.411.jpg
#   inflating: cifar100_fine/cifar100_fine/test/crocodile.428.jpg
#   inflating: cifar100_fine/cifar100_fine/test/flatfish.429.jpg
#   inflating: cifar100_fine/cifar100_fine/test/elephant.436.jpg
#   inflating: cifar100_fine/cifar100_fine/test/tank.445.jpg
#   inflating: cifar100_fine/cifar100_fine/test/woman.454.jpg
#   inflating: cifar100_fine/cifar100_fine/test/baby.463.jpg
#   inflating: cifar100_fine/cifar100_fine/test/shark.474.jpg
#   inflating: cifar100_fine/cifar100_fine/test/lawn_mower.483.jpg
#   inflating: cifar100_fine/cifar100_fine/test/kangaroo.490.jpg
#   inflating: cifar100_fine/cifar100_fine/test/baby.504.jpg
#   inflating: cifar100_fine/cifar100_fine/test/girl.512.jpg
#   inflating: cifar100_fine/cifar100_fine/test/whale.526.jpg
#   inflating: cifar100_fine/cifar100_fine/test/skyscraper.536.jpg
#   inflating: cifar100_fine/cifar100_fine/test/seal.553.jpg
#   inflating: cifar100_fine/cifar100_fine/test/maple_tree.559.jpg
#   inflating: cifar100_fine/cifar100_fine/test/aquarium_fish.572.jpg
#   inflating: cifar100_fine/cifar100_fine/test/television.581.jpg
#   inflating: cifar100_fine/cifar100_fine/test/bridge.587.jpg
#   inflating: cifar100_fine/cifar100_fine/test/raccoon.606.jpg
#   inflating: cifar100_fine/cifar100_fine/test/clock.618.jpg
#   inflating: cifar100_fine/cifar100_fine/test/bus.619.jpg
#   inflating: cifar100_fine/cifar100_fine/test/apple.623.jpg
#   inflating: cifar100_fine/cifar100_fine/test/lawn_mower.640.jpg
#   inflating: cifar100_fine/cifar100_fine/test/shark.671.jpg
#   inflating: cifar100_fine/cifar100_fine/test/snail.676.jpg
#   inflating: cifar100_fine/cifar100_fine/test/couch.697.jpg
#   inflating: cifar100_fine/cifar100_fine/test/snake.699.jpg
#   inflating: cifar100_fine/cifar100_fine/test/pear.719.jpg
#   inflating: cifar100_fine/cifar100_fine/test/television.723.jpg
#   inflating: cifar100_fine/cifar100_fine/test/snake.731.jpg
#   inflating: cifar100_fine/cifar100_fine/test/road.733.jpg
#   inflating: cifar100_fine/cifar100_fine/test/bear.737.jpg
#   inflating: cifar100_fine/cifar100_fine/test/lawn_mower.745.jpg
#   inflating: cifar100_fine/cifar100_fine/test/plain.763.jpg
#   inflating: cifar100_fine/cifar100_fine/test/computer_keyboard.771.jpg
#   inflating: cifar100_fine/cifar100_fine/test/beetle.774.jpg
#   inflating: cifar100_fine/cifar100_fine/test/rose.776.jpg
#   inflating: cifar100_fine/cifar100_fine/test/telephone.800.jpg
#   inflating: cifar100_fine/cifar100_fine/test/cloud.801.jpg
#   inflating: cifar100_fine/cifar100_fine/test/snail.812.jpg
#   inflating: cifar100_fine/cifar100_fine/test/computer_keyboard.839.jpg
#   inflating: cifar100_fine/cifar100_fine/test/orange.848.jpg
#   inflating: cifar100_fine/cifar100_fine/test/orchid.878.jpg
#   inflating: cifar100_fine/cifar100_fine/test/dinosaur.881.jpg
#   inflating: cifar100_fine/cifar100_fine/test/skyscraper.882.jpg
#   inflating: cifar100_fine/cifar100_fine/test/worm.886.jpg
#   inflating: cifar100_fine/cifar100_fine/test/oak_tree.894.jpg
#   inflating: cifar100_fine/cifar100_fine/test/worm.896.jpg
#   inflating: cifar100_fine/cifar100_fine/test/camel.902.jpg
#   inflating: cifar100_fine/cifar100_fine/test/worm.905.jpg
#   inflating: cifar100_fine/cifar100_fine/test/plain.931.jpg
#   inflating: cifar100_fine/cifar100_fine/test/road.933.jpg
#   inflating: cifar100_fine/cifar100_fine/test/lobster.951.jpg
#   inflating: cifar100_fine/cifar100_fine/test/oak_tree.967.jpg
#   inflating: cifar100_fine/cifar100_fine/test/sunflower.976.jpg
#   inflating: cifar100_fine/cifar100_fine/test/lion.981.jpg
#   inflating: cifar100_fine/cifar100_fine/test/snake.983.jpg
#   inflating: cifar100_fine/cifar100_fine/test/raccoon.986.jpg
#   inflating: cifar100_fine/cifar100_fine/test/hamster.996.jpg
#   inflating: cifar100_fine/cifar100_fine/test/seal.1004.jpg
#   inflating: cifar100_fine/cifar100_fine/test/crocodile.1020.jpg
#   inflating: cifar100_fine/cifar100_fine/test/bridge.1025.jpg
#   inflating: cifar100_fine/cifar100_fine/test/bee.1044.jpg
#   inflating: cifar100_fine/cifar100_fine/test/baby.1047.jpg
#   inflating: cifar100_fine/cifar100_fine/test/ray.1053.jpg
#   inflating: cifar100_fine/cifar100_fine/test/streetcar.1056.jpg
#   inflating: cifar100_fine/cifar100_fine/test/kangaroo.1101.jpg
#   inflating: cifar100_fine/cifar100_fine/test/squirrel.1102.jpg
#   inflating: cifar100_fine/cifar100_fine/test/rocket.1129.jpg
#   inflating: cifar100_fine/cifar100_fine/test/rabbit.1140.jpg
#   inflating: cifar100_fine/cifar100_fine/test/rabbit.1146.jpg
#   inflating: cifar100_fine/cifar100_fine/test/mountain.1153.jpg
#   inflating: cifar100_fine/cifar100_fine/test/tractor.1181.jpg
#   inflating: cifar100_fine/cifar100_fine/test/porcupine.1183.jpg
#   inflating: cifar100_fine/cifar100_fine/test/snail.1201.jpg
#   inflating: cifar100_fine/cifar100_fine/test/butterfly.1209.jpg
#   inflating: cifar100_fine/cifar100_fine/test/plain.1213.jpg
#   inflating: cifar100_fine/cifar100_fine/test/bed.1219.jpg
#   inflating: cifar100_fine/cifar100_fine/test/willow_tree.1251.jpg
#   inflating: cifar100_fine/cifar100_fine/test/possum.1262.jpg
#   inflating: cifar100_fine/cifar100_fine/test/orange.1265.jpg
#   inflating: cifar100_fine/cifar100_fine/test/pine_tree.1292.jpg
#   inflating: cifar100_fine/cifar100_fine/test/rose.1317.jpg
#   inflating: cifar100_fine/cifar100_fine/test/bottle.1318.jpg
#   inflating: cifar100_fine/cifar100_fine/test/kangaroo.1336.jpg
#   inflating: cifar100_fine/cifar100_fine/test/plate.1338.jpg
#   inflating: cifar100_fine/cifar100_fine/test/crab.1356.jpg
#   inflating: cifar100_fine/cifar100_fine/test/lion.1374.jpg
#   inflating: cifar100_fine/cifar100_fine/test/lizard.1386.jpg
#   inflating: cifar100_fine/cifar100_fine/test/lion.1397.jpg
#   inflating: cifar100_fine/cifar100_fine/test/fox.1403.jpg
#   inflating: cifar100_fine/cifar100_fine/test/can.1419.jpg
#   inflating: cifar100_fine/cifar100_fine/test/train.1430.jpg
#   inflating: cifar100_fine/cifar100_fine/test/pear.1441.jpg
#   inflating: cifar100_fine/cifar100_fine/test/man.1444.jpg
#   inflating: cifar100_fine/cifar100_fine/test/bowl.1448.jpg
#   inflating: cifar100_fine/cifar100_fine/test/table.1449.jpg
#   inflating: cifar100_fine/cifar100_fine/test/dinosaur.1452.jpg
#   inflating: cifar100_fine/cifar100_fine/test/bridge.1465.jpg
#   inflating: cifar100_fine/cifar100_fine/test/bridge.1474.jpg
#   inflating: cifar100_fine/cifar100_fine/test/bottle.1487.jpg
#   inflating: cifar100_fine/cifar100_fine/test/possum.1502.jpg
#   inflating: cifar100_fine/cifar100_fine/test/house.1503.jpg
#   inflating: cifar100_fine/cifar100_fine/test/tulip.1504.jpg
#   inflating: cifar100_fine/cifar100_fine/test/camel.1510.jpg
#   inflating: cifar100_fine/cifar100_fine/test/bridge.1516.jpg
#   inflating: cifar100_fine/cifar100_fine/test/boy.1541.jpg
#   inflating: cifar100_fine/cifar100_fine/test/rocket.1554.jpg
#   inflating: cifar100_fine/cifar100_fine/test/leopard.1570.jpg
#   inflating: cifar100_fine/cifar100_fine/test/snail.1577.jpg
#   inflating: cifar100_fine/cifar100_fine/test/possum.1584.jpg
#   inflating: cifar100_fine/cifar100_fine/test/crocodile.1603.jpg
#   inflating: cifar100_fine/cifar100_fine/test/can.1628.jpg
#   inflating: cifar100_fine/cifar100_fine/test/spider.1644.jpg
#   inflating: cifar100_fine/cifar100_fine/test/crab.1646.jpg
#   inflating: cifar100_fine/cifar100_fine/test/chair.1652.jpg
#   inflating: cifar100_fine/cifar100_fine/test/couch.1655.jpg
#   inflating: cifar100_fine/cifar100_fine/test/plate.1658.jpg
#   inflating: cifar100_fine/cifar100_fine/test/bus.1662.jpg
#   inflating: cifar100_fine/cifar100_fine/test/motorcycle.1671.jpg
#   inflating: cifar100_fine/cifar100_fine/test/plate.1690.jpg
#   inflating: cifar100_fine/cifar100_fine/test/tank.1694.jpg
#   inflating: cifar100_fine/cifar100_fine/test/seal.1704.jpg
#   inflating: cifar100_fine/cifar100_fine/test/kangaroo.1708.jpg
#   inflating: cifar100_fine/cifar100_fine/test/dolphin.1722.jpg
#   inflating: cifar100_fine/cifar100_fine/test/willow_tree.1724.jpg
#   inflating: cifar100_fine/cifar100_fine/test/crocodile.1728.jpg
#   inflating: cifar100_fine/cifar100_fine/test/television.1733.jpg
#   inflating: cifar100_fine/cifar100_fine/test/pine_tree.1737.jpg
#   inflating: cifar100_fine/cifar100_fine/test/forest.1749.jpg
#   inflating: cifar100_fine/cifar100_fine/test/orchid.1764.jpg
#   inflating: cifar100_fine/cifar100_fine/test/lizard.1772.jpg
#   inflating: cifar100_fine/cifar100_fine/test/willow_tree.1785.jpg
#   inflating: cifar100_fine/cifar100_fine/test/baby.1791.jpg
#   inflating: cifar100_fine/cifar100_fine/test/possum.1796.jpg
#   inflating: cifar100_fine/cifar100_fine/test/train.1797.jpg
#   inflating: cifar100_fine/cifar100_fine/test/fox.1799.jpg
#   inflating: cifar100_fine/cifar100_fine/test/whale.1828.jpg
#   inflating: cifar100_fine/cifar100_fine/test/motorcycle.1829.jpg
#   inflating: cifar100_fine/cifar100_fine/test/wardrobe.1837.jpg
#   inflating: cifar100_fine/cifar100_fine/test/beetle.1861.jpg
#   inflating: cifar100_fine/cifar100_fine/test/hamster.1868.jpg
#   inflating: cifar100_fine/cifar100_fine/test/television.1871.jpg
#   inflating: cifar100_fine/cifar100_fine/test/lizard.1880.jpg
#   inflating: cifar100_fine/cifar100_fine/test/tractor.1881.jpg
#   inflating: cifar100_fine/cifar100_fine/test/house.1886.jpg
#   inflating: cifar100_fine/cifar100_fine/test/plate.1903.jpg
#   inflating: cifar100_fine/cifar100_fine/test/castle.1904.jpg
#   inflating: cifar100_fine/cifar100_fine/test/tiger.1915.jpg
#   inflating: cifar100_fine/cifar100_fine/test/hamster.1918.jpg
#   inflating: cifar100_fine/cifar100_fine/test/bee.1953.jpg
#   inflating: cifar100_fine/cifar100_fine/test/dolphin.1954.jpg
#   inflating: cifar100_fine/cifar100_fine/test/otter.1956.jpg
#   inflating: cifar100_fine/cifar100_fine/test/dolphin.1972.jpg
#   inflating: cifar100_fine/cifar100_fine/test/tractor.1976.jpg
#   inflating: cifar100_fine/cifar100_fine/test/baby.1989.jpg
#   inflating: cifar100_fine/cifar100_fine/test/woman.1991.jpg
#   inflating: cifar100_fine/cifar100_fine/test/girl.2026.jpg
#   inflating: cifar100_fine/cifar100_fine/test/motorcycle.2033.jpg
#   inflating: cifar100_fine/cifar100_fine/test/woman.2034.jpg
#   inflating: cifar100_fine/cifar100_fine/test/caterpillar.2042.jpg
#   inflating: cifar100_fine/cifar100_fine/test/camel.2051.jpg
#   inflating: cifar100_fine/cifar100_fine/test/orange.2058.jpg
#   inflating: cifar100_fine/cifar100_fine/test/motorcycle.2072.jpg
#   inflating: cifar100_fine/cifar100_fine/test/ray.2075.jpg
#   inflating: cifar100_fine/cifar100_fine/test/table.2081.jpg
#   inflating: cifar100_fine/cifar100_fine/test/pear.2088.jpg
#   inflating: cifar100_fine/cifar100_fine/test/ray.2089.jpg
#   inflating: cifar100_fine/cifar100_fine/test/bee.2090.jpg
#   inflating: cifar100_fine/cifar100_fine/test/pickup_truck.2100.jpg
#   inflating: cifar100_fine/cifar100_fine/test/wolf.2102.jpg
#   inflating: cifar100_fine/cifar100_fine/test/bowl.2109.jpg
#   inflating: cifar100_fine/cifar100_fine/test/porcupine.2112.jpg
#   inflating: cifar100_fine/cifar100_fine/test/trout.2113.jpg
#   inflating: cifar100_fine/cifar100_fine/test/crocodile.2128.jpg
#   inflating: cifar100_fine/cifar100_fine/test/wardrobe.2134.jpg
#   inflating: cifar100_fine/cifar100_fine/test/sea.2135.jpg
#   inflating: cifar100_fine/cifar100_fine/test/forest.2139.jpg
#   inflating: cifar100_fine/cifar100_fine/test/bicycle.2147.jpg
#   inflating: cifar100_fine/cifar100_fine/test/motorcycle.2148.jpg
#   inflating: cifar100_fine/cifar100_fine/test/dolphin.2149.jpg
#   inflating: cifar100_fine/cifar100_fine/test/oak_tree.2150.jpg
#   inflating: cifar100_fine/cifar100_fine/test/can.2154.jpg
#   inflating: cifar100_fine/cifar100_fine/test/raccoon.2158.jpg
#   inflating: cifar100_fine/cifar100_fine/test/boy.2170.jpg
#   inflating: cifar100_fine/cifar100_fine/test/tractor.2171.jpg
#   inflating: cifar100_fine/cifar100_fine/test/orchid.2192.jpg
#   inflating: cifar100_fine/cifar100_fine/test/television.2195.jpg
#   inflating: cifar100_fine/cifar100_fine/test/orange.2199.jpg
#   inflating: cifar100_fine/cifar100_fine/test/butterfly.2210.jpg
#   inflating: cifar100_fine/cifar100_fine/test/trout.2218.jpg
#   inflating: cifar100_fine/cifar100_fine/test/table.2227.jpg
#   inflating: cifar100_fine/cifar100_fine/test/dinosaur.2231.jpg
#   inflating: cifar100_fine/cifar100_fine/test/plain.2235.jpg
#   inflating: cifar100_fine/cifar100_fine/test/sea.2247.jpg
#   inflating: cifar100_fine/cifar100_fine/test/castle.2252.jpg
#   inflating: cifar100_fine/cifar100_fine/test/willow_tree.2288.jpg
#   inflating: cifar100_fine/cifar100_fine/test/bowl.2295.jpg
#   inflating: cifar100_fine/cifar100_fine/test/kangaroo.2301.jpg
#   inflating: cifar100_fine/cifar100_fine/test/bowl.2302.jpg
#   inflating: cifar100_fine/cifar100_fine/test/maple_tree.2303.jpg
#   inflating: cifar100_fine/cifar100_fine/test/aquarium_fish.2338.jpg
#   inflating: cifar100_fine/cifar100_fine/test/tulip.2343.jpg
#   inflating: cifar100_fine/cifar100_fine/test/snake.2347.jpg
#   inflating: cifar100_fine/cifar100_fine/test/train.2363.jpg
#   inflating: cifar100_fine/cifar100_fine/test/rose.2371.jpg
#   inflating: cifar100_fine/cifar100_fine/test/plain.2399.jpg
#   inflating: cifar100_fine/cifar100_fine/test/plate.2412.jpg
#   inflating: cifar100_fine/cifar100_fine/test/orange.2414.jpg
#   inflating: cifar100_fine/cifar100_fine/test/mouse.2416.jpg
#   inflating: cifar100_fine/cifar100_fine/test/bridge.2418.jpg
#   inflating: cifar100_fine/cifar100_fine/test/forest.2431.jpg
#   inflating: cifar100_fine/cifar100_fine/test/raccoon.2449.jpg
#   inflating: cifar100_fine/cifar100_fine/test/boy.2451.jpg
#   inflating: cifar100_fine/cifar100_fine/test/wardrobe.2453.jpg
#   inflating: cifar100_fine/cifar100_fine/test/orchid.2459.jpg
#   inflating: cifar100_fine/cifar100_fine/test/chair.2470.jpg
#   inflating: cifar100_fine/cifar100_fine/test/skunk.2476.jpg
#   inflating: cifar100_fine/cifar100_fine/test/forest.2478.jpg
#   inflating: cifar100_fine/cifar100_fine/test/otter.2480.jpg
#   inflating: cifar100_fine/cifar100_fine/test/clock.2487.jpg
#   inflating: cifar100_fine/cifar100_fine/test/apple.2488.jpg
#   inflating: cifar100_fine/cifar100_fine/test/streetcar.2496.jpg
#   inflating: cifar100_fine/cifar100_fine/test/bicycle.2499.jpg
#   inflating: cifar100_fine/cifar100_fine/test/bottle.2510.jpg
#   inflating: cifar100_fine/cifar100_fine/test/can.2511.jpg
#   inflating: cifar100_fine/cifar100_fine/test/orchid.2515.jpg
#   inflating: cifar100_fine/cifar100_fine/test/willow_tree.2531.jpg
#   inflating: cifar100_fine/cifar100_fine/test/lobster.2534.jpg
#   inflating: cifar100_fine/cifar100_fine/test/fox.2544.jpg
#   inflating: cifar100_fine/cifar100_fine/test/sweet_pepper.2547.jpg
#   inflating: cifar100_fine/cifar100_fine/test/lion.2553.jpg
#   inflating: cifar100_fine/cifar100_fine/test/computer_keyboard.2562.jpg
#   inflating: cifar100_fine/cifar100_fine/test/can.2565.jpg
#   inflating: cifar100_fine/cifar100_fine/test/crocodile.2567.jpg
#   inflating: cifar100_fine/cifar100_fine/test/chair.2576.jpg
#   inflating: cifar100_fine/cifar100_fine/test/man.2610.jpg
#   inflating: cifar100_fine/cifar100_fine/test/beaver.2671.jpg
#   inflating: cifar100_fine/cifar100_fine/test/shark.2682.jpg
#   inflating: cifar100_fine/cifar100_fine/test/baby.2685.jpg
#   inflating: cifar100_fine/cifar100_fine/test/cup.2691.jpg
#   inflating: cifar100_fine/cifar100_fine/test/orchid.2694.jpg
#   inflating: cifar100_fine/cifar100_fine/test/train.2724.jpg
#   inflating: cifar100_fine/cifar100_fine/test/whale.2725.jpg
#   inflating: cifar100_fine/cifar100_fine/test/hamster.2739.jpg
#   inflating: cifar100_fine/cifar100_fine/test/road.2749.jpg
#   inflating: cifar100_fine/cifar100_fine/test/lizard.2750.jpg
#   inflating: cifar100_fine/cifar100_fine/test/porcupine.2764.jpg
#   inflating: cifar100_fine/cifar100_fine/test/bed.2765.jpg
#   inflating: cifar100_fine/cifar100_fine/test/pine_tree.2770.jpg
#   inflating: cifar100_fine/cifar100_fine/test/bowl.2797.jpg
#   inflating: cifar100_fine/cifar100_fine/test/clock.2815.jpg
#   inflating: cifar100_fine/cifar100_fine/test/pear.2824.jpg
#   inflating: cifar100_fine/cifar100_fine/test/wolf.2835.jpg
#   inflating: cifar100_fine/cifar100_fine/test/woman.2840.jpg
#   inflating: cifar100_fine/cifar100_fine/test/lizard.2852.jpg
#   inflating: cifar100_fine/cifar100_fine/test/kangaroo.2862.jpg
#   inflating: cifar100_fine/cifar100_fine/test/apple.2865.jpg
#   inflating: cifar100_fine/cifar100_fine/test/table.2867.jpg
#   inflating: cifar100_fine/cifar100_fine/test/lawn_mower.2869.jpg
#   inflating: cifar100_fine/cifar100_fine/test/woman.2870.jpg
#   inflating: cifar100_fine/cifar100_fine/test/boy.2878.jpg
#   inflating: cifar100_fine/cifar100_fine/test/road.2889.jpg
#   inflating: cifar100_fine/cifar100_fine/test/orange.2903.jpg
#   inflating: cifar100_fine/cifar100_fine/test/tiger.2909.jpg
#   inflating: cifar100_fine/cifar100_fine/test/crocodile.2912.jpg
#   inflating: cifar100_fine/cifar100_fine/test/rabbit.2930.jpg
#   inflating: cifar100_fine/cifar100_fine/test/ray.2947.jpg
#   inflating: cifar100_fine/cifar100_fine/test/skunk.2961.jpg
#   inflating: cifar100_fine/cifar100_fine/test/shark.2969.jpg
#   inflating: cifar100_fine/cifar100_fine/test/television.2973.jpg
#   inflating: cifar100_fine/cifar100_fine/test/elephant.2974.jpg
#   inflating: cifar100_fine/cifar100_fine/test/flatfish.2983.jpg
#   inflating: cifar100_fine/cifar100_fine/test/cloud.2999.jpg
#   inflating: cifar100_fine/cifar100_fine/test/lamp.3002.jpg
#   inflating: cifar100_fine/cifar100_fine/test/hamster.3022.jpg
#   inflating: cifar100_fine/cifar100_fine/test/otter.3031.jpg
#   inflating: cifar100_fine/cifar100_fine/test/man.3062.jpg
#   inflating: cifar100_fine/cifar100_fine/test/television.3080.jpg
#   inflating: cifar100_fine/cifar100_fine/test/telephone.3083.jpg
#   inflating: cifar100_fine/cifar100_fine/test/bee.3107.jpg
#   inflating: cifar100_fine/cifar100_fine/test/pear.3123.jpg
#   inflating: cifar100_fine/cifar100_fine/test/ray.3142.jpg
#   inflating: cifar100_fine/cifar100_fine/test/shark.3144.jpg
#   inflating: cifar100_fine/cifar100_fine/test/skyscraper.3146.jpg
#   inflating: cifar100_fine/cifar100_fine/test/kangaroo.3155.jpg
#   inflating: cifar100_fine/cifar100_fine/test/porcupine.3170.jpg
#   inflating: cifar100_fine/cifar100_fine/test/lion.3192.jpg
#   inflating: cifar100_fine/cifar100_fine/test/elephant.3198.jpg
#   inflating: cifar100_fine/cifar100_fine/test/otter.3208.jpg
#   inflating: cifar100_fine/cifar100_fine/test/forest.3220.jpg
#   inflating: cifar100_fine/cifar100_fine/test/train.3223.jpg
#   inflating: cifar100_fine/cifar100_fine/test/sweet_pepper.3233.jpg
#   inflating: cifar100_fine/cifar100_fine/test/can.3238.jpg
#   inflating: cifar100_fine/cifar100_fine/test/raccoon.3259.jpg
#   inflating: cifar100_fine/cifar100_fine/test/flatfish.3268.jpg
#   inflating: cifar100_fine/cifar100_fine/test/dolphin.3272.jpg
#   inflating: cifar100_fine/cifar100_fine/test/worm.3277.jpg
#   inflating: cifar100_fine/cifar100_fine/test/rocket.3279.jpg
#   inflating: cifar100_fine/cifar100_fine/test/mouse.3283.jpg
#   inflating: cifar100_fine/cifar100_fine/test/oak_tree.3301.jpg
#   inflating: cifar100_fine/cifar100_fine/test/poppy.3307.jpg
#   inflating: cifar100_fine/cifar100_fine/test/worm.3312.jpg
#   inflating: cifar100_fine/cifar100_fine/test/television.3320.jpg
#   inflating: cifar100_fine/cifar100_fine/test/tulip.3326.jpg
#   inflating: cifar100_fine/cifar100_fine/test/mushroom.3337.jpg
#   inflating: cifar100_fine/cifar100_fine/test/leopard.3346.jpg
#   inflating: cifar100_fine/cifar100_fine/test/orange.3355.jpg
#   inflating: cifar100_fine/cifar100_fine/test/kangaroo.3362.jpg
#   inflating: cifar100_fine/cifar100_fine/test/skyscraper.3363.jpg
#   inflating: cifar100_fine/cifar100_fine/test/table.3364.jpg
#   inflating: cifar100_fine/cifar100_fine/test/wardrobe.3378.jpg
#   inflating: cifar100_fine/cifar100_fine/test/bee.3384.jpg
#   inflating: cifar100_fine/cifar100_fine/test/cockroach.3385.jpg
#   inflating: cifar100_fine/cifar100_fine/test/crab.3391.jpg
#   inflating: cifar100_fine/cifar100_fine/test/boy.3400.jpg
#   inflating: cifar100_fine/cifar100_fine/test/lizard.3410.jpg
#   inflating: cifar100_fine/cifar100_fine/test/orange.3421.jpg
#   inflating: cifar100_fine/cifar100_fine/test/caterpillar.3437.jpg
#   inflating: cifar100_fine/cifar100_fine/test/otter.3438.jpg
#   inflating: cifar100_fine/cifar100_fine/test/table.3452.jpg
#   inflating: cifar100_fine/cifar100_fine/test/pear.3460.jpg
#   inflating: cifar100_fine/cifar100_fine/test/couch.3463.jpg
#   inflating: cifar100_fine/cifar100_fine/test/cattle.3468.jpg
#   inflating: cifar100_fine/cifar100_fine/test/apple.3510.jpg
#   inflating: cifar100_fine/cifar100_fine/test/beetle.3511.jpg
#   inflating: cifar100_fine/cifar100_fine/test/apple.3518.jpg
#   inflating: cifar100_fine/cifar100_fine/test/chimpanzee.3528.jpg
#   inflating: cifar100_fine/cifar100_fine/test/plain.3541.jpg
#   inflating: cifar100_fine/cifar100_fine/test/crocodile.3552.jpg
#   inflating: cifar100_fine/cifar100_fine/test/butterfly.3562.jpg
#   inflating: cifar100_fine/cifar100_fine/test/worm.3563.jpg
#   inflating: cifar100_fine/cifar100_fine/test/bus.3564.jpg
#   inflating: cifar100_fine/cifar100_fine/test/can.3570.jpg
#   inflating: cifar100_fine/cifar100_fine/test/sweet_pepper.3588.jpg
#   inflating: cifar100_fine/cifar100_fine/test/cattle.3590.jpg
#   inflating: cifar100_fine/cifar100_fine/test/poppy.3601.jpg
#   inflating: cifar100_fine/cifar100_fine/test/orchid.3602.jpg
#   inflating: cifar100_fine/cifar100_fine/test/sea.3612.jpg
#   inflating: cifar100_fine/cifar100_fine/test/whale.3617.jpg
#   inflating: cifar100_fine/cifar100_fine/test/pickup_truck.3630.jpg
#   inflating: cifar100_fine/cifar100_fine/test/telephone.3641.jpg
#   inflating: cifar100_fine/cifar100_fine/test/fox.3644.jpg
#   inflating: cifar100_fine/cifar100_fine/test/lawn_mower.3671.jpg
#   inflating: cifar100_fine/cifar100_fine/test/possum.3673.jpg
#   inflating: cifar100_fine/cifar100_fine/test/orchid.3679.jpg
#   inflating: cifar100_fine/cifar100_fine/test/table.3680.jpg
#   inflating: cifar100_fine/cifar100_fine/test/telephone.3681.jpg
#   inflating: cifar100_fine/cifar100_fine/test/clock.3683.jpg
#   inflating: cifar100_fine/cifar100_fine/test/tulip.3691.jpg
#   inflating: cifar100_fine/cifar100_fine/test/aquarium_fish.3708.jpg
#   inflating: cifar100_fine/cifar100_fine/test/squirrel.3714.jpg
#   inflating: cifar100_fine/cifar100_fine/test/mushroom.3742.jpg
#   inflating: cifar100_fine/cifar100_fine/test/bus.3755.jpg
#   inflating: cifar100_fine/cifar100_fine/test/trout.3762.jpg
#   inflating: cifar100_fine/cifar100_fine/test/bed.3780.jpg
#   inflating: cifar100_fine/cifar100_fine/test/oak_tree.3791.jpg
#   inflating: cifar100_fine/cifar100_fine/test/skyscraper.3797.jpg
#   inflating: cifar100_fine/cifar100_fine/test/chimpanzee.3809.jpg
#   inflating: cifar100_fine/cifar100_fine/test/maple_tree.3811.jpg
#   inflating: cifar100_fine/cifar100_fine/test/willow_tree.3818.jpg
#   inflating: cifar100_fine/cifar100_fine/test/man.3820.jpg
#   inflating: cifar100_fine/cifar100_fine/test/mouse.3824.jpg
#   inflating: cifar100_fine/cifar100_fine/test/pine_tree.3842.jpg
#   inflating: cifar100_fine/cifar100_fine/test/ray.3843.jpg
#   inflating: cifar100_fine/cifar100_fine/test/boy.3869.jpg
#   inflating: cifar100_fine/cifar100_fine/test/wolf.3877.jpg
#   inflating: cifar100_fine/cifar100_fine/test/bridge.3894.jpg
#   inflating: cifar100_fine/cifar100_fine/test/couch.3895.jpg
#   inflating: cifar100_fine/cifar100_fine/test/bottle.3906.jpg
#   inflating: cifar100_fine/cifar100_fine/test/beaver.3916.jpg
#   inflating: cifar100_fine/cifar100_fine/test/bed.3925.jpg
#   inflating: cifar100_fine/cifar100_fine/test/wolf.3927.jpg
#   inflating: cifar100_fine/cifar100_fine/test/castle.3931.jpg
#   inflating: cifar100_fine/cifar100_fine/test/pickup_truck.3933.jpg
#   inflating: cifar100_fine/cifar100_fine/test/porcupine.3945.jpg
#   inflating: cifar100_fine/cifar100_fine/test/lamp.3967.jpg
#   inflating: cifar100_fine/cifar100_fine/test/house.3970.jpg
#   inflating: cifar100_fine/cifar100_fine/test/butterfly.3976.jpg
#   inflating: cifar100_fine/cifar100_fine/test/dinosaur.3987.jpg
#   inflating: cifar100_fine/cifar100_fine/test/skunk.3989.jpg
#   inflating: cifar100_fine/cifar100_fine/test/fox.4004.jpg
#   inflating: cifar100_fine/cifar100_fine/test/snail.4005.jpg
#   inflating: cifar100_fine/cifar100_fine/test/man.4015.jpg
#   inflating: cifar100_fine/cifar100_fine/test/man.4018.jpg
#   inflating: cifar100_fine/cifar100_fine/test/wardrobe.4031.jpg
#   inflating: cifar100_fine/cifar100_fine/test/plate.4037.jpg
#   inflating: cifar100_fine/cifar100_fine/test/television.4053.jpg
#   inflating: cifar100_fine/cifar100_fine/test/lobster.4055.jpg
#   inflating: cifar100_fine/cifar100_fine/test/orchid.4063.jpg
#   inflating: cifar100_fine/cifar100_fine/test/skunk.4064.jpg
#   inflating: cifar100_fine/cifar100_fine/test/butterfly.4070.jpg
#   inflating: cifar100_fine/cifar100_fine/test/pine_tree.4083.jpg
#   inflating: cifar100_fine/cifar100_fine/test/shrew.4108.jpg
#   inflating: cifar100_fine/cifar100_fine/test/tractor.4109.jpg
#   inflating: cifar100_fine/cifar100_fine/test/leopard.4118.jpg
#   inflating: cifar100_fine/cifar100_fine/test/beaver.4126.jpg
#   inflating: cifar100_fine/cifar100_fine/test/bus.4129.jpg
#   inflating: cifar100_fine/cifar100_fine/test/castle.4133.jpg
#   inflating: cifar100_fine/cifar100_fine/test/rose.4139.jpg
#   inflating: cifar100_fine/cifar100_fine/test/forest.4149.jpg
#   inflating: cifar100_fine/cifar100_fine/test/whale.4169.jpg
#   inflating: cifar100_fine/cifar100_fine/test/bus.4173.jpg
#   inflating: cifar100_fine/cifar100_fine/test/chimpanzee.4181.jpg
#   inflating: cifar100_fine/cifar100_fine/test/tiger.4190.jpg
#   inflating: cifar100_fine/cifar100_fine/test/shark.4199.jpg
#   inflating: cifar100_fine/cifar100_fine/test/plate.4204.jpg
#   inflating: cifar100_fine/cifar100_fine/test/bed.4223.jpg
#   inflating: cifar100_fine/cifar100_fine/test/camel.4234.jpg
#   inflating: cifar100_fine/cifar100_fine/test/cockroach.4237.jpg
#   inflating: cifar100_fine/cifar100_fine/test/raccoon.4243.jpg
#   inflating: cifar100_fine/cifar100_fine/test/woman.4247.jpg
#   inflating: cifar100_fine/cifar100_fine/test/spider.4280.jpg
#   inflating: cifar100_fine/cifar100_fine/test/dinosaur.4288.jpg
#   inflating: cifar100_fine/cifar100_fine/test/dinosaur.4300.jpg
#   inflating: cifar100_fine/cifar100_fine/test/palm_tree.4309.jpg
#   inflating: cifar100_fine/cifar100_fine/test/television.4322.jpg
#   inflating: cifar100_fine/cifar100_fine/test/bicycle.4329.jpg
#   inflating: cifar100_fine/cifar100_fine/test/apple.4346.jpg
#   inflating: cifar100_fine/cifar100_fine/test/ray.4356.jpg
#   inflating: cifar100_fine/cifar100_fine/test/palm_tree.4362.jpg
#   inflating: cifar100_fine/cifar100_fine/test/table.4363.jpg
#   inflating: cifar100_fine/cifar100_fine/test/bee.4374.jpg
#   inflating: cifar100_fine/cifar100_fine/test/orchid.4389.jpg
#   inflating: cifar100_fine/cifar100_fine/test/dinosaur.4397.jpg
#   inflating: cifar100_fine/cifar100_fine/test/beetle.4400.jpg
#   inflating: cifar100_fine/cifar100_fine/test/cockroach.4422.jpg
#   inflating: cifar100_fine/cifar100_fine/test/shrew.4430.jpg
#   inflating: cifar100_fine/cifar100_fine/test/telephone.4443.jpg
#   inflating: cifar100_fine/cifar100_fine/test/snail.4452.jpg
#   inflating: cifar100_fine/cifar100_fine/test/television.4456.jpg
#   inflating: cifar100_fine/cifar100_fine/test/mouse.4467.jpg
#   inflating: cifar100_fine/cifar100_fine/test/bee.4482.jpg
#   inflating: cifar100_fine/cifar100_fine/test/spider.4486.jpg
#   inflating: cifar100_fine/cifar100_fine/test/willow_tree.4499.jpg
#   inflating: cifar100_fine/cifar100_fine/test/mouse.4529.jpg
#   inflating: cifar100_fine/cifar100_fine/test/seal.4533.jpg
#   inflating: cifar100_fine/cifar100_fine/test/streetcar.4536.jpg
#   inflating: cifar100_fine/cifar100_fine/test/forest.4541.jpg
#   inflating: cifar100_fine/cifar100_fine/test/man.4551.jpg
#   inflating: cifar100_fine/cifar100_fine/test/baby.4560.jpg
#   inflating: cifar100_fine/cifar100_fine/test/maple_tree.4565.jpg
#   inflating: cifar100_fine/cifar100_fine/test/road.4584.jpg
#   inflating: cifar100_fine/cifar100_fine/test/caterpillar.4590.jpg
#   inflating: cifar100_fine/cifar100_fine/test/cockroach.4591.jpg
#   inflating: cifar100_fine/cifar100_fine/test/snake.4596.jpg
#   inflating: cifar100_fine/cifar100_fine/test/table.4605.jpg
#   inflating: cifar100_fine/cifar100_fine/test/worm.4619.jpg
#   inflating: cifar100_fine/cifar100_fine/test/raccoon.4636.jpg
#   inflating: cifar100_fine/cifar100_fine/test/girl.4654.jpg
#   inflating: cifar100_fine/cifar100_fine/test/clock.4656.jpg
#   inflating: cifar100_fine/cifar100_fine/test/palm_tree.4665.jpg
#   inflating: cifar100_fine/cifar100_fine/test/apple.4666.jpg
#   inflating: cifar100_fine/cifar100_fine/test/computer_keyboard.4670.jpg
#   inflating: cifar100_fine/cifar100_fine/test/beetle.4686.jpg
#   inflating: cifar100_fine/cifar100_fine/test/man.4728.jpg
#   inflating: cifar100_fine/cifar100_fine/test/willow_tree.4737.jpg
#   inflating: cifar100_fine/cifar100_fine/test/whale.4761.jpg
#   inflating: cifar100_fine/cifar100_fine/test/pear.4780.jpg
#   inflating: cifar100_fine/cifar100_fine/test/cockroach.4781.jpg
#   inflating: cifar100_fine/cifar100_fine/test/sunflower.4785.jpg
#   inflating: cifar100_fine/cifar100_fine/test/maple_tree.4795.jpg
#   inflating: cifar100_fine/cifar100_fine/test/elephant.4801.jpg
#   inflating: cifar100_fine/cifar100_fine/test/skyscraper.4822.jpg
#   inflating: cifar100_fine/cifar100_fine/test/man.4836.jpg
#   inflating: cifar100_fine/cifar100_fine/test/computer_keyboard.4838.jpg
#   inflating: cifar100_fine/cifar100_fine/test/butterfly.4843.jpg
#   inflating: cifar100_fine/cifar100_fine/test/can.4855.jpg
#   inflating: cifar100_fine/cifar100_fine/test/skunk.4860.jpg
#   inflating: cifar100_fine/cifar100_fine/test/snake.4861.jpg
#   inflating: cifar100_fine/cifar100_fine/test/cattle.4873.jpg
#   inflating: cifar100_fine/cifar100_fine/test/pine_tree.4874.jpg
#   inflating: cifar100_fine/cifar100_fine/test/castle.4879.jpg
#   inflating: cifar100_fine/cifar100_fine/test/couch.4880.jpg
#   inflating: cifar100_fine/cifar100_fine/test/tank.4883.jpg
#   inflating: cifar100_fine/cifar100_fine/test/bicycle.4888.jpg
#   inflating: cifar100_fine/cifar100_fine/test/road.4916.jpg
#   inflating: cifar100_fine/cifar100_fine/test/pine_tree.4925.jpg
#   inflating: cifar100_fine/cifar100_fine/test/cup.4939.jpg
#   inflating: cifar100_fine/cifar100_fine/test/dolphin.4940.jpg
#   inflating: cifar100_fine/cifar100_fine/test/pear.4948.jpg
#   inflating: cifar100_fine/cifar100_fine/test/worm.4952.jpg
#   inflating: cifar100_fine/cifar100_fine/test/flatfish.4954.jpg
#   inflating: cifar100_fine/cifar100_fine/test/bottle.4956.jpg
#   inflating: cifar100_fine/cifar100_fine/test/butterfly.4966.jpg
#   inflating: cifar100_fine/cifar100_fine/test/elephant.4976.jpg
#   inflating: cifar100_fine/cifar100_fine/test/sunflower.5002.jpg
#   inflating: cifar100_fine/cifar100_fine/test/kangaroo.5012.jpg
#   inflating: cifar100_fine/cifar100_fine/test/leopard.5016.jpg
#   inflating: cifar100_fine/cifar100_fine/test/cloud.5023.jpg
#   inflating: cifar100_fine/cifar100_fine/test/bee.5038.jpg
#   inflating: cifar100_fine/cifar100_fine/test/tiger.5044.jpg
#   inflating: cifar100_fine/cifar100_fine/test/hamster.5058.jpg
#   inflating: cifar100_fine/cifar100_fine/test/bus.5064.jpg
#   inflating: cifar100_fine/cifar100_fine/test/road.5098.jpg
#   inflating: cifar100_fine/cifar100_fine/test/leopard.5109.jpg
#   inflating: cifar100_fine/cifar100_fine/test/motorcycle.5114.jpg
#   inflating: cifar100_fine/cifar100_fine/test/boy.5118.jpg
#   inflating: cifar100_fine/cifar100_fine/test/streetcar.5121.jpg
#   inflating: cifar100_fine/cifar100_fine/test/train.5130.jpg
#   inflating: cifar100_fine/cifar100_fine/test/bee.5148.jpg
#   inflating: cifar100_fine/cifar100_fine/test/plate.5151.jpg
#   inflating: cifar100_fine/cifar100_fine/test/trout.5152.jpg
#   inflating: cifar100_fine/cifar100_fine/test/bus.5163.jpg
#   inflating: cifar100_fine/cifar100_fine/test/chimpanzee.5167.jpg
#   inflating: cifar100_fine/cifar100_fine/test/cockroach.5191.jpg
#   inflating: cifar100_fine/cifar100_fine/test/castle.5205.jpg
#   inflating: cifar100_fine/cifar100_fine/test/shrew.5207.jpg
#   inflating: cifar100_fine/cifar100_fine/test/skunk.5208.jpg
#   inflating: cifar100_fine/cifar100_fine/test/skunk.5217.jpg
#   inflating: cifar100_fine/cifar100_fine/test/bridge.5225.jpg
#   inflating: cifar100_fine/cifar100_fine/test/sea.5232.jpg
#   inflating: cifar100_fine/cifar100_fine/test/sea.5241.jpg
#   inflating: cifar100_fine/cifar100_fine/test/can.5251.jpg
#   inflating: cifar100_fine/cifar100_fine/test/lamp.5259.jpg
#   inflating: cifar100_fine/cifar100_fine/test/maple_tree.5266.jpg
#   inflating: cifar100_fine/cifar100_fine/test/otter.5268.jpg
#   inflating: cifar100_fine/cifar100_fine/test/can.5269.jpg
#   inflating: cifar100_fine/cifar100_fine/test/chimpanzee.5274.jpg
#   inflating: cifar100_fine/cifar100_fine/test/camel.5285.jpg
#   inflating: cifar100_fine/cifar100_fine/test/possum.5299.jpg
#   inflating: cifar100_fine/cifar100_fine/test/pear.5309.jpg
#   inflating: cifar100_fine/cifar100_fine/test/clock.5319.jpg
#   inflating: cifar100_fine/cifar100_fine/test/sweet_pepper.5326.jpg
#   inflating: cifar100_fine/cifar100_fine/test/tiger.5329.jpg
#   inflating: cifar100_fine/cifar100_fine/test/raccoon.5336.jpg
#   inflating: cifar100_fine/cifar100_fine/test/pine_tree.5344.jpg
#   inflating: cifar100_fine/cifar100_fine/test/girl.5345.jpg
#   inflating: cifar100_fine/cifar100_fine/test/motorcycle.5350.jpg
#   inflating: cifar100_fine/cifar100_fine/test/skyscraper.5355.jpg
#   inflating: cifar100_fine/cifar100_fine/test/mouse.5361.jpg
#   inflating: cifar100_fine/cifar100_fine/test/clock.5364.jpg
#   inflating: cifar100_fine/cifar100_fine/test/snake.5369.jpg
#   inflating: cifar100_fine/cifar100_fine/test/mushroom.5375.jpg
#   inflating: cifar100_fine/cifar100_fine/test/plain.5384.jpg
#   inflating: cifar100_fine/cifar100_fine/test/plate.5394.jpg
#   inflating: cifar100_fine/cifar100_fine/test/dinosaur.5395.jpg
#   inflating: cifar100_fine/cifar100_fine/test/tank.5432.jpg
#   inflating: cifar100_fine/cifar100_fine/test/porcupine.5433.jpg
#   inflating: cifar100_fine/cifar100_fine/test/pine_tree.5434.jpg
#   inflating: cifar100_fine/cifar100_fine/test/plain.5439.jpg
#   inflating: cifar100_fine/cifar100_fine/test/turtle.5462.jpg
#   inflating: cifar100_fine/cifar100_fine/test/rose.5520.jpg
#   inflating: cifar100_fine/cifar100_fine/test/woman.5545.jpg
#   inflating: cifar100_fine/cifar100_fine/test/can.5555.jpg
#   inflating: cifar100_fine/cifar100_fine/test/pickup_truck.5568.jpg
#   inflating: cifar100_fine/cifar100_fine/test/kangaroo.5570.jpg
#   inflating: cifar100_fine/cifar100_fine/test/television.5586.jpg
#   inflating: cifar100_fine/cifar100_fine/test/lamp.5608.jpg
#   inflating: cifar100_fine/cifar100_fine/test/forest.5610.jpg
#   inflating: cifar100_fine/cifar100_fine/test/motorcycle.5612.jpg
#   inflating: cifar100_fine/cifar100_fine/test/cup.5617.jpg
#   inflating: cifar100_fine/cifar100_fine/test/road.5630.jpg
#   inflating: cifar100_fine/cifar100_fine/test/streetcar.5631.jpg
#   inflating: cifar100_fine/cifar100_fine/test/house.5635.jpg
#   inflating: cifar100_fine/cifar100_fine/test/cloud.5641.jpg
#   inflating: cifar100_fine/cifar100_fine/test/maple_tree.5645.jpg
#   inflating: cifar100_fine/cifar100_fine/test/bus.5654.jpg
#   inflating: cifar100_fine/cifar100_fine/test/road.5660.jpg
#   inflating: cifar100_fine/cifar100_fine/test/camel.5664.jpg
#   inflating: cifar100_fine/cifar100_fine/test/snail.5665.jpg
#   inflating: cifar100_fine/cifar100_fine/test/house.5682.jpg
#   inflating: cifar100_fine/cifar100_fine/test/clock.5690.jpg
#   inflating: cifar100_fine/cifar100_fine/test/motorcycle.5691.jpg
#   inflating: cifar100_fine/cifar100_fine/test/chair.5699.jpg
#   inflating: cifar100_fine/cifar100_fine/test/palm_tree.5722.jpg
#   inflating: cifar100_fine/cifar100_fine/test/bus.5748.jpg
#   inflating: cifar100_fine/cifar100_fine/test/seal.5771.jpg
#   inflating: cifar100_fine/cifar100_fine/test/forest.5785.jpg
#   inflating: cifar100_fine/cifar100_fine/test/telephone.5786.jpg
#   inflating: cifar100_fine/cifar100_fine/test/lawn_mower.5806.jpg
#   inflating: cifar100_fine/cifar100_fine/test/can.5811.jpg
#   inflating: cifar100_fine/cifar100_fine/test/television.5812.jpg
#   inflating: cifar100_fine/cifar100_fine/test/plain.5816.jpg
#   inflating: cifar100_fine/cifar100_fine/test/cockroach.5835.jpg
#   inflating: cifar100_fine/cifar100_fine/test/cup.5836.jpg
#   inflating: cifar100_fine/cifar100_fine/test/kangaroo.5843.jpg
#   inflating: cifar100_fine/cifar100_fine/test/willow_tree.5850.jpg
#   inflating: cifar100_fine/cifar100_fine/test/bus.5853.jpg
#   inflating: cifar100_fine/cifar100_fine/test/castle.5857.jpg
#   inflating: cifar100_fine/cifar100_fine/test/mouse.5870.jpg
#   inflating: cifar100_fine/cifar100_fine/test/poppy.5931.jpg
#   inflating: cifar100_fine/cifar100_fine/test/tiger.5942.jpg
#   inflating: cifar100_fine/cifar100_fine/test/squirrel.5947.jpg
#   inflating: cifar100_fine/cifar100_fine/test/snake.5955.jpg
#   inflating: cifar100_fine/cifar100_fine/test/snake.5956.jpg
#   inflating: cifar100_fine/cifar100_fine/test/trout.5968.jpg
#   inflating: cifar100_fine/cifar100_fine/test/can.5987.jpg
#   inflating: cifar100_fine/cifar100_fine/test/skyscraper.6013.jpg
#   inflating: cifar100_fine/cifar100_fine/test/poppy.6014.jpg
#   inflating: cifar100_fine/cifar100_fine/test/streetcar.6066.jpg
#   inflating: cifar100_fine/cifar100_fine/test/streetcar.6070.jpg
#   inflating: cifar100_fine/cifar100_fine/test/television.6074.jpg
#   inflating: cifar100_fine/cifar100_fine/test/castle.6083.jpg
#   inflating: cifar100_fine/cifar100_fine/test/boy.6110.jpg
#   inflating: cifar100_fine/cifar100_fine/test/elephant.6119.jpg
#   inflating: cifar100_fine/cifar100_fine/test/table.6120.jpg
#   inflating: cifar100_fine/cifar100_fine/test/chimpanzee.6140.jpg
#   inflating: cifar100_fine/cifar100_fine/test/rabbit.6143.jpg
#   inflating: cifar100_fine/cifar100_fine/test/flatfish.6158.jpg
#   inflating: cifar100_fine/cifar100_fine/test/can.6166.jpg
#   inflating: cifar100_fine/cifar100_fine/test/worm.6198.jpg
#   inflating: cifar100_fine/cifar100_fine/test/tank.6200.jpg
#   inflating: cifar100_fine/cifar100_fine/test/forest.6207.jpg
#   inflating: cifar100_fine/cifar100_fine/test/boy.6241.jpg
#   inflating: cifar100_fine/cifar100_fine/test/otter.6242.jpg
#   inflating: cifar100_fine/cifar100_fine/test/cup.6251.jpg
#   inflating: cifar100_fine/cifar100_fine/test/motorcycle.6279.jpg
#   inflating: cifar100_fine/cifar100_fine/test/man.6291.jpg
#   inflating: cifar100_fine/cifar100_fine/test/possum.6292.jpg
#   inflating: cifar100_fine/cifar100_fine/test/telephone.6299.jpg
#   inflating: cifar100_fine/cifar100_fine/test/pear.6304.jpg
#   inflating: cifar100_fine/cifar100_fine/test/mouse.6321.jpg
#   inflating: cifar100_fine/cifar100_fine/test/tiger.6326.jpg
#   inflating: cifar100_fine/cifar100_fine/test/rocket.6337.jpg
#   inflating: cifar100_fine/cifar100_fine/test/bridge.6352.jpg
#   inflating: cifar100_fine/cifar100_fine/test/shark.6358.jpg
#   inflating: cifar100_fine/cifar100_fine/test/tulip.6366.jpg
#   inflating: cifar100_fine/cifar100_fine/test/crocodile.6377.jpg
#   inflating: cifar100_fine/cifar100_fine/test/tractor.6379.jpg
#   inflating: cifar100_fine/cifar100_fine/test/shrew.6391.jpg
#   inflating: cifar100_fine/cifar100_fine/test/wardrobe.6423.jpg
#   inflating: cifar100_fine/cifar100_fine/test/road.6425.jpg
#   inflating: cifar100_fine/cifar100_fine/test/crocodile.6432.jpg
#   inflating: cifar100_fine/cifar100_fine/test/bottle.6440.jpg
#   inflating: cifar100_fine/cifar100_fine/test/raccoon.6441.jpg
#   inflating: cifar100_fine/cifar100_fine/test/couch.6451.jpg
#   inflating: cifar100_fine/cifar100_fine/test/dinosaur.6495.jpg
#   inflating: cifar100_fine/cifar100_fine/test/crab.6502.jpg
#   inflating: cifar100_fine/cifar100_fine/test/computer_keyboard.6510.jpg
#   inflating: cifar100_fine/cifar100_fine/test/house.6529.jpg
#   inflating: cifar100_fine/cifar100_fine/test/lizard.6535.jpg
#   inflating: cifar100_fine/cifar100_fine/test/plain.6563.jpg
#   inflating: cifar100_fine/cifar100_fine/test/tulip.6587.jpg
#   inflating: cifar100_fine/cifar100_fine/test/sea.6589.jpg
#   inflating: cifar100_fine/cifar100_fine/test/plate.6590.jpg
#   inflating: cifar100_fine/cifar100_fine/test/chair.6594.jpg
#   inflating: cifar100_fine/cifar100_fine/test/elephant.6599.jpg
#   inflating: cifar100_fine/cifar100_fine/test/girl.6611.jpg
#   inflating: cifar100_fine/cifar100_fine/test/camel.6616.jpg
#   inflating: cifar100_fine/cifar100_fine/test/willow_tree.6621.jpg
#   inflating: cifar100_fine/cifar100_fine/test/snail.6625.jpg
#   inflating: cifar100_fine/cifar100_fine/test/squirrel.6631.jpg
#   inflating: cifar100_fine/cifar100_fine/test/sunflower.6647.jpg
#   inflating: cifar100_fine/cifar100_fine/test/chair.6655.jpg
#   inflating: cifar100_fine/cifar100_fine/test/caterpillar.6659.jpg
#   inflating: cifar100_fine/cifar100_fine/test/boy.6672.jpg
#   inflating: cifar100_fine/cifar100_fine/test/bicycle.6713.jpg
#   inflating: cifar100_fine/cifar100_fine/test/crocodile.6715.jpg
#   inflating: cifar100_fine/cifar100_fine/test/cup.6719.jpg
#   inflating: cifar100_fine/cifar100_fine/test/skunk.6723.jpg
#   inflating: cifar100_fine/cifar100_fine/test/beaver.6726.jpg
#   inflating: cifar100_fine/cifar100_fine/test/beaver.6757.jpg
#   inflating: cifar100_fine/cifar100_fine/test/bowl.6772.jpg
#   inflating: cifar100_fine/cifar100_fine/test/wardrobe.6783.jpg
#   inflating: cifar100_fine/cifar100_fine/test/castle.6854.jpg
#   inflating: cifar100_fine/cifar100_fine/test/bridge.6861.jpg
#   inflating: cifar100_fine/cifar100_fine/test/dolphin.6891.jpg
#   inflating: cifar100_fine/cifar100_fine/test/squirrel.6895.jpg
#   inflating: cifar100_fine/cifar100_fine/test/tulip.6896.jpg
#   inflating: cifar100_fine/cifar100_fine/test/ray.6910.jpg
#   inflating: cifar100_fine/cifar100_fine/test/leopard.6924.jpg
#   inflating: cifar100_fine/cifar100_fine/test/sunflower.6928.jpg
#   inflating: cifar100_fine/cifar100_fine/test/cup.6942.jpg
#   inflating: cifar100_fine/cifar100_fine/test/chimpanzee.6946.jpg
#   inflating: cifar100_fine/cifar100_fine/test/skyscraper.6952.jpg
#   inflating: cifar100_fine/cifar100_fine/test/dinosaur.6968.jpg
#   inflating: cifar100_fine/cifar100_fine/test/beetle.6971.jpg
#   inflating: cifar100_fine/cifar100_fine/test/orange.6975.jpg
#   inflating: cifar100_fine/cifar100_fine/test/man.6980.jpg
#   inflating: cifar100_fine/cifar100_fine/test/clock.6981.jpg
#   inflating: cifar100_fine/cifar100_fine/test/skyscraper.6992.jpg
#   inflating: cifar100_fine/cifar100_fine/test/girl.7000.jpg
#   inflating: cifar100_fine/cifar100_fine/test/squirrel.7004.jpg
#   inflating: cifar100_fine/cifar100_fine/test/tractor.7006.jpg
#   inflating: cifar100_fine/cifar100_fine/test/tank.7010.jpg
#   inflating: cifar100_fine/cifar100_fine/test/skunk.7011.jpg
#   inflating: cifar100_fine/cifar100_fine/test/orange.7041.jpg
#   inflating: cifar100_fine/cifar100_fine/test/leopard.7078.jpg
#   inflating: cifar100_fine/cifar100_fine/test/streetcar.7083.jpg
#   inflating: cifar100_fine/cifar100_fine/test/porcupine.7084.jpg
#   inflating: cifar100_fine/cifar100_fine/test/porcupine.7106.jpg
#   inflating: cifar100_fine/cifar100_fine/test/palm_tree.7132.jpg
#   inflating: cifar100_fine/cifar100_fine/test/tractor.7146.jpg
#   inflating: cifar100_fine/cifar100_fine/test/mouse.7150.jpg
#   inflating: cifar100_fine/cifar100_fine/test/skyscraper.7154.jpg
#   inflating: cifar100_fine/cifar100_fine/test/rocket.7167.jpg
#   inflating: cifar100_fine/cifar100_fine/test/seal.7169.jpg
#   inflating: cifar100_fine/cifar100_fine/test/porcupine.7185.jpg
#   inflating: cifar100_fine/cifar100_fine/test/spider.7211.jpg
#   inflating: cifar100_fine/cifar100_fine/test/rabbit.7228.jpg
#   inflating: cifar100_fine/cifar100_fine/test/woman.7236.jpg
#   inflating: cifar100_fine/cifar100_fine/test/dolphin.7241.jpg
#   inflating: cifar100_fine/cifar100_fine/test/chimpanzee.7243.jpg
#   inflating: cifar100_fine/cifar100_fine/test/turtle.7255.jpg
#   inflating: cifar100_fine/cifar100_fine/test/chair.7291.jpg
#   inflating: cifar100_fine/cifar100_fine/test/otter.7294.jpg
#   inflating: cifar100_fine/cifar100_fine/test/whale.7302.jpg
#   inflating: cifar100_fine/cifar100_fine/test/wolf.7308.jpg
#   inflating: cifar100_fine/cifar100_fine/test/snail.7334.jpg
#   inflating: cifar100_fine/cifar100_fine/test/cattle.7357.jpg
#   inflating: cifar100_fine/cifar100_fine/test/dinosaur.7374.jpg
#   inflating: cifar100_fine/cifar100_fine/test/wolf.7375.jpg
#   inflating: cifar100_fine/cifar100_fine/test/maple_tree.7384.jpg
#   inflating: cifar100_fine/cifar100_fine/test/tank.7391.jpg
#   inflating: cifar100_fine/cifar100_fine/test/crocodile.7404.jpg
#   inflating: cifar100_fine/cifar100_fine/test/leopard.7412.jpg
#   inflating: cifar100_fine/cifar100_fine/test/bottle.7415.jpg
#   inflating: cifar100_fine/cifar100_fine/test/telephone.7439.jpg
#   inflating: cifar100_fine/cifar100_fine/test/camel.7445.jpg
#   inflating: cifar100_fine/cifar100_fine/test/hamster.7454.jpg
#   inflating: cifar100_fine/cifar100_fine/test/forest.7478.jpg
#   inflating: cifar100_fine/cifar100_fine/test/chimpanzee.7490.jpg
#   inflating: cifar100_fine/cifar100_fine/test/forest.7496.jpg
# ...
#   inflating: cifar100_fine/cifar100_fine/test/tulip.7556.jpg
#   inflating: cifar100_fine/cifar100_fine/test/cloud.7565.jpg
#   inflating: cifar100_fine/cifar100_fine/test/otter.7574.jpg
#   inflating: cifar100_fine/cifar100_fine/test/flatfish.7576.jpg
#   inflating: cifar100_fine/cifar100_fine/test/woman.7578.jpg
#   inflating: cifar100_fine/cifar100_fine/test/bridge.7583.jpg
#   inflating: cifar100_fine/cifar100_fine/test/tank.7595.jpg
#   inflating: cifar100_fine/cifar100_fine/test/kangaroo.7613.jpg
#   inflating: cifar100_fine/cifar100_fine/test/beaver.7614.jpg
#   inflating: cifar100_fine/cifar100_fine/test/shrew.7620.jpg
#   inflating: cifar100_fine/cifar100_fine/test/fox.7621.jpg
#   inflating: cifar100_fine/cifar100_fine/test/dolphin.7624.jpg
#   inflating: cifar100_fine/cifar100_fine/test/shrew.7625.jpg
#   inflating: cifar100_fine/cifar100_fine/test/wolf.7650.jpg
#   inflating: cifar100_fine/cifar100_fine/test/cattle.7659.jpg
#   inflating: cifar100_fine/cifar100_fine/test/bed.7690.jpg
#   inflating: cifar100_fine/cifar100_fine/test/elephant.7701.jpg
#   inflating: cifar100_fine/cifar100_fine/test/table.7706.jpg
#   inflating: cifar100_fine/cifar100_fine/test/man.7707.jpg
#   inflating: cifar100_fine/cifar100_fine/test/tractor.7736.jpg
#   inflating: cifar100_fine/cifar100_fine/test/rose.7744.jpg
#   inflating: cifar100_fine/cifar100_fine/test/sweet_pepper.7754.jpg
#   inflating: cifar100_fine/cifar100_fine/test/fox.7799.jpg
#   inflating: cifar100_fine/cifar100_fine/test/snail.7810.jpg
#   inflating: cifar100_fine/cifar100_fine/test/tulip.7814.jpg
#   inflating: cifar100_fine/cifar100_fine/test/skunk.7822.jpg
#   inflating: cifar100_fine/cifar100_fine/test/dolphin.7836.jpg
#   inflating: cifar100_fine/cifar100_fine/test/plain.7844.jpg
#   inflating: cifar100_fine/cifar100_fine/test/flatfish.7874.jpg
#   inflating: cifar100_fine/cifar100_fine/test/crocodile.7881.jpg
#   inflating: cifar100_fine/cifar100_fine/test/butterfly.7911.jpg
#   inflating: cifar100_fine/cifar100_fine/test/clock.7933.jpg
#   inflating: cifar100_fine/cifar100_fine/test/table.7945.jpg
#   inflating: cifar100_fine/cifar100_fine/test/dinosaur.7952.jpg
#   inflating: cifar100_fine/cifar100_fine/test/beaver.7958.jpg
#   inflating: cifar100_fine/cifar100_fine/test/clock.7959.jpg
#   inflating: cifar100_fine/cifar100_fine/test/table.7965.jpg
#   inflating: cifar100_fine/cifar100_fine/test/leopard.7974.jpg
#   inflating: cifar100_fine/cifar100_fine/test/wolf.7980.jpg
#   inflating: cifar100_fine/cifar100_fine/test/dinosaur.8017.jpg
#   inflating: cifar100_fine/cifar100_fine/test/palm_tree.8018.jpg
#   inflating: cifar100_fine/cifar100_fine/test/apple.8045.jpg
#   inflating: cifar100_fine/cifar100_fine/test/bed.8071.jpg
#   inflating: cifar100_fine/cifar100_fine/test/clock.8074.jpg
#   inflating: cifar100_fine/cifar100_fine/test/otter.8081.jpg
#   inflating: cifar100_fine/cifar100_fine/test/pine_tree.8094.jpg
#   inflating: cifar100_fine/cifar100_fine/test/pine_tree.8097.jpg
#   inflating: cifar100_fine/cifar100_fine/test/mountain.8103.jpg
#   inflating: cifar100_fine/cifar100_fine/test/apple.8131.jpg
#   inflating: cifar100_fine/cifar100_fine/test/caterpillar.8133.jpg
#   inflating: cifar100_fine/cifar100_fine/test/telephone.8139.jpg
#   inflating: cifar100_fine/cifar100_fine/test/lawn_mower.8148.jpg
#   inflating: cifar100_fine/cifar100_fine/test/ray.8167.jpg
#   inflating: cifar100_fine/cifar100_fine/test/plate.8195.jpg
#   inflating: cifar100_fine/cifar100_fine/test/seal.8206.jpg
#   inflating: cifar100_fine/cifar100_fine/test/otter.8210.jpg
#   inflating: cifar100_fine/cifar100_fine/test/apple.8211.jpg
#   inflating: cifar100_fine/cifar100_fine/test/shrew.8216.jpg
#   inflating: cifar100_fine/cifar100_fine/test/butterfly.8223.jpg
#   inflating: cifar100_fine/cifar100_fine/test/maple_tree.8226.jpg
#   inflating: cifar100_fine/cifar100_fine/test/lawn_mower.8232.jpg
#   inflating: cifar100_fine/cifar100_fine/test/kangaroo.8247.jpg
#   inflating: cifar100_fine/cifar100_fine/test/dinosaur.8254.jpg
#   inflating: cifar100_fine/cifar100_fine/test/motorcycle.8257.jpg
#   inflating: cifar100_fine/cifar100_fine/test/elephant.8263.jpg
#   inflating: cifar100_fine/cifar100_fine/test/otter.8265.jpg
#   inflating: cifar100_fine/cifar100_fine/test/streetcar.8277.jpg
#   inflating: cifar100_fine/cifar100_fine/test/spider.8280.jpg
#   inflating: cifar100_fine/cifar100_fine/test/bridge.8292.jpg
#   inflating: cifar100_fine/cifar100_fine/test/leopard.8310.jpg
#   inflating: cifar100_fine/cifar100_fine/test/leopard.8324.jpg
#   inflating: cifar100_fine/cifar100_fine/test/woman.8337.jpg
#   inflating: cifar100_fine/cifar100_fine/test/can.8340.jpg
#   inflating: cifar100_fine/cifar100_fine/test/aquarium_fish.8352.jpg
#   inflating: cifar100_fine/cifar100_fine/test/willow_tree.8354.jpg
#   inflating: cifar100_fine/cifar100_fine/test/baby.8358.jpg
#   inflating: cifar100_fine/cifar100_fine/test/lawn_mower.8371.jpg
#   inflating: cifar100_fine/cifar100_fine/test/cattle.8383.jpg
#   inflating: cifar100_fine/cifar100_fine/test/television.8386.jpg
#   inflating: cifar100_fine/cifar100_fine/test/television.8393.jpg
#   inflating: cifar100_fine/cifar100_fine/test/bee.8399.jpg
#   inflating: cifar100_fine/cifar100_fine/test/bicycle.8402.jpg
#   inflating: cifar100_fine/cifar100_fine/test/television.8411.jpg
#   inflating: cifar100_fine/cifar100_fine/test/mountain.8412.jpg
#   inflating: cifar100_fine/cifar100_fine/test/bicycle.8419.jpg
#   inflating: cifar100_fine/cifar100_fine/test/skunk.8420.jpg
#   inflating: cifar100_fine/cifar100_fine/test/raccoon.8438.jpg
#   inflating: cifar100_fine/cifar100_fine/test/motorcycle.8457.jpg
#   inflating: cifar100_fine/cifar100_fine/test/rocket.8461.jpg
#   inflating: cifar100_fine/cifar100_fine/test/couch.8464.jpg
#   inflating: cifar100_fine/cifar100_fine/test/turtle.8474.jpg
#   inflating: cifar100_fine/cifar100_fine/test/road.8482.jpg
#   inflating: cifar100_fine/cifar100_fine/test/hamster.8494.jpg
#   inflating: cifar100_fine/cifar100_fine/test/man.8499.jpg
#   inflating: cifar100_fine/cifar100_fine/test/whale.8512.jpg
#   inflating: cifar100_fine/cifar100_fine/test/computer_keyboard.8521.jpg
#   inflating: cifar100_fine/cifar100_fine/test/palm_tree.8522.jpg
#   inflating: cifar100_fine/cifar100_fine/test/otter.8540.jpg
#   inflating: cifar100_fine/cifar100_fine/test/aquarium_fish.8550.jpg
#   inflating: cifar100_fine/cifar100_fine/test/bed.8554.jpg
#   inflating: cifar100_fine/cifar100_fine/test/television.8565.jpg
#   inflating: cifar100_fine/cifar100_fine/test/trout.8584.jpg
#   inflating: cifar100_fine/cifar100_fine/test/boy.8591.jpg
#   inflating: cifar100_fine/cifar100_fine/test/rose.8614.jpg
#   inflating: cifar100_fine/cifar100_fine/test/shrew.8622.jpg
#   inflating: cifar100_fine/cifar100_fine/test/plate.8637.jpg
#   inflating: cifar100_fine/cifar100_fine/test/aquarium_fish.8649.jpg
#   inflating: cifar100_fine/cifar100_fine/test/road.8659.jpg
#   inflating: cifar100_fine/cifar100_fine/test/turtle.8669.jpg
#   inflating: cifar100_fine/cifar100_fine/test/maple_tree.8683.jpg
#   inflating: cifar100_fine/cifar100_fine/test/sweet_pepper.8699.jpg
#   inflating: cifar100_fine/cifar100_fine/test/snake.8714.jpg
#   inflating: cifar100_fine/cifar100_fine/test/crocodile.8750.jpg
#   inflating: cifar100_fine/cifar100_fine/test/wardrobe.8757.jpg
#   inflating: cifar100_fine/cifar100_fine/test/trout.8761.jpg
#   inflating: cifar100_fine/cifar100_fine/test/fox.8762.jpg
#   inflating: cifar100_fine/cifar100_fine/test/pine_tree.8794.jpg
#   inflating: cifar100_fine/cifar100_fine/test/aquarium_fish.8802.jpg
#   inflating: cifar100_fine/cifar100_fine/test/worm.8845.jpg
#   inflating: cifar100_fine/cifar100_fine/test/telephone.8851.jpg
#   inflating: cifar100_fine/cifar100_fine/test/possum.8852.jpg
#   inflating: cifar100_fine/cifar100_fine/test/wardrobe.8868.jpg
#   inflating: cifar100_fine/cifar100_fine/test/whale.8869.jpg
#   inflating: cifar100_fine/cifar100_fine/test/willow_tree.8871.jpg
#   inflating: cifar100_fine/cifar100_fine/test/ray.8874.jpg
#   inflating: cifar100_fine/cifar100_fine/test/shrew.8878.jpg
#   inflating: cifar100_fine/cifar100_fine/test/porcupine.8879.jpg
#   inflating: cifar100_fine/cifar100_fine/test/bridge.8883.jpg
#   inflating: cifar100_fine/cifar100_fine/test/maple_tree.8885.jpg
#   inflating: cifar100_fine/cifar100_fine/test/crocodile.8890.jpg
#   inflating: cifar100_fine/cifar100_fine/test/flatfish.8893.jpg
#   inflating: cifar100_fine/cifar100_fine/test/orange.8925.jpg
#   inflating: cifar100_fine/cifar100_fine/test/raccoon.8927.jpg
#   inflating: cifar100_fine/cifar100_fine/test/wardrobe.8930.jpg
#   inflating: cifar100_fine/cifar100_fine/test/rocket.8932.jpg
#   inflating: cifar100_fine/cifar100_fine/test/beaver.8940.jpg
#   inflating: cifar100_fine/cifar100_fine/test/clock.8949.jpg
#   inflating: cifar100_fine/cifar100_fine/test/maple_tree.8951.jpg
#   inflating: cifar100_fine/cifar100_fine/test/pickup_truck.8953.jpg
#   inflating: cifar100_fine/cifar100_fine/test/wolf.8960.jpg
#   inflating: cifar100_fine/cifar100_fine/test/dinosaur.8965.jpg
#   inflating: cifar100_fine/cifar100_fine/test/lizard.8967.jpg
#   inflating: cifar100_fine/cifar100_fine/test/mouse.8973.jpg
#   inflating: cifar100_fine/cifar100_fine/test/orange.8980.jpg
#   inflating: cifar100_fine/cifar100_fine/test/streetcar.8988.jpg
#   inflating: cifar100_fine/cifar100_fine/test/tiger.9002.jpg
#   inflating: cifar100_fine/cifar100_fine/test/bus.9027.jpg
#   inflating: cifar100_fine/cifar100_fine/test/pine_tree.9035.jpg
#   inflating: cifar100_fine/cifar100_fine/test/lawn_mower.9038.jpg
#   inflating: cifar100_fine/cifar100_fine/test/road.9043.jpg
#   inflating: cifar100_fine/cifar100_fine/test/lamp.9048.jpg
#   inflating: cifar100_fine/cifar100_fine/test/plain.9057.jpg
#   inflating: cifar100_fine/cifar100_fine/test/wardrobe.9059.jpg
#   inflating: cifar100_fine/cifar100_fine/test/seal.9061.jpg
#   inflating: cifar100_fine/cifar100_fine/test/couch.9063.jpg
#   inflating: cifar100_fine/cifar100_fine/test/lion.9109.jpg
#   inflating: cifar100_fine/cifar100_fine/test/otter.9111.jpg
#   inflating: cifar100_fine/cifar100_fine/test/beaver.9118.jpg
#   inflating: cifar100_fine/cifar100_fine/test/computer_keyboard.9122.jpg
#   inflating: cifar100_fine/cifar100_fine/test/bottle.9126.jpg
#   inflating: cifar100_fine/cifar100_fine/test/cattle.9144.jpg
#   inflating: cifar100_fine/cifar100_fine/test/wardrobe.9149.jpg
#   inflating: cifar100_fine/cifar100_fine/test/butterfly.9163.jpg
#   inflating: cifar100_fine/cifar100_fine/test/chimpanzee.9170.jpg
#   inflating: cifar100_fine/cifar100_fine/test/bridge.9175.jpg
#   inflating: cifar100_fine/cifar100_fine/test/bowl.9177.jpg
#   inflating: cifar100_fine/cifar100_fine/test/lawn_mower.9181.jpg
#   inflating: cifar100_fine/cifar100_fine/test/couch.9184.jpg
#   inflating: cifar100_fine/cifar100_fine/test/caterpillar.9192.jpg
#   inflating: cifar100_fine/cifar100_fine/test/trout.9202.jpg
#   inflating: cifar100_fine/cifar100_fine/test/tractor.9203.jpg
#   inflating: cifar100_fine/cifar100_fine/test/lobster.9206.jpg
#   inflating: cifar100_fine/cifar100_fine/test/tulip.9254.jpg
#   inflating: cifar100_fine/cifar100_fine/test/rocket.9255.jpg
#   inflating: cifar100_fine/cifar100_fine/test/cattle.9290.jpg
#   inflating: cifar100_fine/cifar100_fine/test/hamster.9291.jpg
#   inflating: cifar100_fine/cifar100_fine/test/table.9304.jpg
#   inflating: cifar100_fine/cifar100_fine/test/lamp.9316.jpg
#   inflating: cifar100_fine/cifar100_fine/test/willow_tree.9319.jpg
#   inflating: cifar100_fine/cifar100_fine/test/palm_tree.9340.jpg
#   inflating: cifar100_fine/cifar100_fine/test/hamster.9352.jpg
#   inflating: cifar100_fine/cifar100_fine/test/girl.9364.jpg
#   inflating: cifar100_fine/cifar100_fine/test/lizard.9370.jpg
#   inflating: cifar100_fine/cifar100_fine/test/rabbit.9382.jpg
#   inflating: cifar100_fine/cifar100_fine/test/whale.9383.jpg
#   inflating: cifar100_fine/cifar100_fine/test/streetcar.9386.jpg
#   inflating: cifar100_fine/cifar100_fine/test/pine_tree.9392.jpg
#   inflating: cifar100_fine/cifar100_fine/test/computer_keyboard.9421.jpg
#   inflating: cifar100_fine/cifar100_fine/test/worm.9423.jpg
#   inflating: cifar100_fine/cifar100_fine/test/rocket.9428.jpg
#   inflating: cifar100_fine/cifar100_fine/test/orchid.9430.jpg
#   inflating: cifar100_fine/cifar100_fine/test/possum.9440.jpg
#   inflating: cifar100_fine/cifar100_fine/test/orange.9449.jpg
#   inflating: cifar100_fine/cifar100_fine/test/maple_tree.9451.jpg
#   inflating: cifar100_fine/cifar100_fine/test/streetcar.9454.jpg
#   inflating: cifar100_fine/cifar100_fine/test/porcupine.9466.jpg
#   inflating: cifar100_fine/cifar100_fine/test/sweet_pepper.9493.jpg
#   inflating: cifar100_fine/cifar100_fine/test/cup.9501.jpg
#   inflating: cifar100_fine/cifar100_fine/test/castle.9522.jpg
#   inflating: cifar100_fine/cifar100_fine/test/camel.9531.jpg
#   inflating: cifar100_fine/cifar100_fine/test/telephone.9547.jpg
#   inflating: cifar100_fine/cifar100_fine/test/cup.9550.jpg
#   inflating: cifar100_fine/cifar100_fine/test/bicycle.9556.jpg
#   inflating: cifar100_fine/cifar100_fine/test/clock.9558.jpg
#   inflating: cifar100_fine/cifar100_fine/test/television.9560.jpg
#   inflating: cifar100_fine/cifar100_fine/test/girl.9579.jpg
#   inflating: cifar100_fine/cifar100_fine/test/chair.9600.jpg
#   inflating: cifar100_fine/cifar100_fine/test/lizard.9607.jpg
#   inflating: cifar100_fine/cifar100_fine/test/couch.9608.jpg
#   inflating: cifar100_fine/cifar100_fine/test/baby.9625.jpg
#   inflating: cifar100_fine/cifar100_fine/test/squirrel.9649.jpg
#   inflating: cifar100_fine/cifar100_fine/test/beetle.9652.jpg
#   inflating: cifar100_fine/cifar100_fine/test/lion.9660.jpg
#   inflating: cifar100_fine/cifar100_fine/test/pickup_truck.9676.jpg
#   inflating: cifar100_fine/cifar100_fine/test/oak_tree.9688.jpg
#   inflating: cifar100_fine/cifar100_fine/test/bicycle.9692.jpg
#   inflating: cifar100_fine/cifar100_fine/test/beaver.9707.jpg
#   inflating: cifar100_fine/cifar100_fine/test/trout.9712.jpg
#   inflating: cifar100_fine/cifar100_fine/test/whale.9722.jpg
#   inflating: cifar100_fine/cifar100_fine/test/woman.9733.jpg
#   inflating: cifar100_fine/cifar100_fine/test/computer_keyboard.9736.jpg
#   inflating: cifar100_fine/cifar100_fine/test/squirrel.9748.jpg
#   inflating: cifar100_fine/cifar100_fine/test/kangaroo.9758.jpg
#   inflating: cifar100_fine/cifar100_fine/test/cockroach.9760.jpg
#   inflating: cifar100_fine/cifar100_fine/test/rabbit.9762.jpg
#   inflating: cifar100_fine/cifar100_fine/test/spider.9779.jpg
#   inflating: cifar100_fine/cifar100_fine/test/lamp.9791.jpg
#   inflating: cifar100_fine/cifar100_fine/test/bowl.9795.jpg
#   inflating: cifar100_fine/cifar100_fine/test/crocodile.9846.jpg
#   inflating: cifar100_fine/cifar100_fine/test/mushroom.9847.jpg
#   inflating: cifar100_fine/cifar100_fine/test/trout.9848.jpg
#   inflating: cifar100_fine/cifar100_fine/test/apple.9849.jpg
#   inflating: cifar100_fine/cifar100_fine/test/plain.9854.jpg
#   inflating: cifar100_fine/cifar100_fine/test/telephone.9856.jpg
#   inflating: cifar100_fine/cifar100_fine/test/shark.9879.jpg
#   inflating: cifar100_fine/cifar100_fine/test/rose.9884.jpg
#   inflating: cifar100_fine/cifar100_fine/test/telephone.9892.jpg
#   inflating: cifar100_fine/cifar100_fine/test/mouse.9893.jpg
#   inflating: cifar100_fine/cifar100_fine/test/elephant.9895.jpg
#   inflating: cifar100_fine/cifar100_fine/test/hamster.9899.jpg
#   inflating: cifar100_fine/cifar100_fine/test/elephant.9909.jpg
#   inflating: cifar100_fine/cifar100_fine/test/worm.9935.jpg
#   inflating: cifar100_fine/cifar100_fine/test/snake.9941.jpg
#   inflating: cifar100_fine/cifar100_fine/test/rocket.9946.jpg
#   inflating: cifar100_fine/cifar100_fine/test/whale.9954.jpg
#   inflating: cifar100_fine/cifar100_fine/test/willow_tree.9984.jpg

# %%
ITERATION = 1
IMAGE_WIDTH=256
IMAGE_HEIGHT=256
IMAGE_SIZE=(IMAGE_WIDTH, IMAGE_HEIGHT)
IMAGE_CHANNELS=3
RANDOM_SEED = [42, 42, 57, 48, 86, 7, 15, 28, 39, 52][ITERATION-1]
BATCH_SIZE = 32
NUM_CLASSES = 100
EPOCHS = 1000
GABOR_LAYER_INDEX = 0
GABOR_WIDTH = 15
GABOR_HEIGHT = 15
GABOR_SIZE = (GABOR_WIDTH, GABOR_HEIGHT)
NUM_RECEPTIVE_FILTERS = 32
CLASSES = ['airplane', 'automobile', 'bird', 'cat', 'deer',
           'dog', 'frog', 'horse', 'ship', 'truck']
# TRAIN_DIR = "cifar100_fine/cifar100_fine/train/"
# TEST_DIR = "cifar100_fine/cifar100_fine/test/"
TEST_DIR = "cifar100_fine/cifar100_fine/train/"
TRAIN_DIR = "cifar100_fine/cifar100_fine/test/"

# %%
filenames = os.listdir(TRAIN_DIR)
categories = []
for filename in filenames:
    category = filename.split('.')[0]
    categories.append(category)

train_df = pd.DataFrame({
    'filename': filenames,
    'category': categories
})

filenames = os.listdir(TEST_DIR)
categories = []
for filename in filenames:
    category = filename.split('.')[0]
    categories.append(category)

validate_df = pd.DataFrame({
    'filename': filenames,
    'category': categories
})

# %%
train_df = train_df.reset_index(drop=True)
validate_df = validate_df.reset_index(drop=True)
total_train = train_df.shape[0]
total_validate = validate_df.shape[0]

# %%
train_df['category'].value_counts().plot.bar()

# %%
validate_df['category'].value_counts().plot.bar()

# %%
train_datagen = ImageDataGenerator(
    rescale=1./255,
)
train_generator = train_datagen.flow_from_dataframe(
    train_df, 
    TRAIN_DIR, 
    x_col='filename',
    y_col='category',
    target_size=IMAGE_SIZE,
    class_mode='categorical',
    batch_size=BATCH_SIZE
)
# Out:
# Found 10000 validated image filenames belonging to 100 classes.

# %%
validation_datagen = ImageDataGenerator(rescale=1./255)
validation_generator = validation_datagen.flow_from_dataframe(
    validate_df, 
    TEST_DIR, 
    x_col='filename',
    y_col='category',
    target_size=IMAGE_SIZE,
    class_mode='categorical',
    batch_size=BATCH_SIZE
)
# Out:
# Found 50000 validated image filenames belonging to 100 classes.

# %%
# Importing the Keras libraries and packages
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Activation
from tensorflow.keras.layers import Input, Dense, Dropout, BatchNormalization
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import RMSprop, Adam
from tensorflow.keras.models import Sequential
from tensorflow.keras import layers
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau

classifier = None
classifier = Sequential([
    layers.Conv2D(NUM_RECEPTIVE_FILTERS, kernel_size=GABOR_SIZE, strides=(1,1), activation='relu', input_shape=(IMAGE_WIDTH, IMAGE_HEIGHT, 3)),
    layers.BatchNormalization(),
    layers.MaxPooling2D(pool_size=(2,2)),
    Dropout(0.5),
    layers.Conv2D(64, kernel_size=(3,3), strides=(2,2), activation='relu'),
    layers.BatchNormalization(),
    layers.MaxPooling2D(pool_size=(2,2)),
    Dropout(0.5),
    layers.Conv2D(128, kernel_size=(3,3), strides=(2,2), activation='relu'),
    layers.BatchNormalization(),
    layers.MaxPooling2D(pool_size=(2,2)),
    Dropout(0.5),
    layers.Flatten(),
    layers.Dense(512, activation='relu'),
    layers.BatchNormalization(),
    Dropout(0.5),
    layers.Dense(NUM_CLASSES, activation='softmax')
])

classifier.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 242, 242, 32)      21632
# _________________________________________________________________
# batch_normalization (BatchNo (None, 242, 242, 32)      128
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 121, 121, 32)      0
# _________________________________________________________________
# dropout (Dropout)            (None, 121, 121, 32)      0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 60, 60, 64)        18496
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 60, 60, 64)        256
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 30, 30, 64)        0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 30, 30, 64)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 14, 14, 128)       73856
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 14, 14, 128)       512
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 7, 7, 128)         0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 7, 7, 128)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 6272)              0
# _________________________________________________________________
# dense (Dense)                (None, 512)               3211776
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 512)               2048
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 100)               51300
# =================================================================
# Total params: 3,380,004
# Trainable params: 3,378,532
# Non-trainable params: 1,472
# _________________________________________________________________

# %%
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=10,  
                              min_delta=1e-4, mode='min', verbose=1)
stop_alg = EarlyStopping(monitor='val_loss', patience=35, 
                         restore_best_weights=True, verbose=1)
callbacks = [stop_alg, reduce_lr]
opt = RMSprop(learning_rate=0.001)
classifier.compile(loss='categorical_crossentropy', optimizer=opt, metrics=['accuracy'])

start = time.perf_counter()
hist = classifier.fit(
    train_generator, 
    epochs=EPOCHS,
    validation_data=validation_generator,
    validation_steps=total_validate//BATCH_SIZE,
    steps_per_epoch=total_train//BATCH_SIZE,
    callbacks=callbacks
)
finish = time.perf_counter()
# Out:
# Epoch 1/1000
#  14/312 [>.............................] - ETA: 48:45 - loss: 6.1587 - accuracy: 0.0014

# %%
print("Start time = {}".format(start))
print("Finish time = {}".format(finish))
print("Training time = {}".format(finish-start))
hist.history['start_time'] = start
hist.history['finish_time'] = finish
hist.history['train_time'] = finish-start

# %%
import pickle

with open('cifar100_fine-{}-history-kernel-{}.p'.format(ITERATION, GABOR_HEIGHT), 'wb') as fp:
  pickle.dump(hist.history, fp, protocol=pickle.HIGHEST_PROTOCOL)

# %%
import matplotlib.pyplot as plt

fig = plt.figure(figsize=(10,6))
plt.plot(hist.history['loss'], color='#785ef0')
plt.plot(hist.history['val_loss'], color='#dc267f')
plt.title('Model Loss Progress')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Training Set', 'Test Set'], loc='upper right')
plt.savefig('cifar100_fine-{}-loss-kernel-{}.png'.format(ITERATION, GABOR_WIDTH), dpi=350, bbox_inches='tight')
plt.show()

# %%
fig = plt.figure(figsize=(10,6))
plt.plot(hist.history['accuracy'], color='#785ef0')
plt.plot(hist.history['val_accuracy'], color='#dc267f')
plt.title('Model Accuracy Progress')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Training Set', 'Test Set'], loc='upper right')
plt.savefig('cifar100_fine-{}-accuracy-kernel-{}.png'.format(ITERATION, GABOR_WIDTH), dpi=350, bbox_inches='tight')
plt.show()

# %%
from sklearn.preprocessing import MinMaxScaler

cnnl1 = classifier.layers[GABOR_LAYER_INDEX].name   # get the name of the first conv layer
W = classifier.get_layer(name=cnnl1).get_weights()[0]   #get the filters
wshape = W.shape  #save the original shape

# this part will scale to [0, 1] for visualization purposes
scaler = MinMaxScaler()
scaler.fit(W.reshape(-1,1))
W = scaler.transform(W.reshape(-1,1))
W = W.reshape(wshape)

fig, axs = plt.subplots(8,NUM_RECEPTIVE_FILTERS//8, figsize=(24,24))
fig.subplots_adjust(hspace = .25, wspace=.001)
axs = axs.ravel()
for i in range(W.shape[-1]):
  # we reshape to a 3D (RGB) image shape and display
  h = np.reshape(W[:,:,:,i], (GABOR_WIDTH,GABOR_HEIGHT,3))
  axs[i].imshow(h)
  axs[i].set_title('Filter ' + str(i))    
plt.savefig("cifar100_fine-{}-filters-kernel-{}.png".format(ITERATION, GABOR_WIDTH), bbox_inches='tight', dpi=350)

# %%
cnnl1 = classifier.layers[GABOR_LAYER_INDEX].name   # get the name of the first conv layer
W = classifier.get_layer(name=cnnl1).get_weights()[0]
plt.hist(W.ravel(), bins=100)
print(np.min(W),np.max(W))

# %%
filter_layers = []
for i in range(NUM_RECEPTIVE_FILTERS):
    for j in range(3):
        filter_layers.append(np.reshape(W[:,:,j, i], GABOR_SIZE))
for i,gf in enumerate(filter_layers):
    plt.subplot(8, (W.shape[3]*3)//8, i+1)
    plt.imshow(gf, cmap='gray')
    plt.axis('off')
plt.savefig("cifar100_fine-{}-channelwise-filters-kernel-{}.png".format(ITERATION, GABOR_WIDTH), bbox_inches='tight', dpi=350)
