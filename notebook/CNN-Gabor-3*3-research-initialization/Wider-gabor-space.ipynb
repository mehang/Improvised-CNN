# %%
from skimage.filters import gabor_kernel
from skimage import io
from skimage.transform import resize
from matplotlib import pyplot as plt 
import numpy as np

import math

# %%
def get_gabor_filters(inchannels, outchannels, kernel_size = (3,3)):
    delta = 1e-4
    freqs = (1/4)*math.sqrt(2)**(-np.random.randint(0,8, (outchannels, inchannels)))
    thetas = (math.pi/39)*np.random.randint(0,39, (outchannels, inchannels))
    sigmas = 1/(2*freqs)
    psis = math.pi * np.random.rand(outchannels, inchannels)
    x0, y0 = np.ceil(np.array(kernel_size)/2)    
    
    y, x = np.meshgrid(
            np.linspace(-x0 + 1, x0 + 0, kernel_size[0]),
            np.linspace(-y0 + 1, y0 + 0, kernel_size[1]),
    )
    filterbank = []
    
    for i in range(outchannels):
        for j in range(inchannels):
            freq = freqs[i][j]
            theta = thetas[i][j]
            sigma = sigmas[i][j]
            psi = psis[i][j]
            
            rotx = x * np.cos(theta) + y * np.sin(theta)
            roty = -x * np.sin(theta) + y * np.cos(theta)

            g = np.exp(
                -0.5 * ((rotx ** 2 + roty ** 2) / (sigma + delta) ** 2)
            )
            g = g * np.cos(freq * rotx + psi)
            g = g / (2 * math.pi * sigma ** 2)
            g = gabor_kernel(frequency=freq, bandwidth=sigma, theta=theta, offset=psi, n_stds=0).real
            filterbank.append(g)
    return filterbank

filterbank = get_gabor_filters(3, 64, (3,3))

fig = plt.subplots(12, 16, figsize=(22,22))
for i,gf in enumerate(filterbank):
    plt.subplot(12, 16, i+1)
    plt.imshow(gf, cmap='gray')
    plt.axis('off')

# %%
from tensorflow.keras.datasets import cifar10
from tensorflow.keras.utils import to_categorical

# The data, split between train and test sets:
(x_train, y_train), (x_test, y_test) = cifar10.load_data()
x_train = x_train.astype('float32') / 255.0
x_test = x_test.astype('float32') / 255.0

y_train = to_categorical(y_train, 10)
y_test = to_categorical(y_test, 10)

print('x_train shape:', x_train.shape)
print('x_test shape:', x_test.shape)
# Out:
# x_train shape: (50000, 32, 32, 3)
# x_test shape: (10000, 32, 32, 3)

# %%
# Importing the Keras libraries and packages
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Activation
from tensorflow.keras.layers import Input, Dense, Dropout, BatchNormalization
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import RMSprop, Adam

# dimensionality of input and latent encoded representations
inpt_dim = (32, 32, 3)

inpt_img = Input(shape=inpt_dim)

# Block 1
cl1 = Conv2D(64, (3, 3), strides=(2, 2),activation='relu', input_shape = inpt_dim)(inpt_img)
bnl2 = BatchNormalization()(cl1)
# afl3 = Activation('relu')(bnl2)
pl4 = MaxPooling2D(pool_size = (2, 2))(bnl2)

# Adding a second convolutional layer
cl5 = Conv2D(128, (3, 3), strides=(1, 1), activation='relu')(pl4)
bnl6 = BatchNormalization()(cl5)
# afl7 = Activation('relu')(bnl6)
pl8 = MaxPooling2D(pool_size = (2, 2))(bnl6)
bnl9 = BatchNormalization()(pl8)

# Step 3 - Flattening
fl10 = Flatten()(bnl9)

# Step 4 - Full connection
dol11 = Dropout(0.5)(fl10)
dl12 = Dense(units = 256, activation = 'relu')(dol11)
dol13 = Dropout(0.2)(dl12)
dl14 = Dense(units = 64, activation = 'relu')(dol13)
dol15 = Dropout(0.1)(dl14)
output = Dense(units = 10, activation = 'sigmoid')(dol15)

classifier = Model(inpt_img, output)

# Compiling the CNN
opt = RMSprop(learning_rate=0.001)
# opt = Adam(learning_rate=0.01)

classifier.compile(optimizer = opt, loss = 'binary_crossentropy', 
                   metrics = ['accuracy'])

print(classifier.summary())
# Out:
# Model: "functional_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 32, 32, 3)]       0
# _________________________________________________________________
# conv2d (Conv2D)              (None, 15, 15, 64)        1792
# _________________________________________________________________
# batch_normalization (BatchNo (None, 15, 15, 64)        256
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 7, 7, 64)          0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 5, 5, 128)         73856
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 5, 5, 128)         512
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 2, 2, 128)         0
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 2, 2, 128)         512
# _________________________________________________________________
# flatten (Flatten)            (None, 512)               0
# _________________________________________________________________
# dropout (Dropout)            (None, 512)               0
# _________________________________________________________________
# dense (Dense)                (None, 256)               131328
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 64)                16448
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 64)                0
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                650
# =================================================================
# Total params: 225,354
# Trainable params: 224,714
# Non-trainable params: 640
# _________________________________________________________________
# None

# %%
cnnl1 = classifier.layers[1].name   # get the name of the first conv layer
W = classifier.get_layer(name=cnnl1).get_weights()[0]   #get the filters
wshape = W.shape  #save the original shape

# %%
gabor_filters = np.empty(wshape, dtype='float32')
for kernel_index in range(wshape[3]):
    for channel_index in range(3):
        gabor_filters[:,:,channel_index, kernel_index] = filterbank[kernel_index+channel_index]
# for k in range(0,wshape[3],3):
#   gabor_filters[:,:,0,k] = filterbank[k]
#   gabor_filters[:,:,1,k] = filterbank[k]
#   gabor_filters[:,:,2,k] = filterbank[k]

# %%
# Fitting the CNN to the images

from tensorflow.keras.callbacks import ReduceLROnPlateau, EarlyStopping

reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=10,  
                              min_delta=1e-4, mode='min', verbose=1)

stop_alg = EarlyStopping(monitor='val_loss', patience=35, 
                         restore_best_weights=True, verbose=1)

hist = classifier.fit(x_train, y_train, batch_size=100, epochs=1000, 
                   callbacks=[stop_alg, reduce_lr], shuffle=True, 
                   validation_data=(x_test, y_test))

classifier.save_weights("cnn.hdf5")
# Out:
# Epoch 1/1000
# 500/500 [==============================] - 43s 87ms/step - loss: 0.2639 - accuracy: 0.3924 - val_loss: 0.3072 - val_accuracy: 0.3017
# Epoch 2/1000
# 500/500 [==============================] - 43s 86ms/step - loss: 0.2186 - accuracy: 0.5093 - val_loss: 0.2169 - val_accuracy: 0.5187
# Epoch 3/1000
# 500/500 [==============================] - 44s 89ms/step - loss: 0.2033 - accuracy: 0.5510 - val_loss: 0.2420 - val_accuracy: 0.4468
# Epoch 4/1000
# 500/500 [==============================] - 44s 88ms/step - loss: 0.1925 - accuracy: 0.5809 - val_loss: 0.1893 - val_accuracy: 0.5855
# Epoch 5/1000
# 500/500 [==============================] - 47s 95ms/step - loss: 0.1853 - accuracy: 0.5985 - val_loss: 0.1910 - val_accuracy: 0.5773
# Epoch 6/1000
# 500/500 [==============================] - 46s 92ms/step - loss: 0.1788 - accuracy: 0.6140 - val_loss: 0.1888 - val_accuracy: 0.5930
# Epoch 7/1000
# 500/500 [==============================] - 49s 97ms/step - loss: 0.1738 - accuracy: 0.6258 - val_loss: 0.1888 - val_accuracy: 0.5838
# Epoch 8/1000
# 500/500 [==============================] - 51s 103ms/step - loss: 0.1701 - accuracy: 0.6337 - val_loss: 0.1804 - val_accuracy: 0.6098
# Epoch 9/1000
# 500/500 [==============================] - 52s 104ms/step - loss: 0.1655 - accuracy: 0.6444 - val_loss: 0.1618 - val_accuracy: 0.6492
# Epoch 10/1000
# 500/500 [==============================] - 50s 100ms/step - loss: 0.1614 - accuracy: 0.6559 - val_loss: 0.1883 - val_accuracy: 0.5932
# Epoch 11/1000
# 500/500 [==============================] - 46s 92ms/step - loss: 0.1595 - accuracy: 0.6601 - val_loss: 0.2295 - val_accuracy: 0.5201
# Epoch 12/1000
# 500/500 [==============================] - 47s 93ms/step - loss: 0.1572 - accuracy: 0.6663 - val_loss: 0.1584 - val_accuracy: 0.6630
# Epoch 13/1000
# 500/500 [==============================] - 45s 89ms/step - loss: 0.1538 - accuracy: 0.6748 - val_loss: 0.2024 - val_accuracy: 0.5737
# Epoch 14/1000
# 500/500 [==============================] - 44s 89ms/step - loss: 0.1517 - accuracy: 0.6783 - val_loss: 0.1837 - val_accuracy: 0.6034
# Epoch 15/1000
# 500/500 [==============================] - 45s 91ms/step - loss: 0.1492 - accuracy: 0.6865 - val_loss: 0.1686 - val_accuracy: 0.6397
# Epoch 16/1000
# 500/500 [==============================] - 45s 91ms/step - loss: 0.1484 - accuracy: 0.6883 - val_loss: 0.1644 - val_accuracy: 0.6491
# Epoch 17/1000
# 500/500 [==============================] - 41s 82ms/step - loss: 0.1460 - accuracy: 0.6934 - val_loss: 0.1572 - val_accuracy: 0.6638
# Epoch 18/1000
# 500/500 [==============================] - 46s 91ms/step - loss: 0.1447 - accuracy: 0.6962 - val_loss: 0.2041 - val_accuracy: 0.5713
# Epoch 19/1000
# 500/500 [==============================] - 45s 91ms/step - loss: 0.1430 - accuracy: 0.7022 - val_loss: 0.1649 - val_accuracy: 0.6460
# Epoch 20/1000
# 500/500 [==============================] - 44s 89ms/step - loss: 0.1425 - accuracy: 0.7036 - val_loss: 0.1551 - val_accuracy: 0.6735
# Epoch 21/1000
# 500/500 [==============================] - 54s 107ms/step - loss: 0.1405 - accuracy: 0.7096 - val_loss: 0.1556 - val_accuracy: 0.6654
# Epoch 22/1000
# 500/500 [==============================] - 54s 109ms/step - loss: 0.1393 - accuracy: 0.7085 - val_loss: 0.1431 - val_accuracy: 0.7003
# Epoch 23/1000
# 500/500 [==============================] - 53s 106ms/step - loss: 0.1382 - accuracy: 0.7109 - val_loss: 0.1464 - val_accuracy: 0.6933
# Epoch 24/1000
# 500/500 [==============================] - 54s 107ms/step - loss: 0.1369 - accuracy: 0.7133 - val_loss: 0.1742 - val_accuracy: 0.6305
# Epoch 25/1000
# 500/500 [==============================] - 54s 108ms/step - loss: 0.1353 - accuracy: 0.7187 - val_loss: 0.1444 - val_accuracy: 0.6996
# Epoch 26/1000
# 500/500 [==============================] - 53s 106ms/step - loss: 0.1347 - accuracy: 0.7191 - val_loss: 0.1472 - val_accuracy: 0.6931
# Epoch 27/1000
# 500/500 [==============================] - 54s 109ms/step - loss: 0.1342 - accuracy: 0.7214 - val_loss: 0.1605 - val_accuracy: 0.6722
# Epoch 28/1000
# 500/500 [==============================] - 56s 111ms/step - loss: 0.1321 - accuracy: 0.7274 - val_loss: 0.1650 - val_accuracy: 0.6557
# Epoch 29/1000
# 500/500 [==============================] - 52s 104ms/step - loss: 0.1328 - accuracy: 0.7249 - val_loss: 0.1574 - val_accuracy: 0.6689
# Epoch 30/1000
# 500/500 [==============================] - 53s 106ms/step - loss: 0.1308 - accuracy: 0.7301 - val_loss: 0.1460 - val_accuracy: 0.6938
# Epoch 31/1000
# 500/500 [==============================] - 48s 96ms/step - loss: 0.1295 - accuracy: 0.7326 - val_loss: 0.1454 - val_accuracy: 0.6973
# Epoch 32/1000
# 500/500 [==============================] - ETA: 0s - loss: 0.1297 - accuracy: 0.7313
# Epoch 00032: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 500/500 [==============================] - 46s 91ms/step - loss: 0.1297 - accuracy: 0.7313 - val_loss: 0.1495 - val_accuracy: 0.6790
# Epoch 33/1000
# 500/500 [==============================] - 44s 88ms/step - loss: 0.1223 - accuracy: 0.7503 - val_loss: 0.1320 - val_accuracy: 0.7335
# Epoch 34/1000
# 500/500 [==============================] - 50s 100ms/step - loss: 0.1198 - accuracy: 0.7548 - val_loss: 0.1380 - val_accuracy: 0.7112
# Epoch 35/1000
# 500/500 [==============================] - 49s 98ms/step - loss: 0.1174 - accuracy: 0.7595 - val_loss: 0.1788 - val_accuracy: 0.6470
# Epoch 36/1000
# 500/500 [==============================] - 43s 86ms/step - loss: 0.1175 - accuracy: 0.7576 - val_loss: 0.1375 - val_accuracy: 0.7130
# Epoch 37/1000
# 500/500 [==============================] - 44s 88ms/step - loss: 0.1164 - accuracy: 0.7614 - val_loss: 0.1363 - val_accuracy: 0.7202
# Epoch 38/1000
# 500/500 [==============================] - 44s 88ms/step - loss: 0.1160 - accuracy: 0.7620 - val_loss: 0.1323 - val_accuracy: 0.7281
# Epoch 39/1000
# 500/500 [==============================] - 53s 105ms/step - loss: 0.1159 - accuracy: 0.7631 - val_loss: 0.1430 - val_accuracy: 0.7043
# Epoch 40/1000
# 500/500 [==============================] - 53s 106ms/step - loss: 0.1146 - accuracy: 0.7656 - val_loss: 0.1587 - val_accuracy: 0.6813
# Epoch 41/1000
# 500/500 [==============================] - 48s 97ms/step - loss: 0.1143 - accuracy: 0.7652 - val_loss: 0.1355 - val_accuracy: 0.7225
# Epoch 42/1000
# 500/500 [==============================] - 45s 90ms/step - loss: 0.1135 - accuracy: 0.7678 - val_loss: 0.1358 - val_accuracy: 0.7253
# Epoch 43/1000
# 500/500 [==============================] - ETA: 0s - loss: 0.1127 - accuracy: 0.7702
# Epoch 00043: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 500/500 [==============================] - 53s 105ms/step - loss: 0.1127 - accuracy: 0.7702 - val_loss: 0.1358 - val_accuracy: 0.7137
# Epoch 44/1000
# 500/500 [==============================] - 50s 101ms/step - loss: 0.1088 - accuracy: 0.7797 - val_loss: 0.1283 - val_accuracy: 0.7388
# Epoch 45/1000
# 500/500 [==============================] - 55s 110ms/step - loss: 0.1077 - accuracy: 0.7801 - val_loss: 0.1329 - val_accuracy: 0.7285
# Epoch 46/1000
# 500/500 [==============================] - 56s 111ms/step - loss: 0.1067 - accuracy: 0.7836 - val_loss: 0.1319 - val_accuracy: 0.7346
# Epoch 47/1000
# 500/500 [==============================] - 56s 111ms/step - loss: 0.1063 - accuracy: 0.7848 - val_loss: 0.1298 - val_accuracy: 0.7377
# Epoch 48/1000
# 500/500 [==============================] - 49s 98ms/step - loss: 0.1052 - accuracy: 0.7866 - val_loss: 0.1293 - val_accuracy: 0.7413
# Epoch 49/1000
# 500/500 [==============================] - 44s 87ms/step - loss: 0.1061 - accuracy: 0.7849 - val_loss: 0.1324 - val_accuracy: 0.7359
# Epoch 50/1000
# 500/500 [==============================] - 42s 84ms/step - loss: 0.1047 - accuracy: 0.7872 - val_loss: 0.1285 - val_accuracy: 0.7448
# Epoch 51/1000
# 500/500 [==============================] - 46s 92ms/step - loss: 0.1047 - accuracy: 0.7875 - val_loss: 0.1275 - val_accuracy: 0.7419
# Epoch 52/1000
# 500/500 [==============================] - 46s 92ms/step - loss: 0.1050 - accuracy: 0.7874 - val_loss: 0.1299 - val_accuracy: 0.7362
# Epoch 53/1000
# 500/500 [==============================] - 43s 85ms/step - loss: 0.1045 - accuracy: 0.7887 - val_loss: 0.1278 - val_accuracy: 0.7443
# Epoch 54/1000
# 500/500 [==============================] - 43s 85ms/step - loss: 0.1034 - accuracy: 0.7905 - val_loss: 0.1358 - val_accuracy: 0.7315
# Epoch 55/1000
# 500/500 [==============================] - 43s 86ms/step - loss: 0.1036 - accuracy: 0.7892 - val_loss: 0.1277 - val_accuracy: 0.7427
# Epoch 56/1000
# 500/500 [==============================] - 51s 102ms/step - loss: 0.1037 - accuracy: 0.7913 - val_loss: 0.1307 - val_accuracy: 0.7376
# Epoch 57/1000
# 500/500 [==============================] - 54s 108ms/step - loss: 0.1018 - accuracy: 0.7945 - val_loss: 0.1277 - val_accuracy: 0.7409
# Epoch 58/1000
# 500/500 [==============================] - 54s 108ms/step - loss: 0.1033 - accuracy: 0.7913 - val_loss: 0.1293 - val_accuracy: 0.7371
# Epoch 59/1000
# 500/500 [==============================] - 60s 120ms/step - loss: 0.1017 - accuracy: 0.7929 - val_loss: 0.1301 - val_accuracy: 0.7407
# Epoch 60/1000
# 500/500 [==============================] - 49s 97ms/step - loss: 0.1025 - accuracy: 0.7940 - val_loss: 0.1288 - val_accuracy: 0.7435
# Epoch 61/1000
# 500/500 [==============================] - ETA: 0s - loss: 0.1014 - accuracy: 0.7940
# Epoch 00061: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 500/500 [==============================] - 51s 102ms/step - loss: 0.1014 - accuracy: 0.7940 - val_loss: 0.1296 - val_accuracy: 0.7478
# Epoch 62/1000
# 500/500 [==============================] - 50s 100ms/step - loss: 0.1000 - accuracy: 0.7978 - val_loss: 0.1263 - val_accuracy: 0.7467
# Epoch 63/1000
# 500/500 [==============================] - 49s 98ms/step - loss: 0.0985 - accuracy: 0.8013 - val_loss: 0.1259 - val_accuracy: 0.7489
# Epoch 64/1000
# 500/500 [==============================] - 49s 97ms/step - loss: 0.0984 - accuracy: 0.8011 - val_loss: 0.1277 - val_accuracy: 0.7442
# Epoch 65/1000
# 500/500 [==============================] - 50s 101ms/step - loss: 0.0990 - accuracy: 0.8009 - val_loss: 0.1275 - val_accuracy: 0.7465
# Epoch 66/1000
# 500/500 [==============================] - 51s 102ms/step - loss: 0.0982 - accuracy: 0.8029 - val_loss: 0.1260 - val_accuracy: 0.7497
# Epoch 67/1000
# 500/500 [==============================] - 50s 100ms/step - loss: 0.0978 - accuracy: 0.8034 - val_loss: 0.1277 - val_accuracy: 0.7458
# Epoch 68/1000
# 500/500 [==============================] - 50s 99ms/step - loss: 0.0980 - accuracy: 0.8027 - val_loss: 0.1262 - val_accuracy: 0.7502
# Epoch 69/1000
# 500/500 [==============================] - 51s 101ms/step - loss: 0.0983 - accuracy: 0.8006 - val_loss: 0.1267 - val_accuracy: 0.7487
# Epoch 70/1000
# 500/500 [==============================] - 50s 101ms/step - loss: 0.0975 - accuracy: 0.8046 - val_loss: 0.1252 - val_accuracy: 0.7501
# Epoch 71/1000
# 500/500 [==============================] - 52s 103ms/step - loss: 0.0971 - accuracy: 0.8048 - val_loss: 0.1257 - val_accuracy: 0.7495
# Epoch 72/1000
# 500/500 [==============================] - 52s 103ms/step - loss: 0.0981 - accuracy: 0.8027 - val_loss: 0.1255 - val_accuracy: 0.7519
# Epoch 73/1000
# 500/500 [==============================] - 53s 105ms/step - loss: 0.0981 - accuracy: 0.8045 - val_loss: 0.1244 - val_accuracy: 0.7486
# Epoch 74/1000
# 500/500 [==============================] - 54s 109ms/step - loss: 0.0968 - accuracy: 0.8058 - val_loss: 0.1256 - val_accuracy: 0.7493
# Epoch 75/1000
# 500/500 [==============================] - 51s 103ms/step - loss: 0.0970 - accuracy: 0.8061 - val_loss: 0.1252 - val_accuracy: 0.7485
# Epoch 76/1000
# 500/500 [==============================] - 45s 90ms/step - loss: 0.0969 - accuracy: 0.8043 - val_loss: 0.1252 - val_accuracy: 0.7512
# Epoch 77/1000
# 500/500 [==============================] - 45s 90ms/step - loss: 0.0974 - accuracy: 0.8040 - val_loss: 0.1275 - val_accuracy: 0.7495
# Epoch 78/1000
# 500/500 [==============================] - 52s 103ms/step - loss: 0.0974 - accuracy: 0.8040 - val_loss: 0.1254 - val_accuracy: 0.7500
# Epoch 79/1000
# 500/500 [==============================] - 57s 115ms/step - loss: 0.0965 - accuracy: 0.8062 - val_loss: 0.1254 - val_accuracy: 0.7481
# Epoch 80/1000
# 500/500 [==============================] - 53s 106ms/step - loss: 0.0965 - accuracy: 0.8063 - val_loss: 0.1278 - val_accuracy: 0.7457
# Epoch 81/1000
# 500/500 [==============================] - 48s 97ms/step - loss: 0.0959 - accuracy: 0.8086 - val_loss: 0.1309 - val_accuracy: 0.7382
# Epoch 82/1000
# 500/500 [==============================] - 52s 104ms/step - loss: 0.0967 - accuracy: 0.8077 - val_loss: 0.1250 - val_accuracy: 0.7494
# Epoch 83/1000
# 500/500 [==============================] - ETA: 0s - loss: 0.0960 - accuracy: 0.8056
# Epoch 00083: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 500/500 [==============================] - 48s 96ms/step - loss: 0.0960 - accuracy: 0.8056 - val_loss: 0.1267 - val_accuracy: 0.7514
# Epoch 84/1000
# 500/500 [==============================] - 48s 96ms/step - loss: 0.0943 - accuracy: 0.8109 - val_loss: 0.1242 - val_accuracy: 0.7540
# Epoch 85/1000
# 500/500 [==============================] - 48s 97ms/step - loss: 0.0942 - accuracy: 0.8116 - val_loss: 0.1247 - val_accuracy: 0.7528
# Epoch 86/1000
# 500/500 [==============================] - 49s 97ms/step - loss: 0.0939 - accuracy: 0.8115 - val_loss: 0.1267 - val_accuracy: 0.7487
# Epoch 87/1000
# 500/500 [==============================] - 44s 88ms/step - loss: 0.0946 - accuracy: 0.8099 - val_loss: 0.1250 - val_accuracy: 0.7549
# Epoch 88/1000
# 500/500 [==============================] - 46s 92ms/step - loss: 0.0952 - accuracy: 0.8078 - val_loss: 0.1248 - val_accuracy: 0.7547
# Epoch 89/1000
# 500/500 [==============================] - 43s 87ms/step - loss: 0.0949 - accuracy: 0.8109 - val_loss: 0.1248 - val_accuracy: 0.7518
# Epoch 90/1000
# 500/500 [==============================] - 39s 78ms/step - loss: 0.0950 - accuracy: 0.8105 - val_loss: 0.1246 - val_accuracy: 0.7494
# Epoch 91/1000
# 500/500 [==============================] - 27s 54ms/step - loss: 0.0938 - accuracy: 0.8111 - val_loss: 0.1255 - val_accuracy: 0.7532
# Epoch 92/1000
# 500/500 [==============================] - 22s 43ms/step - loss: 0.0936 - accuracy: 0.8132 - val_loss: 0.1252 - val_accuracy: 0.7528
# Epoch 93/1000
# 500/500 [==============================] - 21s 42ms/step - loss: 0.0934 - accuracy: 0.8122 - val_loss: 0.1248 - val_accuracy: 0.7532
# Epoch 94/1000
# 500/500 [==============================] - ETA: 0s - loss: 0.0942 - accuracy: 0.8134
# Epoch 00094: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# 500/500 [==============================] - 24s 47ms/step - loss: 0.0942 - accuracy: 0.8134 - val_loss: 0.1246 - val_accuracy: 0.7513
# Epoch 95/1000
# 500/500 [==============================] - 24s 47ms/step - loss: 0.0940 - accuracy: 0.8124 - val_loss: 0.1244 - val_accuracy: 0.7524
# Epoch 96/1000
# 500/500 [==============================] - 24s 47ms/step - loss: 0.0935 - accuracy: 0.8121 - val_loss: 0.1244 - val_accuracy: 0.7548
# Epoch 97/1000
# 500/500 [==============================] - 22s 45ms/step - loss: 0.0942 - accuracy: 0.8116 - val_loss: 0.1248 - val_accuracy: 0.7504
# Epoch 98/1000
# 500/500 [==============================] - 24s 47ms/step - loss: 0.0927 - accuracy: 0.8160 - val_loss: 0.1247 - val_accuracy: 0.7558
# Epoch 99/1000
# 500/500 [==============================] - 23s 46ms/step - loss: 0.0928 - accuracy: 0.8134 - val_loss: 0.1244 - val_accuracy: 0.7546
# Epoch 100/1000
# 500/500 [==============================] - 25s 50ms/step - loss: 0.0921 - accuracy: 0.8178 - val_loss: 0.1246 - val_accuracy: 0.7542
# Epoch 101/1000
# 500/500 [==============================] - 23s 46ms/step - loss: 0.0922 - accuracy: 0.8153 - val_loss: 0.1247 - val_accuracy: 0.7532
# Epoch 102/1000
# 500/500 [==============================] - 24s 48ms/step - loss: 0.0931 - accuracy: 0.8128 - val_loss: 0.1243 - val_accuracy: 0.7540
# Epoch 103/1000
# 500/500 [==============================] - 31s 63ms/step - loss: 0.0930 - accuracy: 0.8139 - val_loss: 0.1241 - val_accuracy: 0.7549
# Epoch 104/1000
# 500/500 [==============================] - 32s 64ms/step - loss: 0.0925 - accuracy: 0.8149 - val_loss: 0.1249 - val_accuracy: 0.7514
# Epoch 105/1000
# 500/500 [==============================] - 32s 64ms/step - loss: 0.0932 - accuracy: 0.8148 - val_loss: 0.1243 - val_accuracy: 0.7530
# Epoch 106/1000
# 500/500 [==============================] - 31s 62ms/step - loss: 0.0929 - accuracy: 0.8134 - val_loss: 0.1246 - val_accuracy: 0.7531
# Epoch 107/1000
# 500/500 [==============================] - 26s 53ms/step - loss: 0.0921 - accuracy: 0.8166 - val_loss: 0.1244 - val_accuracy: 0.7552
# Epoch 108/1000
# 500/500 [==============================] - 30s 59ms/step - loss: 0.0923 - accuracy: 0.8168 - val_loss: 0.1246 - val_accuracy: 0.7528
# Epoch 109/1000
# 500/500 [==============================] - 30s 60ms/step - loss: 0.0929 - accuracy: 0.8137 - val_loss: 0.1243 - val_accuracy: 0.7530
# Epoch 110/1000
# 500/500 [==============================] - 31s 63ms/step - loss: 0.0928 - accuracy: 0.8138 - val_loss: 0.1245 - val_accuracy: 0.7538
# Epoch 111/1000
# 500/500 [==============================] - 27s 53ms/step - loss: 0.0926 - accuracy: 0.8146 - val_loss: 0.1243 - val_accuracy: 0.7516
# Epoch 112/1000
# 500/500 [==============================] - 27s 54ms/step - loss: 0.0929 - accuracy: 0.8134 - val_loss: 0.1246 - val_accuracy: 0.7521
# Epoch 113/1000
# 500/500 [==============================] - ETA: 0s - loss: 0.0914 - accuracy: 0.8171
# Epoch 00113: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# 500/500 [==============================] - 27s 54ms/step - loss: 0.0914 - accuracy: 0.8171 - val_loss: 0.1247 - val_accuracy: 0.7540
# Epoch 114/1000
# 500/500 [==============================] - 28s 57ms/step - loss: 0.0924 - accuracy: 0.8151 - val_loss: 0.1242 - val_accuracy: 0.7540
# Epoch 115/1000
# 500/500 [==============================] - 26s 52ms/step - loss: 0.0922 - accuracy: 0.8162 - val_loss: 0.1242 - val_accuracy: 0.7543
# Epoch 116/1000
# 500/500 [==============================] - 23s 46ms/step - loss: 0.0914 - accuracy: 0.8167 - val_loss: 0.1240 - val_accuracy: 0.7562
# Epoch 117/1000
# 500/500 [==============================] - 23s 45ms/step - loss: 0.0917 - accuracy: 0.8158 - val_loss: 0.1244 - val_accuracy: 0.7541
# Epoch 118/1000
# 500/500 [==============================] - 23s 47ms/step - loss: 0.0920 - accuracy: 0.8161 - val_loss: 0.1241 - val_accuracy: 0.7548
# Epoch 119/1000
# 500/500 [==============================] - 23s 46ms/step - loss: 0.0920 - accuracy: 0.8153 - val_loss: 0.1243 - val_accuracy: 0.7537
# Epoch 120/1000
# 500/500 [==============================] - 31s 62ms/step - loss: 0.0923 - accuracy: 0.8149 - val_loss: 0.1243 - val_accuracy: 0.7537
# Epoch 121/1000
# 500/500 [==============================] - 27s 54ms/step - loss: 0.0917 - accuracy: 0.8156 - val_loss: 0.1242 - val_accuracy: 0.7534
# Epoch 122/1000
# 500/500 [==============================] - 24s 49ms/step - loss: 0.0917 - accuracy: 0.8182 - val_loss: 0.1244 - val_accuracy: 0.7540
# Epoch 123/1000
# 500/500 [==============================] - ETA: 0s - loss: 0.0913 - accuracy: 0.8192
# Epoch 00123: ReduceLROnPlateau reducing learning rate to 7.812500371073838e-06.
# 500/500 [==============================] - 31s 61ms/step - loss: 0.0913 - accuracy: 0.8192 - val_loss: 0.1242 - val_accuracy: 0.7542
# Epoch 124/1000
# 500/500 [==============================] - 26s 52ms/step - loss: 0.0925 - accuracy: 0.8148 - val_loss: 0.1242 - val_accuracy: 0.7551
# Epoch 125/1000
# 500/500 [==============================] - 27s 54ms/step - loss: 0.0920 - accuracy: 0.8171 - val_loss: 0.1242 - val_accuracy: 0.7559
# Epoch 126/1000
# 500/500 [==============================] - 29s 58ms/step - loss: 0.0916 - accuracy: 0.8171 - val_loss: 0.1242 - val_accuracy: 0.7563
# Epoch 127/1000
# 500/500 [==============================] - 28s 56ms/step - loss: 0.0920 - accuracy: 0.8170 - val_loss: 0.1243 - val_accuracy: 0.7531
# Epoch 128/1000
# 500/500 [==============================] - 29s 59ms/step - loss: 0.0913 - accuracy: 0.8178 - val_loss: 0.1243 - val_accuracy: 0.7547
# Epoch 129/1000
# 500/500 [==============================] - 31s 61ms/step - loss: 0.0905 - accuracy: 0.8185 - val_loss: 0.1243 - val_accuracy: 0.7543
# Epoch 130/1000
# 500/500 [==============================] - 29s 57ms/step - loss: 0.0916 - accuracy: 0.8176 - val_loss: 0.1242 - val_accuracy: 0.7543
# Epoch 131/1000
# 500/500 [==============================] - 33s 66ms/step - loss: 0.0917 - accuracy: 0.8156 - val_loss: 0.1244 - val_accuracy: 0.7534
# Epoch 132/1000
# 500/500 [==============================] - 31s 62ms/step - loss: 0.0926 - accuracy: 0.8149 - val_loss: 0.1244 - val_accuracy: 0.7547
# Epoch 133/1000
# 500/500 [==============================] - ETA: 0s - loss: 0.0919 - accuracy: 0.8154
# Epoch 00133: ReduceLROnPlateau reducing learning rate to 3.906250185536919e-06.
# 500/500 [==============================] - 29s 57ms/step - loss: 0.0919 - accuracy: 0.8154 - val_loss: 0.1245 - val_accuracy: 0.7550
# Epoch 134/1000
# 500/500 [==============================] - 31s 62ms/step - loss: 0.0911 - accuracy: 0.8180 - val_loss: 0.1244 - val_accuracy: 0.7546
# Epoch 135/1000
# 500/500 [==============================] - 32s 64ms/step - loss: 0.0916 - accuracy: 0.8170 - val_loss: 0.1244 - val_accuracy: 0.7547
# Epoch 136/1000
# 500/500 [==============================] - 29s 59ms/step - loss: 0.0918 - accuracy: 0.8174 - val_loss: 0.1243 - val_accuracy: 0.7553
# Epoch 137/1000
# 500/500 [==============================] - 30s 60ms/step - loss: 0.0911 - accuracy: 0.8186 - val_loss: 0.1244 - val_accuracy: 0.7546
# Epoch 138/1000
# 500/500 [==============================] - 29s 57ms/step - loss: 0.0916 - accuracy: 0.8180 - val_loss: 0.1243 - val_accuracy: 0.7551
# Epoch 139/1000
# 500/500 [==============================] - 32s 64ms/step - loss: 0.0910 - accuracy: 0.8188 - val_loss: 0.1243 - val_accuracy: 0.7543
# Epoch 140/1000
# 500/500 [==============================] - 33s 65ms/step - loss: 0.0917 - accuracy: 0.8168 - val_loss: 0.1242 - val_accuracy: 0.7544
# Epoch 141/1000
# 500/500 [==============================] - 23s 46ms/step - loss: 0.0915 - accuracy: 0.8177 - val_loss: 0.1242 - val_accuracy: 0.7549
# Epoch 142/1000
# 500/500 [==============================] - 23s 46ms/step - loss: 0.0916 - accuracy: 0.8181 - val_loss: 0.1243 - val_accuracy: 0.7542
# Epoch 143/1000
# 499/500 [============================>.] - ETA: 0s - loss: 0.0904 - accuracy: 0.8203
# Epoch 00143: ReduceLROnPlateau reducing learning rate to 1.9531250927684596e-06.
# 500/500 [==============================] - 22s 44ms/step - loss: 0.0904 - accuracy: 0.8203 - val_loss: 0.1244 - val_accuracy: 0.7551
# Epoch 144/1000
# 500/500 [==============================] - 23s 46ms/step - loss: 0.0907 - accuracy: 0.8193 - val_loss: 0.1243 - val_accuracy: 0.7542
# Epoch 145/1000
# 500/500 [==============================] - 29s 59ms/step - loss: 0.0904 - accuracy: 0.8182 - val_loss: 0.1244 - val_accuracy: 0.7542
# Epoch 146/1000
# 500/500 [==============================] - 31s 62ms/step - loss: 0.0913 - accuracy: 0.8168 - val_loss: 0.1244 - val_accuracy: 0.7545
# Epoch 147/1000
# 500/500 [==============================] - 28s 56ms/step - loss: 0.0916 - accuracy: 0.8164 - val_loss: 0.1244 - val_accuracy: 0.7547
# Epoch 148/1000
# 500/500 [==============================] - 28s 57ms/step - loss: 0.0911 - accuracy: 0.8174 - val_loss: 0.1244 - val_accuracy: 0.7551
# Epoch 149/1000
# 500/500 [==============================] - 27s 55ms/step - loss: 0.0916 - accuracy: 0.8163 - val_loss: 0.1244 - val_accuracy: 0.7549
# Epoch 150/1000
# 500/500 [==============================] - 28s 56ms/step - loss: 0.0913 - accuracy: 0.8173 - val_loss: 0.1244 - val_accuracy: 0.7558
# Epoch 151/1000
# 500/500 [==============================] - ETA: 0s - loss: 0.0913 - accuracy: 0.8168Restoring model weights from the end of the best epoch.
# 500/500 [==============================] - 27s 55ms/step - loss: 0.0913 - accuracy: 0.8168 - val_loss: 0.1243 - val_accuracy: 0.7548
# Epoch 00151: early stopping

# %%
import matplotlib.pyplot as plt

fig = plt.figure(figsize=(10,6))
plt.plot(hist.history['loss'], color='#785ef0')
plt.plot(hist.history['val_loss'], color='#dc267f')
plt.title('Model Loss Progress')
plt.ylabel('Binary Cross-Entropy Loss')
plt.xlabel('Epoch')
plt.legend(['Training Set', 'Test Set'], loc='upper right')
plt.savefig('cnn-gabor.cifar10.loss-5.png', dpi=350, bbox_inches='tight')
plt.show()

# %%
from sklearn.preprocessing import MinMaxScaler

cnnl1 = classifier.layers[1].name   # get the name of the first conv layer
W = classifier.get_layer(name=cnnl1).get_weights()[0]   #get the filters
wshape = W.shape  #save the original shape

# this part will scale to [0, 1] for visualization purposes
scaler = MinMaxScaler()
scaler.fit(W.reshape(-1,1))
W = scaler.transform(W.reshape(-1,1))
W = W.reshape(wshape)

# since there are 64 filters, we will display them 8x8
fig, axs = plt.subplots(8,8, figsize=(24,24))
fig.subplots_adjust(hspace = .25, wspace=.001)
axs = axs.ravel()
for i in range(W.shape[-1]):
  # we reshape to a 3D (RGB) image shape and display
  h = np.reshape(W[:,:,:,i], (3,3,3))
  axs[i].imshow(h)
  axs[i].set_title('Filter ' + str(i))    
plt.savefig("cnn-gabor.full.filters-5.png", bbox_inches='tight', dpi=350)

# %%
cnnl1 = classifier.layers[1].name   # get the name of the first conv layer
W = classifier.get_layer(name=cnnl1).get_weights()[0]
plt.hist(W.ravel(), bins=100)
print(np.min(W),np.max(W))
# Out:
# -0.3512438 0.36737472
