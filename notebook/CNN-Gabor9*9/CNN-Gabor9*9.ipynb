# %%
from skimage.filters import gabor_kernel
from skimage import io
from skimage.transform import resize
from matplotlib import pyplot as plt 
import numpy as np

# %%
fig = plt.subplots(8, 8, figsize=(22,22))
filterbank = []
cnt = 0
for angle in np.linspace(0.0, 3.14159, 8, endpoint=False):
  for freq in [0.3, 0.5]:
    # cnt = cnt + 1
    # gk = gabor_kernel(frequency=freq)
    # plt.subplot(3, 5, cnt)
    # plt.imshow(gk.real, cmap='gray')
    # print(gk.real.shape)
    # # plt.colorbar()
    # plt.axis('off')
    # plt.title("$\\gamma=${0:0.1f}".format(freq))
    for band in [1.0, 0.8, 0.6, 0.4]:
      print(freq, band, angle)
      cnt = cnt + 1
      gk = gabor_kernel(frequency=freq, bandwidth=band, theta=angle)
      plt.subplot(8, 8, cnt)
      gf = resize(gk.real,(9,9),anti_aliasing=False)
      gf = gf - np.min(gf)
      gf = gf/np.max(gf)
      gf = gf * 0.6
      gf = gf - 0.3
      filterbank.append(gf)
      plt.imshow(gf, cmap='gray')
      print(gk.real.shape)
      # plt.colorbar()
      plt.axis('off')
      plt.title("$\\gamma=${0:0.1f} $\\lambda=${1:0.1f} $\\theta=${0:0.2f}".format(freq,band,angle))
plt.show()
# for angle in np.linspace(0.0, 3.14159, 8, endpoint=False):
#   print(angle)
#   cnt = cnt + 1
#   gk = gabor_kernel(frequency=0.1, theta=angle)
#   plt.subplot(8, 9, cnt)
#   plt.imshow(gk.real, cmap='gray')
#   print(gk.real.shape)
#   # plt.colorbar()
#   plt.axis('off')
#   plt.title("$\\theta=${0:0.2f}".format(angle))

# plt.savefig('gabor_filters.png', bbox_inches='tight', dpi=300)
# Out:
# 0.3 1.0 0.0
# (13, 13)
# 0.3 0.8 0.0
# (15, 15)
# 0.3 0.6 0.0
# (21, 21)
# 0.3 0.4 0.0
# (29, 29)
# 0.5 1.0 0.0
# (9, 9)
# 0.5 0.8 0.0
# (11, 11)
# 0.5 0.6 0.0
# (13, 13)
# 0.5 0.4 0.0
# (19, 19)
# 0.3 1.0 0.39269875
# (13, 13)
# 0.3 0.8 0.39269875
# (15, 15)
# 0.3 0.6 0.39269875
# (19, 19)
# 0.3 0.4 0.39269875
# (27, 27)
# 0.5 1.0 0.39269875
# (9, 9)
# 0.5 0.8 0.39269875
# (9, 9)
# 0.5 0.6 0.39269875
# (13, 13)
# 0.5 0.4 0.39269875
# (17, 17)
# 0.3 1.0 0.7853975
# (9, 9)
# 0.3 0.8 0.7853975
# (11, 11)
# 0.3 0.6 0.7853975
# (15, 15)
# 0.3 0.4 0.7853975
# (21, 21)
# 0.5 1.0 0.7853975
# (7, 7)
# 0.5 0.8 0.7853975
# (7, 7)
# 0.5 0.6 0.7853975
# (9, 9)
# 0.5 0.4 0.7853975
# (13, 13)
# 0.3 1.0 1.1780962499999998
# (13, 13)
# 0.3 0.8 1.1780962499999998
# (15, 15)
# 0.3 0.6 1.1780962499999998
# (19, 19)
# 0.3 0.4 1.1780962499999998
# (27, 27)
# 0.5 1.0 1.1780962499999998
# (9, 9)
# 0.5 0.8 1.1780962499999998
# (9, 9)
# 0.5 0.6 1.1780962499999998
# (13, 13)
# 0.5 0.4 1.1780962499999998
# (17, 17)
# 0.3 1.0 1.570795
# (13, 13)
# 0.3 0.8 1.570795
# (15, 15)
# 0.3 0.6 1.570795
# (21, 21)
# 0.3 0.4 1.570795
# (29, 29)
# 0.5 1.0 1.570795
# (9, 9)
# 0.5 0.8 1.570795
# (11, 11)
# 0.5 0.6 1.570795
# (13, 13)
# 0.5 0.4 1.570795
# (19, 19)
# 0.3 1.0 1.96349375
# (13, 13)
# 0.3 0.8 1.96349375
# (15, 15)
# 0.3 0.6 1.96349375
# (19, 19)
# 0.3 0.4 1.96349375
# (27, 27)
# 0.5 1.0 1.96349375
# (9, 9)
# 0.5 0.8 1.96349375
# (9, 9)
# 0.5 0.6 1.96349375
# (13, 13)
# 0.5 0.4 1.96349375
# (17, 17)
# 0.3 1.0 2.3561924999999997
# (9, 9)
# 0.3 0.8 2.3561924999999997
# (11, 11)
# 0.3 0.6 2.3561924999999997
# (15, 15)
# 0.3 0.4 2.3561924999999997
# (21, 21)
# 0.5 1.0 2.3561924999999997
# (7, 7)
# 0.5 0.8 2.3561924999999997
# (7, 7)
# 0.5 0.6 2.3561924999999997
# (9, 9)
# 0.5 0.4 2.3561924999999997
# (13, 13)
# 0.3 1.0 2.74889125
# (13, 13)
# 0.3 0.8 2.74889125
# (15, 15)
# 0.3 0.6 2.74889125
# (19, 19)
# 0.3 0.4 2.74889125
# (27, 27)
# 0.5 1.0 2.74889125
# (9, 9)
# 0.5 0.8 2.74889125
# (9, 9)
# 0.5 0.6 2.74889125
# (13, 13)
# 0.5 0.4 2.74889125
# (17, 17)

# %%
np.min(gf)
# Out:
# -0.3

# %%
from tensorflow.keras.datasets import cifar10
from tensorflow.keras.utils import to_categorical

# The data, split between train and test sets:
(x_train, y_train), (x_test, y_test) = cifar10.load_data()
x_train = x_train.astype('float32') / 255.0
x_test = x_test.astype('float32') / 255.0

y_train = to_categorical(y_train, 10)
y_test = to_categorical(y_test, 10)

print('x_train shape:', x_train.shape)
print('x_test shape:', x_test.shape)
# Out:
# x_train shape: (50000, 32, 32, 3)
# x_test shape: (10000, 32, 32, 3)

# %%
# Importing the Keras libraries and packages
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Activation
from tensorflow.keras.layers import Input, Dense, Dropout, BatchNormalization
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import RMSprop, Adam

# dimensionality of input and latent encoded representations
inpt_dim = (32, 32, 3)

inpt_img = Input(shape=inpt_dim)

# Block 1
cl1 = Conv2D(64, (9, 9), strides=(2, 2), activation='relu', input_shape = inpt_dim)(inpt_img)
bnl2 = BatchNormalization()(cl1)
# afl3 = Activation('relu')(bnl2)
pl4 = MaxPooling2D(pool_size = (2, 2))(bnl2)

# Adding a second convolutional layer
cl5 = Conv2D(128, (3, 3), strides=(1, 1), activation='relu')(pl4)
bnl6 = BatchNormalization()(cl5)
# afl7 = Activation('relu')(bnl6)
pl8 = MaxPooling2D(pool_size = (2, 2))(bnl6)
bnl9 = BatchNormalization()(pl8)

# Step 3 - Flattening
fl10 = Flatten()(bnl9)

# Step 4 - Full connection
dol11 = Dropout(0.5)(fl10)
dl12 = Dense(units = 256, activation = 'relu')(dol11)
dol13 = Dropout(0.2)(dl12)
dl14 = Dense(units = 64, activation = 'relu')(dol13)
dol15 = Dropout(0.1)(dl14)
output = Dense(units = 10, activation = 'sigmoid')(dol15)

classifier = Model(inpt_img, output)

# Compiling the CNN
opt = RMSprop(learning_rate=0.001)
# opt = Adam(learning_rate=0.01)

classifier.compile(optimizer = opt, loss = 'binary_crossentropy', 
                   metrics = ['accuracy'])

print(classifier.summary())
# Out:
# Model: "functional_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 32, 32, 3)]       0
# _________________________________________________________________
# conv2d (Conv2D)              (None, 12, 12, 64)        15616
# _________________________________________________________________
# batch_normalization (BatchNo (None, 12, 12, 64)        256
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 6, 6, 64)          0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 4, 4, 128)         73856
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 4, 4, 128)         512
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 2, 2, 128)         0
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 2, 2, 128)         512
# _________________________________________________________________
# flatten (Flatten)            (None, 512)               0
# _________________________________________________________________
# dropout (Dropout)            (None, 512)               0
# _________________________________________________________________
# dense (Dense)                (None, 256)               131328
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 64)                16448
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 64)                0
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                650
# =================================================================
# Total params: 239,178
# Trainable params: 238,538
# Non-trainable params: 640
# _________________________________________________________________
# None

# %%
# Fitting the CNN to the images

from tensorflow.keras.callbacks import ReduceLROnPlateau, EarlyStopping

reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=10,  
                              min_delta=1e-4, mode='min', verbose=1)

stop_alg = EarlyStopping(monitor='val_loss', patience=35, 
                         restore_best_weights=True, verbose=1)

hist = classifier.fit(x_train, y_train, batch_size=100, epochs=1000, 
                   callbacks=[stop_alg, reduce_lr], shuffle=True, 
                   validation_data=(x_test, y_test))

classifier.save_weights("cnn.hdf5")
# Out:
# Epoch 1/1000
# 500/500 [==============================] - 21s 42ms/step - loss: 0.2747 - accuracy: 0.3567 - val_loss: 0.2584 - val_accuracy: 0.3824
# Epoch 2/1000
# 500/500 [==============================] - 23s 46ms/step - loss: 0.2272 - accuracy: 0.4815 - val_loss: 0.2486 - val_accuracy: 0.4291
# Epoch 3/1000
# 500/500 [==============================] - 24s 48ms/step - loss: 0.2106 - accuracy: 0.5243 - val_loss: 0.2064 - val_accuracy: 0.5325
# Epoch 4/1000
# 500/500 [==============================] - 25s 50ms/step - loss: 0.2002 - accuracy: 0.5543 - val_loss: 0.2176 - val_accuracy: 0.4931
# Epoch 5/1000
# 500/500 [==============================] - 24s 49ms/step - loss: 0.1915 - accuracy: 0.5757 - val_loss: 0.1965 - val_accuracy: 0.5566
# Epoch 6/1000
# 500/500 [==============================] - 23s 46ms/step - loss: 0.1859 - accuracy: 0.5912 - val_loss: 0.2325 - val_accuracy: 0.5018
# Epoch 7/1000
# 500/500 [==============================] - 24s 49ms/step - loss: 0.1793 - accuracy: 0.6086 - val_loss: 0.2140 - val_accuracy: 0.5171
# Epoch 8/1000
# 500/500 [==============================] - 25s 50ms/step - loss: 0.1741 - accuracy: 0.6223 - val_loss: 0.2372 - val_accuracy: 0.4848
# Epoch 9/1000
# 500/500 [==============================] - 23s 47ms/step - loss: 0.1690 - accuracy: 0.6342 - val_loss: 0.1658 - val_accuracy: 0.6404
# Epoch 10/1000
# 500/500 [==============================] - 23s 47ms/step - loss: 0.1652 - accuracy: 0.6440 - val_loss: 0.2462 - val_accuracy: 0.5121
# Epoch 11/1000
# 500/500 [==============================] - 23s 46ms/step - loss: 0.1620 - accuracy: 0.6503 - val_loss: 0.1591 - val_accuracy: 0.6589
# Epoch 12/1000
# 500/500 [==============================] - 22s 44ms/step - loss: 0.1583 - accuracy: 0.6619 - val_loss: 0.1598 - val_accuracy: 0.6539
# Epoch 13/1000
# 500/500 [==============================] - 22s 44ms/step - loss: 0.1565 - accuracy: 0.6653 - val_loss: 0.1638 - val_accuracy: 0.6438
# Epoch 14/1000
# 500/500 [==============================] - 23s 45ms/step - loss: 0.1530 - accuracy: 0.6756 - val_loss: 0.1580 - val_accuracy: 0.6639
# Epoch 15/1000
# 500/500 [==============================] - 21s 42ms/step - loss: 0.1520 - accuracy: 0.6770 - val_loss: 0.1811 - val_accuracy: 0.5978
# Epoch 16/1000
# 500/500 [==============================] - 23s 47ms/step - loss: 0.1488 - accuracy: 0.6854 - val_loss: 0.1831 - val_accuracy: 0.6011
# Epoch 17/1000
# 500/500 [==============================] - 23s 47ms/step - loss: 0.1483 - accuracy: 0.6841 - val_loss: 0.2232 - val_accuracy: 0.5102
# Epoch 18/1000
# 500/500 [==============================] - 23s 46ms/step - loss: 0.1457 - accuracy: 0.6932 - val_loss: 0.1576 - val_accuracy: 0.6578
# Epoch 19/1000
# 500/500 [==============================] - 23s 45ms/step - loss: 0.1444 - accuracy: 0.6957 - val_loss: 0.1656 - val_accuracy: 0.6436
# Epoch 20/1000
# 500/500 [==============================] - 23s 46ms/step - loss: 0.1425 - accuracy: 0.6999 - val_loss: 0.1521 - val_accuracy: 0.6706
# Epoch 21/1000
# 500/500 [==============================] - 23s 45ms/step - loss: 0.1408 - accuracy: 0.7038 - val_loss: 0.1626 - val_accuracy: 0.6510
# Epoch 22/1000
# 500/500 [==============================] - 22s 44ms/step - loss: 0.1398 - accuracy: 0.7072 - val_loss: 0.1513 - val_accuracy: 0.6755
# Epoch 23/1000
# 500/500 [==============================] - 22s 43ms/step - loss: 0.1389 - accuracy: 0.7078 - val_loss: 0.1483 - val_accuracy: 0.6859
# Epoch 24/1000
# 500/500 [==============================] - 24s 48ms/step - loss: 0.1378 - accuracy: 0.7104 - val_loss: 0.1729 - val_accuracy: 0.6269
# Epoch 25/1000
# 500/500 [==============================] - 26s 52ms/step - loss: 0.1365 - accuracy: 0.7141 - val_loss: 0.1488 - val_accuracy: 0.6811
# Epoch 26/1000
# 500/500 [==============================] - 26s 51ms/step - loss: 0.1357 - accuracy: 0.7184 - val_loss: 0.2146 - val_accuracy: 0.5840
# Epoch 27/1000
# 500/500 [==============================] - 26s 51ms/step - loss: 0.1342 - accuracy: 0.7186 - val_loss: 0.1564 - val_accuracy: 0.6633
# Epoch 28/1000
# 500/500 [==============================] - 23s 46ms/step - loss: 0.1330 - accuracy: 0.7216 - val_loss: 0.2002 - val_accuracy: 0.5824
# Epoch 29/1000
# 500/500 [==============================] - 23s 46ms/step - loss: 0.1325 - accuracy: 0.7245 - val_loss: 0.1338 - val_accuracy: 0.7177
# Epoch 30/1000
# 500/500 [==============================] - 23s 46ms/step - loss: 0.1315 - accuracy: 0.7260 - val_loss: 0.1445 - val_accuracy: 0.6920
# Epoch 31/1000
# 500/500 [==============================] - 22s 45ms/step - loss: 0.1308 - accuracy: 0.7281 - val_loss: 0.1375 - val_accuracy: 0.7081
# Epoch 32/1000
# 500/500 [==============================] - 23s 46ms/step - loss: 0.1292 - accuracy: 0.7321 - val_loss: 0.1528 - val_accuracy: 0.6716
# Epoch 33/1000
# 500/500 [==============================] - 26s 52ms/step - loss: 0.1279 - accuracy: 0.7349 - val_loss: 0.1325 - val_accuracy: 0.7232
# Epoch 34/1000
# 500/500 [==============================] - 28s 55ms/step - loss: 0.1282 - accuracy: 0.7323 - val_loss: 0.1391 - val_accuracy: 0.7085
# Epoch 35/1000
# 500/500 [==============================] - 25s 51ms/step - loss: 0.1267 - accuracy: 0.7372 - val_loss: 0.1521 - val_accuracy: 0.6839
# Epoch 36/1000
# 500/500 [==============================] - 27s 53ms/step - loss: 0.1268 - accuracy: 0.7373 - val_loss: 0.1667 - val_accuracy: 0.6389
# Epoch 37/1000
# 500/500 [==============================] - 27s 54ms/step - loss: 0.1266 - accuracy: 0.7371 - val_loss: 0.1428 - val_accuracy: 0.6978
# Epoch 38/1000
# 500/500 [==============================] - 27s 54ms/step - loss: 0.1255 - accuracy: 0.7399 - val_loss: 0.1408 - val_accuracy: 0.7009
# Epoch 39/1000
# 500/500 [==============================] - 25s 50ms/step - loss: 0.1238 - accuracy: 0.7460 - val_loss: 0.1284 - val_accuracy: 0.7335
# Epoch 40/1000
# 500/500 [==============================] - 26s 52ms/step - loss: 0.1224 - accuracy: 0.7463 - val_loss: 0.1422 - val_accuracy: 0.6953
# Epoch 41/1000
# 500/500 [==============================] - 27s 54ms/step - loss: 0.1228 - accuracy: 0.7478 - val_loss: 0.1339 - val_accuracy: 0.7212
# Epoch 42/1000
# 500/500 [==============================] - 26s 51ms/step - loss: 0.1225 - accuracy: 0.7475 - val_loss: 0.1379 - val_accuracy: 0.7096
# Epoch 43/1000
# 500/500 [==============================] - 23s 47ms/step - loss: 0.1208 - accuracy: 0.7503 - val_loss: 0.1328 - val_accuracy: 0.7172
# Epoch 44/1000
# 500/500 [==============================] - 24s 48ms/step - loss: 0.1214 - accuracy: 0.7510 - val_loss: 0.1295 - val_accuracy: 0.7272
# Epoch 45/1000
# 500/500 [==============================] - 24s 48ms/step - loss: 0.1203 - accuracy: 0.7535 - val_loss: 0.1922 - val_accuracy: 0.6168
# Epoch 46/1000
# 500/500 [==============================] - 24s 48ms/step - loss: 0.1201 - accuracy: 0.7543 - val_loss: 0.1818 - val_accuracy: 0.6344
# Epoch 47/1000
# 500/500 [==============================] - 24s 49ms/step - loss: 0.1191 - accuracy: 0.7558 - val_loss: 0.1320 - val_accuracy: 0.7185
# Epoch 48/1000
# 500/500 [==============================] - 25s 49ms/step - loss: 0.1176 - accuracy: 0.7596 - val_loss: 0.1363 - val_accuracy: 0.7127
# Epoch 49/1000
# 500/500 [==============================] - ETA: 0s - loss: 0.1179 - accuracy: 0.7589
# Epoch 00049: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 500/500 [==============================] - 26s 53ms/step - loss: 0.1179 - accuracy: 0.7589 - val_loss: 0.1405 - val_accuracy: 0.6958
# Epoch 50/1000
# 500/500 [==============================] - 25s 50ms/step - loss: 0.1123 - accuracy: 0.7702 - val_loss: 0.1239 - val_accuracy: 0.7424
# Epoch 51/1000
# 500/500 [==============================] - 22s 44ms/step - loss: 0.1089 - accuracy: 0.7786 - val_loss: 0.1255 - val_accuracy: 0.7379
# Epoch 52/1000
# 500/500 [==============================] - 24s 47ms/step - loss: 0.1089 - accuracy: 0.7779 - val_loss: 0.1243 - val_accuracy: 0.7435
# Epoch 53/1000
# 500/500 [==============================] - 24s 49ms/step - loss: 0.1082 - accuracy: 0.7793 - val_loss: 0.1239 - val_accuracy: 0.7413
# Epoch 54/1000
# 500/500 [==============================] - 22s 45ms/step - loss: 0.1069 - accuracy: 0.7820 - val_loss: 0.1242 - val_accuracy: 0.7391
# Epoch 55/1000
# 500/500 [==============================] - 21s 43ms/step - loss: 0.1067 - accuracy: 0.7827 - val_loss: 0.1244 - val_accuracy: 0.7404
# Epoch 56/1000
# 500/500 [==============================] - 20s 39ms/step - loss: 0.1071 - accuracy: 0.7836 - val_loss: 0.1291 - val_accuracy: 0.7318
# Epoch 57/1000
# 500/500 [==============================] - 21s 42ms/step - loss: 0.1057 - accuracy: 0.7859 - val_loss: 0.1294 - val_accuracy: 0.7317
# Epoch 58/1000
# 500/500 [==============================] - 21s 42ms/step - loss: 0.1055 - accuracy: 0.7859 - val_loss: 0.1241 - val_accuracy: 0.7375
# Epoch 59/1000
# 500/500 [==============================] - 21s 42ms/step - loss: 0.1050 - accuracy: 0.7868 - val_loss: 0.1203 - val_accuracy: 0.7496
# Epoch 60/1000
# 500/500 [==============================] - 21s 42ms/step - loss: 0.1041 - accuracy: 0.7898 - val_loss: 0.1215 - val_accuracy: 0.7502
# Epoch 61/1000
# 500/500 [==============================] - 23s 45ms/step - loss: 0.1051 - accuracy: 0.7889 - val_loss: 0.1206 - val_accuracy: 0.7486
# Epoch 62/1000
# 500/500 [==============================] - 24s 49ms/step - loss: 0.1037 - accuracy: 0.7912 - val_loss: 0.1269 - val_accuracy: 0.7409
# Epoch 63/1000
# 500/500 [==============================] - 25s 50ms/step - loss: 0.1037 - accuracy: 0.7912 - val_loss: 0.1220 - val_accuracy: 0.7480
# Epoch 64/1000
# 500/500 [==============================] - 24s 49ms/step - loss: 0.1038 - accuracy: 0.7911 - val_loss: 0.1211 - val_accuracy: 0.7534
# Epoch 65/1000
# 500/500 [==============================] - 25s 49ms/step - loss: 0.1033 - accuracy: 0.7916 - val_loss: 0.1336 - val_accuracy: 0.7232
# Epoch 66/1000
# 500/500 [==============================] - 23s 46ms/step - loss: 0.1034 - accuracy: 0.7917 - val_loss: 0.1289 - val_accuracy: 0.7326
# Epoch 67/1000
# 500/500 [==============================] - 24s 47ms/step - loss: 0.1028 - accuracy: 0.7926 - val_loss: 0.1209 - val_accuracy: 0.7528
# Epoch 68/1000
# 500/500 [==============================] - 25s 50ms/step - loss: 0.1021 - accuracy: 0.7941 - val_loss: 0.1342 - val_accuracy: 0.7210
# Epoch 69/1000
# 500/500 [==============================] - ETA: 0s - loss: 0.1030 - accuracy: 0.7920
# Epoch 00069: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 500/500 [==============================] - 25s 49ms/step - loss: 0.1030 - accuracy: 0.7920 - val_loss: 0.1209 - val_accuracy: 0.7528
# Epoch 70/1000
# 500/500 [==============================] - 22s 45ms/step - loss: 0.0990 - accuracy: 0.8033 - val_loss: 0.1224 - val_accuracy: 0.7499
# Epoch 71/1000
# 500/500 [==============================] - 23s 45ms/step - loss: 0.0978 - accuracy: 0.8042 - val_loss: 0.1198 - val_accuracy: 0.7543
# Epoch 72/1000
# 500/500 [==============================] - 23s 46ms/step - loss: 0.0983 - accuracy: 0.8031 - val_loss: 0.1194 - val_accuracy: 0.7530
# Epoch 73/1000
# 500/500 [==============================] - 22s 44ms/step - loss: 0.0974 - accuracy: 0.8049 - val_loss: 0.1223 - val_accuracy: 0.7478
# Epoch 74/1000
# 500/500 [==============================] - 23s 47ms/step - loss: 0.0977 - accuracy: 0.8023 - val_loss: 0.1175 - val_accuracy: 0.7601
# Epoch 75/1000
# 500/500 [==============================] - 25s 49ms/step - loss: 0.0973 - accuracy: 0.8071 - val_loss: 0.1206 - val_accuracy: 0.7540
# Epoch 76/1000
# 500/500 [==============================] - 24s 48ms/step - loss: 0.0970 - accuracy: 0.8055 - val_loss: 0.1318 - val_accuracy: 0.7299
# Epoch 77/1000
# 500/500 [==============================] - 23s 46ms/step - loss: 0.0967 - accuracy: 0.8069 - val_loss: 0.1234 - val_accuracy: 0.7443
# Epoch 78/1000
# 500/500 [==============================] - 25s 51ms/step - loss: 0.0962 - accuracy: 0.8078 - val_loss: 0.1219 - val_accuracy: 0.7483
# Epoch 79/1000
# 500/500 [==============================] - 24s 47ms/step - loss: 0.0959 - accuracy: 0.8076 - val_loss: 0.1203 - val_accuracy: 0.7535
# Epoch 80/1000
# 500/500 [==============================] - 22s 43ms/step - loss: 0.0960 - accuracy: 0.8087 - val_loss: 0.1184 - val_accuracy: 0.7594
# Epoch 81/1000
# 500/500 [==============================] - 23s 47ms/step - loss: 0.0961 - accuracy: 0.8080 - val_loss: 0.1264 - val_accuracy: 0.7372
# Epoch 82/1000
# 500/500 [==============================] - 23s 46ms/step - loss: 0.0949 - accuracy: 0.8108 - val_loss: 0.1212 - val_accuracy: 0.7542
# Epoch 83/1000
# 500/500 [==============================] - 24s 48ms/step - loss: 0.0953 - accuracy: 0.8106 - val_loss: 0.1201 - val_accuracy: 0.7520
# Epoch 84/1000
# 499/500 [============================>.] - ETA: 0s - loss: 0.0952 - accuracy: 0.8114
# Epoch 00084: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 500/500 [==============================] - 22s 44ms/step - loss: 0.0951 - accuracy: 0.8115 - val_loss: 0.1183 - val_accuracy: 0.7573
# Epoch 85/1000
# 500/500 [==============================] - 23s 46ms/step - loss: 0.0931 - accuracy: 0.8149 - val_loss: 0.1179 - val_accuracy: 0.7603
# Epoch 86/1000
# 500/500 [==============================] - 25s 49ms/step - loss: 0.0941 - accuracy: 0.8115 - val_loss: 0.1181 - val_accuracy: 0.7632
# Epoch 87/1000
# 500/500 [==============================] - 23s 46ms/step - loss: 0.0936 - accuracy: 0.8147 - val_loss: 0.1206 - val_accuracy: 0.7555
# Epoch 88/1000
# 500/500 [==============================] - 23s 45ms/step - loss: 0.0928 - accuracy: 0.8138 - val_loss: 0.1183 - val_accuracy: 0.7582
# Epoch 89/1000
# 500/500 [==============================] - 22s 45ms/step - loss: 0.0928 - accuracy: 0.8149 - val_loss: 0.1174 - val_accuracy: 0.7619
# Epoch 90/1000
# 500/500 [==============================] - 24s 48ms/step - loss: 0.0937 - accuracy: 0.8129 - val_loss: 0.1200 - val_accuracy: 0.7563
# Epoch 91/1000
# 500/500 [==============================] - 25s 51ms/step - loss: 0.0926 - accuracy: 0.8153 - val_loss: 0.1179 - val_accuracy: 0.7588
# Epoch 92/1000
# 500/500 [==============================] - 27s 54ms/step - loss: 0.0917 - accuracy: 0.8163 - val_loss: 0.1191 - val_accuracy: 0.7567
# Epoch 93/1000
# 500/500 [==============================] - 27s 54ms/step - loss: 0.0923 - accuracy: 0.8167 - val_loss: 0.1207 - val_accuracy: 0.7534
# Epoch 94/1000
# 500/500 [==============================] - ETA: 0s - loss: 0.0930 - accuracy: 0.8147
# Epoch 00094: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 500/500 [==============================] - 24s 48ms/step - loss: 0.0930 - accuracy: 0.8147 - val_loss: 0.1179 - val_accuracy: 0.7605
# Epoch 95/1000
# 500/500 [==============================] - 28s 56ms/step - loss: 0.0914 - accuracy: 0.8172 - val_loss: 0.1170 - val_accuracy: 0.7624
# Epoch 96/1000
# 500/500 [==============================] - 27s 54ms/step - loss: 0.0914 - accuracy: 0.8200 - val_loss: 0.1172 - val_accuracy: 0.7617
# Epoch 97/1000
# 500/500 [==============================] - 25s 51ms/step - loss: 0.0921 - accuracy: 0.8166 - val_loss: 0.1170 - val_accuracy: 0.7618
# Epoch 98/1000
# 500/500 [==============================] - 27s 53ms/step - loss: 0.0907 - accuracy: 0.8178 - val_loss: 0.1174 - val_accuracy: 0.7585
# Epoch 99/1000
# 500/500 [==============================] - 27s 54ms/step - loss: 0.0910 - accuracy: 0.8204 - val_loss: 0.1168 - val_accuracy: 0.7614
# Epoch 100/1000
# 500/500 [==============================] - 27s 53ms/step - loss: 0.0908 - accuracy: 0.8189 - val_loss: 0.1170 - val_accuracy: 0.7617
# Epoch 101/1000
# 500/500 [==============================] - 27s 54ms/step - loss: 0.0906 - accuracy: 0.8197 - val_loss: 0.1174 - val_accuracy: 0.7626
# Epoch 102/1000
# 500/500 [==============================] - 28s 55ms/step - loss: 0.0907 - accuracy: 0.8196 - val_loss: 0.1171 - val_accuracy: 0.7607
# Epoch 103/1000
# 500/500 [==============================] - 27s 54ms/step - loss: 0.0914 - accuracy: 0.8196 - val_loss: 0.1179 - val_accuracy: 0.7591
# Epoch 104/1000
# 500/500 [==============================] - 26s 53ms/step - loss: 0.0905 - accuracy: 0.8214 - val_loss: 0.1172 - val_accuracy: 0.7590
# Epoch 105/1000
# 500/500 [==============================] - 25s 50ms/step - loss: 0.0911 - accuracy: 0.8190 - val_loss: 0.1182 - val_accuracy: 0.7575
# Epoch 106/1000
# 500/500 [==============================] - 26s 52ms/step - loss: 0.0902 - accuracy: 0.8209 - val_loss: 0.1170 - val_accuracy: 0.7624
# Epoch 107/1000
# 500/500 [==============================] - 23s 46ms/step - loss: 0.0914 - accuracy: 0.8187 - val_loss: 0.1175 - val_accuracy: 0.7602
# Epoch 108/1000
# 500/500 [==============================] - 26s 51ms/step - loss: 0.0907 - accuracy: 0.8202 - val_loss: 0.1176 - val_accuracy: 0.7609
# Epoch 109/1000
# 500/500 [==============================] - ETA: 0s - loss: 0.0906 - accuracy: 0.8196
# Epoch 00109: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# 500/500 [==============================] - 23s 45ms/step - loss: 0.0906 - accuracy: 0.8196 - val_loss: 0.1176 - val_accuracy: 0.7614
# Epoch 110/1000
# 500/500 [==============================] - 23s 46ms/step - loss: 0.0906 - accuracy: 0.8193 - val_loss: 0.1166 - val_accuracy: 0.7627
# Epoch 111/1000
# 500/500 [==============================] - 21s 41ms/step - loss: 0.0903 - accuracy: 0.8203 - val_loss: 0.1167 - val_accuracy: 0.7644
# Epoch 112/1000
# 500/500 [==============================] - 20s 40ms/step - loss: 0.0894 - accuracy: 0.8229 - val_loss: 0.1175 - val_accuracy: 0.7629
# Epoch 113/1000
# 500/500 [==============================] - 22s 43ms/step - loss: 0.0890 - accuracy: 0.8243 - val_loss: 0.1168 - val_accuracy: 0.7634
# Epoch 114/1000
# 500/500 [==============================] - 23s 46ms/step - loss: 0.0900 - accuracy: 0.8209 - val_loss: 0.1168 - val_accuracy: 0.7631
# Epoch 115/1000
# 500/500 [==============================] - 24s 48ms/step - loss: 0.0900 - accuracy: 0.8207 - val_loss: 0.1176 - val_accuracy: 0.7610
# Epoch 116/1000
# 500/500 [==============================] - 23s 46ms/step - loss: 0.0894 - accuracy: 0.8240 - val_loss: 0.1173 - val_accuracy: 0.7616
# Epoch 117/1000
# 500/500 [==============================] - 20s 40ms/step - loss: 0.0888 - accuracy: 0.8238 - val_loss: 0.1176 - val_accuracy: 0.7625
# Epoch 118/1000
# 500/500 [==============================] - 21s 41ms/step - loss: 0.0902 - accuracy: 0.8208 - val_loss: 0.1167 - val_accuracy: 0.7637
# Epoch 119/1000
# 500/500 [==============================] - 23s 46ms/step - loss: 0.0897 - accuracy: 0.8223 - val_loss: 0.1168 - val_accuracy: 0.7637
# Epoch 120/1000
# 500/500 [==============================] - ETA: 0s - loss: 0.0901 - accuracy: 0.8207
# Epoch 00120: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# 500/500 [==============================] - 22s 43ms/step - loss: 0.0901 - accuracy: 0.8207 - val_loss: 0.1171 - val_accuracy: 0.7636
# Epoch 121/1000
# 500/500 [==============================] - 23s 45ms/step - loss: 0.0898 - accuracy: 0.8224 - val_loss: 0.1170 - val_accuracy: 0.7628
# Epoch 122/1000
# 500/500 [==============================] - 22s 43ms/step - loss: 0.0887 - accuracy: 0.8230 - val_loss: 0.1167 - val_accuracy: 0.7624
# Epoch 123/1000
# 500/500 [==============================] - 21s 43ms/step - loss: 0.0889 - accuracy: 0.8228 - val_loss: 0.1169 - val_accuracy: 0.7627
# Epoch 124/1000
# 500/500 [==============================] - 21s 42ms/step - loss: 0.0899 - accuracy: 0.8234 - val_loss: 0.1168 - val_accuracy: 0.7631
# Epoch 125/1000
# 500/500 [==============================] - 21s 41ms/step - loss: 0.0899 - accuracy: 0.8225 - val_loss: 0.1168 - val_accuracy: 0.7625
# Epoch 126/1000
# 500/500 [==============================] - 21s 42ms/step - loss: 0.0891 - accuracy: 0.8241 - val_loss: 0.1167 - val_accuracy: 0.7630
# Epoch 127/1000
# 500/500 [==============================] - 21s 42ms/step - loss: 0.0891 - accuracy: 0.8237 - val_loss: 0.1169 - val_accuracy: 0.7629
# Epoch 128/1000
# 500/500 [==============================] - 22s 45ms/step - loss: 0.0885 - accuracy: 0.8250 - val_loss: 0.1169 - val_accuracy: 0.7625
# Epoch 129/1000
# 500/500 [==============================] - 23s 45ms/step - loss: 0.0896 - accuracy: 0.8223 - val_loss: 0.1167 - val_accuracy: 0.7629
# Epoch 130/1000
# 500/500 [==============================] - ETA: 0s - loss: 0.0888 - accuracy: 0.8251
# Epoch 00130: ReduceLROnPlateau reducing learning rate to 7.812500371073838e-06.
# 500/500 [==============================] - 23s 46ms/step - loss: 0.0888 - accuracy: 0.8251 - val_loss: 0.1171 - val_accuracy: 0.7618
# Epoch 131/1000
# 500/500 [==============================] - 22s 45ms/step - loss: 0.0895 - accuracy: 0.8234 - val_loss: 0.1169 - val_accuracy: 0.7624
# Epoch 132/1000
# 500/500 [==============================] - 22s 45ms/step - loss: 0.0884 - accuracy: 0.8265 - val_loss: 0.1167 - val_accuracy: 0.7637
# Epoch 133/1000
# 500/500 [==============================] - 21s 43ms/step - loss: 0.0893 - accuracy: 0.8241 - val_loss: 0.1168 - val_accuracy: 0.7631
# Epoch 134/1000
# 500/500 [==============================] - 21s 42ms/step - loss: 0.0897 - accuracy: 0.8204 - val_loss: 0.1169 - val_accuracy: 0.7640
# Epoch 135/1000
# 500/500 [==============================] - 21s 42ms/step - loss: 0.0894 - accuracy: 0.8221 - val_loss: 0.1169 - val_accuracy: 0.7639
# Epoch 136/1000
# 500/500 [==============================] - 23s 45ms/step - loss: 0.0891 - accuracy: 0.8228 - val_loss: 0.1167 - val_accuracy: 0.7632
# Epoch 137/1000
# 500/500 [==============================] - 24s 48ms/step - loss: 0.0892 - accuracy: 0.8234 - val_loss: 0.1169 - val_accuracy: 0.7621
# Epoch 138/1000
# 500/500 [==============================] - 24s 47ms/step - loss: 0.0888 - accuracy: 0.8238 - val_loss: 0.1167 - val_accuracy: 0.7641
# Epoch 139/1000
# 500/500 [==============================] - 23s 47ms/step - loss: 0.0900 - accuracy: 0.8238 - val_loss: 0.1167 - val_accuracy: 0.7626
# Epoch 140/1000
# 499/500 [============================>.] - ETA: 0s - loss: 0.0890 - accuracy: 0.8228
# Epoch 00140: ReduceLROnPlateau reducing learning rate to 3.906250185536919e-06.
# 500/500 [==============================] - 23s 45ms/step - loss: 0.0890 - accuracy: 0.8230 - val_loss: 0.1169 - val_accuracy: 0.7631
# Epoch 141/1000
# 500/500 [==============================] - 25s 50ms/step - loss: 0.0891 - accuracy: 0.8227 - val_loss: 0.1168 - val_accuracy: 0.7625
# Epoch 142/1000
# 500/500 [==============================] - 23s 46ms/step - loss: 0.0883 - accuracy: 0.8235 - val_loss: 0.1168 - val_accuracy: 0.7626
# Epoch 143/1000
# 500/500 [==============================] - 23s 45ms/step - loss: 0.0882 - accuracy: 0.8242 - val_loss: 0.1168 - val_accuracy: 0.7626
# Epoch 144/1000
# 500/500 [==============================] - 24s 47ms/step - loss: 0.0885 - accuracy: 0.8247 - val_loss: 0.1168 - val_accuracy: 0.7628
# Epoch 145/1000
# 500/500 [==============================] - ETA: 0s - loss: 0.0889 - accuracy: 0.8240Restoring model weights from the end of the best epoch.
# 500/500 [==============================] - 24s 48ms/step - loss: 0.0889 - accuracy: 0.8240 - val_loss: 0.1167 - val_accuracy: 0.7628
# Epoch 00145: early stopping

# %%
import matplotlib.pyplot as plt

fig = plt.figure(figsize=(10,6))
plt.plot(hist.history['loss'], color='#785ef0')
plt.plot(hist.history['val_loss'], color='#dc267f')
plt.title('Model Loss Progress')
plt.ylabel('Binary Cross-Entropy Loss')
plt.xlabel('Epoch')
plt.legend(['Training Set', 'Test Set'], loc='upper right')
plt.savefig('ch.12.cnn.cifar10.loss.png', dpi=350, bbox_inches='tight')
plt.show()

# %%
from sklearn.preprocessing import MinMaxScaler

cnnl1 = classifier.layers[1].name   # get the name of the first conv layer
W = classifier.get_layer(name=cnnl1).get_weights()[0]   #get the filters
wshape = W.shape  #save the original shape

# this part will scale to [0, 1] for visualization purposes
scaler = MinMaxScaler()
scaler.fit(W.reshape(-1,1))
W = scaler.transform(W.reshape(-1,1))
W = W.reshape(wshape)

# since there are 64 filters, we will display them 8x8
fig, axs = plt.subplots(8,8, figsize=(24,24))
fig.subplots_adjust(hspace = .25, wspace=.001)
axs = axs.ravel()
for i in range(W.shape[-1]):
  # we reshape to a 3D (RGB) image shape and display
  h = np.reshape(W[:,:,:,i], (9,9,3))
  axs[i].imshow(h)
  axs[i].set_title('Filter ' + str(i))    
plt.savefig("ch.12.cnn.full.filters.png", bbox_inches='tight', dpi=350)

# %%
cnnl1 = classifier.layers[1].name   # get the name of the first conv layer
W = classifier.get_layer(name=cnnl1).get_weights()[0]
plt.hist(W.ravel(), bins=100)
print(np.min(W),np.max(W))
# Out:
# -0.6532136 0.6167374

# %%
classifier = None

# %%
# Importing the Keras libraries and packages
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Activation
from tensorflow.keras.layers import Input, Dense, Dropout, BatchNormalization
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import RMSprop, Adam

# dimensionality of input and latent encoded representations
inpt_dim = (32, 32, 3)

inpt_img = Input(shape=inpt_dim)

# Block 1
cl1 = Conv2D(64, (9, 9), strides=(2, 2),activation='relu', input_shape = inpt_dim)(inpt_img)
bnl2 = BatchNormalization()(cl1)
# afl3 = Activation('relu')(bnl2)
pl4 = MaxPooling2D(pool_size = (2, 2))(bnl2)

# Adding a second convolutional layer
cl5 = Conv2D(128, (3, 3), strides=(1, 1), activation='relu')(pl4)
bnl6 = BatchNormalization()(cl5)
# afl7 = Activation('relu')(bnl6)
pl8 = MaxPooling2D(pool_size = (2, 2))(bnl6)
bnl9 = BatchNormalization()(pl8)

# Step 3 - Flattening
fl10 = Flatten()(bnl9)

# Step 4 - Full connection
dol11 = Dropout(0.5)(fl10)
dl12 = Dense(units = 256, activation = 'relu')(dol11)
dol13 = Dropout(0.2)(dl12)
dl14 = Dense(units = 64, activation = 'relu')(dol13)
dol15 = Dropout(0.1)(dl14)
output = Dense(units = 10, activation = 'sigmoid')(dol15)

classifier = Model(inpt_img, output)

# Compiling the CNN
opt = RMSprop(learning_rate=0.001)
# opt = Adam(learning_rate=0.01)

classifier.compile(optimizer = opt, loss = 'binary_crossentropy', 
                   metrics = ['accuracy'])

print(classifier.summary())
# Out:
# Model: "functional_11"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_6 (InputLayer)         [(None, 32, 32, 3)]       0
# _________________________________________________________________
# conv2d_10 (Conv2D)           (None, 12, 12, 64)        15616
# _________________________________________________________________
# batch_normalization_15 (Batc (None, 12, 12, 64)        256
# _________________________________________________________________
# max_pooling2d_10 (MaxPooling (None, 6, 6, 64)          0
# _________________________________________________________________
# conv2d_11 (Conv2D)           (None, 4, 4, 128)         73856
# _________________________________________________________________
# batch_normalization_16 (Batc (None, 4, 4, 128)         512
# _________________________________________________________________
# max_pooling2d_11 (MaxPooling (None, 2, 2, 128)         0
# _________________________________________________________________
# batch_normalization_17 (Batc (None, 2, 2, 128)         512
# _________________________________________________________________
# flatten_5 (Flatten)          (None, 512)               0
# _________________________________________________________________
# dropout_15 (Dropout)         (None, 512)               0
# _________________________________________________________________
# dense_15 (Dense)             (None, 256)               131328
# _________________________________________________________________
# dropout_16 (Dropout)         (None, 256)               0
# _________________________________________________________________
# dense_16 (Dense)             (None, 64)                16448
# _________________________________________________________________
# dropout_17 (Dropout)         (None, 64)                0
# _________________________________________________________________
# dense_17 (Dense)             (None, 10)                650
# =================================================================
# Total params: 239,178
# Trainable params: 238,538
# Non-trainable params: 640
# _________________________________________________________________
# None

# %%
gabor_filters = np.empty(wshape, dtype='float32')
for k in range(wshape[3]):
  gabor_filters[:,:,0,k] = filterbank[k]
  gabor_filters[:,:,1,k] = filterbank[k]
  gabor_filters[:,:,2,k] = filterbank[k]

# %%
wshape
# Out:
# (9, 9, 3, 64)

# %%
len(filterbank)
# Out:
# 64

# %%
np.linspace(0.0, 3.14159, 8, endpoint=False)
# Out:
# array([0.        , 0.39269875, 0.7853975 , 1.17809625, 1.570795  ,
#        1.96349375, 2.3561925 , 2.74889125])

# %%
cnnl1 = classifier.layers[1].name   # get the name of the first conv layer
classifier.get_layer(name=cnnl1).set_weights([gabor_filters, np.empty((wshape[3],), dtype='float32')])   #set the filters

# %%
# Fitting the CNN to the images

from tensorflow.keras.callbacks import ReduceLROnPlateau, EarlyStopping

reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=10,  
                              min_delta=1e-4, mode='min', verbose=1)

stop_alg = EarlyStopping(monitor='val_loss', patience=35, 
                         restore_best_weights=True, verbose=1)

hist = classifier.fit(x_train, y_train, batch_size=100, epochs=1000, 
                   callbacks=[stop_alg, reduce_lr], shuffle=True, 
                   validation_data=(x_test, y_test))

classifier.save_weights("cnn.hdf5")
# Out:
# Epoch 1/1000
# 500/500 [==============================] - 26s 51ms/step - loss: 0.3468 - accuracy: 0.1000 - val_loss: 0.4442 - val_accuracy: 0.0999
# Epoch 2/1000
# 500/500 [==============================] - 26s 52ms/step - loss: 0.3305 - accuracy: 0.1025 - val_loss: 0.3798 - val_accuracy: 0.1000
# Epoch 3/1000
# 500/500 [==============================] - 26s 52ms/step - loss: 0.3287 - accuracy: 0.0987 - val_loss: 0.6087 - val_accuracy: 0.1002
# Epoch 4/1000
# 500/500 [==============================] - 24s 48ms/step - loss: 0.3279 - accuracy: 0.0980 - val_loss: 0.3813 - val_accuracy: 0.0994
# Epoch 5/1000
# 500/500 [==============================] - 24s 48ms/step - loss: 0.3273 - accuracy: 0.1000 - val_loss: 0.7128 - val_accuracy: 0.1005
# Epoch 6/1000
# 500/500 [==============================] - 24s 48ms/step - loss: 0.3269 - accuracy: 0.1036 - val_loss: 0.3894 - val_accuracy: 0.1005
# Epoch 7/1000
# 500/500 [==============================] - 25s 49ms/step - loss: 0.3269 - accuracy: 0.0999 - val_loss: 0.4671 - val_accuracy: 0.1015
# Epoch 8/1000
# 500/500 [==============================] - 26s 52ms/step - loss: 0.3269 - accuracy: 0.0999 - val_loss: 0.3321 - val_accuracy: 0.1004
# Epoch 9/1000
# 500/500 [==============================] - 26s 52ms/step - loss: 0.3266 - accuracy: 0.0980 - val_loss: 0.3381 - val_accuracy: 0.1005
# Epoch 10/1000
# 208/500 [===========>..................] - ETA: 15s - loss: 0.3266 - accuracy: 0.0986
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-38-767c9f17cc5d> in <module>
#      11 hist = classifier.fit(x_train, y_train, batch_size=100, epochs=1000,
#      12                    callbacks=[stop_alg, reduce_lr], shuffle=True,
# ---> 13                    validation_data=(x_test, y_test))
#      14
#      15 classifier.save_weights("cnn.hdf5")
#
# ~/PersonalCode/thesis/cnn-env/lib/python3.7/site-packages/tensorflow/python/keras/engine/training.py in _method_wrapper(self, *args, **kwargs)
#     106   def _method_wrapper(self, *args, **kwargs):
#     107     if not self._in_multi_worker_mode():  # pylint: disable=protected-access
# --> 108       return method(self, *args, **kwargs)
#     109
#     110     # Running inside `run_distribute_coordinator` already.
#
# ~/PersonalCode/thesis/cnn-env/lib/python3.7/site-packages/tensorflow/python/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1096                 batch_size=batch_size):
#    1097               callbacks.on_train_batch_begin(step)
# -> 1098               tmp_logs = train_function(iterator)
#    1099               if data_handler.should_sync:
#    1100                 context.async_wait()
#
# ~/PersonalCode/thesis/cnn-env/lib/python3.7/site-packages/tensorflow/python/eager/def_function.py in __call__(self, *args, **kwds)
#     778       else:
#     779         compiler = "nonXla"
# --> 780         result = self._call(*args, **kwds)
#     781
#     782       new_tracing_count = self._get_tracing_count()
#
# ~/PersonalCode/thesis/cnn-env/lib/python3.7/site-packages/tensorflow/python/eager/def_function.py in _call(self, *args, **kwds)
#     805       # In this case we have created variables on the first call, so we run the
#     806       # defunned version which is guaranteed to never create variables.
# --> 807       return self._stateless_fn(*args, **kwds)  # pylint: disable=not-callable
#     808     elif self._stateful_fn is not None:
#     809       # Release the lock early so that multiple threads can perform the call
#
# ~/PersonalCode/thesis/cnn-env/lib/python3.7/site-packages/tensorflow/python/eager/function.py in __call__(self, *args, **kwargs)
#    2827     with self._lock:
#    2828       graph_function, args, kwargs = self._maybe_define_function(args, kwargs)
# -> 2829     return graph_function._filtered_call(args, kwargs)  # pylint: disable=protected-access
#    2830
#    2831   @property
#
# ~/PersonalCode/thesis/cnn-env/lib/python3.7/site-packages/tensorflow/python/eager/function.py in _filtered_call(self, args, kwargs, cancellation_manager)
#    1846                            resource_variable_ops.BaseResourceVariable))],
#    1847         captured_inputs=self.captured_inputs,
# -> 1848         cancellation_manager=cancellation_manager)
#    1849
#    1850   def _call_flat(self, args, captured_inputs, cancellation_manager=None):
#
# ~/PersonalCode/thesis/cnn-env/lib/python3.7/site-packages/tensorflow/python/eager/function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1922       # No tape is watching; skip to running the function.
#    1923       return self._build_call_outputs(self._inference_function.call(
# -> 1924           ctx, args, cancellation_manager=cancellation_manager))
#    1925     forward_backward = self._select_forward_and_backward_functions(
#    1926         args,
#
# ~/PersonalCode/thesis/cnn-env/lib/python3.7/site-packages/tensorflow/python/eager/function.py in call(self, ctx, args, cancellation_manager)
#     548               inputs=args,
#     549               attrs=attrs,
# --> 550               ctx=ctx)
#     551         else:
#     552           outputs = execute.execute_with_cancellation(
#
# ~/PersonalCode/thesis/cnn-env/lib/python3.7/site-packages/tensorflow/python/eager/execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      58     ctx.ensure_initialized()
#      59     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
# ---> 60                                         inputs, attrs, num_outputs)
#      61   except core._NotOkStatusException as e:
#      62     if name is not None:
#
# KeyboardInterrupt:

# %%
import matplotlib.pyplot as plt

fig = plt.figure(figsize=(10,6))
plt.plot(hist.history['loss'], color='#785ef0')
plt.plot(hist.history['val_loss'], color='#dc267f')
plt.title('Model Loss Progress')
plt.ylabel('Binary Cross-Entropy Loss')
plt.xlabel('Epoch')
plt.legend(['Training Set', 'Test Set'], loc='upper right')
plt.savefig('ch.12.cnn.cifar10.loss.png', dpi=350, bbox_inches='tight')
plt.show()

# %%
from sklearn.preprocessing import MinMaxScaler

cnnl1 = classifier.layers[1].name   # get the name of the first conv layer
W = classifier.get_layer(name=cnnl1).get_weights()[0]   #get the filters
wshape = W.shape  #save the original shape

# this part will scale to [0, 1] for visualization purposes
scaler = MinMaxScaler()
scaler.fit(W.reshape(-1,1))
W = scaler.transform(W.reshape(-1,1))
W = W.reshape(wshape)

# since there are 64 filters, we will display them 8x8
fig, axs = plt.subplots(8,8, figsize=(24,24))
fig.subplots_adjust(hspace = .25, wspace=.001)
axs = axs.ravel()
for i in range(W.shape[-1]):
  # we reshape to a 3D (RGB) image shape and display
  h = np.reshape(W[:,:,:,i], (9,9,3))
  axs[i].imshow(h)
  axs[i].set_title('Filter ' + str(i))    
plt.savefig("ch.12.cnn.full.filters.png", bbox_inches='tight', dpi=350)

# %%
cnnl1 = classifier.layers[1].name   # get the name of the first conv layer
W = classifier.get_layer(name=cnnl1).get_weights()[0]
plt.hist(W.ravel(), bins=100)
print(np.min(W),np.max(W))
