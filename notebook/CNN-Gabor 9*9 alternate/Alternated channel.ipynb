# %%
from skimage.filters import gabor_kernel
from skimage import io
from skimage.transform import resize
from matplotlib import pyplot as plt 
import numpy as np

import math

# %%
def get_gabor_filters(inchannels, outchannels, kernel_size = (3,3)):
    delta = 1e-4
    
    freqs = (math.pi/2)*math.sqrt(2)**(-np.linspace(0,4, 5))
    thetas = (math.pi/8)*np.linspace(0,7, 8)
    sigmas = math.pi/(freqs)
    psis = math.pi * np.random.rand(40,)
    x0, y0 = np.ceil(np.array(kernel_size)/2)    
    
    y, x = np.meshgrid(
            np.linspace(-y0, y0 + 1, kernel_size[0]),
            np.linspace(-x0, x0 + 1, kernel_size[1]),
    )
    filterbank = []
    
    for freq in freqs:
        for theta in thetas:
            sigma = math.pi/freq
            psi = math.pi * np.random.rand(1,)[0]
            rotx = x * np.cos(theta) + y * np.sin(theta)
            roty = -x * np.sin(theta) + y * np.cos(theta)

            g = np.exp(
                -0.5 * ((rotx ** 2 + roty ** 2) / (sigma + delta) ** 2)
            )
            g = g * np.cos(freq * rotx + psi)
            g = g / (2 * math.pi * sigma ** 2)
            filterbank.append(g)
    return filterbank

filterbank = get_gabor_filters(1, 40, (9,9))

fig = plt.subplots(12, 16, figsize=(22,22))
for i,gf in enumerate(filterbank):
    plt.subplot(12, 16, i+1)
    plt.imshow(gf, cmap='gray')
    plt.axis('off')

# %%
from tensorflow.keras.datasets import cifar10
from tensorflow.keras.utils import to_categorical

# The data, split between train and test sets:
(x_train, y_train), (x_test, y_test) = cifar10.load_data()
x_train = x_train.astype('float32') / 255.0
x_test = x_test.astype('float32') / 255.0

y_train = to_categorical(y_train, 10)
y_test = to_categorical(y_test, 10)

print('x_train shape:', x_train.shape)
print('x_test shape:', x_test.shape)
# Out:
# x_train shape: (50000, 32, 32, 3)
# x_test shape: (10000, 32, 32, 3)

# %%
# Importing the Keras libraries and packages
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Activation
from tensorflow.keras.layers import Input, Dense, Dropout, BatchNormalization
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import RMSprop, Adam

# dimensionality of input and latent encoded representations
inpt_dim = (32, 32, 3)

inpt_img = Input(shape=inpt_dim)

# Block 1
cl1 = Conv2D(64, (9, 9), strides=(2, 2),activation='relu', input_shape = inpt_dim)(inpt_img)
bnl2 = BatchNormalization()(cl1)
# afl3 = Activation('relu')(bnl2)
pl4 = MaxPooling2D(pool_size = (2, 2))(bnl2)

# Adding a second convolutional layer
cl5 = Conv2D(128, (3, 3), strides=(1, 1), activation='relu')(pl4)
bnl6 = BatchNormalization()(cl5)
# afl7 = Activation('relu')(bnl6)
pl8 = MaxPooling2D(pool_size = (2, 2))(bnl6)
bnl9 = BatchNormalization()(pl8)

# Step 3 - Flattening
fl10 = Flatten()(bnl9)

# Step 4 - Full connection
dol11 = Dropout(0.5)(fl10)
dl12 = Dense(units = 256, activation = 'relu')(dol11)
dol13 = Dropout(0.2)(dl12)
dl14 = Dense(units = 64, activation = 'relu')(dol13)
dol15 = Dropout(0.1)(dl14)
output = Dense(units = 10, activation = 'sigmoid')(dol15)

classifier = Model(inpt_img, output)

# Compiling the CNN
opt = RMSprop(learning_rate=0.001)
# opt = Adam(learning_rate=0.01)

classifier.compile(optimizer = opt, loss = 'binary_crossentropy', 
                   metrics = ['accuracy'])

print(classifier.summary())
# Out:
# Model: "functional_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 32, 32, 3)]       0
# _________________________________________________________________
# conv2d (Conv2D)              (None, 12, 12, 64)        15616
# _________________________________________________________________
# batch_normalization (BatchNo (None, 12, 12, 64)        256
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 6, 6, 64)          0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 4, 4, 128)         73856
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 4, 4, 128)         512
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 2, 2, 128)         0
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 2, 2, 128)         512
# _________________________________________________________________
# flatten (Flatten)            (None, 512)               0
# _________________________________________________________________
# dropout (Dropout)            (None, 512)               0
# _________________________________________________________________
# dense (Dense)                (None, 256)               131328
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 64)                16448
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 64)                0
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                650
# =================================================================
# Total params: 239,178
# Trainable params: 238,538
# Non-trainable params: 640
# _________________________________________________________________
# None

# %%
fig = plt.subplots(12, 16, figsize=(22,22))

cnnl1 = classifier.layers[1].name   # get the name of the first conv layer
W = classifier.get_layer(name=cnnl1).get_weights()[0]   #get the filters
wshape = W.shape  #save the original shape
filter_layers = []
for i in range(64):
    for j in range(3):
        filter_layers.append(np.reshape(W[:,:,j, i], (9,9)))
for i,gf in enumerate(filter_layers):
    plt.subplot(12, 16, i+1)
    plt.imshow(gf, cmap='gray')
    plt.axis('off')

# %%
gabor_filters = W
for i, gf in enumerate(filterbank):
    for j in range(3):
        gabor_filters[:,:,j, i] = gf
# for kernel_index in range(40):
#     for channel_index in range(3):
#         gabor_filters[:,:,channel_index, kernel_index] = filterbank[kernel_index]

cnnl1 = classifier.layers[1].name   # get the name of the first conv layer
classifier.get_layer(name=cnnl1).set_weights([gabor_filters, classifier.get_layer(name=cnnl1).get_weights()[1]])
fig = plt.subplots(12, 16, figsize=(22,22))
W = classifier.get_layer(name=cnnl1).get_weights()[0]   #get the filters
filter_layers = []
for i in range(64):
    for j in range(3):
        filter_layers.append(np.reshape(W[:,:,j, i], (9,9)))
for i,gf in enumerate(filter_layers):
    plt.subplot(12, 16, i+1)
    plt.imshow(gf, cmap='gray')
    plt.axis('off')

# %%
# Fitting the CNN to the images

from tensorflow.keras.callbacks import ReduceLROnPlateau, EarlyStopping

reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=10,  
                              min_delta=1e-4, mode='min', verbose=1)

stop_alg = EarlyStopping(monitor='val_loss', patience=35, 
                         restore_best_weights=True, verbose=1)

hist = classifier.fit(x_train, y_train, batch_size=100, epochs=1000, 
                   callbacks=[stop_alg, reduce_lr], shuffle=True, 
                   validation_data=(x_test, y_test))

classifier.save_weights("cnn.hdf5")
# Out:
# Epoch 1/1000
# 500/500 [==============================] - 40s 80ms/step - loss: 0.2757 - accuracy: 0.3569 - val_loss: 0.2967 - val_accuracy: 0.2998
# Epoch 2/1000
# 500/500 [==============================] - 38s 77ms/step - loss: 0.2271 - accuracy: 0.4782 - val_loss: 0.2273 - val_accuracy: 0.4758
# Epoch 3/1000
# 500/500 [==============================] - 38s 75ms/step - loss: 0.2076 - accuracy: 0.5370 - val_loss: 0.2393 - val_accuracy: 0.4459
# Epoch 4/1000
# 500/500 [==============================] - 38s 77ms/step - loss: 0.1971 - accuracy: 0.5616 - val_loss: 0.2286 - val_accuracy: 0.4813
# Epoch 5/1000
# 500/500 [==============================] - 38s 76ms/step - loss: 0.1881 - accuracy: 0.5874 - val_loss: 0.1917 - val_accuracy: 0.5688
# Epoch 6/1000
# 500/500 [==============================] - 39s 78ms/step - loss: 0.1819 - accuracy: 0.6031 - val_loss: 0.2356 - val_accuracy: 0.5069
# Epoch 7/1000
# 500/500 [==============================] - 41s 82ms/step - loss: 0.1756 - accuracy: 0.6196 - val_loss: 0.2545 - val_accuracy: 0.4317
# Epoch 8/1000
# 500/500 [==============================] - 41s 82ms/step - loss: 0.1718 - accuracy: 0.6261 - val_loss: 0.2388 - val_accuracy: 0.4842
# Epoch 9/1000
# 500/500 [==============================] - 40s 80ms/step - loss: 0.1668 - accuracy: 0.6407 - val_loss: 0.1729 - val_accuracy: 0.6239
# Epoch 10/1000
# 500/500 [==============================] - 42s 83ms/step - loss: 0.1635 - accuracy: 0.6481 - val_loss: 0.2019 - val_accuracy: 0.5451
# Epoch 11/1000
# 500/500 [==============================] - 41s 83ms/step - loss: 0.1606 - accuracy: 0.6552 - val_loss: 0.1664 - val_accuracy: 0.6282
# Epoch 12/1000
# 500/500 [==============================] - 40s 81ms/step - loss: 0.1568 - accuracy: 0.6647 - val_loss: 0.1617 - val_accuracy: 0.6448
# Epoch 13/1000
# 500/500 [==============================] - 39s 77ms/step - loss: 0.1554 - accuracy: 0.6685 - val_loss: 0.1534 - val_accuracy: 0.6650
# Epoch 14/1000
# 500/500 [==============================] - 42s 83ms/step - loss: 0.1527 - accuracy: 0.6731 - val_loss: 0.1595 - val_accuracy: 0.6498
# Epoch 15/1000
# 500/500 [==============================] - 41s 82ms/step - loss: 0.1512 - accuracy: 0.6790 - val_loss: 0.1642 - val_accuracy: 0.6437
# Epoch 16/1000
# 500/500 [==============================] - 43s 86ms/step - loss: 0.1481 - accuracy: 0.6855 - val_loss: 0.1472 - val_accuracy: 0.6816
# Epoch 17/1000
# 500/500 [==============================] - 47s 94ms/step - loss: 0.1465 - accuracy: 0.6919 - val_loss: 0.1635 - val_accuracy: 0.6483
# Epoch 18/1000
# 500/500 [==============================] - 51s 102ms/step - loss: 0.1447 - accuracy: 0.6945 - val_loss: 0.1784 - val_accuracy: 0.6126
# Epoch 19/1000
# 500/500 [==============================] - 39s 78ms/step - loss: 0.1427 - accuracy: 0.6994 - val_loss: 0.1553 - val_accuracy: 0.6585
# Epoch 20/1000
# 500/500 [==============================] - 47s 93ms/step - loss: 0.1423 - accuracy: 0.6998 - val_loss: 0.1628 - val_accuracy: 0.6495
# Epoch 21/1000
# 500/500 [==============================] - 44s 87ms/step - loss: 0.1405 - accuracy: 0.7057 - val_loss: 0.1589 - val_accuracy: 0.6520
# Epoch 22/1000
# 500/500 [==============================] - 45s 90ms/step - loss: 0.1388 - accuracy: 0.7076 - val_loss: 0.1624 - val_accuracy: 0.6470
# Epoch 23/1000
# 500/500 [==============================] - 44s 87ms/step - loss: 0.1389 - accuracy: 0.7089 - val_loss: 0.1748 - val_accuracy: 0.6218
# Epoch 24/1000
# 500/500 [==============================] - 43s 87ms/step - loss: 0.1376 - accuracy: 0.7133 - val_loss: 0.1421 - val_accuracy: 0.7018
# Epoch 25/1000
# 500/500 [==============================] - 43s 87ms/step - loss: 0.1355 - accuracy: 0.7186 - val_loss: 0.1405 - val_accuracy: 0.7005
# Epoch 26/1000
# 500/500 [==============================] - 44s 87ms/step - loss: 0.1348 - accuracy: 0.7188 - val_loss: 0.1477 - val_accuracy: 0.6802
# Epoch 27/1000
# 500/500 [==============================] - 44s 87ms/step - loss: 0.1336 - accuracy: 0.7218 - val_loss: 0.1391 - val_accuracy: 0.7037
# Epoch 28/1000
# 500/500 [==============================] - 44s 88ms/step - loss: 0.1334 - accuracy: 0.7204 - val_loss: 0.1310 - val_accuracy: 0.7239
# Epoch 29/1000
# 500/500 [==============================] - 44s 88ms/step - loss: 0.1323 - accuracy: 0.7232 - val_loss: 0.1400 - val_accuracy: 0.6990
# Epoch 30/1000
# 500/500 [==============================] - 45s 90ms/step - loss: 0.1320 - accuracy: 0.7253 - val_loss: 0.1442 - val_accuracy: 0.6961
# Epoch 31/1000
# 500/500 [==============================] - 41s 83ms/step - loss: 0.1313 - accuracy: 0.7261 - val_loss: 0.1287 - val_accuracy: 0.7330
# Epoch 32/1000
# 500/500 [==============================] - 41s 82ms/step - loss: 0.1298 - accuracy: 0.7316 - val_loss: 0.1319 - val_accuracy: 0.7235
# Epoch 33/1000
# 500/500 [==============================] - 42s 84ms/step - loss: 0.1286 - accuracy: 0.7330 - val_loss: 0.1373 - val_accuracy: 0.7086
# Epoch 34/1000
# 500/500 [==============================] - 42s 83ms/step - loss: 0.1280 - accuracy: 0.7346 - val_loss: 0.1374 - val_accuracy: 0.7042
# Epoch 35/1000
# 500/500 [==============================] - 41s 81ms/step - loss: 0.1281 - accuracy: 0.7334 - val_loss: 0.1416 - val_accuracy: 0.6986
# Epoch 36/1000
# 500/500 [==============================] - 38s 76ms/step - loss: 0.1269 - accuracy: 0.7351 - val_loss: 0.1467 - val_accuracy: 0.6870
# Epoch 37/1000
# 500/500 [==============================] - 39s 78ms/step - loss: 0.1263 - accuracy: 0.7379 - val_loss: 0.1464 - val_accuracy: 0.6904
# Epoch 38/1000
# 500/500 [==============================] - 39s 78ms/step - loss: 0.1264 - accuracy: 0.7390 - val_loss: 0.1392 - val_accuracy: 0.7021
# Epoch 39/1000
# 500/500 [==============================] - 42s 85ms/step - loss: 0.1251 - accuracy: 0.7402 - val_loss: 0.1316 - val_accuracy: 0.7229
# Epoch 40/1000
# 500/500 [==============================] - 37s 73ms/step - loss: 0.1238 - accuracy: 0.7438 - val_loss: 0.1410 - val_accuracy: 0.6919
# Epoch 41/1000
# 500/500 [==============================] - ETA: 0s - loss: 0.1240 - accuracy: 0.7452
# Epoch 00041: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 500/500 [==============================] - 42s 83ms/step - loss: 0.1240 - accuracy: 0.7452 - val_loss: 0.1331 - val_accuracy: 0.7128
# Epoch 42/1000
# 500/500 [==============================] - 42s 83ms/step - loss: 0.1172 - accuracy: 0.7574 - val_loss: 0.1231 - val_accuracy: 0.7387
# Epoch 43/1000
# 500/500 [==============================] - 42s 84ms/step - loss: 0.1149 - accuracy: 0.7650 - val_loss: 0.1215 - val_accuracy: 0.7459
# Epoch 44/1000
# 500/500 [==============================] - 42s 84ms/step - loss: 0.1140 - accuracy: 0.7645 - val_loss: 0.1248 - val_accuracy: 0.7376
# Epoch 45/1000
# 500/500 [==============================] - 42s 83ms/step - loss: 0.1133 - accuracy: 0.7675 - val_loss: 0.1303 - val_accuracy: 0.7286
# Epoch 46/1000
# 500/500 [==============================] - 41s 81ms/step - loss: 0.1130 - accuracy: 0.7682 - val_loss: 0.1328 - val_accuracy: 0.7213
# Epoch 47/1000
# 500/500 [==============================] - 44s 88ms/step - loss: 0.1120 - accuracy: 0.7692 - val_loss: 0.1327 - val_accuracy: 0.7194
# Epoch 48/1000
# 500/500 [==============================] - 42s 84ms/step - loss: 0.1120 - accuracy: 0.7695 - val_loss: 0.1312 - val_accuracy: 0.7232
# Epoch 49/1000
# 500/500 [==============================] - 42s 83ms/step - loss: 0.1123 - accuracy: 0.7713 - val_loss: 0.1425 - val_accuracy: 0.7083
# Epoch 50/1000
# 500/500 [==============================] - 42s 83ms/step - loss: 0.1109 - accuracy: 0.7716 - val_loss: 0.1255 - val_accuracy: 0.7371
# Epoch 51/1000
# 500/500 [==============================] - 42s 85ms/step - loss: 0.1097 - accuracy: 0.7751 - val_loss: 0.1255 - val_accuracy: 0.7390
# Epoch 52/1000
# 500/500 [==============================] - 42s 84ms/step - loss: 0.1098 - accuracy: 0.7774 - val_loss: 0.1332 - val_accuracy: 0.7216
# Epoch 53/1000
# 500/500 [==============================] - ETA: 0s - loss: 0.1090 - accuracy: 0.7775
# Epoch 00053: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 500/500 [==============================] - 42s 84ms/step - loss: 0.1090 - accuracy: 0.7775 - val_loss: 0.1302 - val_accuracy: 0.7250
# Epoch 54/1000
# 500/500 [==============================] - 44s 88ms/step - loss: 0.1062 - accuracy: 0.7827 - val_loss: 0.1194 - val_accuracy: 0.7475
# Epoch 55/1000
# 500/500 [==============================] - 48s 96ms/step - loss: 0.1047 - accuracy: 0.7875 - val_loss: 0.1173 - val_accuracy: 0.7573
# Epoch 56/1000
# 500/500 [==============================] - 44s 88ms/step - loss: 0.1049 - accuracy: 0.7875 - val_loss: 0.1207 - val_accuracy: 0.7493
# Epoch 57/1000
# 500/500 [==============================] - 46s 92ms/step - loss: 0.1044 - accuracy: 0.7876 - val_loss: 0.1164 - val_accuracy: 0.7591
# Epoch 58/1000
# 500/500 [==============================] - 45s 91ms/step - loss: 0.1042 - accuracy: 0.7875 - val_loss: 0.1188 - val_accuracy: 0.7534
# Epoch 59/1000
# 500/500 [==============================] - 41s 83ms/step - loss: 0.1038 - accuracy: 0.7893 - val_loss: 0.1203 - val_accuracy: 0.7523
# Epoch 60/1000
# 500/500 [==============================] - 41s 83ms/step - loss: 0.1027 - accuracy: 0.7897 - val_loss: 0.1362 - val_accuracy: 0.7178
# Epoch 61/1000
# 500/500 [==============================] - 43s 86ms/step - loss: 0.1032 - accuracy: 0.7906 - val_loss: 0.1191 - val_accuracy: 0.7509
# Epoch 62/1000
# 500/500 [==============================] - 42s 84ms/step - loss: 0.1025 - accuracy: 0.7927 - val_loss: 0.1193 - val_accuracy: 0.7504
# Epoch 63/1000
# 500/500 [==============================] - 41s 82ms/step - loss: 0.1027 - accuracy: 0.7901 - val_loss: 0.1182 - val_accuracy: 0.7518
# Epoch 64/1000
# 500/500 [==============================] - 42s 85ms/step - loss: 0.1030 - accuracy: 0.7907 - val_loss: 0.1182 - val_accuracy: 0.7567
# Epoch 65/1000
# 500/500 [==============================] - 43s 86ms/step - loss: 0.1018 - accuracy: 0.7927 - val_loss: 0.1182 - val_accuracy: 0.7570
# Epoch 66/1000
# 500/500 [==============================] - 46s 92ms/step - loss: 0.1018 - accuracy: 0.7928 - val_loss: 0.1189 - val_accuracy: 0.7537
# Epoch 67/1000
# 500/500 [==============================] - ETA: 0s - loss: 0.1015 - accuracy: 0.7955
# Epoch 00067: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 500/500 [==============================] - 44s 87ms/step - loss: 0.1015 - accuracy: 0.7955 - val_loss: 0.1188 - val_accuracy: 0.7552
# Epoch 68/1000
# 500/500 [==============================] - 47s 94ms/step - loss: 0.0998 - accuracy: 0.7969 - val_loss: 0.1163 - val_accuracy: 0.7564
# Epoch 69/1000
# 500/500 [==============================] - 53s 105ms/step - loss: 0.0992 - accuracy: 0.7992 - val_loss: 0.1140 - val_accuracy: 0.7658
# Epoch 70/1000
# 500/500 [==============================] - 42s 83ms/step - loss: 0.0989 - accuracy: 0.8009 - val_loss: 0.1164 - val_accuracy: 0.7614
# Epoch 71/1000
# 500/500 [==============================] - 48s 96ms/step - loss: 0.0990 - accuracy: 0.8004 - val_loss: 0.1146 - val_accuracy: 0.7646
# Epoch 72/1000
# 500/500 [==============================] - 49s 98ms/step - loss: 0.0992 - accuracy: 0.7981 - val_loss: 0.1154 - val_accuracy: 0.7649
# Epoch 73/1000
# 500/500 [==============================] - 42s 84ms/step - loss: 0.0993 - accuracy: 0.7986 - val_loss: 0.1144 - val_accuracy: 0.7656
# Epoch 74/1000
# 500/500 [==============================] - 45s 90ms/step - loss: 0.0987 - accuracy: 0.8011 - val_loss: 0.1155 - val_accuracy: 0.7638
# Epoch 75/1000
# 500/500 [==============================] - 49s 98ms/step - loss: 0.0990 - accuracy: 0.8003 - val_loss: 0.1153 - val_accuracy: 0.7626
# Epoch 76/1000
# 500/500 [==============================] - 44s 88ms/step - loss: 0.0987 - accuracy: 0.8021 - val_loss: 0.1151 - val_accuracy: 0.7639
# Epoch 77/1000
# 500/500 [==============================] - 43s 86ms/step - loss: 0.0979 - accuracy: 0.8025 - val_loss: 0.1144 - val_accuracy: 0.7625
# Epoch 78/1000
# 500/500 [==============================] - 43s 85ms/step - loss: 0.0978 - accuracy: 0.8015 - val_loss: 0.1160 - val_accuracy: 0.7592
# Epoch 79/1000
# 500/500 [==============================] - ETA: 0s - loss: 0.0982 - accuracy: 0.8026
# Epoch 00079: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 500/500 [==============================] - 42s 83ms/step - loss: 0.0982 - accuracy: 0.8026 - val_loss: 0.1152 - val_accuracy: 0.7648
# Epoch 80/1000
# 500/500 [==============================] - 44s 88ms/step - loss: 0.0970 - accuracy: 0.8049 - val_loss: 0.1134 - val_accuracy: 0.7671
# Epoch 81/1000
# 500/500 [==============================] - 42s 83ms/step - loss: 0.0971 - accuracy: 0.8019 - val_loss: 0.1138 - val_accuracy: 0.7675
# Epoch 82/1000
# 500/500 [==============================] - 45s 89ms/step - loss: 0.0971 - accuracy: 0.8028 - val_loss: 0.1144 - val_accuracy: 0.7673
# Epoch 83/1000
# 500/500 [==============================] - 52s 105ms/step - loss: 0.0970 - accuracy: 0.8041 - val_loss: 0.1143 - val_accuracy: 0.7668
# Epoch 84/1000
# 500/500 [==============================] - 39s 78ms/step - loss: 0.0964 - accuracy: 0.8053 - val_loss: 0.1142 - val_accuracy: 0.7660
# Epoch 85/1000
# 500/500 [==============================] - 38s 76ms/step - loss: 0.0967 - accuracy: 0.8047 - val_loss: 0.1144 - val_accuracy: 0.7656
# Epoch 86/1000
# 500/500 [==============================] - 41s 82ms/step - loss: 0.0962 - accuracy: 0.8057 - val_loss: 0.1147 - val_accuracy: 0.7666
# Epoch 87/1000
# 500/500 [==============================] - 44s 89ms/step - loss: 0.0966 - accuracy: 0.8066 - val_loss: 0.1140 - val_accuracy: 0.7673
# Epoch 88/1000
# 500/500 [==============================] - 41s 82ms/step - loss: 0.0964 - accuracy: 0.8061 - val_loss: 0.1138 - val_accuracy: 0.7674
# Epoch 89/1000
# 500/500 [==============================] - 40s 80ms/step - loss: 0.0956 - accuracy: 0.8053 - val_loss: 0.1163 - val_accuracy: 0.7630
# Epoch 90/1000
# 500/500 [==============================] - ETA: 0s - loss: 0.0965 - accuracy: 0.8055
# Epoch 00090: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# 500/500 [==============================] - 42s 83ms/step - loss: 0.0965 - accuracy: 0.8055 - val_loss: 0.1143 - val_accuracy: 0.7669
# Epoch 91/1000
# 500/500 [==============================] - 45s 90ms/step - loss: 0.0951 - accuracy: 0.8082 - val_loss: 0.1137 - val_accuracy: 0.7663
# Epoch 92/1000
# 500/500 [==============================] - 47s 94ms/step - loss: 0.0945 - accuracy: 0.8082 - val_loss: 0.1139 - val_accuracy: 0.7668
# Epoch 93/1000
# 500/500 [==============================] - 44s 88ms/step - loss: 0.0961 - accuracy: 0.8074 - val_loss: 0.1134 - val_accuracy: 0.7658
# Epoch 94/1000
# 500/500 [==============================] - 43s 86ms/step - loss: 0.0958 - accuracy: 0.8068 - val_loss: 0.1134 - val_accuracy: 0.7666
# Epoch 95/1000
# 500/500 [==============================] - 43s 86ms/step - loss: 0.0956 - accuracy: 0.8066 - val_loss: 0.1138 - val_accuracy: 0.7667
# Epoch 96/1000
# 500/500 [==============================] - 46s 92ms/step - loss: 0.0963 - accuracy: 0.8052 - val_loss: 0.1136 - val_accuracy: 0.7671
# Epoch 97/1000
# 500/500 [==============================] - 47s 93ms/step - loss: 0.0964 - accuracy: 0.8067 - val_loss: 0.1139 - val_accuracy: 0.7664
# Epoch 98/1000
# 500/500 [==============================] - 44s 87ms/step - loss: 0.0953 - accuracy: 0.8076 - val_loss: 0.1134 - val_accuracy: 0.7665
# Epoch 99/1000
# 500/500 [==============================] - 39s 79ms/step - loss: 0.0955 - accuracy: 0.8079 - val_loss: 0.1133 - val_accuracy: 0.7682
# Epoch 100/1000
# 500/500 [==============================] - ETA: 0s - loss: 0.0959 - accuracy: 0.8074
# Epoch 00100: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# 500/500 [==============================] - 40s 80ms/step - loss: 0.0959 - accuracy: 0.8074 - val_loss: 0.1134 - val_accuracy: 0.7694
# Epoch 101/1000
# 500/500 [==============================] - 40s 80ms/step - loss: 0.0960 - accuracy: 0.8071 - val_loss: 0.1134 - val_accuracy: 0.7668
# Epoch 102/1000
# 500/500 [==============================] - 44s 88ms/step - loss: 0.0946 - accuracy: 0.8088 - val_loss: 0.1132 - val_accuracy: 0.7679
# Epoch 103/1000
# 500/500 [==============================] - 44s 88ms/step - loss: 0.0958 - accuracy: 0.8070 - val_loss: 0.1131 - val_accuracy: 0.7681
# Epoch 104/1000
# 500/500 [==============================] - 43s 86ms/step - loss: 0.0958 - accuracy: 0.8079 - val_loss: 0.1132 - val_accuracy: 0.7674
# Epoch 105/1000
# 500/500 [==============================] - 42s 84ms/step - loss: 0.0952 - accuracy: 0.8065 - val_loss: 0.1133 - val_accuracy: 0.7673
# Epoch 106/1000
# 500/500 [==============================] - 41s 82ms/step - loss: 0.0952 - accuracy: 0.8083 - val_loss: 0.1133 - val_accuracy: 0.7668
# Epoch 107/1000
# 500/500 [==============================] - 42s 84ms/step - loss: 0.0951 - accuracy: 0.8083 - val_loss: 0.1134 - val_accuracy: 0.7683
# Epoch 108/1000
# 500/500 [==============================] - 27s 55ms/step - loss: 0.0947 - accuracy: 0.8091 - val_loss: 0.1132 - val_accuracy: 0.7677
# Epoch 109/1000
# 500/500 [==============================] - 22s 44ms/step - loss: 0.0946 - accuracy: 0.8091 - val_loss: 0.1131 - val_accuracy: 0.7679
# Epoch 110/1000
# 500/500 [==============================] - 22s 44ms/step - loss: 0.0951 - accuracy: 0.8074 - val_loss: 0.1133 - val_accuracy: 0.7693
# Epoch 111/1000
# 500/500 [==============================] - 24s 48ms/step - loss: 0.0944 - accuracy: 0.8090 - val_loss: 0.1134 - val_accuracy: 0.7685
# Epoch 112/1000
# 500/500 [==============================] - 22s 44ms/step - loss: 0.0953 - accuracy: 0.8071 - val_loss: 0.1132 - val_accuracy: 0.7682
# Epoch 113/1000
# 500/500 [==============================] - ETA: 0s - loss: 0.0950 - accuracy: 0.8113
# Epoch 00113: ReduceLROnPlateau reducing learning rate to 7.812500371073838e-06.
# 500/500 [==============================] - 25s 50ms/step - loss: 0.0950 - accuracy: 0.8113 - val_loss: 0.1132 - val_accuracy: 0.7666
# Epoch 114/1000
# 500/500 [==============================] - 26s 53ms/step - loss: 0.0948 - accuracy: 0.8101 - val_loss: 0.1130 - val_accuracy: 0.7687
# Epoch 115/1000
# 500/500 [==============================] - 21s 42ms/step - loss: 0.0946 - accuracy: 0.8091 - val_loss: 0.1131 - val_accuracy: 0.7682
# Epoch 116/1000
# 500/500 [==============================] - 22s 44ms/step - loss: 0.0950 - accuracy: 0.8088 - val_loss: 0.1131 - val_accuracy: 0.7684
# Epoch 117/1000
# 500/500 [==============================] - 21s 42ms/step - loss: 0.0940 - accuracy: 0.8110 - val_loss: 0.1132 - val_accuracy: 0.7672
# Epoch 118/1000
# 500/500 [==============================] - 22s 43ms/step - loss: 0.0944 - accuracy: 0.8104 - val_loss: 0.1131 - val_accuracy: 0.7666
# Epoch 119/1000
# 500/500 [==============================] - 25s 49ms/step - loss: 0.0950 - accuracy: 0.8085 - val_loss: 0.1131 - val_accuracy: 0.7678
# Epoch 120/1000
# 500/500 [==============================] - 27s 54ms/step - loss: 0.0939 - accuracy: 0.8112 - val_loss: 0.1131 - val_accuracy: 0.7672
# Epoch 121/1000
# 500/500 [==============================] - 20s 40ms/step - loss: 0.0947 - accuracy: 0.8096 - val_loss: 0.1131 - val_accuracy: 0.7670
# Epoch 122/1000
# 500/500 [==============================] - 20s 39ms/step - loss: 0.0945 - accuracy: 0.8112 - val_loss: 0.1132 - val_accuracy: 0.7681
# Epoch 123/1000
# 500/500 [==============================] - 20s 39ms/step - loss: 0.0940 - accuracy: 0.8094 - val_loss: 0.1131 - val_accuracy: 0.7679
# Epoch 124/1000
# 500/500 [==============================] - ETA: 0s - loss: 0.0944 - accuracy: 0.8086
# Epoch 00124: ReduceLROnPlateau reducing learning rate to 3.906250185536919e-06.
# 500/500 [==============================] - 20s 40ms/step - loss: 0.0944 - accuracy: 0.8086 - val_loss: 0.1131 - val_accuracy: 0.7683
# Epoch 125/1000
# 500/500 [==============================] - 20s 39ms/step - loss: 0.0949 - accuracy: 0.8098 - val_loss: 0.1131 - val_accuracy: 0.7684
# Epoch 126/1000
# 500/500 [==============================] - 20s 39ms/step - loss: 0.0948 - accuracy: 0.8092 - val_loss: 0.1131 - val_accuracy: 0.7675
# Epoch 127/1000
# 500/500 [==============================] - 21s 42ms/step - loss: 0.0940 - accuracy: 0.8104 - val_loss: 0.1131 - val_accuracy: 0.7683
# Epoch 128/1000
# 500/500 [==============================] - 24s 48ms/step - loss: 0.0949 - accuracy: 0.8074 - val_loss: 0.1131 - val_accuracy: 0.7679
# Epoch 129/1000
# 500/500 [==============================] - 20s 41ms/step - loss: 0.0939 - accuracy: 0.8117 - val_loss: 0.1131 - val_accuracy: 0.7679
# Epoch 130/1000
# 500/500 [==============================] - 21s 42ms/step - loss: 0.0946 - accuracy: 0.8103 - val_loss: 0.1131 - val_accuracy: 0.7676
# Epoch 131/1000
# 500/500 [==============================] - 20s 39ms/step - loss: 0.0947 - accuracy: 0.8098 - val_loss: 0.1131 - val_accuracy: 0.7676
# Epoch 132/1000
# 500/500 [==============================] - 19s 38ms/step - loss: 0.0937 - accuracy: 0.8123 - val_loss: 0.1131 - val_accuracy: 0.7675
# Epoch 133/1000
# 500/500 [==============================] - 19s 38ms/step - loss: 0.0943 - accuracy: 0.8101 - val_loss: 0.1131 - val_accuracy: 0.7677
# Epoch 134/1000
# 499/500 [============================>.] - ETA: 0s - loss: 0.0952 - accuracy: 0.8091
# Epoch 00134: ReduceLROnPlateau reducing learning rate to 1.9531250927684596e-06.
# 500/500 [==============================] - 19s 38ms/step - loss: 0.0952 - accuracy: 0.8093 - val_loss: 0.1131 - val_accuracy: 0.7688
# Epoch 135/1000
# 500/500 [==============================] - 19s 38ms/step - loss: 0.0945 - accuracy: 0.8098 - val_loss: 0.1132 - val_accuracy: 0.7667
# Epoch 136/1000
# 500/500 [==============================] - 19s 38ms/step - loss: 0.0932 - accuracy: 0.8134 - val_loss: 0.1131 - val_accuracy: 0.7676
# Epoch 137/1000
# 500/500 [==============================] - 24s 48ms/step - loss: 0.0955 - accuracy: 0.8079 - val_loss: 0.1131 - val_accuracy: 0.7676
# Epoch 138/1000
# 500/500 [==============================] - 25s 50ms/step - loss: 0.0951 - accuracy: 0.8080 - val_loss: 0.1131 - val_accuracy: 0.7679
# Epoch 139/1000
# 500/500 [==============================] - 22s 44ms/step - loss: 0.0937 - accuracy: 0.8103 - val_loss: 0.1131 - val_accuracy: 0.7670
# Epoch 140/1000
# 500/500 [==============================] - 22s 43ms/step - loss: 0.0947 - accuracy: 0.8102 - val_loss: 0.1131 - val_accuracy: 0.7678
# Epoch 141/1000
# 500/500 [==============================] - 23s 47ms/step - loss: 0.0935 - accuracy: 0.8125 - val_loss: 0.1131 - val_accuracy: 0.7672
# Epoch 142/1000
# 500/500 [==============================] - 24s 48ms/step - loss: 0.0940 - accuracy: 0.8089 - val_loss: 0.1131 - val_accuracy: 0.7668
# Epoch 143/1000
# 500/500 [==============================] - 21s 42ms/step - loss: 0.0952 - accuracy: 0.8076 - val_loss: 0.1131 - val_accuracy: 0.7676
# Epoch 144/1000
# 500/500 [==============================] - ETA: 0s - loss: 0.0946 - accuracy: 0.8105
# Epoch 00144: ReduceLROnPlateau reducing learning rate to 9.765625463842298e-07.
# 500/500 [==============================] - 23s 45ms/step - loss: 0.0946 - accuracy: 0.8105 - val_loss: 0.1131 - val_accuracy: 0.7668
# Epoch 145/1000
# 500/500 [==============================] - 21s 43ms/step - loss: 0.0945 - accuracy: 0.8091 - val_loss: 0.1131 - val_accuracy: 0.7679
# Epoch 146/1000
# 500/500 [==============================] - 21s 42ms/step - loss: 0.0950 - accuracy: 0.8097 - val_loss: 0.1131 - val_accuracy: 0.7679
# Epoch 147/1000
# 500/500 [==============================] - 21s 43ms/step - loss: 0.0942 - accuracy: 0.8089 - val_loss: 0.1132 - val_accuracy: 0.7667
# Epoch 148/1000
# 500/500 [==============================] - 22s 45ms/step - loss: 0.0951 - accuracy: 0.8081 - val_loss: 0.1131 - val_accuracy: 0.7677
# Epoch 149/1000
# 500/500 [==============================] - ETA: 0s - loss: 0.0949 - accuracy: 0.8084Restoring model weights from the end of the best epoch.
# 500/500 [==============================] - 23s 45ms/step - loss: 0.0949 - accuracy: 0.8084 - val_loss: 0.1131 - val_accuracy: 0.7675
# Epoch 00149: early stopping

# %%
import matplotlib.pyplot as plt

fig = plt.figure(figsize=(10,6))
plt.plot(hist.history['loss'], color='#785ef0')
plt.plot(hist.history['val_loss'], color='#dc267f')
plt.title('Model Loss Progress')
plt.ylabel('Binary Cross-Entropy Loss')
plt.xlabel('Epoch')
plt.legend(['Training Set', 'Test Set'], loc='upper right')
plt.savefig('alternate channel-cifar-10.loss.png', dpi=350, bbox_inches='tight')
plt.show()

# %%
from sklearn.preprocessing import MinMaxScaler

cnnl1 = classifier.layers[1].name   # get the name of the first conv layer
W = classifier.get_layer(name=cnnl1).get_weights()[0]   #get the filters
wshape = W.shape  #save the original shape

# this part will scale to [0, 1] for visualization purposes
scaler = MinMaxScaler()
scaler.fit(W.reshape(-1,1))
W = scaler.transform(W.reshape(-1,1))
W = W.reshape(wshape)

# since there are 64 filters, we will display them 8x8
fig, axs = plt.subplots(8,8, figsize=(24,24))
fig.subplots_adjust(hspace = .25, wspace=.001)
axs = axs.ravel()
for i in range(W.shape[-1]):
  # we reshape to a 3D (RGB) image shape and display
  h = np.reshape(W[:,:,:,i], (9,9,3))
  axs[i].imshow(h)
  axs[i].set_title('Filter ' + str(i))    
plt.savefig("alternate channel-cifar-10.filters.png", bbox_inches='tight', dpi=350)

# %%
cnnl1 = classifier.layers[1].name   # get the name of the first conv layer
W = classifier.get_layer(name=cnnl1).get_weights()[0]
plt.hist(W.ravel(), bins=100)
print(np.min(W),np.max(W))
# Out:
# -0.57298404 0.6035549

# %%
fig = plt.subplots(12, 16, figsize=(22,22))

filter_layers = []
for i in range(64):
    for j in range(3):
        filter_layers.append(np.reshape(W[:,:,j, i], (9,9)))
for i,gf in enumerate(filter_layers):
    plt.subplot(12, 16, i+1)
    plt.imshow(gf, cmap='gray')
    plt.axis('off')
