# %% [markdown]
# <a href="https://colab.research.google.com/github/mehang/Improvised-CNN/blob/master/notebook/Cats-Vs-Dogs/Resized%20cats%20vs%20dogs/CvD_15_15_Gabor_Same.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import matplotlib.pyplot as plt
import numpy as np
import os
import PIL
import tensorflow as tf
import pandas as pd

from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import pathlib
import time

from tensorflow.keras.preprocessing.image import ImageDataGenerator, load_img
from tensorflow.keras.utils import to_categorical
from sklearn.model_selection import train_test_split

# %%
# !unzip /content/drive/My\ Drive/Mehang\ Rai/all-cats-vs-dogs-128.zip -d cats-vs-dogs

# %%
ITERATION = 1
IMAGE_WIDTH=128
IMAGE_HEIGHT=128
IMAGE_SIZE=(IMAGE_WIDTH, IMAGE_HEIGHT)
IMAGE_CHANNELS=3
RANDOM_SEED = [42,42,34,56,62,74,29,15,7,81][ITERATION-1]
BATCH_SIZE = 32
NUM_CLASSES = 2
EPOCHS = 1000
GABOR_LAYER_INDEX = 0
GABOR_WIDTH = 15
GABOR_HEIGHT = 15
GABOR_SIZE = (GABOR_WIDTH, GABOR_HEIGHT)
NUM_RECEPTIVE_FILTERS = 32

# %%
filenames = os.listdir("cats-vs-dogs/all/")
categories = []
for filename in filenames:
    category = filename.split('.')[0]
    if category == 'dog':
        categories.append(1)
    else:
        categories.append(0)

df = pd.DataFrame({
    'filename': filenames,
    'category': categories
})

df["category"] = df["category"].replace({0: 'cat', 1: 'dog'})

# %%
train_df, validate_df = train_test_split(df, test_size=0.20, random_state=RANDOM_SEED)
train_df = train_df.reset_index(drop=True)
validate_df = validate_df.reset_index(drop=True)
total_train = train_df.shape[0]
total_validate = validate_df.shape[0]

# %%
train_df['category'].value_counts().plot.bar()

# %%
validate_df['category'].value_counts().plot.bar()

# %%
train_datagen = ImageDataGenerator(
    rescale=1./255,
)
train_generator = train_datagen.flow_from_dataframe(
    train_df, 
    "cats-vs-dogs/all/", 
    x_col='filename',
    y_col='category',
    target_size=IMAGE_SIZE,
    class_mode='categorical',
    batch_size=BATCH_SIZE
)
# Out:
# Found 20000 validated image filenames belonging to 2 classes.

# %%
validation_datagen = ImageDataGenerator(rescale=1./255)
validation_generator = validation_datagen.flow_from_dataframe(
    validate_df, 
    "cats-vs-dogs/all/", 
    x_col='filename',
    y_col='category',
    target_size=IMAGE_SIZE,
    class_mode='categorical',
    batch_size=BATCH_SIZE
)
# Out:
# Found 5000 validated image filenames belonging to 2 classes.

# %%
import math

def get_gabor_filters(inchannels, outchannels, kernel_size = (3,3)):
    delta = 1e-4
    freqs = (math.pi/2)*(math.sqrt(2)**(-np.random.randint(0,5, (outchannels, inchannels))))
    thetas = (math.pi/8)*np.random.randint(0,8, (outchannels, inchannels))
    sigmas = math.pi/(freqs)
    psis = math.pi * np.random.rand(outchannels, inchannels)
    x0, y0 = np.ceil(np.array(kernel_size)/2)    
    
    y, x = np.meshgrid(
            np.linspace(-x0 + 1, x0 + 0, kernel_size[0]),
            np.linspace(-y0 + 1, y0 + 0, kernel_size[1]),
    )
    filterbank = []
    
    for i in range(outchannels):
        for j in range(inchannels):
            freq = freqs[i][j]
            theta = thetas[i][j]
            sigma = sigmas[i][j]
            psi = psis[i][j]
            
            rotx = x * np.cos(theta) + y * np.sin(theta)
            roty = -x * np.sin(theta) + y * np.cos(theta)

            g = np.exp(
                -0.5 * ((rotx ** 2 + roty ** 2) / (sigma + delta) ** 2)
            )
            g = g * np.cos(freq * rotx + psi)
#             g = g / (2 * math.pi * (sigma ** 2))
#             g = gabor_kernel(frequency=freq, bandwidth=sigma, theta=theta, offset=psi, n_stds=0).real
            filterbank.append(g)
    return filterbank

filterbank = get_gabor_filters(1, NUM_RECEPTIVE_FILTERS, GABOR_SIZE)

fig = plt.subplots(8, len(filterbank)//8, figsize=(22,22))
for i,gf in enumerate(filterbank):
    plt.subplot(8, len(filterbank)//8, i+1)
    plt.imshow(gf, cmap='gray')
    plt.axis('off')

# %%
print(train_df.shape)
print(validate_df.shape)
# Out:
# (20000, 2)
# (5000, 2)

# %%
train_generator.image_shape
# Out:
# (256, 256, 3)

# %%
NUM_CLASSES = len(train_df['category'].value_counts())
print(NUM_CLASSES)
# Out:
# 2

# %%
# Importing the Keras libraries and packages
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Activation
from tensorflow.keras.layers import Input, Dense, Dropout, BatchNormalization
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import RMSprop, Adam
from tensorflow.keras.models import Sequential
from tensorflow.keras import layers
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau

classifier = None
classifier = Sequential([
    layers.Conv2D(NUM_RECEPTIVE_FILTERS, kernel_size=GABOR_SIZE, strides=(1,1), name="GaborLayer", input_shape=train_generator.image_shape),
    layers.BatchNormalization(),
    layers.Activation('relu'),
    layers.MaxPooling2D(pool_size=(2,2)),
    Dropout(0.5),
    layers.Conv2D(64, kernel_size=(3,3), strides=(2,2)),
    layers.BatchNormalization(),
    layers.Activation('relu'),
    layers.MaxPooling2D(pool_size=(2,2)),
    Dropout(0.5),
    layers.Conv2D(128, kernel_size=(3,3), strides=(2,2)),
    layers.BatchNormalization(),
    layers.Activation('relu'),
    layers.MaxPooling2D(pool_size=(2,2)),
    Dropout(0.5),
    layers.Flatten(),
    layers.Dense(256),
    layers.BatchNormalization(),
    layers.Activation('relu'),
    Dropout(0.5),
    layers.Dense(NUM_CLASSES, activation='softmax')
])

classifier.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# GaborLayer (Conv2D)          (None, 242, 242, 32)      21632
# _________________________________________________________________
# batch_normalization (BatchNo (None, 242, 242, 32)      128
# _________________________________________________________________
# activation (Activation)      (None, 242, 242, 32)      0
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 121, 121, 32)      0
# _________________________________________________________________
# dropout (Dropout)            (None, 121, 121, 32)      0
# _________________________________________________________________
# conv2d (Conv2D)              (None, 60, 60, 64)        18496
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 60, 60, 64)        256
# _________________________________________________________________
# activation_1 (Activation)    (None, 60, 60, 64)        0
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 30, 30, 64)        0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 30, 30, 64)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 14, 14, 128)       73856
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 14, 14, 128)       512
# _________________________________________________________________
# activation_2 (Activation)    (None, 14, 14, 128)       0
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 7, 7, 128)         0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 7, 7, 128)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 6272)              0
# _________________________________________________________________
# dense (Dense)                (None, 256)               1605888
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 256)               1024
# _________________________________________________________________
# activation_3 (Activation)    (None, 256)               0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 2)                 514
# =================================================================
# Total params: 1,722,306
# Trainable params: 1,721,346
# Non-trainable params: 960
# _________________________________________________________________

# %%
NUM_RECEPTIVE_FILTERS
# Out:
# 32

# %%
cnnl1 = classifier.layers[GABOR_LAYER_INDEX].name   # get the name of the first conv layer
W = classifier.get_layer(name=cnnl1).get_weights()[0]   #get the filters
wshape = W.shape  #save the original shape
gabor_filters = W
for kernel_index in range(wshape[3]):
    for channel_index in range(3):
        gabor_filters[:,:,channel_index, kernel_index] = filterbank[kernel_index]

classifier.get_layer(name=cnnl1).set_weights([gabor_filters, classifier.get_layer(name=cnnl1).get_weights()[1]])
filter_layers = []
for i in range(NUM_RECEPTIVE_FILTERS):
    for j in range(3):
        filter_layers.append(np.reshape(W[:,:,j, i], GABOR_SIZE))
for i,gf in enumerate(filter_layers):
    plt.subplot(8, len(filter_layers)//8, i+1)
    plt.imshow(gf, cmap='gray')
    plt.axis('off')
plt.savefig('cvd-{}-initial-gabor-same-kernel-{}.png'.format(ITERATION,GABOR_WIDTH), dpi=350, bbox_inches='tight')

import copy
untrained_layers = copy.deepcopy(classifier.get_layer(name=classifier.layers[GABOR_LAYER_INDEX].name).get_weights())

# %%
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=10,  
                              min_delta=1e-4, mode='min', verbose=1)
stop_alg = EarlyStopping(monitor='val_loss', patience=35, 
                         restore_best_weights=True, verbose=1)
callbacks = [stop_alg, reduce_lr]
opt = Adam(learning_rate=0.001)
classifier.compile(loss='categorical_crossentropy', optimizer=opt, metrics=['accuracy', 'AUC'])

start = time.perf_counter()
hist = classifier.fit(
    train_generator, 
    epochs=EPOCHS,
    validation_data=validation_generator,
    validation_steps=total_validate//BATCH_SIZE,
    steps_per_epoch=total_train//BATCH_SIZE,
    callbacks=callbacks
)
finish = time.perf_counter()
# Out:
# Epoch 1/1000
# 625/625 [==============================] - 76s 117ms/step - loss: 0.7677 - accuracy: 0.6292 - auc: 0.6736 - val_loss: 0.5767 - val_accuracy: 0.6979 - val_auc: 0.7904
# Epoch 2/1000
# 625/625 [==============================] - 71s 114ms/step - loss: 0.5090 - accuracy: 0.7479 - auc: 0.8295 - val_loss: 0.5011 - val_accuracy: 0.7536 - val_auc: 0.8356
# Epoch 3/1000
# 625/625 [==============================] - 71s 113ms/step - loss: 0.4652 - accuracy: 0.7805 - auc: 0.8617 - val_loss: 0.4717 - val_accuracy: 0.7849 - val_auc: 0.8584
# Epoch 4/1000
# 625/625 [==============================] - 69s 110ms/step - loss: 0.4478 - accuracy: 0.7938 - auc: 0.8731 - val_loss: 0.4260 - val_accuracy: 0.8033 - val_auc: 0.8859
# Epoch 5/1000
# 625/625 [==============================] - 70s 112ms/step - loss: 0.4252 - accuracy: 0.8040 - auc: 0.8859 - val_loss: 0.4576 - val_accuracy: 0.7837 - val_auc: 0.8665
# Epoch 6/1000
# 625/625 [==============================] - 70s 112ms/step - loss: 0.4170 - accuracy: 0.8069 - auc: 0.8900 - val_loss: 0.4262 - val_accuracy: 0.8093 - val_auc: 0.8878
# Epoch 7/1000
# 625/625 [==============================] - 70s 112ms/step - loss: 0.3991 - accuracy: 0.8215 - auc: 0.9005 - val_loss: 0.3958 - val_accuracy: 0.8195 - val_auc: 0.9023
# Epoch 8/1000
# 625/625 [==============================] - 69s 111ms/step - loss: 0.3718 - accuracy: 0.8334 - auc: 0.9145 - val_loss: 0.5875 - val_accuracy: 0.6803 - val_auc: 0.7966
# Epoch 9/1000
# 625/625 [==============================] - 70s 112ms/step - loss: 0.3652 - accuracy: 0.8362 - auc: 0.9174 - val_loss: 0.3462 - val_accuracy: 0.8484 - val_auc: 0.9265
# Epoch 10/1000
# 625/625 [==============================] - 69s 111ms/step - loss: 0.3571 - accuracy: 0.8422 - auc: 0.9211 - val_loss: 0.5123 - val_accuracy: 0.7560 - val_auc: 0.8462
# Epoch 11/1000
# 625/625 [==============================] - 70s 112ms/step - loss: 0.3482 - accuracy: 0.8478 - auc: 0.9257 - val_loss: 0.4238 - val_accuracy: 0.8043 - val_auc: 0.8885
# Epoch 12/1000
# 625/625 [==============================] - 71s 114ms/step - loss: 0.3258 - accuracy: 0.8603 - auc: 0.9349 - val_loss: 0.3763 - val_accuracy: 0.8291 - val_auc: 0.9139
# Epoch 13/1000
# 625/625 [==============================] - 70s 112ms/step - loss: 0.3280 - accuracy: 0.8553 - auc: 0.9340 - val_loss: 0.4453 - val_accuracy: 0.8015 - val_auc: 0.8885
# Epoch 14/1000
# 625/625 [==============================] - 70s 112ms/step - loss: 0.3150 - accuracy: 0.8660 - auc: 0.9393 - val_loss: 0.7281 - val_accuracy: 0.6933 - val_auc: 0.7978
# Epoch 15/1000
# 625/625 [==============================] - 70s 112ms/step - loss: 0.2988 - accuracy: 0.8709 - auc: 0.9454 - val_loss: 0.3240 - val_accuracy: 0.8660 - val_auc: 0.9368
# Epoch 16/1000
# 625/625 [==============================] - 70s 111ms/step - loss: 0.2970 - accuracy: 0.8748 - auc: 0.9461 - val_loss: 0.3780 - val_accuracy: 0.8423 - val_auc: 0.9199
# Epoch 17/1000
# 625/625 [==============================] - 69s 110ms/step - loss: 0.2808 - accuracy: 0.8816 - auc: 0.9518 - val_loss: 0.4398 - val_accuracy: 0.7979 - val_auc: 0.8902
# Epoch 18/1000
# 625/625 [==============================] - 69s 111ms/step - loss: 0.2778 - accuracy: 0.8823 - auc: 0.9529 - val_loss: 0.3068 - val_accuracy: 0.8676 - val_auc: 0.9438
# Epoch 19/1000
# 625/625 [==============================] - 70s 112ms/step - loss: 0.2592 - accuracy: 0.8901 - auc: 0.9592 - val_loss: 0.2868 - val_accuracy: 0.8834 - val_auc: 0.9507
# Epoch 20/1000
# 625/625 [==============================] - 70s 112ms/step - loss: 0.2584 - accuracy: 0.8888 - auc: 0.9593 - val_loss: 0.4614 - val_accuracy: 0.8149 - val_auc: 0.9008
# Epoch 21/1000
# 625/625 [==============================] - 70s 111ms/step - loss: 0.2587 - accuracy: 0.8911 - auc: 0.9592 - val_loss: 0.5528 - val_accuracy: 0.7827 - val_auc: 0.8672
# Epoch 22/1000
# 625/625 [==============================] - 70s 111ms/step - loss: 0.2519 - accuracy: 0.8979 - auc: 0.9613 - val_loss: 0.4756 - val_accuracy: 0.8025 - val_auc: 0.8860
# Epoch 23/1000
# 625/625 [==============================] - 69s 111ms/step - loss: 0.2310 - accuracy: 0.9060 - auc: 0.9675 - val_loss: 0.3907 - val_accuracy: 0.8333 - val_auc: 0.9193
# Epoch 24/1000
# 625/625 [==============================] - 70s 111ms/step - loss: 0.2387 - accuracy: 0.9003 - auc: 0.9653 - val_loss: 0.3164 - val_accuracy: 0.8644 - val_auc: 0.9414
# Epoch 25/1000
# 625/625 [==============================] - 70s 111ms/step - loss: 0.2329 - accuracy: 0.9010 - auc: 0.9671 - val_loss: 0.3881 - val_accuracy: 0.8409 - val_auc: 0.9211
# Epoch 26/1000
# 625/625 [==============================] - 69s 111ms/step - loss: 0.2252 - accuracy: 0.9057 - auc: 0.9691 - val_loss: 0.4225 - val_accuracy: 0.8393 - val_auc: 0.9199
# Epoch 27/1000
# 625/625 [==============================] - 69s 111ms/step - loss: 0.2211 - accuracy: 0.9065 - auc: 0.9701 - val_loss: 0.2974 - val_accuracy: 0.8736 - val_auc: 0.9472
# Epoch 28/1000
# 625/625 [==============================] - 69s 111ms/step - loss: 0.2086 - accuracy: 0.9121 - auc: 0.9735 - val_loss: 0.4270 - val_accuracy: 0.8313 - val_auc: 0.9164
# Epoch 29/1000
# 625/625 [==============================] - 69s 111ms/step - loss: 0.2071 - accuracy: 0.9157 - auc: 0.9739 - val_loss: 0.3631 - val_accuracy: 0.8554 - val_auc: 0.9340
#
# Epoch 00029: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# Epoch 30/1000
# 625/625 [==============================] - 69s 110ms/step - loss: 0.1973 - accuracy: 0.9197 - auc: 0.9763 - val_loss: 0.3633 - val_accuracy: 0.8608 - val_auc: 0.9345
# Epoch 31/1000
# 625/625 [==============================] - 70s 111ms/step - loss: 0.1829 - accuracy: 0.9275 - auc: 0.9796 - val_loss: 0.3237 - val_accuracy: 0.8650 - val_auc: 0.9433
# Epoch 32/1000
# 625/625 [==============================] - 70s 112ms/step - loss: 0.1790 - accuracy: 0.9270 - auc: 0.9804 - val_loss: 0.3393 - val_accuracy: 0.8652 - val_auc: 0.9429
# Epoch 33/1000
# 625/625 [==============================] - 71s 113ms/step - loss: 0.1813 - accuracy: 0.9289 - auc: 0.9798 - val_loss: 0.2812 - val_accuracy: 0.8868 - val_auc: 0.9536
# Epoch 34/1000
# 625/625 [==============================] - 71s 113ms/step - loss: 0.1771 - accuracy: 0.9304 - auc: 0.9806 - val_loss: 0.2637 - val_accuracy: 0.8946 - val_auc: 0.9608
# Epoch 35/1000
# 625/625 [==============================] - 69s 111ms/step - loss: 0.1668 - accuracy: 0.9303 - auc: 0.9830 - val_loss: 0.3008 - val_accuracy: 0.8842 - val_auc: 0.9523
# Epoch 36/1000
# 625/625 [==============================] - 69s 111ms/step - loss: 0.1699 - accuracy: 0.9328 - auc: 0.9823 - val_loss: 0.3385 - val_accuracy: 0.8736 - val_auc: 0.9450
# Epoch 37/1000
# 625/625 [==============================] - 70s 111ms/step - loss: 0.1653 - accuracy: 0.9320 - auc: 0.9831 - val_loss: 0.2630 - val_accuracy: 0.8962 - val_auc: 0.9616
# Epoch 38/1000
# 625/625 [==============================] - 70s 111ms/step - loss: 0.1567 - accuracy: 0.9383 - auc: 0.9850 - val_loss: 0.2613 - val_accuracy: 0.8990 - val_auc: 0.9631
# Epoch 39/1000
# 625/625 [==============================] - 70s 112ms/step - loss: 0.1552 - accuracy: 0.9398 - auc: 0.9851 - val_loss: 0.3629 - val_accuracy: 0.8714 - val_auc: 0.9421
# Epoch 40/1000
# 625/625 [==============================] - 69s 110ms/step - loss: 0.1543 - accuracy: 0.9383 - auc: 0.9854 - val_loss: 0.3318 - val_accuracy: 0.8780 - val_auc: 0.9476
# Epoch 41/1000
# 625/625 [==============================] - 70s 111ms/step - loss: 0.1570 - accuracy: 0.9345 - auc: 0.9848 - val_loss: 0.7725 - val_accuracy: 0.7596 - val_auc: 0.8522
# Epoch 42/1000
# 625/625 [==============================] - 69s 111ms/step - loss: 0.1398 - accuracy: 0.9459 - auc: 0.9880 - val_loss: 0.2921 - val_accuracy: 0.8898 - val_auc: 0.9562
# Epoch 43/1000
# 625/625 [==============================] - 69s 110ms/step - loss: 0.1486 - accuracy: 0.9399 - auc: 0.9865 - val_loss: 0.2754 - val_accuracy: 0.8894 - val_auc: 0.9592
# Epoch 44/1000
# 625/625 [==============================] - 69s 110ms/step - loss: 0.1490 - accuracy: 0.9419 - auc: 0.9862 - val_loss: 0.3479 - val_accuracy: 0.8728 - val_auc: 0.9446
# Epoch 45/1000
# 625/625 [==============================] - 69s 110ms/step - loss: 0.1425 - accuracy: 0.9462 - auc: 0.9874 - val_loss: 0.3448 - val_accuracy: 0.8712 - val_auc: 0.9430
# Epoch 46/1000
# 625/625 [==============================] - 69s 111ms/step - loss: 0.1477 - accuracy: 0.9404 - auc: 0.9864 - val_loss: 0.3091 - val_accuracy: 0.8804 - val_auc: 0.9523
# Epoch 47/1000
# 625/625 [==============================] - 69s 110ms/step - loss: 0.1457 - accuracy: 0.9452 - auc: 0.9864 - val_loss: 0.2618 - val_accuracy: 0.8968 - val_auc: 0.9625
# Epoch 48/1000
# 625/625 [==============================] - 69s 110ms/step - loss: 0.1378 - accuracy: 0.9493 - auc: 0.9882 - val_loss: 0.2818 - val_accuracy: 0.8916 - val_auc: 0.9585
#
# Epoch 00048: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# Epoch 49/1000
# 625/625 [==============================] - 69s 110ms/step - loss: 0.1352 - accuracy: 0.9479 - auc: 0.9886 - val_loss: 0.2533 - val_accuracy: 0.9020 - val_auc: 0.9644
# Epoch 50/1000
# 625/625 [==============================] - 70s 112ms/step - loss: 0.1341 - accuracy: 0.9461 - auc: 0.9889 - val_loss: 0.3064 - val_accuracy: 0.8858 - val_auc: 0.9543
# Epoch 51/1000
# 625/625 [==============================] - 69s 111ms/step - loss: 0.1298 - accuracy: 0.9489 - auc: 0.9898 - val_loss: 0.3545 - val_accuracy: 0.8692 - val_auc: 0.9438
# Epoch 52/1000
# 625/625 [==============================] - 69s 111ms/step - loss: 0.1210 - accuracy: 0.9546 - auc: 0.9908 - val_loss: 0.3259 - val_accuracy: 0.8802 - val_auc: 0.9507
# Epoch 53/1000
# 625/625 [==============================] - 70s 111ms/step - loss: 0.1278 - accuracy: 0.9505 - auc: 0.9897 - val_loss: 0.3286 - val_accuracy: 0.8814 - val_auc: 0.9505
# Epoch 54/1000
# 625/625 [==============================] - 70s 111ms/step - loss: 0.1257 - accuracy: 0.9516 - auc: 0.9900 - val_loss: 0.3119 - val_accuracy: 0.8854 - val_auc: 0.9532
# Epoch 55/1000
# 625/625 [==============================] - 70s 111ms/step - loss: 0.1247 - accuracy: 0.9517 - auc: 0.9902 - val_loss: 0.3205 - val_accuracy: 0.8840 - val_auc: 0.9522
# Epoch 56/1000
# 625/625 [==============================] - 70s 112ms/step - loss: 0.1229 - accuracy: 0.9522 - auc: 0.9903 - val_loss: 0.2750 - val_accuracy: 0.8946 - val_auc: 0.9624
# Epoch 57/1000
# 625/625 [==============================] - 70s 111ms/step - loss: 0.1273 - accuracy: 0.9522 - auc: 0.9897 - val_loss: 0.3115 - val_accuracy: 0.8860 - val_auc: 0.9551
# Epoch 58/1000
# 625/625 [==============================] - 69s 111ms/step - loss: 0.1221 - accuracy: 0.9530 - auc: 0.9906 - val_loss: 0.3127 - val_accuracy: 0.8852 - val_auc: 0.9548
# Epoch 59/1000
# 625/625 [==============================] - 69s 111ms/step - loss: 0.1240 - accuracy: 0.9496 - auc: 0.9905 - val_loss: 0.3593 - val_accuracy: 0.8768 - val_auc: 0.9462
#
# Epoch 00059: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# Epoch 60/1000
# 625/625 [==============================] - 69s 111ms/step - loss: 0.1108 - accuracy: 0.9585 - auc: 0.9925 - val_loss: 0.3055 - val_accuracy: 0.8886 - val_auc: 0.9564
# Epoch 61/1000
# 625/625 [==============================] - 69s 110ms/step - loss: 0.1178 - accuracy: 0.9548 - auc: 0.9911 - val_loss: 0.2854 - val_accuracy: 0.8972 - val_auc: 0.9616
# Epoch 62/1000
# 625/625 [==============================] - 70s 111ms/step - loss: 0.1143 - accuracy: 0.9549 - auc: 0.9920 - val_loss: 0.2676 - val_accuracy: 0.9020 - val_auc: 0.9650
# Epoch 63/1000
# 625/625 [==============================] - 70s 111ms/step - loss: 0.1067 - accuracy: 0.9594 - auc: 0.9929 - val_loss: 0.2999 - val_accuracy: 0.8920 - val_auc: 0.9582
# Epoch 64/1000
# 625/625 [==============================] - 69s 111ms/step - loss: 0.1058 - accuracy: 0.9585 - auc: 0.9931 - val_loss: 0.2952 - val_accuracy: 0.8950 - val_auc: 0.9601
# Epoch 65/1000
# 625/625 [==============================] - 69s 110ms/step - loss: 0.1065 - accuracy: 0.9616 - auc: 0.9929 - val_loss: 0.3257 - val_accuracy: 0.8852 - val_auc: 0.9533
# Epoch 66/1000
# 625/625 [==============================] - 69s 111ms/step - loss: 0.1086 - accuracy: 0.9587 - auc: 0.9926 - val_loss: 0.3323 - val_accuracy: 0.8822 - val_auc: 0.9510
# Epoch 67/1000
# 625/625 [==============================] - 70s 111ms/step - loss: 0.1147 - accuracy: 0.9567 - auc: 0.9916 - val_loss: 0.3261 - val_accuracy: 0.8886 - val_auc: 0.9544
# Epoch 68/1000
# 625/625 [==============================] - 69s 111ms/step - loss: 0.1165 - accuracy: 0.9560 - auc: 0.9911 - val_loss: 0.3349 - val_accuracy: 0.8828 - val_auc: 0.9516
# Epoch 69/1000
# 625/625 [==============================] - 69s 111ms/step - loss: 0.1150 - accuracy: 0.9575 - auc: 0.9918 - val_loss: 0.3129 - val_accuracy: 0.8932 - val_auc: 0.9579
#
# Epoch 00069: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# Epoch 70/1000
# 625/625 [==============================] - 69s 111ms/step - loss: 0.1192 - accuracy: 0.9529 - auc: 0.9910 - val_loss: 0.2598 - val_accuracy: 0.9048 - val_auc: 0.9666
# Epoch 71/1000
# 625/625 [==============================] - 70s 111ms/step - loss: 0.1111 - accuracy: 0.9589 - auc: 0.9919 - val_loss: 0.2920 - val_accuracy: 0.8974 - val_auc: 0.9608
# Epoch 72/1000
# 625/625 [==============================] - 69s 111ms/step - loss: 0.1055 - accuracy: 0.9595 - auc: 0.9929 - val_loss: 0.2965 - val_accuracy: 0.8954 - val_auc: 0.9603
# Epoch 73/1000
# 625/625 [==============================] - 69s 111ms/step - loss: 0.1025 - accuracy: 0.9631 - auc: 0.9931 - val_loss: 0.3029 - val_accuracy: 0.8940 - val_auc: 0.9590
# Epoch 74/1000
# 625/625 [==============================] - 69s 110ms/step - loss: 0.1089 - accuracy: 0.9583 - auc: 0.9926 - val_loss: 0.3048 - val_accuracy: 0.8916 - val_auc: 0.9580
# Epoch 75/1000
# 625/625 [==============================] - 70s 111ms/step - loss: 0.1110 - accuracy: 0.9565 - auc: 0.9923 - val_loss: 0.3172 - val_accuracy: 0.8900 - val_auc: 0.9559
# Epoch 76/1000
# 625/625 [==============================] - 70s 112ms/step - loss: 0.1091 - accuracy: 0.9592 - auc: 0.9925 - val_loss: 0.2677 - val_accuracy: 0.9056 - val_auc: 0.9657
# Epoch 77/1000
# 625/625 [==============================] - 70s 112ms/step - loss: 0.1066 - accuracy: 0.9562 - auc: 0.9928 - val_loss: 0.2741 - val_accuracy: 0.9004 - val_auc: 0.9641
# Epoch 78/1000
# 625/625 [==============================] - 69s 111ms/step - loss: 0.1006 - accuracy: 0.9605 - auc: 0.9935 - val_loss: 0.3136 - val_accuracy: 0.8898 - val_auc: 0.9567
# Epoch 79/1000
# 625/625 [==============================] - 70s 112ms/step - loss: 0.1113 - accuracy: 0.9586 - auc: 0.9917 - val_loss: 0.3296 - val_accuracy: 0.8850 - val_auc: 0.9533
#
# Epoch 00079: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# Epoch 80/1000
# 625/625 [==============================] - 70s 111ms/step - loss: 0.1068 - accuracy: 0.9599 - auc: 0.9927 - val_loss: 0.2893 - val_accuracy: 0.8970 - val_auc: 0.9614
# Epoch 81/1000
# 625/625 [==============================] - 69s 111ms/step - loss: 0.1053 - accuracy: 0.9603 - auc: 0.9929 - val_loss: 0.3131 - val_accuracy: 0.8902 - val_auc: 0.9570
# Epoch 82/1000
# 625/625 [==============================] - 69s 110ms/step - loss: 0.1001 - accuracy: 0.9619 - auc: 0.9938 - val_loss: 0.2999 - val_accuracy: 0.8958 - val_auc: 0.9598
# Epoch 83/1000
# 625/625 [==============================] - 69s 110ms/step - loss: 0.1045 - accuracy: 0.9609 - auc: 0.9929 - val_loss: 0.3055 - val_accuracy: 0.8934 - val_auc: 0.9592
# Epoch 84/1000
# 625/625 [==============================] - 70s 111ms/step - loss: 0.0972 - accuracy: 0.9622 - auc: 0.9942 - val_loss: 0.3153 - val_accuracy: 0.8910 - val_auc: 0.9565
# Restoring model weights from the end of the best epoch.
# Epoch 00084: early stopping

# %%
classifier.layers[GABOR_LAYER_INDEX].name
# Out:
# 'GaborLayer'

# %%
print("Start time = {}".format(start))
print("Finish time = {}".format(finish))
print("Training time = {}".format(finish-start))
hist.history['start_time'] = start
hist.history['finish_time'] = finish
hist.history['train_time'] = finish-start
# Out:
# Start time = 9268.706997565
# Finish time = 15118.560796494
# Training time = 5849.853798929002

# %%
import pickle

trained_layers = copy.deepcopy(classifier.get_layer(name=classifier.layers[GABOR_LAYER_INDEX].name).get_weights())
hist.history['untrained_layers'] = untrained_layers
hist.history['trained_layers'] = trained_layers

with open('cvd-{}-history-gabor-same-kernel-{}.p'.format(ITERATION, GABOR_WIDTH),'wb') as fp:
    pickle.dump(hist.history, fp, protocol=pickle.HIGHEST_PROTOCOL)

# %%
import matplotlib.pyplot as plt

fig = plt.figure(figsize=(10,6))
plt.plot(hist.history['loss'], color='#785ef0')
plt.plot(hist.history['val_loss'], color='#dc267f')
plt.title('Model Loss Progress')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Training Set', 'Test Set'], loc='upper right')
plt.savefig('cvd-{}-loss-gabor-same-kernel-{}.png'.format(ITERATION,GABOR_WIDTH), dpi=350, bbox_inches='tight')
plt.show()

# %%
fig = plt.figure(figsize=(10,6))
plt.plot(hist.history['accuracy'], color='#785ef0')
plt.plot(hist.history['val_accuracy'], color='#dc267f')
plt.title('Model Accuracy Progress')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Training Set', 'Test Set'], loc='upper right')
plt.savefig('cvd-{}-accuracy-gabor-same-kernel-{}.png'.format(ITERATION, GABOR_WIDTH), dpi=350, bbox_inches='tight')
plt.show()

# %%
from sklearn.preprocessing import MinMaxScaler

cnnl1 = classifier.layers[GABOR_LAYER_INDEX].name   # get the name of the first conv layer
W = classifier.get_layer(name=cnnl1).get_weights()[0]   #get the filters
wshape = W.shape  #save the original shape

# this part will scale to [0, 1] for visualization purposes
scaler = MinMaxScaler()
scaler.fit(W.reshape(-1,1))
W = scaler.transform(W.reshape(-1,1))
W = W.reshape(wshape)

fig, axs = plt.subplots(8,NUM_RECEPTIVE_FILTERS//8, figsize=(24,24))
fig.subplots_adjust(hspace = .25, wspace=.001)
axs = axs.ravel()
for i in range(W.shape[-1]):
  # we reshape to a 3D (RGB) image shape and display
  h = np.reshape(W[:,:,:,i], (GABOR_WIDTH,GABOR_HEIGHT,3))
  axs[i].imshow(h)
  axs[i].set_title('Filter ' + str(i))    
plt.savefig("cvd-{}-filters-gabor-same-kernel-{}.png".format(ITERATION,GABOR_WIDTH), bbox_inches='tight', dpi=350)

# %%
cnnl1 = classifier.layers[GABOR_LAYER_INDEX].name   # get the name of the first conv layer
W = classifier.get_layer(name=cnnl1).get_weights()[0]
plt.hist(W.ravel(), bins=100)
print(np.min(W),np.max(W))
# Out:
# -1.1953863 1.1651068

# %%
filter_layers = []
for i in range(NUM_RECEPTIVE_FILTERS):
    for j in range(3):
        filter_layers.append(np.reshape(W[:,:,j, i], GABOR_SIZE))
for i,gf in enumerate(filter_layers):
    plt.subplot(8, (W.shape[3]*3)//8, i+1)
    plt.imshow(gf, cmap='gray')
    plt.axis('off')
plt.savefig("cvd-{}-channelwise-gabor-same-filters-kernel-{}.png".format(ITERATION,GABOR_WIDTH), bbox_inches='tight', dpi=350)

# %%
# !cp cvd-1-initial-gabor-same-kernel-15.png /content/drive/My\ Drive/Mehang\ Rai/analysis/image-size/128/15/cats-vs-dogs-128/1/

# %%
# !cp cvd-1-history-gabor-same-kernel-15.p /content/drive/My\ Drive/Mehang\ Rai/analysis/image-size/128/15/cats-vs-dogs-128/1/

# %%
# !cp cvd-1-loss-gabor-same-kernel-15.png /content/drive/My\ Drive/Mehang\ Rai/analysis/image-size/128/15/cats-vs-dogs-128/1/

# %%
# !cp cvd-1-accuracy-gabor-same-kernel-15.png /content/drive/My\ Drive/Mehang\ Rai/analysis/image-size/128/15/cats-vs-dogs-128/1/

# %%
# !cp cvd-1-filters-gabor-same-kernel-15.png /content/drive/My\ Drive/Mehang\ Rai/analysis/image-size/128/15/cats-vs-dogs-128/1/

# %%
# !cp cvd-1-channelwise-gabor-same-filters-kernel-15.png /content/drive/My\ Drive/Mehang\ Rai/analysis/image-size/128/15/cats-vs-dogs-128/1/
