# %% [markdown]
# <a href="https://colab.research.google.com/github/mehang/Improvised-CNN/blob/master/notebook/Cats%20Vs%20Dogs/Resized%20cats%20vs%20dogs/Collab_Cats_vs_Dogs.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import matplotlib.pyplot as plt
import numpy as np
import os
import PIL
import tensorflow as tf

from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential
from keras.preprocessing.image import ImageDataGenerator
import pathlib

# %%
import os

print(os.listdir("/content/drive/My Drive/Gabor Dataset/"))
# Out:
# ['cats-vs-dogs.zip']

# %%
# !unzip /content/drive/My\ Drive/Gabor\ Dataset/cats-vs-dogs.zip -d cats-vs-dogs
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.1234.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.6670.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.862.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.7225.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.4007.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.1698.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.4729.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.11973.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.5975.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.7848.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.11888.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.5743.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.4416.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.974.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.237.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.220.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.5076.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.6999.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.5976.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.12027.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.8196.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.4662.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.2887.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.7853.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.767.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.153.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.2158.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.6993.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.9844.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.5529.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.2125.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.6962.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.1884.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.10697.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.4206.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.699.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.1624.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.9919.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.9395.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.10474.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.9374.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.124.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.1363.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.236.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.11874.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.3334.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.3361.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.152.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.3620.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.2414.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.8090.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.9704.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.11840.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.5465.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.10899.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.5814.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.4118.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.426.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.8949.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.10734.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.6148.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.7995.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.6687.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.3798.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.11893.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.3685.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.6033.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.12379.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.7745.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.12202.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.2757.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.11656.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.7183.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.4043.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.92.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.2561.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.822.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.11505.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.10799.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.3674.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.4937.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.11006.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.10895.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.3910.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.10549.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.10577.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.712.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.6925.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.1214.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.11832.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.10683.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.7833.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.1753.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.1902.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.2303.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.1981.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.11311.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.3172.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.1824.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.10073.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.3650.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.604.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.10840.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.424.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.535.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.11720.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.5598.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.11018.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.9445.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.12482.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.10248.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.10189.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.12347.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.12198.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.10391.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.11687.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.9334.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.10277.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.6743.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.9142.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.3775.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.94.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.2768.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.2635.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.528.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.12108.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.4886.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.8791.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.4571.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.2108.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.8267.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.11558.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.3349.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.6765.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.4717.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.11845.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.4642.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.714.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.5667.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.5907.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.5085.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.6823.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.242.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.12176.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.2274.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.11349.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.264.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.8631.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.2504.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.9908.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.4994.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.2560.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.12436.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.8843.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.8358.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.10718.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.7105.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.11605.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.8048.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.10206.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.1651.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.7158.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.11395.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.2978.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.7928.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.8553.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.8652.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.11047.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.6645.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.9703.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.4749.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.10846.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.9388.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.12019.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.1357.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.6471.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.7651.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.7232.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.5038.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.8805.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.9605.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.5354.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.12486.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.7591.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.9882.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.2759.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.10727.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.4420.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.7851.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.10450.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.9224.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.903.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.8519.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.6066.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.6528.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.9831.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.8434.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.2291.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.2327.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.6898.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.5790.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.7131.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.2078.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.11574.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.1154.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.11396.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.9619.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.7626.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.9203.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.7479.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.9121.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.3507.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.11822.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.6181.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.670.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.3223.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.1793.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.7441.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.6997.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.11714.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.2708.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.8527.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.10702.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.3124.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.11295.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.3397.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.2076.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.11644.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.5050.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.2550.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.8551.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.3050.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.11189.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.11095.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.5296.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.8324.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.8587.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.6648.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.5381.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.10094.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.891.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.5879.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.9608.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.11547.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.5476.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.12460.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.938.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.1458.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.3634.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.9956.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.6004.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.11910.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.8243.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.2505.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.8512.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.7475.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.2857.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.9681.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.5551.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.11504.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.12092.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.11113.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.5826.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.11514.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.6802.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.3461.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.5356.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.11529.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.1026.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.2818.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.11538.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.3631.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.7165.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.614.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.1483.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.9377.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.7178.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.6578.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.4679.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.310.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.4882.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.9359.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.3704.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.5254.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.4629.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.10310.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.1140.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.12146.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.3734.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.10154.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.9859.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.8727.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.2976.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.4564.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.10861.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.819.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.7547.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.5136.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.19.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.9946.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.2044.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.12356.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.9370.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.1014.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.9472.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.4006.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.6468.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.351.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.845.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.3218.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.4878.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.10945.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.2226.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.11131.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.915.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.491.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.857.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.10399.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.2293.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.9531.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.3894.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.6673.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.9838.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.1311.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.7705.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.4124.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.7168.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.9912.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.1425.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.6556.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.3140.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.4374.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.6920.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.11907.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.6211.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.2460.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.7202.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.7676.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.6121.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.8128.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.5886.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.7172.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.9934.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.6187.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.9664.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.10008.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.7340.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.7802.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.259.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.5712.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.7880.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.5541.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.3709.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.2248.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.10432.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.8620.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.10388.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.10.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.5242.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.3194.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.5439.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.11953.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.6171.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.1951.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.10242.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.751.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.6044.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.4194.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.9748.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.11100.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.6510.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.9896.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.1800.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.5902.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.433.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.2343.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.3258.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.7486.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.4378.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.8961.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.11223.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.827.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.9270.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.11935.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.7502.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.7819.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.3595.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.6108.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.1528.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.4843.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.3788.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.4885.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.6240.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.1366.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.5290.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.483.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.10870.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.2966.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.9444.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.4128.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.10091.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.1333.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.2949.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.8562.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.2606.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.11044.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.7181.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.3088.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.6908.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.2276.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.96.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.10625.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.9244.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.817.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.2931.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.8955.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.6818.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.1143.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.1583.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.10805.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.8388.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.2856.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.8339.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.8057.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.8455.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.431.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.3275.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.11843.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.7820.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.6599.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.1503.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.1943.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.1452.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.3205.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.8660.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.6615.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.5652.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.11937.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.398.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.10126.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.2283.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.7584.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.8813.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.8718.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.11754.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.3807.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.1973.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.3864.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.1204.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.12155.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.7732.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.5872.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.12388.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.12242.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.1427.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.5267.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.1843.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.6564.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.2171.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.4039.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.2953.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.7605.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.3872.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.2487.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.2726.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.6374.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.10801.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.9276.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.305.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.8156.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.3700.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.4733.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.4730.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.1162.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.8979.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.11448.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.4599.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.10551.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.4884.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.4742.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.8237.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.9652.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.4781.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.6912.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.7048.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.11056.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.10330.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.10300.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.4188.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.1741.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.2973.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.10506.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.3040.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.11115.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.3850.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.4638.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.5016.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.7447.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.416.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.6608.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.11566.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.622.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.1292.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.5882.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.2633.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.7253.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.10192.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.9988.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.10431.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.3454.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.10236.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.9127.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.5320.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.10699.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.12225.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.6625.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.6407.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.450.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.10228.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.5113.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.1969.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.10238.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.6720.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.10463.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.11455.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.3784.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.11856.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.6573.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.6983.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.8613.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.5056.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.6895.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.383.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.72.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.9243.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.2196.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.4977.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.2085.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.294.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.935.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.11090.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.4359.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.4567.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.4796.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.9738.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.1832.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.8440.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.2164.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.8934.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.7417.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.8381.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.5406.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.7668.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.3553.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.5134.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.2965.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.2572.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.3447.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.11775.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.3742.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.9509.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.2004.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.10990.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.2014.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.8676.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.1935.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.1684.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.2480.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.11039.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.1201.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.4161.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.9357.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.2205.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.5909.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.8023.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.8842.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.7388.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.2727.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.771.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.5593.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.6145.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.7744.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.3643.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.5371.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.9411.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.5297.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.12381.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.1872.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.8120.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.5.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.12359.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.10830.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.47.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.4405.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.1436.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.1749.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.11675.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.2050.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.3577.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.3799.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.1113.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.11260.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.11499.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.5026.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.8684.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.10421.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.2694.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.3771.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.2368.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.1037.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.10259.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.4287.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.7093.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.3623.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.7414.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.2658.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.10822.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.10914.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.3360.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.2808.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.12440.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.6897.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.172.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.6640.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.7033.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.4653.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.2472.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.6110.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.1394.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.11707.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.8143.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.366.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.1556.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.11677.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.5247.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.5981.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.1947.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.715.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.8828.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.1210.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.9293.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.9005.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.9925.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.5022.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.1352.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.142.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.4795.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.6671.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.12320.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.7909.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.2688.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.551.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.7663.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.6948.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.14.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.2407.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.6977.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.1578.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.10022.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.2979.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.11235.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.1531.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.5467.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.3439.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.12185.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.4341.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.11918.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.5347.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.7192.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.691.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.4690.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.8710.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.9032.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.7614.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.9514.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.11160.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.1746.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.4315.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.4528.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.518.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.5646.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.814.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.6132.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.1334.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.8516.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.601.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.1995.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.11404.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.9329.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.2562.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.7095.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.9879.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.224.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.10319.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.7184.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.8773.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.1031.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.1392.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.5201.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.10230.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.7717.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.9120.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.11614.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.2313.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.11848.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.6691.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.12096.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.11204.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.7003.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.7582.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.4201.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.11587.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.6921.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.10472.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.6020.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.95.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.1661.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.5269.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.8151.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.8654.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.1589.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.7354.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.10804.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.10793.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.12212.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.8262.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.10169.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.8077.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.10198.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.7785.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.9253.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.6057.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.7701.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.1504.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.8980.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.6482.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.11014.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.8162.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.4290.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.9929.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.3126.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.643.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.5821.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.1020.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.6130.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.6180.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.11826.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.5036.jpg
# ...
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.394.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.11766.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.6298.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.7576.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.1312.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.723.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.6580.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.10071.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.4603.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.82.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.6776.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.11065.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.10728.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.5431.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.9643.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.6771.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.12009.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.4036.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.6419.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.10179.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.2840.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.2023.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.3832.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.2640.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.438.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.8889.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.5722.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.11612.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.3873.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.3249.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.11943.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.1984.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.10278.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.4431.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.5559.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.6322.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.11776.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.8789.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.5063.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.3866.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.9324.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.9848.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.6401.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.2030.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.10156.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.9581.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.9463.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.320.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.6795.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.7100.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.10062.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.907.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.1494.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.3255.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.12144.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.5325.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.8724.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.2013.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.6460.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.9861.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.5940.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.8224.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.2927.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.11082.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.6306.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.5332.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.5496.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.5892.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.1180.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.2844.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.7748.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.1493.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.7797.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.9780.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.10378.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.8914.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.3400.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.949.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.1939.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.10814.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.3486.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.2335.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.9066.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.32.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.9889.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.6074.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.8916.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.4160.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.9418.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.8314.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.1270.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.3308.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.146.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.1027.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.8481.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.3129.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.2588.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.4601.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.6311.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.184.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.5676.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.9274.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.553.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.9363.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.3253.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.11175.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.7887.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.6193.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.1859.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.9722.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.1802.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.3669.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.8130.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.7439.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.10383.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.1665.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.7699.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.2974.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.4732.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.4972.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.6733.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.6412.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.5732.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.6900.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.2282.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.7002.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.958.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.4265.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.4710.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.11920.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.9583.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.1259.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.7142.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.11338.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.11980.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.7750.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.7511.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.9776.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.11692.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.11696.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.10977.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.12090.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.231.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.5881.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.2503.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.8984.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.9935.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.9634.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.11269.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.2745.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.5776.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.3613.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.2946.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.11695.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.8486.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.9228.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.11796.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.9415.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.6409.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.753.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.7644.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.8005.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.6729.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.9706.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.137.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.8172.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.3912.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.11375.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.7468.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.6283.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.1286.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.9828.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.7618.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.7060.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.2877.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.4357.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.2352.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.11162.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.4333.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.10425.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.1766.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.9702.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.10158.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.6987.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.11226.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.4666.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.7046.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.4088.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.11621.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.5151.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.5985.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.3074.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.820.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.9936.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.2838.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.12314.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.9022.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.3513.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.7233.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.5015.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.7127.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.3282.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.669.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.5845.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.7930.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.7269.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.11610.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.2874.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.2498.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.6725.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.1619.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.5764.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.7357.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.7119.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.10202.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.9101.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.10675.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.1301.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.1291.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.5524.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.1676.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.7326.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.11308.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.11812.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.1898.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.5070.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.6589.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.3934.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.6750.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.8309.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.11738.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.7129.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.7014.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.12077.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.4421.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.5308.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.330.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.5777.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.12188.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.121.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.5233.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.1549.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.3999.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.5645.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.7943.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.8759.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.9498.jpg
#   inflating: cats-vs-dogs/cats-vs-dogs/train/dog/dog.380.jpg
#    creating: cats-vs-dogs/cats-vs-dogs/test/

# %%
import os

print(os.listdir("cats-vs-dogs/cats-vs-dogs/train/"))
# Out:
# ['dog', 'cat']

# %%
data_dir = "cats-vs-dogs/cats-vs-dogs/train/"
img_size = 256
batch_size = 32

train_ds = tf.keras.preprocessing.image_dataset_from_directory(
  data_dir, 
  validation_split=0.2,
  subset="training",
  seed=123,
  image_size=(img_size, img_size),
  batch_size=batch_size)

val_ds = tf.keras.preprocessing.image_dataset_from_directory(
  data_dir,
  validation_split=0.2,
  subset="validation",
  seed=123,
  image_size=(img_size, img_size),
  batch_size=batch_size)
# Out:
# Found 25000 files belonging to 2 classes.
# Using 20000 files for training.
# Found 25000 files belonging to 2 classes.
# Using 5000 files for validation.

# %%
class_names = train_ds.class_names
print(class_names)
# Out:
# ['cat', 'dog']

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 10))
for images, labels in train_ds.take(1):
    for i in range(9):
        ax = plt.subplot(3, 3, i + 1)
        plt.imshow(images[i].numpy().astype("uint8"))
        plt.title(class_names[labels[i]])
        plt.axis("off")

# %%
for image_batch, labels_batch in train_ds:
    print(image_batch.shape)
    print(labels_batch.shape)
    break
# Out:
# (32, 256, 256, 3)
# (32,)

# %%
AUTOTUNE = tf.data.experimental.AUTOTUNE

train_ds = train_ds.cache().shuffle(1000).prefetch(buffer_size=AUTOTUNE)
val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)

# %%
normalization_layer = layers.experimental.preprocessing.Rescaling(1./255)

normalized_ds = train_ds.map(lambda x, y: (normalization_layer(x), y))

# %%
# Importing the Keras libraries and packages
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Activation
from tensorflow.keras.layers import Input, Dense, Dropout, BatchNormalization
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import RMSprop, Adam

num_classes = 2

classifier = Sequential([
    # layers.experimental.preprocessing.Rescaling(1./255, input_shape=(img_size, img_size, 3)),
    layers.Conv2D(32, kernel_size=(15,15), strides=(1,1), activation='relu', input_shape=(img_size, img_size, 3)),
    layers.MaxPooling2D(pool_size=(2,2)),
    Dropout(0.5),
    layers.Conv2D(64, kernel_size=(3,3), strides=(2,2), activation='relu'),
    layers.MaxPooling2D(pool_size=(2,2)),
    layers.Conv2D(128, kernel_size=(3,3), strides=(2,2), activation='relu'),
    layers.MaxPooling2D(pool_size=(2,2)),
    Dropout(0.5),
    layers.Conv2D(64, 3, padding='same', activation='relu'),
    layers.MaxPooling2D(),
    layers.Flatten(),
    layers.Dense(128, activation='relu'),
    Dropout(0.5),
    layers.Dense(num_classes)
])

classifier.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 242, 242, 32)      21632
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 121, 121, 32)      0
# _________________________________________________________________
# dropout (Dropout)            (None, 121, 121, 32)      0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 60, 60, 64)        18496
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 30, 30, 64)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 14, 14, 128)       73856
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 7, 7, 128)         0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 7, 7, 128)         0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 7, 7, 64)          73792
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 3, 3, 64)          0
# _________________________________________________________________
# flatten (Flatten)            (None, 576)               0
# _________________________________________________________________
# dense (Dense)                (None, 128)               73856
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 5)                 645
# =================================================================
# Total params: 262,277
# Trainable params: 262,277
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Fitting the CNN to the images

from tensorflow.keras.callbacks import ReduceLROnPlateau, EarlyStopping
import time

reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=10,  
                              min_delta=1e-4, mode='min', verbose=1)

stop_alg = EarlyStopping(monitor='val_loss', patience=35, 
                         restore_best_weights=True, verbose=1)

classifier.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])



epochs=10
start = time.perf_counter()
hist = classifier.fit(train_ds,validation_data=val_ds,epochs=epochs,callbacks=[stop_alg, reduce_lr])
finish = time.perf_counter()
# Out:
# Epoch 1/10

# %%
import matplotlib.pyplot as plt

fig = plt.figure(figsize=(10,6))
plt.plot(hist.history['loss'], color='#785ef0')
plt.plot(hist.history['val_loss'], color='#dc267f')
plt.title('Model Loss Progress')
plt.ylabel('Binary Cross-Entropy Loss')
plt.xlabel('Epoch')
plt.legend(['Training Set', 'Test Set'], loc='upper right')
plt.savefig('cnn-gabor.cifar10.loss-2.png', dpi=350, bbox_inches='tight')
plt.show()

# %%
print(start)
print(finish)

# %%
from sklearn.preprocessing import MinMaxScaler

cnnl1 = classifier.layers[1].name   # get the name of the first conv layer
W = classifier.get_layer(name=cnnl1).get_weights()[0]   #get the filters
wshape = W.shape  #save the original shape

# this part will scale to [0, 1] for visualization purposes
scaler = MinMaxScaler()
scaler.fit(W.reshape(-1,1))
W = scaler.transform(W.reshape(-1,1))
W = W.reshape(wshape)

# since there are 64 filters, we will display them 8x8
fig, axs = plt.subplots(8,8, figsize=(24,24))
fig.subplots_adjust(hspace = .25, wspace=.001)
axs = axs.ravel()
for i in range(W.shape[-1]):
  # we reshape to a 3D (RGB) image shape and display
  h = np.reshape(W[:,:,:,i], (3,3,3))
  axs[i].imshow(h)
  axs[i].set_title('Filter ' + str(i))    
plt.savefig("cnn-gabor.full.filters-2.png", bbox_inches='tight', dpi=350)

# %%
cnnl1 = classifier.layers[1].name   # get the name of the first conv layer
W = classifier.get_layer(name=cnnl1).get_weights()[0]
plt.hist(W.ravel(), bins=100)
print(np.min(W),np.max(W))

# %%
import numpy as np
import pandas as pd 
from keras.preprocessing.image import ImageDataGenerator, load_img
from keras.utils import to_categorical
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import random
import os

# %%
FAST_RUN = False
IMAGE_WIDTH=256
IMAGE_HEIGHT=256
IMAGE_SIZE=(IMAGE_WIDTH, IMAGE_HEIGHT)
IMAGE_CHANNELS=3

# %%
filenames = os.listdir("cats-vs-dogs/cats-vs-dogs/train/cat/") + os.listdir("cats-vs-dogs/cats-vs-dogs/train/dog/")
categories = []
for filename in filenames:
    category = filename.split('.')[0]
    if category == 'dog':
        categories.append(1)
    else:
        categories.append(0)

df = pd.DataFrame({
    'filename': filenames,
    'category': categories
})

# %%
df["category"] = df["category"].replace({0: 'cat', 1: 'dog'})

# %%
train_df, validate_df = train_test_split(df, test_size=0.20, random_state=42)
train_df = train_df.reset_index(drop=True)
validate_df = validate_df.reset_index(drop=True)

# %%
train_df['category'].value_counts().plot.bar()

# %%
validate_df['category'].value_counts().plot.bar()

# %%
total_train = train_df.shape[0]
total_validate = validate_df.shape[0]
batch_size=15

# %%
train_datagen = ImageDataGenerator(rescale=1./255,)
