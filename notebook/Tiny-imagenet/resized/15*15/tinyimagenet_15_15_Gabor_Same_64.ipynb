# %% [markdown]
# <a href="https://colab.research.google.com/github/mehang/Improvised-CNN/blob/master/notebook/Tiny-imagenet/resized/15*15/tinyimagenet_15_15_Gabor_Same_64.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import matplotlib.pyplot as plt
import numpy as np
import os
import PIL
import tensorflow as tf
import pandas as pd

from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import pathlib
import time

from tensorflow.keras.preprocessing.image import ImageDataGenerator, load_img
from tensorflow.keras.utils import to_categorical
from sklearn.model_selection import train_test_split

# %%
# !unzip /content/drive/My\ Drive/Mehang\ Rai/tiny-imagenet.zip -d tiny-imagenet

# %%
ITERATION = 1
IMAGE_WIDTH=64
IMAGE_HEIGHT=64
IMAGE_SIZE=(IMAGE_WIDTH, IMAGE_HEIGHT)
IMAGE_CHANNELS=3
RANDOM_SEED = [42,42,34,56,62,74,29,15,7,81][ITERATION-1]
BATCH_SIZE = 64
NUM_CLASSES = 200
EPOCHS = 1000
GABOR_LAYER_INDEX = 0
GABOR_WIDTH = 9
GABOR_HEIGHT = 9
GABOR_SIZE = (GABOR_WIDTH, GABOR_HEIGHT)
NUM_RECEPTIVE_FILTERS = 64
TRAIN_DIR = "tiny-imagenet/tiny-imagenet/train/"
TEST_DIR = "tiny-imagenet/tiny-imagenet/test/"

# %%
filenames = os.listdir(TRAIN_DIR)
categories = []
for filename in filenames:
    category = filename.split('.')[0]
    categories.append(category)

train_df = pd.DataFrame({
    'filename': filenames,
    'category': categories
})

filenames = os.listdir(TEST_DIR)
categories = []
for filename in filenames:
    category = filename.split('.')[0]
    categories.append(category)

validate_df = pd.DataFrame({
    'filename': filenames,
    'category': categories
})

# %%
train_df = train_df.reset_index(drop=True)
validate_df = validate_df.reset_index(drop=True)
total_train = train_df.shape[0]
total_validate = validate_df.shape[0]

# %%
train_df['category'].value_counts().plot.bar()

# %%
validate_df['category'].value_counts().plot.bar()

# %%
from tensorflow.image import random_flip_left_right, random_crop, random_saturation
def preprocess(image):
  image = np.array(image)
  image = random_flip_left_right(image)
  image = random_saturation(image, 0.5, 2.0)
  return image


train_datagen = ImageDataGenerator(
    width_shift_range=0.2,
    height_shift_range=0.2,
    preprocessing_function=preprocess,
    rescale=1./255,
)
train_generator = train_datagen.flow_from_dataframe(
    train_df, 
    TRAIN_DIR, 
    x_col='filename',
    y_col='category',
    target_size=(IMAGE_SIZE),
    class_mode='categorical',
    batch_size=BATCH_SIZE
)
# Out:
# Found 100000 validated image filenames belonging to 200 classes.

# %%
validation_datagen = ImageDataGenerator(
    rescale=1./255)
validation_generator = validation_datagen.flow_from_dataframe(
    validate_df, 
    TEST_DIR, 
    x_col='filename',
    y_col='category',
    target_size=IMAGE_SIZE,
    class_mode='categorical',
    batch_size=BATCH_SIZE
)
# Out:
# Found 10000 validated image filenames belonging to 200 classes.

# %%
print(train_df.shape)
print(validate_df.shape)
# Out:
# (100000, 2)
# (10000, 2)

# %%
train_generator.image_shape
# Out:
# (64, 64, 3)

# %%
NUM_CLASSES = len(train_df['category'].value_counts())
print(NUM_CLASSES)
# Out:
# 200

# %%
import math

def get_gabor_filters(inchannels, outchannels, kernel_size = (3,3)):
    delta = 1e-4
    freqs = (math.pi/2)*(math.sqrt(2)**(-np.random.randint(0,5, (outchannels, inchannels))))
    thetas = (math.pi/8)*np.random.randint(0,8, (outchannels, inchannels))
    sigmas = math.pi/(freqs)
    psis = math.pi * np.random.rand(outchannels, inchannels)
    x0, y0 = np.ceil(np.array(kernel_size)/2)    
    
    y, x = np.meshgrid(
            np.linspace(-x0 + 1, x0 + 0, kernel_size[0]),
            np.linspace(-y0 + 1, y0 + 0, kernel_size[1]),
    )
    filterbank = []
    
    for i in range(outchannels):
        for j in range(inchannels):
            freq = freqs[i][j]
            theta = thetas[i][j]
            sigma = sigmas[i][j]
            psi = psis[i][j]
            
            rotx = x * np.cos(theta) + y * np.sin(theta)
            roty = -x * np.sin(theta) + y * np.cos(theta)

            g = np.exp(
                -0.5 * ((rotx ** 2 + roty ** 2) / (sigma + delta) ** 2)
            )
            g = g * np.cos(freq * rotx + psi)
#             g = g / (2 * math.pi * (sigma ** 2))
#             g = gabor_kernel(frequency=freq, bandwidth=sigma, theta=theta, offset=psi, n_stds=0).real
            filterbank.append(g)
    return filterbank

filterbank = get_gabor_filters(3, NUM_RECEPTIVE_FILTERS, GABOR_SIZE)

fig = plt.subplots(8, len(filterbank)//8, figsize=(22,22))
for i,gf in enumerate(filterbank):
    plt.subplot(8, len(filterbank)//8, i+1)
    plt.imshow(gf, cmap='gray')
    plt.axis('off')

# %%
# Importing the Keras libraries and packages
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Activation
from tensorflow.keras.layers import Input, Dense, Dropout, BatchNormalization
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import RMSprop, Adam, SGD
from tensorflow.keras.regularizers import L2
from tensorflow.keras.models import Sequential
from tensorflow.keras import layers
from tensorflow.keras.losses import CategoricalCrossentropy
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau

# with width, height and preprocessing
classifier = None
classifier = Sequential([
    layers.Conv2D(64, kernel_size=GABOR_SIZE, strides=(1,1), padding='same', activation='relu',  name="GaborLayer", input_shape=train_generator.image_shape),
    layers.Conv2D(64, kernel_size=(3,3), strides=(1,1), padding='same', activation='relu'),
    layers.MaxPooling2D(pool_size=(2,2), strides=(2,2)),
    layers.Conv2D(128, kernel_size=(3,3), strides=(1,1), padding='same', activation='relu'),
    layers.Conv2D(128, kernel_size=(3,3), strides=(1,1), padding='same', activation='relu'),
    layers.MaxPooling2D(pool_size=(2,2), strides=(2,2)),
    layers.Conv2D(256, kernel_size=(3,3), strides=(1,1), padding='same', activation='relu'),
    layers.Conv2D(256, kernel_size=(3,3), strides=(1,1), padding='same', activation='relu'),
    layers.Conv2D(256, kernel_size=(3,3), strides=(1,1), padding='same', activation='relu'),
    layers.MaxPooling2D(pool_size=(2,2), strides=(2,2)),
    layers.Conv2D(512, kernel_size=(3,3), strides=(1,1), padding='same', activation='relu'),
    layers.Conv2D(512, kernel_size=(3,3), strides=(1,1), padding='same', activation='relu'),
    layers.Conv2D(512, kernel_size=(3,3), strides=(1,1), padding='same', activation='relu'),
    layers.MaxPooling2D(pool_size=(2,2), strides=(2,2)),
    layers.Flatten(),
    layers.Dense(2048, activation='relu'),
    layers.Dropout(0.1),
    layers.Dense(2048, activation='relu'),
    layers.Dropout(0.1),
    layers.Dense(NUM_CLASSES, activation='softmax')
])

classifier.summary()

cnnl1 = classifier.layers[GABOR_LAYER_INDEX].name   # get the name of the first conv layer
W = classifier.get_layer(name=cnnl1).get_weights()[0]   #get the filters
wshape = W.shape  #save the original shape
gabor_filters = W
for kernel_index in range(wshape[3]):
    for channel_index in range(3):
        gabor_filters[:,:,channel_index, kernel_index] = filterbank[kernel_index+channel_index]

classifier.get_layer(name=cnnl1).set_weights([gabor_filters, classifier.get_layer(name=cnnl1).get_weights()[1]])
filter_layers = []
for i in range(NUM_RECEPTIVE_FILTERS):
    for j in range(3):
        filter_layers.append(np.reshape(W[:,:,j, i], GABOR_SIZE))
for i,gf in enumerate(filter_layers):
    plt.subplot(8, len(filterbank)//8, i+1)
    plt.imshow(gf, cmap='gray')
    plt.axis('off')
plt.savefig('cifar100-fine-{}-initial-gabor-random-kernel-{}.png'.format(ITERATION, GABOR_WIDTH), dpi=350, bbox_inches='tight')

import copy
untrained_layers = copy.deepcopy(classifier.get_layer(name=classifier.layers[GABOR_LAYER_INDEX].name).get_weights())

reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=1/5, patience=3,  
                              min_delta=1e-4, mode='min', verbose=1)
stop_alg = EarlyStopping(monitor='val_loss', patience=15, 
                         restore_best_weights=True, verbose=1)
callbacks = [stop_alg, reduce_lr]
opt = SGD(learning_rate=0.01, momentum=0.9, nesterov=True)

classifier.compile(loss=CategoricalCrossentropy(label_smoothing=0.1), optimizer=opt, metrics=['accuracy', 'AUC'])

start = time.perf_counter()
hist = classifier.fit(
    train_generator, 
    epochs=EPOCHS,
    validation_data=validation_generator,
    validation_steps=total_validate//BATCH_SIZE,
    steps_per_epoch=total_train//BATCH_SIZE,
    callbacks=callbacks
)
finish = time.perf_counter()

import matplotlib.pyplot as plt

fig = plt.figure(figsize=(10,6))
plt.plot(hist.history['loss'], color='#785ef0')
plt.plot(hist.history['val_loss'], color='#dc267f')
plt.title('Model Loss Progress')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Training Set', 'Test Set'], loc='upper right')
# plt.savefig('stanfordcars-{}-loss-kernel-{}.png'.format(ITERATION,GABOR_WIDTH), dpi=350, bbox_inches='tight')
plt.show()

fig = plt.figure(figsize=(10,6))
plt.plot(hist.history['accuracy'], color='#785ef0')
plt.plot(hist.history['val_accuracy'], color='#dc267f')
plt.title('Model Accuracy Progress')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Training Set', 'Test Set'], loc='upper right')
# plt.savefig('stanfordcars-{}-accuracy-kernel-{}.png'.format(ITERATION, GABOR_WIDTH), dpi=350, bbox_inches='tight')
plt.show()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# GaborLayer (Conv2D)          (None, 64, 64, 64)        15616
# _________________________________________________________________
# conv2d (Conv2D)              (None, 64, 64, 64)        36928
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 32, 32, 64)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 32, 32, 128)       73856
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 32, 32, 128)       147584
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 16, 16, 128)       0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 16, 16, 256)       295168
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 16, 16, 256)       590080
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 16, 16, 256)       590080
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 8, 8, 256)         0
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 8, 8, 512)         1180160
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 8, 8, 512)         2359808
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 8, 8, 512)         2359808
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 4, 4, 512)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 8192)              0
# _________________________________________________________________
# dense (Dense)                (None, 2048)              16779264
# _________________________________________________________________
# dropout (Dropout)            (None, 2048)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 2048)              4196352
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 2048)              0
# _________________________________________________________________
# dense_2 (Dense)              (None, 200)               409800
# =================================================================
# Total params: 29,034,504
# Trainable params: 29,034,504
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/1000
# 1562/1562 [==============================] - 334s 203ms/step - loss: 5.2111 - accuracy: 0.0116 - auc: 0.5761 - val_loss: 4.8151 - val_accuracy: 0.0465 - val_auc: 0.7519
# Epoch 2/1000
# 1562/1562 [==============================] - 314s 201ms/step - loss: 4.7890 - accuracy: 0.0561 - auc: 0.7511 - val_loss: 4.4821 - val_accuracy: 0.0980 - val_auc: 0.8083
# Epoch 3/1000
# 1562/1562 [==============================] - 313s 201ms/step - loss: 4.4883 - accuracy: 0.1010 - auc: 0.8073 - val_loss: 4.1466 - val_accuracy: 0.1537 - val_auc: 0.8534
# Epoch 4/1000
# 1562/1562 [==============================] - 314s 201ms/step - loss: 4.2063 - accuracy: 0.1493 - auc: 0.8477 - val_loss: 3.8532 - val_accuracy: 0.2175 - val_auc: 0.8861
# Epoch 5/1000
# 1562/1562 [==============================] - 314s 201ms/step - loss: 3.9658 - accuracy: 0.1970 - auc: 0.8717 - val_loss: 3.7370 - val_accuracy: 0.2426 - val_auc: 0.8932
# Epoch 6/1000
# 1562/1562 [==============================] - 313s 201ms/step - loss: 3.7794 - accuracy: 0.2320 - auc: 0.8892 - val_loss: 3.5653 - val_accuracy: 0.2785 - val_auc: 0.9018
# Epoch 7/1000
# 1562/1562 [==============================] - 313s 200ms/step - loss: 3.6207 - accuracy: 0.2636 - auc: 0.9017 - val_loss: 3.4559 - val_accuracy: 0.3063 - val_auc: 0.9084
# Epoch 8/1000
# 1562/1562 [==============================] - 313s 201ms/step - loss: 3.4907 - accuracy: 0.2955 - auc: 0.9116 - val_loss: 3.4253 - val_accuracy: 0.3187 - val_auc: 0.9124
# Epoch 9/1000
# 1562/1562 [==============================] - 313s 200ms/step - loss: 3.3713 - accuracy: 0.3213 - auc: 0.9201 - val_loss: 3.3349 - val_accuracy: 0.3371 - val_auc: 0.9183
# Epoch 10/1000
# 1562/1562 [==============================] - 312s 200ms/step - loss: 3.2660 - accuracy: 0.3430 - auc: 0.9269 - val_loss: 3.2711 - val_accuracy: 0.3549 - val_auc: 0.9180
# Epoch 11/1000
# 1562/1562 [==============================] - 312s 200ms/step - loss: 3.1672 - accuracy: 0.3709 - auc: 0.9328 - val_loss: 3.1845 - val_accuracy: 0.3687 - val_auc: 0.9272
# Epoch 12/1000
# 1562/1562 [==============================] - 312s 200ms/step - loss: 3.0946 - accuracy: 0.3878 - auc: 0.9380 - val_loss: 3.1549 - val_accuracy: 0.3858 - val_auc: 0.9255
# Epoch 13/1000
# 1562/1562 [==============================] - 312s 200ms/step - loss: 3.0159 - accuracy: 0.4037 - auc: 0.9419 - val_loss: 3.1167 - val_accuracy: 0.3912 - val_auc: 0.9268
# Epoch 14/1000
# 1562/1562 [==============================] - 312s 200ms/step - loss: 2.9538 - accuracy: 0.4186 - auc: 0.9456 - val_loss: 3.1359 - val_accuracy: 0.3929 - val_auc: 0.9232
# Epoch 15/1000
# 1562/1562 [==============================] - 314s 201ms/step - loss: 2.8868 - accuracy: 0.4343 - auc: 0.9495 - val_loss: 3.1470 - val_accuracy: 0.3851 - val_auc: 0.9234
# Epoch 16/1000
# 1562/1562 [==============================] - 312s 200ms/step - loss: 2.8182 - accuracy: 0.4525 - auc: 0.9528 - val_loss: 3.0864 - val_accuracy: 0.3945 - val_auc: 0.9294
# Epoch 17/1000
# 1562/1562 [==============================] - 313s 200ms/step - loss: 2.7721 - accuracy: 0.4655 - auc: 0.9554 - val_loss: 3.0934 - val_accuracy: 0.4029 - val_auc: 0.9254
# Epoch 18/1000
# 1562/1562 [==============================] - 313s 200ms/step - loss: 2.7134 - accuracy: 0.4776 - auc: 0.9583 - val_loss: 3.0755 - val_accuracy: 0.4105 - val_auc: 0.9229
# Epoch 19/1000
# 1562/1562 [==============================] - 315s 202ms/step - loss: 2.6579 - accuracy: 0.4936 - auc: 0.9612 - val_loss: 3.1285 - val_accuracy: 0.4016 - val_auc: 0.9202
# Epoch 20/1000
# 1562/1562 [==============================] - 313s 201ms/step - loss: 2.6051 - accuracy: 0.5064 - auc: 0.9638 - val_loss: 3.1423 - val_accuracy: 0.3980 - val_auc: 0.9199
# Epoch 21/1000
# 1562/1562 [==============================] - 313s 200ms/step - loss: 2.5427 - accuracy: 0.5245 - auc: 0.9669 - val_loss: 3.0576 - val_accuracy: 0.4152 - val_auc: 0.9265
# Epoch 22/1000
# 1562/1562 [==============================] - 311s 199ms/step - loss: 2.5156 - accuracy: 0.5339 - auc: 0.9680 - val_loss: 3.0473 - val_accuracy: 0.4138 - val_auc: 0.9257
# Epoch 23/1000
# 1562/1562 [==============================] - 311s 199ms/step - loss: 2.4683 - accuracy: 0.5459 - auc: 0.9706 - val_loss: 3.0974 - val_accuracy: 0.4082 - val_auc: 0.9200
# Epoch 24/1000
# 1562/1562 [==============================] - 312s 200ms/step - loss: 2.4230 - accuracy: 0.5568 - auc: 0.9723 - val_loss: 3.0941 - val_accuracy: 0.4239 - val_auc: 0.9182
# Epoch 25/1000
# 1562/1562 [==============================] - 313s 200ms/step - loss: 2.3884 - accuracy: 0.5664 - auc: 0.9739 - val_loss: 3.0496 - val_accuracy: 0.4292 - val_auc: 0.9208
#
# Epoch 00025: ReduceLROnPlateau reducing learning rate to 0.0019999999552965165.
# Epoch 26/1000
# 1562/1562 [==============================] - 313s 201ms/step - loss: 2.1604 - accuracy: 0.6385 - auc: 0.9822 - val_loss: 2.9482 - val_accuracy: 0.4577 - val_auc: 0.9268
# Epoch 27/1000
# 1562/1562 [==============================] - 313s 200ms/step - loss: 1.9923 - accuracy: 0.6894 - auc: 0.9872 - val_loss: 2.9442 - val_accuracy: 0.4659 - val_auc: 0.9260
# Epoch 28/1000
# 1562/1562 [==============================] - 313s 200ms/step - loss: 1.9386 - accuracy: 0.7076 - auc: 0.9889 - val_loss: 2.9647 - val_accuracy: 0.4658 - val_auc: 0.9235
# Epoch 29/1000
# 1562/1562 [==============================] - 313s 200ms/step - loss: 1.8914 - accuracy: 0.7242 - auc: 0.9903 - val_loss: 2.9843 - val_accuracy: 0.4585 - val_auc: 0.9229
# Epoch 30/1000
# 1562/1562 [==============================] - 312s 200ms/step - loss: 1.8600 - accuracy: 0.7327 - auc: 0.9911 - val_loss: 2.9815 - val_accuracy: 0.4668 - val_auc: 0.9210
#
# Epoch 00030: ReduceLROnPlateau reducing learning rate to 0.0003999999724328518.
# Epoch 31/1000
# 1562/1562 [==============================] - 312s 200ms/step - loss: 1.7874 - accuracy: 0.7591 - auc: 0.9927 - val_loss: 2.9721 - val_accuracy: 0.4648 - val_auc: 0.9222
# Epoch 32/1000
# 1562/1562 [==============================] - 314s 201ms/step - loss: 1.7763 - accuracy: 0.7629 - auc: 0.9931 - val_loss: 2.9743 - val_accuracy: 0.4668 - val_auc: 0.9225
# Epoch 33/1000
# 1562/1562 [==============================] - 314s 201ms/step - loss: 1.7583 - accuracy: 0.7704 - auc: 0.9934 - val_loss: 2.9701 - val_accuracy: 0.4673 - val_auc: 0.9216
#
# Epoch 00033: ReduceLROnPlateau reducing learning rate to 7.999999215826393e-05.
# Epoch 34/1000
# 1562/1562 [==============================] - 312s 200ms/step - loss: 1.7478 - accuracy: 0.7732 - auc: 0.9935 - val_loss: 2.9672 - val_accuracy: 0.4681 - val_auc: 0.9219
# Epoch 35/1000
# 1562/1562 [==============================] - 312s 200ms/step - loss: 1.7400 - accuracy: 0.7782 - auc: 0.9935 - val_loss: 2.9687 - val_accuracy: 0.4694 - val_auc: 0.9218
# Epoch 36/1000
# 1562/1562 [==============================] - 312s 200ms/step - loss: 1.7399 - accuracy: 0.7752 - auc: 0.9937 - val_loss: 2.9721 - val_accuracy: 0.4679 - val_auc: 0.9213
#
# Epoch 00036: ReduceLROnPlateau reducing learning rate to 1.599999814061448e-05.
# Epoch 37/1000
# 1562/1562 [==============================] - 312s 200ms/step - loss: 1.7310 - accuracy: 0.7787 - auc: 0.9937 - val_loss: 2.9687 - val_accuracy: 0.4682 - val_auc: 0.9216
# Epoch 38/1000
# 1562/1562 [==============================] - 312s 200ms/step - loss: 1.7325 - accuracy: 0.7780 - auc: 0.9941 - val_loss: 2.9681 - val_accuracy: 0.4683 - val_auc: 0.9216
# Epoch 39/1000
# 1562/1562 [==============================] - 311s 199ms/step - loss: 1.7367 - accuracy: 0.7769 - auc: 0.9937 - val_loss: 2.9699 - val_accuracy: 0.4678 - val_auc: 0.9214
#
# Epoch 00039: ReduceLROnPlateau reducing learning rate to 3.199999628122896e-06.
# Epoch 40/1000
# 1562/1562 [==============================] - 313s 201ms/step - loss: 1.7379 - accuracy: 0.7768 - auc: 0.9933 - val_loss: 2.9688 - val_accuracy: 0.4679 - val_auc: 0.9217
# Epoch 41/1000
# 1562/1562 [==============================] - 312s 200ms/step - loss: 1.7270 - accuracy: 0.7803 - auc: 0.9940 - val_loss: 2.9681 - val_accuracy: 0.4679 - val_auc: 0.9215
# Epoch 42/1000
# 1562/1562 [==============================] - 312s 200ms/step - loss: 1.7367 - accuracy: 0.7776 - auc: 0.9937 - val_loss: 2.9679 - val_accuracy: 0.4680 - val_auc: 0.9215
# Restoring model weights from the end of the best epoch.
#
# Epoch 00042: ReduceLROnPlateau reducing learning rate to 6.399999165296323e-07.
# Epoch 00042: early stopping

# %%
# Importing the Keras libraries and packages
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Activation
from tensorflow.keras.layers import Input, Dense, Dropout, BatchNormalization
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import RMSprop, Adam, SGD
from tensorflow.keras.regularizers import L2
from tensorflow.keras.models import Sequential
from tensorflow.keras import layers
from tensorflow.keras.losses import CategoricalCrossentropy
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau

# with width, height and preprocessing
classifier = None
classifier = Sequential([
    layers.Conv2D(64, kernel_size=GABOR_SIZE, strides=(1,1), padding='same', activation='relu',  name="GaborLayer", input_shape=train_generator.image_shape),
    layers.Conv2D(64, kernel_size=(3,3), strides=(1,1), padding='same', activation='relu'),
    layers.MaxPooling2D(pool_size=(2,2), strides=(2,2)),
    layers.Conv2D(128, kernel_size=(3,3), strides=(1,1), padding='same', activation='relu'),
    layers.Conv2D(128, kernel_size=(3,3), strides=(1,1), padding='same', activation='relu'),
    layers.MaxPooling2D(pool_size=(2,2), strides=(2,2)),
    layers.Conv2D(256, kernel_size=(3,3), strides=(1,1), padding='same', activation='relu'),
    layers.Conv2D(256, kernel_size=(3,3), strides=(1,1), padding='same', activation='relu'),
    layers.Conv2D(256, kernel_size=(3,3), strides=(1,1), padding='same', activation='relu'),
    layers.MaxPooling2D(pool_size=(2,2), strides=(2,2)),
    layers.Conv2D(512, kernel_size=(3,3), strides=(1,1), padding='same', activation='relu'),
    layers.Conv2D(512, kernel_size=(3,3), strides=(1,1), padding='same', activation='relu'),
    layers.Conv2D(512, kernel_size=(3,3), strides=(1,1), padding='same', activation='relu'),
    layers.MaxPooling2D(pool_size=(2,2), strides=(2,2)),
    layers.Flatten(),
    layers.Dense(4096, activation='relu'),
    layers.Dropout(0.1),
    layers.Dense(2048, activation='relu'),
    layers.Dropout(0.1),
    layers.Dense(NUM_CLASSES, activation='softmax')
])

classifier.summary()

import copy
untrained_layers = copy.deepcopy(classifier.get_layer(name=classifier.layers[GABOR_LAYER_INDEX].name).get_weights())

reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=1/5, patience=3,  
                              min_delta=1e-4, mode='min', verbose=1)
stop_alg = EarlyStopping(monitor='val_loss', patience=15, 
                         restore_best_weights=True, verbose=1)
callbacks = [stop_alg, reduce_lr]
opt = SGD(learning_rate=0.01, momentum=0.9, nesterov=True)

classifier.compile(loss=CategoricalCrossentropy(label_smoothing=0.1), optimizer=opt, metrics=['accuracy', 'AUC'])

start = time.perf_counter()
hist = classifier.fit(
    train_generator, 
    epochs=EPOCHS,
    validation_data=validation_generator,
    validation_steps=total_validate//BATCH_SIZE,
    steps_per_epoch=total_train//BATCH_SIZE,
    callbacks=callbacks
)
finish = time.perf_counter()

import matplotlib.pyplot as plt

fig = plt.figure(figsize=(10,6))
plt.plot(hist.history['loss'], color='#785ef0')
plt.plot(hist.history['val_loss'], color='#dc267f')
plt.title('Model Loss Progress')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Training Set', 'Test Set'], loc='upper right')
# plt.savefig('stanfordcars-{}-loss-kernel-{}.png'.format(ITERATION,GABOR_WIDTH), dpi=350, bbox_inches='tight')
plt.show()

fig = plt.figure(figsize=(10,6))
plt.plot(hist.history['accuracy'], color='#785ef0')
plt.plot(hist.history['val_accuracy'], color='#dc267f')
plt.title('Model Accuracy Progress')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Training Set', 'Test Set'], loc='upper right')
# plt.savefig('stanfordcars-{}-accuracy-kernel-{}.png'.format(ITERATION, GABOR_WIDTH), dpi=350, bbox_inches='tight')
plt.show()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# GaborLayer (Conv2D)          (None, 64, 64, 64)        15616
# _________________________________________________________________
# conv2d (Conv2D)              (None, 64, 64, 64)        36928
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 32, 32, 64)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 32, 32, 128)       73856
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 32, 32, 128)       147584
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 16, 16, 128)       0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 16, 16, 256)       295168
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 16, 16, 256)       590080
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 16, 16, 256)       590080
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 8, 8, 256)         0
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 8, 8, 512)         1180160
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 8, 8, 512)         2359808
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 8, 8, 512)         2359808
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 4, 4, 512)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 8192)              0
# _________________________________________________________________
# dense (Dense)                (None, 4096)              33558528
# _________________________________________________________________
# dropout (Dropout)            (None, 4096)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 2048)              8390656
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 2048)              0
# _________________________________________________________________
# dense_2 (Dense)              (None, 200)               409800
# =================================================================
# Total params: 50,008,072
# Trainable params: 50,008,072
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/1000
# 1562/1562 [==============================] - 336s 204ms/step - loss: 5.2743 - accuracy: 0.0068 - auc: 0.5246 - val_loss: 5.0944 - val_accuracy: 0.0196 - val_auc: 0.6526
# Epoch 2/1000
# 1562/1562 [==============================] - 316s 202ms/step - loss: 5.0462 - accuracy: 0.0251 - auc: 0.6697 - val_loss: 4.7353 - val_accuracy: 0.0631 - val_auc: 0.7637
# Epoch 3/1000
# 1562/1562 [==============================] - 316s 202ms/step - loss: 4.7344 - accuracy: 0.0614 - auc: 0.7625 - val_loss: 4.4733 - val_accuracy: 0.0979 - val_auc: 0.8119
# Epoch 4/1000
# 1562/1562 [==============================] - 315s 202ms/step - loss: 4.4716 - accuracy: 0.1045 - auc: 0.8092 - val_loss: 4.1571 - val_accuracy: 0.1573 - val_auc: 0.8510
# Epoch 5/1000
# 1562/1562 [==============================] - 315s 201ms/step - loss: 4.2160 - accuracy: 0.1446 - auc: 0.8451 - val_loss: 3.9473 - val_accuracy: 0.1950 - val_auc: 0.8719
# Epoch 6/1000
# 1562/1562 [==============================] - 315s 202ms/step - loss: 3.9720 - accuracy: 0.1940 - auc: 0.8721 - val_loss: 3.7640 - val_accuracy: 0.2322 - val_auc: 0.8941
# Epoch 7/1000
# 1562/1562 [==============================] - 314s 201ms/step - loss: 3.7655 - accuracy: 0.2333 - auc: 0.8914 - val_loss: 3.5791 - val_accuracy: 0.2796 - val_auc: 0.9038
# Epoch 8/1000
# 1562/1562 [==============================] - 315s 201ms/step - loss: 3.6085 - accuracy: 0.2664 - auc: 0.9041 - val_loss: 3.5172 - val_accuracy: 0.2935 - val_auc: 0.9054
# Epoch 9/1000
# 1562/1562 [==============================] - 315s 202ms/step - loss: 3.4450 - accuracy: 0.3060 - auc: 0.9160 - val_loss: 3.3787 - val_accuracy: 0.3254 - val_auc: 0.9164
# Epoch 10/1000
# 1562/1562 [==============================] - 314s 201ms/step - loss: 3.3131 - accuracy: 0.3340 - auc: 0.9247 - val_loss: 3.3739 - val_accuracy: 0.3318 - val_auc: 0.9132
# Epoch 11/1000
# 1562/1562 [==============================] - 314s 201ms/step - loss: 3.2105 - accuracy: 0.3592 - auc: 0.9318 - val_loss: 3.2509 - val_accuracy: 0.3575 - val_auc: 0.9219
# Epoch 12/1000
# 1562/1562 [==============================] - 316s 202ms/step - loss: 3.0921 - accuracy: 0.3882 - auc: 0.9378 - val_loss: 3.1712 - val_accuracy: 0.3773 - val_auc: 0.9251
# Epoch 13/1000
# 1562/1562 [==============================] - 318s 204ms/step - loss: 3.0022 - accuracy: 0.4078 - auc: 0.9430 - val_loss: 3.1562 - val_accuracy: 0.3827 - val_auc: 0.9233
# Epoch 14/1000
# 1562/1562 [==============================] - 316s 202ms/step - loss: 2.9135 - accuracy: 0.4306 - auc: 0.9489 - val_loss: 3.1491 - val_accuracy: 0.3854 - val_auc: 0.9221
# Epoch 15/1000
# 1562/1562 [==============================] - 316s 202ms/step - loss: 2.8276 - accuracy: 0.4516 - auc: 0.9532 - val_loss: 3.0494 - val_accuracy: 0.4077 - val_auc: 0.9301
# Epoch 16/1000
# 1562/1562 [==============================] - 314s 201ms/step - loss: 2.7379 - accuracy: 0.4778 - auc: 0.9571 - val_loss: 3.0935 - val_accuracy: 0.4098 - val_auc: 0.9250
# Epoch 17/1000
# 1562/1562 [==============================] - 313s 201ms/step - loss: 2.6610 - accuracy: 0.4962 - auc: 0.9617 - val_loss: 3.0675 - val_accuracy: 0.4146 - val_auc: 0.9269
# Epoch 18/1000
# 1562/1562 [==============================] - 317s 203ms/step - loss: 2.5927 - accuracy: 0.5112 - auc: 0.9651 - val_loss: 3.0366 - val_accuracy: 0.4264 - val_auc: 0.9250
# Epoch 19/1000
# 1562/1562 [==============================] - 318s 204ms/step - loss: 2.5264 - accuracy: 0.5315 - auc: 0.9675 - val_loss: 3.0470 - val_accuracy: 0.4263 - val_auc: 0.9249
# Epoch 20/1000
# 1562/1562 [==============================] - 315s 202ms/step - loss: 2.4582 - accuracy: 0.5497 - auc: 0.9708 - val_loss: 3.0601 - val_accuracy: 0.4221 - val_auc: 0.9239
# Epoch 21/1000
# 1562/1562 [==============================] - 314s 201ms/step - loss: 2.3901 - accuracy: 0.5704 - auc: 0.9739 - val_loss: 3.0649 - val_accuracy: 0.4256 - val_auc: 0.9218
#
# Epoch 00021: ReduceLROnPlateau reducing learning rate to 0.0019999999552965165.
# Epoch 22/1000
# 1562/1562 [==============================] - 318s 203ms/step - loss: 2.1198 - accuracy: 0.6504 - auc: 0.9839 - val_loss: 2.9155 - val_accuracy: 0.4684 - val_auc: 0.9308
# Epoch 23/1000
# 1562/1562 [==============================] - 318s 203ms/step - loss: 1.9556 - accuracy: 0.7055 - auc: 0.9888 - val_loss: 2.9304 - val_accuracy: 0.4681 - val_auc: 0.9277
# Epoch 24/1000
# 1562/1562 [==============================] - 314s 201ms/step - loss: 1.8965 - accuracy: 0.7253 - auc: 0.9900 - val_loss: 2.9548 - val_accuracy: 0.4661 - val_auc: 0.9247
# Epoch 25/1000
# 1562/1562 [==============================] - 314s 201ms/step - loss: 1.8437 - accuracy: 0.7426 - auc: 0.9912 - val_loss: 2.9533 - val_accuracy: 0.4725 - val_auc: 0.9241
#
# Epoch 00025: ReduceLROnPlateau reducing learning rate to 0.0003999999724328518.
# Epoch 26/1000
# 1562/1562 [==============================] - 316s 202ms/step - loss: 1.7650 - accuracy: 0.7725 - auc: 0.9933 - val_loss: 2.9478 - val_accuracy: 0.4737 - val_auc: 0.9247
# Epoch 27/1000
# 1562/1562 [==============================] - 315s 202ms/step - loss: 1.7410 - accuracy: 0.7807 - auc: 0.9938 - val_loss: 2.9504 - val_accuracy: 0.4712 - val_auc: 0.9244
# Epoch 28/1000
# 1562/1562 [==============================] - 314s 201ms/step - loss: 1.7247 - accuracy: 0.7870 - auc: 0.9940 - val_loss: 2.9393 - val_accuracy: 0.4747 - val_auc: 0.9258
#
# Epoch 00028: ReduceLROnPlateau reducing learning rate to 7.999999215826393e-05.
# Epoch 29/1000
# 1562/1562 [==============================] - 314s 201ms/step - loss: 1.7109 - accuracy: 0.7909 - auc: 0.9941 - val_loss: 2.9466 - val_accuracy: 0.4731 - val_auc: 0.9244
# Epoch 30/1000
# 1562/1562 [==============================] - 315s 202ms/step - loss: 1.7115 - accuracy: 0.7918 - auc: 0.9943 - val_loss: 2.9420 - val_accuracy: 0.4735 - val_auc: 0.9253
# Epoch 31/1000
# 1562/1562 [==============================] - 316s 202ms/step - loss: 1.7001 - accuracy: 0.7959 - auc: 0.9946 - val_loss: 2.9466 - val_accuracy: 0.4729 - val_auc: 0.9242
#
# Epoch 00031: ReduceLROnPlateau reducing learning rate to 1.599999814061448e-05.
# Epoch 32/1000
# 1562/1562 [==============================] - 317s 203ms/step - loss: 1.6966 - accuracy: 0.7947 - auc: 0.9948 - val_loss: 2.9439 - val_accuracy: 0.4741 - val_auc: 0.9243
# Epoch 33/1000
# 1562/1562 [==============================] - 316s 202ms/step - loss: 1.6976 - accuracy: 0.7958 - auc: 0.9945 - val_loss: 2.9447 - val_accuracy: 0.4745 - val_auc: 0.9244
# Epoch 34/1000
# 1562/1562 [==============================] - 314s 201ms/step - loss: 1.6938 - accuracy: 0.7962 - auc: 0.9947 - val_loss: 2.9434 - val_accuracy: 0.4748 - val_auc: 0.9245
#
# Epoch 00034: ReduceLROnPlateau reducing learning rate to 3.199999628122896e-06.
# Epoch 35/1000
# 1562/1562 [==============================] - 316s 202ms/step - loss: 1.6961 - accuracy: 0.7959 - auc: 0.9945 - val_loss: 2.9446 - val_accuracy: 0.4746 - val_auc: 0.9244
# Epoch 36/1000
# 1562/1562 [==============================] - 314s 201ms/step - loss: 1.6970 - accuracy: 0.7958 - auc: 0.9947 - val_loss: 2.9442 - val_accuracy: 0.4747 - val_auc: 0.9244
# Epoch 37/1000
# 1562/1562 [==============================] - 314s 201ms/step - loss: 1.6970 - accuracy: 0.7941 - auc: 0.9946 - val_loss: 2.9448 - val_accuracy: 0.4751 - val_auc: 0.9244
# Restoring model weights from the end of the best epoch.
#
# Epoch 00037: ReduceLROnPlateau reducing learning rate to 6.399999165296323e-07.
# Epoch 00037: early stopping
