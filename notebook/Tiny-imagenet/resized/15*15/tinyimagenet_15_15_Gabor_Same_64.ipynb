# %% [markdown]
# <a href="https://colab.research.google.com/github/mehang/Improvised-CNN/blob/master/notebook/Tiny-imagenet/resized/15*15/tinyimagenet_15_15_Gabor_Same_64.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import matplotlib.pyplot as plt
import numpy as np
import os
import PIL
import tensorflow as tf
import pandas as pd

from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import pathlib
import time

from tensorflow.keras.preprocessing.image import ImageDataGenerator, load_img
from tensorflow.keras.utils import to_categorical
from sklearn.model_selection import train_test_split

# %%
# !unzip /content/drive/My\ Drive/Mehang\ Rai/tiny-imagenet-128.zip -d tiny-imagenet-128

# %%
ITERATION = 10
IMAGE_WIDTH=128
IMAGE_HEIGHT=128
IMAGE_SIZE=(IMAGE_WIDTH, IMAGE_HEIGHT)
IMAGE_CHANNELS=3
RANDOM_SEED = [42,42,34,56,62,74,29,15,7,81][ITERATION-1]
BATCH_SIZE = 64
NUM_CLASSES = 200
EPOCHS = 1000
GABOR_LAYER_INDEX = 0
GABOR_WIDTH = 15
GABOR_HEIGHT = 15
GABOR_SIZE = (GABOR_WIDTH, GABOR_HEIGHT)
NUM_RECEPTIVE_FILTERS = 64
TRAIN_DIR = "tiny-imagenet-128/tiny-imagenet-128/train/"
TEST_DIR = "tiny-imagenet-128/tiny-imagenet-128/test/"

# %%
filenames = os.listdir(TRAIN_DIR)
categories = []
for filename in filenames:
    category = filename.split('.')[0]
    categories.append(category)

train_df = pd.DataFrame({
    'filename': filenames,
    'category': categories
})

filenames = os.listdir(TEST_DIR)
categories = []
for filename in filenames:
    category = filename.split('.')[0]
    categories.append(category)

validate_df = pd.DataFrame({
    'filename': filenames,
    'category': categories
})

# %%
train_df = train_df.reset_index(drop=True)
validate_df = validate_df.reset_index(drop=True)
total_train = train_df.shape[0]
total_validate = validate_df.shape[0]

# %%
train_df['category'].value_counts().plot.bar()

# %%
validate_df['category'].value_counts().plot.bar()

# %%
from tensorflow.image import random_flip_left_right, random_crop, random_saturation
def preprocess(image):
  image = np.array(image)
  image = random_flip_left_right(image)
  image = random_saturation(image, 0.5, 2.0)
  return image


train_datagen = ImageDataGenerator(
    width_shift_range=0.2,
    height_shift_range=0.2,
    preprocessing_function=preprocess,
    rescale=1./255,
)
train_generator = train_datagen.flow_from_dataframe(
    train_df, 
    TRAIN_DIR, 
    x_col='filename',
    y_col='category',
    target_size=(IMAGE_SIZE),
    class_mode='categorical',
    batch_size=BATCH_SIZE
)
# Out:
# Found 100000 validated image filenames belonging to 200 classes.

# %%
validation_datagen = ImageDataGenerator(
    rescale=1./255)
validation_generator = validation_datagen.flow_from_dataframe(
    validate_df, 
    TEST_DIR, 
    x_col='filename',
    y_col='category',
    target_size=IMAGE_SIZE,
    class_mode='categorical',
    batch_size=BATCH_SIZE
)
# Out:
# Found 10000 validated image filenames belonging to 200 classes.

# %%
print(train_df.shape)
print(validate_df.shape)
# Out:
# (100000, 2)
# (10000, 2)

# %%
train_generator.image_shape
# Out:
# (128, 128, 3)

# %%
NUM_CLASSES = len(train_df['category'].value_counts())
print(NUM_CLASSES)
# Out:
# 200

# %%
import math

def get_gabor_filters(inchannels, outchannels, kernel_size = (3,3)):
    delta = 1e-4
    freqs = (math.pi/2)*(math.sqrt(2)**(-np.random.randint(0,5, (outchannels, inchannels))))
    thetas = (math.pi/8)*np.random.randint(0,8, (outchannels, inchannels))
    sigmas = math.pi/(freqs)
    psis = math.pi * np.random.rand(outchannels, inchannels)
    x0, y0 = np.ceil(np.array(kernel_size)/2)    
    
    y, x = np.meshgrid(
            np.linspace(-x0 + 1, x0 + 0, kernel_size[0]),
            np.linspace(-y0 + 1, y0 + 0, kernel_size[1]),
    )
    filterbank = []
    
    for i in range(outchannels):
        for j in range(inchannels):
            freq = freqs[i][j]
            theta = thetas[i][j]
            sigma = sigmas[i][j]
            psi = psis[i][j]
            
            rotx = x * np.cos(theta) + y * np.sin(theta)
            roty = -x * np.sin(theta) + y * np.cos(theta)

            g = np.exp(
                -0.5 * ((rotx ** 2 + roty ** 2) / (sigma + delta) ** 2)
            )
            g = g * np.cos(freq * rotx + psi)
#             g = g / (2 * math.pi * (sigma ** 2))
#             g = gabor_kernel(frequency=freq, bandwidth=sigma, theta=theta, offset=psi, n_stds=0).real
            filterbank.append(g)
    return filterbank

filterbank = get_gabor_filters(3, NUM_RECEPTIVE_FILTERS, GABOR_SIZE)

fig = plt.subplots(8, len(filterbank)//8, figsize=(22,22))
for i,gf in enumerate(filterbank):
    plt.subplot(8, len(filterbank)//8, i+1)
    plt.imshow(gf, cmap='gray')
    plt.axis('off')

# %%
# Importing the Keras libraries and packages
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Activation
from tensorflow.keras.layers import Input, Dense, Dropout, BatchNormalization
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import RMSprop, Adam, SGD
from tensorflow.keras.regularizers import L2
from tensorflow.keras.models import Sequential
from tensorflow.keras import layers
from tensorflow.keras.losses import CategoricalCrossentropy
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau

# with width, height and preprocessing
classifier = None
classifier = Sequential([
    layers.Conv2D(NUM_RECEPTIVE_FILTERS, kernel_size=GABOR_SIZE, strides=(1,1), padding='same', activation='relu',  name="GaborLayer", input_shape=train_generator.image_shape),
    layers.Conv2D(64, kernel_size=(3,3), strides=(1,1), padding='same', activation='relu'),
    layers.MaxPooling2D(pool_size=(2,2), strides=(2,2)),
    layers.Conv2D(128, kernel_size=(3,3), strides=(1,1), padding='same', activation='relu'),
    layers.Conv2D(128, kernel_size=(3,3), strides=(1,1), padding='same', activation='relu'),
    layers.MaxPooling2D(pool_size=(2,2), strides=(2,2)),
    layers.Conv2D(256, kernel_size=(3,3), strides=(1,1), padding='same', activation='relu'),
    layers.Conv2D(256, kernel_size=(3,3), strides=(1,1), padding='same', activation='relu'),
    layers.Conv2D(256, kernel_size=(3,3), strides=(1,1), padding='same', activation='relu'),
    layers.MaxPooling2D(pool_size=(2,2), strides=(2,2)),
    layers.Conv2D(512, kernel_size=(3,3), strides=(1,1), padding='same', activation='relu'),
    layers.Conv2D(512, kernel_size=(3,3), strides=(1,1), padding='same', activation='relu'),
    layers.Conv2D(512, kernel_size=(3,3), strides=(1,1), padding='same', activation='relu'),
    layers.MaxPooling2D(pool_size=(2,2), strides=(2,2)),
    layers.Flatten(),
    layers.Dense(4096, activation='relu'),
    layers.Dropout(0.1),
    layers.Dense(2048, activation='relu'),
    layers.Dropout(0.1),
    layers.Dense(NUM_CLASSES, activation='softmax')
])

classifier.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# GaborLayer (Conv2D)          (None, 128, 128, 64)      43264
# _________________________________________________________________
# conv2d (Conv2D)              (None, 128, 128, 64)      36928
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 64, 64, 64)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 64, 64, 128)       73856
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 64, 64, 128)       147584
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 32, 32, 128)       0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 32, 32, 256)       295168
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 32, 32, 256)       590080
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 32, 32, 256)       590080
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 16, 16, 256)       0
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 16, 16, 512)       1180160
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 16, 16, 512)       2359808
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 16, 16, 512)       2359808
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 8, 8, 512)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 32768)             0
# _________________________________________________________________
# dense (Dense)                (None, 4096)              134221824
# _________________________________________________________________
# dropout (Dropout)            (None, 4096)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 2048)              8390656
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 2048)              0
# _________________________________________________________________
# dense_2 (Dense)              (None, 200)               409800
# =================================================================
# Total params: 150,699,016
# Trainable params: 150,699,016
# Non-trainable params: 0
# _________________________________________________________________

# %%
cnnl1 = classifier.layers[GABOR_LAYER_INDEX].name   # get the name of the first conv layer
W = classifier.get_layer(name=cnnl1).get_weights()[0]   #get the filters
wshape = W.shape  #save the original shape
gabor_filters = W
for kernel_index in range(wshape[3]):
    for channel_index in range(3):
        gabor_filters[:,:,channel_index, kernel_index] = filterbank[kernel_index]

classifier.get_layer(name=cnnl1).set_weights([gabor_filters, classifier.get_layer(name=cnnl1).get_weights()[1]])
filter_layers = []
for i in range(NUM_RECEPTIVE_FILTERS):
    for j in range(3):
        filter_layers.append(np.reshape(W[:,:,j, i], GABOR_SIZE))
for i,gf in enumerate(filter_layers):
    plt.subplot(8, len(filter_layers)//8, i+1)
    plt.imshow(gf, cmap='gray')
    plt.axis('off')
plt.savefig('tinyimagenet-{}-initial-gabor-same-kernel-{}.png'.format(ITERATION,GABOR_WIDTH), dpi=350, bbox_inches='tight')

import copy
untrained_layers = copy.deepcopy(classifier.get_layer(name=classifier.layers[GABOR_LAYER_INDEX].name).get_weights())

# %%
print(classifier.layers[GABOR_LAYER_INDEX].trainable)
classifier.layers[GABOR_LAYER_INDEX].trainable = False
print(classifier.layers[GABOR_LAYER_INDEX].trainable)
# Out:
# True
# False

# %%
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=1/5, patience=3,  
                              min_delta=1e-4, mode='min', verbose=1)
stop_alg = EarlyStopping(monitor='val_loss', patience=15, 
                         restore_best_weights=True, verbose=1)
callbacks = [stop_alg, reduce_lr]
opt = SGD(learning_rate=0.01, momentum=0.9, nesterov=True)

classifier.compile(loss=CategoricalCrossentropy(label_smoothing=0.1), optimizer=opt, metrics=['accuracy', 'AUC'])

start = time.perf_counter()
hist = classifier.fit(
    train_generator, 
    epochs=EPOCHS,
    validation_data=validation_generator,
    validation_steps=total_validate//BATCH_SIZE,
    steps_per_epoch=total_train//BATCH_SIZE,
    callbacks=callbacks
)
finish = time.perf_counter()
# Out:
# Epoch 1/1000
# 1562/1562 [==============================] - 695s 433ms/step - loss: 5.1809 - accuracy: 0.0155 - auc: 0.6020 - val_loss: 4.8719 - val_accuracy: 0.0445 - val_auc: 0.7352
# Epoch 2/1000
# 1562/1562 [==============================] - 673s 431ms/step - loss: 4.7410 - accuracy: 0.0613 - auc: 0.7637 - val_loss: 4.4580 - val_accuracy: 0.1052 - val_auc: 0.8112
# Epoch 3/1000
# 1562/1562 [==============================] - 671s 429ms/step - loss: 4.3769 - accuracy: 0.1121 - auc: 0.8290 - val_loss: 4.0901 - val_accuracy: 0.1630 - val_auc: 0.8671
# Epoch 4/1000
# 1562/1562 [==============================] - 672s 430ms/step - loss: 4.1002 - accuracy: 0.1631 - auc: 0.8621 - val_loss: 3.8773 - val_accuracy: 0.2084 - val_auc: 0.8817
# Epoch 5/1000
# 1562/1562 [==============================] - 672s 430ms/step - loss: 3.8714 - accuracy: 0.2087 - auc: 0.8836 - val_loss: 3.7176 - val_accuracy: 0.2456 - val_auc: 0.8918
# Epoch 6/1000
# 1562/1562 [==============================] - 671s 430ms/step - loss: 3.6890 - accuracy: 0.2465 - auc: 0.8987 - val_loss: 3.5174 - val_accuracy: 0.2866 - val_auc: 0.9103
# Epoch 7/1000
# 1562/1562 [==============================] - 669s 428ms/step - loss: 3.5344 - accuracy: 0.2836 - auc: 0.9097 - val_loss: 3.4454 - val_accuracy: 0.3087 - val_auc: 0.9112
# Epoch 8/1000
# 1562/1562 [==============================] - 667s 427ms/step - loss: 3.4102 - accuracy: 0.3108 - auc: 0.9184 - val_loss: 3.3460 - val_accuracy: 0.3302 - val_auc: 0.9166
# Epoch 9/1000
# 1562/1562 [==============================] - 669s 428ms/step - loss: 3.2962 - accuracy: 0.3373 - auc: 0.9258 - val_loss: 3.2943 - val_accuracy: 0.3461 - val_auc: 0.9211
# Epoch 10/1000
# 1562/1562 [==============================] - 670s 429ms/step - loss: 3.1898 - accuracy: 0.3650 - auc: 0.9323 - val_loss: 3.1896 - val_accuracy: 0.3676 - val_auc: 0.9271
# Epoch 11/1000
# 1562/1562 [==============================] - 668s 428ms/step - loss: 3.1034 - accuracy: 0.3853 - auc: 0.9373 - val_loss: 3.2020 - val_accuracy: 0.3701 - val_auc: 0.9250
# Epoch 12/1000
# 1562/1562 [==============================] - 668s 428ms/step - loss: 3.0147 - accuracy: 0.4073 - auc: 0.9428 - val_loss: 3.1413 - val_accuracy: 0.3872 - val_auc: 0.9265
# Epoch 13/1000
# 1562/1562 [==============================] - 669s 428ms/step - loss: 2.9410 - accuracy: 0.4271 - auc: 0.9462 - val_loss: 3.1224 - val_accuracy: 0.3868 - val_auc: 0.9289
# Epoch 14/1000
# 1562/1562 [==============================] - 669s 428ms/step - loss: 2.8686 - accuracy: 0.4455 - auc: 0.9506 - val_loss: 3.1077 - val_accuracy: 0.4014 - val_auc: 0.9262
# Epoch 15/1000
# 1562/1562 [==============================] - 668s 428ms/step - loss: 2.7965 - accuracy: 0.4621 - auc: 0.9548 - val_loss: 3.0620 - val_accuracy: 0.4156 - val_auc: 0.9291
# Epoch 16/1000
# 1562/1562 [==============================] - 670s 429ms/step - loss: 2.7386 - accuracy: 0.4777 - auc: 0.9575 - val_loss: 3.0832 - val_accuracy: 0.4103 - val_auc: 0.9276
# Epoch 17/1000
# 1562/1562 [==============================] - 669s 428ms/step - loss: 2.6752 - accuracy: 0.4936 - auc: 0.9609 - val_loss: 3.0536 - val_accuracy: 0.4187 - val_auc: 0.9272
# Epoch 18/1000
# 1562/1562 [==============================] - 669s 428ms/step - loss: 2.6279 - accuracy: 0.5083 - auc: 0.9628 - val_loss: 3.0973 - val_accuracy: 0.4119 - val_auc: 0.9243
# Epoch 19/1000
# 1562/1562 [==============================] - 670s 429ms/step - loss: 2.5753 - accuracy: 0.5229 - auc: 0.9653 - val_loss: 3.0810 - val_accuracy: 0.4219 - val_auc: 0.9225
# Epoch 20/1000
# 1562/1562 [==============================] - 670s 429ms/step - loss: 2.5179 - accuracy: 0.5373 - auc: 0.9676 - val_loss: 3.0590 - val_accuracy: 0.4290 - val_auc: 0.9242
#
# Epoch 00020: ReduceLROnPlateau reducing learning rate to 0.0019999999552965165.
# Epoch 21/1000
# 1562/1562 [==============================] - 669s 428ms/step - loss: 2.2056 - accuracy: 0.6326 - auc: 0.9807 - val_loss: 2.9163 - val_accuracy: 0.4643 - val_auc: 0.9310
# Epoch 22/1000
# 1562/1562 [==============================] - 669s 429ms/step - loss: 2.1014 - accuracy: 0.6659 - auc: 0.9835 - val_loss: 2.9252 - val_accuracy: 0.4626 - val_auc: 0.9301
# Epoch 23/1000
# 1562/1562 [==============================] - 670s 429ms/step - loss: 2.0538 - accuracy: 0.6798 - auc: 0.9851 - val_loss: 2.9262 - val_accuracy: 0.4644 - val_auc: 0.9302
# Epoch 24/1000
# 1562/1562 [==============================] - 669s 428ms/step - loss: 2.0102 - accuracy: 0.6929 - auc: 0.9864 - val_loss: 2.9316 - val_accuracy: 0.4689 - val_auc: 0.9286
#
# Epoch 00024: ReduceLROnPlateau reducing learning rate to 0.0003999999724328518.
# Epoch 25/1000
# 1562/1562 [==============================] - 677s 433ms/step - loss: 1.9317 - accuracy: 0.7203 - auc: 0.9888 - val_loss: 2.9051 - val_accuracy: 0.4728 - val_auc: 0.9301
# Epoch 26/1000
# 1562/1562 [==============================] - 680s 435ms/step - loss: 1.9109 - accuracy: 0.7268 - auc: 0.9896 - val_loss: 2.9166 - val_accuracy: 0.4702 - val_auc: 0.9294
# Epoch 27/1000
# 1562/1562 [==============================] - 680s 435ms/step - loss: 1.8994 - accuracy: 0.7302 - auc: 0.9898 - val_loss: 2.9176 - val_accuracy: 0.4715 - val_auc: 0.9286
# Epoch 28/1000
# 1562/1562 [==============================] - 679s 435ms/step - loss: 1.8887 - accuracy: 0.7344 - auc: 0.9901 - val_loss: 2.9193 - val_accuracy: 0.4692 - val_auc: 0.9295
#
# Epoch 00028: ReduceLROnPlateau reducing learning rate to 7.999999215826393e-05.
# Epoch 29/1000
# 1562/1562 [==============================] - 680s 436ms/step - loss: 1.8721 - accuracy: 0.7397 - auc: 0.9905 - val_loss: 2.9162 - val_accuracy: 0.4725 - val_auc: 0.9295
# Epoch 30/1000
# 1562/1562 [==============================] - 681s 436ms/step - loss: 1.8750 - accuracy: 0.7398 - auc: 0.9903 - val_loss: 2.9154 - val_accuracy: 0.4727 - val_auc: 0.9292
# Epoch 31/1000
# 1562/1562 [==============================] - 681s 436ms/step - loss: 1.8661 - accuracy: 0.7423 - auc: 0.9905 - val_loss: 2.9170 - val_accuracy: 0.4734 - val_auc: 0.9293
#
# Epoch 00031: ReduceLROnPlateau reducing learning rate to 1.599999814061448e-05.
# Epoch 32/1000
# 1562/1562 [==============================] - 682s 436ms/step - loss: 1.8607 - accuracy: 0.7453 - auc: 0.9905 - val_loss: 2.9142 - val_accuracy: 0.4737 - val_auc: 0.9296
# Epoch 33/1000
# 1562/1562 [==============================] - 681s 436ms/step - loss: 1.8628 - accuracy: 0.7439 - auc: 0.9906 - val_loss: 2.9162 - val_accuracy: 0.4746 - val_auc: 0.9296
# Epoch 34/1000
# 1562/1562 [==============================] - 682s 436ms/step - loss: 1.8598 - accuracy: 0.7448 - auc: 0.9905 - val_loss: 2.9146 - val_accuracy: 0.4746 - val_auc: 0.9293
#
# Epoch 00034: ReduceLROnPlateau reducing learning rate to 3.199999628122896e-06.
# Epoch 35/1000
# 1562/1562 [==============================] - 682s 436ms/step - loss: 1.8603 - accuracy: 0.7445 - auc: 0.9908 - val_loss: 2.9141 - val_accuracy: 0.4751 - val_auc: 0.9295
# Epoch 36/1000
# 1562/1562 [==============================] - 678s 434ms/step - loss: 1.8626 - accuracy: 0.7439 - auc: 0.9908 - val_loss: 2.9151 - val_accuracy: 0.4748 - val_auc: 0.9294
# Epoch 37/1000
# 1562/1562 [==============================] - 678s 434ms/step - loss: 1.8655 - accuracy: 0.7423 - auc: 0.9908 - val_loss: 2.9148 - val_accuracy: 0.4747 - val_auc: 0.9295
#
# Epoch 00037: ReduceLROnPlateau reducing learning rate to 6.399999165296323e-07.
# Epoch 38/1000
# 1562/1562 [==============================] - 678s 434ms/step - loss: 1.8606 - accuracy: 0.7439 - auc: 0.9909 - val_loss: 2.9165 - val_accuracy: 0.4743 - val_auc: 0.9294
# Epoch 39/1000
# 1562/1562 [==============================] - 678s 434ms/step - loss: 1.8616 - accuracy: 0.7442 - auc: 0.9908 - val_loss: 2.9168 - val_accuracy: 0.4740 - val_auc: 0.9291
# Epoch 40/1000
# 1562/1562 [==============================] - 679s 434ms/step - loss: 1.8606 - accuracy: 0.7434 - auc: 0.9909 - val_loss: 2.9141 - val_accuracy: 0.4745 - val_auc: 0.9294
# Restoring model weights from the end of the best epoch.
#
# Epoch 00040: ReduceLROnPlateau reducing learning rate to 1.2799998785339995e-07.
# Epoch 00040: early stopping

# %%
print("Start time = {}".format(start))
print("Finish time = {}".format(finish))
print("Training time = {}".format(finish-start))
hist.history['start_time'] = start
hist.history['finish_time'] = finish
hist.history['train_time'] = finish-start
# Out:
# Start time = 1853.178749903
# Finish time = 28981.189359769
# Training time = 27128.010609866

# %%
import pickle

trained_layers = copy.deepcopy(classifier.get_layer(name=classifier.layers[GABOR_LAYER_INDEX].name).get_weights())
hist.history['untrained_layers'] = untrained_layers
hist.history['trained_layers'] = trained_layers

with open('tinyimagenet-{}-history-gabor-same-kernel-{}.p'.format(ITERATION, GABOR_WIDTH),'wb') as fp:
    pickle.dump(hist.history, fp, protocol=pickle.HIGHEST_PROTOCOL)

# %%
import matplotlib.pyplot as plt

fig = plt.figure(figsize=(10,6))
plt.plot(hist.history['loss'], color='#785ef0')
plt.plot(hist.history['val_loss'], color='#dc267f')
plt.title('Model Loss Progress')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Training Set', 'Test Set'], loc='upper right')
plt.savefig('tinyimagenet-{}-loss-gabor-same-kernel-{}.png'.format(ITERATION,GABOR_WIDTH), dpi=350, bbox_inches='tight')
plt.show()

# %%
fig = plt.figure(figsize=(10,6))
plt.plot(hist.history['accuracy'], color='#785ef0')
plt.plot(hist.history['val_accuracy'], color='#dc267f')
plt.title('Model Accuracy Progress')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Training Set', 'Test Set'], loc='upper right')
plt.savefig('tinyimagenet-{}-accuracy-gabor-same-kernel-{}.png'.format(ITERATION, GABOR_WIDTH), dpi=350, bbox_inches='tight')
plt.show()

# %%
from sklearn.preprocessing import MinMaxScaler

cnnl1 = classifier.layers[GABOR_LAYER_INDEX].name   # get the name of the first conv layer
W = classifier.get_layer(name=cnnl1).get_weights()[0]   #get the filters
wshape = W.shape  #save the original shape

# this part will scale to [0, 1] for visualization purposes
scaler = MinMaxScaler()
scaler.fit(W.reshape(-1,1))
W = scaler.transform(W.reshape(-1,1))
W = W.reshape(wshape)

fig, axs = plt.subplots(8,NUM_RECEPTIVE_FILTERS//8, figsize=(24,24))
fig.subplots_adjust(hspace = .25, wspace=.001)
axs = axs.ravel()
for i in range(W.shape[-1]):
  # we reshape to a 3D (RGB) image shape and display
  h = np.reshape(W[:,:,:,i], (GABOR_WIDTH,GABOR_HEIGHT,3))
  axs[i].imshow(h)
  axs[i].set_title('Filter ' + str(i))    
plt.savefig("tinyimagenet-{}-filters-gabor-same-kernel-{}.png".format(ITERATION,GABOR_WIDTH), bbox_inches='tight', dpi=350)

# %%
cnnl1 = classifier.layers[GABOR_LAYER_INDEX].name   # get the name of the first conv layer
W = classifier.get_layer(name=cnnl1).get_weights()[0]
plt.hist(W.ravel(), bins=100)
print(np.min(W),np.max(W))
# Out:
# -0.993793 0.9948888

# %%
filter_layers = []
for i in range(NUM_RECEPTIVE_FILTERS):
    for j in range(3):
        filter_layers.append(np.reshape(W[:,:,j, i], GABOR_SIZE))
for i,gf in enumerate(filter_layers):
    plt.subplot(8, (W.shape[3]*3)//8, i+1)
    plt.imshow(gf, cmap='gray')
    plt.axis('off')
plt.savefig("tinyimagenet-{}-channelwise-gabor-same-filters-kernel-{}.png".format(ITERATION,GABOR_WIDTH), bbox_inches='tight', dpi=350)

# %%
# !cp tinyimagenet-10-initial-gabor-same-kernel-15.png /content/drive/My\ Drive/Mehang\ Rai/analysis/freezing/tinyimagenet-128/10/

# %%
# !cp tinyimagenet-10-history-gabor-same-kernel-15.p /content/drive/My\ Drive/Mehang\ Rai/analysis/freezing/tinyimagenet-128/10/

# %%
# !cp tinyimagenet-10-loss-gabor-same-kernel-15.png /content/drive/My\ Drive/Mehang\ Rai/analysis/freezing/tinyimagenet-128/10/

# %%
# !cp tinyimagenet-10-accuracy-gabor-same-kernel-15.png /content/drive/My\ Drive/Mehang\ Rai/analysis/freezing/tinyimagenet-128/10/

# %%
# !cp tinyimagenet-10-filters-gabor-same-kernel-15.png /content/drive/My\ Drive/Mehang\ Rai/analysis/freezing/tinyimagenet-128/10/

# %%
# !cp tinyimagenet-10-channelwise-gabor-same-filters-kernel-15.png /content/drive/My\ Drive/Mehang\ Rai/analysis/freezing/tinyimagenet-128/10/
