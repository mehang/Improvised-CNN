# %%
from skimage.filters import gabor_kernel
from skimage import io
from skimage.transform import resize
from matplotlib import pyplot as plt 
import numpy as np

import math

# %%
def get_gabor_filters(inchannels, outchannels, kernel_size = (3,3)):
    delta = 1e-4
    freqs = (math.pi/2)*math.sqrt(2)**(-np.random.randint(0,5, (outchannels, inchannels)))
    thetas = (math.pi/8)*np.random.randint(0,8, (outchannels, inchannels))
    sigmas = math.pi/freqs
    psis = math.pi * np.random.rand(outchannels, inchannels)
    x0, y0 = np.ceil(np.array(kernel_size)/2)    
    
    y, x = np.meshgrid(
            np.linspace(-x0 + 1, x0 + 0, kernel_size[0]),
            np.linspace(-y0 + 1, y0 + 0, kernel_size[1]),
    )
    filterbank = []
    
    for i in range(outchannels):
        for j in range(inchannels):
            freq = freqs[i][j]
            theta = thetas[i][j]
            sigma = sigmas[i][j]
            psi = psis[i][j]
            
            rotx = x * np.cos(theta) + y * np.sin(theta)
            roty = -x * np.sin(theta) + y * np.cos(theta)

            g = np.exp(
                -0.5 * ((rotx ** 2 + roty ** 2) / (sigma + delta) ** 2)
            )
            g = g * np.cos(freq * rotx + psi)
            g = g / (2 * math.pi * sigma ** 2)
            filterbank.append(g)
    return filterbank

filterbank = get_gabor_filters(3, 64, (9,9))

fig = plt.subplots(12, 16, figsize=(22,22))
for i,gf in enumerate(filterbank):
    plt.subplot(12, 16, i+1)
    plt.imshow(gf, cmap='gray')
    plt.axis('off')

# %%
from tensorflow.keras.datasets import cifar10
from tensorflow.keras.utils import to_categorical

# The data, split between train and test sets:
(x_train, y_train), (x_test, y_test) = cifar10.load_data()
x_train = x_train.astype('float32') / 255.0
x_test = x_test.astype('float32') / 255.0

y_train = to_categorical(y_train, 10)
y_test = to_categorical(y_test, 10)

print('x_train shape:', x_train.shape)
print('x_test shape:', x_test.shape)
# Out:
# x_train shape: (50000, 32, 32, 3)
# x_test shape: (10000, 32, 32, 3)

# %%
# Importing the Keras libraries and packages
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Activation
from tensorflow.keras.layers import Input, Dense, Dropout, BatchNormalization
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import RMSprop, Adam

input_dim = (32,32,3)
input_img = Input(shape=input_dim)

cl1 = Conv2D(64, kernel_size=(9,9), strides=(1,1), padding='same',
             input_shape=input_dim, activation='relu')(input_img)
pl1 = MaxPooling2D(pool_size=(2,2), strides=(2,2))(cl1)

cl2 = Conv2D(128, kernel_size=(3,3), strides=(1,1), padding='same',
             activation='relu')(pl1)
pl2 = MaxPooling2D(pool_size=(2,2), strides=(2,2))(cl2)

cl3 = Conv2D(256, kernel_size=(3,3), strides=(1,1), padding='same',
             activation='relu')(pl2)
pl3 = MaxPooling2D(pool_size=(2,2), strides=(2,2))(cl3)

cl4 = Conv2D(512, kernel_size=(3,3), strides=(1,1), padding='same',
             activation='relu')(pl3)
pl4 = MaxPooling2D(pool_size=(2,2), strides=(2,2))(cl4)

cl5 = Conv2D(512, kernel_size=(3,3), strides=(1,1), padding='same',
             activation='relu')(pl4)
pl5 = MaxPooling2D(pool_size=(2,2), strides=(2,2))(cl5)

flat = Flatten()(pl5)

fc6 = Dense(units=4096, activation='relu')(flat)
fc7 = Dense(units=4096, activation='relu')(fc6)

output = Dense(units=10, activation='softmax')(fc7)

classifier = Model(input_img, output)

# Compiling the CNN
opt = RMSprop(learning_rate=0.001)
# opt = Adam(learning_rate=0.01)

classifier.compile(optimizer = opt, loss = 'binary_crossentropy', 
                   metrics = ['accuracy'])

print(classifier.summary())
# Out:
# Model: "functional_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 32, 32, 3)]       0
# _________________________________________________________________
# conv2d (Conv2D)              (None, 32, 32, 64)        15616
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 16, 16, 64)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 16, 16, 128)       73856
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 8, 8, 128)         0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 8, 8, 256)         295168
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 4, 4, 256)         0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 4, 4, 512)         1180160
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 2, 2, 512)         0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 2, 2, 512)         2359808
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 1, 1, 512)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 512)               0
# _________________________________________________________________
# dense (Dense)                (None, 4096)              2101248
# _________________________________________________________________
# dense_1 (Dense)              (None, 4096)              16781312
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                40970
# =================================================================
# Total params: 22,848,138
# Trainable params: 22,848,138
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
cnnl1 = classifier.layers[1].name   # get the name of the first conv layer
W = classifier.get_layer(name=cnnl1).get_weights()[0]   #get the filters
wshape = W.shape  #save the original shape

gabor_filters = W
for kernel_index in range(wshape[3]):
    for channel_index in range(3):
        gabor_filters[:,:,channel_index, kernel_index] = filterbank[kernel_index+channel_index]

cnnl1 = classifier.layers[1].name   # get the name of the first conv layer
classifier.get_layer(name=cnnl1).set_weights([gabor_filters, classifier.get_layer(name=cnnl1).get_weights()[1]])
filter_layers = []
for i in range(64):
    for j in range(3):
        filter_layers.append(np.reshape(W[:,:,j, i], (9,9)))
for i,gf in enumerate(filter_layers):
    plt.subplot(12, 16, i+1)
    plt.imshow(gf, cmap='gray')
    plt.axis('off')

# %%
# Fitting the CNN to the images

from tensorflow.keras.callbacks import ReduceLROnPlateau, EarlyStopping

reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=10,  
                              min_delta=1e-4, mode='min', verbose=1)

stop_alg = EarlyStopping(monitor='val_loss', patience=35, 
                         restore_best_weights=True, verbose=1)

hist = classifier.fit(x_train, y_train, batch_size=100, epochs=1000, 
                   callbacks=[stop_alg, reduce_lr], shuffle=True, 
                   validation_data=(x_test, y_test))
# Out:
# Epoch 1/1000
# 500/500 [==============================] - 860s 2s/step - loss: 0.3247 - accuracy: 0.1311 - val_loss: 0.3044 - val_accuracy: 0.1736
# Epoch 2/1000
# 500/500 [==============================] - 1549s 3s/step - loss: 0.2670 - accuracy: 0.3369 - val_loss: 0.2314 - val_accuracy: 0.4477
# Epoch 3/1000
# 500/500 [==============================] - 1589s 3s/step - loss: 0.2211 - accuracy: 0.4850 - val_loss: 0.1986 - val_accuracy: 0.5502
# Epoch 4/1000
# 500/500 [==============================] - 1605s 3s/step - loss: 0.1925 - accuracy: 0.5707 - val_loss: 0.1938 - val_accuracy: 0.5655
# Epoch 5/1000
# 500/500 [==============================] - 1590s 3s/step - loss: 0.1696 - accuracy: 0.6293 - val_loss: 0.1692 - val_accuracy: 0.6296
# Epoch 6/1000
# 500/500 [==============================] - 1136s 2s/step - loss: 0.1520 - accuracy: 0.6755 - val_loss: 0.1718 - val_accuracy: 0.6433
# Epoch 7/1000
# 500/500 [==============================] - 822s 2s/step - loss: 0.1375 - accuracy: 0.7091 - val_loss: 0.1779 - val_accuracy: 0.6301
# Epoch 8/1000
# 500/500 [==============================] - 819s 2s/step - loss: 0.1269 - accuracy: 0.7358 - val_loss: 0.1878 - val_accuracy: 0.6600
# Epoch 9/1000
# 500/500 [==============================] - 826s 2s/step - loss: 0.1172 - accuracy: 0.7602 - val_loss: 0.1647 - val_accuracy: 0.6677
# Epoch 10/1000
# 500/500 [==============================] - 845s 2s/step - loss: 0.1076 - accuracy: 0.7821 - val_loss: 0.1712 - val_accuracy: 0.6715
# Epoch 11/1000
# 500/500 [==============================] - 929s 2s/step - loss: 0.1020 - accuracy: 0.7958 - val_loss: 0.1834 - val_accuracy: 0.6612
# Epoch 12/1000
# 500/500 [==============================] - 850s 2s/step - loss: 0.0939 - accuracy: 0.8145 - val_loss: 0.1891 - val_accuracy: 0.6190
# Epoch 13/1000
# 500/500 [==============================] - 819s 2s/step - loss: 0.0887 - accuracy: 0.8247 - val_loss: 0.1897 - val_accuracy: 0.6855
# Epoch 14/1000
# 500/500 [==============================] - 818s 2s/step - loss: 0.0865 - accuracy: 0.8306 - val_loss: 0.2257 - val_accuracy: 0.6582
# Epoch 15/1000
# 500/500 [==============================] - 818s 2s/step - loss: 0.0818 - accuracy: 0.8448 - val_loss: 0.2223 - val_accuracy: 0.6893
# Epoch 16/1000
# 500/500 [==============================] - 819s 2s/step - loss: 0.0764 - accuracy: 0.8531 - val_loss: 0.1909 - val_accuracy: 0.6897
# Epoch 17/1000
# 500/500 [==============================] - 818s 2s/step - loss: 0.0743 - accuracy: 0.8597 - val_loss: 0.2713 - val_accuracy: 0.6889
# Epoch 18/1000
# 500/500 [==============================] - 829s 2s/step - loss: 0.0721 - accuracy: 0.8676 - val_loss: 0.1996 - val_accuracy: 0.6927
# Epoch 19/1000
# 500/500 [==============================] - ETA: 0s - loss: 0.0732 - accuracy: 0.8672
# Epoch 00019: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 500/500 [==============================] - 828s 2s/step - loss: 0.0732 - accuracy: 0.8672 - val_loss: 0.2030 - val_accuracy: 0.6972
# Epoch 20/1000
# 500/500 [==============================] - 828s 2s/step - loss: 0.0357 - accuracy: 0.9356 - val_loss: 0.2623 - val_accuracy: 0.7012
# Epoch 21/1000
# 500/500 [==============================] - 813s 2s/step - loss: 0.0300 - accuracy: 0.9484 - val_loss: 0.3031 - val_accuracy: 0.7099
# Epoch 22/1000
# 500/500 [==============================] - 793s 2s/step - loss: 0.0282 - accuracy: 0.9524 - val_loss: 0.3210 - val_accuracy: 0.6727
# Epoch 23/1000
# 500/500 [==============================] - 793s 2s/step - loss: 0.0287 - accuracy: 0.9547 - val_loss: 0.2944 - val_accuracy: 0.7042
# Epoch 24/1000
# 500/500 [==============================] - 798s 2s/step - loss: 0.0281 - accuracy: 0.9562 - val_loss: 0.3122 - val_accuracy: 0.6925
# Epoch 25/1000
# 500/500 [==============================] - 795s 2s/step - loss: 0.0277 - accuracy: 0.9568 - val_loss: 0.3506 - val_accuracy: 0.7078
# Epoch 26/1000
# 500/500 [==============================] - 793s 2s/step - loss: 0.0255 - accuracy: 0.9611 - val_loss: 0.3318 - val_accuracy: 0.7062
# Epoch 27/1000
# 500/500 [==============================] - 792s 2s/step - loss: 0.0260 - accuracy: 0.9613 - val_loss: 0.3198 - val_accuracy: 0.6929
# Epoch 28/1000
# 500/500 [==============================] - 795s 2s/step - loss: 0.0259 - accuracy: 0.9613 - val_loss: 0.3638 - val_accuracy: 0.7062
# Epoch 29/1000
# 500/500 [==============================] - ETA: 0s - loss: 0.0241 - accuracy: 0.9644
# Epoch 00029: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 500/500 [==============================] - 797s 2s/step - loss: 0.0241 - accuracy: 0.9644 - val_loss: 0.3617 - val_accuracy: 0.6489
# Epoch 30/1000
# 500/500 [==============================] - 789s 2s/step - loss: 0.0114 - accuracy: 0.9842 - val_loss: 0.4058 - val_accuracy: 0.7099
# Epoch 31/1000
# 500/500 [==============================] - 791s 2s/step - loss: 0.0104 - accuracy: 0.9866 - val_loss: 0.4190 - val_accuracy: 0.7194
# Epoch 32/1000
# 500/500 [==============================] - 795s 2s/step - loss: 0.0098 - accuracy: 0.9880 - val_loss: 0.4700 - val_accuracy: 0.6844
# Epoch 33/1000
# 500/500 [==============================] - 894s 2s/step - loss: 0.0096 - accuracy: 0.9884 - val_loss: 0.5101 - val_accuracy: 0.7150
# Epoch 34/1000
# 500/500 [==============================] - 821s 2s/step - loss: 0.0094 - accuracy: 0.9888 - val_loss: 0.4991 - val_accuracy: 0.7012
# Epoch 35/1000
# 500/500 [==============================] - 794s 2s/step - loss: 0.0096 - accuracy: 0.9883 - val_loss: 0.4898 - val_accuracy: 0.7096
# Epoch 36/1000
# 500/500 [==============================] - 792s 2s/step - loss: 0.0098 - accuracy: 0.9894 - val_loss: 0.4959 - val_accuracy: 0.7020
# Epoch 37/1000
# 500/500 [==============================] - 792s 2s/step - loss: 0.0116 - accuracy: 0.9882 - val_loss: 0.4718 - val_accuracy: 0.6990
# Epoch 38/1000
# 500/500 [==============================] - 797s 2s/step - loss: 0.0101 - accuracy: 0.9884 - val_loss: 0.4772 - val_accuracy: 0.7016
# Epoch 39/1000
# 500/500 [==============================] - ETA: 0s - loss: 0.0154 - accuracy: 0.9868
# Epoch 00039: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 500/500 [==============================] - 795s 2s/step - loss: 0.0154 - accuracy: 0.9868 - val_loss: 0.5320 - val_accuracy: 0.7123
# Epoch 40/1000
# 500/500 [==============================] - 800s 2s/step - loss: 0.0049 - accuracy: 0.9956 - val_loss: 0.5697 - val_accuracy: 0.7115
# Epoch 41/1000
# 500/500 [==============================] - 791s 2s/step - loss: 0.0051 - accuracy: 0.9965 - val_loss: 0.5334 - val_accuracy: 0.7077
# Epoch 42/1000
# 500/500 [==============================] - 891s 2s/step - loss: 0.0053 - accuracy: 0.9967 - val_loss: 0.6187 - val_accuracy: 0.7144
# Epoch 43/1000
# 500/500 [==============================] - 823s 2s/step - loss: 0.0047 - accuracy: 0.9967 - val_loss: 0.6416 - val_accuracy: 0.7103
# Epoch 44/1000
# 500/500 [==============================] - ETA: 0s - loss: 0.0045 - accuracy: 0.9964Restoring model weights from the end of the best epoch.
# 500/500 [==============================] - 496s 993ms/step - loss: 0.0045 - accuracy: 0.9964 - val_loss: 0.6172 - val_accuracy: 0.7062
# Epoch 00044: early stopping

# %%
import matplotlib.pyplot as plt

fig = plt.figure(figsize=(10,6))
plt.plot(hist.history['loss'], color='#785ef0')
plt.plot(hist.history['val_loss'], color='#dc267f')
plt.title('Model Loss Progress')
plt.ylabel('Binary Cross-Entropy Loss')
plt.xlabel('Epoch')
plt.legend(['Training Set', 'Test Set'], loc='upper right')
plt.savefig('gabor vgg 9*9-cifar-10.loss.png', dpi=350, bbox_inches='tight')
plt.show()

# %%
from sklearn.preprocessing import MinMaxScaler

cnnl1 = classifier.layers[1].name   # get the name of the first conv layer
W = classifier.get_layer(name=cnnl1).get_weights()[0]   #get the filters
wshape = W.shape  #save the original shape

# this part will scale to [0, 1] for visualization purposes
scaler = MinMaxScaler()
scaler.fit(W.reshape(-1,1))
W = scaler.transform(W.reshape(-1,1))
W = W.reshape(wshape)

# since there are 64 filters, we will display them 8x8
fig, axs = plt.subplots(8,8, figsize=(24,24))
fig.subplots_adjust(hspace = .25, wspace=.001)
axs = axs.ravel()
for i in range(W.shape[-1]):
  # we reshape to a 3D (RGB) image shape and display
  h = np.reshape(W[:,:,:,i], (9,9,3))
  axs[i].imshow(h)
  axs[i].set_title('Filter ' + str(i))    
plt.savefig("gabor vgg 9*9-cifar-10.filters.png", bbox_inches='tight', dpi=350)

# %%
cnnl1 = classifier.layers[1].name   # get the name of the first conv layer
W = classifier.get_layer(name=cnnl1).get_weights()[0]
plt.hist(W.ravel(), bins=100)
print(np.min(W),np.max(W))
# Out:
# -0.19182824 0.18059388

# %%
fig = plt.subplots(12, 16, figsize=(22,22))

filter_layers = []
for i in range(64):
    for j in range(3):
        filter_layers.append(np.reshape(W[:,:,j, i], (9,9)))
for i,gf in enumerate(filter_layers):
    plt.subplot(12, 16, i+1)
    plt.imshow(gf, cmap='gray')
    plt.axis('off')
