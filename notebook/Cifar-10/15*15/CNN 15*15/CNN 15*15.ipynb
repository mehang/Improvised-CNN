# %%
from skimage.filters import gabor_kernel
from skimage import io
from skimage.transform import resize
from matplotlib import pyplot as plt 
import numpy as np

# %%
from tensorflow.keras.datasets import cifar10
from tensorflow.keras.utils import to_categorical

# The data, split between train and test sets:
(x_train, y_train), (x_test, y_test) = cifar10.load_data()
x_train = x_train.astype('float32') / 255.0
x_test = x_test.astype('float32') / 255.0

y_train = to_categorical(y_train, 10)
y_test = to_categorical(y_test, 10)

print('x_train shape:', x_train.shape)
print('x_test shape:', x_test.shape)
# Out:
# x_train shape: (50000, 32, 32, 3)
# x_test shape: (10000, 32, 32, 3)

# %%
# Importing the Keras libraries and packages
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Activation
from tensorflow.keras.layers import Input, Dense, Dropout, BatchNormalization
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import RMSprop, Adam

# dimensionality of input and latent encoded representations
inpt_dim = (32, 32, 3)

inpt_img = Input(shape=inpt_dim)

# Block 1
cl1 = Conv2D(32, (15, 15), strides=(1, 1), activation='relu', input_shape = inpt_dim)(inpt_img)
bnl2 = BatchNormalization()(cl1)
# afl3 = Activation('relu')(bnl2)
pl4 = MaxPooling2D(pool_size = (2, 2))(bnl2)

# Adding a second convolutional layer
cl5 = Conv2D(128, (3, 3), strides=(1, 1), activation='relu')(pl4)
bnl6 = BatchNormalization()(cl5)
# afl7 = Activation('relu')(bnl6)
pl8 = MaxPooling2D(pool_size = (2, 2))(bnl6)
bnl9 = BatchNormalization()(pl8)

# Step 3 - Flattening
fl10 = Flatten()(bnl9)

# Step 4 - Full connection
dol11 = Dropout(0.5)(fl10)
dl12 = Dense(units = 256, activation = 'relu')(dol11)
dol13 = Dropout(0.2)(dl12)
dl14 = Dense(units = 64, activation = 'relu')(dol13)
dol15 = Dropout(0.1)(dl14)
output = Dense(units = 10, activation = 'sigmoid')(dol15)

classifier = Model(inpt_img, output)

# Compiling the CNN
opt = RMSprop(learning_rate=0.001)
# opt = Adam(learning_rate=0.01)

classifier.compile(optimizer = opt, loss = 'binary_crossentropy', 
                   metrics = ['accuracy'])

print(classifier.summary())
# Out:
# Model: "functional_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 32, 32, 3)]       0
# _________________________________________________________________
# conv2d (Conv2D)              (None, 18, 18, 32)        21632
# _________________________________________________________________
# batch_normalization (BatchNo (None, 18, 18, 32)        128
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 9, 9, 32)          0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 7, 7, 128)         36992
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 7, 7, 128)         512
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 3, 3, 128)         0
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 3, 3, 128)         512
# _________________________________________________________________
# flatten (Flatten)            (None, 1152)              0
# _________________________________________________________________
# dropout (Dropout)            (None, 1152)              0
# _________________________________________________________________
# dense (Dense)                (None, 256)               295168
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 64)                16448
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 64)                0
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                650
# =================================================================
# Total params: 372,042
# Trainable params: 371,466
# Non-trainable params: 576
# _________________________________________________________________
# None

# %%
# Fitting the CNN to the images

from tensorflow.keras.callbacks import ReduceLROnPlateau, EarlyStopping

reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=10,  
                              min_delta=1e-4, mode='min', verbose=1)

stop_alg = EarlyStopping(monitor='val_loss', patience=35, 
                         restore_best_weights=True, verbose=1)

hist = classifier.fit(x_train, y_train, batch_size=100, epochs=1000, 
                   callbacks=[stop_alg, reduce_lr], shuffle=True, 
                   validation_data=(x_test, y_test))

classifier.save_weights("cnn.hdf5")
# Out:
# Epoch 1/1000
# 500/500 [==============================] - 54s 109ms/step - loss: 0.2842 - accuracy: 0.3302 - val_loss: 0.3712 - val_accuracy: 0.2021
# Epoch 2/1000
# 500/500 [==============================] - 52s 105ms/step - loss: 0.2450 - accuracy: 0.4359 - val_loss: 0.2635 - val_accuracy: 0.3726
# Epoch 3/1000
# 500/500 [==============================] - 56s 112ms/step - loss: 0.2301 - accuracy: 0.4712 - val_loss: 0.2408 - val_accuracy: 0.4427
# Epoch 4/1000
# 500/500 [==============================] - 53s 107ms/step - loss: 0.2190 - accuracy: 0.5069 - val_loss: 0.2395 - val_accuracy: 0.4428
# Epoch 5/1000
# 500/500 [==============================] - 62s 125ms/step - loss: 0.2115 - accuracy: 0.5256 - val_loss: 0.2682 - val_accuracy: 0.4273
# Epoch 6/1000
# 500/500 [==============================] - 50s 100ms/step - loss: 0.2051 - accuracy: 0.5404 - val_loss: 0.2214 - val_accuracy: 0.5121
# Epoch 7/1000
# 500/500 [==============================] - 50s 99ms/step - loss: 0.2000 - accuracy: 0.5547 - val_loss: 0.2217 - val_accuracy: 0.4953
# Epoch 8/1000
# 500/500 [==============================] - 49s 99ms/step - loss: 0.1957 - accuracy: 0.5643 - val_loss: 0.2599 - val_accuracy: 0.4446
# Epoch 9/1000
# 500/500 [==============================] - 51s 101ms/step - loss: 0.1926 - accuracy: 0.5751 - val_loss: 0.1839 - val_accuracy: 0.5956
# Epoch 10/1000
# 500/500 [==============================] - 50s 99ms/step - loss: 0.1881 - accuracy: 0.5890 - val_loss: 0.1991 - val_accuracy: 0.5544
# Epoch 11/1000
# 500/500 [==============================] - 50s 99ms/step - loss: 0.1851 - accuracy: 0.5941 - val_loss: 0.1830 - val_accuracy: 0.6001
# Epoch 12/1000
# 500/500 [==============================] - 50s 100ms/step - loss: 0.1829 - accuracy: 0.5979 - val_loss: 0.2049 - val_accuracy: 0.5287
# Epoch 13/1000
# 500/500 [==============================] - 50s 99ms/step - loss: 0.1807 - accuracy: 0.6029 - val_loss: 0.1765 - val_accuracy: 0.6132
# Epoch 14/1000
# 500/500 [==============================] - 50s 99ms/step - loss: 0.1780 - accuracy: 0.6096 - val_loss: 0.2070 - val_accuracy: 0.5345
# Epoch 15/1000
# 500/500 [==============================] - 49s 98ms/step - loss: 0.1761 - accuracy: 0.6171 - val_loss: 0.2410 - val_accuracy: 0.5081
# Epoch 16/1000
# 500/500 [==============================] - 49s 98ms/step - loss: 0.1743 - accuracy: 0.6216 - val_loss: 0.1798 - val_accuracy: 0.5997
# Epoch 17/1000
# 500/500 [==============================] - 49s 98ms/step - loss: 0.1724 - accuracy: 0.6247 - val_loss: 0.1876 - val_accuracy: 0.5764
# Epoch 18/1000
# 500/500 [==============================] - 49s 99ms/step - loss: 0.1715 - accuracy: 0.6288 - val_loss: 0.1923 - val_accuracy: 0.5711
# Epoch 19/1000
# 500/500 [==============================] - 49s 98ms/step - loss: 0.1698 - accuracy: 0.6342 - val_loss: 0.1813 - val_accuracy: 0.6004
# Epoch 20/1000
# 500/500 [==============================] - 49s 98ms/step - loss: 0.1685 - accuracy: 0.6359 - val_loss: 0.2135 - val_accuracy: 0.5505
# Epoch 21/1000
# 500/500 [==============================] - 49s 99ms/step - loss: 0.1668 - accuracy: 0.6398 - val_loss: 0.1898 - val_accuracy: 0.5749
# Epoch 22/1000
# 500/500 [==============================] - 49s 98ms/step - loss: 0.1664 - accuracy: 0.6385 - val_loss: 0.2031 - val_accuracy: 0.5549
# Epoch 23/1000
# 500/500 [==============================] - 49s 98ms/step - loss: 0.1646 - accuracy: 0.6437 - val_loss: 0.1743 - val_accuracy: 0.6149
# Epoch 24/1000
# 500/500 [==============================] - 49s 98ms/step - loss: 0.1635 - accuracy: 0.6485 - val_loss: 0.1873 - val_accuracy: 0.5813
# Epoch 25/1000
# 500/500 [==============================] - 60s 121ms/step - loss: 0.1637 - accuracy: 0.6488 - val_loss: 0.2059 - val_accuracy: 0.5414
# Epoch 26/1000
# 500/500 [==============================] - 67s 133ms/step - loss: 0.1629 - accuracy: 0.6520 - val_loss: 0.1671 - val_accuracy: 0.6292
# Epoch 27/1000
# 500/500 [==============================] - 59s 117ms/step - loss: 0.1616 - accuracy: 0.6542 - val_loss: 0.1890 - val_accuracy: 0.5752
# Epoch 28/1000
# 500/500 [==============================] - 62s 124ms/step - loss: 0.1617 - accuracy: 0.6515 - val_loss: 0.1700 - val_accuracy: 0.6256
# Epoch 29/1000
# 500/500 [==============================] - 61s 122ms/step - loss: 0.1591 - accuracy: 0.6595 - val_loss: 0.1956 - val_accuracy: 0.5602
# Epoch 30/1000
# 500/500 [==============================] - 67s 133ms/step - loss: 0.1596 - accuracy: 0.6602 - val_loss: 0.1959 - val_accuracy: 0.5693
# Epoch 31/1000
# 500/500 [==============================] - 62s 124ms/step - loss: 0.1595 - accuracy: 0.6594 - val_loss: 0.1779 - val_accuracy: 0.6056
# Epoch 32/1000
# 500/500 [==============================] - 49s 98ms/step - loss: 0.1577 - accuracy: 0.6630 - val_loss: 0.1805 - val_accuracy: 0.6009
# Epoch 33/1000
# 500/500 [==============================] - 50s 99ms/step - loss: 0.1581 - accuracy: 0.6619 - val_loss: 0.1825 - val_accuracy: 0.5861
# Epoch 34/1000
# 500/500 [==============================] - 51s 103ms/step - loss: 0.1570 - accuracy: 0.6644 - val_loss: 0.1683 - val_accuracy: 0.6285
# Epoch 35/1000
# 500/500 [==============================] - 59s 117ms/step - loss: 0.1567 - accuracy: 0.6672 - val_loss: 0.1653 - val_accuracy: 0.6394
# Epoch 36/1000
# 500/500 [==============================] - 57s 113ms/step - loss: 0.1557 - accuracy: 0.6699 - val_loss: 0.1691 - val_accuracy: 0.6311
# Epoch 37/1000
# 500/500 [==============================] - 63s 126ms/step - loss: 0.1545 - accuracy: 0.6717 - val_loss: 0.1805 - val_accuracy: 0.6098
# Epoch 38/1000
# 500/500 [==============================] - 61s 123ms/step - loss: 0.1531 - accuracy: 0.6740 - val_loss: 0.1787 - val_accuracy: 0.6016
# Epoch 39/1000
# 500/500 [==============================] - 67s 133ms/step - loss: 0.1537 - accuracy: 0.6743 - val_loss: 0.1713 - val_accuracy: 0.6277
# Epoch 40/1000
# 500/500 [==============================] - 62s 125ms/step - loss: 0.1532 - accuracy: 0.6739 - val_loss: 0.1771 - val_accuracy: 0.6190
# Epoch 41/1000
# 500/500 [==============================] - 55s 111ms/step - loss: 0.1529 - accuracy: 0.6757 - val_loss: 0.1703 - val_accuracy: 0.6246
# Epoch 42/1000
# 500/500 [==============================] - 65s 129ms/step - loss: 0.1526 - accuracy: 0.6752 - val_loss: 0.1645 - val_accuracy: 0.6446
# Epoch 43/1000
# 500/500 [==============================] - 63s 126ms/step - loss: 0.1520 - accuracy: 0.6781 - val_loss: 0.1874 - val_accuracy: 0.5868
# Epoch 44/1000
# 500/500 [==============================] - 64s 128ms/step - loss: 0.1518 - accuracy: 0.6783 - val_loss: 0.1647 - val_accuracy: 0.6428
# Epoch 45/1000
# 500/500 [==============================] - 56s 112ms/step - loss: 0.1510 - accuracy: 0.6796 - val_loss: 0.1790 - val_accuracy: 0.6084
# Epoch 46/1000
# 500/500 [==============================] - 67s 133ms/step - loss: 0.1494 - accuracy: 0.6835 - val_loss: 0.1742 - val_accuracy: 0.6127
# Epoch 47/1000
# 500/500 [==============================] - 66s 132ms/step - loss: 0.1498 - accuracy: 0.6833 - val_loss: 0.1775 - val_accuracy: 0.6089
# Epoch 48/1000
# 500/500 [==============================] - 66s 133ms/step - loss: 0.1484 - accuracy: 0.6876 - val_loss: 0.1724 - val_accuracy: 0.6146
# Epoch 49/1000
# 500/500 [==============================] - 65s 131ms/step - loss: 0.1489 - accuracy: 0.6860 - val_loss: 0.1629 - val_accuracy: 0.6472
# Epoch 50/1000
# 500/500 [==============================] - 66s 132ms/step - loss: 0.1478 - accuracy: 0.6895 - val_loss: 0.1728 - val_accuracy: 0.6425
# Epoch 51/1000
# 500/500 [==============================] - 59s 119ms/step - loss: 0.1480 - accuracy: 0.6885 - val_loss: 0.1701 - val_accuracy: 0.6350
# Epoch 52/1000
# 500/500 [==============================] - 61s 122ms/step - loss: 0.1463 - accuracy: 0.6926 - val_loss: 0.1848 - val_accuracy: 0.6322
# Epoch 53/1000
# 500/500 [==============================] - 57s 114ms/step - loss: 0.1465 - accuracy: 0.6905 - val_loss: 0.1645 - val_accuracy: 0.6381
# Epoch 54/1000
# 500/500 [==============================] - 53s 106ms/step - loss: 0.1454 - accuracy: 0.6930 - val_loss: 0.1685 - val_accuracy: 0.6353
# Epoch 55/1000
# 500/500 [==============================] - 50s 101ms/step - loss: 0.1457 - accuracy: 0.6928 - val_loss: 0.1918 - val_accuracy: 0.6129
# Epoch 56/1000
# 500/500 [==============================] - 61s 122ms/step - loss: 0.1441 - accuracy: 0.6975 - val_loss: 0.1645 - val_accuracy: 0.6429
# Epoch 57/1000
# 500/500 [==============================] - 61s 123ms/step - loss: 0.1431 - accuracy: 0.6976 - val_loss: 0.1674 - val_accuracy: 0.6441
# Epoch 58/1000
# 500/500 [==============================] - 64s 127ms/step - loss: 0.1435 - accuracy: 0.6972 - val_loss: 0.1738 - val_accuracy: 0.6132
# Epoch 59/1000
# 500/500 [==============================] - ETA: 0s - loss: 0.1428 - accuracy: 0.6995
# Epoch 00059: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 500/500 [==============================] - 68s 135ms/step - loss: 0.1428 - accuracy: 0.6995 - val_loss: 0.1652 - val_accuracy: 0.6372
# Epoch 60/1000
# 500/500 [==============================] - 67s 134ms/step - loss: 0.1358 - accuracy: 0.7167 - val_loss: 0.1595 - val_accuracy: 0.6565
# Epoch 61/1000
# 500/500 [==============================] - 67s 134ms/step - loss: 0.1351 - accuracy: 0.7166 - val_loss: 0.1572 - val_accuracy: 0.6581
# Epoch 62/1000
# 500/500 [==============================] - 61s 122ms/step - loss: 0.1332 - accuracy: 0.7237 - val_loss: 0.1636 - val_accuracy: 0.6507
# Epoch 63/1000
# 500/500 [==============================] - 64s 128ms/step - loss: 0.1330 - accuracy: 0.7219 - val_loss: 0.1634 - val_accuracy: 0.6547
# Epoch 64/1000
# 500/500 [==============================] - 60s 120ms/step - loss: 0.1331 - accuracy: 0.7227 - val_loss: 0.1548 - val_accuracy: 0.6625
# Epoch 65/1000
# 500/500 [==============================] - 57s 114ms/step - loss: 0.1314 - accuracy: 0.7264 - val_loss: 0.1685 - val_accuracy: 0.6606
# Epoch 66/1000
# 500/500 [==============================] - 66s 131ms/step - loss: 0.1317 - accuracy: 0.7259 - val_loss: 0.1540 - val_accuracy: 0.6704
# Epoch 67/1000
# 500/500 [==============================] - 64s 128ms/step - loss: 0.1316 - accuracy: 0.7247 - val_loss: 0.1588 - val_accuracy: 0.6540
# Epoch 68/1000
# 500/500 [==============================] - 63s 127ms/step - loss: 0.1319 - accuracy: 0.7258 - val_loss: 0.1557 - val_accuracy: 0.6663
# Epoch 69/1000
# 500/500 [==============================] - 61s 122ms/step - loss: 0.1315 - accuracy: 0.7268 - val_loss: 0.1565 - val_accuracy: 0.6658
# Epoch 70/1000
# 500/500 [==============================] - 59s 119ms/step - loss: 0.1310 - accuracy: 0.7277 - val_loss: 0.1573 - val_accuracy: 0.6586
# Epoch 71/1000
# 500/500 [==============================] - 67s 133ms/step - loss: 0.1301 - accuracy: 0.7294 - val_loss: 0.1581 - val_accuracy: 0.6577
# Epoch 72/1000
# 500/500 [==============================] - 67s 134ms/step - loss: 0.1295 - accuracy: 0.7325 - val_loss: 0.1632 - val_accuracy: 0.6478
# Epoch 73/1000
# 500/500 [==============================] - 66s 133ms/step - loss: 0.1299 - accuracy: 0.7301 - val_loss: 0.1614 - val_accuracy: 0.6624
# Epoch 74/1000
# 500/500 [==============================] - 62s 124ms/step - loss: 0.1288 - accuracy: 0.7295 - val_loss: 0.1574 - val_accuracy: 0.6631
# Epoch 75/1000
# 500/500 [==============================] - 51s 102ms/step - loss: 0.1284 - accuracy: 0.7331 - val_loss: 0.1556 - val_accuracy: 0.6669
# Epoch 76/1000
# 500/500 [==============================] - ETA: 0s - loss: 0.1286 - accuracy: 0.7341
# Epoch 00076: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 500/500 [==============================] - 58s 116ms/step - loss: 0.1286 - accuracy: 0.7341 - val_loss: 0.1653 - val_accuracy: 0.6445
# Epoch 77/1000
# 500/500 [==============================] - 56s 111ms/step - loss: 0.1251 - accuracy: 0.7402 - val_loss: 0.1522 - val_accuracy: 0.6755
# Epoch 78/1000
# 500/500 [==============================] - 61s 121ms/step - loss: 0.1246 - accuracy: 0.7421 - val_loss: 0.1509 - val_accuracy: 0.6798
# Epoch 79/1000
# 500/500 [==============================] - 59s 119ms/step - loss: 0.1235 - accuracy: 0.7434 - val_loss: 0.1589 - val_accuracy: 0.6624
# Epoch 80/1000
# 500/500 [==============================] - 63s 126ms/step - loss: 0.1233 - accuracy: 0.7457 - val_loss: 0.1510 - val_accuracy: 0.6765
# Epoch 81/1000
# 500/500 [==============================] - 58s 116ms/step - loss: 0.1232 - accuracy: 0.7474 - val_loss: 0.1523 - val_accuracy: 0.6746
# Epoch 82/1000
# 500/500 [==============================] - 49s 98ms/step - loss: 0.1225 - accuracy: 0.7458 - val_loss: 0.1520 - val_accuracy: 0.6719
# Epoch 83/1000
# 500/500 [==============================] - 49s 98ms/step - loss: 0.1234 - accuracy: 0.7459 - val_loss: 0.1571 - val_accuracy: 0.6677
# Epoch 84/1000
# 500/500 [==============================] - 49s 98ms/step - loss: 0.1230 - accuracy: 0.7479 - val_loss: 0.1509 - val_accuracy: 0.6748
# Epoch 85/1000
# 500/500 [==============================] - 49s 97ms/step - loss: 0.1225 - accuracy: 0.7482 - val_loss: 0.1581 - val_accuracy: 0.6631
# Epoch 86/1000
# 500/500 [==============================] - 48s 97ms/step - loss: 0.1230 - accuracy: 0.7471 - val_loss: 0.1529 - val_accuracy: 0.6719
# Epoch 87/1000
# 500/500 [==============================] - 49s 97ms/step - loss: 0.1220 - accuracy: 0.7500 - val_loss: 0.1520 - val_accuracy: 0.6768
# Epoch 88/1000
# 500/500 [==============================] - ETA: 0s - loss: 0.1209 - accuracy: 0.7501
# Epoch 00088: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 500/500 [==============================] - 49s 97ms/step - loss: 0.1209 - accuracy: 0.7501 - val_loss: 0.1552 - val_accuracy: 0.6680
# Epoch 89/1000
# 500/500 [==============================] - 49s 97ms/step - loss: 0.1200 - accuracy: 0.7535 - val_loss: 0.1509 - val_accuracy: 0.6770
# Epoch 90/1000
# 500/500 [==============================] - 52s 103ms/step - loss: 0.1198 - accuracy: 0.7565 - val_loss: 0.1518 - val_accuracy: 0.6761
# Epoch 91/1000
# 500/500 [==============================] - 55s 110ms/step - loss: 0.1194 - accuracy: 0.7523 - val_loss: 0.1508 - val_accuracy: 0.6818
# Epoch 92/1000
# 500/500 [==============================] - 58s 116ms/step - loss: 0.1195 - accuracy: 0.7520 - val_loss: 0.1508 - val_accuracy: 0.6771
# Epoch 93/1000
# 500/500 [==============================] - 58s 115ms/step - loss: 0.1192 - accuracy: 0.7551 - val_loss: 0.1517 - val_accuracy: 0.6774
# Epoch 94/1000
# 500/500 [==============================] - 53s 106ms/step - loss: 0.1192 - accuracy: 0.7549 - val_loss: 0.1521 - val_accuracy: 0.6789
# Epoch 95/1000
# 500/500 [==============================] - 60s 119ms/step - loss: 0.1188 - accuracy: 0.7572 - val_loss: 0.1513 - val_accuracy: 0.6798
# Epoch 96/1000
# 500/500 [==============================] - 56s 112ms/step - loss: 0.1188 - accuracy: 0.7547 - val_loss: 0.1519 - val_accuracy: 0.6755
# Epoch 97/1000
# 500/500 [==============================] - 56s 111ms/step - loss: 0.1186 - accuracy: 0.7575 - val_loss: 0.1506 - val_accuracy: 0.6807
# Epoch 98/1000
# 500/500 [==============================] - 59s 117ms/step - loss: 0.1176 - accuracy: 0.7592 - val_loss: 0.1508 - val_accuracy: 0.6810
# Epoch 99/1000
# 500/500 [==============================] - 55s 110ms/step - loss: 0.1176 - accuracy: 0.7576 - val_loss: 0.1525 - val_accuracy: 0.6793
# Epoch 100/1000
# 500/500 [==============================] - 54s 109ms/step - loss: 0.1183 - accuracy: 0.7575 - val_loss: 0.1510 - val_accuracy: 0.6803
# Epoch 101/1000
# 500/500 [==============================] - 55s 110ms/step - loss: 0.1178 - accuracy: 0.7582 - val_loss: 0.1519 - val_accuracy: 0.6819
# Epoch 102/1000
# 500/500 [==============================] - 58s 115ms/step - loss: 0.1181 - accuracy: 0.7560 - val_loss: 0.1506 - val_accuracy: 0.6821
# Epoch 103/1000
# 500/500 [==============================] - 58s 117ms/step - loss: 0.1184 - accuracy: 0.7576 - val_loss: 0.1503 - val_accuracy: 0.6814
# Epoch 104/1000
# 500/500 [==============================] - 61s 122ms/step - loss: 0.1172 - accuracy: 0.7601 - val_loss: 0.1517 - val_accuracy: 0.6761
# Epoch 105/1000
# 500/500 [==============================] - 59s 118ms/step - loss: 0.1174 - accuracy: 0.7609 - val_loss: 0.1506 - val_accuracy: 0.6785
# Epoch 106/1000
# 500/500 [==============================] - 58s 116ms/step - loss: 0.1167 - accuracy: 0.7624 - val_loss: 0.1513 - val_accuracy: 0.6777
# Epoch 107/1000
# 500/500 [==============================] - 49s 98ms/step - loss: 0.1179 - accuracy: 0.7585 - val_loss: 0.1517 - val_accuracy: 0.6779
# Epoch 108/1000
# 500/500 [==============================] - 52s 104ms/step - loss: 0.1170 - accuracy: 0.7611 - val_loss: 0.1511 - val_accuracy: 0.6786
# Epoch 109/1000
# 500/500 [==============================] - 57s 114ms/step - loss: 0.1165 - accuracy: 0.7598 - val_loss: 0.1504 - val_accuracy: 0.6808
# Epoch 110/1000
# 500/500 [==============================] - 56s 111ms/step - loss: 0.1178 - accuracy: 0.7571 - val_loss: 0.1538 - val_accuracy: 0.6736
# Epoch 111/1000
# 500/500 [==============================] - 56s 113ms/step - loss: 0.1171 - accuracy: 0.7592 - val_loss: 0.1509 - val_accuracy: 0.6826
# Epoch 112/1000
# 500/500 [==============================] - 61s 122ms/step - loss: 0.1167 - accuracy: 0.7615 - val_loss: 0.1518 - val_accuracy: 0.6859
# Epoch 113/1000
# 500/500 [==============================] - ETA: 0s - loss: 0.1170 - accuracy: 0.7611
# Epoch 00113: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 500/500 [==============================] - 58s 116ms/step - loss: 0.1170 - accuracy: 0.7611 - val_loss: 0.1509 - val_accuracy: 0.6793
# Epoch 114/1000
# 500/500 [==============================] - 58s 117ms/step - loss: 0.1159 - accuracy: 0.7636 - val_loss: 0.1506 - val_accuracy: 0.6791
# Epoch 115/1000
# 500/500 [==============================] - 55s 110ms/step - loss: 0.1152 - accuracy: 0.7649 - val_loss: 0.1505 - val_accuracy: 0.6818
# Epoch 116/1000
# 500/500 [==============================] - 56s 113ms/step - loss: 0.1159 - accuracy: 0.7631 - val_loss: 0.1520 - val_accuracy: 0.6815
# Epoch 117/1000
# 500/500 [==============================] - 67s 133ms/step - loss: 0.1154 - accuracy: 0.7623 - val_loss: 0.1503 - val_accuracy: 0.6806
# Epoch 118/1000
# 500/500 [==============================] - 63s 127ms/step - loss: 0.1153 - accuracy: 0.7619 - val_loss: 0.1513 - val_accuracy: 0.6794
# Epoch 119/1000
# 500/500 [==============================] - 63s 127ms/step - loss: 0.1147 - accuracy: 0.7644 - val_loss: 0.1511 - val_accuracy: 0.6805
# Epoch 120/1000
# 500/500 [==============================] - 62s 124ms/step - loss: 0.1158 - accuracy: 0.7645 - val_loss: 0.1503 - val_accuracy: 0.6827
# Epoch 121/1000
# 500/500 [==============================] - 51s 102ms/step - loss: 0.1154 - accuracy: 0.7653 - val_loss: 0.1507 - val_accuracy: 0.6828
# Epoch 122/1000
# 500/500 [==============================] - 50s 99ms/step - loss: 0.1154 - accuracy: 0.7632 - val_loss: 0.1506 - val_accuracy: 0.6810
# Epoch 123/1000
# 500/500 [==============================] - ETA: 0s - loss: 0.1152 - accuracy: 0.7644
# Epoch 00123: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# 500/500 [==============================] - 58s 117ms/step - loss: 0.1152 - accuracy: 0.7644 - val_loss: 0.1527 - val_accuracy: 0.6834
# Epoch 124/1000
# 500/500 [==============================] - 63s 125ms/step - loss: 0.1149 - accuracy: 0.7664 - val_loss: 0.1507 - val_accuracy: 0.6828
# Epoch 125/1000
# 500/500 [==============================] - 60s 120ms/step - loss: 0.1154 - accuracy: 0.7648 - val_loss: 0.1504 - val_accuracy: 0.6818
# Epoch 126/1000
# 500/500 [==============================] - 50s 100ms/step - loss: 0.1138 - accuracy: 0.7671 - val_loss: 0.1503 - val_accuracy: 0.6815
# Epoch 127/1000
# 500/500 [==============================] - 49s 97ms/step - loss: 0.1151 - accuracy: 0.7636 - val_loss: 0.1500 - val_accuracy: 0.6826
# Epoch 128/1000
# 500/500 [==============================] - 48s 97ms/step - loss: 0.1154 - accuracy: 0.7644 - val_loss: 0.1503 - val_accuracy: 0.6835
# Epoch 129/1000
# 500/500 [==============================] - 52s 104ms/step - loss: 0.1152 - accuracy: 0.7629 - val_loss: 0.1506 - val_accuracy: 0.6820
# Epoch 130/1000
# 500/500 [==============================] - 63s 126ms/step - loss: 0.1149 - accuracy: 0.7657 - val_loss: 0.1511 - val_accuracy: 0.6810
# Epoch 131/1000
# 500/500 [==============================] - 63s 126ms/step - loss: 0.1146 - accuracy: 0.7651 - val_loss: 0.1512 - val_accuracy: 0.6828
# Epoch 132/1000
# 500/500 [==============================] - 63s 126ms/step - loss: 0.1137 - accuracy: 0.7679 - val_loss: 0.1509 - val_accuracy: 0.6819
# Epoch 133/1000
# 500/500 [==============================] - 56s 111ms/step - loss: 0.1150 - accuracy: 0.7674 - val_loss: 0.1512 - val_accuracy: 0.6811
# Epoch 134/1000
# 500/500 [==============================] - 60s 120ms/step - loss: 0.1146 - accuracy: 0.7672 - val_loss: 0.1511 - val_accuracy: 0.6815
# Epoch 135/1000
# 500/500 [==============================] - 63s 126ms/step - loss: 0.1150 - accuracy: 0.7662 - val_loss: 0.1509 - val_accuracy: 0.6804
# Epoch 136/1000
# 500/500 [==============================] - 60s 120ms/step - loss: 0.1140 - accuracy: 0.7663 - val_loss: 0.1512 - val_accuracy: 0.6833
# Epoch 137/1000
# 500/500 [==============================] - ETA: 0s - loss: 0.1149 - accuracy: 0.7633
# Epoch 00137: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# 500/500 [==============================] - 55s 110ms/step - loss: 0.1149 - accuracy: 0.7633 - val_loss: 0.1503 - val_accuracy: 0.6846
# Epoch 138/1000
# 500/500 [==============================] - 57s 114ms/step - loss: 0.1147 - accuracy: 0.7658 - val_loss: 0.1506 - val_accuracy: 0.6824
# Epoch 139/1000
# 500/500 [==============================] - 63s 127ms/step - loss: 0.1143 - accuracy: 0.7676 - val_loss: 0.1507 - val_accuracy: 0.6835
# Epoch 140/1000
# 500/500 [==============================] - 62s 125ms/step - loss: 0.1142 - accuracy: 0.7661 - val_loss: 0.1504 - val_accuracy: 0.6840
# Epoch 141/1000
# 500/500 [==============================] - 62s 125ms/step - loss: 0.1140 - accuracy: 0.7667 - val_loss: 0.1507 - val_accuracy: 0.6817
# Epoch 142/1000
# 500/500 [==============================] - 63s 126ms/step - loss: 0.1142 - accuracy: 0.7676 - val_loss: 0.1509 - val_accuracy: 0.6832
# Epoch 143/1000
# 500/500 [==============================] - 56s 112ms/step - loss: 0.1143 - accuracy: 0.7664 - val_loss: 0.1503 - val_accuracy: 0.6826
# Epoch 144/1000
# 500/500 [==============================] - 61s 123ms/step - loss: 0.1139 - accuracy: 0.7675 - val_loss: 0.1506 - val_accuracy: 0.6833
# Epoch 145/1000
# 500/500 [==============================] - 52s 105ms/step - loss: 0.1141 - accuracy: 0.7666 - val_loss: 0.1508 - val_accuracy: 0.6824
# Epoch 146/1000
# 500/500 [==============================] - 59s 118ms/step - loss: 0.1137 - accuracy: 0.7668 - val_loss: 0.1508 - val_accuracy: 0.6841
# Epoch 147/1000
# 500/500 [==============================] - ETA: 0s - loss: 0.1141 - accuracy: 0.7677
# Epoch 00147: ReduceLROnPlateau reducing learning rate to 7.812500371073838e-06.
# 500/500 [==============================] - 58s 116ms/step - loss: 0.1141 - accuracy: 0.7677 - val_loss: 0.1509 - val_accuracy: 0.6820
# Epoch 148/1000
# 500/500 [==============================] - 55s 111ms/step - loss: 0.1136 - accuracy: 0.7677 - val_loss: 0.1507 - val_accuracy: 0.6830
# Epoch 149/1000
# 500/500 [==============================] - 54s 109ms/step - loss: 0.1142 - accuracy: 0.7641 - val_loss: 0.1508 - val_accuracy: 0.6815
# Epoch 150/1000
# 500/500 [==============================] - 60s 119ms/step - loss: 0.1149 - accuracy: 0.7673 - val_loss: 0.1506 - val_accuracy: 0.6829
# Epoch 151/1000
# 500/500 [==============================] - 56s 113ms/step - loss: 0.1136 - accuracy: 0.7670 - val_loss: 0.1503 - val_accuracy: 0.6808
# Epoch 152/1000
# 500/500 [==============================] - 53s 105ms/step - loss: 0.1139 - accuracy: 0.7694 - val_loss: 0.1505 - val_accuracy: 0.6822
# Epoch 153/1000
# 500/500 [==============================] - 56s 112ms/step - loss: 0.1139 - accuracy: 0.7669 - val_loss: 0.1505 - val_accuracy: 0.6817
# Epoch 154/1000
# 500/500 [==============================] - 55s 110ms/step - loss: 0.1134 - accuracy: 0.7688 - val_loss: 0.1505 - val_accuracy: 0.6829
# Epoch 155/1000
# 500/500 [==============================] - 54s 107ms/step - loss: 0.1145 - accuracy: 0.7664 - val_loss: 0.1505 - val_accuracy: 0.6819
# Epoch 156/1000
# 500/500 [==============================] - 58s 115ms/step - loss: 0.1132 - accuracy: 0.7695 - val_loss: 0.1507 - val_accuracy: 0.6820
# Epoch 157/1000
# 500/500 [==============================] - ETA: 0s - loss: 0.1136 - accuracy: 0.7670
# Epoch 00157: ReduceLROnPlateau reducing learning rate to 3.906250185536919e-06.
# 500/500 [==============================] - 62s 125ms/step - loss: 0.1136 - accuracy: 0.7670 - val_loss: 0.1504 - val_accuracy: 0.6815
# Epoch 158/1000
# 500/500 [==============================] - 63s 126ms/step - loss: 0.1139 - accuracy: 0.7665 - val_loss: 0.1506 - val_accuracy: 0.6810
# Epoch 159/1000
# 500/500 [==============================] - 65s 129ms/step - loss: 0.1136 - accuracy: 0.7674 - val_loss: 0.1505 - val_accuracy: 0.6808
# Epoch 160/1000
# 500/500 [==============================] - 63s 126ms/step - loss: 0.1144 - accuracy: 0.7675 - val_loss: 0.1507 - val_accuracy: 0.6818
# Epoch 161/1000
# 500/500 [==============================] - 65s 130ms/step - loss: 0.1127 - accuracy: 0.7683 - val_loss: 0.1506 - val_accuracy: 0.6820
# Epoch 162/1000
# 500/500 [==============================] - ETA: 0s - loss: 0.1126 - accuracy: 0.7702Restoring model weights from the end of the best epoch.
# 500/500 [==============================] - 63s 126ms/step - loss: 0.1126 - accuracy: 0.7702 - val_loss: 0.1506 - val_accuracy: 0.6805
# Epoch 00162: early stopping

# %%
import matplotlib.pyplot as plt

fig = plt.figure(figsize=(10,6))
plt.plot(hist.history['loss'], color='#785ef0')
plt.plot(hist.history['val_loss'], color='#dc267f')
plt.title('Model Loss Progress')
plt.ylabel('Binary Cross-Entropy Loss')
plt.xlabel('Epoch')
plt.legend(['Training Set', 'Test Set'], loc='upper right')
plt.savefig('cnn 15*15.cifar10.loss1.png', dpi=350, bbox_inches='tight')
plt.show()

# %%
from sklearn.preprocessing import MinMaxScaler

cnnl1 = classifier.layers[1].name   # get the name of the first conv layer
W = classifier.get_layer(name=cnnl1).get_weights()[0]   #get the filters
wshape = W.shape  #save the original shape

# this part will scale to [0, 1] for visualization purposes
scaler = MinMaxScaler()
scaler.fit(W.reshape(-1,1))
W = scaler.transform(W.reshape(-1,1))
W = W.reshape(wshape)

# since there are 64 filters, we will display them 8x8
fig, axs = plt.subplots(8,8, figsize=(24,24))
fig.subplots_adjust(hspace = .25, wspace=.001)
axs = axs.ravel()
for i in range(W.shape[-1]):
  # we reshape to a 3D (RGB) image shape and display
  h = np.reshape(W[:,:,:,i], (15,15,3))
  axs[i].imshow(h)
  axs[i].set_title('Filter ' + str(i))    
plt.savefig("cnn 15*15.full.filters1.png", bbox_inches='tight', dpi=350)

# %%
cnnl1 = classifier.layers[1].name   # get the name of the first conv layer
W = classifier.get_layer(name=cnnl1).get_weights()[0]
plt.hist(W.ravel(), bins=100)
print(np.min(W),np.max(W))
# Out:
# -0.7364154 0.7540064

# %%
fig = plt.subplots(12, 16, figsize=(22,22))

filter_layers = []
for i in range(32):
    for j in range(3):
        filter_layers.append(np.reshape(W[:,:,j, i], (15,15)))
for i,gf in enumerate(filter_layers):
    plt.subplot(12, 16, i+1)
    plt.imshow(gf, cmap='gray')
    plt.axis('off')
