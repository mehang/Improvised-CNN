# %%
from skimage.filters import gabor_kernel
from skimage import io
from skimage.transform import resize
from matplotlib import pyplot as plt 
import numpy as np

import math

# %%
def get_gabor_filters(inchannels, outchannels, kernel_size = (3,3)):
    delta = 1e-4
    
    freqs = (math.pi/2)*math.sqrt(2)**(-np.linspace(0,4, 5))
    thetas = (math.pi/8)*np.linspace(0,7, 8)
    sigmas = math.pi/(freqs)
    psis = math.pi * np.random.rand(40,)
    x0, y0 = np.ceil(np.array(kernel_size)/2)    
    
    y, x = np.meshgrid(
            np.linspace(-y0, y0 + 1, kernel_size[0]),
            np.linspace(-x0, x0 + 1, kernel_size[1]),
    )
    filterbank = []
    
    for freq in freqs:
        for theta in thetas:
            sigma = math.pi/freq
            psi = math.pi * np.random.rand(1,)[0]
            rotx = x * np.cos(theta) + y * np.sin(theta)
            roty = -x * np.sin(theta) + y * np.cos(theta)

            g = np.exp(
                -0.5 * ((rotx ** 2 + roty ** 2) / (sigma + delta) ** 2)
            )
            g = g * np.cos(freq * rotx + psi)
            g = g / (2 * math.pi * sigma ** 2)
            filterbank.append(g)
    return filterbank

filterbank = get_gabor_filters(1, 40, (3,3))

fig = plt.subplots(12, 16, figsize=(22,22))
for i,gf in enumerate(filterbank):
    plt.subplot(12, 16, i+1)
    plt.imshow(gf, cmap='gray')
    plt.axis('off')

# %%
from tensorflow.keras.datasets import cifar10
from tensorflow.keras.utils import to_categorical

# The data, split between train and test sets:
(x_train, y_train), (x_test, y_test) = cifar10.load_data()
x_train = x_train.astype('float32') / 255.0
x_test = x_test.astype('float32') / 255.0

y_train = to_categorical(y_train, 10)
y_test = to_categorical(y_test, 10)

print('x_train shape:', x_train.shape)
print('x_test shape:', x_test.shape)
# Out:
# x_train shape: (50000, 32, 32, 3)
# x_test shape: (10000, 32, 32, 3)

# %%
# Importing the Keras libraries and packages
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Activation
from tensorflow.keras.layers import Input, Dense, Dropout, BatchNormalization
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import RMSprop, Adam

# dimensionality of input and latent encoded representations
inpt_dim = (32, 32, 3)

inpt_img = Input(shape=inpt_dim)

# Block 1
cl1 = Conv2D(64, (3, 3), strides=(2, 2),activation='relu', input_shape = inpt_dim)(inpt_img)
bnl2 = BatchNormalization()(cl1)
# afl3 = Activation('relu')(bnl2)
pl4 = MaxPooling2D(pool_size = (2, 2))(bnl2)

# Adding a second convolutional layer
cl5 = Conv2D(128, (3, 3), strides=(1, 1), activation='relu')(pl4)
bnl6 = BatchNormalization()(cl5)
# afl7 = Activation('relu')(bnl6)
pl8 = MaxPooling2D(pool_size = (2, 2))(bnl6)
bnl9 = BatchNormalization()(pl8)

# Step 3 - Flattening
fl10 = Flatten()(bnl9)

# Step 4 - Full connection
dol11 = Dropout(0.5)(fl10)
dl12 = Dense(units = 256, activation = 'relu')(dol11)
dol13 = Dropout(0.2)(dl12)
dl14 = Dense(units = 64, activation = 'relu')(dol13)
dol15 = Dropout(0.1)(dl14)
output = Dense(units = 10, activation = 'sigmoid')(dol15)

classifier = Model(inpt_img, output)

# Compiling the CNN
opt = RMSprop(learning_rate=0.001)
# opt = Adam(learning_rate=0.01)

classifier.compile(optimizer = opt, loss = 'binary_crossentropy', 
                   metrics = ['accuracy'])

print(classifier.summary())
# Out:
# Model: "functional_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 32, 32, 3)]       0
# _________________________________________________________________
# conv2d (Conv2D)              (None, 15, 15, 64)        1792
# _________________________________________________________________
# batch_normalization (BatchNo (None, 15, 15, 64)        256
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 7, 7, 64)          0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 5, 5, 128)         73856
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 5, 5, 128)         512
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 2, 2, 128)         0
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 2, 2, 128)         512
# _________________________________________________________________
# flatten (Flatten)            (None, 512)               0
# _________________________________________________________________
# dropout (Dropout)            (None, 512)               0
# _________________________________________________________________
# dense (Dense)                (None, 256)               131328
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 64)                16448
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 64)                0
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                650
# =================================================================
# Total params: 225,354
# Trainable params: 224,714
# Non-trainable params: 640
# _________________________________________________________________
# None

# %%
fig = plt.subplots(12, 16, figsize=(22,22))

cnnl1 = classifier.layers[1].name   # get the name of the first conv layer
W = classifier.get_layer(name=cnnl1).get_weights()[0]   #get the filters
wshape = W.shape  #save the original shape
filter_layers = []
for i in range(64):
    for j in range(3):
        filter_layers.append(np.reshape(W[:,:,j, i], (3,3)))
for i,gf in enumerate(filter_layers):
    plt.subplot(12, 16, i+1)
    plt.imshow(gf, cmap='gray')
    plt.axis('off')

# %%
gabor_filters = W
for i, gf in enumerate(filterbank):
    for j in range(3):
        gabor_filters
for kernel_index in range(40):
    for channel_index in range(3):
        gabor_filters[:,:,channel_index, kernel_index] = filterbank[kernel_index]

cnnl1 = classifier.layers[1].name   # get the name of the first conv layer
classifier.get_layer(name=cnnl1).set_weights([gabor_filters, classifier.get_layer(name=cnnl1).get_weights()[1]])
fig = plt.subplots(12, 16, figsize=(22,22))
W = classifier.get_layer(name=cnnl1).get_weights()[0]   #get the filters
filter_layers = []
for i in range(64):
    for j in range(3):
        filter_layers.append(np.reshape(W[:,:,j, i], (3,3)))
for i,gf in enumerate(filter_layers):
    plt.subplot(12, 16, i+1)
    plt.imshow(gf, cmap='gray')
    plt.axis('off')

# %%
# Fitting the CNN to the images

from tensorflow.keras.callbacks import ReduceLROnPlateau, EarlyStopping

reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=10,  
                              min_delta=1e-4, mode='min', verbose=1)

stop_alg = EarlyStopping(monitor='val_loss', patience=35, 
                         restore_best_weights=True, verbose=1)

hist = classifier.fit(x_train, y_train, batch_size=100, epochs=1000, 
                   callbacks=[stop_alg, reduce_lr], shuffle=True, 
                   validation_data=(x_test, y_test))

classifier.save_weights("cnn.hdf5")
# Out:
# Epoch 1/1000
# 500/500 [==============================] - 22s 44ms/step - loss: 0.2676 - accuracy: 0.3826 - val_loss: 0.2763 - val_accuracy: 0.3578
# Epoch 2/1000
# 500/500 [==============================] - 21s 42ms/step - loss: 0.2243 - accuracy: 0.4932 - val_loss: 0.2094 - val_accuracy: 0.5322
# Epoch 3/1000
# 500/500 [==============================] - 21s 42ms/step - loss: 0.2067 - accuracy: 0.5404 - val_loss: 0.2348 - val_accuracy: 0.4590
# Epoch 4/1000
# 500/500 [==============================] - 25s 49ms/step - loss: 0.1972 - accuracy: 0.5649 - val_loss: 0.2090 - val_accuracy: 0.5313
# Epoch 5/1000
# 500/500 [==============================] - 23s 45ms/step - loss: 0.1893 - accuracy: 0.5882 - val_loss: 0.1972 - val_accuracy: 0.5590
# Epoch 6/1000
# 500/500 [==============================] - 22s 45ms/step - loss: 0.1842 - accuracy: 0.5988 - val_loss: 0.1688 - val_accuracy: 0.6333
# Epoch 7/1000
# 500/500 [==============================] - 22s 44ms/step - loss: 0.1789 - accuracy: 0.6144 - val_loss: 0.2151 - val_accuracy: 0.5319
# Epoch 8/1000
# 500/500 [==============================] - 22s 44ms/step - loss: 0.1746 - accuracy: 0.6233 - val_loss: 0.2077 - val_accuracy: 0.5318
# Epoch 9/1000
# 500/500 [==============================] - 23s 45ms/step - loss: 0.1704 - accuracy: 0.6334 - val_loss: 0.1886 - val_accuracy: 0.5914
# Epoch 10/1000
# 500/500 [==============================] - 22s 44ms/step - loss: 0.1672 - accuracy: 0.6415 - val_loss: 0.1940 - val_accuracy: 0.5716
# Epoch 11/1000
# 500/500 [==============================] - 22s 44ms/step - loss: 0.1646 - accuracy: 0.6493 - val_loss: 0.2016 - val_accuracy: 0.5551
# Epoch 12/1000
# 500/500 [==============================] - 23s 46ms/step - loss: 0.1613 - accuracy: 0.6554 - val_loss: 0.1593 - val_accuracy: 0.6556
# Epoch 13/1000
# 500/500 [==============================] - 22s 44ms/step - loss: 0.1594 - accuracy: 0.6651 - val_loss: 0.1790 - val_accuracy: 0.6259
# Epoch 14/1000
# 500/500 [==============================] - 22s 44ms/step - loss: 0.1561 - accuracy: 0.6695 - val_loss: 0.1635 - val_accuracy: 0.6495
# Epoch 15/1000
# 500/500 [==============================] - 22s 45ms/step - loss: 0.1543 - accuracy: 0.6747 - val_loss: 0.1965 - val_accuracy: 0.5818
# Epoch 16/1000
# 500/500 [==============================] - 22s 44ms/step - loss: 0.1532 - accuracy: 0.6777 - val_loss: 0.1614 - val_accuracy: 0.6510
# Epoch 17/1000
# 500/500 [==============================] - 22s 44ms/step - loss: 0.1520 - accuracy: 0.6807 - val_loss: 0.1575 - val_accuracy: 0.6652
# Epoch 18/1000
# 500/500 [==============================] - 22s 45ms/step - loss: 0.1508 - accuracy: 0.6815 - val_loss: 0.1504 - val_accuracy: 0.6828
# Epoch 19/1000
# 500/500 [==============================] - 23s 46ms/step - loss: 0.1486 - accuracy: 0.6886 - val_loss: 0.1511 - val_accuracy: 0.6780
# Epoch 20/1000
# 500/500 [==============================] - 22s 44ms/step - loss: 0.1465 - accuracy: 0.6902 - val_loss: 0.1985 - val_accuracy: 0.5771
# Epoch 21/1000
# 500/500 [==============================] - 22s 44ms/step - loss: 0.1461 - accuracy: 0.6940 - val_loss: 0.1473 - val_accuracy: 0.6882
# Epoch 22/1000
# 500/500 [==============================] - 22s 45ms/step - loss: 0.1450 - accuracy: 0.6956 - val_loss: 0.1460 - val_accuracy: 0.6895
# Epoch 23/1000
# 500/500 [==============================] - 22s 44ms/step - loss: 0.1439 - accuracy: 0.6991 - val_loss: 0.1535 - val_accuracy: 0.6725
# Epoch 24/1000
# 500/500 [==============================] - 22s 45ms/step - loss: 0.1423 - accuracy: 0.7033 - val_loss: 0.1719 - val_accuracy: 0.6468
# Epoch 25/1000
# 500/500 [==============================] - 22s 44ms/step - loss: 0.1422 - accuracy: 0.7028 - val_loss: 0.1738 - val_accuracy: 0.6447
# Epoch 26/1000
# 500/500 [==============================] - 22s 44ms/step - loss: 0.1402 - accuracy: 0.7061 - val_loss: 0.1430 - val_accuracy: 0.6947
# Epoch 27/1000
# 500/500 [==============================] - 23s 46ms/step - loss: 0.1404 - accuracy: 0.7081 - val_loss: 0.1591 - val_accuracy: 0.6638
# Epoch 28/1000
# 500/500 [==============================] - 22s 44ms/step - loss: 0.1384 - accuracy: 0.7108 - val_loss: 0.1468 - val_accuracy: 0.6855
# Epoch 29/1000
# 500/500 [==============================] - 23s 45ms/step - loss: 0.1382 - accuracy: 0.7146 - val_loss: 0.1701 - val_accuracy: 0.6516
# Epoch 30/1000
# 500/500 [==============================] - 24s 48ms/step - loss: 0.1370 - accuracy: 0.7148 - val_loss: 0.1427 - val_accuracy: 0.6997
# Epoch 31/1000
# 500/500 [==============================] - 22s 44ms/step - loss: 0.1367 - accuracy: 0.7164 - val_loss: 0.1534 - val_accuracy: 0.6672
# Epoch 32/1000
# 500/500 [==============================] - 26s 51ms/step - loss: 0.1353 - accuracy: 0.7203 - val_loss: 0.1488 - val_accuracy: 0.6877
# Epoch 33/1000
# 500/500 [==============================] - 22s 45ms/step - loss: 0.1350 - accuracy: 0.7207 - val_loss: 0.1689 - val_accuracy: 0.6512
# Epoch 34/1000
# 500/500 [==============================] - 21s 43ms/step - loss: 0.1346 - accuracy: 0.7200 - val_loss: 0.1423 - val_accuracy: 0.6981
# Epoch 35/1000
# 500/500 [==============================] - 22s 44ms/step - loss: 0.1337 - accuracy: 0.7235 - val_loss: 0.1518 - val_accuracy: 0.6779
# Epoch 36/1000
# 500/500 [==============================] - 22s 44ms/step - loss: 0.1327 - accuracy: 0.7271 - val_loss: 0.1590 - val_accuracy: 0.6742
# Epoch 37/1000
# 500/500 [==============================] - 21s 42ms/step - loss: 0.1333 - accuracy: 0.7263 - val_loss: 0.1466 - val_accuracy: 0.6907
# Epoch 38/1000
# 500/500 [==============================] - 21s 43ms/step - loss: 0.1320 - accuracy: 0.7291 - val_loss: 0.1486 - val_accuracy: 0.6932
# Epoch 39/1000
# 500/500 [==============================] - 22s 44ms/step - loss: 0.1310 - accuracy: 0.7285 - val_loss: 0.1429 - val_accuracy: 0.7001
# Epoch 40/1000
# 500/500 [==============================] - 22s 43ms/step - loss: 0.1297 - accuracy: 0.7336 - val_loss: 0.1636 - val_accuracy: 0.6503
# Epoch 41/1000
# 500/500 [==============================] - 21s 43ms/step - loss: 0.1305 - accuracy: 0.7316 - val_loss: 0.1515 - val_accuracy: 0.6745
# Epoch 42/1000
# 500/500 [==============================] - 21s 43ms/step - loss: 0.1288 - accuracy: 0.7345 - val_loss: 0.1439 - val_accuracy: 0.6948
# Epoch 43/1000
# 500/500 [==============================] - 21s 43ms/step - loss: 0.1274 - accuracy: 0.7371 - val_loss: 0.1481 - val_accuracy: 0.6980
# Epoch 44/1000
# 500/500 [==============================] - ETA: 0s - loss: 0.1279 - accuracy: 0.7354
# Epoch 00044: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 500/500 [==============================] - 22s 44ms/step - loss: 0.1279 - accuracy: 0.7354 - val_loss: 0.1568 - val_accuracy: 0.6635
# Epoch 45/1000
# 500/500 [==============================] - 21s 43ms/step - loss: 0.1206 - accuracy: 0.7523 - val_loss: 0.1326 - val_accuracy: 0.7228
# Epoch 46/1000
# 500/500 [==============================] - 22s 43ms/step - loss: 0.1196 - accuracy: 0.7545 - val_loss: 0.1419 - val_accuracy: 0.7058
# Epoch 47/1000
# 500/500 [==============================] - 22s 44ms/step - loss: 0.1195 - accuracy: 0.7552 - val_loss: 0.1319 - val_accuracy: 0.7280
# Epoch 48/1000
# 500/500 [==============================] - 21s 43ms/step - loss: 0.1179 - accuracy: 0.7567 - val_loss: 0.1292 - val_accuracy: 0.7325
# Epoch 49/1000
# 500/500 [==============================] - 21s 43ms/step - loss: 0.1163 - accuracy: 0.7639 - val_loss: 0.1336 - val_accuracy: 0.7190
# Epoch 50/1000
# 500/500 [==============================] - 21s 42ms/step - loss: 0.1167 - accuracy: 0.7644 - val_loss: 0.1343 - val_accuracy: 0.7177
# Epoch 51/1000
# 500/500 [==============================] - 21s 43ms/step - loss: 0.1158 - accuracy: 0.7636 - val_loss: 0.1357 - val_accuracy: 0.7194
# Epoch 52/1000
# 500/500 [==============================] - 22s 43ms/step - loss: 0.1156 - accuracy: 0.7625 - val_loss: 0.1343 - val_accuracy: 0.7200
# Epoch 53/1000
# 500/500 [==============================] - 24s 48ms/step - loss: 0.1150 - accuracy: 0.7643 - val_loss: 0.1450 - val_accuracy: 0.7027
# Epoch 54/1000
# 500/500 [==============================] - 22s 44ms/step - loss: 0.1146 - accuracy: 0.7663 - val_loss: 0.1305 - val_accuracy: 0.7301
# Epoch 55/1000
# 500/500 [==============================] - 22s 45ms/step - loss: 0.1147 - accuracy: 0.7630 - val_loss: 0.1386 - val_accuracy: 0.7167
# Epoch 56/1000
# 500/500 [==============================] - 21s 43ms/step - loss: 0.1143 - accuracy: 0.7663 - val_loss: 0.1340 - val_accuracy: 0.7224
# Epoch 57/1000
# 500/500 [==============================] - 21s 42ms/step - loss: 0.1129 - accuracy: 0.7698 - val_loss: 0.1352 - val_accuracy: 0.7215
# Epoch 58/1000
# 500/500 [==============================] - ETA: 0s - loss: 0.1134 - accuracy: 0.7684
# Epoch 00058: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 500/500 [==============================] - 22s 44ms/step - loss: 0.1134 - accuracy: 0.7684 - val_loss: 0.1409 - val_accuracy: 0.7094
# Epoch 59/1000
# 500/500 [==============================] - 21s 43ms/step - loss: 0.1104 - accuracy: 0.7740 - val_loss: 0.1287 - val_accuracy: 0.7371
# Epoch 60/1000
# 500/500 [==============================] - 22s 44ms/step - loss: 0.1099 - accuracy: 0.7755 - val_loss: 0.1265 - val_accuracy: 0.7408
# Epoch 61/1000
# 500/500 [==============================] - 21s 43ms/step - loss: 0.1091 - accuracy: 0.7804 - val_loss: 0.1295 - val_accuracy: 0.7375
# Epoch 62/1000
# 500/500 [==============================] - 22s 44ms/step - loss: 0.1084 - accuracy: 0.7795 - val_loss: 0.1304 - val_accuracy: 0.7335
# Epoch 63/1000
# 500/500 [==============================] - 24s 48ms/step - loss: 0.1080 - accuracy: 0.7812 - val_loss: 0.1292 - val_accuracy: 0.7326
# Epoch 64/1000
# 500/500 [==============================] - 22s 44ms/step - loss: 0.1085 - accuracy: 0.7803 - val_loss: 0.1335 - val_accuracy: 0.7262
# Epoch 65/1000
# 500/500 [==============================] - 21s 43ms/step - loss: 0.1077 - accuracy: 0.7817 - val_loss: 0.1367 - val_accuracy: 0.7243
# Epoch 66/1000
# 500/500 [==============================] - 22s 44ms/step - loss: 0.1073 - accuracy: 0.7854 - val_loss: 0.1296 - val_accuracy: 0.7368
# Epoch 67/1000
# 500/500 [==============================] - 22s 43ms/step - loss: 0.1071 - accuracy: 0.7841 - val_loss: 0.1279 - val_accuracy: 0.7358
# Epoch 68/1000
# 500/500 [==============================] - 23s 46ms/step - loss: 0.1069 - accuracy: 0.7843 - val_loss: 0.1329 - val_accuracy: 0.7276
# Epoch 69/1000
# 500/500 [==============================] - 22s 45ms/step - loss: 0.1058 - accuracy: 0.7865 - val_loss: 0.1302 - val_accuracy: 0.7300
# Epoch 70/1000
# 500/500 [==============================] - ETA: 0s - loss: 0.1068 - accuracy: 0.7846
# Epoch 00070: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 500/500 [==============================] - 22s 44ms/step - loss: 0.1068 - accuracy: 0.7846 - val_loss: 0.1337 - val_accuracy: 0.7235
# Epoch 71/1000
# 500/500 [==============================] - 22s 44ms/step - loss: 0.1045 - accuracy: 0.7892 - val_loss: 0.1270 - val_accuracy: 0.7379
# Epoch 72/1000
# 500/500 [==============================] - 23s 45ms/step - loss: 0.1053 - accuracy: 0.7881 - val_loss: 0.1270 - val_accuracy: 0.7421
# Epoch 73/1000
# 500/500 [==============================] - 22s 43ms/step - loss: 0.1043 - accuracy: 0.7891 - val_loss: 0.1264 - val_accuracy: 0.7413
# Epoch 74/1000
# 500/500 [==============================] - 22s 44ms/step - loss: 0.1044 - accuracy: 0.7892 - val_loss: 0.1268 - val_accuracy: 0.7399
# Epoch 75/1000
# 500/500 [==============================] - 24s 47ms/step - loss: 0.1052 - accuracy: 0.7881 - val_loss: 0.1261 - val_accuracy: 0.7431
# Epoch 76/1000
# 500/500 [==============================] - 27s 55ms/step - loss: 0.1047 - accuracy: 0.7894 - val_loss: 0.1280 - val_accuracy: 0.7377
# Epoch 77/1000
# 500/500 [==============================] - 22s 44ms/step - loss: 0.1038 - accuracy: 0.7900 - val_loss: 0.1266 - val_accuracy: 0.7422
# Epoch 78/1000
# 500/500 [==============================] - 23s 46ms/step - loss: 0.1030 - accuracy: 0.7929 - val_loss: 0.1266 - val_accuracy: 0.7429
# Epoch 79/1000
# 500/500 [==============================] - 23s 45ms/step - loss: 0.1033 - accuracy: 0.7918 - val_loss: 0.1269 - val_accuracy: 0.7393
# Epoch 80/1000
# 500/500 [==============================] - 22s 44ms/step - loss: 0.1032 - accuracy: 0.7933 - val_loss: 0.1272 - val_accuracy: 0.7383
# Epoch 81/1000
# 500/500 [==============================] - 22s 44ms/step - loss: 0.1029 - accuracy: 0.7920 - val_loss: 0.1278 - val_accuracy: 0.7414
# Epoch 82/1000
# 500/500 [==============================] - 22s 44ms/step - loss: 0.1029 - accuracy: 0.7929 - val_loss: 0.1266 - val_accuracy: 0.7404
# Epoch 83/1000
# 500/500 [==============================] - 20s 40ms/step - loss: 0.1035 - accuracy: 0.7913 - val_loss: 0.1265 - val_accuracy: 0.7413
# Epoch 84/1000
# 500/500 [==============================] - 24s 47ms/step - loss: 0.1023 - accuracy: 0.7939 - val_loss: 0.1268 - val_accuracy: 0.7379
# Epoch 85/1000
# 499/500 [============================>.] - ETA: 0s - loss: 0.1027 - accuracy: 0.7935
# Epoch 00085: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 500/500 [==============================] - 21s 41ms/step - loss: 0.1027 - accuracy: 0.7933 - val_loss: 0.1281 - val_accuracy: 0.7403
# Epoch 86/1000
# 500/500 [==============================] - 22s 43ms/step - loss: 0.1015 - accuracy: 0.7959 - val_loss: 0.1262 - val_accuracy: 0.7433
# Epoch 87/1000
# 500/500 [==============================] - 22s 45ms/step - loss: 0.1016 - accuracy: 0.7969 - val_loss: 0.1263 - val_accuracy: 0.7431
# Epoch 88/1000
# 500/500 [==============================] - 22s 44ms/step - loss: 0.1017 - accuracy: 0.7959 - val_loss: 0.1274 - val_accuracy: 0.7381
# Epoch 89/1000
# 500/500 [==============================] - 24s 48ms/step - loss: 0.1016 - accuracy: 0.7971 - val_loss: 0.1259 - val_accuracy: 0.7415
# Epoch 90/1000
# 500/500 [==============================] - 21s 42ms/step - loss: 0.1010 - accuracy: 0.7979 - val_loss: 0.1259 - val_accuracy: 0.7454
# Epoch 91/1000
# 500/500 [==============================] - 20s 40ms/step - loss: 0.1016 - accuracy: 0.7976 - val_loss: 0.1260 - val_accuracy: 0.7433
# Epoch 92/1000
# 500/500 [==============================] - 19s 38ms/step - loss: 0.1008 - accuracy: 0.7984 - val_loss: 0.1259 - val_accuracy: 0.7433
# Epoch 93/1000
# 500/500 [==============================] - 19s 38ms/step - loss: 0.1006 - accuracy: 0.7974 - val_loss: 0.1259 - val_accuracy: 0.7424
# Epoch 94/1000
# 500/500 [==============================] - 19s 38ms/step - loss: 0.1017 - accuracy: 0.7965 - val_loss: 0.1262 - val_accuracy: 0.7435
# Epoch 95/1000
# 500/500 [==============================] - 19s 38ms/step - loss: 0.1020 - accuracy: 0.7949 - val_loss: 0.1262 - val_accuracy: 0.7414
# Epoch 96/1000
# 500/500 [==============================] - 19s 38ms/step - loss: 0.1009 - accuracy: 0.7976 - val_loss: 0.1264 - val_accuracy: 0.7405
# Epoch 97/1000
# 500/500 [==============================] - 19s 38ms/step - loss: 0.1003 - accuracy: 0.7992 - val_loss: 0.1267 - val_accuracy: 0.7412
# Epoch 98/1000
# 500/500 [==============================] - 19s 38ms/step - loss: 0.1013 - accuracy: 0.7979 - val_loss: 0.1260 - val_accuracy: 0.7434
# Epoch 99/1000
# 499/500 [============================>.] - ETA: 0s - loss: 0.1005 - accuracy: 0.7997
# Epoch 00099: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# 500/500 [==============================] - 19s 38ms/step - loss: 0.1005 - accuracy: 0.7997 - val_loss: 0.1262 - val_accuracy: 0.7432
# Epoch 100/1000
# 500/500 [==============================] - 19s 38ms/step - loss: 0.0995 - accuracy: 0.8014 - val_loss: 0.1262 - val_accuracy: 0.7424
# Epoch 101/1000
# 500/500 [==============================] - 21s 43ms/step - loss: 0.1004 - accuracy: 0.7983 - val_loss: 0.1261 - val_accuracy: 0.7445
# Epoch 102/1000
# 500/500 [==============================] - 23s 47ms/step - loss: 0.1006 - accuracy: 0.7973 - val_loss: 0.1261 - val_accuracy: 0.7443
# Epoch 103/1000
# 500/500 [==============================] - 23s 47ms/step - loss: 0.1005 - accuracy: 0.7985 - val_loss: 0.1261 - val_accuracy: 0.7438
# Epoch 104/1000
# 500/500 [==============================] - 19s 39ms/step - loss: 0.1006 - accuracy: 0.7976 - val_loss: 0.1263 - val_accuracy: 0.7434
# Epoch 105/1000
# 500/500 [==============================] - 20s 39ms/step - loss: 0.1004 - accuracy: 0.7977 - val_loss: 0.1261 - val_accuracy: 0.7455
# Epoch 106/1000
# 500/500 [==============================] - 20s 40ms/step - loss: 0.0999 - accuracy: 0.7995 - val_loss: 0.1260 - val_accuracy: 0.7428
# Epoch 107/1000
# 500/500 [==============================] - 24s 49ms/step - loss: 0.1001 - accuracy: 0.7984 - val_loss: 0.1259 - val_accuracy: 0.7449
# Epoch 108/1000
# 500/500 [==============================] - 23s 45ms/step - loss: 0.1002 - accuracy: 0.7998 - val_loss: 0.1260 - val_accuracy: 0.7442
# Epoch 109/1000
# 500/500 [==============================] - ETA: 0s - loss: 0.0997 - accuracy: 0.8007
# Epoch 00109: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# 500/500 [==============================] - 22s 44ms/step - loss: 0.0997 - accuracy: 0.8007 - val_loss: 0.1260 - val_accuracy: 0.7437
# Epoch 110/1000
# 500/500 [==============================] - 22s 43ms/step - loss: 0.0994 - accuracy: 0.8009 - val_loss: 0.1258 - val_accuracy: 0.7434
# Epoch 111/1000
# 500/500 [==============================] - 22s 43ms/step - loss: 0.0991 - accuracy: 0.8001 - val_loss: 0.1257 - val_accuracy: 0.7436
# Epoch 112/1000
# 500/500 [==============================] - 21s 43ms/step - loss: 0.1003 - accuracy: 0.7998 - val_loss: 0.1258 - val_accuracy: 0.7438
# Epoch 113/1000
# 500/500 [==============================] - 22s 43ms/step - loss: 0.0997 - accuracy: 0.7999 - val_loss: 0.1259 - val_accuracy: 0.7417
# Epoch 114/1000
# 500/500 [==============================] - 21s 43ms/step - loss: 0.0988 - accuracy: 0.8029 - val_loss: 0.1258 - val_accuracy: 0.7437
# Epoch 115/1000
# 500/500 [==============================] - 22s 43ms/step - loss: 0.0993 - accuracy: 0.8003 - val_loss: 0.1258 - val_accuracy: 0.7437
# Epoch 116/1000
# 500/500 [==============================] - 24s 49ms/step - loss: 0.0992 - accuracy: 0.8016 - val_loss: 0.1258 - val_accuracy: 0.7432
# Epoch 117/1000
# 500/500 [==============================] - 20s 40ms/step - loss: 0.0995 - accuracy: 0.8003 - val_loss: 0.1257 - val_accuracy: 0.7423
# Epoch 118/1000
# 500/500 [==============================] - 20s 40ms/step - loss: 0.0998 - accuracy: 0.8001 - val_loss: 0.1258 - val_accuracy: 0.7430
# Epoch 119/1000
# 500/500 [==============================] - 21s 42ms/step - loss: 0.0994 - accuracy: 0.7998 - val_loss: 0.1259 - val_accuracy: 0.7424
# Epoch 120/1000
# 500/500 [==============================] - 21s 42ms/step - loss: 0.0998 - accuracy: 0.7987 - val_loss: 0.1260 - val_accuracy: 0.7436
# Epoch 121/1000
# 500/500 [==============================] - ETA: 0s - loss: 0.0991 - accuracy: 0.8022
# Epoch 00121: ReduceLROnPlateau reducing learning rate to 7.812500371073838e-06.
# 500/500 [==============================] - 21s 42ms/step - loss: 0.0991 - accuracy: 0.8022 - val_loss: 0.1261 - val_accuracy: 0.7399
# Epoch 122/1000
# 500/500 [==============================] - 24s 48ms/step - loss: 0.1003 - accuracy: 0.7995 - val_loss: 0.1259 - val_accuracy: 0.7431
# Epoch 123/1000
# 500/500 [==============================] - 23s 46ms/step - loss: 0.0994 - accuracy: 0.8015 - val_loss: 0.1258 - val_accuracy: 0.7437
# Epoch 124/1000
# 500/500 [==============================] - 24s 48ms/step - loss: 0.0990 - accuracy: 0.8020 - val_loss: 0.1259 - val_accuracy: 0.7427
# Epoch 125/1000
# 500/500 [==============================] - 21s 41ms/step - loss: 0.0998 - accuracy: 0.8002 - val_loss: 0.1259 - val_accuracy: 0.7430
# Epoch 126/1000
# 500/500 [==============================] - 20s 40ms/step - loss: 0.0988 - accuracy: 0.8025 - val_loss: 0.1259 - val_accuracy: 0.7427
# Epoch 127/1000
# 500/500 [==============================] - 26s 53ms/step - loss: 0.0997 - accuracy: 0.7968 - val_loss: 0.1259 - val_accuracy: 0.7426
# Epoch 128/1000
# 500/500 [==============================] - 23s 46ms/step - loss: 0.0995 - accuracy: 0.8015 - val_loss: 0.1259 - val_accuracy: 0.7431
# Epoch 129/1000
# 500/500 [==============================] - 21s 41ms/step - loss: 0.0992 - accuracy: 0.8000 - val_loss: 0.1259 - val_accuracy: 0.7427
# Epoch 130/1000
# 500/500 [==============================] - 20s 41ms/step - loss: 0.0993 - accuracy: 0.8013 - val_loss: 0.1259 - val_accuracy: 0.7420
# Epoch 131/1000
# 499/500 [============================>.] - ETA: 0s - loss: 0.0986 - accuracy: 0.8028
# Epoch 00131: ReduceLROnPlateau reducing learning rate to 3.906250185536919e-06.
# 500/500 [==============================] - 22s 44ms/step - loss: 0.0986 - accuracy: 0.8028 - val_loss: 0.1259 - val_accuracy: 0.7426
# Epoch 132/1000
# 500/500 [==============================] - 20s 41ms/step - loss: 0.0984 - accuracy: 0.8019 - val_loss: 0.1259 - val_accuracy: 0.7421
# Epoch 133/1000
# 500/500 [==============================] - 24s 48ms/step - loss: 0.0996 - accuracy: 0.8010 - val_loss: 0.1258 - val_accuracy: 0.7422
# Epoch 134/1000
# 500/500 [==============================] - 24s 48ms/step - loss: 0.0991 - accuracy: 0.7992 - val_loss: 0.1259 - val_accuracy: 0.7422
# Epoch 135/1000
# 500/500 [==============================] - 21s 43ms/step - loss: 0.0992 - accuracy: 0.8001 - val_loss: 0.1259 - val_accuracy: 0.7428
# Epoch 136/1000
# 500/500 [==============================] - 22s 43ms/step - loss: 0.0990 - accuracy: 0.8008 - val_loss: 0.1259 - val_accuracy: 0.7431
# Epoch 137/1000
# 500/500 [==============================] - 21s 42ms/step - loss: 0.1000 - accuracy: 0.7997 - val_loss: 0.1258 - val_accuracy: 0.7427
# Epoch 138/1000
# 500/500 [==============================] - 20s 41ms/step - loss: 0.0991 - accuracy: 0.8003 - val_loss: 0.1259 - val_accuracy: 0.7437
# Epoch 139/1000
# 500/500 [==============================] - 21s 42ms/step - loss: 0.0998 - accuracy: 0.8013 - val_loss: 0.1258 - val_accuracy: 0.7427
# Epoch 140/1000
# 500/500 [==============================] - 23s 45ms/step - loss: 0.0991 - accuracy: 0.8032 - val_loss: 0.1258 - val_accuracy: 0.7426
# Epoch 141/1000
# 500/500 [==============================] - ETA: 0s - loss: 0.0988 - accuracy: 0.8025
# Epoch 00141: ReduceLROnPlateau reducing learning rate to 1.9531250927684596e-06.
# 500/500 [==============================] - 22s 43ms/step - loss: 0.0988 - accuracy: 0.8025 - val_loss: 0.1258 - val_accuracy: 0.7418
# Epoch 142/1000
# 500/500 [==============================] - 21s 42ms/step - loss: 0.0996 - accuracy: 0.8006 - val_loss: 0.1258 - val_accuracy: 0.7416
# Epoch 143/1000
# 500/500 [==============================] - 19s 39ms/step - loss: 0.0993 - accuracy: 0.8011 - val_loss: 0.1258 - val_accuracy: 0.7418
# Epoch 144/1000
# 500/500 [==============================] - 19s 39ms/step - loss: 0.0994 - accuracy: 0.7992 - val_loss: 0.1258 - val_accuracy: 0.7433
# Epoch 145/1000
# 500/500 [==============================] - 21s 42ms/step - loss: 0.0993 - accuracy: 0.8013 - val_loss: 0.1258 - val_accuracy: 0.7425
# Epoch 146/1000
# 500/500 [==============================] - 21s 43ms/step - loss: 0.0994 - accuracy: 0.8001 - val_loss: 0.1258 - val_accuracy: 0.7427
# Epoch 147/1000
# 500/500 [==============================] - 23s 47ms/step - loss: 0.0993 - accuracy: 0.8020 - val_loss: 0.1258 - val_accuracy: 0.7424
# Epoch 148/1000
# 500/500 [==============================] - 21s 42ms/step - loss: 0.0987 - accuracy: 0.8029 - val_loss: 0.1259 - val_accuracy: 0.7426
# Epoch 149/1000
# 500/500 [==============================] - 21s 42ms/step - loss: 0.0990 - accuracy: 0.8013 - val_loss: 0.1259 - val_accuracy: 0.7428
# Epoch 150/1000
# 500/500 [==============================] - 21s 43ms/step - loss: 0.0999 - accuracy: 0.8009 - val_loss: 0.1258 - val_accuracy: 0.7425
# Epoch 151/1000
# 500/500 [==============================] - ETA: 0s - loss: 0.0989 - accuracy: 0.8016
# Epoch 00151: ReduceLROnPlateau reducing learning rate to 9.765625463842298e-07.
# 500/500 [==============================] - 21s 43ms/step - loss: 0.0989 - accuracy: 0.8016 - val_loss: 0.1258 - val_accuracy: 0.7424
# Epoch 152/1000
# 499/500 [============================>.] - ETA: 0s - loss: 0.0986 - accuracy: 0.8024Restoring model weights from the end of the best epoch.
# 500/500 [==============================] - 19s 39ms/step - loss: 0.0986 - accuracy: 0.8023 - val_loss: 0.1259 - val_accuracy: 0.7430
# Epoch 00152: early stopping

# %%
import matplotlib.pyplot as plt

fig = plt.figure(figsize=(10,6))
plt.plot(hist.history['loss'], color='#785ef0')
plt.plot(hist.history['val_loss'], color='#dc267f')
plt.title('Model Loss Progress')
plt.ylabel('Binary Cross-Entropy Loss')
plt.xlabel('Epoch')
plt.legend(['Training Set', 'Test Set'], loc='upper right')
plt.savefig('3*3 alternate-cifar-10.loss.png', dpi=350, bbox_inches='tight')
plt.show()

# %%
from sklearn.preprocessing import MinMaxScaler

cnnl1 = classifier.layers[1].name   # get the name of the first conv layer
W = classifier.get_layer(name=cnnl1).get_weights()[0]   #get the filters
wshape = W.shape  #save the original shape

# this part will scale to [0, 1] for visualization purposes
scaler = MinMaxScaler()
scaler.fit(W.reshape(-1,1))
W = scaler.transform(W.reshape(-1,1))
W = W.reshape(wshape)

# since there are 64 filters, we will display them 8x8
fig, axs = plt.subplots(8,8, figsize=(24,24))
fig.subplots_adjust(hspace = .25, wspace=.001)
axs = axs.ravel()
for i in range(W.shape[-1]):
  # we reshape to a 3D (RGB) image shape and display
  h = np.reshape(W[:,:,:,i], (3,3,3))
  axs[i].imshow(h)
  axs[i].set_title('Filter ' + str(i))    
plt.savefig("3*3 alternate-cifar-10.filters.png", bbox_inches='tight', dpi=350)

# %%
cnnl1 = classifier.layers[1].name   # get the name of the first conv layer
W = classifier.get_layer(name=cnnl1).get_weights()[0]
plt.hist(W.ravel(), bins=100)
print(np.min(W),np.max(W))
# Out:
# -0.3789103 0.45845246
