# %%
from skimage.filters import gabor_kernel
from skimage import io
from skimage.transform import resize
from matplotlib import pyplot as plt 
import numpy as np

import math

# %%
def get_gabor_filters(inchannels, outchannels, kernel_size = (3,3)):
    delta = 1e-4
    
    freqs = (math.pi/2)*math.sqrt(2)**(-np.linspace(0,4, 5))
    thetas = (math.pi/8)*np.linspace(0,7, 8)
    sigmas = math.pi/(freqs)
    psis = math.pi * np.random.rand(40,)
    x0, y0 = np.ceil(np.array(kernel_size)/2)    
    
    y, x = np.meshgrid(
            np.linspace(-y0, y0 + 1, kernel_size[0]),
            np.linspace(-x0, x0 + 1, kernel_size[1]),
    )
    filterbank = []
    
    for freq in freqs:
        for theta in thetas:
            sigma = math.pi/freq
            psi = math.pi * np.random.rand(1,)[0]
            rotx = x * np.cos(theta) + y * np.sin(theta)
            roty = -x * np.sin(theta) + y * np.cos(theta)

            g = np.exp(
                -0.5 * ((rotx ** 2 + roty ** 2) / (sigma + delta) ** 2)
            )
            g = g * np.cos(freq * rotx + psi)
            g = g / (2 * math.pi * sigma ** 2)
            filterbank.append(g)
    return filterbank

filterbank = get_gabor_filters(1, 40, (9,9))

fig = plt.subplots(12, 16, figsize=(22,22))
for i,gf in enumerate(filterbank):
    plt.subplot(12, 16, i+1)
    plt.imshow(gf, cmap='gray')
    plt.axis('off')

# %%
from tensorflow.keras.datasets import cifar10
from tensorflow.keras.utils import to_categorical

# The data, split between train and test sets:
(x_train, y_train), (x_test, y_test) = cifar10.load_data()
x_train = x_train.astype('float32') / 255.0
x_test = x_test.astype('float32') / 255.0

y_train = to_categorical(y_train, 10)
y_test = to_categorical(y_test, 10)

print('x_train shape:', x_train.shape)
print('x_test shape:', x_test.shape)
# Out:
# x_train shape: (50000, 32, 32, 3)
# x_test shape: (10000, 32, 32, 3)

# %%
# Importing the Keras libraries and packages
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Activation
from tensorflow.keras.layers import Input, Dense, Dropout, BatchNormalization
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import RMSprop, Adam

# dimensionality of input and latent encoded representations
inpt_dim = (32, 32, 3)

inpt_img = Input(shape=inpt_dim)

# Block 1
cl1 = Conv2D(64, (9, 9), strides=(2, 2),activation='relu', input_shape = inpt_dim)(inpt_img)
bnl2 = BatchNormalization()(cl1)
# afl3 = Activation('relu')(bnl2)
pl4 = MaxPooling2D(pool_size = (2, 2))(bnl2)

# Adding a second convolutional layer
cl5 = Conv2D(128, (3, 3), strides=(1, 1), activation='relu')(pl4)
bnl6 = BatchNormalization()(cl5)
# afl7 = Activation('relu')(bnl6)
pl8 = MaxPooling2D(pool_size = (2, 2))(bnl6)
bnl9 = BatchNormalization()(pl8)

# Step 3 - Flattening
fl10 = Flatten()(bnl9)

# Step 4 - Full connection
dol11 = Dropout(0.5)(fl10)
dl12 = Dense(units = 256, activation = 'relu')(dol11)
dol13 = Dropout(0.2)(dl12)
dl14 = Dense(units = 64, activation = 'relu')(dol13)
dol15 = Dropout(0.1)(dl14)
output = Dense(units = 10, activation = 'sigmoid')(dol15)

classifier = Model(inpt_img, output)

# Compiling the CNN
opt = RMSprop(learning_rate=0.001)
# opt = Adam(learning_rate=0.01)

classifier.compile(optimizer = opt, loss = 'binary_crossentropy', 
                   metrics = ['accuracy'])

print(classifier.summary())
# Out:
# Model: "functional_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 32, 32, 3)]       0
# _________________________________________________________________
# conv2d (Conv2D)              (None, 12, 12, 64)        15616
# _________________________________________________________________
# batch_normalization (BatchNo (None, 12, 12, 64)        256
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 6, 6, 64)          0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 4, 4, 128)         73856
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 4, 4, 128)         512
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 2, 2, 128)         0
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 2, 2, 128)         512
# _________________________________________________________________
# flatten (Flatten)            (None, 512)               0
# _________________________________________________________________
# dropout (Dropout)            (None, 512)               0
# _________________________________________________________________
# dense (Dense)                (None, 256)               131328
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 64)                16448
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 64)                0
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                650
# =================================================================
# Total params: 239,178
# Trainable params: 238,538
# Non-trainable params: 640
# _________________________________________________________________
# None

# %%
fig = plt.subplots(12, 16, figsize=(22,22))

cnnl1 = classifier.layers[1].name   # get the name of the first conv layer
W = classifier.get_layer(name=cnnl1).get_weights()[0]   #get the filters
wshape = W.shape  #save the original shape
filter_layers = []
for i in range(64):
    for j in range(3):
        filter_layers.append(np.reshape(W[:,:,j, i], (9,9)))
for i,gf in enumerate(filter_layers):
    plt.subplot(12, 16, i+1)
    plt.imshow(gf, cmap='gray')
    plt.axis('off')

# %%
gabor_filters = W
for i, gf in enumerate(filterbank):
    for j in range(3):
        gabor_filters
for kernel_index in range(40):
    for channel_index in range(3):
        gabor_filters[:,:,channel_index, kernel_index] = filterbank[kernel_index]

cnnl1 = classifier.layers[1].name   # get the name of the first conv layer
classifier.get_layer(name=cnnl1).set_weights([gabor_filters, classifier.get_layer(name=cnnl1).get_weights()[1]])
fig = plt.subplots(12, 16, figsize=(22,22))
W = classifier.get_layer(name=cnnl1).get_weights()[0]   #get the filters
filter_layers = []
for i in range(64):
    for j in range(3):
        filter_layers.append(np.reshape(W[:,:,j, i], (9,9)))
for i,gf in enumerate(filter_layers):
    plt.subplot(12, 16, i+1)
    plt.imshow(gf, cmap='gray')
    plt.axis('off')

# %%
# Fitting the CNN to the images

from tensorflow.keras.callbacks import ReduceLROnPlateau, EarlyStopping

reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=10,  
                              min_delta=1e-4, mode='min', verbose=1)

stop_alg = EarlyStopping(monitor='val_loss', patience=35, 
                         restore_best_weights=True, verbose=1)

hist = classifier.fit(x_train, y_train, batch_size=100, epochs=1000, 
                   callbacks=[stop_alg, reduce_lr], shuffle=True, 
                   validation_data=(x_test, y_test))

classifier.save_weights("cnn.hdf5")
# Out:
# Epoch 1/1000
# 500/500 [==============================] - 22s 44ms/step - loss: 0.2761 - accuracy: 0.3547 - val_loss: 0.2911 - val_accuracy: 0.3408
# Epoch 2/1000
# 500/500 [==============================] - 20s 40ms/step - loss: 0.2298 - accuracy: 0.4701 - val_loss: 0.2241 - val_accuracy: 0.4853
# Epoch 3/1000
# 500/500 [==============================] - 22s 44ms/step - loss: 0.2126 - accuracy: 0.5215 - val_loss: 0.2143 - val_accuracy: 0.5265
# Epoch 4/1000
# 500/500 [==============================] - 24s 47ms/step - loss: 0.2005 - accuracy: 0.5533 - val_loss: 0.1978 - val_accuracy: 0.5562
# Epoch 5/1000
# 500/500 [==============================] - 21s 42ms/step - loss: 0.1917 - accuracy: 0.5759 - val_loss: 0.2092 - val_accuracy: 0.5400
# Epoch 6/1000
# 500/500 [==============================] - 20s 40ms/step - loss: 0.1856 - accuracy: 0.5903 - val_loss: 0.1879 - val_accuracy: 0.5855
# Epoch 7/1000
# 500/500 [==============================] - 23s 45ms/step - loss: 0.1796 - accuracy: 0.6062 - val_loss: 0.1995 - val_accuracy: 0.5586
# Epoch 8/1000
# 500/500 [==============================] - 21s 42ms/step - loss: 0.1749 - accuracy: 0.6197 - val_loss: 0.1829 - val_accuracy: 0.5954
# Epoch 9/1000
# 500/500 [==============================] - 22s 43ms/step - loss: 0.1697 - accuracy: 0.6321 - val_loss: 0.1696 - val_accuracy: 0.6370
# Epoch 10/1000
# 500/500 [==============================] - 22s 44ms/step - loss: 0.1659 - accuracy: 0.6435 - val_loss: 0.2124 - val_accuracy: 0.5118
# Epoch 11/1000
# 500/500 [==============================] - 20s 39ms/step - loss: 0.1621 - accuracy: 0.6537 - val_loss: 0.1551 - val_accuracy: 0.6752
# Epoch 12/1000
# 500/500 [==============================] - 20s 40ms/step - loss: 0.1590 - accuracy: 0.6578 - val_loss: 0.2149 - val_accuracy: 0.5468
# Epoch 13/1000
# 500/500 [==============================] - 19s 38ms/step - loss: 0.1560 - accuracy: 0.6663 - val_loss: 0.1615 - val_accuracy: 0.6608
# Epoch 14/1000
# 500/500 [==============================] - 22s 44ms/step - loss: 0.1533 - accuracy: 0.6739 - val_loss: 0.1549 - val_accuracy: 0.6709
# Epoch 15/1000
# 500/500 [==============================] - 25s 50ms/step - loss: 0.1513 - accuracy: 0.6778 - val_loss: 0.1614 - val_accuracy: 0.6502
# Epoch 16/1000
# 500/500 [==============================] - 20s 41ms/step - loss: 0.1498 - accuracy: 0.6820 - val_loss: 0.1971 - val_accuracy: 0.5602
# Epoch 17/1000
# 500/500 [==============================] - 21s 42ms/step - loss: 0.1476 - accuracy: 0.6865 - val_loss: 0.1862 - val_accuracy: 0.5928
# Epoch 18/1000
# 500/500 [==============================] - 23s 46ms/step - loss: 0.1460 - accuracy: 0.6916 - val_loss: 0.1565 - val_accuracy: 0.6583
# Epoch 19/1000
# 500/500 [==============================] - 23s 46ms/step - loss: 0.1438 - accuracy: 0.6954 - val_loss: 0.1422 - val_accuracy: 0.6933
# Epoch 20/1000
# 500/500 [==============================] - 29s 57ms/step - loss: 0.1432 - accuracy: 0.6974 - val_loss: 0.1469 - val_accuracy: 0.6918
# Epoch 21/1000
# 500/500 [==============================] - 20s 40ms/step - loss: 0.1412 - accuracy: 0.7030 - val_loss: 0.1859 - val_accuracy: 0.6069
# Epoch 22/1000
# 500/500 [==============================] - 21s 41ms/step - loss: 0.1393 - accuracy: 0.7087 - val_loss: 0.1446 - val_accuracy: 0.6925
# Epoch 23/1000
# 500/500 [==============================] - 21s 41ms/step - loss: 0.1389 - accuracy: 0.7059 - val_loss: 0.1477 - val_accuracy: 0.6872
# Epoch 24/1000
# 500/500 [==============================] - 20s 40ms/step - loss: 0.1375 - accuracy: 0.7113 - val_loss: 0.1652 - val_accuracy: 0.6469
# Epoch 25/1000
# 500/500 [==============================] - 20s 39ms/step - loss: 0.1363 - accuracy: 0.7148 - val_loss: 0.1495 - val_accuracy: 0.6854
# Epoch 26/1000
# 500/500 [==============================] - 20s 40ms/step - loss: 0.1347 - accuracy: 0.7156 - val_loss: 0.1491 - val_accuracy: 0.6843
# Epoch 27/1000
# 500/500 [==============================] - 23s 46ms/step - loss: 0.1334 - accuracy: 0.7218 - val_loss: 0.1657 - val_accuracy: 0.6503
# Epoch 28/1000
# 500/500 [==============================] - 25s 50ms/step - loss: 0.1336 - accuracy: 0.7216 - val_loss: 0.1388 - val_accuracy: 0.7111
# Epoch 29/1000
# 500/500 [==============================] - 25s 49ms/step - loss: 0.1313 - accuracy: 0.7258 - val_loss: 0.1474 - val_accuracy: 0.6817
# Epoch 30/1000
# 500/500 [==============================] - 19s 39ms/step - loss: 0.1311 - accuracy: 0.7272 - val_loss: 0.1528 - val_accuracy: 0.6722
# Epoch 31/1000
# 500/500 [==============================] - 19s 39ms/step - loss: 0.1303 - accuracy: 0.7279 - val_loss: 0.1466 - val_accuracy: 0.6856
# Epoch 32/1000
# 500/500 [==============================] - 20s 40ms/step - loss: 0.1295 - accuracy: 0.7299 - val_loss: 0.1458 - val_accuracy: 0.6872
# Epoch 33/1000
# 500/500 [==============================] - 19s 39ms/step - loss: 0.1277 - accuracy: 0.7327 - val_loss: 0.1473 - val_accuracy: 0.6833
# Epoch 34/1000
# 500/500 [==============================] - 19s 39ms/step - loss: 0.1280 - accuracy: 0.7338 - val_loss: 0.1320 - val_accuracy: 0.7229
# Epoch 35/1000
# 500/500 [==============================] - 20s 39ms/step - loss: 0.1267 - accuracy: 0.7385 - val_loss: 0.1300 - val_accuracy: 0.7247
# Epoch 36/1000
# 500/500 [==============================] - 19s 39ms/step - loss: 0.1268 - accuracy: 0.7379 - val_loss: 0.1578 - val_accuracy: 0.6606
# Epoch 37/1000
# 500/500 [==============================] - 20s 40ms/step - loss: 0.1241 - accuracy: 0.7423 - val_loss: 0.1330 - val_accuracy: 0.7144
# Epoch 38/1000
# 500/500 [==============================] - 20s 41ms/step - loss: 0.1253 - accuracy: 0.7404 - val_loss: 0.1358 - val_accuracy: 0.7160
# Epoch 39/1000
# 500/500 [==============================] - 20s 39ms/step - loss: 0.1251 - accuracy: 0.7420 - val_loss: 0.1369 - val_accuracy: 0.7109
# Epoch 40/1000
# 500/500 [==============================] - 21s 42ms/step - loss: 0.1232 - accuracy: 0.7450 - val_loss: 0.1321 - val_accuracy: 0.7193
# Epoch 41/1000
# 500/500 [==============================] - 23s 45ms/step - loss: 0.1223 - accuracy: 0.7473 - val_loss: 0.1341 - val_accuracy: 0.7164
# Epoch 42/1000
# 500/500 [==============================] - 30s 60ms/step - loss: 0.1220 - accuracy: 0.7486 - val_loss: 0.1281 - val_accuracy: 0.7333
# Epoch 43/1000
# 500/500 [==============================] - 40s 79ms/step - loss: 0.1208 - accuracy: 0.7506 - val_loss: 0.1467 - val_accuracy: 0.6870
# Epoch 44/1000
# 500/500 [==============================] - 38s 77ms/step - loss: 0.1208 - accuracy: 0.7519 - val_loss: 0.1338 - val_accuracy: 0.7156
# Epoch 45/1000
# 500/500 [==============================] - 38s 77ms/step - loss: 0.1200 - accuracy: 0.7531 - val_loss: 0.1468 - val_accuracy: 0.6924
# Epoch 46/1000
# 500/500 [==============================] - 39s 77ms/step - loss: 0.1199 - accuracy: 0.7520 - val_loss: 0.1333 - val_accuracy: 0.7187
# Epoch 47/1000
# 500/500 [==============================] - 38s 77ms/step - loss: 0.1191 - accuracy: 0.7564 - val_loss: 0.1404 - val_accuracy: 0.7045
# Epoch 48/1000
# 500/500 [==============================] - 39s 79ms/step - loss: 0.1189 - accuracy: 0.7560 - val_loss: 0.1503 - val_accuracy: 0.6744
# Epoch 49/1000
# 500/500 [==============================] - 41s 82ms/step - loss: 0.1187 - accuracy: 0.7545 - val_loss: 0.1272 - val_accuracy: 0.7359
# Epoch 50/1000
# 500/500 [==============================] - 41s 82ms/step - loss: 0.1162 - accuracy: 0.7632 - val_loss: 0.1361 - val_accuracy: 0.7150
# Epoch 51/1000
# 500/500 [==============================] - 42s 84ms/step - loss: 0.1168 - accuracy: 0.7615 - val_loss: 0.1352 - val_accuracy: 0.7085
# Epoch 52/1000
# 500/500 [==============================] - 42s 84ms/step - loss: 0.1151 - accuracy: 0.7634 - val_loss: 0.1305 - val_accuracy: 0.7294
# Epoch 53/1000
# 500/500 [==============================] - 42s 84ms/step - loss: 0.1153 - accuracy: 0.7649 - val_loss: 0.1514 - val_accuracy: 0.6783
# Epoch 54/1000
# 500/500 [==============================] - 39s 79ms/step - loss: 0.1147 - accuracy: 0.7651 - val_loss: 0.1533 - val_accuracy: 0.6867
# Epoch 55/1000
# 500/500 [==============================] - 40s 80ms/step - loss: 0.1132 - accuracy: 0.7701 - val_loss: 0.1370 - val_accuracy: 0.7154
# Epoch 56/1000
# 500/500 [==============================] - 40s 81ms/step - loss: 0.1143 - accuracy: 0.7693 - val_loss: 0.1313 - val_accuracy: 0.7221
# Epoch 57/1000
# 500/500 [==============================] - 43s 86ms/step - loss: 0.1127 - accuracy: 0.7683 - val_loss: 0.1333 - val_accuracy: 0.7230
# Epoch 58/1000
# 500/500 [==============================] - 44s 87ms/step - loss: 0.1128 - accuracy: 0.7694 - val_loss: 0.1273 - val_accuracy: 0.7352
# Epoch 59/1000
# 500/500 [==============================] - 48s 96ms/step - loss: 0.1124 - accuracy: 0.7711 - val_loss: 0.1234 - val_accuracy: 0.7430
# Epoch 60/1000
# 500/500 [==============================] - 49s 98ms/step - loss: 0.1119 - accuracy: 0.7750 - val_loss: 0.1308 - val_accuracy: 0.7191
# Epoch 61/1000
# 500/500 [==============================] - 45s 89ms/step - loss: 0.1122 - accuracy: 0.7723 - val_loss: 0.1360 - val_accuracy: 0.7108
# Epoch 62/1000
# 500/500 [==============================] - 42s 84ms/step - loss: 0.1104 - accuracy: 0.7766 - val_loss: 0.1376 - val_accuracy: 0.7102
# Epoch 63/1000
# 500/500 [==============================] - 46s 92ms/step - loss: 0.1107 - accuracy: 0.7753 - val_loss: 0.1355 - val_accuracy: 0.7162
# Epoch 64/1000
# 500/500 [==============================] - 44s 88ms/step - loss: 0.1101 - accuracy: 0.7779 - val_loss: 0.1388 - val_accuracy: 0.7144
# Epoch 65/1000
# 500/500 [==============================] - 44s 88ms/step - loss: 0.1098 - accuracy: 0.7777 - val_loss: 0.1282 - val_accuracy: 0.7351
# Epoch 66/1000
# 500/500 [==============================] - 44s 88ms/step - loss: 0.1098 - accuracy: 0.7781 - val_loss: 0.1344 - val_accuracy: 0.7247
# Epoch 67/1000
# 500/500 [==============================] - 44s 87ms/step - loss: 0.1100 - accuracy: 0.7780 - val_loss: 0.1274 - val_accuracy: 0.7346
# Epoch 68/1000
# 500/500 [==============================] - 44s 88ms/step - loss: 0.1094 - accuracy: 0.7780 - val_loss: 0.1315 - val_accuracy: 0.7286
# Epoch 69/1000
# 500/500 [==============================] - ETA: 0s - loss: 0.1099 - accuracy: 0.7775
# Epoch 00069: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 500/500 [==============================] - 44s 87ms/step - loss: 0.1099 - accuracy: 0.7775 - val_loss: 0.1348 - val_accuracy: 0.7161
# Epoch 70/1000
# 500/500 [==============================] - 44s 87ms/step - loss: 0.1025 - accuracy: 0.7942 - val_loss: 0.1214 - val_accuracy: 0.7476
# Epoch 71/1000
# 500/500 [==============================] - 45s 89ms/step - loss: 0.1011 - accuracy: 0.7981 - val_loss: 0.1376 - val_accuracy: 0.7232
# Epoch 72/1000
# 500/500 [==============================] - 43s 86ms/step - loss: 0.1013 - accuracy: 0.7988 - val_loss: 0.1239 - val_accuracy: 0.7468
# Epoch 73/1000
# 500/500 [==============================] - 41s 83ms/step - loss: 0.1000 - accuracy: 0.7982 - val_loss: 0.1227 - val_accuracy: 0.7483
# Epoch 74/1000
# 500/500 [==============================] - 43s 86ms/step - loss: 0.0996 - accuracy: 0.8024 - val_loss: 0.1422 - val_accuracy: 0.7008
# Epoch 75/1000
# 500/500 [==============================] - 42s 85ms/step - loss: 0.0993 - accuracy: 0.8007 - val_loss: 0.1236 - val_accuracy: 0.7452
# Epoch 76/1000
# 500/500 [==============================] - 40s 81ms/step - loss: 0.0989 - accuracy: 0.8018 - val_loss: 0.1240 - val_accuracy: 0.7471
# Epoch 77/1000
# 500/500 [==============================] - 40s 80ms/step - loss: 0.0999 - accuracy: 0.7993 - val_loss: 0.1256 - val_accuracy: 0.7382
# Epoch 78/1000
# 500/500 [==============================] - 39s 78ms/step - loss: 0.0982 - accuracy: 0.8056 - val_loss: 0.1270 - val_accuracy: 0.7412
# Epoch 79/1000
# 500/500 [==============================] - 38s 76ms/step - loss: 0.0985 - accuracy: 0.8036 - val_loss: 0.1226 - val_accuracy: 0.7487
# Epoch 80/1000
# 500/500 [==============================] - ETA: 0s - loss: 0.0984 - accuracy: 0.8046
# Epoch 00080: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 500/500 [==============================] - 43s 87ms/step - loss: 0.0984 - accuracy: 0.8046 - val_loss: 0.1217 - val_accuracy: 0.7521
# Epoch 81/1000
# 500/500 [==============================] - 38s 76ms/step - loss: 0.0949 - accuracy: 0.8120 - val_loss: 0.1175 - val_accuracy: 0.7605
# Epoch 82/1000
# 500/500 [==============================] - 40s 79ms/step - loss: 0.0946 - accuracy: 0.8117 - val_loss: 0.1177 - val_accuracy: 0.7590
# Epoch 83/1000
# 500/500 [==============================] - 42s 83ms/step - loss: 0.0943 - accuracy: 0.8129 - val_loss: 0.1203 - val_accuracy: 0.7545
# Epoch 84/1000
# 500/500 [==============================] - 42s 84ms/step - loss: 0.0940 - accuracy: 0.8122 - val_loss: 0.1189 - val_accuracy: 0.7584
# Epoch 85/1000
# 500/500 [==============================] - 42s 85ms/step - loss: 0.0934 - accuracy: 0.8131 - val_loss: 0.1217 - val_accuracy: 0.7507
# Epoch 86/1000
# 500/500 [==============================] - 42s 84ms/step - loss: 0.0924 - accuracy: 0.8170 - val_loss: 0.1174 - val_accuracy: 0.7575
# Epoch 87/1000
# 500/500 [==============================] - 43s 85ms/step - loss: 0.0932 - accuracy: 0.8156 - val_loss: 0.1259 - val_accuracy: 0.7476
# Epoch 88/1000
# 500/500 [==============================] - 41s 82ms/step - loss: 0.0936 - accuracy: 0.8149 - val_loss: 0.1199 - val_accuracy: 0.7551
# Epoch 89/1000
# 500/500 [==============================] - 43s 87ms/step - loss: 0.0925 - accuracy: 0.8154 - val_loss: 0.1175 - val_accuracy: 0.7598
# Epoch 90/1000
# 500/500 [==============================] - 43s 85ms/step - loss: 0.0924 - accuracy: 0.8165 - val_loss: 0.1165 - val_accuracy: 0.7622
# Epoch 91/1000
# 500/500 [==============================] - 42s 84ms/step - loss: 0.0929 - accuracy: 0.8171 - val_loss: 0.1244 - val_accuracy: 0.7508
# Epoch 92/1000
# 500/500 [==============================] - 42s 84ms/step - loss: 0.0914 - accuracy: 0.8183 - val_loss: 0.1265 - val_accuracy: 0.7413
# Epoch 93/1000
# 500/500 [==============================] - 43s 85ms/step - loss: 0.0922 - accuracy: 0.8179 - val_loss: 0.1190 - val_accuracy: 0.7575
# Epoch 94/1000
# 500/500 [==============================] - 42s 84ms/step - loss: 0.0915 - accuracy: 0.8182 - val_loss: 0.1220 - val_accuracy: 0.7549
# Epoch 95/1000
# 500/500 [==============================] - 42s 84ms/step - loss: 0.0923 - accuracy: 0.8172 - val_loss: 0.1181 - val_accuracy: 0.7603
# Epoch 96/1000
# 500/500 [==============================] - 50s 101ms/step - loss: 0.0923 - accuracy: 0.8171 - val_loss: 0.1204 - val_accuracy: 0.7592
# Epoch 97/1000
# 500/500 [==============================] - 44s 89ms/step - loss: 0.0916 - accuracy: 0.8193 - val_loss: 0.1200 - val_accuracy: 0.7559
# Epoch 98/1000
# 500/500 [==============================] - 45s 90ms/step - loss: 0.0922 - accuracy: 0.8158 - val_loss: 0.1191 - val_accuracy: 0.7580
# Epoch 99/1000
# 500/500 [==============================] - 49s 97ms/step - loss: 0.0908 - accuracy: 0.8210 - val_loss: 0.1182 - val_accuracy: 0.7633
# Epoch 100/1000
# 500/500 [==============================] - ETA: 0s - loss: 0.0911 - accuracy: 0.8182
# Epoch 00100: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 500/500 [==============================] - 40s 80ms/step - loss: 0.0911 - accuracy: 0.8182 - val_loss: 0.1230 - val_accuracy: 0.7502
# Epoch 101/1000
# 500/500 [==============================] - 44s 87ms/step - loss: 0.0905 - accuracy: 0.8205 - val_loss: 0.1163 - val_accuracy: 0.7628
# Epoch 102/1000
# 500/500 [==============================] - 43s 86ms/step - loss: 0.0891 - accuracy: 0.8228 - val_loss: 0.1178 - val_accuracy: 0.7637
# Epoch 103/1000
# 500/500 [==============================] - 41s 83ms/step - loss: 0.0890 - accuracy: 0.8220 - val_loss: 0.1198 - val_accuracy: 0.7588
# Epoch 104/1000
# 500/500 [==============================] - 40s 80ms/step - loss: 0.0886 - accuracy: 0.8233 - val_loss: 0.1175 - val_accuracy: 0.7625
# Epoch 105/1000
# 500/500 [==============================] - 43s 86ms/step - loss: 0.0883 - accuracy: 0.8264 - val_loss: 0.1180 - val_accuracy: 0.7593
# Epoch 106/1000
# 500/500 [==============================] - 43s 86ms/step - loss: 0.0889 - accuracy: 0.8260 - val_loss: 0.1175 - val_accuracy: 0.7640
# Epoch 107/1000
# 500/500 [==============================] - 46s 92ms/step - loss: 0.0894 - accuracy: 0.8246 - val_loss: 0.1168 - val_accuracy: 0.7639
# Epoch 108/1000
# 500/500 [==============================] - 44s 88ms/step - loss: 0.0887 - accuracy: 0.8254 - val_loss: 0.1164 - val_accuracy: 0.7653
# Epoch 109/1000
# 500/500 [==============================] - 45s 90ms/step - loss: 0.0892 - accuracy: 0.8243 - val_loss: 0.1174 - val_accuracy: 0.7654
# Epoch 110/1000
# 500/500 [==============================] - 51s 102ms/step - loss: 0.0886 - accuracy: 0.8257 - val_loss: 0.1180 - val_accuracy: 0.7640
# Epoch 111/1000
# 500/500 [==============================] - ETA: 0s - loss: 0.0880 - accuracy: 0.8257
# Epoch 00111: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 500/500 [==============================] - 46s 93ms/step - loss: 0.0880 - accuracy: 0.8257 - val_loss: 0.1185 - val_accuracy: 0.7606
# Epoch 112/1000
# 500/500 [==============================] - 46s 92ms/step - loss: 0.0882 - accuracy: 0.8255 - val_loss: 0.1160 - val_accuracy: 0.7654
# Epoch 113/1000
# 500/500 [==============================] - 51s 102ms/step - loss: 0.0871 - accuracy: 0.8259 - val_loss: 0.1168 - val_accuracy: 0.7649
# Epoch 114/1000
# 500/500 [==============================] - 43s 86ms/step - loss: 0.0875 - accuracy: 0.8278 - val_loss: 0.1170 - val_accuracy: 0.7662
# Epoch 115/1000
# 500/500 [==============================] - 44s 89ms/step - loss: 0.0873 - accuracy: 0.8280 - val_loss: 0.1170 - val_accuracy: 0.7648
# Epoch 116/1000
# 500/500 [==============================] - 49s 98ms/step - loss: 0.0866 - accuracy: 0.8285 - val_loss: 0.1172 - val_accuracy: 0.7650
# Epoch 117/1000
# 500/500 [==============================] - 45s 90ms/step - loss: 0.0871 - accuracy: 0.8286 - val_loss: 0.1164 - val_accuracy: 0.7674
# Epoch 118/1000
# 500/500 [==============================] - 44s 88ms/step - loss: 0.0875 - accuracy: 0.8255 - val_loss: 0.1170 - val_accuracy: 0.7660
# Epoch 119/1000
# 500/500 [==============================] - 42s 83ms/step - loss: 0.0871 - accuracy: 0.8290 - val_loss: 0.1165 - val_accuracy: 0.7676
# Epoch 120/1000
# 500/500 [==============================] - 42s 85ms/step - loss: 0.0876 - accuracy: 0.8280 - val_loss: 0.1160 - val_accuracy: 0.7663
# Epoch 121/1000
# 500/500 [==============================] - 44s 88ms/step - loss: 0.0868 - accuracy: 0.8287 - val_loss: 0.1168 - val_accuracy: 0.7657
# Epoch 122/1000
# 500/500 [==============================] - ETA: 0s - loss: 0.0875 - accuracy: 0.8274
# Epoch 00122: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# 500/500 [==============================] - 43s 85ms/step - loss: 0.0875 - accuracy: 0.8274 - val_loss: 0.1163 - val_accuracy: 0.7650
# Epoch 123/1000
# 500/500 [==============================] - 44s 88ms/step - loss: 0.0870 - accuracy: 0.8289 - val_loss: 0.1164 - val_accuracy: 0.7653
# Epoch 124/1000
# 500/500 [==============================] - 53s 107ms/step - loss: 0.0870 - accuracy: 0.8292 - val_loss: 0.1165 - val_accuracy: 0.7666
# Epoch 125/1000
# 500/500 [==============================] - 41s 82ms/step - loss: 0.0863 - accuracy: 0.8286 - val_loss: 0.1161 - val_accuracy: 0.7666
# Epoch 126/1000
# 500/500 [==============================] - 38s 76ms/step - loss: 0.0864 - accuracy: 0.8287 - val_loss: 0.1163 - val_accuracy: 0.7656
# Epoch 127/1000
# 500/500 [==============================] - 42s 83ms/step - loss: 0.0868 - accuracy: 0.8283 - val_loss: 0.1162 - val_accuracy: 0.7675
# Epoch 128/1000
# 500/500 [==============================] - 44s 88ms/step - loss: 0.0867 - accuracy: 0.8302 - val_loss: 0.1164 - val_accuracy: 0.7682
# Epoch 129/1000
# 500/500 [==============================] - 41s 82ms/step - loss: 0.0863 - accuracy: 0.8301 - val_loss: 0.1164 - val_accuracy: 0.7670
# Epoch 130/1000
# 500/500 [==============================] - 40s 81ms/step - loss: 0.0873 - accuracy: 0.8290 - val_loss: 0.1168 - val_accuracy: 0.7662
# Epoch 131/1000
# 500/500 [==============================] - 41s 83ms/step - loss: 0.0862 - accuracy: 0.8302 - val_loss: 0.1168 - val_accuracy: 0.7669
# Epoch 132/1000
# 500/500 [==============================] - ETA: 0s - loss: 0.0863 - accuracy: 0.8318
# Epoch 00132: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# 500/500 [==============================] - 45s 90ms/step - loss: 0.0863 - accuracy: 0.8318 - val_loss: 0.1163 - val_accuracy: 0.7685
# Epoch 133/1000
# 500/500 [==============================] - 48s 96ms/step - loss: 0.0857 - accuracy: 0.8321 - val_loss: 0.1160 - val_accuracy: 0.7669
# Epoch 134/1000
# 500/500 [==============================] - 45s 89ms/step - loss: 0.0867 - accuracy: 0.8300 - val_loss: 0.1163 - val_accuracy: 0.7676
# Epoch 135/1000
# 500/500 [==============================] - 43s 86ms/step - loss: 0.0862 - accuracy: 0.8319 - val_loss: 0.1162 - val_accuracy: 0.7658
# Epoch 136/1000
# 500/500 [==============================] - 44s 87ms/step - loss: 0.0864 - accuracy: 0.8299 - val_loss: 0.1164 - val_accuracy: 0.7677
# Epoch 137/1000
# 500/500 [==============================] - 46s 93ms/step - loss: 0.0865 - accuracy: 0.8283 - val_loss: 0.1164 - val_accuracy: 0.7672
# Epoch 138/1000
# 500/500 [==============================] - 47s 94ms/step - loss: 0.0854 - accuracy: 0.8315 - val_loss: 0.1165 - val_accuracy: 0.7678
# Epoch 139/1000
# 500/500 [==============================] - 44s 89ms/step - loss: 0.0863 - accuracy: 0.8302 - val_loss: 0.1164 - val_accuracy: 0.7653
# Epoch 140/1000
# 500/500 [==============================] - 39s 78ms/step - loss: 0.0862 - accuracy: 0.8312 - val_loss: 0.1162 - val_accuracy: 0.7664
# Epoch 141/1000
# 500/500 [==============================] - 40s 79ms/step - loss: 0.0865 - accuracy: 0.8295 - val_loss: 0.1163 - val_accuracy: 0.7661
# Epoch 142/1000
# 500/500 [==============================] - ETA: 0s - loss: 0.0867 - accuracy: 0.8299
# Epoch 00142: ReduceLROnPlateau reducing learning rate to 7.812500371073838e-06.
# 500/500 [==============================] - 40s 80ms/step - loss: 0.0867 - accuracy: 0.8299 - val_loss: 0.1163 - val_accuracy: 0.7662
# Epoch 143/1000
# 500/500 [==============================] - 44s 87ms/step - loss: 0.0862 - accuracy: 0.8316 - val_loss: 0.1161 - val_accuracy: 0.7670
# Epoch 144/1000
# 500/500 [==============================] - 44s 87ms/step - loss: 0.0852 - accuracy: 0.8347 - val_loss: 0.1162 - val_accuracy: 0.7665
# Epoch 145/1000
# 500/500 [==============================] - 44s 88ms/step - loss: 0.0861 - accuracy: 0.8311 - val_loss: 0.1161 - val_accuracy: 0.7677
# Epoch 146/1000
# 500/500 [==============================] - 42s 85ms/step - loss: 0.0864 - accuracy: 0.8305 - val_loss: 0.1163 - val_accuracy: 0.7659
# Epoch 147/1000
# 500/500 [==============================] - ETA: 0s - loss: 0.0863 - accuracy: 0.8301Restoring model weights from the end of the best epoch.
# 500/500 [==============================] - 41s 82ms/step - loss: 0.0863 - accuracy: 0.8301 - val_loss: 0.1161 - val_accuracy: 0.7657
# Epoch 00147: early stopping

# %%
import matplotlib.pyplot as plt

fig = plt.figure(figsize=(10,6))
plt.plot(hist.history['loss'], color='#785ef0')
plt.plot(hist.history['val_loss'], color='#dc267f')
plt.title('Model Loss Progress')
plt.ylabel('Binary Cross-Entropy Loss')
plt.xlabel('Epoch')
plt.legend(['Training Set', 'Test Set'], loc='upper right')
plt.savefig('alternate-cifar-10.loss.png', dpi=350, bbox_inches='tight')
plt.show()

# %%
from sklearn.preprocessing import MinMaxScaler

cnnl1 = classifier.layers[1].name   # get the name of the first conv layer
W = classifier.get_layer(name=cnnl1).get_weights()[0]   #get the filters
wshape = W.shape  #save the original shape

# this part will scale to [0, 1] for visualization purposes
scaler = MinMaxScaler()
scaler.fit(W.reshape(-1,1))
W = scaler.transform(W.reshape(-1,1))
W = W.reshape(wshape)

# since there are 64 filters, we will display them 8x8
fig, axs = plt.subplots(8,8, figsize=(24,24))
fig.subplots_adjust(hspace = .25, wspace=.001)
axs = axs.ravel()
for i in range(W.shape[-1]):
  # we reshape to a 3D (RGB) image shape and display
  h = np.reshape(W[:,:,:,i], (9,9,3))
  axs[i].imshow(h)
  axs[i].set_title('Filter ' + str(i))    
plt.savefig("alternate-cifar-10.filters.png", bbox_inches='tight', dpi=350)

# %%
cnnl1 = classifier.layers[1].name   # get the name of the first conv layer
W = classifier.get_layer(name=cnnl1).get_weights()[0]
plt.hist(W.ravel(), bins=100)
print(np.min(W),np.max(W))
# Out:
# -0.6250715 0.6675064

# %%
fig = plt.subplots(12, 16, figsize=(22,22))

filter_layers = []
for i in range(64):
    for j in range(3):
        filter_layers.append(np.reshape(W[:,:,j, i], (9,9)))
for i,gf in enumerate(filter_layers):
    plt.subplot(12, 16, i+1)
    plt.imshow(gf, cmap='gray')
    plt.axis('off')
