# %% [markdown]
# <a href="https://colab.research.google.com/github/mehang/Improvised-CNN/blob/master/notebook/Cifar-10/resized/15*15/cifar10_15_15_Gabor_Alternate.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import matplotlib.pyplot as plt
import numpy as np
import os
import PIL
import tensorflow as tf
import pandas as pd

from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import pathlib
import time

from tensorflow.keras.preprocessing.image import ImageDataGenerator, load_img
from tensorflow.keras.utils import to_categorical
from sklearn.model_selection import train_test_split

# %%
# !unzip /content/drive/My\ Drive/Gabor\ Dataset/cifar10.zip -d cifar10
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: cifar10/cifar10/test/ship.1.jpg
#   inflating: cifar10/cifar10/test/airplane.10.jpg
#   inflating: cifar10/cifar10/test/horse.13.jpg
#   inflating: cifar10/cifar10/test/truck.38.jpg
#   inflating: cifar10/cifar10/test/frog.43.jpg
#   inflating: cifar10/cifar10/test/horse.83.jpg
#   inflating: cifar10/cifar10/test/cat.91.jpg
#   inflating: cifar10/cifar10/test/frog.102.jpg
#   inflating: cifar10/cifar10/test/frog.112.jpg
#   inflating: cifar10/cifar10/test/bird.138.jpg
#   inflating: cifar10/cifar10/test/frog.142.jpg
#   inflating: cifar10/cifar10/test/horse.145.jpg
#   inflating: cifar10/cifar10/test/frog.146.jpg
#   inflating: cifar10/cifar10/test/frog.163.jpg
#   inflating: cifar10/cifar10/test/dog.178.jpg
#   inflating: cifar10/cifar10/test/airplane.180.jpg
#   inflating: cifar10/cifar10/test/bird.182.jpg
#   inflating: cifar10/cifar10/test/cat.184.jpg
#   inflating: cifar10/cifar10/test/deer.188.jpg
#   inflating: cifar10/cifar10/test/ship.199.jpg
#   inflating: cifar10/cifar10/test/truck.209.jpg
#   inflating: cifar10/cifar10/test/horse.220.jpg
#   inflating: cifar10/cifar10/test/truck.222.jpg
#   inflating: cifar10/cifar10/test/airplane.237.jpg
#   inflating: cifar10/cifar10/test/truck.243.jpg
#   inflating: cifar10/cifar10/test/airplane.258.jpg
#   inflating: cifar10/cifar10/test/ship.274.jpg
#   inflating: cifar10/cifar10/test/airplane.298.jpg
#   inflating: cifar10/cifar10/test/automobile.305.jpg
#   inflating: cifar10/cifar10/test/frog.311.jpg
#   inflating: cifar10/cifar10/test/deer.324.jpg
#   inflating: cifar10/cifar10/test/ship.358.jpg
#   inflating: cifar10/cifar10/test/truck.381.jpg
#   inflating: cifar10/cifar10/test/dog.389.jpg
#   inflating: cifar10/cifar10/test/frog.395.jpg
#   inflating: cifar10/cifar10/test/truck.411.jpg
#   inflating: cifar10/cifar10/test/truck.442.jpg
#   inflating: cifar10/cifar10/test/horse.445.jpg
#   inflating: cifar10/cifar10/test/cat.456.jpg
#   inflating: cifar10/cifar10/test/frog.461.jpg
#   inflating: cifar10/cifar10/test/frog.476.jpg
#   inflating: cifar10/cifar10/test/deer.479.jpg
#   inflating: cifar10/cifar10/test/bird.498.jpg
#   inflating: cifar10/cifar10/test/airplane.499.jpg
#   inflating: cifar10/cifar10/test/deer.500.jpg
#   inflating: cifar10/cifar10/test/frog.501.jpg
#   inflating: cifar10/cifar10/test/deer.509.jpg
#   inflating: cifar10/cifar10/test/frog.512.jpg
#   inflating: cifar10/cifar10/test/ship.519.jpg
#   inflating: cifar10/cifar10/test/horse.521.jpg
#   inflating: cifar10/cifar10/test/deer.528.jpg
#   inflating: cifar10/cifar10/test/truck.530.jpg
#   inflating: cifar10/cifar10/test/frog.536.jpg
#   inflating: cifar10/cifar10/test/bird.537.jpg
#   inflating: cifar10/cifar10/test/truck.545.jpg
#   inflating: cifar10/cifar10/test/truck.554.jpg
#   inflating: cifar10/cifar10/test/truck.568.jpg
#   inflating: cifar10/cifar10/test/frog.574.jpg
#   inflating: cifar10/cifar10/test/frog.575.jpg
#   inflating: cifar10/cifar10/test/cat.586.jpg
#   inflating: cifar10/cifar10/test/cat.599.jpg
#   inflating: cifar10/cifar10/test/cat.637.jpg
#   inflating: cifar10/cifar10/test/truck.684.jpg
#   inflating: cifar10/cifar10/test/frog.685.jpg
#   inflating: cifar10/cifar10/test/truck.686.jpg
#   inflating: cifar10/cifar10/test/bird.706.jpg
#   inflating: cifar10/cifar10/test/bird.740.jpg
#   inflating: cifar10/cifar10/test/horse.743.jpg
#   inflating: cifar10/cifar10/test/bird.758.jpg
#   inflating: cifar10/cifar10/test/frog.761.jpg
#   inflating: cifar10/cifar10/test/frog.762.jpg
#   inflating: cifar10/cifar10/test/deer.793.jpg
#   inflating: cifar10/cifar10/test/horse.798.jpg
#   inflating: cifar10/cifar10/test/bird.821.jpg
#   inflating: cifar10/cifar10/test/cat.829.jpg
#   inflating: cifar10/cifar10/test/bird.832.jpg
#   inflating: cifar10/cifar10/test/deer.860.jpg
#   inflating: cifar10/cifar10/test/airplane.864.jpg
#   inflating: cifar10/cifar10/test/airplane.868.jpg
#   inflating: cifar10/cifar10/test/automobile.869.jpg
#   inflating: cifar10/cifar10/test/deer.872.jpg
#   inflating: cifar10/cifar10/test/cat.874.jpg
#   inflating: cifar10/cifar10/test/frog.891.jpg
#   inflating: cifar10/cifar10/test/frog.902.jpg
#   inflating: cifar10/cifar10/test/frog.907.jpg
#   inflating: cifar10/cifar10/test/ship.918.jpg
#   inflating: cifar10/cifar10/test/airplane.919.jpg
#   inflating: cifar10/cifar10/test/frog.920.jpg
#   inflating: cifar10/cifar10/test/truck.921.jpg
#   inflating: cifar10/cifar10/test/airplane.928.jpg
#   inflating: cifar10/cifar10/test/truck.940.jpg
#   inflating: cifar10/cifar10/test/deer.943.jpg
#   inflating: cifar10/cifar10/test/airplane.944.jpg
#   inflating: cifar10/cifar10/test/bird.988.jpg
#   inflating: cifar10/cifar10/test/frog.994.jpg
#   inflating: cifar10/cifar10/test/dog.1000.jpg
#   inflating: cifar10/cifar10/test/ship.1002.jpg
#   inflating: cifar10/cifar10/test/frog.1009.jpg
#   inflating: cifar10/cifar10/test/dog.1019.jpg
#   inflating: cifar10/cifar10/test/cat.1033.jpg
#   inflating: cifar10/cifar10/test/dog.1055.jpg
#   inflating: cifar10/cifar10/test/frog.1069.jpg
#   inflating: cifar10/cifar10/test/airplane.1077.jpg
#   inflating: cifar10/cifar10/test/airplane.1078.jpg
#   inflating: cifar10/cifar10/test/airplane.1090.jpg
#   inflating: cifar10/cifar10/test/bird.1099.jpg
#   inflating: cifar10/cifar10/test/dog.1117.jpg
#   inflating: cifar10/cifar10/test/horse.1119.jpg
#   inflating: cifar10/cifar10/test/dog.1120.jpg
#   inflating: cifar10/cifar10/test/cat.1121.jpg
#   inflating: cifar10/cifar10/test/frog.1125.jpg
#   inflating: cifar10/cifar10/test/deer.1128.jpg
#   inflating: cifar10/cifar10/test/cat.1129.jpg
#   inflating: cifar10/cifar10/test/bird.1132.jpg
#   inflating: cifar10/cifar10/test/truck.1155.jpg
#   inflating: cifar10/cifar10/test/deer.1167.jpg
#   inflating: cifar10/cifar10/test/horse.1170.jpg
#   inflating: cifar10/cifar10/test/automobile.1182.jpg
#   inflating: cifar10/cifar10/test/automobile.1185.jpg
#   inflating: cifar10/cifar10/test/horse.1198.jpg
#   inflating: cifar10/cifar10/test/dog.1239.jpg
#   inflating: cifar10/cifar10/test/truck.1256.jpg
#   inflating: cifar10/cifar10/test/ship.1263.jpg
#   inflating: cifar10/cifar10/test/truck.1265.jpg
#   inflating: cifar10/cifar10/test/ship.1286.jpg
#   inflating: cifar10/cifar10/test/deer.1293.jpg
#   inflating: cifar10/cifar10/test/deer.1303.jpg
#   inflating: cifar10/cifar10/test/deer.1304.jpg
#   inflating: cifar10/cifar10/test/automobile.1313.jpg
#   inflating: cifar10/cifar10/test/horse.1320.jpg
#   inflating: cifar10/cifar10/test/frog.1326.jpg
#   inflating: cifar10/cifar10/test/dog.1329.jpg
#   inflating: cifar10/cifar10/test/horse.1342.jpg
#   inflating: cifar10/cifar10/test/truck.1344.jpg
#   inflating: cifar10/cifar10/test/truck.1361.jpg
#   inflating: cifar10/cifar10/test/airplane.1365.jpg
#   inflating: cifar10/cifar10/test/frog.1390.jpg
#   inflating: cifar10/cifar10/test/horse.1398.jpg
#   inflating: cifar10/cifar10/test/ship.1407.jpg
#   inflating: cifar10/cifar10/test/deer.1443.jpg
#   inflating: cifar10/cifar10/test/frog.1449.jpg
#   inflating: cifar10/cifar10/test/cat.1454.jpg
#   inflating: cifar10/cifar10/test/bird.1479.jpg
#   inflating: cifar10/cifar10/test/automobile.1509.jpg
#   inflating: cifar10/cifar10/test/dog.1543.jpg
#   inflating: cifar10/cifar10/test/dog.1548.jpg
#   inflating: cifar10/cifar10/test/cat.1552.jpg
#   inflating: cifar10/cifar10/test/deer.1553.jpg
#   inflating: cifar10/cifar10/test/deer.1554.jpg
#   inflating: cifar10/cifar10/test/airplane.1574.jpg
#   inflating: cifar10/cifar10/test/horse.1576.jpg
#   inflating: cifar10/cifar10/test/dog.1577.jpg
#   inflating: cifar10/cifar10/test/airplane.1579.jpg
#   inflating: cifar10/cifar10/test/bird.1587.jpg
#   inflating: cifar10/cifar10/test/dog.1599.jpg
#   inflating: cifar10/cifar10/test/cat.1612.jpg
#   inflating: cifar10/cifar10/test/ship.1613.jpg
#   inflating: cifar10/cifar10/test/deer.1624.jpg
#   inflating: cifar10/cifar10/test/cat.1625.jpg
#   inflating: cifar10/cifar10/test/horse.1640.jpg
#   inflating: cifar10/cifar10/test/truck.1643.jpg
#   inflating: cifar10/cifar10/test/frog.1663.jpg
#   inflating: cifar10/cifar10/test/frog.1670.jpg
#   inflating: cifar10/cifar10/test/deer.1674.jpg
#   inflating: cifar10/cifar10/test/bird.1678.jpg
#   inflating: cifar10/cifar10/test/dog.1701.jpg
#   inflating: cifar10/cifar10/test/dog.1703.jpg
#   inflating: cifar10/cifar10/test/deer.1710.jpg
#   inflating: cifar10/cifar10/test/bird.1723.jpg
#   inflating: cifar10/cifar10/test/ship.1729.jpg
#   inflating: cifar10/cifar10/test/airplane.1739.jpg
#   inflating: cifar10/cifar10/test/airplane.1744.jpg
#   inflating: cifar10/cifar10/test/ship.1750.jpg
#   inflating: cifar10/cifar10/test/bird.1756.jpg
#   inflating: cifar10/cifar10/test/dog.1764.jpg
#   inflating: cifar10/cifar10/test/automobile.1784.jpg
#   inflating: cifar10/cifar10/test/automobile.1811.jpg
#   inflating: cifar10/cifar10/test/horse.1816.jpg
#   inflating: cifar10/cifar10/test/deer.1821.jpg
#   inflating: cifar10/cifar10/test/cat.1830.jpg
#   inflating: cifar10/cifar10/test/dog.1862.jpg
#   inflating: cifar10/cifar10/test/automobile.1882.jpg
#   inflating: cifar10/cifar10/test/ship.1897.jpg
#   inflating: cifar10/cifar10/test/horse.1899.jpg
#   inflating: cifar10/cifar10/test/truck.1915.jpg
#   inflating: cifar10/cifar10/test/ship.1946.jpg
#   inflating: cifar10/cifar10/test/deer.1953.jpg
#   inflating: cifar10/cifar10/test/horse.1967.jpg
#   inflating: cifar10/cifar10/test/dog.1977.jpg
#   inflating: cifar10/cifar10/test/frog.1978.jpg
#   inflating: cifar10/cifar10/test/dog.1988.jpg
#   inflating: cifar10/cifar10/test/dog.2001.jpg
#   inflating: cifar10/cifar10/test/ship.2014.jpg
#   inflating: cifar10/cifar10/test/truck.2019.jpg
#   inflating: cifar10/cifar10/test/frog.2035.jpg
#   inflating: cifar10/cifar10/test/dog.2037.jpg
#   inflating: cifar10/cifar10/test/automobile.2063.jpg
#   inflating: cifar10/cifar10/test/cat.2081.jpg
#   inflating: cifar10/cifar10/test/bird.2082.jpg
#   inflating: cifar10/cifar10/test/bird.2114.jpg
#   inflating: cifar10/cifar10/test/truck.2143.jpg
#   inflating: cifar10/cifar10/test/horse.2163.jpg
#   inflating: cifar10/cifar10/test/ship.2169.jpg
#   inflating: cifar10/cifar10/test/truck.2190.jpg
#   inflating: cifar10/cifar10/test/bird.2193.jpg
#   inflating: cifar10/cifar10/test/dog.2201.jpg
#   inflating: cifar10/cifar10/test/deer.2208.jpg
#   inflating: cifar10/cifar10/test/deer.2214.jpg
#   inflating: cifar10/cifar10/test/airplane.2232.jpg
#   inflating: cifar10/cifar10/test/truck.2246.jpg
#   inflating: cifar10/cifar10/test/airplane.2248.jpg
#   inflating: cifar10/cifar10/test/airplane.2257.jpg
#   inflating: cifar10/cifar10/test/truck.2279.jpg
#   inflating: cifar10/cifar10/test/dog.2281.jpg
#   inflating: cifar10/cifar10/test/ship.2284.jpg
#   inflating: cifar10/cifar10/test/dog.2288.jpg
#   inflating: cifar10/cifar10/test/horse.2319.jpg
#   inflating: cifar10/cifar10/test/horse.2326.jpg
#   inflating: cifar10/cifar10/test/frog.2333.jpg
#   inflating: cifar10/cifar10/test/horse.2337.jpg
#   inflating: cifar10/cifar10/test/frog.2338.jpg
#   inflating: cifar10/cifar10/test/ship.2347.jpg
#   inflating: cifar10/cifar10/test/deer.2353.jpg
#   inflating: cifar10/cifar10/test/automobile.2369.jpg
#   inflating: cifar10/cifar10/test/airplane.2370.jpg
#   inflating: cifar10/cifar10/test/airplane.2373.jpg
#   inflating: cifar10/cifar10/test/cat.2422.jpg
#   inflating: cifar10/cifar10/test/bird.2423.jpg
#   inflating: cifar10/cifar10/test/bird.2448.jpg
#   inflating: cifar10/cifar10/test/ship.2456.jpg
#   inflating: cifar10/cifar10/test/truck.2469.jpg
#   inflating: cifar10/cifar10/test/ship.2471.jpg
#   inflating: cifar10/cifar10/test/automobile.2477.jpg
#   inflating: cifar10/cifar10/test/bird.2483.jpg
#   inflating: cifar10/cifar10/test/horse.2486.jpg
#   inflating: cifar10/cifar10/test/cat.2498.jpg
#   inflating: cifar10/cifar10/test/deer.2500.jpg
#   inflating: cifar10/cifar10/test/deer.2510.jpg
#   inflating: cifar10/cifar10/test/automobile.2520.jpg
#   inflating: cifar10/cifar10/test/automobile.2522.jpg
#   inflating: cifar10/cifar10/test/cat.2543.jpg
#   inflating: cifar10/cifar10/test/deer.2567.jpg
#   inflating: cifar10/cifar10/test/bird.2592.jpg
#   inflating: cifar10/cifar10/test/cat.2606.jpg
#   inflating: cifar10/cifar10/test/dog.2609.jpg
#   inflating: cifar10/cifar10/test/bird.2610.jpg
#   inflating: cifar10/cifar10/test/cat.2612.jpg
#   inflating: cifar10/cifar10/test/airplane.2628.jpg
#   inflating: cifar10/cifar10/test/deer.2648.jpg
#   inflating: cifar10/cifar10/test/dog.2650.jpg
#   inflating: cifar10/cifar10/test/deer.2664.jpg
#   inflating: cifar10/cifar10/test/airplane.2668.jpg
#   inflating: cifar10/cifar10/test/airplane.2672.jpg
#   inflating: cifar10/cifar10/test/horse.2686.jpg
#   inflating: cifar10/cifar10/test/cat.2706.jpg
#   inflating: cifar10/cifar10/test/dog.2731.jpg
#   inflating: cifar10/cifar10/test/cat.2779.jpg
#   inflating: cifar10/cifar10/test/cat.2795.jpg
#   inflating: cifar10/cifar10/test/deer.2809.jpg
#   inflating: cifar10/cifar10/test/truck.2817.jpg
#   inflating: cifar10/cifar10/test/cat.2829.jpg
#   inflating: cifar10/cifar10/test/frog.2830.jpg
#   inflating: cifar10/cifar10/test/cat.2832.jpg
#   inflating: cifar10/cifar10/test/dog.2864.jpg
#   inflating: cifar10/cifar10/test/automobile.2875.jpg
#   inflating: cifar10/cifar10/test/truck.2876.jpg
#   inflating: cifar10/cifar10/test/horse.2881.jpg
#   inflating: cifar10/cifar10/test/horse.2889.jpg
#   inflating: cifar10/cifar10/test/airplane.2892.jpg
#   inflating: cifar10/cifar10/test/horse.2904.jpg
#   inflating: cifar10/cifar10/test/airplane.2913.jpg
#   inflating: cifar10/cifar10/test/ship.2935.jpg
#   inflating: cifar10/cifar10/test/ship.2962.jpg
#   inflating: cifar10/cifar10/test/dog.2970.jpg
#   inflating: cifar10/cifar10/test/deer.2971.jpg
#   inflating: cifar10/cifar10/test/truck.2974.jpg
#   inflating: cifar10/cifar10/test/bird.2977.jpg
#   inflating: cifar10/cifar10/test/deer.2995.jpg
#   inflating: cifar10/cifar10/test/bird.3003.jpg
#   inflating: cifar10/cifar10/test/frog.3010.jpg
#   inflating: cifar10/cifar10/test/automobile.3028.jpg
#   inflating: cifar10/cifar10/test/frog.3030.jpg
#   inflating: cifar10/cifar10/test/automobile.3033.jpg
#   inflating: cifar10/cifar10/test/horse.3082.jpg
#   inflating: cifar10/cifar10/test/airplane.3087.jpg
#   inflating: cifar10/cifar10/test/truck.3099.jpg
#   inflating: cifar10/cifar10/test/dog.3107.jpg
#   inflating: cifar10/cifar10/test/dog.3115.jpg
#   inflating: cifar10/cifar10/test/frog.3118.jpg
#   inflating: cifar10/cifar10/test/truck.3126.jpg
#   inflating: cifar10/cifar10/test/airplane.3177.jpg
#   inflating: cifar10/cifar10/test/airplane.3184.jpg
#   inflating: cifar10/cifar10/test/dog.3200.jpg
#   inflating: cifar10/cifar10/test/deer.3203.jpg
#   inflating: cifar10/cifar10/test/ship.3265.jpg
#   inflating: cifar10/cifar10/test/horse.3266.jpg
#   inflating: cifar10/cifar10/test/automobile.3293.jpg
#   inflating: cifar10/cifar10/test/airplane.3294.jpg
#   inflating: cifar10/cifar10/test/deer.3297.jpg
#   inflating: cifar10/cifar10/test/horse.3311.jpg
#   inflating: cifar10/cifar10/test/dog.3369.jpg
#   inflating: cifar10/cifar10/test/frog.3374.jpg
#   inflating: cifar10/cifar10/test/horse.3377.jpg
#   inflating: cifar10/cifar10/test/dog.3381.jpg
#   inflating: cifar10/cifar10/test/bird.3382.jpg
#   inflating: cifar10/cifar10/test/bird.3386.jpg
#   inflating: cifar10/cifar10/test/cat.3387.jpg
#   inflating: cifar10/cifar10/test/dog.3393.jpg
#   inflating: cifar10/cifar10/test/automobile.3394.jpg
#   inflating: cifar10/cifar10/test/automobile.3407.jpg
#   inflating: cifar10/cifar10/test/airplane.3425.jpg
#   inflating: cifar10/cifar10/test/frog.3435.jpg
#   inflating: cifar10/cifar10/test/bird.3440.jpg
#   inflating: cifar10/cifar10/test/truck.3450.jpg
#   inflating: cifar10/cifar10/test/bird.3454.jpg
#   inflating: cifar10/cifar10/test/frog.3465.jpg
#   inflating: cifar10/cifar10/test/horse.3470.jpg
#   inflating: cifar10/cifar10/test/airplane.3483.jpg
#   inflating: cifar10/cifar10/test/automobile.3485.jpg
#   inflating: cifar10/cifar10/test/deer.3505.jpg
#   inflating: cifar10/cifar10/test/deer.3523.jpg
#   inflating: cifar10/cifar10/test/dog.3535.jpg
#   inflating: cifar10/cifar10/test/bird.3541.jpg
#   inflating: cifar10/cifar10/test/deer.3545.jpg
#   inflating: cifar10/cifar10/test/dog.3546.jpg
#   inflating: cifar10/cifar10/test/airplane.3551.jpg
#   inflating: cifar10/cifar10/test/automobile.3565.jpg
#   inflating: cifar10/cifar10/test/ship.3585.jpg
#   inflating: cifar10/cifar10/test/frog.3588.jpg
#   inflating: cifar10/cifar10/test/cat.3594.jpg
#   inflating: cifar10/cifar10/test/bird.3598.jpg
#   inflating: cifar10/cifar10/test/frog.3615.jpg
#   inflating: cifar10/cifar10/test/deer.3616.jpg
#   inflating: cifar10/cifar10/test/horse.3639.jpg
#   inflating: cifar10/cifar10/test/ship.3643.jpg
#   inflating: cifar10/cifar10/test/airplane.3650.jpg
#   inflating: cifar10/cifar10/test/truck.3670.jpg
#   inflating: cifar10/cifar10/test/bird.3681.jpg
#   inflating: cifar10/cifar10/test/truck.3684.jpg
#   inflating: cifar10/cifar10/test/frog.3703.jpg
#   inflating: cifar10/cifar10/test/deer.3706.jpg
#   inflating: cifar10/cifar10/test/frog.3711.jpg
#   inflating: cifar10/cifar10/test/automobile.3715.jpg
#   inflating: cifar10/cifar10/test/ship.3729.jpg
#   inflating: cifar10/cifar10/test/bird.3741.jpg
#   inflating: cifar10/cifar10/test/frog.3767.jpg
#   inflating: cifar10/cifar10/test/truck.3770.jpg
#   inflating: cifar10/cifar10/test/bird.3773.jpg
#   inflating: cifar10/cifar10/test/truck.3789.jpg
#   inflating: cifar10/cifar10/test/dog.3806.jpg
#   inflating: cifar10/cifar10/test/deer.3822.jpg
#   inflating: cifar10/cifar10/test/frog.3840.jpg
#   inflating: cifar10/cifar10/test/truck.3846.jpg
#   inflating: cifar10/cifar10/test/deer.3862.jpg
#   inflating: cifar10/cifar10/test/airplane.3866.jpg
#   inflating: cifar10/cifar10/test/cat.3867.jpg
#   inflating: cifar10/cifar10/test/ship.3870.jpg
#   inflating: cifar10/cifar10/test/ship.3871.jpg
#   inflating: cifar10/cifar10/test/horse.3879.jpg
#   inflating: cifar10/cifar10/test/airplane.3897.jpg
#   inflating: cifar10/cifar10/test/frog.3899.jpg
#   inflating: cifar10/cifar10/test/automobile.3904.jpg
#   inflating: cifar10/cifar10/test/dog.3909.jpg
#   inflating: cifar10/cifar10/test/horse.3917.jpg
#   inflating: cifar10/cifar10/test/horse.3919.jpg
#   inflating: cifar10/cifar10/test/frog.3936.jpg
#   inflating: cifar10/cifar10/test/automobile.3942.jpg
#   inflating: cifar10/cifar10/test/horse.3944.jpg
#   inflating: cifar10/cifar10/test/bird.3947.jpg
#   inflating: cifar10/cifar10/test/cat.3977.jpg
#   inflating: cifar10/cifar10/test/bird.3978.jpg
#   inflating: cifar10/cifar10/test/horse.3986.jpg
#   inflating: cifar10/cifar10/test/bird.3997.jpg
#   inflating: cifar10/cifar10/test/frog.4022.jpg
#   inflating: cifar10/cifar10/test/deer.4027.jpg
#   inflating: cifar10/cifar10/test/deer.4029.jpg
#   inflating: cifar10/cifar10/test/automobile.4030.jpg
#   inflating: cifar10/cifar10/test/deer.4042.jpg
#   inflating: cifar10/cifar10/test/dog.4052.jpg
#   inflating: cifar10/cifar10/test/horse.4063.jpg
#   inflating: cifar10/cifar10/test/horse.4064.jpg
#   inflating: cifar10/cifar10/test/ship.4068.jpg
#   inflating: cifar10/cifar10/test/dog.4069.jpg
#   inflating: cifar10/cifar10/test/bird.4074.jpg
#   inflating: cifar10/cifar10/test/ship.4079.jpg
#   inflating: cifar10/cifar10/test/ship.4086.jpg
#   inflating: cifar10/cifar10/test/deer.4099.jpg
#   inflating: cifar10/cifar10/test/airplane.4126.jpg
#   inflating: cifar10/cifar10/test/frog.4130.jpg
#   inflating: cifar10/cifar10/test/bird.4133.jpg
#   inflating: cifar10/cifar10/test/bird.4204.jpg
#   inflating: cifar10/cifar10/test/deer.4205.jpg
#   inflating: cifar10/cifar10/test/bird.4208.jpg
#   inflating: cifar10/cifar10/test/automobile.4215.jpg
#   inflating: cifar10/cifar10/test/ship.4223.jpg
#   inflating: cifar10/cifar10/test/ship.4242.jpg
#   inflating: cifar10/cifar10/test/ship.4251.jpg
#   inflating: cifar10/cifar10/test/truck.4293.jpg
#   inflating: cifar10/cifar10/test/airplane.4313.jpg
#   inflating: cifar10/cifar10/test/automobile.4314.jpg
#   inflating: cifar10/cifar10/test/dog.4321.jpg
#   inflating: cifar10/cifar10/test/dog.4323.jpg
#   inflating: cifar10/cifar10/test/bird.4331.jpg
#   inflating: cifar10/cifar10/test/horse.4332.jpg
#   inflating: cifar10/cifar10/test/airplane.4387.jpg
#   inflating: cifar10/cifar10/test/cat.4400.jpg
#   inflating: cifar10/cifar10/test/automobile.4401.jpg
#   inflating: cifar10/cifar10/test/ship.4409.jpg
#   inflating: cifar10/cifar10/test/horse.4432.jpg
#   inflating: cifar10/cifar10/test/cat.4435.jpg
#   inflating: cifar10/cifar10/test/ship.4455.jpg
#   inflating: cifar10/cifar10/test/cat.4457.jpg
#   inflating: cifar10/cifar10/test/truck.4460.jpg
#   inflating: cifar10/cifar10/test/truck.4480.jpg
#   inflating: cifar10/cifar10/test/ship.4486.jpg
#   inflating: cifar10/cifar10/test/horse.4489.jpg
#   inflating: cifar10/cifar10/test/ship.4497.jpg
#   inflating: cifar10/cifar10/test/truck.4508.jpg
#   inflating: cifar10/cifar10/test/truck.4521.jpg
#   inflating: cifar10/cifar10/test/deer.4529.jpg
#   inflating: cifar10/cifar10/test/automobile.4531.jpg
#   inflating: cifar10/cifar10/test/automobile.4532.jpg
#   inflating: cifar10/cifar10/test/cat.4537.jpg
#   inflating: cifar10/cifar10/test/horse.4538.jpg
#   inflating: cifar10/cifar10/test/airplane.4557.jpg
#   inflating: cifar10/cifar10/test/bird.4572.jpg
#   inflating: cifar10/cifar10/test/deer.4576.jpg
#   inflating: cifar10/cifar10/test/airplane.4586.jpg
#   inflating: cifar10/cifar10/test/dog.4593.jpg
#   inflating: cifar10/cifar10/test/ship.4599.jpg
#   inflating: cifar10/cifar10/test/automobile.4611.jpg
#   inflating: cifar10/cifar10/test/horse.4634.jpg
#   inflating: cifar10/cifar10/test/horse.4655.jpg
#   inflating: cifar10/cifar10/test/truck.4656.jpg
#   inflating: cifar10/cifar10/test/horse.4657.jpg
#   inflating: cifar10/cifar10/test/horse.4664.jpg
#   inflating: cifar10/cifar10/test/frog.4669.jpg
#   inflating: cifar10/cifar10/test/frog.4671.jpg
#   inflating: cifar10/cifar10/test/horse.4676.jpg
#   inflating: cifar10/cifar10/test/frog.4743.jpg
#   inflating: cifar10/cifar10/test/dog.4747.jpg
#   inflating: cifar10/cifar10/test/bird.4753.jpg
#   inflating: cifar10/cifar10/test/frog.4767.jpg
#   inflating: cifar10/cifar10/test/frog.4774.jpg
#   inflating: cifar10/cifar10/test/bird.4775.jpg
#   inflating: cifar10/cifar10/test/bird.4782.jpg
#   inflating: cifar10/cifar10/test/cat.4785.jpg
#   inflating: cifar10/cifar10/test/frog.4786.jpg
#   inflating: cifar10/cifar10/test/frog.4788.jpg
#   inflating: cifar10/cifar10/test/cat.4804.jpg
#   inflating: cifar10/cifar10/test/cat.4818.jpg
#   inflating: cifar10/cifar10/test/automobile.4822.jpg
#   inflating: cifar10/cifar10/test/dog.4829.jpg
#   inflating: cifar10/cifar10/test/automobile.4838.jpg
#   inflating: cifar10/cifar10/test/automobile.4843.jpg
#   inflating: cifar10/cifar10/test/dog.4844.jpg
#   inflating: cifar10/cifar10/test/truck.4851.jpg
#   inflating: cifar10/cifar10/test/airplane.4854.jpg
#   inflating: cifar10/cifar10/test/automobile.4855.jpg
#   inflating: cifar10/cifar10/test/frog.4859.jpg
#   inflating: cifar10/cifar10/test/airplane.4861.jpg
#   inflating: cifar10/cifar10/test/airplane.4868.jpg
#   inflating: cifar10/cifar10/test/truck.4874.jpg
#   inflating: cifar10/cifar10/test/frog.4879.jpg
#   inflating: cifar10/cifar10/test/dog.4888.jpg
#   inflating: cifar10/cifar10/test/automobile.4895.jpg
#   inflating: cifar10/cifar10/test/airplane.4901.jpg
#   inflating: cifar10/cifar10/test/truck.4904.jpg
#   inflating: cifar10/cifar10/test/ship.4910.jpg
#   inflating: cifar10/cifar10/test/ship.4919.jpg
#   inflating: cifar10/cifar10/test/automobile.4927.jpg
#   inflating: cifar10/cifar10/test/deer.4957.jpg
#   inflating: cifar10/cifar10/test/deer.4958.jpg
#   inflating: cifar10/cifar10/test/cat.4962.jpg
#   inflating: cifar10/cifar10/test/cat.4965.jpg
#   inflating: cifar10/cifar10/test/ship.4972.jpg
#   inflating: cifar10/cifar10/test/frog.5016.jpg
#   inflating: cifar10/cifar10/test/airplane.5021.jpg
#   inflating: cifar10/cifar10/test/cat.5050.jpg
#   inflating: cifar10/cifar10/test/automobile.5051.jpg
#   inflating: cifar10/cifar10/test/frog.5052.jpg
#   inflating: cifar10/cifar10/test/ship.5073.jpg
#   inflating: cifar10/cifar10/test/airplane.5074.jpg
#   inflating: cifar10/cifar10/test/truck.5083.jpg
#   inflating: cifar10/cifar10/test/cat.5086.jpg
#   inflating: cifar10/cifar10/test/automobile.5090.jpg
#   inflating: cifar10/cifar10/test/truck.5092.jpg
#   inflating: cifar10/cifar10/test/ship.5104.jpg
#   inflating: cifar10/cifar10/test/horse.5105.jpg
#   inflating: cifar10/cifar10/test/truck.5107.jpg
#   inflating: cifar10/cifar10/test/ship.5110.jpg
#   inflating: cifar10/cifar10/test/truck.5120.jpg
#   inflating: cifar10/cifar10/test/cat.5128.jpg
#   inflating: cifar10/cifar10/test/cat.5148.jpg
#   inflating: cifar10/cifar10/test/horse.5162.jpg
#   inflating: cifar10/cifar10/test/bird.5165.jpg
#   inflating: cifar10/cifar10/test/cat.5200.jpg
#   inflating: cifar10/cifar10/test/ship.5205.jpg
#   inflating: cifar10/cifar10/test/cat.5206.jpg
#   inflating: cifar10/cifar10/test/cat.5218.jpg
#   inflating: cifar10/cifar10/test/truck.5248.jpg
#   inflating: cifar10/cifar10/test/bird.5274.jpg
#   inflating: cifar10/cifar10/test/truck.5276.jpg
#   inflating: cifar10/cifar10/test/cat.5281.jpg
#   inflating: cifar10/cifar10/test/deer.5288.jpg
#   inflating: cifar10/cifar10/test/deer.5296.jpg
#   inflating: cifar10/cifar10/test/dog.5298.jpg
#   inflating: cifar10/cifar10/test/truck.5300.jpg
#   inflating: cifar10/cifar10/test/horse.5304.jpg
#   inflating: cifar10/cifar10/test/truck.5350.jpg
#   inflating: cifar10/cifar10/test/airplane.5357.jpg
#   inflating: cifar10/cifar10/test/automobile.5378.jpg
#   inflating: cifar10/cifar10/test/automobile.5394.jpg
#   inflating: cifar10/cifar10/test/automobile.5396.jpg
#   inflating: cifar10/cifar10/test/deer.5402.jpg
#   inflating: cifar10/cifar10/test/automobile.5409.jpg
#   inflating: cifar10/cifar10/test/cat.5410.jpg
#   inflating: cifar10/cifar10/test/horse.5435.jpg
#   inflating: cifar10/cifar10/test/automobile.5439.jpg
#   inflating: cifar10/cifar10/test/truck.5440.jpg
#   inflating: cifar10/cifar10/test/horse.5444.jpg
#   inflating: cifar10/cifar10/test/horse.5445.jpg
#   inflating: cifar10/cifar10/test/dog.5450.jpg
#   inflating: cifar10/cifar10/test/airplane.5454.jpg
#   inflating: cifar10/cifar10/test/automobile.5474.jpg
#   inflating: cifar10/cifar10/test/frog.5476.jpg
#   inflating: cifar10/cifar10/test/ship.5485.jpg
#   inflating: cifar10/cifar10/test/airplane.5491.jpg
#   inflating: cifar10/cifar10/test/ship.5503.jpg
#   inflating: cifar10/cifar10/test/deer.5505.jpg
#   inflating: cifar10/cifar10/test/deer.5510.jpg
#   inflating: cifar10/cifar10/test/bird.5533.jpg
#   inflating: cifar10/cifar10/test/bird.5537.jpg
#   inflating: cifar10/cifar10/test/dog.5552.jpg
#   inflating: cifar10/cifar10/test/dog.5553.jpg
#   inflating: cifar10/cifar10/test/automobile.5566.jpg
#   inflating: cifar10/cifar10/test/frog.5567.jpg
#   inflating: cifar10/cifar10/test/cat.5575.jpg
#   inflating: cifar10/cifar10/test/bird.5577.jpg
#   inflating: cifar10/cifar10/test/airplane.5585.jpg
#   inflating: cifar10/cifar10/test/deer.5602.jpg
#   inflating: cifar10/cifar10/test/dog.5609.jpg
#   inflating: cifar10/cifar10/test/frog.5616.jpg
#   inflating: cifar10/cifar10/test/automobile.5624.jpg
#   inflating: cifar10/cifar10/test/frog.5631.jpg
#   inflating: cifar10/cifar10/test/airplane.5652.jpg
#   inflating: cifar10/cifar10/test/dog.5653.jpg
#   inflating: cifar10/cifar10/test/deer.5658.jpg
#   inflating: cifar10/cifar10/test/horse.5684.jpg
#   inflating: cifar10/cifar10/test/bird.5687.jpg
#   inflating: cifar10/cifar10/test/dog.5692.jpg
#   inflating: cifar10/cifar10/test/bird.5705.jpg
#   inflating: cifar10/cifar10/test/airplane.5707.jpg
#   inflating: cifar10/cifar10/test/bird.5712.jpg
#   inflating: cifar10/cifar10/test/bird.5739.jpg
#   inflating: cifar10/cifar10/test/truck.5759.jpg
#   inflating: cifar10/cifar10/test/airplane.5762.jpg
#   inflating: cifar10/cifar10/test/cat.5769.jpg
#   inflating: cifar10/cifar10/test/cat.5773.jpg
#   inflating: cifar10/cifar10/test/horse.5778.jpg
#   inflating: cifar10/cifar10/test/ship.5793.jpg
#   inflating: cifar10/cifar10/test/frog.5807.jpg
#   inflating: cifar10/cifar10/test/dog.5810.jpg
#   inflating: cifar10/cifar10/test/dog.5823.jpg
#   inflating: cifar10/cifar10/test/frog.5831.jpg
#   inflating: cifar10/cifar10/test/bird.5837.jpg
#   inflating: cifar10/cifar10/test/deer.5838.jpg
#   inflating: cifar10/cifar10/test/airplane.5880.jpg
#   inflating: cifar10/cifar10/test/automobile.5887.jpg
#   inflating: cifar10/cifar10/test/frog.5889.jpg
#   inflating: cifar10/cifar10/test/cat.5890.jpg
#   inflating: cifar10/cifar10/test/truck.5902.jpg
#   inflating: cifar10/cifar10/test/deer.5906.jpg
#   inflating: cifar10/cifar10/test/automobile.5909.jpg
#   inflating: cifar10/cifar10/test/horse.5913.jpg
#   inflating: cifar10/cifar10/test/dog.5930.jpg
#   inflating: cifar10/cifar10/test/truck.5952.jpg
#   inflating: cifar10/cifar10/test/airplane.5968.jpg
#   inflating: cifar10/cifar10/test/ship.5972.jpg
#   inflating: cifar10/cifar10/test/truck.5982.jpg
#   inflating: cifar10/cifar10/test/ship.5993.jpg
#   inflating: cifar10/cifar10/test/deer.5994.jpg
#   inflating: cifar10/cifar10/test/horse.5998.jpg
#   inflating: cifar10/cifar10/test/dog.6035.jpg
#   inflating: cifar10/cifar10/test/deer.6038.jpg
#   inflating: cifar10/cifar10/test/horse.6041.jpg
#   inflating: cifar10/cifar10/test/airplane.6055.jpg
#   inflating: cifar10/cifar10/test/automobile.6080.jpg
#   inflating: cifar10/cifar10/test/dog.6092.jpg
#   inflating: cifar10/cifar10/test/dog.6094.jpg
#   inflating: cifar10/cifar10/test/automobile.6100.jpg
#   inflating: cifar10/cifar10/test/truck.6107.jpg
#   inflating: cifar10/cifar10/test/truck.6114.jpg
#   inflating: cifar10/cifar10/test/automobile.6159.jpg
#   inflating: cifar10/cifar10/test/cat.6163.jpg
#   inflating: cifar10/cifar10/test/horse.6164.jpg
#   inflating: cifar10/cifar10/test/cat.6174.jpg
#   inflating: cifar10/cifar10/test/ship.6179.jpg
#   inflating: cifar10/cifar10/test/automobile.6182.jpg
#   inflating: cifar10/cifar10/test/truck.6188.jpg
#   inflating: cifar10/cifar10/test/automobile.6195.jpg
#   inflating: cifar10/cifar10/test/automobile.6205.jpg
#   inflating: cifar10/cifar10/test/deer.6210.jpg
#   inflating: cifar10/cifar10/test/horse.6219.jpg
#   inflating: cifar10/cifar10/test/deer.6228.jpg
#   inflating: cifar10/cifar10/test/deer.6246.jpg
#   inflating: cifar10/cifar10/test/dog.6249.jpg
#   inflating: cifar10/cifar10/test/airplane.6258.jpg
#   inflating: cifar10/cifar10/test/automobile.6301.jpg
#   inflating: cifar10/cifar10/test/ship.6348.jpg
#   inflating: cifar10/cifar10/test/airplane.6351.jpg
#   inflating: cifar10/cifar10/test/airplane.6355.jpg
#   inflating: cifar10/cifar10/test/horse.6356.jpg
#   inflating: cifar10/cifar10/test/deer.6362.jpg
#   inflating: cifar10/cifar10/test/truck.6369.jpg
#   inflating: cifar10/cifar10/test/automobile.6372.jpg
#   inflating: cifar10/cifar10/test/deer.6382.jpg
#   inflating: cifar10/cifar10/test/horse.6390.jpg
#   inflating: cifar10/cifar10/test/cat.6393.jpg
#   inflating: cifar10/cifar10/test/airplane.6394.jpg
#   inflating: cifar10/cifar10/test/frog.6398.jpg
#   inflating: cifar10/cifar10/test/horse.6404.jpg
#   inflating: cifar10/cifar10/test/automobile.6405.jpg
#   inflating: cifar10/cifar10/test/automobile.6410.jpg
#   inflating: cifar10/cifar10/test/automobile.6415.jpg
#   inflating: cifar10/cifar10/test/ship.6429.jpg
#   inflating: cifar10/cifar10/test/automobile.6431.jpg
#   inflating: cifar10/cifar10/test/dog.6441.jpg
#   inflating: cifar10/cifar10/test/frog.6443.jpg
#   inflating: cifar10/cifar10/test/airplane.6450.jpg
#   inflating: cifar10/cifar10/test/airplane.6462.jpg
#   inflating: cifar10/cifar10/test/airplane.6491.jpg
#   inflating: cifar10/cifar10/test/deer.6498.jpg
#   inflating: cifar10/cifar10/test/horse.6517.jpg
#   inflating: cifar10/cifar10/test/ship.6524.jpg
#   inflating: cifar10/cifar10/test/bird.6529.jpg
#   inflating: cifar10/cifar10/test/bird.6533.jpg
#   inflating: cifar10/cifar10/test/frog.6543.jpg
#   inflating: cifar10/cifar10/test/automobile.6555.jpg
#   inflating: cifar10/cifar10/test/automobile.6566.jpg
#   inflating: cifar10/cifar10/test/ship.6569.jpg
#   inflating: cifar10/cifar10/test/bird.6593.jpg
#   inflating: cifar10/cifar10/test/bird.6599.jpg
#   inflating: cifar10/cifar10/test/airplane.6618.jpg
#   inflating: cifar10/cifar10/test/automobile.6643.jpg
#   inflating: cifar10/cifar10/test/deer.6654.jpg
#   inflating: cifar10/cifar10/test/horse.6657.jpg
#   inflating: cifar10/cifar10/test/airplane.6676.jpg
#   inflating: cifar10/cifar10/test/dog.6690.jpg
#   inflating: cifar10/cifar10/test/bird.6699.jpg
#   inflating: cifar10/cifar10/test/cat.6709.jpg
#   inflating: cifar10/cifar10/test/ship.6716.jpg
#   inflating: cifar10/cifar10/test/airplane.6717.jpg
#   inflating: cifar10/cifar10/test/deer.6736.jpg
#   inflating: cifar10/cifar10/test/deer.6750.jpg
#   inflating: cifar10/cifar10/test/ship.6765.jpg
#   inflating: cifar10/cifar10/test/ship.6766.jpg
#   inflating: cifar10/cifar10/test/cat.6781.jpg
#   inflating: cifar10/cifar10/test/cat.6783.jpg
#   inflating: cifar10/cifar10/test/dog.6787.jpg
#   inflating: cifar10/cifar10/test/automobile.6788.jpg
#   inflating: cifar10/cifar10/test/automobile.6789.jpg
#   inflating: cifar10/cifar10/test/automobile.6806.jpg
#   inflating: cifar10/cifar10/test/airplane.6815.jpg
#   inflating: cifar10/cifar10/test/truck.6840.jpg
#   inflating: cifar10/cifar10/test/frog.6867.jpg
#   inflating: cifar10/cifar10/test/bird.6881.jpg
#   inflating: cifar10/cifar10/test/cat.6893.jpg
#   inflating: cifar10/cifar10/test/truck.6897.jpg
#   inflating: cifar10/cifar10/test/cat.6913.jpg
#   inflating: cifar10/cifar10/test/ship.6961.jpg
#   inflating: cifar10/cifar10/test/horse.6977.jpg
#   inflating: cifar10/cifar10/test/deer.6978.jpg
#   inflating: cifar10/cifar10/test/ship.6997.jpg
#   inflating: cifar10/cifar10/test/truck.7007.jpg
#   inflating: cifar10/cifar10/test/automobile.7013.jpg
#   inflating: cifar10/cifar10/test/bird.7022.jpg
#   inflating: cifar10/cifar10/test/dog.7064.jpg
#   inflating: cifar10/cifar10/test/truck.7076.jpg
#   inflating: cifar10/cifar10/test/ship.7088.jpg
#   inflating: cifar10/cifar10/test/horse.7089.jpg
#   inflating: cifar10/cifar10/test/deer.7094.jpg
#   inflating: cifar10/cifar10/test/dog.7111.jpg
#   inflating: cifar10/cifar10/test/airplane.7116.jpg
#   inflating: cifar10/cifar10/test/frog.7130.jpg
#   inflating: cifar10/cifar10/test/dog.7149.jpg
#   inflating: cifar10/cifar10/test/horse.7153.jpg
#   inflating: cifar10/cifar10/test/airplane.7154.jpg
#   inflating: cifar10/cifar10/test/dog.7161.jpg
#   inflating: cifar10/cifar10/test/automobile.7169.jpg
#   inflating: cifar10/cifar10/test/frog.7180.jpg
#   inflating: cifar10/cifar10/test/airplane.7189.jpg
#   inflating: cifar10/cifar10/test/cat.7207.jpg
#   inflating: cifar10/cifar10/test/airplane.7209.jpg
#   inflating: cifar10/cifar10/test/automobile.7215.jpg
#   inflating: cifar10/cifar10/test/cat.7221.jpg
#   inflating: cifar10/cifar10/test/airplane.7240.jpg
#   inflating: cifar10/cifar10/test/ship.7247.jpg
#   inflating: cifar10/cifar10/test/ship.7261.jpg
#   inflating: cifar10/cifar10/test/automobile.7276.jpg
#   inflating: cifar10/cifar10/test/dog.7278.jpg
#   inflating: cifar10/cifar10/test/dog.7287.jpg
#   inflating: cifar10/cifar10/test/frog.7301.jpg
#   inflating: cifar10/cifar10/test/automobile.7311.jpg
#   inflating: cifar10/cifar10/test/bird.7319.jpg
#   inflating: cifar10/cifar10/test/deer.7327.jpg
#   inflating: cifar10/cifar10/test/automobile.7329.jpg
#   inflating: cifar10/cifar10/test/dog.7330.jpg
#   inflating: cifar10/cifar10/test/deer.7335.jpg
#   inflating: cifar10/cifar10/test/deer.7341.jpg
#   inflating: cifar10/cifar10/test/cat.7349.jpg
#   inflating: cifar10/cifar10/test/ship.7358.jpg
#   inflating: cifar10/cifar10/test/dog.7368.jpg
#   inflating: cifar10/cifar10/test/cat.7377.jpg
#   inflating: cifar10/cifar10/test/automobile.7387.jpg
#   inflating: cifar10/cifar10/test/deer.7391.jpg
#   inflating: cifar10/cifar10/test/cat.7400.jpg
#   inflating: cifar10/cifar10/test/truck.7424.jpg
#   inflating: cifar10/cifar10/test/horse.7426.jpg
#   inflating: cifar10/cifar10/test/bird.7427.jpg
#   inflating: cifar10/cifar10/test/airplane.7428.jpg
#   inflating: cifar10/cifar10/test/dog.7429.jpg
#   inflating: cifar10/cifar10/test/frog.7445.jpg
#   inflating: cifar10/cifar10/test/ship.7447.jpg
#   inflating: cifar10/cifar10/test/automobile.7450.jpg
#   inflating: cifar10/cifar10/test/truck.7451.jpg
#   inflating: cifar10/cifar10/test/cat.7475.jpg
#   inflating: cifar10/cifar10/test/deer.7490.jpg
#   inflating: cifar10/cifar10/test/bird.7519.jpg
#   inflating: cifar10/cifar10/test/deer.7520.jpg
#   inflating: cifar10/cifar10/test/cat.7524.jpg
#   inflating: cifar10/cifar10/test/bird.7530.jpg
#   inflating: cifar10/cifar10/test/airplane.7560.jpg
#   inflating: cifar10/cifar10/test/truck.7563.jpg
#   inflating: cifar10/cifar10/test/horse.7587.jpg
#   inflating: cifar10/cifar10/test/truck.7592.jpg
#   inflating: cifar10/cifar10/test/frog.7593.jpg
#   inflating: cifar10/cifar10/test/automobile.7595.jpg
#   inflating: cifar10/cifar10/test/cat.7618.jpg
#   inflating: cifar10/cifar10/test/truck.7630.jpg
#   inflating: cifar10/cifar10/test/truck.7640.jpg
#   inflating: cifar10/cifar10/test/frog.7672.jpg
#   inflating: cifar10/cifar10/test/frog.7687.jpg
#   inflating: cifar10/cifar10/test/airplane.7698.jpg
#   inflating: cifar10/cifar10/test/cat.7709.jpg
#   inflating: cifar10/cifar10/test/dog.7716.jpg
#   inflating: cifar10/cifar10/test/bird.7719.jpg
#   inflating: cifar10/cifar10/test/bird.7738.jpg
#   inflating: cifar10/cifar10/test/automobile.7749.jpg
#   inflating: cifar10/cifar10/test/horse.7755.jpg
#   inflating: cifar10/cifar10/test/horse.7758.jpg
#   inflating: cifar10/cifar10/test/deer.7763.jpg
#   inflating: cifar10/cifar10/test/frog.7764.jpg
#   inflating: cifar10/cifar10/test/truck.7770.jpg
#   inflating: cifar10/cifar10/test/bird.7771.jpg
#   inflating: cifar10/cifar10/test/cat.7783.jpg
#   inflating: cifar10/cifar10/test/cat.7789.jpg
#   inflating: cifar10/cifar10/test/dog.7795.jpg
#   inflating: cifar10/cifar10/test/dog.7804.jpg
#   inflating: cifar10/cifar10/test/dog.7834.jpg
#   inflating: cifar10/cifar10/test/airplane.7843.jpg
#   inflating: cifar10/cifar10/test/horse.7847.jpg
#   inflating: cifar10/cifar10/test/automobile.7862.jpg
#   inflating: cifar10/cifar10/test/airplane.7863.jpg
#   inflating: cifar10/cifar10/test/frog.7874.jpg
#   inflating: cifar10/cifar10/test/cat.7879.jpg
#   inflating: cifar10/cifar10/test/automobile.7893.jpg
#   inflating: cifar10/cifar10/test/horse.7899.jpg
#   inflating: cifar10/cifar10/test/automobile.7901.jpg
#   inflating: cifar10/cifar10/test/deer.7916.jpg
#   inflating: cifar10/cifar10/test/ship.7922.jpg
#   inflating: cifar10/cifar10/test/truck.7931.jpg
#   inflating: cifar10/cifar10/test/bird.7938.jpg
#   inflating: cifar10/cifar10/test/dog.7941.jpg
#   inflating: cifar10/cifar10/test/automobile.7948.jpg
#   inflating: cifar10/cifar10/test/automobile.7953.jpg
#   inflating: cifar10/cifar10/test/ship.7977.jpg
#   inflating: cifar10/cifar10/test/cat.7980.jpg
#   inflating: cifar10/cifar10/test/ship.7984.jpg
#   inflating: cifar10/cifar10/test/truck.7991.jpg
#   inflating: cifar10/cifar10/test/truck.8000.jpg
#   inflating: cifar10/cifar10/test/automobile.8005.jpg
#   inflating: cifar10/cifar10/test/bird.8014.jpg
#   inflating: cifar10/cifar10/test/bird.8030.jpg
#   inflating: cifar10/cifar10/test/truck.8034.jpg
#   inflating: cifar10/cifar10/test/automobile.8035.jpg
#   inflating: cifar10/cifar10/test/truck.8044.jpg
#   inflating: cifar10/cifar10/test/bird.8055.jpg
#   inflating: cifar10/cifar10/test/deer.8058.jpg
#   inflating: cifar10/cifar10/test/airplane.8073.jpg
#   inflating: cifar10/cifar10/test/deer.8080.jpg
#   inflating: cifar10/cifar10/test/bird.8085.jpg
#   inflating: cifar10/cifar10/test/horse.8088.jpg
#   inflating: cifar10/cifar10/test/horse.8091.jpg
#   inflating: cifar10/cifar10/test/deer.8092.jpg
#   inflating: cifar10/cifar10/test/horse.8093.jpg
#   inflating: cifar10/cifar10/test/cat.8096.jpg
#   inflating: cifar10/cifar10/test/automobile.8097.jpg
#   inflating: cifar10/cifar10/test/cat.8102.jpg
#   inflating: cifar10/cifar10/test/bird.8109.jpg
#   inflating: cifar10/cifar10/test/cat.8131.jpg
#   inflating: cifar10/cifar10/test/automobile.8139.jpg
#   inflating: cifar10/cifar10/test/truck.8145.jpg
#   inflating: cifar10/cifar10/test/frog.8150.jpg
#   inflating: cifar10/cifar10/test/deer.8153.jpg
#   inflating: cifar10/cifar10/test/automobile.8155.jpg
#   inflating: cifar10/cifar10/test/frog.8164.jpg
#   inflating: cifar10/cifar10/test/frog.8168.jpg
#   inflating: cifar10/cifar10/test/truck.8178.jpg
#   inflating: cifar10/cifar10/test/deer.8179.jpg
#   inflating: cifar10/cifar10/test/dog.8187.jpg
#   inflating: cifar10/cifar10/test/ship.8208.jpg
#   inflating: cifar10/cifar10/test/dog.8212.jpg
#   inflating: cifar10/cifar10/test/cat.8219.jpg
#   inflating: cifar10/cifar10/test/horse.8221.jpg
#   inflating: cifar10/cifar10/test/horse.8237.jpg
#   inflating: cifar10/cifar10/test/automobile.8238.jpg
#   inflating: cifar10/cifar10/test/dog.8242.jpg
#   inflating: cifar10/cifar10/test/ship.8256.jpg
#   inflating: cifar10/cifar10/test/cat.8281.jpg
#   inflating: cifar10/cifar10/test/horse.8286.jpg
#   inflating: cifar10/cifar10/test/dog.8301.jpg
#   inflating: cifar10/cifar10/test/frog.8306.jpg
#   inflating: cifar10/cifar10/test/dog.8317.jpg
#   inflating: cifar10/cifar10/test/ship.8339.jpg
#   inflating: cifar10/cifar10/test/automobile.8342.jpg
#   inflating: cifar10/cifar10/test/truck.8355.jpg
#   inflating: cifar10/cifar10/test/ship.8361.jpg
#   inflating: cifar10/cifar10/test/deer.8369.jpg
#   inflating: cifar10/cifar10/test/truck.8380.jpg
#   inflating: cifar10/cifar10/test/bird.8383.jpg
#   inflating: cifar10/cifar10/test/deer.8398.jpg
#   inflating: cifar10/cifar10/test/ship.8411.jpg
#   inflating: cifar10/cifar10/test/truck.8426.jpg
#   inflating: cifar10/cifar10/test/frog.8442.jpg
#   inflating: cifar10/cifar10/test/bird.8454.jpg
#   inflating: cifar10/cifar10/test/bird.8472.jpg
#   inflating: cifar10/cifar10/test/truck.8475.jpg
#   inflating: cifar10/cifar10/test/bird.8480.jpg
#   inflating: cifar10/cifar10/test/cat.8491.jpg
#   inflating: cifar10/cifar10/test/bird.8493.jpg
#   inflating: cifar10/cifar10/test/automobile.8504.jpg
#   inflating: cifar10/cifar10/test/horse.8510.jpg
#   inflating: cifar10/cifar10/test/ship.8530.jpg
#   inflating: cifar10/cifar10/test/cat.8532.jpg
#   inflating: cifar10/cifar10/test/horse.8538.jpg
#   inflating: cifar10/cifar10/test/cat.8548.jpg
#   inflating: cifar10/cifar10/test/ship.8551.jpg
#   inflating: cifar10/cifar10/test/bird.8562.jpg
#   inflating: cifar10/cifar10/test/automobile.8564.jpg
#   inflating: cifar10/cifar10/test/frog.8588.jpg
#   inflating: cifar10/cifar10/test/cat.8594.jpg
#   inflating: cifar10/cifar10/test/dog.8618.jpg
#   inflating: cifar10/cifar10/test/cat.8620.jpg
#   inflating: cifar10/cifar10/test/horse.8627.jpg
#   inflating: cifar10/cifar10/test/airplane.8638.jpg
#   inflating: cifar10/cifar10/test/automobile.8648.jpg
#   inflating: cifar10/cifar10/test/truck.8652.jpg
#   inflating: cifar10/cifar10/test/ship.8679.jpg
#   inflating: cifar10/cifar10/test/bird.8681.jpg
#   inflating: cifar10/cifar10/test/truck.8693.jpg
#   inflating: cifar10/cifar10/test/bird.8720.jpg
#   inflating: cifar10/cifar10/test/bird.8740.jpg
#   inflating: cifar10/cifar10/test/frog.8748.jpg
#   inflating: cifar10/cifar10/test/dog.8749.jpg
#   inflating: cifar10/cifar10/test/frog.8771.jpg
#   inflating: cifar10/cifar10/test/cat.8786.jpg
#   inflating: cifar10/cifar10/test/airplane.8795.jpg
#   inflating: cifar10/cifar10/test/cat.8803.jpg
#   inflating: cifar10/cifar10/test/truck.8805.jpg
#   inflating: cifar10/cifar10/test/cat.8806.jpg
#   inflating: cifar10/cifar10/test/horse.8816.jpg
#   inflating: cifar10/cifar10/test/deer.8817.jpg
#   inflating: cifar10/cifar10/test/cat.8818.jpg
#   inflating: cifar10/cifar10/test/bird.8820.jpg
#   inflating: cifar10/cifar10/test/ship.8834.jpg
#   inflating: cifar10/cifar10/test/ship.8838.jpg
#   inflating: cifar10/cifar10/test/automobile.8839.jpg
#   inflating: cifar10/cifar10/test/frog.8858.jpg
#   inflating: cifar10/cifar10/test/bird.8860.jpg
#   inflating: cifar10/cifar10/test/dog.8870.jpg
#   inflating: cifar10/cifar10/test/truck.8877.jpg
#   inflating: cifar10/cifar10/test/truck.8879.jpg
#   inflating: cifar10/cifar10/test/cat.8885.jpg
#   inflating: cifar10/cifar10/test/frog.8893.jpg
#   inflating: cifar10/cifar10/test/airplane.8894.jpg
#   inflating: cifar10/cifar10/test/dog.8901.jpg
#   inflating: cifar10/cifar10/test/airplane.8909.jpg
#   inflating: cifar10/cifar10/test/deer.8911.jpg
#   inflating: cifar10/cifar10/test/truck.8927.jpg
#   inflating: cifar10/cifar10/test/deer.8928.jpg
#   inflating: cifar10/cifar10/test/cat.8930.jpg
#   inflating: cifar10/cifar10/test/truck.8946.jpg
#   inflating: cifar10/cifar10/test/horse.8949.jpg
#   inflating: cifar10/cifar10/test/dog.8973.jpg
#   inflating: cifar10/cifar10/test/bird.8974.jpg
#   inflating: cifar10/cifar10/test/cat.8983.jpg
#   inflating: cifar10/cifar10/test/frog.9002.jpg
#   inflating: cifar10/cifar10/test/cat.9003.jpg
#   inflating: cifar10/cifar10/test/airplane.9021.jpg
#   inflating: cifar10/cifar10/test/cat.9022.jpg
#   inflating: cifar10/cifar10/test/bird.9033.jpg
#   inflating: cifar10/cifar10/test/bird.9038.jpg
#   inflating: cifar10/cifar10/test/bird.9040.jpg
#   inflating: cifar10/cifar10/test/bird.9059.jpg
#   inflating: cifar10/cifar10/test/truck.9062.jpg
#   inflating: cifar10/cifar10/test/truck.9072.jpg
#   inflating: cifar10/cifar10/test/deer.9073.jpg
#   inflating: cifar10/cifar10/test/deer.9112.jpg
#   inflating: cifar10/cifar10/test/automobile.9145.jpg
#   inflating: cifar10/cifar10/test/horse.9149.jpg
#   inflating: cifar10/cifar10/test/frog.9156.jpg
#   inflating: cifar10/cifar10/test/bird.9168.jpg
#   inflating: cifar10/cifar10/test/ship.9176.jpg
#   inflating: cifar10/cifar10/test/airplane.9196.jpg
#   inflating: cifar10/cifar10/test/frog.9212.jpg
#   inflating: cifar10/cifar10/test/frog.9216.jpg
#   inflating: cifar10/cifar10/test/cat.9228.jpg
#   inflating: cifar10/cifar10/test/horse.9231.jpg
#   inflating: cifar10/cifar10/test/truck.9247.jpg
#   inflating: cifar10/cifar10/test/truck.9249.jpg
#   inflating: cifar10/cifar10/test/dog.9260.jpg
#   inflating: cifar10/cifar10/test/horse.9278.jpg
#   inflating: cifar10/cifar10/test/horse.9286.jpg
#   inflating: cifar10/cifar10/test/automobile.9298.jpg
#   inflating: cifar10/cifar10/test/frog.9317.jpg
#   inflating: cifar10/cifar10/test/frog.9325.jpg
#   inflating: cifar10/cifar10/test/horse.9331.jpg
#   inflating: cifar10/cifar10/test/deer.9335.jpg
#   inflating: cifar10/cifar10/test/bird.9341.jpg
#   inflating: cifar10/cifar10/test/ship.9343.jpg
#   inflating: cifar10/cifar10/test/frog.9350.jpg
#   inflating: cifar10/cifar10/test/dog.9353.jpg
#   inflating: cifar10/cifar10/test/airplane.9356.jpg
#   inflating: cifar10/cifar10/test/truck.9357.jpg
#   inflating: cifar10/cifar10/test/bird.9358.jpg
#   inflating: cifar10/cifar10/test/dog.9380.jpg
#   inflating: cifar10/cifar10/test/bird.9381.jpg
#   inflating: cifar10/cifar10/test/deer.9384.jpg
#   inflating: cifar10/cifar10/test/dog.9410.jpg
#   inflating: cifar10/cifar10/test/cat.9431.jpg
#   inflating: cifar10/cifar10/test/ship.9451.jpg
# ...
#   inflating: cifar10/cifar10/test/truck.6936.jpg
#   inflating: cifar10/cifar10/test/cat.6938.jpg
#   inflating: cifar10/cifar10/test/deer.6941.jpg
#   inflating: cifar10/cifar10/test/cat.6942.jpg
#   inflating: cifar10/cifar10/test/deer.6943.jpg
#   inflating: cifar10/cifar10/test/truck.6960.jpg
#   inflating: cifar10/cifar10/test/automobile.6972.jpg
#   inflating: cifar10/cifar10/test/cat.7002.jpg
#   inflating: cifar10/cifar10/test/cat.7004.jpg
#   inflating: cifar10/cifar10/test/horse.7012.jpg
#   inflating: cifar10/cifar10/test/horse.7020.jpg
#   inflating: cifar10/cifar10/test/automobile.7021.jpg
#   inflating: cifar10/cifar10/test/cat.7026.jpg
#   inflating: cifar10/cifar10/test/deer.7041.jpg
#   inflating: cifar10/cifar10/test/ship.7042.jpg
#   inflating: cifar10/cifar10/test/ship.7055.jpg
#   inflating: cifar10/cifar10/test/frog.7057.jpg
#   inflating: cifar10/cifar10/test/horse.7079.jpg
#   inflating: cifar10/cifar10/test/deer.7081.jpg
#   inflating: cifar10/cifar10/test/dog.7085.jpg
#   inflating: cifar10/cifar10/test/cat.7099.jpg
#   inflating: cifar10/cifar10/test/dog.7119.jpg
#   inflating: cifar10/cifar10/test/truck.7121.jpg
#   inflating: cifar10/cifar10/test/dog.7127.jpg
#   inflating: cifar10/cifar10/test/ship.7142.jpg
#   inflating: cifar10/cifar10/test/automobile.7166.jpg
#   inflating: cifar10/cifar10/test/deer.7172.jpg
#   inflating: cifar10/cifar10/test/frog.7181.jpg
#   inflating: cifar10/cifar10/test/deer.7188.jpg
#   inflating: cifar10/cifar10/test/bird.7190.jpg
#   inflating: cifar10/cifar10/test/dog.7233.jpg
#   inflating: cifar10/cifar10/test/deer.7238.jpg
#   inflating: cifar10/cifar10/test/dog.7241.jpg
#   inflating: cifar10/cifar10/test/ship.7250.jpg
#   inflating: cifar10/cifar10/test/cat.7255.jpg
#   inflating: cifar10/cifar10/test/dog.7258.jpg
#   inflating: cifar10/cifar10/test/deer.7264.jpg
#   inflating: cifar10/cifar10/test/truck.7270.jpg
#   inflating: cifar10/cifar10/test/horse.7281.jpg
#   inflating: cifar10/cifar10/test/cat.7283.jpg
#   inflating: cifar10/cifar10/test/horse.7288.jpg
#   inflating: cifar10/cifar10/test/ship.7307.jpg
#   inflating: cifar10/cifar10/test/frog.7317.jpg
#   inflating: cifar10/cifar10/test/ship.7320.jpg
#   inflating: cifar10/cifar10/test/deer.7326.jpg
#   inflating: cifar10/cifar10/test/frog.7333.jpg
#   inflating: cifar10/cifar10/test/frog.7339.jpg
#   inflating: cifar10/cifar10/test/airplane.7354.jpg
#   inflating: cifar10/cifar10/test/bird.7366.jpg
#   inflating: cifar10/cifar10/test/horse.7380.jpg
#   inflating: cifar10/cifar10/test/bird.7395.jpg
#   inflating: cifar10/cifar10/test/deer.7397.jpg
#   inflating: cifar10/cifar10/test/horse.7406.jpg
#   inflating: cifar10/cifar10/test/truck.7407.jpg
#   inflating: cifar10/cifar10/test/dog.7421.jpg
#   inflating: cifar10/cifar10/test/airplane.7434.jpg
#   inflating: cifar10/cifar10/test/dog.7439.jpg
#   inflating: cifar10/cifar10/test/frog.7466.jpg
#   inflating: cifar10/cifar10/test/ship.7468.jpg
#   inflating: cifar10/cifar10/test/dog.7476.jpg
#   inflating: cifar10/cifar10/test/truck.7491.jpg
#   inflating: cifar10/cifar10/test/frog.7498.jpg
#   inflating: cifar10/cifar10/test/airplane.7523.jpg
#   inflating: cifar10/cifar10/test/ship.7525.jpg
#   inflating: cifar10/cifar10/test/truck.7547.jpg
#   inflating: cifar10/cifar10/test/bird.7558.jpg
#   inflating: cifar10/cifar10/test/bird.7562.jpg
#   inflating: cifar10/cifar10/test/automobile.7570.jpg
#   inflating: cifar10/cifar10/test/deer.7571.jpg
#   inflating: cifar10/cifar10/test/automobile.7623.jpg
#   inflating: cifar10/cifar10/test/deer.7628.jpg
#   inflating: cifar10/cifar10/test/automobile.7638.jpg
#   inflating: cifar10/cifar10/test/ship.7643.jpg
#   inflating: cifar10/cifar10/test/automobile.7656.jpg
#   inflating: cifar10/cifar10/test/bird.7659.jpg
#   inflating: cifar10/cifar10/test/truck.7661.jpg
#   inflating: cifar10/cifar10/test/bird.7664.jpg
#   inflating: cifar10/cifar10/test/truck.7665.jpg
#   inflating: cifar10/cifar10/test/frog.7667.jpg
#   inflating: cifar10/cifar10/test/ship.7682.jpg
#   inflating: cifar10/cifar10/test/truck.7685.jpg
#   inflating: cifar10/cifar10/test/airplane.7689.jpg
#   inflating: cifar10/cifar10/test/truck.7694.jpg
#   inflating: cifar10/cifar10/test/frog.7711.jpg
#   inflating: cifar10/cifar10/test/dog.7713.jpg
#   inflating: cifar10/cifar10/test/dog.7720.jpg
#   inflating: cifar10/cifar10/test/ship.7724.jpg
#   inflating: cifar10/cifar10/test/airplane.7733.jpg
#   inflating: cifar10/cifar10/test/airplane.7748.jpg
#   inflating: cifar10/cifar10/test/dog.7756.jpg
#   inflating: cifar10/cifar10/test/deer.7773.jpg
#   inflating: cifar10/cifar10/test/cat.7780.jpg
#   inflating: cifar10/cifar10/test/ship.7793.jpg
#   inflating: cifar10/cifar10/test/deer.7801.jpg
#   inflating: cifar10/cifar10/test/cat.7825.jpg
#   inflating: cifar10/cifar10/test/truck.7826.jpg
#   inflating: cifar10/cifar10/test/airplane.7850.jpg
#   inflating: cifar10/cifar10/test/bird.7858.jpg
#   inflating: cifar10/cifar10/test/horse.7859.jpg
#   inflating: cifar10/cifar10/test/dog.7887.jpg
#   inflating: cifar10/cifar10/test/horse.7888.jpg
#   inflating: cifar10/cifar10/test/automobile.7892.jpg
#   inflating: cifar10/cifar10/test/bird.7902.jpg
#   inflating: cifar10/cifar10/test/dog.7926.jpg
#   inflating: cifar10/cifar10/test/bird.7928.jpg
#   inflating: cifar10/cifar10/test/truck.7954.jpg
#   inflating: cifar10/cifar10/test/deer.7956.jpg
#   inflating: cifar10/cifar10/test/horse.7966.jpg
#   inflating: cifar10/cifar10/test/automobile.7973.jpg
#   inflating: cifar10/cifar10/test/frog.7988.jpg
#   inflating: cifar10/cifar10/test/automobile.8001.jpg
#   inflating: cifar10/cifar10/test/airplane.8017.jpg
#   inflating: cifar10/cifar10/test/cat.8023.jpg
#   inflating: cifar10/cifar10/test/airplane.8024.jpg
#   inflating: cifar10/cifar10/test/frog.8038.jpg
#   inflating: cifar10/cifar10/test/truck.8051.jpg
#   inflating: cifar10/cifar10/test/horse.8074.jpg
#   inflating: cifar10/cifar10/test/ship.8075.jpg
#   inflating: cifar10/cifar10/test/dog.8084.jpg
#   inflating: cifar10/cifar10/test/truck.8089.jpg
#   inflating: cifar10/cifar10/test/frog.8090.jpg
#   inflating: cifar10/cifar10/test/automobile.8138.jpg
#   inflating: cifar10/cifar10/test/ship.8146.jpg
#   inflating: cifar10/cifar10/test/ship.8151.jpg
#   inflating: cifar10/cifar10/test/dog.8172.jpg
#   inflating: cifar10/cifar10/test/dog.8173.jpg
#   inflating: cifar10/cifar10/test/cat.8175.jpg
#   inflating: cifar10/cifar10/test/cat.8201.jpg
#   inflating: cifar10/cifar10/test/cat.8216.jpg
#   inflating: cifar10/cifar10/test/automobile.8222.jpg
#   inflating: cifar10/cifar10/test/truck.8225.jpg
#   inflating: cifar10/cifar10/test/dog.8236.jpg
#   inflating: cifar10/cifar10/test/ship.8239.jpg
#   inflating: cifar10/cifar10/test/frog.8250.jpg
#   inflating: cifar10/cifar10/test/bird.8252.jpg
#   inflating: cifar10/cifar10/test/ship.8259.jpg
#   inflating: cifar10/cifar10/test/automobile.8297.jpg
#   inflating: cifar10/cifar10/test/deer.8307.jpg
#   inflating: cifar10/cifar10/test/frog.8314.jpg
#   inflating: cifar10/cifar10/test/bird.8359.jpg
#   inflating: cifar10/cifar10/test/deer.8375.jpg
#   inflating: cifar10/cifar10/test/cat.8386.jpg
#   inflating: cifar10/cifar10/test/horse.8394.jpg
#   inflating: cifar10/cifar10/test/cat.8396.jpg
#   inflating: cifar10/cifar10/test/airplane.8397.jpg
#   inflating: cifar10/cifar10/test/airplane.8415.jpg
#   inflating: cifar10/cifar10/test/horse.8419.jpg
#   inflating: cifar10/cifar10/test/frog.8423.jpg
#   inflating: cifar10/cifar10/test/dog.8424.jpg
#   inflating: cifar10/cifar10/test/dog.8428.jpg
#   inflating: cifar10/cifar10/test/dog.8444.jpg
#   inflating: cifar10/cifar10/test/deer.8456.jpg
#   inflating: cifar10/cifar10/test/truck.8459.jpg
#   inflating: cifar10/cifar10/test/horse.8461.jpg
#   inflating: cifar10/cifar10/test/frog.8464.jpg
#   inflating: cifar10/cifar10/test/deer.8486.jpg
#   inflating: cifar10/cifar10/test/airplane.8496.jpg
#   inflating: cifar10/cifar10/test/ship.8501.jpg
#   inflating: cifar10/cifar10/test/automobile.8502.jpg
#   inflating: cifar10/cifar10/test/truck.8518.jpg
#   inflating: cifar10/cifar10/test/frog.8523.jpg
#   inflating: cifar10/cifar10/test/frog.8524.jpg
#   inflating: cifar10/cifar10/test/cat.8557.jpg
#   inflating: cifar10/cifar10/test/bird.8558.jpg
#   inflating: cifar10/cifar10/test/ship.8567.jpg
#   inflating: cifar10/cifar10/test/horse.8571.jpg
#   inflating: cifar10/cifar10/test/bird.8576.jpg
#   inflating: cifar10/cifar10/test/frog.8586.jpg
#   inflating: cifar10/cifar10/test/horse.8587.jpg
#   inflating: cifar10/cifar10/test/ship.8602.jpg
#   inflating: cifar10/cifar10/test/frog.8605.jpg
#   inflating: cifar10/cifar10/test/deer.8612.jpg
#   inflating: cifar10/cifar10/test/cat.8616.jpg
#   inflating: cifar10/cifar10/test/automobile.8621.jpg
#   inflating: cifar10/cifar10/test/truck.8624.jpg
#   inflating: cifar10/cifar10/test/horse.8628.jpg
#   inflating: cifar10/cifar10/test/bird.8631.jpg
#   inflating: cifar10/cifar10/test/cat.8632.jpg
#   inflating: cifar10/cifar10/test/horse.8639.jpg
#   inflating: cifar10/cifar10/test/airplane.8643.jpg
#   inflating: cifar10/cifar10/test/automobile.8645.jpg
#   inflating: cifar10/cifar10/test/bird.8646.jpg
#   inflating: cifar10/cifar10/test/truck.8673.jpg
#   inflating: cifar10/cifar10/test/horse.8675.jpg
#   inflating: cifar10/cifar10/test/bird.8684.jpg
#   inflating: cifar10/cifar10/test/ship.8690.jpg
#   inflating: cifar10/cifar10/test/deer.8699.jpg
#   inflating: cifar10/cifar10/test/bird.8707.jpg
#   inflating: cifar10/cifar10/test/horse.8710.jpg
#   inflating: cifar10/cifar10/test/bird.8716.jpg
#   inflating: cifar10/cifar10/test/horse.8718.jpg
#   inflating: cifar10/cifar10/test/bird.8730.jpg
#   inflating: cifar10/cifar10/test/bird.8734.jpg
#   inflating: cifar10/cifar10/test/cat.8746.jpg
#   inflating: cifar10/cifar10/test/truck.8750.jpg
#   inflating: cifar10/cifar10/test/airplane.8761.jpg
#   inflating: cifar10/cifar10/test/deer.8787.jpg
#   inflating: cifar10/cifar10/test/dog.8789.jpg
#   inflating: cifar10/cifar10/test/truck.8796.jpg
#   inflating: cifar10/cifar10/test/automobile.8811.jpg
#   inflating: cifar10/cifar10/test/airplane.8812.jpg
#   inflating: cifar10/cifar10/test/airplane.8819.jpg
#   inflating: cifar10/cifar10/test/truck.8849.jpg
#   inflating: cifar10/cifar10/test/horse.8865.jpg
#   inflating: cifar10/cifar10/test/automobile.8866.jpg
#   inflating: cifar10/cifar10/test/frog.8940.jpg
#   inflating: cifar10/cifar10/test/ship.8951.jpg
#   inflating: cifar10/cifar10/test/bird.8956.jpg
#   inflating: cifar10/cifar10/test/airplane.8964.jpg
#   inflating: cifar10/cifar10/test/cat.8966.jpg
#   inflating: cifar10/cifar10/test/frog.8978.jpg
#   inflating: cifar10/cifar10/test/dog.8997.jpg
#   inflating: cifar10/cifar10/test/horse.9004.jpg
#   inflating: cifar10/cifar10/test/bird.9009.jpg
#   inflating: cifar10/cifar10/test/horse.9013.jpg
#   inflating: cifar10/cifar10/test/horse.9014.jpg
#   inflating: cifar10/cifar10/test/truck.9032.jpg
#   inflating: cifar10/cifar10/test/bird.9039.jpg
#   inflating: cifar10/cifar10/test/dog.9041.jpg
#   inflating: cifar10/cifar10/test/ship.9057.jpg
#   inflating: cifar10/cifar10/test/bird.9070.jpg
#   inflating: cifar10/cifar10/test/truck.9099.jpg
#   inflating: cifar10/cifar10/test/ship.9101.jpg
#   inflating: cifar10/cifar10/test/deer.9104.jpg
#   inflating: cifar10/cifar10/test/ship.9114.jpg
#   inflating: cifar10/cifar10/test/deer.9116.jpg
#   inflating: cifar10/cifar10/test/horse.9140.jpg
#   inflating: cifar10/cifar10/test/truck.9143.jpg
#   inflating: cifar10/cifar10/test/deer.9163.jpg
#   inflating: cifar10/cifar10/test/dog.9164.jpg
#   inflating: cifar10/cifar10/test/airplane.9170.jpg
#   inflating: cifar10/cifar10/test/automobile.9185.jpg
#   inflating: cifar10/cifar10/test/horse.9186.jpg
#   inflating: cifar10/cifar10/test/dog.9188.jpg
#   inflating: cifar10/cifar10/test/bird.9213.jpg
#   inflating: cifar10/cifar10/test/dog.9215.jpg
#   inflating: cifar10/cifar10/test/truck.9219.jpg
#   inflating: cifar10/cifar10/test/frog.9241.jpg
#   inflating: cifar10/cifar10/test/cat.9243.jpg
#   inflating: cifar10/cifar10/test/horse.9252.jpg
#   inflating: cifar10/cifar10/test/ship.9266.jpg
#   inflating: cifar10/cifar10/test/horse.9268.jpg
#   inflating: cifar10/cifar10/test/dog.9305.jpg
#   inflating: cifar10/cifar10/test/frog.9342.jpg
#   inflating: cifar10/cifar10/test/dog.9363.jpg
#   inflating: cifar10/cifar10/test/dog.9364.jpg
#   inflating: cifar10/cifar10/test/ship.9371.jpg
#   inflating: cifar10/cifar10/test/deer.9377.jpg
#   inflating: cifar10/cifar10/test/horse.9399.jpg
#   inflating: cifar10/cifar10/test/frog.9400.jpg
#   inflating: cifar10/cifar10/test/frog.9402.jpg
#   inflating: cifar10/cifar10/test/frog.9408.jpg
#   inflating: cifar10/cifar10/test/bird.9424.jpg
#   inflating: cifar10/cifar10/test/deer.9441.jpg
#   inflating: cifar10/cifar10/test/cat.9448.jpg
#   inflating: cifar10/cifar10/test/frog.9450.jpg
#   inflating: cifar10/cifar10/test/automobile.9457.jpg
#   inflating: cifar10/cifar10/test/horse.9468.jpg
#   inflating: cifar10/cifar10/test/frog.9504.jpg
#   inflating: cifar10/cifar10/test/truck.9517.jpg
#   inflating: cifar10/cifar10/test/automobile.9520.jpg
#   inflating: cifar10/cifar10/test/deer.9555.jpg
#   inflating: cifar10/cifar10/test/frog.9571.jpg
#   inflating: cifar10/cifar10/test/cat.9576.jpg
#   inflating: cifar10/cifar10/test/airplane.9577.jpg
#   inflating: cifar10/cifar10/test/horse.9581.jpg
#   inflating: cifar10/cifar10/test/cat.9584.jpg
#   inflating: cifar10/cifar10/test/frog.9614.jpg
#   inflating: cifar10/cifar10/test/frog.9621.jpg
#   inflating: cifar10/cifar10/test/cat.9648.jpg
#   inflating: cifar10/cifar10/test/dog.9654.jpg
#   inflating: cifar10/cifar10/test/ship.9655.jpg
#   inflating: cifar10/cifar10/test/automobile.9662.jpg
#   inflating: cifar10/cifar10/test/ship.9669.jpg
#   inflating: cifar10/cifar10/test/truck.9674.jpg
#   inflating: cifar10/cifar10/test/automobile.9696.jpg
#   inflating: cifar10/cifar10/test/horse.9702.jpg
#   inflating: cifar10/cifar10/test/deer.9703.jpg
#   inflating: cifar10/cifar10/test/horse.9723.jpg
#   inflating: cifar10/cifar10/test/bird.9750.jpg
#   inflating: cifar10/cifar10/test/dog.9756.jpg
#   inflating: cifar10/cifar10/test/frog.9762.jpg
#   inflating: cifar10/cifar10/test/deer.9770.jpg
#   inflating: cifar10/cifar10/test/truck.9777.jpg
#   inflating: cifar10/cifar10/test/ship.9784.jpg
#   inflating: cifar10/cifar10/test/frog.9789.jpg
#   inflating: cifar10/cifar10/test/deer.9795.jpg
#   inflating: cifar10/cifar10/test/truck.9796.jpg
#   inflating: cifar10/cifar10/test/ship.9806.jpg
#   inflating: cifar10/cifar10/test/automobile.9813.jpg
#   inflating: cifar10/cifar10/test/airplane.9822.jpg
#   inflating: cifar10/cifar10/test/automobile.9824.jpg
#   inflating: cifar10/cifar10/test/bird.9825.jpg
#   inflating: cifar10/cifar10/test/cat.9839.jpg
#   inflating: cifar10/cifar10/test/airplane.9847.jpg
#   inflating: cifar10/cifar10/test/frog.9861.jpg
#   inflating: cifar10/cifar10/test/ship.9864.jpg
#   inflating: cifar10/cifar10/test/truck.9868.jpg
#   inflating: cifar10/cifar10/test/dog.9878.jpg
#   inflating: cifar10/cifar10/test/ship.9897.jpg
#   inflating: cifar10/cifar10/test/cat.9901.jpg
#   inflating: cifar10/cifar10/test/horse.9923.jpg
#   inflating: cifar10/cifar10/test/dog.9939.jpg
#   inflating: cifar10/cifar10/test/horse.9943.jpg
#   inflating: cifar10/cifar10/test/horse.9945.jpg
#   inflating: cifar10/cifar10/test/cat.9950.jpg
#   inflating: cifar10/cifar10/test/airplane.9954.jpg
#   inflating: cifar10/cifar10/test/airplane.9956.jpg
#   inflating: cifar10/cifar10/test/frog.9969.jpg
#   inflating: cifar10/cifar10/test/automobile.9974.jpg
#   inflating: cifar10/cifar10/test/airplane.9983.jpg
#   inflating: cifar10/cifar10/test/bird.9989.jpg
#   inflating: cifar10/cifar10/test/cat.9994.jpg
#   inflating: cifar10/cifar10/test/horse.9999.jpg

# %%
ITERATION = 10
IMAGE_WIDTH=256
IMAGE_HEIGHT=256
IMAGE_SIZE=(IMAGE_WIDTH, IMAGE_HEIGHT)
IMAGE_CHANNELS=3
RANDOM_SEED = [42, 42, 57, 48, 86, 7, 15, 28, 39, 52][ITERATION-1]
BATCH_SIZE = 32
NUM_CLASSES = 10
EPOCHS = 1000
GABOR_LAYER_INDEX = 0
GABOR_WIDTH = 15
GABOR_HEIGHT = 15
GABOR_SIZE = (GABOR_WIDTH, GABOR_HEIGHT)
NUM_RECEPTIVE_FILTERS = 32
CLASSES = ['airplane', 'automobile', 'bird', 'cat', 'deer',
           'dog', 'frog', 'horse', 'ship', 'truck']
# TRAIN_DIR = "cifar10/cifar10/train/"
# TEST_DIR = "cifar10/cifar10/test/"
TEST_DIR = "cifar10/cifar10/train/"
TRAIN_DIR = "cifar10/cifar10/test/"

# %%
filenames = os.listdir(TRAIN_DIR)
categories = []
for filename in filenames:
    category = filename.split('.')[0]
    categories.append(category)

train_df = pd.DataFrame({
    'filename': filenames,
    'category': categories
})

filenames = os.listdir(TEST_DIR)
categories = []
for filename in filenames:
    category = filename.split('.')[0]
    categories.append(category)

validate_df = pd.DataFrame({
    'filename': filenames,
    'category': categories
})

# %%
train_df = train_df.reset_index(drop=True)
validate_df = validate_df.reset_index(drop=True)
total_train = train_df.shape[0]
total_validate = validate_df.shape[0]

# %%
train_df['category'].value_counts().plot.bar()

# %%
validate_df['category'].value_counts().plot.bar()

# %%
train_datagen = ImageDataGenerator(
    rescale=1./255,
)
train_generator = train_datagen.flow_from_dataframe(
    train_df, 
    TRAIN_DIR, 
    x_col='filename',
    y_col='category',
    target_size=IMAGE_SIZE,
    class_mode='categorical',
    batch_size=BATCH_SIZE
)
# Out:
# Found 10000 validated image filenames belonging to 10 classes.

# %%
validation_datagen = ImageDataGenerator(rescale=1./255)
validation_generator = validation_datagen.flow_from_dataframe(
    validate_df, 
    TEST_DIR, 
    x_col='filename',
    y_col='category',
    target_size=IMAGE_SIZE,
    class_mode='categorical',
    batch_size=BATCH_SIZE
)
# Out:
# Found 50000 validated image filenames belonging to 10 classes.

# %%
import math

def get_gabor_filters(inchannels, outchannels, kernel_size = (3,3)):
    delta = 1e-4
    freqs = (math.pi/2)*(math.sqrt(2)**(-np.random.randint(0,5, (outchannels, inchannels))))
    thetas = (math.pi/8)*np.random.randint(0,8, (outchannels, inchannels))
    sigmas = math.pi/(freqs)
    psis = math.pi * np.random.rand(outchannels, inchannels)
    x0, y0 = np.ceil(np.array(kernel_size)/2)    
    
    y, x = np.meshgrid(
            np.linspace(-x0 + 1, x0 + 0, kernel_size[0]),
            np.linspace(-y0 + 1, y0 + 0, kernel_size[1]),
    )
    filterbank = []
    
    for i in range(outchannels):
        for j in range(inchannels):
            freq = freqs[i][j]
            theta = thetas[i][j]
            sigma = sigmas[i][j]
            psi = psis[i][j]
            
            rotx = x * np.cos(theta) + y * np.sin(theta)
            roty = -x * np.sin(theta) + y * np.cos(theta)

            g = np.exp(
                -0.5 * ((rotx ** 2 + roty ** 2) / (sigma + delta) ** 2)
            )
            g = g * np.cos(freq * rotx + psi)
#             g = g / (2 * math.pi * (sigma ** 2))
#             g = gabor_kernel(frequency=freq, bandwidth=sigma, theta=theta, offset=psi, n_stds=0).real
            filterbank.append(g)
    return filterbank

filterbank = get_gabor_filters(1, NUM_RECEPTIVE_FILTERS, GABOR_SIZE)

fig = plt.subplots(8, len(filterbank)//8, figsize=(22,22))
for i,gf in enumerate(filterbank):
    plt.subplot(8, len(filterbank)//8, i+1)
    plt.imshow(gf, cmap='gray')
    plt.axis('off')

# %%
# Importing the Keras libraries and packages
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Activation
from tensorflow.keras.layers import Input, Dense, Dropout, BatchNormalization
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import RMSprop, Adam
from tensorflow.keras.models import Sequential
from tensorflow.keras import layers
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau

classifier = None
classifier = Sequential([
    layers.Conv2D(NUM_RECEPTIVE_FILTERS, kernel_size=GABOR_SIZE, strides=(1,1), activation='relu', input_shape=(IMAGE_WIDTH, IMAGE_HEIGHT, 3)),
    layers.BatchNormalization(),
    layers.MaxPooling2D(pool_size=(2,2)),
    Dropout(0.5),
    layers.Conv2D(64, kernel_size=(3,3), strides=(2,2), activation='relu'),
    layers.BatchNormalization(),
    layers.MaxPooling2D(pool_size=(2,2)),
    Dropout(0.5),
    layers.Conv2D(128, kernel_size=(3,3), strides=(2,2), activation='relu'),
    layers.BatchNormalization(),
    layers.MaxPooling2D(pool_size=(2,2)),
    Dropout(0.5),
    layers.Flatten(),
    layers.Dense(512, activation='relu'),
    layers.BatchNormalization(),
    Dropout(0.5),
    layers.Dense(NUM_CLASSES, activation='softmax')
])

classifier.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 242, 242, 32)      21632
# _________________________________________________________________
# batch_normalization (BatchNo (None, 242, 242, 32)      128
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 121, 121, 32)      0
# _________________________________________________________________
# dropout (Dropout)            (None, 121, 121, 32)      0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 60, 60, 64)        18496
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 60, 60, 64)        256
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 30, 30, 64)        0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 30, 30, 64)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 14, 14, 128)       73856
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 14, 14, 128)       512
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 7, 7, 128)         0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 7, 7, 128)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 6272)              0
# _________________________________________________________________
# dense (Dense)                (None, 512)               3211776
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 512)               2048
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 10)                5130
# =================================================================
# Total params: 3,333,834
# Trainable params: 3,332,362
# Non-trainable params: 1,472
# _________________________________________________________________

# %%
cnnl1 = classifier.layers[GABOR_LAYER_INDEX].name   # get the name of the first conv layer
W = classifier.get_layer(name=cnnl1).get_weights()[0]   #get the filters
wshape = W.shape  #save the original shape
gabor_filters = W
for kernel_index in range(wshape[3]//2): # initialize only half of the filters with gabor filters
    for channel_index in range(3):
        gabor_filters[:,:,channel_index, kernel_index] = filterbank[kernel_index]

classifier.get_layer(name=cnnl1).set_weights([gabor_filters, classifier.get_layer(name=cnnl1).get_weights()[1]])
filter_layers = []
for i in range(NUM_RECEPTIVE_FILTERS):
    for j in range(3):
        filter_layers.append(np.reshape(W[:,:,j, i], GABOR_SIZE))
for i,gf in enumerate(filter_layers):
    plt.subplot(8, len(filter_layers)//8, i+1)
    plt.imshow(gf, cmap='gray')
    plt.axis('off')
plt.savefig('cifar10-{}-initial-gabor-alternate-kernel-{}.png'.format(ITERATION,GABOR_WIDTH), dpi=350, bbox_inches='tight')

# %%
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=10,  
                              min_delta=1e-4, mode='min', verbose=1)
stop_alg = EarlyStopping(monitor='val_loss', patience=35, 
                         restore_best_weights=True, verbose=1)
callbacks = [stop_alg, reduce_lr]
opt = RMSprop(learning_rate=0.001)
classifier.compile(loss='categorical_crossentropy', optimizer=opt, metrics=['accuracy'])

start = time.perf_counter()
hist = classifier.fit(
    train_generator, 
    epochs=EPOCHS,
    validation_data=validation_generator,
    validation_steps=total_validate//BATCH_SIZE,
    steps_per_epoch=total_train//BATCH_SIZE,
    callbacks=callbacks
)
finish = time.perf_counter()
# Out:
# Epoch 1/1000
# 312/312 [==============================] - 126s 405ms/step - loss: 2.3405 - accuracy: 0.3011 - val_loss: 2.1986 - val_accuracy: 0.3593
# Epoch 2/1000
# 312/312 [==============================] - 125s 400ms/step - loss: 1.7292 - accuracy: 0.4148 - val_loss: 2.2826 - val_accuracy: 0.3054
# Epoch 3/1000
# 312/312 [==============================] - 124s 398ms/step - loss: 1.4908 - accuracy: 0.4819 - val_loss: 1.6143 - val_accuracy: 0.4395
# Epoch 4/1000
# 312/312 [==============================] - 126s 405ms/step - loss: 1.3376 - accuracy: 0.5276 - val_loss: 1.6504 - val_accuracy: 0.4518
# Epoch 5/1000
# 312/312 [==============================] - 124s 398ms/step - loss: 1.2585 - accuracy: 0.5640 - val_loss: 1.2709 - val_accuracy: 0.5559
# Epoch 6/1000
# 312/312 [==============================] - 123s 394ms/step - loss: 1.1816 - accuracy: 0.5817 - val_loss: 1.5163 - val_accuracy: 0.4923
# Epoch 7/1000
# 312/312 [==============================] - 123s 394ms/step - loss: 1.1400 - accuracy: 0.6021 - val_loss: 1.1690 - val_accuracy: 0.5961
# Epoch 8/1000
# 312/312 [==============================] - 123s 394ms/step - loss: 1.0761 - accuracy: 0.6179 - val_loss: 1.2991 - val_accuracy: 0.5803
# Epoch 9/1000
# 312/312 [==============================] - 122s 391ms/step - loss: 1.0127 - accuracy: 0.6492 - val_loss: 1.4042 - val_accuracy: 0.5620
# Epoch 10/1000
# 312/312 [==============================] - 122s 390ms/step - loss: 0.9946 - accuracy: 0.6515 - val_loss: 1.2792 - val_accuracy: 0.5731
# Epoch 11/1000
# 312/312 [==============================] - 122s 391ms/step - loss: 0.9427 - accuracy: 0.6768 - val_loss: 1.1460 - val_accuracy: 0.6078
# Epoch 12/1000
# 312/312 [==============================] - 123s 393ms/step - loss: 0.9018 - accuracy: 0.6875 - val_loss: 1.1592 - val_accuracy: 0.6292
# Epoch 13/1000
# 312/312 [==============================] - 121s 389ms/step - loss: 0.8750 - accuracy: 0.6973 - val_loss: 1.1806 - val_accuracy: 0.6163
# Epoch 14/1000
# 312/312 [==============================] - 122s 392ms/step - loss: 0.8550 - accuracy: 0.7021 - val_loss: 1.5163 - val_accuracy: 0.5203
# Epoch 15/1000
# 312/312 [==============================] - 122s 391ms/step - loss: 0.8011 - accuracy: 0.7214 - val_loss: 1.5141 - val_accuracy: 0.5733
# Epoch 16/1000
# 312/312 [==============================] - 122s 391ms/step - loss: 0.7699 - accuracy: 0.7304 - val_loss: 1.2508 - val_accuracy: 0.6196
# Epoch 17/1000
# 312/312 [==============================] - 122s 392ms/step - loss: 0.7329 - accuracy: 0.7412 - val_loss: 1.1476 - val_accuracy: 0.6393
# Epoch 18/1000
# 312/312 [==============================] - 122s 391ms/step - loss: 0.7130 - accuracy: 0.7488 - val_loss: 1.3622 - val_accuracy: 0.6045
# Epoch 19/1000
# 312/312 [==============================] - 123s 395ms/step - loss: 0.6971 - accuracy: 0.7578 - val_loss: 1.1719 - val_accuracy: 0.6550
# Epoch 20/1000
# 312/312 [==============================] - 123s 393ms/step - loss: 0.6646 - accuracy: 0.7732 - val_loss: 1.2656 - val_accuracy: 0.6135
# Epoch 21/1000
# 312/312 [==============================] - ETA: 0s - loss: 0.6292 - accuracy: 0.7823
# Epoch 00021: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 312/312 [==============================] - 122s 391ms/step - loss: 0.6292 - accuracy: 0.7823 - val_loss: 1.2513 - val_accuracy: 0.6431
# Epoch 22/1000
# 312/312 [==============================] - 122s 392ms/step - loss: 0.5627 - accuracy: 0.8066 - val_loss: 1.2537 - val_accuracy: 0.6596
# Epoch 23/1000
# 312/312 [==============================] - 122s 392ms/step - loss: 0.5287 - accuracy: 0.8155 - val_loss: 1.1382 - val_accuracy: 0.6713
# Epoch 24/1000
# 312/312 [==============================] - 122s 392ms/step - loss: 0.5049 - accuracy: 0.8246 - val_loss: 1.2680 - val_accuracy: 0.6576
# Epoch 25/1000
# 312/312 [==============================] - 122s 391ms/step - loss: 0.4981 - accuracy: 0.8244 - val_loss: 1.2421 - val_accuracy: 0.6583
# Epoch 26/1000
# 312/312 [==============================] - 121s 389ms/step - loss: 0.4909 - accuracy: 0.8270 - val_loss: 1.3375 - val_accuracy: 0.6533
# Epoch 27/1000
# 312/312 [==============================] - 122s 391ms/step - loss: 0.4747 - accuracy: 0.8391 - val_loss: 1.2912 - val_accuracy: 0.6583
# Epoch 28/1000
# 312/312 [==============================] - 122s 391ms/step - loss: 0.4509 - accuracy: 0.8417 - val_loss: 1.2661 - val_accuracy: 0.6639
# Epoch 29/1000
# 312/312 [==============================] - 122s 392ms/step - loss: 0.4472 - accuracy: 0.8457 - val_loss: 1.3311 - val_accuracy: 0.6625
# Epoch 30/1000
# 312/312 [==============================] - 122s 391ms/step - loss: 0.4222 - accuracy: 0.8530 - val_loss: 1.6182 - val_accuracy: 0.6424
# Epoch 31/1000
# 312/312 [==============================] - 122s 391ms/step - loss: 0.4207 - accuracy: 0.8537 - val_loss: 1.2439 - val_accuracy: 0.6754
# Epoch 32/1000
# 312/312 [==============================] - 122s 392ms/step - loss: 0.4126 - accuracy: 0.8567 - val_loss: 1.2678 - val_accuracy: 0.6701
# Epoch 33/1000
# 312/312 [==============================] - ETA: 0s - loss: 0.4030 - accuracy: 0.8578
# Epoch 00033: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 312/312 [==============================] - 122s 392ms/step - loss: 0.4030 - accuracy: 0.8578 - val_loss: 1.4821 - val_accuracy: 0.6474
# Epoch 34/1000
# 312/312 [==============================] - 121s 389ms/step - loss: 0.3680 - accuracy: 0.8731 - val_loss: 1.3101 - val_accuracy: 0.6697
# Epoch 35/1000
# 312/312 [==============================] - 121s 389ms/step - loss: 0.3713 - accuracy: 0.8701 - val_loss: 1.3662 - val_accuracy: 0.6749
# Epoch 36/1000
# 312/312 [==============================] - 122s 391ms/step - loss: 0.3696 - accuracy: 0.8708 - val_loss: 1.3341 - val_accuracy: 0.6752
# Epoch 37/1000
# 312/312 [==============================] - 122s 392ms/step - loss: 0.3469 - accuracy: 0.8810 - val_loss: 1.3505 - val_accuracy: 0.6761
# Epoch 38/1000
# 312/312 [==============================] - 122s 390ms/step - loss: 0.3296 - accuracy: 0.8894 - val_loss: 1.4180 - val_accuracy: 0.6662
# Epoch 39/1000
# 312/312 [==============================] - 121s 389ms/step - loss: 0.3328 - accuracy: 0.8827 - val_loss: 1.3327 - val_accuracy: 0.6764
# Epoch 40/1000
# 312/312 [==============================] - 123s 393ms/step - loss: 0.3358 - accuracy: 0.8830 - val_loss: 1.3461 - val_accuracy: 0.6821
# Epoch 41/1000
# 312/312 [==============================] - 122s 391ms/step - loss: 0.3308 - accuracy: 0.8876 - val_loss: 1.3949 - val_accuracy: 0.6775
# Epoch 42/1000
# 312/312 [==============================] - 122s 393ms/step - loss: 0.3159 - accuracy: 0.8944 - val_loss: 1.4824 - val_accuracy: 0.6731
# Epoch 43/1000
# 312/312 [==============================] - ETA: 0s - loss: 0.3096 - accuracy: 0.8912
# Epoch 00043: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 312/312 [==============================] - 122s 390ms/step - loss: 0.3096 - accuracy: 0.8912 - val_loss: 1.4559 - val_accuracy: 0.6706
# Epoch 44/1000
# 312/312 [==============================] - 123s 393ms/step - loss: 0.3017 - accuracy: 0.8959 - val_loss: 1.3652 - val_accuracy: 0.6715
# Epoch 45/1000
# 312/312 [==============================] - 123s 394ms/step - loss: 0.2864 - accuracy: 0.9000 - val_loss: 1.3803 - val_accuracy: 0.6720
# Epoch 46/1000
# 312/312 [==============================] - 123s 393ms/step - loss: 0.2968 - accuracy: 0.8966 - val_loss: 1.4159 - val_accuracy: 0.6798
# Epoch 47/1000
# 312/312 [==============================] - 124s 396ms/step - loss: 0.2906 - accuracy: 0.8992 - val_loss: 1.3498 - val_accuracy: 0.6772
# Epoch 48/1000
# 312/312 [==============================] - 124s 396ms/step - loss: 0.2816 - accuracy: 0.9041 - val_loss: 1.4049 - val_accuracy: 0.6815
# Epoch 49/1000
# 312/312 [==============================] - 123s 393ms/step - loss: 0.2781 - accuracy: 0.9047 - val_loss: 1.3899 - val_accuracy: 0.6778
# Epoch 50/1000
# 312/312 [==============================] - 124s 397ms/step - loss: 0.2746 - accuracy: 0.9058 - val_loss: 1.4140 - val_accuracy: 0.6771
# Epoch 51/1000
# 312/312 [==============================] - 123s 396ms/step - loss: 0.2738 - accuracy: 0.9045 - val_loss: 1.3808 - val_accuracy: 0.6833
# Epoch 52/1000
# 312/312 [==============================] - 124s 396ms/step - loss: 0.2781 - accuracy: 0.9043 - val_loss: 1.3587 - val_accuracy: 0.6775
# Epoch 53/1000
# 312/312 [==============================] - ETA: 0s - loss: 0.2735 - accuracy: 0.9063
# Epoch 00053: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 312/312 [==============================] - 123s 395ms/step - loss: 0.2735 - accuracy: 0.9063 - val_loss: 1.4232 - val_accuracy: 0.6755
# Epoch 54/1000
# 312/312 [==============================] - 123s 393ms/step - loss: 0.2767 - accuracy: 0.9047 - val_loss: 1.3730 - val_accuracy: 0.6822
# Epoch 55/1000
# 312/312 [==============================] - 123s 394ms/step - loss: 0.2671 - accuracy: 0.9074 - val_loss: 1.4216 - val_accuracy: 0.6815
# Epoch 56/1000
# 312/312 [==============================] - 123s 393ms/step - loss: 0.2526 - accuracy: 0.9116 - val_loss: 1.3756 - val_accuracy: 0.6821
# Epoch 57/1000
# 312/312 [==============================] - 123s 395ms/step - loss: 0.2636 - accuracy: 0.9110 - val_loss: 1.4516 - val_accuracy: 0.6805
# Epoch 58/1000
# 312/312 [==============================] - ETA: 0s - loss: 0.2585 - accuracy: 0.9142Restoring model weights from the end of the best epoch.
# 312/312 [==============================] - 123s 394ms/step - loss: 0.2585 - accuracy: 0.9142 - val_loss: 1.3944 - val_accuracy: 0.6833
# Epoch 00058: early stopping

# %%
print("Start time = {}".format(start))
print("Finish time = {}".format(finish))
print("Training time = {}".format(finish-start))
hist.history['start_time'] = start
hist.history['finish_time'] = finish
hist.history['train_time'] = finish-start
# Out:
# Start time = 538.724181038
# Finish time = 7668.868457481
# Training time = 7130.144276443

# %%
import pickle

with open('cifar10-{}-history-gabor-alternate-kernel-{}.p'.format(ITERATION, GABOR_HEIGHT), 'wb') as fp:
  pickle.dump(hist.history, fp, protocol=pickle.HIGHEST_PROTOCOL)

# %%
import matplotlib.pyplot as plt

fig = plt.figure(figsize=(10,6))
plt.plot(hist.history['loss'], color='#785ef0')
plt.plot(hist.history['val_loss'], color='#dc267f')
plt.title('Model Loss Progress')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Training Set', 'Test Set'], loc='upper right')
plt.savefig('cifar10-{}-loss-gabor-alternate-kernel-{}.png'.format(ITERATION, GABOR_WIDTH), dpi=350, bbox_inches='tight')
plt.show()

# %%
fig = plt.figure(figsize=(10,6))
plt.plot(hist.history['accuracy'], color='#785ef0')
plt.plot(hist.history['val_accuracy'], color='#dc267f')
plt.title('Model Accuracy Progress')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Training Set', 'Test Set'], loc='upper right')
plt.savefig('cifar10-{}-accuracy-gabor-alternate-kernel-{}.png'.format(ITERATION, GABOR_WIDTH), dpi=350, bbox_inches='tight')
plt.show()

# %%
from sklearn.preprocessing import MinMaxScaler

cnnl1 = classifier.layers[GABOR_LAYER_INDEX].name   # get the name of the first conv layer
W = classifier.get_layer(name=cnnl1).get_weights()[0]   #get the filters
wshape = W.shape  #save the original shape

# this part will scale to [0, 1] for visualization purposes
scaler = MinMaxScaler()
scaler.fit(W.reshape(-1,1))
W = scaler.transform(W.reshape(-1,1))
W = W.reshape(wshape)

fig, axs = plt.subplots(8,NUM_RECEPTIVE_FILTERS//8, figsize=(24,24))
fig.subplots_adjust(hspace = .25, wspace=.001)
axs = axs.ravel()
for i in range(W.shape[-1]):
  # we reshape to a 3D (RGB) image shape and display
  h = np.reshape(W[:,:,:,i], (GABOR_WIDTH,GABOR_HEIGHT,3))
  axs[i].imshow(h)
  axs[i].set_title('Filter ' + str(i))    
plt.savefig("cifar10-{}-filters-gabor-alternate-kernel-{}.png".format(ITERATION, GABOR_WIDTH), bbox_inches='tight', dpi=350)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
cnnl1 = classifier.layers[GABOR_LAYER_INDEX].name   # get the name of the first conv layer
W = classifier.get_layer(name=cnnl1).get_weights()[0]
plt.hist(W.ravel(), bins=100)
print(np.min(W),np.max(W))
# Out:
# -1.0264877 1.071049

# %%
filter_layers = []
for i in range(NUM_RECEPTIVE_FILTERS):
    for j in range(3):
        filter_layers.append(np.reshape(W[:,:,j, i], GABOR_SIZE))
for i,gf in enumerate(filter_layers):
    plt.subplot(8, (W.shape[3]*3)//8, i+1)
    plt.imshow(gf, cmap='gray')
    plt.axis('off')
plt.savefig("cifar10-{}-channelwise-gabor-alternate-filters-kernel-{}.png".format(ITERATION, GABOR_WIDTH), bbox_inches='tight', dpi=350)
