# %%
from skimage.filters import gabor_kernel
from skimage import io
from skimage.transform import resize
from matplotlib import pyplot as plt 
import numpy as np

import math

# %%
def get_gabor_filters(inchannels, outchannels, kernel_size = (3,3)):
    delta = 1e-8
    
    freqs = (math.pi/2)*math.sqrt(2)**(-np.linspace(0,4, 5))
    thetas = (math.pi/8)*np.linspace(0,7, 8)
    sigmas = math.pi/(freqs)
    psis = math.pi * np.random.rand(40,)
    x0, y0 = np.ceil(np.array(kernel_size)/2)    
    
    y, x = np.meshgrid(
            np.linspace(-y0, y0 + 1, kernel_size[0]),
            np.linspace(-x0, x0 + 1, kernel_size[1]),
    )
    filterbank = []
    
    for freq in freqs:
        for theta in thetas:
            sigma = math.pi/freq
            psi = math.pi * np.random.rand(1,)[0]
            rotx = x * np.cos(theta) + y * np.sin(theta)
            roty = -x * np.sin(theta) + y * np.cos(theta)

            g = np.exp(
                -0.5 * ((rotx ** 2 + roty ** 2) / (sigma + delta) ** 2)
            )
            g = g * np.cos(freq * rotx + psi)
            g = g / (2 * math.pi * sigma ** 2)
            filterbank.append(g)
    return filterbank

filterbank = get_gabor_filters(1, 40, (9,9))

fig = plt.subplots(12, 16, figsize=(22,22))
for i,gf in enumerate(filterbank):
    plt.subplot(12, 16, i+1)
    plt.imshow(gf, cmap='gray')
    plt.axis('off')

# %%
np.array(filterbank).shape
# Out:
# (192, 3, 3)

# %%
np.linspace(0,4, 5)
# Out:
# array([0., 1., 2., 3., 4.])

# %%
np.random.rand(1,)
# Out:
# array([0.35421304])

# %%
from tensorflow.keras.datasets import cifar10
from tensorflow.keras.utils import to_categorical

# The data, split between train and test sets:
(x_train, y_train), (x_test, y_test) = cifar10.load_data()
x_train = x_train.astype('float32') / 255.0
x_test = x_test.astype('float32') / 255.0

y_train = to_categorical(y_train, 10)
y_test = to_categorical(y_test, 10)

print('x_train shape:', x_train.shape)
print('x_test shape:', x_test.shape)
# Out:
# x_train shape: (50000, 32, 32, 3)
# x_test shape: (10000, 32, 32, 3)

# %%
# Importing the Keras libraries and packages
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Activation
from tensorflow.keras.layers import Input, Dense, Dropout, BatchNormalization
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import RMSprop, Adam

# dimensionality of input and latent encoded representations
inpt_dim = (32, 32, 3)

inpt_img = Input(shape=inpt_dim)

# Block 1
cl1 = Conv2D(64, (9, 9), strides=(2, 2),activation='relu', input_shape = inpt_dim)(inpt_img)
bnl2 = BatchNormalization()(cl1)
# afl3 = Activation('relu')(bnl2)
pl4 = MaxPooling2D(pool_size = (2, 2))(bnl2)

# Adding a second convolutional layer
cl5 = Conv2D(128, (3, 3), strides=(1, 1), activation='relu')(pl4)
bnl6 = BatchNormalization()(cl5)
# afl7 = Activation('relu')(bnl6)
pl8 = MaxPooling2D(pool_size = (2, 2))(bnl6)
bnl9 = BatchNormalization()(pl8)

# Step 3 - Flattening
fl10 = Flatten()(bnl9)

# Step 4 - Full connection
dol11 = Dropout(0.5)(fl10)
dl12 = Dense(units = 256, activation = 'relu')(dol11)
dol13 = Dropout(0.2)(dl12)
dl14 = Dense(units = 64, activation = 'relu')(dol13)
dol15 = Dropout(0.1)(dl14)
output = Dense(units = 10, activation = 'sigmoid')(dol15)

classifier = Model(inpt_img, output)

# Compiling the CNN
opt = RMSprop(learning_rate=0.001)
# opt = Adam(learning_rate=0.01)

classifier.compile(optimizer = opt, loss = 'binary_crossentropy', 
                   metrics = ['accuracy'])

print(classifier.summary())
# Out:
# Model: "functional_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 32, 32, 3)]       0
# _________________________________________________________________
# conv2d (Conv2D)              (None, 12, 12, 64)        15616
# _________________________________________________________________
# batch_normalization (BatchNo (None, 12, 12, 64)        256
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 6, 6, 64)          0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 4, 4, 128)         73856
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 4, 4, 128)         512
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 2, 2, 128)         0
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 2, 2, 128)         512
# _________________________________________________________________
# flatten (Flatten)            (None, 512)               0
# _________________________________________________________________
# dropout (Dropout)            (None, 512)               0
# _________________________________________________________________
# dense (Dense)                (None, 256)               131328
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 64)                16448
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 64)                0
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                650
# =================================================================
# Total params: 239,178
# Trainable params: 238,538
# Non-trainable params: 640
# _________________________________________________________________
# None

# %%
fig = plt.subplots(12, 16, figsize=(22,22))

cnnl1 = classifier.layers[1].name   # get the name of the first conv layer
W = classifier.get_layer(name=cnnl1).get_weights()[0]   #get the filters
wshape = W.shape  #save the original shape
filter_layers = []
for i in range(64):
    for j in range(3):
        filter_layers.append(np.reshape(W[:,:,j, i], (9,9)))
for i,gf in enumerate(filter_layers):
    plt.subplot(12, 16, i+1)
    plt.imshow(gf, cmap='gray')
    plt.axis('off')

# %%
wshape
# Out:
# (9, 9, 3, 64)

# %%
gabor_filters = W
for i, gf in enumerate(filterbank):
    for j in range(3):
        gabor_filters
for kernel_index in range(40):
    for channel_index in range(3):
        gabor_filters[:,:,channel_index, kernel_index] = filterbank[kernel_index]

cnnl1 = classifier.layers[1].name   # get the name of the first conv layer
classifier.get_layer(name=cnnl1).set_weights([gabor_filters, classifier.get_layer(name=cnnl1).get_weights()[1]])
fig = plt.subplots(12, 16, figsize=(22,22))
W = classifier.get_layer(name=cnnl1).get_weights()[0]   #get the filters
filter_layers = []
for i in range(64):
    for j in range(3):
        filter_layers.append(np.reshape(W[:,:,j, i], (9,9)))
for i,gf in enumerate(filter_layers):
    plt.subplot(12, 16, i+1)
    plt.imshow(gf, cmap='gray')
    plt.axis('off')

# %%
# Fitting the CNN to the images

from tensorflow.keras.callbacks import ReduceLROnPlateau, EarlyStopping

reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=10,  
                              min_delta=1e-4, mode='min', verbose=1)

stop_alg = EarlyStopping(monitor='val_loss', patience=35, 
                         restore_best_weights=True, verbose=1)

hist = classifier.fit(x_train, y_train, batch_size=100, epochs=1000, 
                   callbacks=[stop_alg, reduce_lr], shuffle=True, 
                   validation_data=(x_test, y_test))

classifier.save_weights("cnn.hdf5")
# Out:
# Epoch 1/1000
# 500/500 [==============================] - 39s 78ms/step - loss: 0.2781 - accuracy: 0.3447 - val_loss: 0.2454 - val_accuracy: 0.4232
# Epoch 2/1000
# 500/500 [==============================] - 43s 85ms/step - loss: 0.2320 - accuracy: 0.4672 - val_loss: 0.3230 - val_accuracy: 0.3243
# Epoch 3/1000
# 500/500 [==============================] - 41s 83ms/step - loss: 0.2155 - accuracy: 0.5093 - val_loss: 0.2174 - val_accuracy: 0.5129
# Epoch 4/1000
# 500/500 [==============================] - 42s 85ms/step - loss: 0.2039 - accuracy: 0.5427 - val_loss: 0.2209 - val_accuracy: 0.5051
# Epoch 5/1000
# 500/500 [==============================] - 41s 82ms/step - loss: 0.1957 - accuracy: 0.5642 - val_loss: 0.2930 - val_accuracy: 0.3736
# Epoch 6/1000
# 500/500 [==============================] - 42s 85ms/step - loss: 0.1886 - accuracy: 0.5865 - val_loss: 0.1920 - val_accuracy: 0.5839
# Epoch 7/1000
# 500/500 [==============================] - 44s 88ms/step - loss: 0.1826 - accuracy: 0.5978 - val_loss: 0.2000 - val_accuracy: 0.5707
# Epoch 8/1000
# 500/500 [==============================] - 42s 84ms/step - loss: 0.1779 - accuracy: 0.6099 - val_loss: 0.1864 - val_accuracy: 0.5881
# Epoch 9/1000
# 500/500 [==============================] - 43s 85ms/step - loss: 0.1734 - accuracy: 0.6208 - val_loss: 0.2764 - val_accuracy: 0.4365
# Epoch 10/1000
# 500/500 [==============================] - 40s 80ms/step - loss: 0.1696 - accuracy: 0.6323 - val_loss: 0.1736 - val_accuracy: 0.6184
# Epoch 11/1000
# 500/500 [==============================] - 40s 79ms/step - loss: 0.1657 - accuracy: 0.6401 - val_loss: 0.1809 - val_accuracy: 0.6017
# Epoch 12/1000
# 500/500 [==============================] - 40s 79ms/step - loss: 0.1642 - accuracy: 0.6440 - val_loss: 0.2170 - val_accuracy: 0.5133
# Epoch 13/1000
# 500/500 [==============================] - 43s 86ms/step - loss: 0.1602 - accuracy: 0.6540 - val_loss: 0.2488 - val_accuracy: 0.4963
# Epoch 14/1000
# 500/500 [==============================] - 41s 82ms/step - loss: 0.1572 - accuracy: 0.6632 - val_loss: 0.2338 - val_accuracy: 0.5008
# Epoch 15/1000
# 500/500 [==============================] - 42s 84ms/step - loss: 0.1537 - accuracy: 0.6722 - val_loss: 0.1725 - val_accuracy: 0.6237
# Epoch 16/1000
# 500/500 [==============================] - 41s 82ms/step - loss: 0.1532 - accuracy: 0.6743 - val_loss: 0.2624 - val_accuracy: 0.5171
# Epoch 17/1000
# 500/500 [==============================] - 44s 87ms/step - loss: 0.1502 - accuracy: 0.6776 - val_loss: 0.1706 - val_accuracy: 0.6394
# Epoch 18/1000
# 500/500 [==============================] - 42s 85ms/step - loss: 0.1484 - accuracy: 0.6853 - val_loss: 0.1631 - val_accuracy: 0.6431
# Epoch 19/1000
# 500/500 [==============================] - 42s 84ms/step - loss: 0.1468 - accuracy: 0.6884 - val_loss: 0.1562 - val_accuracy: 0.6598
# Epoch 20/1000
# 500/500 [==============================] - 42s 85ms/step - loss: 0.1450 - accuracy: 0.6924 - val_loss: 0.1709 - val_accuracy: 0.6309
# Epoch 21/1000
# 500/500 [==============================] - 42s 85ms/step - loss: 0.1432 - accuracy: 0.6992 - val_loss: 0.1717 - val_accuracy: 0.6292
# Epoch 22/1000
# 500/500 [==============================] - 43s 86ms/step - loss: 0.1422 - accuracy: 0.6995 - val_loss: 0.1805 - val_accuracy: 0.6242
# Epoch 23/1000
# 500/500 [==============================] - 39s 78ms/step - loss: 0.1404 - accuracy: 0.7047 - val_loss: 0.1751 - val_accuracy: 0.6176
# Epoch 24/1000
# 500/500 [==============================] - 40s 79ms/step - loss: 0.1397 - accuracy: 0.7068 - val_loss: 0.1377 - val_accuracy: 0.7050
# Epoch 25/1000
# 500/500 [==============================] - 43s 85ms/step - loss: 0.1378 - accuracy: 0.7107 - val_loss: 0.1663 - val_accuracy: 0.6393
# Epoch 26/1000
# 500/500 [==============================] - 41s 83ms/step - loss: 0.1376 - accuracy: 0.7115 - val_loss: 0.1458 - val_accuracy: 0.6910
# Epoch 27/1000
# 500/500 [==============================] - 42s 84ms/step - loss: 0.1365 - accuracy: 0.7132 - val_loss: 0.1540 - val_accuracy: 0.6681
# Epoch 28/1000
# 500/500 [==============================] - 43s 85ms/step - loss: 0.1348 - accuracy: 0.7194 - val_loss: 0.1555 - val_accuracy: 0.6719
# Epoch 29/1000
# 500/500 [==============================] - 41s 81ms/step - loss: 0.1338 - accuracy: 0.7203 - val_loss: 0.1413 - val_accuracy: 0.6979
# Epoch 30/1000
# 500/500 [==============================] - 41s 83ms/step - loss: 0.1334 - accuracy: 0.7197 - val_loss: 0.1344 - val_accuracy: 0.7161
# Epoch 31/1000
# 500/500 [==============================] - 40s 81ms/step - loss: 0.1324 - accuracy: 0.7226 - val_loss: 0.1411 - val_accuracy: 0.6991
# Epoch 32/1000
# 500/500 [==============================] - 41s 82ms/step - loss: 0.1321 - accuracy: 0.7249 - val_loss: 0.1582 - val_accuracy: 0.6741
# Epoch 33/1000
# 500/500 [==============================] - 40s 81ms/step - loss: 0.1308 - accuracy: 0.7277 - val_loss: 0.2269 - val_accuracy: 0.5691
# Epoch 34/1000
# 500/500 [==============================] - 43s 86ms/step - loss: 0.1295 - accuracy: 0.7304 - val_loss: 0.1423 - val_accuracy: 0.6993
# Epoch 35/1000
# 500/500 [==============================] - 45s 90ms/step - loss: 0.1290 - accuracy: 0.7326 - val_loss: 0.1320 - val_accuracy: 0.7227
# Epoch 36/1000
# 500/500 [==============================] - 42s 84ms/step - loss: 0.1283 - accuracy: 0.7339 - val_loss: 0.1440 - val_accuracy: 0.6939
# Epoch 37/1000
# 500/500 [==============================] - 42s 84ms/step - loss: 0.1282 - accuracy: 0.7352 - val_loss: 0.1667 - val_accuracy: 0.6410
# Epoch 38/1000
# 500/500 [==============================] - 41s 81ms/step - loss: 0.1267 - accuracy: 0.7369 - val_loss: 0.1356 - val_accuracy: 0.7149
# Epoch 39/1000
# 500/500 [==============================] - 42s 84ms/step - loss: 0.1254 - accuracy: 0.7400 - val_loss: 0.1405 - val_accuracy: 0.7004
# Epoch 40/1000
# 500/500 [==============================] - 42s 83ms/step - loss: 0.1253 - accuracy: 0.7405 - val_loss: 0.1636 - val_accuracy: 0.6424
# Epoch 41/1000
# 500/500 [==============================] - 41s 81ms/step - loss: 0.1254 - accuracy: 0.7400 - val_loss: 0.1800 - val_accuracy: 0.6256
# Epoch 42/1000
# 500/500 [==============================] - 41s 83ms/step - loss: 0.1246 - accuracy: 0.7405 - val_loss: 0.1357 - val_accuracy: 0.7126
# Epoch 43/1000
# 500/500 [==============================] - 42s 83ms/step - loss: 0.1235 - accuracy: 0.7455 - val_loss: 0.1461 - val_accuracy: 0.6908
# Epoch 44/1000
# 500/500 [==============================] - 42s 83ms/step - loss: 0.1230 - accuracy: 0.7485 - val_loss: 0.1514 - val_accuracy: 0.6826
# Epoch 45/1000
# 500/500 [==============================] - ETA: 0s - loss: 0.1217 - accuracy: 0.7495
# Epoch 00045: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 500/500 [==============================] - 39s 79ms/step - loss: 0.1217 - accuracy: 0.7495 - val_loss: 0.1471 - val_accuracy: 0.6912
# Epoch 46/1000
# 500/500 [==============================] - 38s 77ms/step - loss: 0.1153 - accuracy: 0.7637 - val_loss: 0.1376 - val_accuracy: 0.7183
# Epoch 47/1000
# 500/500 [==============================] - 38s 77ms/step - loss: 0.1136 - accuracy: 0.7649 - val_loss: 0.1356 - val_accuracy: 0.7202
# Epoch 48/1000
# 500/500 [==============================] - 38s 77ms/step - loss: 0.1131 - accuracy: 0.7688 - val_loss: 0.1290 - val_accuracy: 0.7365
# Epoch 49/1000
# 500/500 [==============================] - 39s 77ms/step - loss: 0.1123 - accuracy: 0.7706 - val_loss: 0.1319 - val_accuracy: 0.7274
# Epoch 50/1000
# 500/500 [==============================] - 40s 80ms/step - loss: 0.1122 - accuracy: 0.7697 - val_loss: 0.1246 - val_accuracy: 0.7402
# Epoch 51/1000
# 500/500 [==============================] - 38s 76ms/step - loss: 0.1104 - accuracy: 0.7748 - val_loss: 0.1244 - val_accuracy: 0.7396
# Epoch 52/1000
# 500/500 [==============================] - 38s 76ms/step - loss: 0.1105 - accuracy: 0.7750 - val_loss: 0.1323 - val_accuracy: 0.7247
# Epoch 53/1000
# 500/500 [==============================] - 38s 77ms/step - loss: 0.1104 - accuracy: 0.7741 - val_loss: 0.1393 - val_accuracy: 0.7125
# Epoch 54/1000
# 500/500 [==============================] - 38s 76ms/step - loss: 0.1092 - accuracy: 0.7769 - val_loss: 0.1257 - val_accuracy: 0.7365
# Epoch 55/1000
# 500/500 [==============================] - 38s 77ms/step - loss: 0.1086 - accuracy: 0.7778 - val_loss: 0.1373 - val_accuracy: 0.7177
# Epoch 56/1000
# 500/500 [==============================] - 38s 76ms/step - loss: 0.1089 - accuracy: 0.7793 - val_loss: 0.1417 - val_accuracy: 0.7038
# Epoch 57/1000
# 500/500 [==============================] - 39s 78ms/step - loss: 0.1081 - accuracy: 0.7811 - val_loss: 0.1244 - val_accuracy: 0.7418
# Epoch 58/1000
# 500/500 [==============================] - 39s 78ms/step - loss: 0.1084 - accuracy: 0.7788 - val_loss: 0.1258 - val_accuracy: 0.7401
# Epoch 59/1000
# 500/500 [==============================] - 45s 90ms/step - loss: 0.1071 - accuracy: 0.7833 - val_loss: 0.1312 - val_accuracy: 0.7306
# Epoch 60/1000
# 500/500 [==============================] - 42s 84ms/step - loss: 0.1066 - accuracy: 0.7837 - val_loss: 0.1330 - val_accuracy: 0.7188
# Epoch 61/1000
# 500/500 [==============================] - ETA: 0s - loss: 0.1065 - accuracy: 0.7820
# Epoch 00061: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 500/500 [==============================] - 41s 83ms/step - loss: 0.1065 - accuracy: 0.7820 - val_loss: 0.1382 - val_accuracy: 0.7154
# Epoch 62/1000
# 500/500 [==============================] - 43s 86ms/step - loss: 0.1040 - accuracy: 0.7882 - val_loss: 0.1271 - val_accuracy: 0.7377
# Epoch 63/1000
# 500/500 [==============================] - 43s 86ms/step - loss: 0.1029 - accuracy: 0.7911 - val_loss: 0.1196 - val_accuracy: 0.7518
# Epoch 64/1000
# 500/500 [==============================] - 42s 83ms/step - loss: 0.1020 - accuracy: 0.7929 - val_loss: 0.1197 - val_accuracy: 0.7525
# Epoch 65/1000
# 500/500 [==============================] - 40s 79ms/step - loss: 0.1021 - accuracy: 0.7935 - val_loss: 0.1199 - val_accuracy: 0.7536
# Epoch 66/1000
# 500/500 [==============================] - 39s 78ms/step - loss: 0.1029 - accuracy: 0.7931 - val_loss: 0.1185 - val_accuracy: 0.7551
# Epoch 67/1000
# 500/500 [==============================] - 38s 77ms/step - loss: 0.1021 - accuracy: 0.7935 - val_loss: 0.1230 - val_accuracy: 0.7481
# Epoch 68/1000
# 500/500 [==============================] - 37s 74ms/step - loss: 0.1009 - accuracy: 0.7962 - val_loss: 0.1209 - val_accuracy: 0.7520
# Epoch 69/1000
# 500/500 [==============================] - 36s 73ms/step - loss: 0.1007 - accuracy: 0.7971 - val_loss: 0.1188 - val_accuracy: 0.7538
# Epoch 70/1000
# 500/500 [==============================] - 37s 73ms/step - loss: 0.1017 - accuracy: 0.7935 - val_loss: 0.1214 - val_accuracy: 0.7527
# Epoch 71/1000
# 500/500 [==============================] - 37s 74ms/step - loss: 0.1009 - accuracy: 0.7951 - val_loss: 0.1201 - val_accuracy: 0.7509
# Epoch 72/1000
# 500/500 [==============================] - 39s 78ms/step - loss: 0.1007 - accuracy: 0.7974 - val_loss: 0.1191 - val_accuracy: 0.7556
# Epoch 73/1000
# 500/500 [==============================] - 39s 77ms/step - loss: 0.0998 - accuracy: 0.7963 - val_loss: 0.1203 - val_accuracy: 0.7522
# Epoch 74/1000
# 500/500 [==============================] - 38s 77ms/step - loss: 0.1000 - accuracy: 0.7982 - val_loss: 0.1207 - val_accuracy: 0.7524
# Epoch 75/1000
# 500/500 [==============================] - 39s 78ms/step - loss: 0.1001 - accuracy: 0.7974 - val_loss: 0.1196 - val_accuracy: 0.7565
# Epoch 76/1000
# 499/500 [============================>.] - ETA: 0s - loss: 0.0999 - accuracy: 0.7976
# Epoch 00076: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 500/500 [==============================] - 23s 46ms/step - loss: 0.0999 - accuracy: 0.7975 - val_loss: 0.1239 - val_accuracy: 0.7429
# Epoch 77/1000
# 500/500 [==============================] - 20s 40ms/step - loss: 0.0983 - accuracy: 0.8020 - val_loss: 0.1189 - val_accuracy: 0.7562
# Epoch 78/1000
# 500/500 [==============================] - 19s 39ms/step - loss: 0.0977 - accuracy: 0.8035 - val_loss: 0.1209 - val_accuracy: 0.7512
# Epoch 79/1000
# 500/500 [==============================] - 20s 39ms/step - loss: 0.0972 - accuracy: 0.8037 - val_loss: 0.1182 - val_accuracy: 0.7599
# Epoch 80/1000
# 500/500 [==============================] - 20s 39ms/step - loss: 0.0971 - accuracy: 0.8044 - val_loss: 0.1196 - val_accuracy: 0.7554
# Epoch 81/1000
# 500/500 [==============================] - 20s 39ms/step - loss: 0.0969 - accuracy: 0.8060 - val_loss: 0.1178 - val_accuracy: 0.7580
# Epoch 82/1000
# 500/500 [==============================] - 20s 40ms/step - loss: 0.0963 - accuracy: 0.8066 - val_loss: 0.1184 - val_accuracy: 0.7596
# Epoch 83/1000
# 500/500 [==============================] - 23s 46ms/step - loss: 0.0960 - accuracy: 0.8078 - val_loss: 0.1205 - val_accuracy: 0.7522
# Epoch 84/1000
# 500/500 [==============================] - 21s 43ms/step - loss: 0.0963 - accuracy: 0.8060 - val_loss: 0.1192 - val_accuracy: 0.7579
# Epoch 85/1000
# 500/500 [==============================] - 21s 42ms/step - loss: 0.0964 - accuracy: 0.8061 - val_loss: 0.1185 - val_accuracy: 0.7604
# Epoch 86/1000
# 500/500 [==============================] - 21s 43ms/step - loss: 0.0967 - accuracy: 0.8071 - val_loss: 0.1178 - val_accuracy: 0.7608
# Epoch 87/1000
# 500/500 [==============================] - 21s 41ms/step - loss: 0.0954 - accuracy: 0.8082 - val_loss: 0.1231 - val_accuracy: 0.7500
# Epoch 88/1000
# 500/500 [==============================] - 21s 41ms/step - loss: 0.0958 - accuracy: 0.8076 - val_loss: 0.1179 - val_accuracy: 0.7575
# Epoch 89/1000
# 500/500 [==============================] - 20s 39ms/step - loss: 0.0950 - accuracy: 0.8081 - val_loss: 0.1186 - val_accuracy: 0.7593
# Epoch 90/1000
# 500/500 [==============================] - 19s 38ms/step - loss: 0.0964 - accuracy: 0.8070 - val_loss: 0.1187 - val_accuracy: 0.7568
# Epoch 91/1000
# 500/500 [==============================] - ETA: 0s - loss: 0.0960 - accuracy: 0.8089
# Epoch 00091: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 500/500 [==============================] - 19s 38ms/step - loss: 0.0960 - accuracy: 0.8089 - val_loss: 0.1196 - val_accuracy: 0.7556
# Epoch 92/1000
# 500/500 [==============================] - 19s 38ms/step - loss: 0.0950 - accuracy: 0.8101 - val_loss: 0.1180 - val_accuracy: 0.7604
# Epoch 93/1000
# 500/500 [==============================] - 19s 38ms/step - loss: 0.0946 - accuracy: 0.8109 - val_loss: 0.1177 - val_accuracy: 0.7625
# Epoch 94/1000
# 500/500 [==============================] - 19s 39ms/step - loss: 0.0952 - accuracy: 0.8100 - val_loss: 0.1173 - val_accuracy: 0.7613
# Epoch 95/1000
# 500/500 [==============================] - 24s 47ms/step - loss: 0.0945 - accuracy: 0.8104 - val_loss: 0.1179 - val_accuracy: 0.7630
# Epoch 96/1000
# 500/500 [==============================] - 22s 43ms/step - loss: 0.0948 - accuracy: 0.8084 - val_loss: 0.1183 - val_accuracy: 0.7600
# Epoch 97/1000
# 500/500 [==============================] - 21s 42ms/step - loss: 0.0944 - accuracy: 0.8105 - val_loss: 0.1181 - val_accuracy: 0.7618
# Epoch 98/1000
# 500/500 [==============================] - 21s 42ms/step - loss: 0.0939 - accuracy: 0.8132 - val_loss: 0.1180 - val_accuracy: 0.7602
# Epoch 99/1000
# 500/500 [==============================] - 22s 44ms/step - loss: 0.0948 - accuracy: 0.8094 - val_loss: 0.1171 - val_accuracy: 0.7629
# Epoch 100/1000
# 500/500 [==============================] - 21s 42ms/step - loss: 0.0934 - accuracy: 0.8132 - val_loss: 0.1175 - val_accuracy: 0.7622
# Epoch 101/1000
# 500/500 [==============================] - 21s 42ms/step - loss: 0.0937 - accuracy: 0.8126 - val_loss: 0.1180 - val_accuracy: 0.7587
# Epoch 102/1000
# 500/500 [==============================] - 20s 40ms/step - loss: 0.0934 - accuracy: 0.8126 - val_loss: 0.1178 - val_accuracy: 0.7600
# Epoch 103/1000
# 500/500 [==============================] - 22s 44ms/step - loss: 0.0939 - accuracy: 0.8115 - val_loss: 0.1173 - val_accuracy: 0.7604
# Epoch 104/1000
# 500/500 [==============================] - 20s 40ms/step - loss: 0.0935 - accuracy: 0.8125 - val_loss: 0.1174 - val_accuracy: 0.7607
# Epoch 105/1000
# 500/500 [==============================] - 20s 40ms/step - loss: 0.0943 - accuracy: 0.8111 - val_loss: 0.1178 - val_accuracy: 0.7624
# Epoch 106/1000
# 500/500 [==============================] - 21s 43ms/step - loss: 0.0934 - accuracy: 0.8109 - val_loss: 0.1177 - val_accuracy: 0.7606
# Epoch 107/1000
# 500/500 [==============================] - 24s 47ms/step - loss: 0.0939 - accuracy: 0.8116 - val_loss: 0.1191 - val_accuracy: 0.7580
# Epoch 108/1000
# 500/500 [==============================] - 21s 41ms/step - loss: 0.0933 - accuracy: 0.8140 - val_loss: 0.1178 - val_accuracy: 0.7593
# Epoch 109/1000
# 499/500 [============================>.] - ETA: 0s - loss: 0.0946 - accuracy: 0.8111
# Epoch 00109: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# 500/500 [==============================] - 20s 39ms/step - loss: 0.0945 - accuracy: 0.8111 - val_loss: 0.1181 - val_accuracy: 0.7588
# Epoch 110/1000
# 500/500 [==============================] - 20s 40ms/step - loss: 0.0926 - accuracy: 0.8147 - val_loss: 0.1176 - val_accuracy: 0.7618
# Epoch 111/1000
# 500/500 [==============================] - 21s 42ms/step - loss: 0.0928 - accuracy: 0.8145 - val_loss: 0.1178 - val_accuracy: 0.7611
# Epoch 112/1000
# 500/500 [==============================] - 20s 40ms/step - loss: 0.0925 - accuracy: 0.8133 - val_loss: 0.1177 - val_accuracy: 0.7612
# Epoch 113/1000
# 500/500 [==============================] - 23s 46ms/step - loss: 0.0936 - accuracy: 0.8134 - val_loss: 0.1175 - val_accuracy: 0.7633
# Epoch 114/1000
# 500/500 [==============================] - 22s 44ms/step - loss: 0.0918 - accuracy: 0.8161 - val_loss: 0.1176 - val_accuracy: 0.7627
# Epoch 115/1000
# 500/500 [==============================] - 20s 41ms/step - loss: 0.0923 - accuracy: 0.8143 - val_loss: 0.1177 - val_accuracy: 0.7604
# Epoch 116/1000
# 500/500 [==============================] - 20s 41ms/step - loss: 0.0927 - accuracy: 0.8144 - val_loss: 0.1174 - val_accuracy: 0.7614
# Epoch 117/1000
# 500/500 [==============================] - 20s 41ms/step - loss: 0.0938 - accuracy: 0.8126 - val_loss: 0.1174 - val_accuracy: 0.7607
# Epoch 118/1000
# 500/500 [==============================] - 21s 41ms/step - loss: 0.0925 - accuracy: 0.8129 - val_loss: 0.1182 - val_accuracy: 0.7597
# Epoch 119/1000
# 500/500 [==============================] - ETA: 0s - loss: 0.0927 - accuracy: 0.8152
# Epoch 00119: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# 500/500 [==============================] - 20s 40ms/step - loss: 0.0927 - accuracy: 0.8152 - val_loss: 0.1183 - val_accuracy: 0.7597
# Epoch 120/1000
# 500/500 [==============================] - 21s 41ms/step - loss: 0.0921 - accuracy: 0.8145 - val_loss: 0.1174 - val_accuracy: 0.7624
# Epoch 121/1000
# 500/500 [==============================] - 21s 41ms/step - loss: 0.0928 - accuracy: 0.8137 - val_loss: 0.1173 - val_accuracy: 0.7640
# Epoch 122/1000
# 500/500 [==============================] - 20s 41ms/step - loss: 0.0931 - accuracy: 0.8135 - val_loss: 0.1174 - val_accuracy: 0.7630
# Epoch 123/1000
# 500/500 [==============================] - 22s 43ms/step - loss: 0.0924 - accuracy: 0.8128 - val_loss: 0.1173 - val_accuracy: 0.7623
# Epoch 124/1000
# 500/500 [==============================] - 20s 40ms/step - loss: 0.0922 - accuracy: 0.8164 - val_loss: 0.1173 - val_accuracy: 0.7625
# Epoch 125/1000
# 500/500 [==============================] - 20s 39ms/step - loss: 0.0922 - accuracy: 0.8143 - val_loss: 0.1174 - val_accuracy: 0.7640
# Epoch 126/1000
# 500/500 [==============================] - 20s 41ms/step - loss: 0.0926 - accuracy: 0.8145 - val_loss: 0.1174 - val_accuracy: 0.7634
# Epoch 127/1000
# 500/500 [==============================] - 21s 41ms/step - loss: 0.0924 - accuracy: 0.8158 - val_loss: 0.1174 - val_accuracy: 0.7621
# Epoch 128/1000
# 500/500 [==============================] - 21s 41ms/step - loss: 0.0927 - accuracy: 0.8146 - val_loss: 0.1174 - val_accuracy: 0.7617
# Epoch 129/1000
# 500/500 [==============================] - ETA: 0s - loss: 0.0919 - accuracy: 0.8174
# Epoch 00129: ReduceLROnPlateau reducing learning rate to 7.812500371073838e-06.
# 500/500 [==============================] - 20s 40ms/step - loss: 0.0919 - accuracy: 0.8174 - val_loss: 0.1173 - val_accuracy: 0.7623
# Epoch 130/1000
# 500/500 [==============================] - 19s 39ms/step - loss: 0.0930 - accuracy: 0.8140 - val_loss: 0.1172 - val_accuracy: 0.7622
# Epoch 131/1000
# 500/500 [==============================] - 19s 39ms/step - loss: 0.0926 - accuracy: 0.8152 - val_loss: 0.1174 - val_accuracy: 0.7614
# Epoch 132/1000
# 500/500 [==============================] - 20s 40ms/step - loss: 0.0928 - accuracy: 0.8152 - val_loss: 0.1173 - val_accuracy: 0.7632
# Epoch 133/1000
# 500/500 [==============================] - 21s 41ms/step - loss: 0.0916 - accuracy: 0.8162 - val_loss: 0.1173 - val_accuracy: 0.7632
# Epoch 134/1000
# 500/500 [==============================] - ETA: 0s - loss: 0.0930 - accuracy: 0.8133Restoring model weights from the end of the best epoch.
# 500/500 [==============================] - 20s 41ms/step - loss: 0.0930 - accuracy: 0.8133 - val_loss: 0.1172 - val_accuracy: 0.7623
# Epoch 00134: early stopping

# %%
import matplotlib.pyplot as plt

fig = plt.figure(figsize=(10,6))
plt.plot(hist.history['loss'], color='#785ef0')
plt.plot(hist.history['val_loss'], color='#dc267f')
plt.title('Model Loss Progress')
plt.ylabel('Binary Cross-Entropy Loss')
plt.xlabel('Epoch')
plt.legend(['Training Set', 'Test Set'], loc='upper right')
plt.savefig('alternate-cifar-10.loss.png', dpi=350, bbox_inches='tight')
plt.show()

# %%
from sklearn.preprocessing import MinMaxScaler

cnnl1 = classifier.layers[1].name   # get the name of the first conv layer
W = classifier.get_layer(name=cnnl1).get_weights()[0]   #get the filters
wshape = W.shape  #save the original shape

# this part will scale to [0, 1] for visualization purposes
scaler = MinMaxScaler()
scaler.fit(W.reshape(-1,1))
W = scaler.transform(W.reshape(-1,1))
W = W.reshape(wshape)

# since there are 64 filters, we will display them 8x8
fig, axs = plt.subplots(8,8, figsize=(24,24))
fig.subplots_adjust(hspace = .25, wspace=.001)
axs = axs.ravel()
for i in range(W.shape[-1]):
  # we reshape to a 3D (RGB) image shape and display
  h = np.reshape(W[:,:,:,i], (9,9,3))
  axs[i].imshow(h)
  axs[i].set_title('Filter ' + str(i))    
plt.savefig("alternate-cifar-10.filters.png", bbox_inches='tight', dpi=350)

# %%
cnnl1 = classifier.layers[1].name   # get the name of the first conv layer
W = classifier.get_layer(name=cnnl1).get_weights()[0]
plt.hist(W.ravel(), bins=100)
print(np.min(W),np.max(W))
# Out:
# -0.6509564 0.4918079

# %%
plt.hist(np.array(filterbank).ravel(), bins=100)
print(np.min(filterbank), np.max(filterbank))
# Out:
# -0.03580871090360805 0.0349803095912802

# %%
fig = plt.subplots(12, 16, figsize=(22,22))

filter_layers = []
for i in range(64):
    for j in range(3):
        filter_layers.append(np.reshape(W[:,:,j, i], (9,9)))
for i,gf in enumerate(filter_layers):
    plt.subplot(12, 16, i+1)
    plt.imshow(gf, cmap='gray')
    plt.axis('off')
