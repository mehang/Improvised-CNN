# %%
from skimage.filters import gabor_kernel
from skimage import io
from skimage.transform import resize
from matplotlib import pyplot as plt 
import numpy as np

import math

# %%
def get_gabor_filters(inchannels, outchannels, kernel_size = (3,3)):
    delta = 1e-4
    
    freqs = (1/4)*math.sqrt(2)**(-np.random.randint(0,15, (outchannels, inchannels)))
    thetas = (math.pi/8)*np.random.randint(0,8, (outchannels, inchannels))
    sigmas = 1/(2*freqs)
    psis = math.pi * np.random.rand(outchannels, inchannels)
    x0, y0 = np.ceil(np.array(kernel_size)/2)    
    
    y, x = np.meshgrid(
            np.linspace(-y0, y0 + 1, kernel_size[0]),
            np.linspace(-x0, x0 + 1, kernel_size[1]),
    )
    filterbank = []
    
    for i in range(outchannels):
        for j in range(inchannels):
            freq = freqs[i][j]
            theta = thetas[i][j]
            sigma = sigmas[i][j]
            psi = psis[i][j]
            
            rotx = x * np.cos(theta) + y * np.sin(theta)
            roty = -x * np.sin(theta) + y * np.cos(theta)

            g = np.exp(
                -0.5 * ((rotx ** 2 + roty ** 2) / (sigma + delta) ** 2)
            )
            g = g * np.cos(freq * rotx + psi)
            g = g / (2 * math.pi * sigma ** 2)
#             g = gabor_kernel(frequency=freq, bandwidth=sigma, theta=theta, offset=psi, n_stds=0).real
            filterbank.append(g)
    return filterbank

filterbank = get_gabor_filters(3, 64, (3,3))

fig = plt.subplots(12, 16, figsize=(22,22))
for i,gf in enumerate(filterbank):
    plt.subplot(12, 16, i+1)
    plt.imshow(gf, cmap='gray')
    plt.axis('off')

# %%
from tensorflow.keras.datasets import cifar10
from tensorflow.keras.utils import to_categorical

# The data, split between train and test sets:
(x_train, y_train), (x_test, y_test) = cifar10.load_data()
x_train = x_train.astype('float32') / 255.0
x_test = x_test.astype('float32') / 255.0

y_train = to_categorical(y_train, 10)
y_test = to_categorical(y_test, 10)

print('x_train shape:', x_train.shape)
print('x_test shape:', x_test.shape)
# Out:
# x_train shape: (50000, 32, 32, 3)
# x_test shape: (10000, 32, 32, 3)

# %%
# Importing the Keras libraries and packages
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Activation
from tensorflow.keras.layers import Input, Dense, Dropout, BatchNormalization
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import RMSprop, Adam

# dimensionality of input and latent encoded representations
inpt_dim = (32, 32, 3)

inpt_img = Input(shape=inpt_dim)

# Block 1
cl1 = Conv2D(64, (3, 3), strides=(2, 2),activation='relu', input_shape = inpt_dim)(inpt_img)
bnl2 = BatchNormalization()(cl1)
# afl3 = Activation('relu')(bnl2)
pl4 = MaxPooling2D(pool_size = (2, 2))(bnl2)

# Adding a second convolutional layer
cl5 = Conv2D(128, (3, 3), strides=(1, 1), activation='relu')(pl4)
bnl6 = BatchNormalization()(cl5)
# afl7 = Activation('relu')(bnl6)
pl8 = MaxPooling2D(pool_size = (2, 2))(bnl6)
bnl9 = BatchNormalization()(pl8)

# Step 3 - Flattening
fl10 = Flatten()(bnl9)

# Step 4 - Full connection
dol11 = Dropout(0.5)(fl10)
dl12 = Dense(units = 256, activation = 'relu')(dol11)
dol13 = Dropout(0.2)(dl12)
dl14 = Dense(units = 64, activation = 'relu')(dol13)
dol15 = Dropout(0.1)(dl14)
output = Dense(units = 10, activation = 'sigmoid')(dol15)

classifier = Model(inpt_img, output)

# Compiling the CNN
opt = RMSprop(learning_rate=0.001)
# opt = Adam(learning_rate=0.01)

classifier.compile(optimizer = opt, loss = 'binary_crossentropy', 
                   metrics = ['accuracy'])

print(classifier.summary())
# Out:
# Model: "functional_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 32, 32, 3)]       0
# _________________________________________________________________
# conv2d (Conv2D)              (None, 15, 15, 64)        1792
# _________________________________________________________________
# batch_normalization (BatchNo (None, 15, 15, 64)        256
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 7, 7, 64)          0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 5, 5, 128)         73856
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 5, 5, 128)         512
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 2, 2, 128)         0
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 2, 2, 128)         512
# _________________________________________________________________
# flatten (Flatten)            (None, 512)               0
# _________________________________________________________________
# dropout (Dropout)            (None, 512)               0
# _________________________________________________________________
# dense (Dense)                (None, 256)               131328
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 64)                16448
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 64)                0
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                650
# =================================================================
# Total params: 225,354
# Trainable params: 224,714
# Non-trainable params: 640
# _________________________________________________________________
# None

# %%
cnnl1 = classifier.layers[1].name   # get the name of the first conv layer
W = classifier.get_layer(name=cnnl1).get_weights()[0]   #get the filters
wshape = W.shape  #save the original shape

# %%
gabor_filters = np.empty(wshape, dtype='float32')
for kernel_index in range(wshape[3]):
    for channel_index in range(3):
        gabor_filters[:,:,channel_index, kernel_index] = filterbank[kernel_index+channel_index]
        
cnnl1 = classifier.layers[1].name   # get the name of the first conv layer
classifier.get_layer(name=cnnl1).set_weights([gabor_filters, classifier.get_layer(name=cnnl1).get_weights()[1]])

fig = plt.subplots(12, 16, figsize=(22,22))
W = classifier.get_layer(name=cnnl1).get_weights()[0]   #get the filters
filter_layers = []
for i in range(64):
    for j in range(3):
        filter_layers.append(np.reshape(W[:,:,j, i], (3,3)))
for i,gf in enumerate(filter_layers):
    plt.subplot(12, 16, i+1)
    plt.imshow(gf, cmap='gray')
    plt.axis('off')

# %%
# Fitting the CNN to the images

from tensorflow.keras.callbacks import ReduceLROnPlateau, EarlyStopping

reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=10,  
                              min_delta=1e-4, mode='min', verbose=1)

stop_alg = EarlyStopping(monitor='val_loss', patience=35, 
                         restore_best_weights=True, verbose=1)

hist = classifier.fit(x_train, y_train, batch_size=100, epochs=1000, 
                   callbacks=[stop_alg, reduce_lr], shuffle=True, 
                   validation_data=(x_test, y_test))

classifier.save_weights("cnn1.hdf5")
# Out:
# Epoch 1/1000
# 500/500 [==============================] - 22s 45ms/step - loss: 0.2765 - accuracy: 0.3520 - val_loss: 0.2824 - val_accuracy: 0.3021
# Epoch 2/1000
# 500/500 [==============================] - 21s 42ms/step - loss: 0.2309 - accuracy: 0.4720 - val_loss: 0.2287 - val_accuracy: 0.4713
# Epoch 3/1000
# 500/500 [==============================] - 22s 43ms/step - loss: 0.2165 - accuracy: 0.5141 - val_loss: 0.2294 - val_accuracy: 0.4767
# Epoch 4/1000
# 500/500 [==============================] - 22s 44ms/step - loss: 0.2058 - accuracy: 0.5428 - val_loss: 0.2466 - val_accuracy: 0.4463
# Epoch 5/1000
# 500/500 [==============================] - 22s 45ms/step - loss: 0.1975 - accuracy: 0.5663 - val_loss: 0.2047 - val_accuracy: 0.5311
# Epoch 6/1000
# 500/500 [==============================] - 22s 43ms/step - loss: 0.1917 - accuracy: 0.5809 - val_loss: 0.1796 - val_accuracy: 0.6040
# Epoch 7/1000
# 500/500 [==============================] - 22s 45ms/step - loss: 0.1871 - accuracy: 0.5914 - val_loss: 0.1988 - val_accuracy: 0.5591
# Epoch 8/1000
# 500/500 [==============================] - 21s 42ms/step - loss: 0.1819 - accuracy: 0.6028 - val_loss: 0.1933 - val_accuracy: 0.5776
# Epoch 9/1000
# 500/500 [==============================] - 22s 44ms/step - loss: 0.1780 - accuracy: 0.6162 - val_loss: 0.1732 - val_accuracy: 0.6217
# Epoch 10/1000
# 500/500 [==============================] - 28s 57ms/step - loss: 0.1740 - accuracy: 0.6227 - val_loss: 0.1938 - val_accuracy: 0.5681
# Epoch 11/1000
# 500/500 [==============================] - 46s 91ms/step - loss: 0.1719 - accuracy: 0.6288 - val_loss: 0.1690 - val_accuracy: 0.6328
# Epoch 12/1000
# 500/500 [==============================] - 59s 118ms/step - loss: 0.1695 - accuracy: 0.6355 - val_loss: 0.1693 - val_accuracy: 0.6390
# Epoch 13/1000
# 500/500 [==============================] - 59s 119ms/step - loss: 0.1675 - accuracy: 0.6399 - val_loss: 0.1860 - val_accuracy: 0.5904
# Epoch 14/1000
# 500/500 [==============================] - 59s 118ms/step - loss: 0.1651 - accuracy: 0.6465 - val_loss: 0.4733 - val_accuracy: 0.3129
# Epoch 15/1000
# 500/500 [==============================] - 59s 119ms/step - loss: 0.1625 - accuracy: 0.6536 - val_loss: 0.1672 - val_accuracy: 0.6347
# Epoch 16/1000
# 500/500 [==============================] - 59s 119ms/step - loss: 0.1606 - accuracy: 0.6592 - val_loss: 0.1701 - val_accuracy: 0.6367
# Epoch 17/1000
# 500/500 [==============================] - 59s 118ms/step - loss: 0.1597 - accuracy: 0.6599 - val_loss: 0.1655 - val_accuracy: 0.6436
# Epoch 18/1000
# 500/500 [==============================] - 58s 116ms/step - loss: 0.1579 - accuracy: 0.6650 - val_loss: 0.1587 - val_accuracy: 0.6593
# Epoch 19/1000
# 500/500 [==============================] - 59s 118ms/step - loss: 0.1561 - accuracy: 0.6707 - val_loss: 0.1624 - val_accuracy: 0.6470
# Epoch 20/1000
# 500/500 [==============================] - 59s 118ms/step - loss: 0.1551 - accuracy: 0.6684 - val_loss: 0.1716 - val_accuracy: 0.6265
# Epoch 21/1000
# 500/500 [==============================] - 59s 118ms/step - loss: 0.1543 - accuracy: 0.6718 - val_loss: 0.1545 - val_accuracy: 0.6689
# Epoch 22/1000
# 500/500 [==============================] - 59s 117ms/step - loss: 0.1524 - accuracy: 0.6773 - val_loss: 0.1647 - val_accuracy: 0.6481
# Epoch 23/1000
# 500/500 [==============================] - 59s 118ms/step - loss: 0.1513 - accuracy: 0.6820 - val_loss: 0.1599 - val_accuracy: 0.6573
# Epoch 24/1000
# 500/500 [==============================] - 58s 116ms/step - loss: 0.1501 - accuracy: 0.6857 - val_loss: 0.1576 - val_accuracy: 0.6684
# Epoch 25/1000
# 500/500 [==============================] - 56s 111ms/step - loss: 0.1496 - accuracy: 0.6851 - val_loss: 0.1630 - val_accuracy: 0.6422
# Epoch 26/1000
# 500/500 [==============================] - 57s 113ms/step - loss: 0.1487 - accuracy: 0.6851 - val_loss: 0.1492 - val_accuracy: 0.6785
# Epoch 27/1000
# 500/500 [==============================] - 56s 112ms/step - loss: 0.1475 - accuracy: 0.6922 - val_loss: 0.1538 - val_accuracy: 0.6706
# Epoch 28/1000
# 500/500 [==============================] - 56s 112ms/step - loss: 0.1471 - accuracy: 0.6901 - val_loss: 0.1632 - val_accuracy: 0.6470
# Epoch 29/1000
# 500/500 [==============================] - 56s 113ms/step - loss: 0.1466 - accuracy: 0.6917 - val_loss: 0.1559 - val_accuracy: 0.6675
# Epoch 30/1000
# 500/500 [==============================] - 56s 112ms/step - loss: 0.1446 - accuracy: 0.6942 - val_loss: 0.1510 - val_accuracy: 0.6808
# Epoch 31/1000
# 500/500 [==============================] - 57s 113ms/step - loss: 0.1456 - accuracy: 0.6973 - val_loss: 0.1589 - val_accuracy: 0.6587
# Epoch 32/1000
# 500/500 [==============================] - 56s 112ms/step - loss: 0.1442 - accuracy: 0.6972 - val_loss: 0.1444 - val_accuracy: 0.6978
# Epoch 33/1000
# 500/500 [==============================] - 56s 112ms/step - loss: 0.1430 - accuracy: 0.7011 - val_loss: 0.1719 - val_accuracy: 0.6447
# Epoch 34/1000
# 500/500 [==============================] - 56s 112ms/step - loss: 0.1426 - accuracy: 0.7018 - val_loss: 0.1560 - val_accuracy: 0.6738
# Epoch 35/1000
# 500/500 [==============================] - 56s 113ms/step - loss: 0.1431 - accuracy: 0.7001 - val_loss: 0.1448 - val_accuracy: 0.6922
# Epoch 36/1000
# 500/500 [==============================] - 56s 112ms/step - loss: 0.1417 - accuracy: 0.7045 - val_loss: 0.1469 - val_accuracy: 0.6903
# Epoch 37/1000
# 500/500 [==============================] - 56s 112ms/step - loss: 0.1403 - accuracy: 0.7084 - val_loss: 0.1460 - val_accuracy: 0.6888
# Epoch 38/1000
# 500/500 [==============================] - 56s 112ms/step - loss: 0.1407 - accuracy: 0.7063 - val_loss: 0.1427 - val_accuracy: 0.6987
# Epoch 39/1000
# 500/500 [==============================] - 56s 112ms/step - loss: 0.1402 - accuracy: 0.7077 - val_loss: 0.1503 - val_accuracy: 0.6744
# Epoch 40/1000
# 500/500 [==============================] - 56s 113ms/step - loss: 0.1388 - accuracy: 0.7100 - val_loss: 0.1465 - val_accuracy: 0.6899
# Epoch 41/1000
# 500/500 [==============================] - 56s 112ms/step - loss: 0.1392 - accuracy: 0.7111 - val_loss: 0.1454 - val_accuracy: 0.6946
# Epoch 42/1000
# 500/500 [==============================] - 56s 113ms/step - loss: 0.1382 - accuracy: 0.7117 - val_loss: 0.1482 - val_accuracy: 0.6841
# Epoch 43/1000
# 500/500 [==============================] - 56s 112ms/step - loss: 0.1392 - accuracy: 0.7073 - val_loss: 0.1685 - val_accuracy: 0.6376
# Epoch 44/1000
# 500/500 [==============================] - 56s 113ms/step - loss: 0.1377 - accuracy: 0.7133 - val_loss: 0.1419 - val_accuracy: 0.7000
# Epoch 45/1000
# 500/500 [==============================] - 56s 112ms/step - loss: 0.1365 - accuracy: 0.7170 - val_loss: 0.1468 - val_accuracy: 0.6855
# Epoch 46/1000
# 500/500 [==============================] - 56s 113ms/step - loss: 0.1356 - accuracy: 0.7180 - val_loss: 0.1471 - val_accuracy: 0.6823
# Epoch 47/1000
# 500/500 [==============================] - 56s 112ms/step - loss: 0.1355 - accuracy: 0.7185 - val_loss: 0.1485 - val_accuracy: 0.6902
# Epoch 48/1000
# 500/500 [==============================] - 56s 112ms/step - loss: 0.1352 - accuracy: 0.7183 - val_loss: 0.1488 - val_accuracy: 0.6824
# Epoch 49/1000
# 500/500 [==============================] - 56s 112ms/step - loss: 0.1352 - accuracy: 0.7187 - val_loss: 0.1502 - val_accuracy: 0.6797
# Epoch 50/1000
# 500/500 [==============================] - 56s 112ms/step - loss: 0.1348 - accuracy: 0.7201 - val_loss: 0.1389 - val_accuracy: 0.7073
# Epoch 51/1000
# 500/500 [==============================] - 56s 112ms/step - loss: 0.1335 - accuracy: 0.7232 - val_loss: 0.1382 - val_accuracy: 0.7103
# Epoch 52/1000
# 500/500 [==============================] - 56s 112ms/step - loss: 0.1333 - accuracy: 0.7242 - val_loss: 0.1736 - val_accuracy: 0.6372
# Epoch 53/1000
# 500/500 [==============================] - 56s 112ms/step - loss: 0.1325 - accuracy: 0.7264 - val_loss: 0.1439 - val_accuracy: 0.6968
# Epoch 54/1000
# 500/500 [==============================] - 56s 111ms/step - loss: 0.1317 - accuracy: 0.7296 - val_loss: 0.1487 - val_accuracy: 0.6821
# Epoch 55/1000
# 500/500 [==============================] - 56s 113ms/step - loss: 0.1326 - accuracy: 0.7252 - val_loss: 0.1446 - val_accuracy: 0.6958
# Epoch 56/1000
# 500/500 [==============================] - 56s 113ms/step - loss: 0.1314 - accuracy: 0.7297 - val_loss: 0.1360 - val_accuracy: 0.7192
# Epoch 57/1000
# 500/500 [==============================] - 56s 112ms/step - loss: 0.1314 - accuracy: 0.7299 - val_loss: 0.1607 - val_accuracy: 0.6585
# Epoch 58/1000
# 500/500 [==============================] - 56s 112ms/step - loss: 0.1302 - accuracy: 0.7319 - val_loss: 0.1662 - val_accuracy: 0.6380
# Epoch 59/1000
# 500/500 [==============================] - 56s 113ms/step - loss: 0.1309 - accuracy: 0.7294 - val_loss: 0.1398 - val_accuracy: 0.7067
# Epoch 60/1000
# 500/500 [==============================] - 56s 112ms/step - loss: 0.1301 - accuracy: 0.7303 - val_loss: 0.1450 - val_accuracy: 0.6928
# Epoch 61/1000
# 500/500 [==============================] - 56s 112ms/step - loss: 0.1297 - accuracy: 0.7328 - val_loss: 0.1662 - val_accuracy: 0.6497
# Epoch 62/1000
# 500/500 [==============================] - 56s 111ms/step - loss: 0.1292 - accuracy: 0.7343 - val_loss: 0.1497 - val_accuracy: 0.6805
# Epoch 63/1000
# 500/500 [==============================] - 56s 111ms/step - loss: 0.1291 - accuracy: 0.7356 - val_loss: 0.1419 - val_accuracy: 0.6971
# Epoch 64/1000
# 500/500 [==============================] - 56s 112ms/step - loss: 0.1288 - accuracy: 0.7357 - val_loss: 0.1425 - val_accuracy: 0.6987
# Epoch 65/1000
# 500/500 [==============================] - 56s 112ms/step - loss: 0.1291 - accuracy: 0.7362 - val_loss: 0.1347 - val_accuracy: 0.7161
# Epoch 66/1000
# 500/500 [==============================] - 56s 112ms/step - loss: 0.1282 - accuracy: 0.7376 - val_loss: 0.1497 - val_accuracy: 0.6862
# Epoch 67/1000
# 500/500 [==============================] - 56s 112ms/step - loss: 0.1290 - accuracy: 0.7370 - val_loss: 0.1456 - val_accuracy: 0.6923
# Epoch 68/1000
# 500/500 [==============================] - 56s 111ms/step - loss: 0.1289 - accuracy: 0.7373 - val_loss: 0.1427 - val_accuracy: 0.7044
# Epoch 69/1000
# 500/500 [==============================] - 56s 112ms/step - loss: 0.1278 - accuracy: 0.7391 - val_loss: 0.1349 - val_accuracy: 0.7182
# Epoch 70/1000
# 500/500 [==============================] - 56s 112ms/step - loss: 0.1286 - accuracy: 0.7344 - val_loss: 0.1429 - val_accuracy: 0.7022
# Epoch 71/1000
# 500/500 [==============================] - 56s 112ms/step - loss: 0.1270 - accuracy: 0.7382 - val_loss: 0.1414 - val_accuracy: 0.6993
# Epoch 72/1000
# 500/500 [==============================] - 56s 112ms/step - loss: 0.1272 - accuracy: 0.7384 - val_loss: 0.1374 - val_accuracy: 0.7084
# Epoch 73/1000
# 500/500 [==============================] - 56s 112ms/step - loss: 0.1271 - accuracy: 0.7405 - val_loss: 0.1453 - val_accuracy: 0.6949
# Epoch 74/1000
# 500/500 [==============================] - 61s 122ms/step - loss: 0.1268 - accuracy: 0.7403 - val_loss: 0.1379 - val_accuracy: 0.7078
# Epoch 75/1000
# 500/500 [==============================] - ETA: 0s - loss: 0.1268 - accuracy: 0.7424
# Epoch 00075: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 500/500 [==============================] - 59s 117ms/step - loss: 0.1268 - accuracy: 0.7424 - val_loss: 0.1364 - val_accuracy: 0.7160
# Epoch 76/1000
# 500/500 [==============================] - 59s 117ms/step - loss: 0.1217 - accuracy: 0.7539 - val_loss: 0.1342 - val_accuracy: 0.7190
# Epoch 77/1000
# 500/500 [==============================] - 58s 116ms/step - loss: 0.1217 - accuracy: 0.7522 - val_loss: 0.1351 - val_accuracy: 0.7194
# Epoch 78/1000
# 500/500 [==============================] - 58s 117ms/step - loss: 0.1205 - accuracy: 0.7549 - val_loss: 0.1409 - val_accuracy: 0.7022
# Epoch 79/1000
# 500/500 [==============================] - 59s 118ms/step - loss: 0.1190 - accuracy: 0.7578 - val_loss: 0.1381 - val_accuracy: 0.7027
# Epoch 80/1000
# 500/500 [==============================] - 59s 118ms/step - loss: 0.1186 - accuracy: 0.7591 - val_loss: 0.1347 - val_accuracy: 0.7180
# Epoch 81/1000
# 500/500 [==============================] - 59s 117ms/step - loss: 0.1190 - accuracy: 0.7602 - val_loss: 0.1432 - val_accuracy: 0.6981
# Epoch 82/1000
# 500/500 [==============================] - 59s 118ms/step - loss: 0.1187 - accuracy: 0.7599 - val_loss: 0.1420 - val_accuracy: 0.7012
# Epoch 83/1000
# 500/500 [==============================] - 58s 117ms/step - loss: 0.1196 - accuracy: 0.7582 - val_loss: 0.1333 - val_accuracy: 0.7176
# Epoch 84/1000
# 500/500 [==============================] - 59s 118ms/step - loss: 0.1190 - accuracy: 0.7597 - val_loss: 0.1374 - val_accuracy: 0.7101
# Epoch 85/1000
# 500/500 [==============================] - 59s 118ms/step - loss: 0.1186 - accuracy: 0.7585 - val_loss: 0.1414 - val_accuracy: 0.7018
# Epoch 86/1000
# 500/500 [==============================] - 59s 117ms/step - loss: 0.1185 - accuracy: 0.7578 - val_loss: 0.1338 - val_accuracy: 0.7228
# Epoch 87/1000
# 500/500 [==============================] - 61s 122ms/step - loss: 0.1184 - accuracy: 0.7588 - val_loss: 0.1421 - val_accuracy: 0.7024
# Epoch 88/1000
# 500/500 [==============================] - 58s 117ms/step - loss: 0.1187 - accuracy: 0.7602 - val_loss: 0.1321 - val_accuracy: 0.7242
# Epoch 89/1000
# 500/500 [==============================] - 59s 117ms/step - loss: 0.1181 - accuracy: 0.7588 - val_loss: 0.1337 - val_accuracy: 0.7204
# Epoch 90/1000
# 500/500 [==============================] - 59s 117ms/step - loss: 0.1177 - accuracy: 0.7616 - val_loss: 0.1423 - val_accuracy: 0.7002
# Epoch 91/1000
# 500/500 [==============================] - 58s 117ms/step - loss: 0.1171 - accuracy: 0.7637 - val_loss: 0.1353 - val_accuracy: 0.7199
# Epoch 92/1000
# 500/500 [==============================] - 59s 118ms/step - loss: 0.1171 - accuracy: 0.7605 - val_loss: 0.1323 - val_accuracy: 0.7224
# Epoch 93/1000
# 500/500 [==============================] - 58s 116ms/step - loss: 0.1172 - accuracy: 0.7638 - val_loss: 0.1371 - val_accuracy: 0.7110
# Epoch 94/1000
# 500/500 [==============================] - 58s 117ms/step - loss: 0.1165 - accuracy: 0.7648 - val_loss: 0.1369 - val_accuracy: 0.7141
# Epoch 95/1000
# 500/500 [==============================] - 59s 118ms/step - loss: 0.1172 - accuracy: 0.7629 - val_loss: 0.1322 - val_accuracy: 0.7215
# Epoch 96/1000
# 500/500 [==============================] - 63s 126ms/step - loss: 0.1163 - accuracy: 0.7641 - val_loss: 0.1366 - val_accuracy: 0.7166
# Epoch 97/1000
# 500/500 [==============================] - 69s 138ms/step - loss: 0.1173 - accuracy: 0.7632 - val_loss: 0.1332 - val_accuracy: 0.7230
# Epoch 98/1000
# 500/500 [==============================] - ETA: 0s - loss: 0.1180 - accuracy: 0.7606
# Epoch 00098: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 500/500 [==============================] - 63s 126ms/step - loss: 0.1180 - accuracy: 0.7606 - val_loss: 0.1336 - val_accuracy: 0.7241
# Epoch 99/1000
# 500/500 [==============================] - 69s 138ms/step - loss: 0.1135 - accuracy: 0.7714 - val_loss: 0.1327 - val_accuracy: 0.7239
# Epoch 100/1000
# 500/500 [==============================] - 63s 125ms/step - loss: 0.1131 - accuracy: 0.7716 - val_loss: 0.1321 - val_accuracy: 0.7281
# Epoch 101/1000
# 500/500 [==============================] - 58s 115ms/step - loss: 0.1132 - accuracy: 0.7714 - val_loss: 0.1332 - val_accuracy: 0.7203
# Epoch 102/1000
# 500/500 [==============================] - 58s 115ms/step - loss: 0.1131 - accuracy: 0.7730 - val_loss: 0.1305 - val_accuracy: 0.7276
# Epoch 103/1000
# 500/500 [==============================] - 57s 114ms/step - loss: 0.1129 - accuracy: 0.7708 - val_loss: 0.1304 - val_accuracy: 0.7276
# Epoch 104/1000
# 500/500 [==============================] - 64s 127ms/step - loss: 0.1134 - accuracy: 0.7714 - val_loss: 0.1332 - val_accuracy: 0.7189
# Epoch 105/1000
# 500/500 [==============================] - 56s 111ms/step - loss: 0.1132 - accuracy: 0.7705 - val_loss: 0.1298 - val_accuracy: 0.7286
# Epoch 106/1000
# 500/500 [==============================] - 56s 113ms/step - loss: 0.1124 - accuracy: 0.7725 - val_loss: 0.1308 - val_accuracy: 0.7251
# Epoch 107/1000
# 500/500 [==============================] - 61s 122ms/step - loss: 0.1127 - accuracy: 0.7738 - val_loss: 0.1306 - val_accuracy: 0.7278
# Epoch 108/1000
# 500/500 [==============================] - 64s 127ms/step - loss: 0.1124 - accuracy: 0.7729 - val_loss: 0.1306 - val_accuracy: 0.7297
# Epoch 109/1000
# 500/500 [==============================] - 59s 118ms/step - loss: 0.1124 - accuracy: 0.7730 - val_loss: 0.1334 - val_accuracy: 0.7207
# Epoch 110/1000
# 500/500 [==============================] - 58s 116ms/step - loss: 0.1117 - accuracy: 0.7747 - val_loss: 0.1326 - val_accuracy: 0.7230
# Epoch 111/1000
# 500/500 [==============================] - 58s 116ms/step - loss: 0.1126 - accuracy: 0.7727 - val_loss: 0.1301 - val_accuracy: 0.7252
# Epoch 112/1000
# 500/500 [==============================] - 59s 119ms/step - loss: 0.1118 - accuracy: 0.7745 - val_loss: 0.1310 - val_accuracy: 0.7275
# Epoch 113/1000
# 500/500 [==============================] - 60s 121ms/step - loss: 0.1121 - accuracy: 0.7732 - val_loss: 0.1309 - val_accuracy: 0.7273
# Epoch 114/1000
# 500/500 [==============================] - 60s 120ms/step - loss: 0.1116 - accuracy: 0.7745 - val_loss: 0.1317 - val_accuracy: 0.7270
# Epoch 115/1000
# 500/500 [==============================] - ETA: 0s - loss: 0.1126 - accuracy: 0.7730
# Epoch 00115: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 500/500 [==============================] - 63s 125ms/step - loss: 0.1126 - accuracy: 0.7730 - val_loss: 0.1309 - val_accuracy: 0.7284
# Epoch 116/1000
# 500/500 [==============================] - 61s 121ms/step - loss: 0.1108 - accuracy: 0.7774 - val_loss: 0.1287 - val_accuracy: 0.7297
# Epoch 117/1000
# 500/500 [==============================] - 59s 118ms/step - loss: 0.1102 - accuracy: 0.7755 - val_loss: 0.1286 - val_accuracy: 0.7321
# Epoch 118/1000
# 500/500 [==============================] - 56s 113ms/step - loss: 0.1103 - accuracy: 0.7796 - val_loss: 0.1295 - val_accuracy: 0.7292
# Epoch 119/1000
# 500/500 [==============================] - 56s 112ms/step - loss: 0.1098 - accuracy: 0.7797 - val_loss: 0.1314 - val_accuracy: 0.7302
# Epoch 120/1000
# 500/500 [==============================] - 56s 112ms/step - loss: 0.1106 - accuracy: 0.7782 - val_loss: 0.1295 - val_accuracy: 0.7293
# Epoch 121/1000
# 500/500 [==============================] - 56s 113ms/step - loss: 0.1096 - accuracy: 0.7810 - val_loss: 0.1297 - val_accuracy: 0.7306
# Epoch 122/1000
# 500/500 [==============================] - 58s 116ms/step - loss: 0.1096 - accuracy: 0.7786 - val_loss: 0.1290 - val_accuracy: 0.7307
# Epoch 123/1000
# 500/500 [==============================] - 57s 114ms/step - loss: 0.1101 - accuracy: 0.7786 - val_loss: 0.1301 - val_accuracy: 0.7292
# Epoch 124/1000
# 500/500 [==============================] - 56s 113ms/step - loss: 0.1090 - accuracy: 0.7822 - val_loss: 0.1300 - val_accuracy: 0.7293
# Epoch 125/1000
# 500/500 [==============================] - 56s 112ms/step - loss: 0.1098 - accuracy: 0.7770 - val_loss: 0.1302 - val_accuracy: 0.7327
# Epoch 126/1000
# 500/500 [==============================] - 57s 114ms/step - loss: 0.1107 - accuracy: 0.7777 - val_loss: 0.1297 - val_accuracy: 0.7293
# Epoch 127/1000
# 500/500 [==============================] - ETA: 0s - loss: 0.1095 - accuracy: 0.7806
# Epoch 00127: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 500/500 [==============================] - 62s 123ms/step - loss: 0.1095 - accuracy: 0.7806 - val_loss: 0.1293 - val_accuracy: 0.7328
# Epoch 128/1000
# 500/500 [==============================] - 59s 117ms/step - loss: 0.1090 - accuracy: 0.7841 - val_loss: 0.1292 - val_accuracy: 0.7320
# Epoch 129/1000
# 500/500 [==============================] - 59s 117ms/step - loss: 0.1081 - accuracy: 0.7837 - val_loss: 0.1296 - val_accuracy: 0.7329
# Epoch 130/1000
# 500/500 [==============================] - 59s 118ms/step - loss: 0.1086 - accuracy: 0.7821 - val_loss: 0.1290 - val_accuracy: 0.7303
# Epoch 131/1000
# 500/500 [==============================] - 59s 119ms/step - loss: 0.1090 - accuracy: 0.7826 - val_loss: 0.1286 - val_accuracy: 0.7307
# Epoch 132/1000
# 500/500 [==============================] - 59s 117ms/step - loss: 0.1093 - accuracy: 0.7774 - val_loss: 0.1291 - val_accuracy: 0.7301
# Epoch 133/1000
# 500/500 [==============================] - 59s 118ms/step - loss: 0.1083 - accuracy: 0.7815 - val_loss: 0.1296 - val_accuracy: 0.7283
# Epoch 134/1000
# 500/500 [==============================] - 59s 117ms/step - loss: 0.1088 - accuracy: 0.7828 - val_loss: 0.1291 - val_accuracy: 0.7324
# Epoch 135/1000
# 500/500 [==============================] - 60s 119ms/step - loss: 0.1078 - accuracy: 0.7829 - val_loss: 0.1289 - val_accuracy: 0.7304
# Epoch 136/1000
# 500/500 [==============================] - 59s 118ms/step - loss: 0.1092 - accuracy: 0.7824 - val_loss: 0.1288 - val_accuracy: 0.7306
# Epoch 137/1000
# 500/500 [==============================] - ETA: 0s - loss: 0.1084 - accuracy: 0.7817
# Epoch 00137: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# 500/500 [==============================] - 60s 120ms/step - loss: 0.1084 - accuracy: 0.7817 - val_loss: 0.1293 - val_accuracy: 0.7287
# Epoch 138/1000
# 500/500 [==============================] - 59s 118ms/step - loss: 0.1086 - accuracy: 0.7827 - val_loss: 0.1289 - val_accuracy: 0.7287
# Epoch 139/1000
# 500/500 [==============================] - 59s 118ms/step - loss: 0.1083 - accuracy: 0.7817 - val_loss: 0.1291 - val_accuracy: 0.7307
# Epoch 140/1000
# 500/500 [==============================] - 58s 116ms/step - loss: 0.1083 - accuracy: 0.7826 - val_loss: 0.1287 - val_accuracy: 0.7316
# Epoch 141/1000
# 500/500 [==============================] - 59s 117ms/step - loss: 0.1077 - accuracy: 0.7836 - val_loss: 0.1289 - val_accuracy: 0.7302
# Epoch 142/1000
# 500/500 [==============================] - 59s 117ms/step - loss: 0.1077 - accuracy: 0.7822 - val_loss: 0.1287 - val_accuracy: 0.7301
# Epoch 143/1000
# 500/500 [==============================] - 59s 118ms/step - loss: 0.1081 - accuracy: 0.7820 - val_loss: 0.1286 - val_accuracy: 0.7310
# Epoch 144/1000
# 500/500 [==============================] - 59s 117ms/step - loss: 0.1086 - accuracy: 0.7810 - val_loss: 0.1289 - val_accuracy: 0.7304
# Epoch 145/1000
# 500/500 [==============================] - 59s 117ms/step - loss: 0.1083 - accuracy: 0.7820 - val_loss: 0.1287 - val_accuracy: 0.7318
# Epoch 146/1000
# 500/500 [==============================] - 59s 117ms/step - loss: 0.1072 - accuracy: 0.7856 - val_loss: 0.1289 - val_accuracy: 0.7288
# Epoch 147/1000
# 500/500 [==============================] - ETA: 0s - loss: 0.1077 - accuracy: 0.7844
# Epoch 00147: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# 500/500 [==============================] - 58s 117ms/step - loss: 0.1077 - accuracy: 0.7844 - val_loss: 0.1287 - val_accuracy: 0.7313
# Epoch 148/1000
# 500/500 [==============================] - 58s 116ms/step - loss: 0.1083 - accuracy: 0.7832 - val_loss: 0.1286 - val_accuracy: 0.7296
# Epoch 149/1000
# 500/500 [==============================] - 60s 120ms/step - loss: 0.1078 - accuracy: 0.7854 - val_loss: 0.1286 - val_accuracy: 0.7315
# Epoch 150/1000
# 500/500 [==============================] - 59s 118ms/step - loss: 0.1078 - accuracy: 0.7843 - val_loss: 0.1286 - val_accuracy: 0.7288
# Epoch 151/1000
# 500/500 [==============================] - 58s 117ms/step - loss: 0.1074 - accuracy: 0.7853 - val_loss: 0.1286 - val_accuracy: 0.7314
# Epoch 152/1000
# 500/500 [==============================] - 58s 117ms/step - loss: 0.1081 - accuracy: 0.7814 - val_loss: 0.1286 - val_accuracy: 0.7309
# Epoch 153/1000
# 500/500 [==============================] - 59s 118ms/step - loss: 0.1084 - accuracy: 0.7825 - val_loss: 0.1287 - val_accuracy: 0.7304
# Epoch 154/1000
# 500/500 [==============================] - 59s 117ms/step - loss: 0.1075 - accuracy: 0.7839 - val_loss: 0.1286 - val_accuracy: 0.7291
# Epoch 155/1000
# 500/500 [==============================] - 59s 117ms/step - loss: 0.1080 - accuracy: 0.7828 - val_loss: 0.1286 - val_accuracy: 0.7312
# Epoch 156/1000
# 500/500 [==============================] - 59s 117ms/step - loss: 0.1080 - accuracy: 0.7835 - val_loss: 0.1286 - val_accuracy: 0.7313
# Epoch 157/1000
# 500/500 [==============================] - 61s 121ms/step - loss: 0.1080 - accuracy: 0.7848 - val_loss: 0.1285 - val_accuracy: 0.7332
# Epoch 158/1000
# 500/500 [==============================] - 60s 120ms/step - loss: 0.1079 - accuracy: 0.7832 - val_loss: 0.1287 - val_accuracy: 0.7308
# Epoch 159/1000
# 500/500 [==============================] - 50s 101ms/step - loss: 0.1073 - accuracy: 0.7849 - val_loss: 0.1286 - val_accuracy: 0.7307
# Epoch 160/1000
# 500/500 [==============================] - 40s 79ms/step - loss: 0.1067 - accuracy: 0.7864 - val_loss: 0.1286 - val_accuracy: 0.7295
# Epoch 161/1000
# 500/500 [==============================] - 38s 76ms/step - loss: 0.1074 - accuracy: 0.7845 - val_loss: 0.1285 - val_accuracy: 0.7298
# Epoch 162/1000
# 500/500 [==============================] - 38s 76ms/step - loss: 0.1083 - accuracy: 0.7839 - val_loss: 0.1285 - val_accuracy: 0.7308
# Epoch 163/1000
# 500/500 [==============================] - 38s 76ms/step - loss: 0.1069 - accuracy: 0.7857 - val_loss: 0.1286 - val_accuracy: 0.7318
# Epoch 164/1000
# 500/500 [==============================] - 38s 76ms/step - loss: 0.1068 - accuracy: 0.7857 - val_loss: 0.1285 - val_accuracy: 0.7324
# Epoch 165/1000
# 500/500 [==============================] - 38s 77ms/step - loss: 0.1083 - accuracy: 0.7833 - val_loss: 0.1285 - val_accuracy: 0.7306
# Epoch 166/1000
# 500/500 [==============================] - 39s 79ms/step - loss: 0.1074 - accuracy: 0.7848 - val_loss: 0.1287 - val_accuracy: 0.7300
# Epoch 167/1000
# 500/500 [==============================] - ETA: 0s - loss: 0.1074 - accuracy: 0.7843
# Epoch 00167: ReduceLROnPlateau reducing learning rate to 7.812500371073838e-06.
# 500/500 [==============================] - 42s 84ms/step - loss: 0.1074 - accuracy: 0.7843 - val_loss: 0.1286 - val_accuracy: 0.7297
# Epoch 168/1000
# 500/500 [==============================] - 41s 82ms/step - loss: 0.1077 - accuracy: 0.7854 - val_loss: 0.1286 - val_accuracy: 0.7307
# Epoch 169/1000
# 500/500 [==============================] - 41s 81ms/step - loss: 0.1084 - accuracy: 0.7822 - val_loss: 0.1286 - val_accuracy: 0.7300
# Epoch 170/1000
# 500/500 [==============================] - 39s 79ms/step - loss: 0.1083 - accuracy: 0.7837 - val_loss: 0.1286 - val_accuracy: 0.7311
# Epoch 171/1000
# 500/500 [==============================] - 39s 79ms/step - loss: 0.1076 - accuracy: 0.7849 - val_loss: 0.1286 - val_accuracy: 0.7291
# Epoch 172/1000
# 500/500 [==============================] - 39s 79ms/step - loss: 0.1072 - accuracy: 0.7839 - val_loss: 0.1285 - val_accuracy: 0.7313
# Epoch 173/1000
# 500/500 [==============================] - 40s 79ms/step - loss: 0.1071 - accuracy: 0.7850 - val_loss: 0.1286 - val_accuracy: 0.7305
# Epoch 174/1000
# 500/500 [==============================] - 40s 79ms/step - loss: 0.1074 - accuracy: 0.7864 - val_loss: 0.1286 - val_accuracy: 0.7305
# Epoch 175/1000
# 500/500 [==============================] - 40s 80ms/step - loss: 0.1075 - accuracy: 0.7832 - val_loss: 0.1286 - val_accuracy: 0.7299
# Epoch 176/1000
# 500/500 [==============================] - 40s 80ms/step - loss: 0.1073 - accuracy: 0.7867 - val_loss: 0.1286 - val_accuracy: 0.7303
# Epoch 177/1000
# 500/500 [==============================] - ETA: 0s - loss: 0.1075 - accuracy: 0.7847
# Epoch 00177: ReduceLROnPlateau reducing learning rate to 3.906250185536919e-06.
# 500/500 [==============================] - 38s 77ms/step - loss: 0.1075 - accuracy: 0.7847 - val_loss: 0.1286 - val_accuracy: 0.7303
# Epoch 178/1000
# 500/500 [==============================] - 38s 76ms/step - loss: 0.1077 - accuracy: 0.7841 - val_loss: 0.1286 - val_accuracy: 0.7312
# Epoch 179/1000
# 500/500 [==============================] - 38s 75ms/step - loss: 0.1068 - accuracy: 0.7871 - val_loss: 0.1286 - val_accuracy: 0.7295
# Epoch 180/1000
# 500/500 [==============================] - 38s 76ms/step - loss: 0.1082 - accuracy: 0.7827 - val_loss: 0.1286 - val_accuracy: 0.7293
# Epoch 181/1000
# 500/500 [==============================] - 38s 76ms/step - loss: 0.1069 - accuracy: 0.7857 - val_loss: 0.1285 - val_accuracy: 0.7306
# Epoch 182/1000
# 500/500 [==============================] - 38s 76ms/step - loss: 0.1074 - accuracy: 0.7845 - val_loss: 0.1286 - val_accuracy: 0.7301
# Epoch 183/1000
# 500/500 [==============================] - 38s 76ms/step - loss: 0.1083 - accuracy: 0.7839 - val_loss: 0.1286 - val_accuracy: 0.7301
# Epoch 184/1000
# 500/500 [==============================] - 38s 77ms/step - loss: 0.1078 - accuracy: 0.7839 - val_loss: 0.1286 - val_accuracy: 0.7300
# Epoch 185/1000
# 500/500 [==============================] - 38s 76ms/step - loss: 0.1087 - accuracy: 0.7827 - val_loss: 0.1286 - val_accuracy: 0.7314
# Epoch 186/1000
# 500/500 [==============================] - 38s 76ms/step - loss: 0.1074 - accuracy: 0.7839 - val_loss: 0.1285 - val_accuracy: 0.7315
# Epoch 187/1000
# 500/500 [==============================] - ETA: 0s - loss: 0.1064 - accuracy: 0.7864
# Epoch 00187: ReduceLROnPlateau reducing learning rate to 1.9531250927684596e-06.
# 500/500 [==============================] - 38s 76ms/step - loss: 0.1064 - accuracy: 0.7864 - val_loss: 0.1286 - val_accuracy: 0.7316
# Epoch 188/1000
# 500/500 [==============================] - 38s 76ms/step - loss: 0.1081 - accuracy: 0.7842 - val_loss: 0.1286 - val_accuracy: 0.7309
# Epoch 189/1000
# 500/500 [==============================] - 38s 76ms/step - loss: 0.1069 - accuracy: 0.7845 - val_loss: 0.1286 - val_accuracy: 0.7316
# Epoch 190/1000
# 500/500 [==============================] - 38s 76ms/step - loss: 0.1064 - accuracy: 0.7861 - val_loss: 0.1286 - val_accuracy: 0.7310
# Epoch 191/1000
# 500/500 [==============================] - 38s 76ms/step - loss: 0.1075 - accuracy: 0.7844 - val_loss: 0.1286 - val_accuracy: 0.7304
# Epoch 192/1000
# 500/500 [==============================] - ETA: 0s - loss: 0.1071 - accuracy: 0.7859Restoring model weights from the end of the best epoch.
# 500/500 [==============================] - 38s 76ms/step - loss: 0.1071 - accuracy: 0.7859 - val_loss: 0.1286 - val_accuracy: 0.7309
# Epoch 00192: early stopping

# %%
import matplotlib.pyplot as plt

fig = plt.figure(figsize=(10,6))
plt.plot(hist.history['loss'], color='#785ef0')
plt.plot(hist.history['val_loss'], color='#dc267f')
plt.title('Model Loss Progress')
plt.ylabel('Binary Cross-Entropy Loss')
plt.xlabel('Epoch')
plt.legend(['Training Set', 'Test Set'], loc='upper right')
plt.savefig('3*3 freq-5 theta-10.cifar10.loss.png', dpi=350, bbox_inches='tight')
plt.show()

# %%
from sklearn.preprocessing import MinMaxScaler

cnnl1 = classifier.layers[1].name   # get the name of the first conv layer
W = classifier.get_layer(name=cnnl1).get_weights()[0]   #get the filters
wshape = W.shape  #save the original shape

# this part will scale to [0, 1] for visualization purposes
scaler = MinMaxScaler()
scaler.fit(W.reshape(-1,1))|
W = scaler.transform(W.reshape(-1,1))
W = W.reshape(wshape)

# since there are 64 filters, we will display them 8x8
fig, axs = plt.subplots(8,8, figsize=(24,24))
fig.subplots_adjust(hspace = .25, wspace=.001)
axs = axs.ravel()
for i in range(W.shape[-1]):
  # we reshape to a 3D (RGB) image shape and display
  h = np.reshape(W[:,:,:,i], (3,3,3))
  axs[i].imshow(h)
  axs[i].set_title('Filter ' + str(i))    
plt.savefig("3*3 freq-5 theta-10.cifar10.filters.png", bbox_inches='tight', dpi=350)
# Out:
#   File "<ipython-input-9-027c5b7002bb>", line 9
#     scaler.fit(W.reshape(-1,1))|
#                                 ^
# SyntaxError: invalid syntax

# %%
cnnl1 = classifier.layers[1].name   # get the name of the first conv layer
W = classifier.get_layer(name=cnnl1).get_weights()[0]
plt.hist(W.ravel(), bins=100)
print(np.min(W),np.max(W))
